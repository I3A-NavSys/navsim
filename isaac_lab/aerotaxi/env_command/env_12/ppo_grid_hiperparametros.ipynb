# %%
# Parámetros a configurar:
import os
experiment_name = "command8"
task_name = "Command8"
cfg_dir = "C:/Users/Teresa/Documents/GitHub/navsim/isaac_lab/aerotaxi/env_command/env_12/grid_hiperparametros/cfg_files"
path_resultados = "C:/Users/Teresa/Documents/GitHub/navsim/tmp/tmpTeresa/resultados_grid_command_v8"
isaaclab_bat = "C:/Users/Teresa/Desktop/RuralData/IsaacLab/IsaacLab/isaaclab.bat"
train_script = "C:/Users/Teresa/Documents/GitHub/navsim/isaac_lab/rl_v5_1_0/rsl_rl/train.py"
id_task = f"Isaac-{task_name}-Aerotaxi-RANDOM" # luego se le añade el número de task con el guión (Isaac-Command2-Aerotaxi-RANDOM-34)
play_script = "C:/Users/Teresa/Documents/GitHub/navsim/isaac_lab/rl_v5_1_0/rsl_rl/play.py"
num_iter = "1001"
num_steps_per_env = 100
powershell_script = os.path.join(cfg_dir, "run_all.ps1")

# el num_steps_per_env = 100 también está en el env, al final del todo, y deben tener el mismo valor
# Recuerda iniciar en el init todos los experimentos

# %%
import random
import os

# Si los directorios no existen (el último indicado), lo crea
os.makedirs(cfg_dir, exist_ok=True)
os.makedirs(path_resultados, exist_ok=True)
# Opciones de hiperparámetros
param_options = {
    "init_noise_std": [0.0, 0.1, 0.2, 0.5, 0.8, 1.0],
    "actor_hidden_dims": [[64, 64], [128, 128], [256, 256], [128, 64]],
    "critic_hidden_dims": [[64, 64], [128, 128], [256, 256]],
    "activation": ["relu", "tanh", "elu", "gelu"],
    "value_loss_coef": [0.5, 1.0, 2.0],
    "clip_param": [0.1, 0.2, 0.3],
    "entropy_coef": [0.0, 0.001, 0.01, 0.05],
    "num_learning_epochs": [4, 8, 12],
    "num_mini_batches": [2, 4, 8],
    "learning_rate": [5e-05, 1e-4, 3e-4, 1e-3, 3e-3],
    "gamma": [0.95, 0.98, 0.99],
    "lam": [0.90, 0.95, 0.97],
    "max_grad_norm": [0.5, 1.0, 2.0],
    "desired_kl": [0.005, 0.008, 0.01, 0.02],
}

num_trials = 35  # cantidad de configuraciones

cfg_files = []

for i in range(num_trials):
    run_name = f"ppo_random_{experiment_name}_{i+1}"
    sampled = {k: random.choice(v) for k, v in param_options.items()}

    # Convertir listas a string
    actor_dims = sampled["actor_hidden_dims"]
    critic_dims = sampled["critic_hidden_dims"]

    cfg_content = f"""
from isaaclab.utils import configclass
from isaaclab_rl.rsl_rl import RslRlOnPolicyRunnerCfg, RslRlPpoActorCriticCfg, RslRlPpoAlgorithmCfg

@configclass
class {task_name}PPORunnerCfg(RslRlOnPolicyRunnerCfg):
    num_steps_per_env = {num_steps_per_env} 
    max_iterations = {num_iter}
    save_interval = 100
    experiment_name = "{experiment_name}"
    run_name = "{run_name}"
    resume = False
    empirical_normalization = False
    csv_path_metrics = "{path_resultados}"
    callbacks = True
    policy = RslRlPpoActorCriticCfg(
        init_noise_std={sampled['init_noise_std']},
        actor_hidden_dims={actor_dims},
        critic_hidden_dims={critic_dims},
        activation="{sampled['activation']}",
    )
    algorithm = RslRlPpoAlgorithmCfg(
        value_loss_coef={sampled['value_loss_coef']},
        use_clipped_value_loss=True,
        clip_param={sampled['clip_param']},
        entropy_coef={sampled['entropy_coef']},
        num_learning_epochs={sampled['num_learning_epochs']},
        num_mini_batches={sampled['num_mini_batches']},
        learning_rate={sampled['learning_rate']},
        schedule="adaptive",
        gamma={sampled['gamma']},
        lam={sampled['lam']},
        desired_kl={sampled['desired_kl']},
        max_grad_norm={sampled['max_grad_norm']},
    )
"""
    cfg_path = os.path.join(cfg_dir, f"{run_name}_cfg.py")
    with open(cfg_path, "w") as f:
        f.write(cfg_content.strip())
    cfg_files.append((run_name, cfg_path))

# Crear archivo PowerShell para ejecutar todas las configuraciones
powershell_script = os.path.join(cfg_dir, "run_all.ps1")

num_envs =  [64, 128, 512, 1024, 2048, 4096, 8196] #número de entornos para train (paralelizados)

with open(powershell_script, "w") as f:
    f.write("$ErrorActionPreference = 'Stop'\n\n")
    j = 0
    for run_name, cfg_path in cfg_files:
        # Convertir path a módulo Python (reemplazar / y .py)
        num_envs_i = random.choice(num_envs)
        module_path = cfg_path.replace("/", ".").replace("\\", ".").replace(".py", "")
        f.write(f'Write-Host "Ejecutando {run_name}"\n')
        f.write(f'& "{isaaclab_bat}" -p "{train_script}" --task {id_task}-{j+1} --num_envs {num_envs_i} --headless \n\n')
        j += 1
print("Archivos de configuración generados y script PowerShell listo en:", powershell_script)
# Out:
# Archivos de configuración generados y script PowerShell listo en: C:/Users/Teresa/Documents/GitHub/navsim/isaac_lab/aerotaxi/env_command/env_11/grid_hiperparametros/cfg_files\run_all.ps1

# %%
# Ejecuta el entrenamiento de forma automática
# !powershell -ExecutionPolicy Bypass -File "{powershell_script}"
import subprocess
import sys

# Ruta al script que generaste
powershell_script_path = powershell_script 

print(f"Iniciando ejecución de: {powershell_script_path}\n")

# Ejecutamos el proceso capturando la salida en tiempo real
process = subprocess.Popen(
    ["powershell.exe", "-ExecutionPolicy", "Bypass", "-File", powershell_script_path],
    stdout=subprocess.PIPE,
    stderr=subprocess.STDOUT, # Redirigimos errores a la salida estándar para verlos
    text=True,
    bufsize=1
)

# Leemos la salida línea a línea conforme se genera
try:
    for line in process.stdout:
        print(line, end="") # Imprime la salida de PowerShell en la celda
        sys.stdout.flush()   # Fuerza a Jupyter a mostrar la línea inmediatamente
except KeyboardInterrupt:
    process.kill()
    print("\nEntrenamiento cancelado por el usuario.")

process.wait()
print("\n--- Todos los experimentos han finalizado ---")
# Out:
# Iniciando ejecución de: C:/Users/Teresa/Documents/GitHub/navsim/isaac_lab/aerotaxi/env_command/env_12/grid_hiperparametros/cfg_files\run_all.ps1
#
# Ejecutando ppo_random_command8_11
# [INFO] Using python from: C:\Users\Teresa\miniconda3\envs\env_isaaclab\python.exe
# [INFO][AppLauncher]: Using device: cuda:0
# [INFO][AppLauncher]: Loading experience file: C:\Users\Teresa\miniconda3\envs\env_isaaclab\Lib\site-packages\isaaclab\apps\isaaclab.python.headless.kit
# Loading user config located at: 'c:/users/teresa/miniconda3/envs/env_isaaclab/lib/site-packages/isaacsim/kit/data/Kit/Isaac-Sim/5.1/user.config.json'
# [Info] [carb] Logging to file: c:/users/teresa/miniconda3/envs/env_isaaclab/lib/site-packages/isaacsim/kit/logs/Kit/Isaac-Sim/5.1/kit_20260303_092831.log
# 2026-03-03T08:28:31Z s] [Warning] [omni.usd_config.extension] Enable omni.materialx.libs extension to use MaterialX
# 2026-03-03T08:28:32Z s] [Warning] [carb] Acquiring non optional plugin interface which is not listed as dependency: [omni::physx::IPhysxBenchmarks v1.0] (plugin: <default plugin>), by client: omni.physics.physx.plugin. Add it to CARB_PLUGIN_IMPL_DEPS() macro of a client.
# 2026-03-03T08:28:32Z s] [Warning] [omni.isaac.dynamic_control] omni.isaac.dynamic_control is deprecated as of Isaac Sim 4.5. No action is needed from end-users.
# 2026-03-03T08:28:33Z [2,317ms] [Warning] [gpu.foundation.plugin] Skipping unsupported non-NVIDIA GPU: AMD Radeon(TM) Graphics
# 2026-03-03T08:28:33Z [2,318ms] [Warning] [gpu.foundation.plugin] Skipping unsupported non-NVIDIA GPU: AMD Radeon(TM) Graphics
#
# |---------------------------------------------------------------------------------------------|
# | Driver Version: 581.29        | Graphics API: D3D12
# |=============================================================================================|
# | GPU | Name                             | Active | LDA | GPU Memory | Vendor-ID | LUID       |
# |     |                                  |        |     |            | Device-ID | UUID       |
# |     |                                  |        |     |            | Bus-ID    |            |
# |---------------------------------------------------------------------------------------------|
# | 0   | NVIDIA GeForce RTX 5080          | Yes: 0 |     | 15889   MB | 10de      | 295a0100.. |
# |     |                                  |        |     |            | 2c02      | 0          |
# |     |                                  |        |     |            | 1         |            |
# |---------------------------------------------------------------------------------------------|
# | 1   | AMD Radeon(TM) Graphics          |        |     | 1995    MB | 1002      | 876d0100.. |
# |     |                                  |        |     |            | 13c0      | 0          |
# |     |                                  |        |     |            | N/A       |            |
# |=============================================================================================|
# | OS: Windows 11 Pro, Version: 10.0 (25H2), Build: 26200, Kernel: 10.0.26100.7824
# | Processor: AMD Ryzen 9 9950X 16-Core Processor
# | Cores: 16 | Logical Cores: 32
# |---------------------------------------------------------------------------------------------|
# | Total Memory (MB): 128627 | Free Memory: 101257
# | Total Page/Swap (MB): 136819 | Free Page/Swap: 101766
# |---------------------------------------------------------------------------------------------|
# C:\Users\Teresa\Documents\GitHub\navsim\isaac_lab\aerotaxi\env_command\env_12\flight_plan.py:29: UserWarning: Treat the new Tool classes introduced in v1.5 as experimental for now; the API and rcParam may change in future versions.
#   plt.rcParams["toolbar"] = "toolmanager"
# [INFO]: Parsing configuration from: aerotaxi.env_command.env_12.env:UAVEnvCfg
# [INFO]: Parsing configuration from: aerotaxi.env_command.env_12.grid_hiperparametros.cfg_files.ppo_random_command8_11_cfg:Command8PPORunnerCfg
# [INFO] Logging experiment in directory: C:\Users\Teresa\Documents\GitHub\navsim\isaac_lab\aerotaxi\env_command\env_12\logs\rsl_rl\command8
# Exact experiment name requested from command line: 2026-03-03_09-28-35
# Setting seed: 42
# [INFO]: Base environment:
# 	Environment device    : cuda:0
# 	Environment seed      : 42
# 	Physics step-size     : 0.005
# 	Rendering step-size   : 0.02
# 	Environment step-size : 0.02
# [INFO]: Time taken for scene creation : 4.057717 seconds
# [INFO]: Scene manager:  <class InteractiveScene>
# 	Number of environments: 8196
# 	Environment spacing   : 200.0
# 	Source prim name      : /World/envs/env_0
# 	Global prim paths     : []
# 	Replicate physics     : False
# [INFO]: Starting the simulation. This may take a few seconds. Please wait...
# [INFO]: Time taken for simulation start : 5.929745 seconds
# [INFO] Command Manager:  <CommandManager> contains 1 active terms.
# +--------------------------------------+
# |         Active Command Terms         |
# +-------+-------------+----------------+
# | Index | Name        |      Type      |
# +-------+-------------+----------------+
# |   0   | vel_command | UAVcommandTerm |
# +-------+-------------+----------------+
#
# [INFO] Event Manager:  <EventManager> contains 1 active terms.
# +-----------------------------------+
# | Active Event Terms in Mode: 'reset' |
# +----------+------------------------+
# |  Index   | Name                   |
# +----------+------------------------+
# |    0     | reset_pos              |
# |    1     | randomize_mass         |
# |    2     | randomize_wind         |
# +----------+------------------------+
#
# [INFO] Recorder Manager:  <RecorderManager> contains 0 active terms.
# +---------------------+
# | Active Recorder Terms |
# +-----------+---------+
# |   Index   | Name    |
# +-----------+---------+
# +-----------+---------+
#
# [INFO] Action Manager:  <ActionManager> contains 1 active terms.
# +-----------------------------------+
# |   Active Action Terms (shape: 4)  |
# +--------+-------------+------------+
# | Index  | Name        |  Dimension |
# +--------+-------------+------------+
# |   0    | rotors_vel  |          4 |
# +--------+-------------+------------+
#
# [INFO] Observation Manager: <ObservationManager> contains 2 groups.
# +---------------------------------------------------------+
# | Active Observation Terms in Group: 'policy' (shape: (13,)) |
# +-----------+---------------------------------+-----------+
# |   Index   | Name                            |   Shape   |
# +-----------+---------------------------------+-----------+
# |     0     | dist                            |    (3,)   |
# |     1     | lin_vel                         |    (3,)   |
# |     2     | ang_vel                         |    (3,)   |
# |     3     | height                          |    (1,)   |
# |     4     | projected_gravity               |    (3,)   |
# +-----------+---------------------------------+-----------+
# +---------------------------------------------------------+
# | Active Observation Terms in Group: 'critic' (shape: (13,)) |
# +-----------+---------------------------------+-----------+
# |   Index   | Name                            |   Shape   |
# +-----------+---------------------------------+-----------+
# |     0     | dist                            |    (3,)   |
# |     1     | lin_vel                         |    (3,)   |
# |     2     | ang_vel                         |    (3,)   |
# |     3     | height                          |    (1,)   |
# |     4     | projected_gravity               |    (3,)   |
# +-----------+---------------------------------+-----------+
#
# [INFO] Termination Manager:  <TerminationManager> contains 4 active terms.
# +---------------------------------------+
# |        Active Termination Terms       |
# +-------+--------------------+----------+
# | Index | Name               | Time Out |
# +-------+--------------------+----------+
# |   0   | time_out           |   True   |
# |   1   | below_min_altitude |  False   |
# |   2   | bad_attitude       |  False   |
# |   3   | safety_shutdown    |  False   |
# +-------+--------------------+----------+
#
# [INFO] Reward Manager:  <RewardManager> contains 6 active terms.
# +------------------------------------------+
# |           Active Reward Terms            |
# +-------+-------------------------+--------+
# | Index | Name                    | Weight |
# +-------+-------------------------+--------+
# |   0   | rew_attitude_stability2 |    2.0 |
# |   1   | rew_ang_vel_stability4  |    3.0 |
# |   2   | rew_altitude_hold2      |    4.0 |
# |   3   | rew_vel2                |    3.0 |
# |   4   | rew_pos2                |    3.0 |
# |   5   | rew_action_rate         |    0.5 |
# +-------+-------------------------+--------+
#
# [INFO] Curriculum Manager:  <CurriculumManager> contains 0 active terms.
# +----------------------+
# | Active Curriculum Terms |
# +-----------+----------+
# |   Index   | Name     |
# +-----------+----------+
# +-----------+----------+
#
# [INFO]: Completed setting up the environment...
# 2026-03-03T08:28:45Z [14,014ms] [Warning] [omni.physx.fabric.plugin] FabricManager::initializePointInstancer mismatched prototypes on point instancer: /Visuals/target_commands.
# C:\Users\Teresa\miniconda3\envs\env_isaaclab\Lib\site-packages\rsl_rl\utils\utils.py:244: UserWarning: The observation configuration dictionary 'obs_groups' must contain the 'policy' key. As an observation group with the name 'policy' was found, this is assumed to be the observation set. Consider adding the 'policy' key to the 'obs_groups' dictionary for clarity. This behavior will be removed in a future version.
#   warnings.warn(
# C:\Users\Teresa\miniconda3\envs\env_isaaclab\Lib\site-packages\rsl_rl\utils\utils.py:282: UserWarning: The observation configuration dictionary 'obs_groups' must contain the 'critic' key. As an observation group with the name 'critic' was found, this is assumed to be the observation set. Consider adding the 'critic' key to the 'obs_groups' dictionary for clarity. This behavior will be removed in a future version.
#   warnings.warn(
# --------------------------------------------------------------------------------
# Resolved observation sets:
# 	 policy :  ['policy']
# 	 critic :  ['critic']
# --------------------------------------------------------------------------------
# Actor MLP: MLP(
#   (0): Linear(in_features=13, out_features=128, bias=True)
#   (1): ELU(alpha=1.0)
#   (2): Linear(in_features=128, out_features=128, bias=True)
#   (3): ELU(alpha=1.0)
#   (4): Linear(in_features=128, out_features=128, bias=True)
#   (5): ELU(alpha=1.0)
#   (6): Linear(in_features=128, out_features=128, bias=True)
#   (7): ELU(alpha=1.0)
#   (8): Linear(in_features=128, out_features=4, bias=True)
# )
# Critic MLP: MLP(
#   (0): Linear(in_features=13, out_features=512, bias=True)
#   (1): ELU(alpha=1.0)
#   (2): Linear(in_features=512, out_features=512, bias=True)
#   (3): ELU(alpha=1.0)
#   (4): Linear(in_features=512, out_features=512, bias=True)
#   (5): ELU(alpha=1.0)
#   (6): Linear(in_features=512, out_features=512, bias=True)
#   (7): ELU(alpha=1.0)
#   (8): Linear(in_features=512, out_features=512, bias=True)
#   (9): ELU(alpha=1.0)
#   (10): Linear(in_features=512, out_features=1, bias=True)
# )
# ################################################################################
#                        Learning iteration 0/1001
#
#                        Computation: 158706 steps/s (collection: 5.258s, learning 1.352s)
#              Mean action noise std: 0.05
#           Mean value_function loss: 4.0201
#                Mean surrogate loss: 0.1004
#                  Mean entropy loss: -6.1759
#                        Mean reward: 15.45
#                Mean episode length: 123.48
# Episode_Reward/rew_attitude_stability2: 0.0399
# Episode_Reward/rew_ang_vel_stability4: 0.1221
#  Episode_Reward/rew_altitude_hold2: 0.1246
#            Episode_Reward/rew_vel2: 0.0168
#            Episode_Reward/rew_pos2: 0.0772
#     Episode_Reward/rew_action_rate: -0.0000
#       Episode_Termination/time_out: 0.0457
# Episode_Termination/below_min_altitude: 0.0209
#   Episode_Termination/bad_attitude: 0.1194
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 1049088
#                     Iteration time: 6.61s
#                       Time elapsed: 00:00:06
#                                ETA: 01:50:16
#
# Could not find git repository in C:\Users\Teresa\miniconda3\envs\env_isaaclab\Lib\site-packages\rsl_rl\__init__.py. Skipping.
# Storing git diff for 'navsim' in: C:\Users\Teresa\Documents\GitHub\navsim\isaac_lab\aerotaxi\env_command\env_12\logs\rsl_rl\command8\2026-03-03_09-28-35_ppo_random_command8_11\git\navsim.diff
# ################################################################################
#                        Learning iteration 1/1001
#
#                        Computation: 195907 steps/s (collection: 4.106s, learning 1.249s)
#              Mean action noise std: 0.05
#           Mean value_function loss: 3.1145
#                Mean surrogate loss: 0.0274
#                  Mean entropy loss: -6.1783
#                        Mean reward: 12.28
#                Mean episode length: 89.08
# Episode_Reward/rew_attitude_stability2: 0.0640
# Episode_Reward/rew_ang_vel_stability4: 0.1852
#  Episode_Reward/rew_altitude_hold2: 0.1727
#            Episode_Reward/rew_vel2: 0.0204
#            Episode_Reward/rew_pos2: 0.0973
#     Episode_Reward/rew_action_rate: -0.0000
#       Episode_Termination/time_out: 0.0219
# Episode_Termination/below_min_altitude: 0.2062
#   Episode_Termination/bad_attitude: 0.6967
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 2098176
#                     Iteration time: 5.36s
#                       Time elapsed: 00:00:11
#                                ETA: 01:39:42
#
# ################################################################################
#                        Learning iteration 2/1001
#
#                        Computation: 197568 steps/s (collection: 4.062s, learning 1.248s)
#              Mean action noise std: 0.05
#           Mean value_function loss: 2.9470
#                Mean surrogate loss: 0.0175
#                  Mean entropy loss: -6.0815
#                        Mean reward: 12.75
#                Mean episode length: 93.00
# Episode_Reward/rew_attitude_stability2: 0.0523
# Episode_Reward/rew_ang_vel_stability4: 0.1515
#  Episode_Reward/rew_altitude_hold2: 0.1630
#            Episode_Reward/rew_vel2: 0.0200
#            Episode_Reward/rew_pos2: 0.0974
#     Episode_Reward/rew_action_rate: -0.0000
#       Episode_Termination/time_out: 0.0012
# Episode_Termination/below_min_altitude: 0.0535
#   Episode_Termination/bad_attitude: 0.9429
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 3147264
#                     Iteration time: 5.31s
#                       Time elapsed: 00:00:17
#                                ETA: 01:35:52
#
# ################################################################################
#                        Learning iteration 3/1001
#
#                        Computation: 196605 steps/s (collection: 4.088s, learning 1.248s)
#              Mean action noise std: 0.05
#           Mean value_function loss: 2.7240
#                Mean surrogate loss: 0.0224
#                  Mean entropy loss: -6.0036
#                        Mean reward: 12.08
#                Mean episode length: 88.49
# Episode_Reward/rew_attitude_stability2: 0.0525
# Episode_Reward/rew_ang_vel_stability4: 0.1544
#  Episode_Reward/rew_altitude_hold2: 0.1631
#            Episode_Reward/rew_vel2: 0.0197
#            Episode_Reward/rew_pos2: 0.0968
#     Episode_Reward/rew_action_rate: -0.0000
#       Episode_Termination/time_out: 0.0001
# Episode_Termination/below_min_altitude: 0.0527
#   Episode_Termination/bad_attitude: 0.9468
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 4196352
#                     Iteration time: 5.34s
#                       Time elapsed: 00:00:22
#                                ETA: 01:34:01
#
# ################################################################################
#                        Learning iteration 4/1001
#
#                        Computation: 197271 steps/s (collection: 4.069s, learning 1.249s)
#              Mean action noise std: 0.05
#           Mean value_function loss: 2.6200
#                Mean surrogate loss: 0.0269
#                  Mean entropy loss: -5.9170
#                        Mean reward: 12.77
#                Mean episode length: 94.62
# Episode_Reward/rew_attitude_stability2: 0.0531
# Episode_Reward/rew_ang_vel_stability4: 0.1588
#  Episode_Reward/rew_altitude_hold2: 0.1642
#            Episode_Reward/rew_vel2: 0.0201
#            Episode_Reward/rew_pos2: 0.0973
#     Episode_Reward/rew_action_rate: -0.0000
#       Episode_Termination/time_out: 0.0001
# Episode_Termination/below_min_altitude: 0.0611
#   Episode_Termination/bad_attitude: 0.9388
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 5245440
#                     Iteration time: 5.32s
#                       Time elapsed: 00:00:27
#                                ETA: 01:32:49
#
# ################################################################################
#                        Learning iteration 5/1001
#
#                        Computation: 195925 steps/s (collection: 4.103s, learning 1.252s)
#              Mean action noise std: 0.06
#           Mean value_function loss: 2.4893
#                Mean surrogate loss: 0.0138
#                  Mean entropy loss: -5.8839
#                        Mean reward: 12.47
#                Mean episode length: 93.81
# Episode_Reward/rew_attitude_stability2: 0.0542
# Episode_Reward/rew_ang_vel_stability4: 0.1622
#  Episode_Reward/rew_altitude_hold2: 0.1663
#            Episode_Reward/rew_vel2: 0.0201
#            Episode_Reward/rew_pos2: 0.0969
#     Episode_Reward/rew_action_rate: -0.0000
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 0.0778
#   Episode_Termination/bad_attitude: 0.9222
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 6294528
#                     Iteration time: 5.35s
#                       Time elapsed: 00:00:33
#                                ETA: 01:32:05
#
# ################################################################################
#                        Learning iteration 6/1001
#
#                        Computation: 193537 steps/s (collection: 4.170s, learning 1.251s)
#              Mean action noise std: 0.06
#           Mean value_function loss: 2.3482
#                Mean surrogate loss: 0.0255
#                  Mean entropy loss: -5.7936
#                        Mean reward: 12.50
#                Mean episode length: 92.30
# Episode_Reward/rew_attitude_stability2: 0.0542
# Episode_Reward/rew_ang_vel_stability4: 0.1607
#  Episode_Reward/rew_altitude_hold2: 0.1657
#            Episode_Reward/rew_vel2: 0.0202
#            Episode_Reward/rew_pos2: 0.0973
#     Episode_Reward/rew_action_rate: -0.0000
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 0.0693
#   Episode_Termination/bad_attitude: 0.9307
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 7343616
#                     Iteration time: 5.42s
#                       Time elapsed: 00:00:38
#                                ETA: 01:31:41
#
# ################################################################################
#                        Learning iteration 7/1001
#
#                        Computation: 195724 steps/s (collection: 4.110s, learning 1.250s)
#              Mean action noise std: 0.06
#           Mean value_function loss: 2.1230
#                Mean surrogate loss: 0.0140
#                  Mean entropy loss: -5.7824
#                        Mean reward: 12.55
#                Mean episode length: 92.47
# Episode_Reward/rew_attitude_stability2: 0.0538
# Episode_Reward/rew_ang_vel_stability4: 0.1605
#  Episode_Reward/rew_altitude_hold2: 0.1661
#            Episode_Reward/rew_vel2: 0.0203
#            Episode_Reward/rew_pos2: 0.0974
#     Episode_Reward/rew_action_rate: -0.0000
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 0.0672
#   Episode_Termination/bad_attitude: 0.9328
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 8392704
#                     Iteration time: 5.36s
#                       Time elapsed: 00:00:44
#                                ETA: 01:31:15
#
# ################################################################################
#                        Learning iteration 8/1001
#
#                        Computation: 195670 steps/s (collection: 4.115s, learning 1.247s)
#              Mean action noise std: 0.06
#           Mean value_function loss: 1.8205
#                Mean surrogate loss: 0.0135
#                  Mean entropy loss: -5.7107
#                        Mean reward: 11.85
#                Mean episode length: 88.34
# Episode_Reward/rew_attitude_stability2: 0.0537
# Episode_Reward/rew_ang_vel_stability4: 0.1584
#  Episode_Reward/rew_altitude_hold2: 0.1658
#            Episode_Reward/rew_vel2: 0.0201
#            Episode_Reward/rew_pos2: 0.0971
#     Episode_Reward/rew_action_rate: -0.0000
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 0.0728
#   Episode_Termination/bad_attitude: 0.9272
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 9441792
#                     Iteration time: 5.36s
#                       Time elapsed: 00:00:49
#                                ETA: 01:30:53
#
# ################################################################################
#                        Learning iteration 9/1001
#
#                        Computation: 196859 steps/s (collection: 4.081s, learning 1.248s)
#              Mean action noise std: 0.06
#           Mean value_function loss: 1.6398
#                Mean surrogate loss: 0.0110
#                  Mean entropy loss: -5.6506
#                        Mean reward: 12.23
#                Mean episode length: 91.87
# Episode_Reward/rew_attitude_stability2: 0.0520
# Episode_Reward/rew_ang_vel_stability4: 0.1542
#  Episode_Reward/rew_altitude_hold2: 0.1641
#            Episode_Reward/rew_vel2: 0.0199
#            Episode_Reward/rew_pos2: 0.0968
#     Episode_Reward/rew_action_rate: -0.0000
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 0.0555
#   Episode_Termination/bad_attitude: 0.9445
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 10490880
#                     Iteration time: 5.33s
#                       Time elapsed: 00:00:54
#                                ETA: 01:30:31
#
# ################################################################################
#                        Learning iteration 10/1001
#
#                        Computation: 191877 steps/s (collection: 4.209s, learning 1.258s)
#              Mean action noise std: 0.06
#           Mean value_function loss: 1.4224
#                Mean surrogate loss: 0.0133
#                  Mean entropy loss: -5.5877
#                        Mean reward: 11.75
#                Mean episode length: 89.21
# Episode_Reward/rew_attitude_stability2: 0.0521
# Episode_Reward/rew_ang_vel_stability4: 0.1535
#  Episode_Reward/rew_altitude_hold2: 0.1630
#            Episode_Reward/rew_vel2: 0.0200
#            Episode_Reward/rew_pos2: 0.0970
#     Episode_Reward/rew_action_rate: -0.0000
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 0.0574
#   Episode_Termination/bad_attitude: 0.9426
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 11539968
#                     Iteration time: 5.47s
#                       Time elapsed: 00:01:00
#                                ETA: 01:30:25
#
# ################################################################################
#                        Learning iteration 11/1001
#
#                        Computation: 195762 steps/s (collection: 4.112s, learning 1.247s)
#              Mean action noise std: 0.06
#           Mean value_function loss: 1.1089
#                Mean surrogate loss: 0.0089
#                  Mean entropy loss: -5.5314
#                        Mean reward: 11.81
#                Mean episode length: 89.22
# Episode_Reward/rew_attitude_stability2: 0.0520
# Episode_Reward/rew_ang_vel_stability4: 0.1538
#  Episode_Reward/rew_altitude_hold2: 0.1631
#            Episode_Reward/rew_vel2: 0.0198
#            Episode_Reward/rew_pos2: 0.0969
#     Episode_Reward/rew_action_rate: -0.0000
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 0.0559
#   Episode_Termination/bad_attitude: 0.9441
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 12589056
#                     Iteration time: 5.36s
#                       Time elapsed: 00:01:05
#                                ETA: 01:30:10
#
# ################################################################################
#                        Learning iteration 12/1001
#
#                        Computation: 195016 steps/s (collection: 4.127s, learning 1.253s)
#              Mean action noise std: 0.06
#           Mean value_function loss: 0.9109
#                Mean surrogate loss: 0.0095
#                  Mean entropy loss: -5.4699
#                        Mean reward: 12.07
#                Mean episode length: 92.80
# Episode_Reward/rew_attitude_stability2: 0.0530
# Episode_Reward/rew_ang_vel_stability4: 0.1594
#  Episode_Reward/rew_altitude_hold2: 0.1648
#            Episode_Reward/rew_vel2: 0.0199
#            Episode_Reward/rew_pos2: 0.0967
#     Episode_Reward/rew_action_rate: -0.0000
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 0.0706
#   Episode_Termination/bad_attitude: 0.9294
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 13638144
#                     Iteration time: 5.38s
#                       Time elapsed: 00:01:10
#                                ETA: 01:29:58
#
# ################################################################################
#                        Learning iteration 13/1001
#
#                        Computation: 197177 steps/s (collection: 4.066s, learning 1.254s)
#              Mean action noise std: 0.06
#           Mean value_function loss: 0.6856
#                Mean surrogate loss: 0.0080
#                  Mean entropy loss: -5.4073
#                        Mean reward: 12.84
#                Mean episode length: 95.18
# Episode_Reward/rew_attitude_stability2: 0.0539
# Episode_Reward/rew_ang_vel_stability4: 0.1633
#  Episode_Reward/rew_altitude_hold2: 0.1645
#            Episode_Reward/rew_vel2: 0.0198
#            Episode_Reward/rew_pos2: 0.0967
#     Episode_Reward/rew_action_rate: -0.0000
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 0.0884
#   Episode_Termination/bad_attitude: 0.9116
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 14687232
#                     Iteration time: 5.32s
#                       Time elapsed: 00:01:16
#                                ETA: 01:29:43
#
# ################################################################################
#                        Learning iteration 14/1001
#
#                        Computation: 195378 steps/s (collection: 4.119s, learning 1.251s)
#              Mean action noise std: 0.06
#           Mean value_function loss: 0.6007
#                Mean surrogate loss: 0.0074
#                  Mean entropy loss: -5.3589
#                        Mean reward: 12.12
#                Mean episode length: 89.05
# Episode_Reward/rew_attitude_stability2: 0.0543
# Episode_Reward/rew_ang_vel_stability4: 0.1637
#  Episode_Reward/rew_altitude_hold2: 0.1647
#            Episode_Reward/rew_vel2: 0.0200
#            Episode_Reward/rew_pos2: 0.0972
#     Episode_Reward/rew_action_rate: -0.0000
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 0.0917
#   Episode_Termination/bad_attitude: 0.9083
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 15736320
#                     Iteration time: 5.37s
#                       Time elapsed: 00:01:21
#                                ETA: 01:29:32
#
# ################################################################################
#                        Learning iteration 15/1001
#
#                        Computation: 197605 steps/s (collection: 4.061s, learning 1.248s)
#              Mean action noise std: 0.06
#           Mean value_function loss: 0.4721
#                Mean surrogate loss: 0.0164
#                  Mean entropy loss: -5.2895
#                        Mean reward: 12.58
#                Mean episode length: 94.85
# Episode_Reward/rew_attitude_stability2: 0.0543
# Episode_Reward/rew_ang_vel_stability4: 0.1645
#  Episode_Reward/rew_altitude_hold2: 0.1661
#            Episode_Reward/rew_vel2: 0.0200
#            Episode_Reward/rew_pos2: 0.0971
#     Episode_Reward/rew_action_rate: -0.0000
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 0.0873
#   Episode_Termination/bad_attitude: 0.9127
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 16785408
#                     Iteration time: 5.31s
#                       Time elapsed: 00:01:26
#                                ETA: 01:29:18
#
# ################################################################################
#                        Learning iteration 16/1001
#
#                        Computation: 196587 steps/s (collection: 4.088s, learning 1.248s)
#              Mean action noise std: 0.07
#           Mean value_function loss: 0.4454
#                Mean surrogate loss: 0.0047
#                  Mean entropy loss: -5.2186
#                        Mean reward: 13.06
#                Mean episode length: 100.06
# Episode_Reward/rew_attitude_stability2: 0.0557
# Episode_Reward/rew_ang_vel_stability4: 0.1732
#  Episode_Reward/rew_altitude_hold2: 0.1671
#            Episode_Reward/rew_vel2: 0.0201
#            Episode_Reward/rew_pos2: 0.0972
#     Episode_Reward/rew_action_rate: -0.0000
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 0.1092
#   Episode_Termination/bad_attitude: 0.8908
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 17834496
#                     Iteration time: 5.34s
#                       Time elapsed: 00:01:32
#                                ETA: 01:29:07
#
# ################################################################################
#                        Learning iteration 17/1001
#
#                        Computation: 196329 steps/s (collection: 4.094s, learning 1.249s)
#              Mean action noise std: 0.07
#           Mean value_function loss: 0.3137
#                Mean surrogate loss: 0.0082
#                  Mean entropy loss: -5.1469
#                        Mean reward: 12.65
#                Mean episode length: 100.32
# Episode_Reward/rew_attitude_stability2: 0.0576
# Episode_Reward/rew_ang_vel_stability4: 0.1807
#  Episode_Reward/rew_altitude_hold2: 0.1690
#            Episode_Reward/rew_vel2: 0.0201
#            Episode_Reward/rew_pos2: 0.0971
#     Episode_Reward/rew_action_rate: -0.0000
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 0.1490
#   Episode_Termination/bad_attitude: 0.8510
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 18883584
#                     Iteration time: 5.34s
#                       Time elapsed: 00:01:37
#                                ETA: 01:28:57
#
# ################################################################################
#                        Learning iteration 18/1001
#
#                        Computation: 196605 steps/s (collection: 4.086s, learning 1.250s)
#              Mean action noise std: 0.07
#           Mean value_function loss: 0.2804
#                Mean surrogate loss: 0.0044
#                  Mean entropy loss: -5.0821
#                        Mean reward: 13.53
#                Mean episode length: 100.97
# Episode_Reward/rew_attitude_stability2: 0.0584
# Episode_Reward/rew_ang_vel_stability4: 0.1838
#  Episode_Reward/rew_altitude_hold2: 0.1710
#            Episode_Reward/rew_vel2: 0.0201
#            Episode_Reward/rew_pos2: 0.0971
#     Episode_Reward/rew_action_rate: -0.0000
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 0.1535
#   Episode_Termination/bad_attitude: 0.8465
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 19932672
#                     Iteration time: 5.34s
#                       Time elapsed: 00:01:42
#                                ETA: 01:28:47
#
# ################################################################################
#                        Learning iteration 19/1001
#
#                        Computation: 193095 steps/s (collection: 4.156s, learning 1.277s)
#              Mean action noise std: 0.07
#           Mean value_function loss: 0.2415
#                Mean surrogate loss: 0.0046
#                  Mean entropy loss: -5.0088
#                        Mean reward: 13.59
#                Mean episode length: 102.58
# Episode_Reward/rew_attitude_stability2: 0.0599
# Episode_Reward/rew_ang_vel_stability4: 0.1880
#  Episode_Reward/rew_altitude_hold2: 0.1725
#            Episode_Reward/rew_vel2: 0.0204
#            Episode_Reward/rew_pos2: 0.0974
#     Episode_Reward/rew_action_rate: -0.0000
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 0.1693
#   Episode_Termination/bad_attitude: 0.8307
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 20981760
#                     Iteration time: 5.43s
#                       Time elapsed: 00:01:48
#                                ETA: 01:28:42
#
# ################################################################################
#                        Learning iteration 20/1001
#
#                        Computation: 196090 steps/s (collection: 4.100s, learning 1.250s)
#              Mean action noise std: 0.07
#           Mean value_function loss: 0.2327
#                Mean surrogate loss: 0.0043
#                  Mean entropy loss: -4.9446
#                        Mean reward: 13.51
#                Mean episode length: 104.86
# Episode_Reward/rew_attitude_stability2: 0.0603
# Episode_Reward/rew_ang_vel_stability4: 0.1923
#  Episode_Reward/rew_altitude_hold2: 0.1737
#            Episode_Reward/rew_vel2: 0.0203
#            Episode_Reward/rew_pos2: 0.0975
#     Episode_Reward/rew_action_rate: -0.0000
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 0.1834
#   Episode_Termination/bad_attitude: 0.8166
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 22030848
#                     Iteration time: 5.35s
#                       Time elapsed: 00:01:53
#                                ETA: 01:28:34
#
# ################################################################################
#                        Learning iteration 21/1001
#
#                        Computation: 198000 steps/s (collection: 4.051s, learning 1.247s)
#              Mean action noise std: 0.07
#           Mean value_function loss: 0.2366
#                Mean surrogate loss: 0.0026
#                  Mean entropy loss: -4.8735
#                        Mean reward: 13.82
#                Mean episode length: 106.45
# Episode_Reward/rew_attitude_stability2: 0.0622
# Episode_Reward/rew_ang_vel_stability4: 0.1987
#  Episode_Reward/rew_altitude_hold2: 0.1732
#            Episode_Reward/rew_vel2: 0.0203
#            Episode_Reward/rew_pos2: 0.0977
#     Episode_Reward/rew_action_rate: -0.0000
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 0.2092
#   Episode_Termination/bad_attitude: 0.7908
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 23079936
#                     Iteration time: 5.30s
#                       Time elapsed: 00:01:59
#                                ETA: 01:28:23
#
# ################################################################################
#                        Learning iteration 22/1001
#
#                        Computation: 197828 steps/s (collection: 4.055s, learning 1.248s)
#              Mean action noise std: 0.07
#           Mean value_function loss: 0.1787
#                Mean surrogate loss: 0.0016
#                  Mean entropy loss: -4.8053
#                        Mean reward: 15.00
#                Mean episode length: 113.73
# Episode_Reward/rew_attitude_stability2: 0.0639
# Episode_Reward/rew_ang_vel_stability4: 0.2044
#  Episode_Reward/rew_altitude_hold2: 0.1738
#            Episode_Reward/rew_vel2: 0.0203
#            Episode_Reward/rew_pos2: 0.0980
#     Episode_Reward/rew_action_rate: -0.0000
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 0.2321
#   Episode_Termination/bad_attitude: 0.7679
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 24129024
#                     Iteration time: 5.30s
#                       Time elapsed: 00:02:04
#                                ETA: 01:28:13
#
# ################################################################################
#                        Learning iteration 23/1001
#
#                        Computation: 195651 steps/s (collection: 4.112s, learning 1.250s)
#              Mean action noise std: 0.07
#           Mean value_function loss: 0.2034
#                Mean surrogate loss: 0.0019
#                  Mean entropy loss: -4.7254
#                        Mean reward: 14.75
#                Mean episode length: 115.29
# Episode_Reward/rew_attitude_stability2: 0.0668
# Episode_Reward/rew_ang_vel_stability4: 0.2161
#  Episode_Reward/rew_altitude_hold2: 0.1753
#            Episode_Reward/rew_vel2: 0.0202
#            Episode_Reward/rew_pos2: 0.0974
#     Episode_Reward/rew_action_rate: -0.0000
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 0.2690
#   Episode_Termination/bad_attitude: 0.7310
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 25178112
#                     Iteration time: 5.36s
#                       Time elapsed: 00:02:09
#                                ETA: 01:28:06
#
# ################################################################################
#                        Learning iteration 24/1001
#
#                        Computation: 196567 steps/s (collection: 4.090s, learning 1.247s)
#              Mean action noise std: 0.08
#           Mean value_function loss: 0.2119
#                Mean surrogate loss: 0.0016
#                  Mean entropy loss: -4.6574
#                        Mean reward: 15.01
#                Mean episode length: 117.97
# Episode_Reward/rew_attitude_stability2: 0.0708
# Episode_Reward/rew_ang_vel_stability4: 0.2283
#  Episode_Reward/rew_altitude_hold2: 0.1772
#            Episode_Reward/rew_vel2: 0.0200
#            Episode_Reward/rew_pos2: 0.0974
#     Episode_Reward/rew_action_rate: -0.0000
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 0.3251
#   Episode_Termination/bad_attitude: 0.6749
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 26227200
#                     Iteration time: 5.34s
#                       Time elapsed: 00:02:15
#                                ETA: 01:27:58
#
# ################################################################################
#                        Learning iteration 25/1001
#
#                        Computation: 195358 steps/s (collection: 4.113s, learning 1.257s)
#              Mean action noise std: 0.08
#           Mean value_function loss: 0.2042
#                Mean surrogate loss: 0.0011
#                  Mean entropy loss: -4.5882
#                        Mean reward: 15.50
#                Mean episode length: 123.73
# Episode_Reward/rew_attitude_stability2: 0.0743
# Episode_Reward/rew_ang_vel_stability4: 0.2403
#  Episode_Reward/rew_altitude_hold2: 0.1793
#            Episode_Reward/rew_vel2: 0.0203
#            Episode_Reward/rew_pos2: 0.0977
#     Episode_Reward/rew_action_rate: -0.0000
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 0.3729
#   Episode_Termination/bad_attitude: 0.6271
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 27276288
#                     Iteration time: 5.37s
#                       Time elapsed: 00:02:20
#                                ETA: 01:27:51
#
# ################################################################################
#                        Learning iteration 26/1001
#
#                        Computation: 196972 steps/s (collection: 4.081s, learning 1.245s)
#              Mean action noise std: 0.08
#           Mean value_function loss: 0.2576
#                Mean surrogate loss: 0.0008
#                  Mean entropy loss: -4.5209
#                        Mean reward: 15.70
#                Mean episode length: 125.08
# Episode_Reward/rew_attitude_stability2: 0.0783
# Episode_Reward/rew_ang_vel_stability4: 0.2523
#  Episode_Reward/rew_altitude_hold2: 0.1830
#            Episode_Reward/rew_vel2: 0.0207
#            Episode_Reward/rew_pos2: 0.0981
#     Episode_Reward/rew_action_rate: -0.0000
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 0.4239
#   Episode_Termination/bad_attitude: 0.5761
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 28325376
#                     Iteration time: 5.33s
#                       Time elapsed: 00:02:25
#                                ETA: 01:27:43
#
# ################################################################################
#                        Learning iteration 27/1001
#
#                        Computation: 197863 steps/s (collection: 4.054s, learning 1.248s)
#              Mean action noise std: 0.08
#           Mean value_function loss: 0.2163
#                Mean surrogate loss: 0.0032
#                  Mean entropy loss: -4.4588
#                        Mean reward: 17.19
#                Mean episode length: 135.25
# Episode_Reward/rew_attitude_stability2: 0.0826
# Episode_Reward/rew_ang_vel_stability4: 0.2630
#  Episode_Reward/rew_altitude_hold2: 0.1873
#            Episode_Reward/rew_vel2: 0.0209
#            Episode_Reward/rew_pos2: 0.0987
#     Episode_Reward/rew_action_rate: -0.0000
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 0.4570
#   Episode_Termination/bad_attitude: 0.5430
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 29374464
#                     Iteration time: 5.30s
#                       Time elapsed: 00:02:31
#                                ETA: 01:27:34
#
# ################################################################################
#                        Learning iteration 28/1001
#
#                        Computation: 195016 steps/s (collection: 4.129s, learning 1.250s)
#              Mean action noise std: 0.08
#           Mean value_function loss: 0.2099
#                Mean surrogate loss: 0.0006
#                  Mean entropy loss: -4.3929
#                        Mean reward: 17.23
#                Mean episode length: 137.86
# Episode_Reward/rew_attitude_stability2: 0.0872
# Episode_Reward/rew_ang_vel_stability4: 0.2733
#  Episode_Reward/rew_altitude_hold2: 0.1873
#            Episode_Reward/rew_vel2: 0.0204
#            Episode_Reward/rew_pos2: 0.0978
#     Episode_Reward/rew_action_rate: -0.0000
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 0.4868
#   Episode_Termination/bad_attitude: 0.5132
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 30423552
#                     Iteration time: 5.38s
#                       Time elapsed: 00:02:36
#                                ETA: 01:27:28
#
# ################################################################################
#                        Learning iteration 29/1001
#
#                        Computation: 197904 steps/s (collection: 4.053s, learning 1.248s)
#              Mean action noise std: 0.08
#           Mean value_function loss: 0.2242
#                Mean surrogate loss: 0.0006
#                  Mean entropy loss: -4.3295
#                        Mean reward: 17.30
#                Mean episode length: 140.01
# Episode_Reward/rew_attitude_stability2: 0.0889
# Episode_Reward/rew_ang_vel_stability4: 0.2782
#  Episode_Reward/rew_altitude_hold2: 0.1889
#            Episode_Reward/rew_vel2: 0.0205
#            Episode_Reward/rew_pos2: 0.0983
#     Episode_Reward/rew_action_rate: -0.0000
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 0.4891
#   Episode_Termination/bad_attitude: 0.5109
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 31472640
#                     Iteration time: 5.30s
#                       Time elapsed: 00:02:41
#                                ETA: 01:27:20
#
# ################################################################################
#                        Learning iteration 30/1001
#
#                        Computation: 196311 steps/s (collection: 4.097s, learning 1.247s)
#              Mean action noise std: 0.08
#           Mean value_function loss: 0.2249
#                Mean surrogate loss: 0.0015
#                  Mean entropy loss: -4.2630
#                        Mean reward: 17.26
#                Mean episode length: 138.13
# Episode_Reward/rew_attitude_stability2: 0.0910
# Episode_Reward/rew_ang_vel_stability4: 0.2853
#  Episode_Reward/rew_altitude_hold2: 0.1910
# ...
#                    Total timesteps: 794159616
#                     Iteration time: 6.22s
#                       Time elapsed: 01:09:52
#                                ETA: 00:22:36
#
# ################################################################################
#                       Learning iteration 757/1001
#
#                        Computation: 170746 steps/s (collection: 4.861s, learning 1.283s)
#              Mean action noise std: 4.25
#           Mean value_function loss: 0.1475
#                Mean surrogate loss: 0.0004
#                  Mean entropy loss: 11.4572
#                        Mean reward: 287.28
#                Mean episode length: 1232.51
# Episode_Reward/rew_attitude_stability2: 1.9332
# Episode_Reward/rew_ang_vel_stability4: 2.7729
#  Episode_Reward/rew_altitude_hold2: 3.6724
#            Episode_Reward/rew_vel2: 2.7039
#            Episode_Reward/rew_pos2: 1.1534
#     Episode_Reward/rew_action_rate: -0.8061
#       Episode_Termination/time_out: 0.9653
# Episode_Termination/below_min_altitude: 0.0347
#   Episode_Termination/bad_attitude: 0.0000
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 795208704
#                     Iteration time: 6.14s
#                       Time elapsed: 01:09:58
#                                ETA: 00:22:31
#
# ################################################################################
#                       Learning iteration 758/1001
#
#                        Computation: 167555 steps/s (collection: 4.948s, learning 1.313s)
#              Mean action noise std: 4.25
#           Mean value_function loss: 0.1499
#                Mean surrogate loss: 0.0004
#                  Mean entropy loss: 11.4628
#                        Mean reward: 282.20
#                Mean episode length: 1221.33
# Episode_Reward/rew_attitude_stability2: 1.9062
# Episode_Reward/rew_ang_vel_stability4: 2.7215
#  Episode_Reward/rew_altitude_hold2: 3.5845
#            Episode_Reward/rew_vel2: 2.6498
#            Episode_Reward/rew_pos2: 1.1257
#     Episode_Reward/rew_action_rate: -0.7987
#       Episode_Termination/time_out: 0.9650
# Episode_Termination/below_min_altitude: 0.0350
#   Episode_Termination/bad_attitude: 0.0000
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 796257792
#                     Iteration time: 6.26s
#                       Time elapsed: 01:10:04
#                                ETA: 00:22:26
#
# ################################################################################
#                       Learning iteration 759/1001
#
#                        Computation: 172217 steps/s (collection: 4.847s, learning 1.245s)
#              Mean action noise std: 4.26
#           Mean value_function loss: 0.1263
#                Mean surrogate loss: 0.0005
#                  Mean entropy loss: 11.4691
#                        Mean reward: 286.25
#                Mean episode length: 1220.50
# Episode_Reward/rew_attitude_stability2: 1.9324
# Episode_Reward/rew_ang_vel_stability4: 2.7797
#  Episode_Reward/rew_altitude_hold2: 3.6288
#            Episode_Reward/rew_vel2: 2.7037
#            Episode_Reward/rew_pos2: 1.2432
#     Episode_Reward/rew_action_rate: -0.8099
#       Episode_Termination/time_out: 0.9641
# Episode_Termination/below_min_altitude: 0.0359
#   Episode_Termination/bad_attitude: 0.0000
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 797306880
#                     Iteration time: 6.09s
#                       Time elapsed: 01:10:10
#                                ETA: 00:22:20
#
# ################################################################################
#                       Learning iteration 760/1001
#
#                        Computation: 172812 steps/s (collection: 4.803s, learning 1.268s)
#              Mean action noise std: 4.26
#           Mean value_function loss: 0.1349
#                Mean surrogate loss: -0.0001
#                  Mean entropy loss: 11.4749
#                        Mean reward: 292.94
#                Mean episode length: 1232.39
# Episode_Reward/rew_attitude_stability2: 1.9215
# Episode_Reward/rew_ang_vel_stability4: 2.7537
#  Episode_Reward/rew_altitude_hold2: 3.6374
#            Episode_Reward/rew_vel2: 2.6838
#            Episode_Reward/rew_pos2: 1.1758
#     Episode_Reward/rew_action_rate: -0.8084
#       Episode_Termination/time_out: 0.9626
# Episode_Termination/below_min_altitude: 0.0374
#   Episode_Termination/bad_attitude: 0.0000
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 798355968
#                     Iteration time: 6.07s
#                       Time elapsed: 01:10:16
#                                ETA: 00:22:15
#
# ################################################################################
#                       Learning iteration 761/1001
#
#                        Computation: 174987 steps/s (collection: 4.756s, learning 1.240s)
#              Mean action noise std: 4.27
#           Mean value_function loss: 0.1376
#                Mean surrogate loss: -0.0001
#                  Mean entropy loss: 11.4798
#                        Mean reward: 285.33
#                Mean episode length: 1223.32
# Episode_Reward/rew_attitude_stability2: 1.9257
# Episode_Reward/rew_ang_vel_stability4: 2.7576
#  Episode_Reward/rew_altitude_hold2: 3.6324
#            Episode_Reward/rew_vel2: 2.6874
#            Episode_Reward/rew_pos2: 1.1420
#     Episode_Reward/rew_action_rate: -0.8143
#       Episode_Termination/time_out: 0.9624
# Episode_Termination/below_min_altitude: 0.0376
#   Episode_Termination/bad_attitude: 0.0000
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 799405056
#                     Iteration time: 6.00s
#                       Time elapsed: 01:10:22
#                                ETA: 00:22:10
#
# ################################################################################
#                       Learning iteration 762/1001
#
#                        Computation: 174016 steps/s (collection: 4.765s, learning 1.264s)
#              Mean action noise std: 4.28
#           Mean value_function loss: 0.1360
#                Mean surrogate loss: -0.0000
#                  Mean entropy loss: 11.4850
#                        Mean reward: 286.56
#                Mean episode length: 1234.28
# Episode_Reward/rew_attitude_stability2: 1.9326
# Episode_Reward/rew_ang_vel_stability4: 2.7704
#  Episode_Reward/rew_altitude_hold2: 3.6109
#            Episode_Reward/rew_vel2: 2.6940
#            Episode_Reward/rew_pos2: 1.1253
#     Episode_Reward/rew_action_rate: -0.8188
#       Episode_Termination/time_out: 0.9628
# Episode_Termination/below_min_altitude: 0.0372
#   Episode_Termination/bad_attitude: 0.0000
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 800454144
#                     Iteration time: 6.03s
#                       Time elapsed: 01:10:28
#                                ETA: 00:22:04
#
# ################################################################################
#                       Learning iteration 763/1001
#
#                        Computation: 175340 steps/s (collection: 4.743s, learning 1.240s)
#              Mean action noise std: 4.28
#           Mean value_function loss: 0.1357
#                Mean surrogate loss: 0.0007
#                  Mean entropy loss: 11.4906
#                        Mean reward: 288.96
#                Mean episode length: 1240.26
# Episode_Reward/rew_attitude_stability2: 1.9229
# Episode_Reward/rew_ang_vel_stability4: 2.7548
#  Episode_Reward/rew_altitude_hold2: 3.6421
#            Episode_Reward/rew_vel2: 2.6833
#            Episode_Reward/rew_pos2: 1.1637
#     Episode_Reward/rew_action_rate: -0.8172
#       Episode_Termination/time_out: 0.9633
# Episode_Termination/below_min_altitude: 0.0367
#   Episode_Termination/bad_attitude: 0.0000
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 801503232
#                     Iteration time: 5.98s
#                       Time elapsed: 01:10:34
#                                ETA: 00:21:59
#
# ################################################################################
#                       Learning iteration 764/1001
#
#                        Computation: 171038 steps/s (collection: 4.871s, learning 1.263s)
#              Mean action noise std: 4.29
#           Mean value_function loss: 0.1310
#                Mean surrogate loss: 0.0002
#                  Mean entropy loss: 11.4972
#                        Mean reward: 289.21
#                Mean episode length: 1223.25
# Episode_Reward/rew_attitude_stability2: 1.9374
# Episode_Reward/rew_ang_vel_stability4: 2.7659
#  Episode_Reward/rew_altitude_hold2: 3.6443
#            Episode_Reward/rew_vel2: 2.7009
#            Episode_Reward/rew_pos2: 1.1281
#     Episode_Reward/rew_action_rate: -0.8260
#       Episode_Termination/time_out: 0.9641
# Episode_Termination/below_min_altitude: 0.0359
#   Episode_Termination/bad_attitude: 0.0000
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 802552320
#                     Iteration time: 6.13s
#                       Time elapsed: 01:10:41
#                                ETA: 00:21:53
#
# ################################################################################
#                       Learning iteration 765/1001
#
#                        Computation: 174148 steps/s (collection: 4.779s, learning 1.245s)
#              Mean action noise std: 4.30
#           Mean value_function loss: 0.1337
#                Mean surrogate loss: 0.0004
#                  Mean entropy loss: 11.5049
#                        Mean reward: 284.85
#                Mean episode length: 1221.39
# Episode_Reward/rew_attitude_stability2: 1.9358
# Episode_Reward/rew_ang_vel_stability4: 2.7724
#  Episode_Reward/rew_altitude_hold2: 3.6672
#            Episode_Reward/rew_vel2: 2.7068
#            Episode_Reward/rew_pos2: 1.2375
#     Episode_Reward/rew_action_rate: -0.8271
#       Episode_Termination/time_out: 0.9648
# Episode_Termination/below_min_altitude: 0.0352
#   Episode_Termination/bad_attitude: 0.0000
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 803601408
#                     Iteration time: 6.02s
#                       Time elapsed: 01:10:47
#                                ETA: 00:21:48
#
# ################################################################################
#                       Learning iteration 766/1001
#
#                        Computation: 175282 steps/s (collection: 4.746s, learning 1.239s)
#              Mean action noise std: 4.30
#           Mean value_function loss: 0.1398
#                Mean surrogate loss: -0.0001
#                  Mean entropy loss: 11.5114
#                        Mean reward: 282.34
#                Mean episode length: 1208.91
# Episode_Reward/rew_attitude_stability2: 1.9259
# Episode_Reward/rew_ang_vel_stability4: 2.7498
#  Episode_Reward/rew_altitude_hold2: 3.6225
#            Episode_Reward/rew_vel2: 2.6736
#            Episode_Reward/rew_pos2: 1.0914
#     Episode_Reward/rew_action_rate: -0.8255
#       Episode_Termination/time_out: 0.9648
# Episode_Termination/below_min_altitude: 0.0352
#   Episode_Termination/bad_attitude: 0.0000
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 804650496
#                     Iteration time: 5.99s
#                       Time elapsed: 01:10:53
#                                ETA: 00:21:43
#
# ################################################################################
#                       Learning iteration 767/1001
#
#                        Computation: 174539 steps/s (collection: 4.771s, learning 1.240s)
#              Mean action noise std: 4.31
#           Mean value_function loss: 0.1483
#                Mean surrogate loss: 0.0004
#                  Mean entropy loss: 11.5166
#                        Mean reward: 287.17
#                Mean episode length: 1240.36
# Episode_Reward/rew_attitude_stability2: 1.9316
# Episode_Reward/rew_ang_vel_stability4: 2.7653
#  Episode_Reward/rew_altitude_hold2: 3.6174
#            Episode_Reward/rew_vel2: 2.6902
#            Episode_Reward/rew_pos2: 1.1979
#     Episode_Reward/rew_action_rate: -0.8281
#       Episode_Termination/time_out: 0.9642
# Episode_Termination/below_min_altitude: 0.0358
#   Episode_Termination/bad_attitude: 0.0000
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 805699584
#                     Iteration time: 6.01s
#                       Time elapsed: 01:10:59
#                                ETA: 00:21:37
#
# ################################################################################
#                       Learning iteration 768/1001
#
#                        Computation: 174514 steps/s (collection: 4.739s, learning 1.273s)
#              Mean action noise std: 4.32
#           Mean value_function loss: 0.1312
#                Mean surrogate loss: 0.0006
#                  Mean entropy loss: 11.5217
#                        Mean reward: 286.55
#                Mean episode length: 1223.30
# Episode_Reward/rew_attitude_stability2: 1.9287
# Episode_Reward/rew_ang_vel_stability4: 2.7562
#  Episode_Reward/rew_altitude_hold2: 3.6422
#            Episode_Reward/rew_vel2: 2.6930
#            Episode_Reward/rew_pos2: 1.1952
#     Episode_Reward/rew_action_rate: -0.8313
#       Episode_Termination/time_out: 0.9649
# Episode_Termination/below_min_altitude: 0.0351
#   Episode_Termination/bad_attitude: 0.0000
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 806748672
#                     Iteration time: 6.01s
#                       Time elapsed: 01:11:05
#                                ETA: 00:21:32
#
# ################################################################################
#                       Learning iteration 769/1001
#
#                        Computation: 179681 steps/s (collection: 4.586s, learning 1.252s)
#              Mean action noise std: 4.32
#           Mean value_function loss: 0.1236
#                Mean surrogate loss: 0.0001
#                  Mean entropy loss: 11.5269
#                        Mean reward: 290.33
#                Mean episode length: 1234.75
# Episode_Reward/rew_attitude_stability2: 1.9324
# Episode_Reward/rew_ang_vel_stability4: 2.7649
#  Episode_Reward/rew_altitude_hold2: 3.6435
#            Episode_Reward/rew_vel2: 2.6991
#            Episode_Reward/rew_pos2: 1.1674
#     Episode_Reward/rew_action_rate: -0.8341
#       Episode_Termination/time_out: 0.9654
# Episode_Termination/below_min_altitude: 0.0346
#   Episode_Termination/bad_attitude: 0.0000
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 807797760
#                     Iteration time: 5.84s
#                       Time elapsed: 01:11:10
#                                ETA: 00:21:26
#
#
# Entrenamiento cancelado por el usuario.
#
# --- Todos los experimentos han finalizado ---

# %% [markdown]
# ``Análisis de los datos``

# %%
import csv
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

seed = 42
n=5

df_results_grid_actions = pd.read_csv(path_resultados+"/resultados_grid_PPO.csv")

# %%
def get_group(value):
    if f"_{experiment_name}" in value:
        return task_name

df_results_grid_actions["tarea"] = df_results_grid_actions["id_run_name"].apply(get_group)

# %%
df_copy = df_results_grid_actions.copy()
df_results_grid_actions.sample(n, random_state=seed)
# Out:
#               id_run_name  iteration      reward  max_reward  std_reward  \
# 1  ppo_random_command8_11        100   47.825158  128.700653   19.420658
# 5  ppo_random_command8_11        500  303.714029  360.006409   53.944312
# 0  ppo_random_command8_11          0   15.450691   25.011047    3.095577
# 7  ppo_random_command8_11        700  277.697492  351.741669   63.398951
# 2  ppo_random_command8_11        200  284.238390  362.580170   82.305878
#
#    num_envs_train  mean_Episode_Reward/rew_attitude_stability2  \
# 1            8196                                     0.470285
# 5            8196                                     1.906664
# 0            8196                                     0.039948
# 7            8196                                     1.924442
# 2            8196                                     1.799104
#
#    mean_Episode_Reward/rew_ang_vel_stability4  \
# 1                                    0.913315
# 5                                    2.816948
# 0                                    0.122146
# 7                                    2.802721
# 2                                    2.677947
#
#    mean_Episode_Reward/rew_altitude_hold2  mean_Episode_Reward/rew_vel2  \
# 1                                0.353210                      0.055846
# 5                                3.625334                      2.660648
# 0                                0.124632                      0.016812
# 7                                3.619743                      2.685354
# 2                                3.275686                      2.397425
#
#    mean_Episode_Reward/rew_pos2  mean_Episode_Reward/rew_action_rate  \
# 1                      0.125407                            -0.001157
# 5                      1.312681                            -0.322466
# 0                      0.077165                            -0.000005
# 7                      1.194380                            -0.674488
# 2                      1.023805                            -0.019145
#
#    mean_Episode_Termination/time_out  \
# 1                           0.001089
# 5                           0.952711
# 0                           0.045655
# 7                           0.964879
# 2                           0.891511
#
#    mean_Episode_Termination/below_min_altitude  \
# 1                                     0.853680
# 5                                     0.047289
# 0                                     0.020935
# 7                                     0.035121
# 2                                     0.108489
#
#    mean_Episode_Termination/bad_attitude  \
# 1                               0.144864
# 5                               0.000000
# 0                               0.119366
# 7                               0.000000
# 2                               0.000000
#
#    mean_Episode_Termination/safety_shutdown     tarea
# 1                                  0.000368  Command8
# 5                                  0.000000  Command8
# 0                                  0.000000  Command8
# 7                                  0.000000  Command8
# 2                                  0.000000  Command8

# %%
df_results_grid_actions.set_index(['tarea','id_run_name'],inplace=True)
top5 = (
    df_results_grid_actions.groupby(level="tarea")
      .apply(lambda g: g.sort_values("reward", ascending=False).head(5))
)

# Eliminar el nivel adicional que introduce groupby+apply
top5.index = top5.index.droplevel(0)

top5
# Out:
#                                  iteration      reward  max_reward  \
# tarea    id_run_name
# Command8 ppo_random_command8_11        400  306.981887  361.832336
#          ppo_random_command8_11        500  303.714029  360.006409
#          ppo_random_command8_11        300  285.193192  358.530273
#          ppo_random_command8_11        200  284.238390  362.580170
#          ppo_random_command8_11        700  277.697492  351.741669
#
#                                  std_reward  num_envs_train  \
# tarea    id_run_name
# Command8 ppo_random_command8_11   53.577227            8196
#          ppo_random_command8_11   53.944312            8196
#          ppo_random_command8_11   84.052216            8196
#          ppo_random_command8_11   82.305878            8196
#          ppo_random_command8_11   63.398951            8196
#
#                                  mean_Episode_Reward/rew_attitude_stability2  \
# tarea    id_run_name
# Command8 ppo_random_command8_11                                     1.902033
#          ppo_random_command8_11                                     1.906664
#          ppo_random_command8_11                                     1.860254
#          ppo_random_command8_11                                     1.799104
#          ppo_random_command8_11                                     1.924442
#
#                                  mean_Episode_Reward/rew_ang_vel_stability4  \
# tarea    id_run_name
# Command8 ppo_random_command8_11                                    2.824073
#          ppo_random_command8_11                                    2.816948
#          ppo_random_command8_11                                    2.772347
#          ppo_random_command8_11                                    2.677947
#          ppo_random_command8_11                                    2.802721
#
#                                  mean_Episode_Reward/rew_altitude_hold2  \
# tarea    id_run_name
# Command8 ppo_random_command8_11                                3.596654
#          ppo_random_command8_11                                3.625334
#          ppo_random_command8_11                                3.491581
#          ppo_random_command8_11                                3.275686
#          ppo_random_command8_11                                3.619743
#
#                                  mean_Episode_Reward/rew_vel2  \
# tarea    id_run_name
# Command8 ppo_random_command8_11                      2.644271
#          ppo_random_command8_11                      2.660648
#          ppo_random_command8_11                      2.546070
#          ppo_random_command8_11                      2.397425
#          ppo_random_command8_11                      2.685354
#
#                                  mean_Episode_Reward/rew_pos2  \
# tarea    id_run_name
# Command8 ppo_random_command8_11                      1.259314
#          ppo_random_command8_11                      1.312681
#          ppo_random_command8_11                      1.174713
#          ppo_random_command8_11                      1.023805
#          ppo_random_command8_11                      1.194380
#
#                                  mean_Episode_Reward/rew_action_rate  \
# tarea    id_run_name
# Command8 ppo_random_command8_11                            -0.185128
#          ppo_random_command8_11                            -0.322466
#          ppo_random_command8_11                            -0.079396
#          ppo_random_command8_11                            -0.019145
#          ppo_random_command8_11                            -0.674488
#
#                                  mean_Episode_Termination/time_out  \
# tarea    id_run_name
# Command8 ppo_random_command8_11                           0.945093
#          ppo_random_command8_11                           0.952711
#          ppo_random_command8_11                           0.918007
#          ppo_random_command8_11                           0.891511
#          ppo_random_command8_11                           0.964879
#
#                                  mean_Episode_Termination/below_min_altitude  \
# tarea    id_run_name
# Command8 ppo_random_command8_11                                     0.054907
#          ppo_random_command8_11                                     0.047289
#          ppo_random_command8_11                                     0.081993
#          ppo_random_command8_11                                     0.108489
#          ppo_random_command8_11                                     0.035121
#
#                                  mean_Episode_Termination/bad_attitude  \
# tarea    id_run_name
# Command8 ppo_random_command8_11                                    0.0
#          ppo_random_command8_11                                    0.0
#          ppo_random_command8_11                                    0.0
#          ppo_random_command8_11                                    0.0
#          ppo_random_command8_11                                    0.0
#
#                                  mean_Episode_Termination/safety_shutdown
# tarea    id_run_name
# Command8 ppo_random_command8_11                                       0.0
#          ppo_random_command8_11                                       0.0
#          ppo_random_command8_11                                       0.0
#          ppo_random_command8_11                                       0.0
#          ppo_random_command8_11                                       0.0

# %%
mean_rewards = df_results_grid_actions.groupby(["tarea", "id_run_name"])["reward"].mean()

for tarea, subdf in mean_rewards.groupby(level="tarea"):
    plt.figure(figsize=(12,5))
    
    # Convertir a DataFrame y resetear index para graficar
    plot_df = subdf.reset_index()
    plot_df = plot_df.sort_values("reward", ascending=False)
    
    plt.bar(plot_df["id_run_name"], plot_df["reward"])
    plt.title(f"Reward media por modelo - {tarea}")
    plt.xlabel("id_run_name")
    plt.ylabel("Reward media")
    plt.xticks(rotation=90)
    plt.tight_layout()
    plt.show()

# %%
df_callbacks = pd.read_csv(path_resultados+"/reward_best_models.csv",index_col='id_run_name')
top5_models = df_callbacks.nlargest(5,columns="reward")
top5_models
# Out:
#                         iteration      reward  max_reward  std_reward  \
# id_run_name
# ppo_random_command8_11        412  320.285452  362.532379   26.208705
#
#                         num_envs_train  \
# id_run_name
# ppo_random_command8_11            8196
#
#                         mean_Episode_Reward/rew_attitude_stability2  \
# id_run_name
# ppo_random_command8_11                                     1.898345
#
#                         mean_Episode_Reward/rew_ang_vel_stability4  \
# id_run_name
# ppo_random_command8_11                                    2.815376
#
#                         mean_Episode_Reward/rew_altitude_hold2  \
# id_run_name
# ppo_random_command8_11                                3.597731
#
#                         mean_Episode_Reward/rew_vel2  \
# id_run_name
# ppo_random_command8_11                       2.65278
#
#                         mean_Episode_Reward/rew_pos2  \
# id_run_name
# ppo_random_command8_11                      1.308047
#
#                         mean_Episode_Reward/rew_action_rate  \
# id_run_name
# ppo_random_command8_11                            -0.200465
#
#                         mean_Episode_Termination/time_out  \
# id_run_name
# ppo_random_command8_11                           0.948198
#
#                         mean_Episode_Termination/below_min_altitude  \
# id_run_name
# ppo_random_command8_11                                     0.051802
#
#                         mean_Episode_Termination/bad_attitude  \
# id_run_name
# ppo_random_command8_11                                    0.0
#
#                         mean_Episode_Termination/safety_shutdown
# id_run_name
# ppo_random_command8_11                                       0.0

# %% [markdown]
# Graficamos cómo fue el entrenamiento para los 5 mejores modelos según los callbacks:

# %%
import matplotlib.pyplot as plt
import numpy as np

# Aseguramos que `top5_auc` tenga 'tarea' e 'id_run_name' como columnas, no solo en el índice
df_callbacks = pd.read_csv(path_resultados+"/reward_best_models.csv",index_col='id_run_name')
top5_models = df_callbacks.nlargest(5,columns="reward")
top5_reset = top5_models.reset_index()
top5_reset["tarea"] = top5_reset["id_run_name"].apply(get_group)


# Convertir el índice jerárquico en columnas (para acceder a 'tarea' y 'id_run_name')
df_copy_reset = df_copy.reset_index()

# Unimos `top5_auc_reset` con `df_copy_reset` en las columnas comunes: 'tarea' y 'id_run_name'
merged_df = pd.merge(df_copy_reset, top5_reset[['tarea', 'id_run_name']], on=['tarea', 'id_run_name'], how='inner')

# Usamos una lista de colores para asignar un color diferente a cada modelo
colors = plt.cm.viridis(np.linspace(0, 1, len(merged_df['id_run_name'].unique())))

# Ahora, procedemos a graficar
for tarea, task_df in merged_df.groupby('tarea'):
    plt.figure(figsize=(10, 6))
    
    # Iteramos sobre los modelos (id_run_name) para esta tarea
    for i, (run_name, subdf) in enumerate(task_df.groupby('id_run_name')):
        # Graficamos la evolución de la recompensa a lo largo de las iteraciones
        plt.plot(subdf['iteration'], subdf['reward'], label=run_name, color=colors[i])
    
    plt.xlabel('Iteración')
    plt.ylabel('Reward')
    plt.title(f'Evolución de la Recompensa - Tarea: {tarea}')
    plt.legend(title="Modelos", bbox_to_anchor=(1.05, 1), loc='upper left')
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ``Cojo los 5 modelos mejores de todos de los callbacks``

# %%
import os
df_callbacks = pd.read_csv(path_resultados+"/reward_best_models.csv",index_col='id_run_name')
top5_models = df_callbacks.nlargest(5,columns="reward")

powershell_script_test = os.path.join(cfg_dir, "run_tests.ps1")

with open(powershell_script_test, "w") as f:
    f.write("$ErrorActionPreference = 'Stop'\n\n")
    
    for run_id, row in top5_models.iterrows():
        # Extraemos el número del id (ej: de 'ppo_random_hover_4' sacamos '4')
        experiment_number = run_id.split('_')[-1]
        
        # Construimos la ruta exacta del checkpoint
        # Nota: Asegúrate de que path_resultados termine en / o usar os.path.join
        checkpoint_path = f"{path_resultados}/best_model_{run_id}_{int(row['num_envs_train'])}.pt"
        f.write(f'Write-Host "Ejecutando Test final para Experimento {experiment_number}..."\n')
        
        # Usamos el experiment_number extraído para la tarea (--task)
        # Se añaden flags típicos de play.py: --num_envs 1 y se quita --headless para ver el visualizador
        f.write(f'& "{isaaclab_bat}" -p "{play_script}" '
                f'--task {id_task}-{experiment_number} '
                f'--num_envs 1 '
                f' --headless '
                f'--checkpoint "{checkpoint_path}"\n\n')
        
print(f"Script de test generado en: {powershell_script_test}")
# Out:
# Script de test generado en: C:/Users/Teresa/Documents/GitHub/navsim/isaac_lab/aerotaxi/env_command/env_12/grid_hiperparametros/cfg_files\run_tests.ps1

# %% [markdown]
# ### Test con 1 entorno

# %%
# Ejecuta el entrenamiento de forma automática
# !powershell -ExecutionPolicy Bypass -File "{powershell_script}"
import subprocess
import sys

# Ruta al script que generaste
powershell_script_path = powershell_script_test 

print(f"Iniciando ejecución de: {powershell_script_path}\n")

# Ejecutamos el proceso capturando la salida en tiempo real
process = subprocess.Popen(
    ["powershell.exe", "-ExecutionPolicy", "Bypass", "-File", powershell_script_path],
    stdout=subprocess.PIPE,
    stderr=subprocess.STDOUT, # Redirigimos errores a la salida estándar para verlos
    text=True,
    bufsize=1
)

# Leemos la salida línea a línea conforme se genera
try:
    for line in process.stdout:
        print(line, end="") # Imprime la salida de PowerShell en la celda
        sys.stdout.flush()   # Fuerza a Jupyter a mostrar la línea inmediatamente
except KeyboardInterrupt:
    process.kill()
    print("\nEntrenamiento cancelado por el usuario.")

process.wait()
print("\n--- Todos los experimentos de test han finalizado ---")
# Out:
# Iniciando ejecución de: C:/Users/Teresa/Documents/GitHub/navsim/isaac_lab/aerotaxi/env_command/env_12/grid_hiperparametros/cfg_files\run_tests.ps1
#
# Ejecutando Test final para Experimento 11...
# [INFO] Using python from: C:\Users\Teresa\miniconda3\envs\env_isaaclab\python.exe
# [INFO][AppLauncher]: Using device: cuda:0
# [INFO][AppLauncher]: Loading experience file: C:\Users\Teresa\miniconda3\envs\env_isaaclab\Lib\site-packages\isaaclab\apps\isaaclab.python.headless.kit
# Loading user config located at: 'c:/users/teresa/miniconda3/envs/env_isaaclab/lib/site-packages/isaacsim/kit/data/Kit/Isaac-Sim/5.1/user.config.json'
# [Info] [carb] Logging to file: c:/users/teresa/miniconda3/envs/env_isaaclab/lib/site-packages/isaacsim/kit/logs/Kit/Isaac-Sim/5.1/kit_20260303_104137.log
# 2026-03-03T09:41:37Z s] [Warning] [omni.usd_config.extension] Enable omni.materialx.libs extension to use MaterialX
# 2026-03-03T09:41:38Z s] [Warning] [carb] Acquiring non optional plugin interface which is not listed as dependency: [omni::physx::IPhysxBenchmarks v1.0] (plugin: <default plugin>), by client: omni.physics.physx.plugin. Add it to CARB_PLUGIN_IMPL_DEPS() macro of a client.
# 2026-03-03T09:41:38Z s] [Warning] [omni.isaac.dynamic_control] omni.isaac.dynamic_control is deprecated as of Isaac Sim 4.5. No action is needed from end-users.
# 2026-03-03T09:41:40Z [2,481ms] [Warning] [gpu.foundation.plugin] Skipping unsupported non-NVIDIA GPU: AMD Radeon(TM) Graphics
# 2026-03-03T09:41:40Z [2,482ms] [Warning] [gpu.foundation.plugin] Skipping unsupported non-NVIDIA GPU: AMD Radeon(TM) Graphics
#
# |---------------------------------------------------------------------------------------------|
# | Driver Version: 581.29        | Graphics API: D3D12
# |=============================================================================================|
# | GPU | Name                             | Active | LDA | GPU Memory | Vendor-ID | LUID       |
# |     |                                  |        |     |            | Device-ID | UUID       |
# |     |                                  |        |     |            | Bus-ID    |            |
# |---------------------------------------------------------------------------------------------|
# | 0   | NVIDIA GeForce RTX 5080          | Yes: 0 |     | 15889   MB | 10de      | 295a0100.. |
# |     |                                  |        |     |            | 2c02      | 0          |
# |     |                                  |        |     |            | 1         |            |
# |---------------------------------------------------------------------------------------------|
# | 1   | AMD Radeon(TM) Graphics          |        |     | 1995    MB | 1002      | 876d0100.. |
# |     |                                  |        |     |            | 13c0      | 0          |
# |     |                                  |        |     |            | N/A       |            |
# |=============================================================================================|
# | OS: Windows 11 Pro, Version: 10.0 (25H2), Build: 26200, Kernel: 10.0.26100.7824
# | Processor: AMD Ryzen 9 9950X 16-Core Processor
# | Cores: 16 | Logical Cores: 32
# |---------------------------------------------------------------------------------------------|
# | Total Memory (MB): 128627 | Free Memory: 101066
# | Total Page/Swap (MB): 136819 | Free Page/Swap: 101625
# |---------------------------------------------------------------------------------------------|
# C:\Users\Teresa\Documents\GitHub\navsim\isaac_lab\aerotaxi\env_command\env_12\flight_plan.py:29: UserWarning: Treat the new Tool classes introduced in v1.5 as experimental for now; the API and rcParam may change in future versions.
#   plt.rcParams["toolbar"] = "toolmanager"
# [INFO]: Parsing configuration from: aerotaxi.env_command.env_12.env:UAVEnvCfg
# [INFO]: Parsing configuration from: aerotaxi.env_command.env_12.grid_hiperparametros.cfg_files.ppo_random_command8_11_cfg:Command8PPORunnerCfg
# [INFO] Loading experiment from directory: C:\Users\Teresa\Documents\GitHub\navsim\isaac_lab\aerotaxi\env_command\env_12\logs\rsl_rl\command8
# Setting seed: 42
# [INFO]: Base environment:
# 	Environment device    : cuda:0
# 	Environment seed      : 42
# 	Physics step-size     : 0.005
# 	Rendering step-size   : 0.02
# 	Environment step-size : 0.02
# [INFO]: Time taken for scene creation : 1.027782 seconds
# [INFO]: Scene manager:  <class InteractiveScene>
# 	Number of environments: 1
# 	Environment spacing   : 200.0
# 	Source prim name      : /World/envs/env_0
# 	Global prim paths     : []
# 	Replicate physics     : False
# [INFO]: Starting the simulation. This may take a few seconds. Please wait...
# [INFO]: Time taken for simulation start : 0.241068 seconds
# [INFO] Command Manager:  <CommandManager> contains 1 active terms.
# +--------------------------------------+
# |         Active Command Terms         |
# +-------+-------------+----------------+
# | Index | Name        |      Type      |
# +-------+-------------+----------------+
# |   0   | vel_command | UAVcommandTerm |
# +-------+-------------+----------------+
#
# [INFO] Event Manager:  <EventManager> contains 1 active terms.
# +-----------------------------------+
# | Active Event Terms in Mode: 'reset' |
# +----------+------------------------+
# |  Index   | Name                   |
# +----------+------------------------+
# |    0     | reset_pos              |
# |    1     | randomize_mass         |
# |    2     | randomize_wind         |
# +----------+------------------------+
#
# [INFO] Recorder Manager:  <RecorderManager> contains 0 active terms.
# +---------------------+
# | Active Recorder Terms |
# +-----------+---------+
# |   Index   | Name    |
# +-----------+---------+
# +-----------+---------+
#
# [INFO] Action Manager:  <ActionManager> contains 1 active terms.
# +-----------------------------------+
# |   Active Action Terms (shape: 4)  |
# +--------+-------------+------------+
# | Index  | Name        |  Dimension |
# +--------+-------------+------------+
# |   0    | rotors_vel  |          4 |
# +--------+-------------+------------+
#
# [INFO] Observation Manager: <ObservationManager> contains 2 groups.
# +---------------------------------------------------------+
# | Active Observation Terms in Group: 'policy' (shape: (13,)) |
# +-----------+---------------------------------+-----------+
# |   Index   | Name                            |   Shape   |
# +-----------+---------------------------------+-----------+
# |     0     | dist                            |    (3,)   |
# |     1     | lin_vel                         |    (3,)   |
# |     2     | ang_vel                         |    (3,)   |
# |     3     | height                          |    (1,)   |
# |     4     | projected_gravity               |    (3,)   |
# +-----------+---------------------------------+-----------+
# +---------------------------------------------------------+
# | Active Observation Terms in Group: 'critic' (shape: (13,)) |
# +-----------+---------------------------------+-----------+
# |   Index   | Name                            |   Shape   |
# +-----------+---------------------------------+-----------+
# |     0     | dist                            |    (3,)   |
# |     1     | lin_vel                         |    (3,)   |
# |     2     | ang_vel                         |    (3,)   |
# |     3     | height                          |    (1,)   |
# |     4     | projected_gravity               |    (3,)   |
# +-----------+---------------------------------+-----------+
#
# [INFO] Termination Manager:  <TerminationManager> contains 4 active terms.
# +---------------------------------------+
# |        Active Termination Terms       |
# +-------+--------------------+----------+
# | Index | Name               | Time Out |
# +-------+--------------------+----------+
# |   0   | time_out           |   True   |
# |   1   | below_min_altitude |  False   |
# |   2   | bad_attitude       |  False   |
# |   3   | safety_shutdown    |  False   |
# +-------+--------------------+----------+
#
# [INFO] Reward Manager:  <RewardManager> contains 6 active terms.
# +------------------------------------------+
# |           Active Reward Terms            |
# +-------+-------------------------+--------+
# | Index | Name                    | Weight |
# +-------+-------------------------+--------+
# |   0   | rew_attitude_stability2 |    2.0 |
# |   1   | rew_ang_vel_stability4  |    3.0 |
# |   2   | rew_altitude_hold2      |    4.0 |
# |   3   | rew_vel2                |    3.0 |
# |   4   | rew_pos2                |    3.0 |
# |   5   | rew_action_rate         |    0.5 |
# +-------+-------------------------+--------+
#
# [INFO] Curriculum Manager:  <CurriculumManager> contains 0 active terms.
# +----------------------+
# | Active Curriculum Terms |
# +-----------+----------+
# |   Index   | Name     |
# +-----------+----------+
# +-----------+----------+
#
# [INFO]: Completed setting up the environment...
# 2026-03-03T09:41:43Z [5,376ms] [Warning] [omni.physx.fabric.plugin] FabricManager::initializePointInstancer mismatched prototypes on point instancer: /Visuals/target_commands.
# [INFO]: Loading model checkpoint from: C:\Users\Teresa\Documents\GitHub\navsim\tmp\tmpTeresa\resultados_grid_command_v8\best_model_ppo_random_command8_11_8196.pt
# C:\Users\Teresa\miniconda3\envs\env_isaaclab\Lib\site-packages\rsl_rl\utils\utils.py:244: UserWarning: The observation configuration dictionary 'obs_groups' must contain the 'policy' key. As an observation group with the name 'policy' was found, this is assumed to be the observation set. Consider adding the 'policy' key to the 'obs_groups' dictionary for clarity. This behavior will be removed in a future version.
#   warnings.warn(
# C:\Users\Teresa\miniconda3\envs\env_isaaclab\Lib\site-packages\rsl_rl\utils\utils.py:282: UserWarning: The observation configuration dictionary 'obs_groups' must contain the 'critic' key. As an observation group with the name 'critic' was found, this is assumed to be the observation set. Consider adding the 'critic' key to the 'obs_groups' dictionary for clarity. This behavior will be removed in a future version.
#   warnings.warn(
# --------------------------------------------------------------------------------
# Resolved observation sets:
# 	 policy :  ['policy']
# 	 critic :  ['critic']
# --------------------------------------------------------------------------------
# Actor MLP: MLP(
#   (0): Linear(in_features=13, out_features=128, bias=True)
#   (1): ELU(alpha=1.0)
#   (2): Linear(in_features=128, out_features=128, bias=True)
#   (3): ELU(alpha=1.0)
#   (4): Linear(in_features=128, out_features=128, bias=True)
#   (5): ELU(alpha=1.0)
#   (6): Linear(in_features=128, out_features=128, bias=True)
#   (7): ELU(alpha=1.0)
#   (8): Linear(in_features=128, out_features=4, bias=True)
# )
# Critic MLP: MLP(
#   (0): Linear(in_features=13, out_features=512, bias=True)
#   (1): ELU(alpha=1.0)
#   (2): Linear(in_features=512, out_features=512, bias=True)
#   (3): ELU(alpha=1.0)
#   (4): Linear(in_features=512, out_features=512, bias=True)
#   (5): ELU(alpha=1.0)
#   (6): Linear(in_features=512, out_features=512, bias=True)
#   (7): ELU(alpha=1.0)
#   (8): Linear(in_features=512, out_features=512, bias=True)
#   (9): ELU(alpha=1.0)
#   (10): Linear(in_features=512, out_features=1, bias=True)
# )
#
# --- Todos los experimentos de test han finalizado ---

# %%
df_callbacks = pd.read_csv(path_resultados+"/reward_best_models.csv",index_col='id_run_name')
top5_models = df_callbacks.nlargest(5,columns="reward")

# %%
df_rewards_play = pd.read_csv(path_resultados+'/rewards_play_PPO.csv')

# %%
df_rewards_play
# Out:
#               id_run_name      reward  max_reward       std  num_envs_test  \
# 0  ppo_random_command8_11  123.925476  196.593587  72.66811              1
#
#                                           checkpoint  \
# 0  C:/Users/Teresa/Documents/GitHub/navsim/tmp/tm...
#
#    mean_Episode_Reward/rew_attitude_stability2  \
# 0                                     0.418711
#
#    mean_Episode_Reward/rew_ang_vel_stability4  \
# 0                                    0.746797
#
#    mean_Episode_Reward/rew_altitude_hold2  mean_Episode_Reward/rew_vel2  \
# 0                                0.434215                      0.144813
#
#    mean_Episode_Reward/rew_pos2  mean_Episode_Reward/rew_action_rate  \
# 0                      0.307523                            -0.001764
#
#    mean_Episode_Termination/time_out  \
# 0                                0.0
#
#    mean_Episode_Termination/below_min_altitude  \
# 0                                          1.0
#
#    mean_Episode_Termination/bad_attitude  \
# 0                                    0.0
#
#    mean_Episode_Termination/safety_shutdown
# 0                                       0.0

# %% [markdown]
# ### Test con 64 entornos

# %%
import os
df_callbacks = pd.read_csv(path_resultados+"/reward_best_models.csv",index_col='id_run_name')
top5_models = df_callbacks.nlargest(5,columns="reward")

powershell_script_test_2 = os.path.join(cfg_dir, "run_tests_2.ps1")

with open(powershell_script_test_2, "w") as f:
    f.write("$ErrorActionPreference = 'Stop'\n\n")
    
    for run_id, row in top5_models.iterrows():
        # Extraemos el número del id (ej: de 'ppo_random_hover_4' sacamos '4')
        experiment_number = run_id.split('_')[-1]
        
        # Construimos la ruta exacta del checkpoint
        # Nota: Asegúrate de que path_resultados termine en / o usar os.path.join
        checkpoint_path = f"{path_resultados}/best_model_{run_id}_{int(row['num_envs_train'])}.pt"
        f.write(f'Write-Host "Ejecutando Test final para Experimento {experiment_number}..."\n')
        
        # Usamos el experiment_number extraído para la tarea (--task)
        # Se añaden flags típicos de play.py: --num_envs 1 y se quita --headless para ver el visualizador
        f.write(f'& "{isaaclab_bat}" -p "{play_script}" '
                f'--task {id_task}-{experiment_number} '
                f'--num_envs 64 '
                f' --headless '
                f'--checkpoint "{checkpoint_path}"\n\n')
        
print(f"Script de test generado en: {powershell_script_test_2}")
# Out:
# Script de test generado en: C:/Users/Teresa/Documents/GitHub/navsim/isaac_lab/aerotaxi/env_command/env_12/grid_hiperparametros/cfg_files\run_tests_2.ps1

# %%
# Ejecuta el entrenamiento de forma automática
# !powershell -ExecutionPolicy Bypass -File "{powershell_script}"
import subprocess
import sys

# Ruta al script que generaste
powershell_script_path = powershell_script_test_2 

print(f"Iniciando ejecución de: {powershell_script_path}\n")

# Ejecutamos el proceso capturando la salida en tiempo real
process = subprocess.Popen(
    ["powershell.exe", "-ExecutionPolicy", "Bypass", "-File", powershell_script_path],
    stdout=subprocess.PIPE,
    stderr=subprocess.STDOUT, # Redirigimos errores a la salida estándar para verlos
    text=True,
    bufsize=1
)

# Leemos la salida línea a línea conforme se genera
try:
    for line in process.stdout:
        print(line, end="") # Imprime la salida de PowerShell en la celda
        sys.stdout.flush()   # Fuerza a Jupyter a mostrar la línea inmediatamente
except KeyboardInterrupt:
    process.kill()
    print("\nEntrenamiento cancelado por el usuario.")

process.wait()
print("\n--- Todos los experimentos de test han finalizado ---")
# Out:
# Iniciando ejecución de: C:/Users/Teresa/Documents/GitHub/navsim/isaac_lab/aerotaxi/env_command/env_12/grid_hiperparametros/cfg_files\run_tests_2.ps1
#
# Ejecutando Test final para Experimento 11...
# [INFO] Using python from: C:\Users\Teresa\miniconda3\envs\env_isaaclab\python.exe
# [INFO][AppLauncher]: Using device: cuda:0
# [INFO][AppLauncher]: Loading experience file: C:\Users\Teresa\miniconda3\envs\env_isaaclab\Lib\site-packages\isaaclab\apps\isaaclab.python.headless.kit
# Loading user config located at: 'c:/users/teresa/miniconda3/envs/env_isaaclab/lib/site-packages/isaacsim/kit/data/Kit/Isaac-Sim/5.1/user.config.json'
# [Info] [carb] Logging to file: c:/users/teresa/miniconda3/envs/env_isaaclab/lib/site-packages/isaacsim/kit/logs/Kit/Isaac-Sim/5.1/kit_20260303_104217.log
# 2026-03-03T09:42:17Z s] [Warning] [omni.usd_config.extension] Enable omni.materialx.libs extension to use MaterialX
# 2026-03-03T09:42:18Z s] [Warning] [carb] Acquiring non optional plugin interface which is not listed as dependency: [omni::physx::IPhysxBenchmarks v1.0] (plugin: <default plugin>), by client: omni.physics.physx.plugin. Add it to CARB_PLUGIN_IMPL_DEPS() macro of a client.
# 2026-03-03T09:42:18Z s] [Warning] [omni.isaac.dynamic_control] omni.isaac.dynamic_control is deprecated as of Isaac Sim 4.5. No action is needed from end-users.
# 2026-03-03T09:42:19Z [2,318ms] [Warning] [gpu.foundation.plugin] Skipping unsupported non-NVIDIA GPU: AMD Radeon(TM) Graphics
# 2026-03-03T09:42:19Z [2,318ms] [Warning] [gpu.foundation.plugin] Skipping unsupported non-NVIDIA GPU: AMD Radeon(TM) Graphics
#
# |---------------------------------------------------------------------------------------------|
# | Driver Version: 581.29        | Graphics API: D3D12
# |=============================================================================================|
# | GPU | Name                             | Active | LDA | GPU Memory | Vendor-ID | LUID       |
# |     |                                  |        |     |            | Device-ID | UUID       |
# |     |                                  |        |     |            | Bus-ID    |            |
# |---------------------------------------------------------------------------------------------|
# | 0   | NVIDIA GeForce RTX 5080          | Yes: 0 |     | 15889   MB | 10de      | 295a0100.. |
# |     |                                  |        |     |            | 2c02      | 0          |
# |     |                                  |        |     |            | 1         |            |
# |---------------------------------------------------------------------------------------------|
# | 1   | AMD Radeon(TM) Graphics          |        |     | 1995    MB | 1002      | 876d0100.. |
# |     |                                  |        |     |            | 13c0      | 0          |
# |     |                                  |        |     |            | N/A       |            |
# |=============================================================================================|
# | OS: Windows 11 Pro, Version: 10.0 (25H2), Build: 26200, Kernel: 10.0.26100.7824
# | Processor: AMD Ryzen 9 9950X 16-Core Processor
# | Cores: 16 | Logical Cores: 32
# |---------------------------------------------------------------------------------------------|
# | Total Memory (MB): 128627 | Free Memory: 100790
# | Total Page/Swap (MB): 136819 | Free Page/Swap: 101356
# |---------------------------------------------------------------------------------------------|
# C:\Users\Teresa\Documents\GitHub\navsim\isaac_lab\aerotaxi\env_command\env_12\flight_plan.py:29: UserWarning: Treat the new Tool classes introduced in v1.5 as experimental for now; the API and rcParam may change in future versions.
#   plt.rcParams["toolbar"] = "toolmanager"
# [INFO]: Parsing configuration from: aerotaxi.env_command.env_12.env:UAVEnvCfg
# [INFO]: Parsing configuration from: aerotaxi.env_command.env_12.grid_hiperparametros.cfg_files.ppo_random_command8_11_cfg:Command8PPORunnerCfg
# [INFO] Loading experiment from directory: C:\Users\Teresa\Documents\GitHub\navsim\isaac_lab\aerotaxi\env_command\env_12\logs\rsl_rl\command8
# Setting seed: 42
# [INFO]: Base environment:
# 	Environment device    : cuda:0
# 	Environment seed      : 42
# 	Physics step-size     : 0.005
# 	Rendering step-size   : 0.02
# 	Environment step-size : 0.02
# [INFO]: Time taken for scene creation : 0.983833 seconds
# [INFO]: Scene manager:  <class InteractiveScene>
# 	Number of environments: 64
# 	Environment spacing   : 200.0
# 	Source prim name      : /World/envs/env_0
# 	Global prim paths     : []
# 	Replicate physics     : False
# [INFO]: Starting the simulation. This may take a few seconds. Please wait...
# [INFO]: Time taken for simulation start : 0.265190 seconds
# [INFO] Command Manager:  <CommandManager> contains 1 active terms.
# +--------------------------------------+
# |         Active Command Terms         |
# +-------+-------------+----------------+
# | Index | Name        |      Type      |
# +-------+-------------+----------------+
# |   0   | vel_command | UAVcommandTerm |
# +-------+-------------+----------------+
#
# [INFO] Event Manager:  <EventManager> contains 1 active terms.
# +-----------------------------------+
# | Active Event Terms in Mode: 'reset' |
# +----------+------------------------+
# |  Index   | Name                   |
# +----------+------------------------+
# |    0     | reset_pos              |
# |    1     | randomize_mass         |
# |    2     | randomize_wind         |
# +----------+------------------------+
#
# [INFO] Recorder Manager:  <RecorderManager> contains 0 active terms.
# +---------------------+
# | Active Recorder Terms |
# +-----------+---------+
# |   Index   | Name    |
# +-----------+---------+
# +-----------+---------+
#
# [INFO] Action Manager:  <ActionManager> contains 1 active terms.
# +-----------------------------------+
# |   Active Action Terms (shape: 4)  |
# +--------+-------------+------------+
# | Index  | Name        |  Dimension |
# +--------+-------------+------------+
# |   0    | rotors_vel  |          4 |
# +--------+-------------+------------+
#
# [INFO] Observation Manager: <ObservationManager> contains 2 groups.
# +---------------------------------------------------------+
# | Active Observation Terms in Group: 'policy' (shape: (13,)) |
# +-----------+---------------------------------+-----------+
# |   Index   | Name                            |   Shape   |
# +-----------+---------------------------------+-----------+
# |     0     | dist                            |    (3,)   |
# |     1     | lin_vel                         |    (3,)   |
# |     2     | ang_vel                         |    (3,)   |
# |     3     | height                          |    (1,)   |
# |     4     | projected_gravity               |    (3,)   |
# +-----------+---------------------------------+-----------+
# +---------------------------------------------------------+
# | Active Observation Terms in Group: 'critic' (shape: (13,)) |
# +-----------+---------------------------------+-----------+
# |   Index   | Name                            |   Shape   |
# +-----------+---------------------------------+-----------+
# |     0     | dist                            |    (3,)   |
# |     1     | lin_vel                         |    (3,)   |
# |     2     | ang_vel                         |    (3,)   |
# |     3     | height                          |    (1,)   |
# |     4     | projected_gravity               |    (3,)   |
# +-----------+---------------------------------+-----------+
#
# [INFO] Termination Manager:  <TerminationManager> contains 4 active terms.
# +---------------------------------------+
# |        Active Termination Terms       |
# +-------+--------------------+----------+
# | Index | Name               | Time Out |
# +-------+--------------------+----------+
# |   0   | time_out           |   True   |
# |   1   | below_min_altitude |  False   |
# |   2   | bad_attitude       |  False   |
# |   3   | safety_shutdown    |  False   |
# +-------+--------------------+----------+
#
# [INFO] Reward Manager:  <RewardManager> contains 6 active terms.
# +------------------------------------------+
# |           Active Reward Terms            |
# +-------+-------------------------+--------+
# | Index | Name                    | Weight |
# +-------+-------------------------+--------+
# |   0   | rew_attitude_stability2 |    2.0 |
# |   1   | rew_ang_vel_stability4  |    3.0 |
# |   2   | rew_altitude_hold2      |    4.0 |
# |   3   | rew_vel2                |    3.0 |
# |   4   | rew_pos2                |    3.0 |
# |   5   | rew_action_rate         |    0.5 |
# +-------+-------------------------+--------+
#
# [INFO] Curriculum Manager:  <CurriculumManager> contains 0 active terms.
# +----------------------+
# | Active Curriculum Terms |
# +-----------+----------+
# |   Index   | Name     |
# +-----------+----------+
# +-----------+----------+
#
# [INFO]: Completed setting up the environment...
# 2026-03-03T09:42:22Z [5,232ms] [Warning] [omni.physx.fabric.plugin] FabricManager::initializePointInstancer mismatched prototypes on point instancer: /Visuals/target_commands.
# [INFO]: Loading model checkpoint from: C:\Users\Teresa\Documents\GitHub\navsim\tmp\tmpTeresa\resultados_grid_command_v8\best_model_ppo_random_command8_11_8196.pt
# C:\Users\Teresa\miniconda3\envs\env_isaaclab\Lib\site-packages\rsl_rl\utils\utils.py:244: UserWarning: The observation configuration dictionary 'obs_groups' must contain the 'policy' key. As an observation group with the name 'policy' was found, this is assumed to be the observation set. Consider adding the 'policy' key to the 'obs_groups' dictionary for clarity. This behavior will be removed in a future version.
#   warnings.warn(
# C:\Users\Teresa\miniconda3\envs\env_isaaclab\Lib\site-packages\rsl_rl\utils\utils.py:282: UserWarning: The observation configuration dictionary 'obs_groups' must contain the 'critic' key. As an observation group with the name 'critic' was found, this is assumed to be the observation set. Consider adding the 'critic' key to the 'obs_groups' dictionary for clarity. This behavior will be removed in a future version.
#   warnings.warn(
# --------------------------------------------------------------------------------
# Resolved observation sets:
# 	 policy :  ['policy']
# 	 critic :  ['critic']
# --------------------------------------------------------------------------------
# Actor MLP: MLP(
#   (0): Linear(in_features=13, out_features=128, bias=True)
#   (1): ELU(alpha=1.0)
#   (2): Linear(in_features=128, out_features=128, bias=True)
#   (3): ELU(alpha=1.0)
#   (4): Linear(in_features=128, out_features=128, bias=True)
#   (5): ELU(alpha=1.0)
#   (6): Linear(in_features=128, out_features=128, bias=True)
#   (7): ELU(alpha=1.0)
#   (8): Linear(in_features=128, out_features=4, bias=True)
# )
# Critic MLP: MLP(
#   (0): Linear(in_features=13, out_features=512, bias=True)
#   (1): ELU(alpha=1.0)
#   (2): Linear(in_features=512, out_features=512, bias=True)
#   (3): ELU(alpha=1.0)
#   (4): Linear(in_features=512, out_features=512, bias=True)
#   (5): ELU(alpha=1.0)
#   (6): Linear(in_features=512, out_features=512, bias=True)
#   (7): ELU(alpha=1.0)
#   (8): Linear(in_features=512, out_features=512, bias=True)
#   (9): ELU(alpha=1.0)
#   (10): Linear(in_features=512, out_features=1, bias=True)
# )
#
# --- Todos los experimentos de test han finalizado ---

# %% [markdown]
# #### Test con 256 entornos

# %%
import os
df_callbacks = pd.read_csv(path_resultados+"/reward_best_models.csv",index_col='id_run_name')
top5_models = df_callbacks.nlargest(5,columns="reward")

powershell_script_test_3 = os.path.join(cfg_dir, "run_tests_3.ps1")

with open(powershell_script_test_3, "w") as f:
    f.write("$ErrorActionPreference = 'Stop'\n\n")
    
    for run_id, row in top5_models.iterrows():
        # Extraemos el número del id (ej: de 'ppo_random_hover_4' sacamos '4')
        experiment_number = run_id.split('_')[-1]
        
        # Construimos la ruta exacta del checkpoint
        # Nota: Asegúrate de que path_resultados termine en / o usar os.path.join
        checkpoint_path = f"{path_resultados}/best_model_{run_id}_{int(row['num_envs_train'])}.pt"
        f.write(f'Write-Host "Ejecutando Test final para Experimento {experiment_number}..."\n')
        
        # Usamos el experiment_number extraído para la tarea (--task)
        # Se añaden flags típicos de play.py: --num_envs 1 y se quita --headless para ver el visualizador
        f.write(f'& "{isaaclab_bat}" -p "{play_script}" '
                f'--task {id_task}-{experiment_number} '
                f'--num_envs 256 '
                f' --headless '
                f'--checkpoint "{checkpoint_path}"\n\n')
        
print(f"Script de test generado en: {powershell_script_test_3}")
# Out:
# Script de test generado en: C:/Users/Teresa/Documents/GitHub/navsim/isaac_lab/aerotaxi/env_command/env_12/grid_hiperparametros/cfg_files\run_tests_3.ps1

# %%
# Ejecuta el entrenamiento de forma automática
# !powershell -ExecutionPolicy Bypass -File "{powershell_script}"
import subprocess
import sys

# Ruta al script que generaste
powershell_script_path = powershell_script_test_3 

print(f"Iniciando ejecución de: {powershell_script_path}\n")

# Ejecutamos el proceso capturando la salida en tiempo real
process = subprocess.Popen(
    ["powershell.exe", "-ExecutionPolicy", "Bypass", "-File", powershell_script_path],
    stdout=subprocess.PIPE,
    stderr=subprocess.STDOUT, # Redirigimos errores a la salida estándar para verlos
    text=True,
    bufsize=1
)

# Leemos la salida línea a línea conforme se genera
try:
    for line in process.stdout:
        print(line, end="") # Imprime la salida de PowerShell en la celda
        sys.stdout.flush()   # Fuerza a Jupyter a mostrar la línea inmediatamente
except KeyboardInterrupt:
    process.kill()
    print("\nEntrenamiento cancelado por el usuario.")

process.wait()
print("\n--- Todos los experimentos de test han finalizado ---")
# Out:
# Iniciando ejecución de: C:/Users/Teresa/Documents/GitHub/navsim/isaac_lab/aerotaxi/env_command/env_12/grid_hiperparametros/cfg_files\run_tests_3.ps1
#
# Ejecutando Test final para Experimento 11...
# [INFO] Using python from: C:\Users\Teresa\miniconda3\envs\env_isaaclab\python.exe
# [INFO][AppLauncher]: Using device: cuda:0
# [INFO][AppLauncher]: Loading experience file: C:\Users\Teresa\miniconda3\envs\env_isaaclab\Lib\site-packages\isaaclab\apps\isaaclab.python.headless.kit
# Loading user config located at: 'c:/users/teresa/miniconda3/envs/env_isaaclab/lib/site-packages/isaacsim/kit/data/Kit/Isaac-Sim/5.1/user.config.json'
# [Info] [carb] Logging to file: c:/users/teresa/miniconda3/envs/env_isaaclab/lib/site-packages/isaacsim/kit/logs/Kit/Isaac-Sim/5.1/kit_20260303_104250.log
# 2026-03-03T09:42:50Z s] [Warning] [omni.usd_config.extension] Enable omni.materialx.libs extension to use MaterialX
# 2026-03-03T09:42:51Z s] [Warning] [carb] Acquiring non optional plugin interface which is not listed as dependency: [omni::physx::IPhysxBenchmarks v1.0] (plugin: <default plugin>), by client: omni.physics.physx.plugin. Add it to CARB_PLUGIN_IMPL_DEPS() macro of a client.
# 2026-03-03T09:42:51Z s] [Warning] [omni.isaac.dynamic_control] omni.isaac.dynamic_control is deprecated as of Isaac Sim 4.5. No action is needed from end-users.
# 2026-03-03T09:42:52Z [2,584ms] [Warning] [gpu.foundation.plugin] Skipping unsupported non-NVIDIA GPU: AMD Radeon(TM) Graphics
# 2026-03-03T09:42:52Z [2,585ms] [Warning] [gpu.foundation.plugin] Skipping unsupported non-NVIDIA GPU: AMD Radeon(TM) Graphics
#
# |---------------------------------------------------------------------------------------------|
# | Driver Version: 581.29        | Graphics API: D3D12
# |=============================================================================================|
# | GPU | Name                             | Active | LDA | GPU Memory | Vendor-ID | LUID       |
# |     |                                  |        |     |            | Device-ID | UUID       |
# |     |                                  |        |     |            | Bus-ID    |            |
# |---------------------------------------------------------------------------------------------|
# | 0   | NVIDIA GeForce RTX 5080          | Yes: 0 |     | 15889   MB | 10de      | 295a0100.. |
# |     |                                  |        |     |            | 2c02      | 0          |
# |     |                                  |        |     |            | 1         |            |
# |---------------------------------------------------------------------------------------------|
# | 1   | AMD Radeon(TM) Graphics          |        |     | 1995    MB | 1002      | 876d0100.. |
# |     |                                  |        |     |            | 13c0      | 0          |
# |     |                                  |        |     |            | N/A       |            |
# |=============================================================================================|
# | OS: Windows 11 Pro, Version: 10.0 (25H2), Build: 26200, Kernel: 10.0.26100.7824
# | Processor: AMD Ryzen 9 9950X 16-Core Processor
# | Cores: 16 | Logical Cores: 32
# |---------------------------------------------------------------------------------------------|
# | Total Memory (MB): 128627 | Free Memory: 100272
# | Total Page/Swap (MB): 136819 | Free Page/Swap: 100731
# |---------------------------------------------------------------------------------------------|
# C:\Users\Teresa\Documents\GitHub\navsim\isaac_lab\aerotaxi\env_command\env_12\flight_plan.py:29: UserWarning: Treat the new Tool classes introduced in v1.5 as experimental for now; the API and rcParam may change in future versions.
#   plt.rcParams["toolbar"] = "toolmanager"
# [INFO]: Parsing configuration from: aerotaxi.env_command.env_12.env:UAVEnvCfg
# [INFO]: Parsing configuration from: aerotaxi.env_command.env_12.grid_hiperparametros.cfg_files.ppo_random_command8_11_cfg:Command8PPORunnerCfg
# [INFO] Loading experiment from directory: C:\Users\Teresa\Documents\GitHub\navsim\isaac_lab\aerotaxi\env_command\env_12\logs\rsl_rl\command8
# Setting seed: 42
# [INFO]: Base environment:
# 	Environment device    : cuda:0
# 	Environment seed      : 42
# 	Physics step-size     : 0.005
# 	Rendering step-size   : 0.02
# 	Environment step-size : 0.02
# [INFO]: Time taken for scene creation : 1.095154 seconds
# [INFO]: Scene manager:  <class InteractiveScene>
# 	Number of environments: 256
# 	Environment spacing   : 200.0
# 	Source prim name      : /World/envs/env_0
# 	Global prim paths     : []
# 	Replicate physics     : False
# [INFO]: Starting the simulation. This may take a few seconds. Please wait...
# [INFO]: Time taken for simulation start : 0.386291 seconds
# [INFO] Command Manager:  <CommandManager> contains 1 active terms.
# +--------------------------------------+
# |         Active Command Terms         |
# +-------+-------------+----------------+
# | Index | Name        |      Type      |
# +-------+-------------+----------------+
# |   0   | vel_command | UAVcommandTerm |
# +-------+-------------+----------------+
#
# [INFO] Event Manager:  <EventManager> contains 1 active terms.
# +-----------------------------------+
# | Active Event Terms in Mode: 'reset' |
# +----------+------------------------+
# |  Index   | Name                   |
# +----------+------------------------+
# |    0     | reset_pos              |
# |    1     | randomize_mass         |
# |    2     | randomize_wind         |
# +----------+------------------------+
#
# [INFO] Recorder Manager:  <RecorderManager> contains 0 active terms.
# +---------------------+
# | Active Recorder Terms |
# +-----------+---------+
# |   Index   | Name    |
# +-----------+---------+
# +-----------+---------+
#
# [INFO] Action Manager:  <ActionManager> contains 1 active terms.
# +-----------------------------------+
# |   Active Action Terms (shape: 4)  |
# +--------+-------------+------------+
# | Index  | Name        |  Dimension |
# +--------+-------------+------------+
# |   0    | rotors_vel  |          4 |
# +--------+-------------+------------+
#
# [INFO] Observation Manager: <ObservationManager> contains 2 groups.
# +---------------------------------------------------------+
# | Active Observation Terms in Group: 'policy' (shape: (13,)) |
# +-----------+---------------------------------+-----------+
# |   Index   | Name                            |   Shape   |
# +-----------+---------------------------------+-----------+
# |     0     | dist                            |    (3,)   |
# |     1     | lin_vel                         |    (3,)   |
# |     2     | ang_vel                         |    (3,)   |
# |     3     | height                          |    (1,)   |
# |     4     | projected_gravity               |    (3,)   |
# +-----------+---------------------------------+-----------+
# +---------------------------------------------------------+
# | Active Observation Terms in Group: 'critic' (shape: (13,)) |
# +-----------+---------------------------------+-----------+
# |   Index   | Name                            |   Shape   |
# +-----------+---------------------------------+-----------+
# |     0     | dist                            |    (3,)   |
# |     1     | lin_vel                         |    (3,)   |
# |     2     | ang_vel                         |    (3,)   |
# |     3     | height                          |    (1,)   |
# |     4     | projected_gravity               |    (3,)   |
# +-----------+---------------------------------+-----------+
#
# [INFO] Termination Manager:  <TerminationManager> contains 4 active terms.
# +---------------------------------------+
# |        Active Termination Terms       |
# +-------+--------------------+----------+
# | Index | Name               | Time Out |
# +-------+--------------------+----------+
# |   0   | time_out           |   True   |
# |   1   | below_min_altitude |  False   |
# |   2   | bad_attitude       |  False   |
# |   3   | safety_shutdown    |  False   |
# +-------+--------------------+----------+
#
# [INFO] Reward Manager:  <RewardManager> contains 6 active terms.
# +------------------------------------------+
# |           Active Reward Terms            |
# +-------+-------------------------+--------+
# | Index | Name                    | Weight |
# +-------+-------------------------+--------+
# |   0   | rew_attitude_stability2 |    2.0 |
# |   1   | rew_ang_vel_stability4  |    3.0 |
# |   2   | rew_altitude_hold2      |    4.0 |
# |   3   | rew_vel2                |    3.0 |
# |   4   | rew_pos2                |    3.0 |
# |   5   | rew_action_rate         |    0.5 |
# +-------+-------------------------+--------+
#
# [INFO] Curriculum Manager:  <CurriculumManager> contains 0 active terms.
# +----------------------+
# | Active Curriculum Terms |
# +-----------+----------+
# |   Index   | Name     |
# +-----------+----------+
# +-----------+----------+
#
# [INFO]: Completed setting up the environment...
# 2026-03-03T09:42:56Z [5,928ms] [Warning] [omni.physx.fabric.plugin] FabricManager::initializePointInstancer mismatched prototypes on point instancer: /Visuals/target_commands.
# [INFO]: Loading model checkpoint from: C:\Users\Teresa\Documents\GitHub\navsim\tmp\tmpTeresa\resultados_grid_command_v8\best_model_ppo_random_command8_11_8196.pt
# C:\Users\Teresa\miniconda3\envs\env_isaaclab\Lib\site-packages\rsl_rl\utils\utils.py:244: UserWarning: The observation configuration dictionary 'obs_groups' must contain the 'policy' key. As an observation group with the name 'policy' was found, this is assumed to be the observation set. Consider adding the 'policy' key to the 'obs_groups' dictionary for clarity. This behavior will be removed in a future version.
#   warnings.warn(
# C:\Users\Teresa\miniconda3\envs\env_isaaclab\Lib\site-packages\rsl_rl\utils\utils.py:282: UserWarning: The observation configuration dictionary 'obs_groups' must contain the 'critic' key. As an observation group with the name 'critic' was found, this is assumed to be the observation set. Consider adding the 'critic' key to the 'obs_groups' dictionary for clarity. This behavior will be removed in a future version.
#   warnings.warn(
# --------------------------------------------------------------------------------
# Resolved observation sets:
# 	 policy :  ['policy']
# 	 critic :  ['critic']
# --------------------------------------------------------------------------------
# Actor MLP: MLP(
#   (0): Linear(in_features=13, out_features=128, bias=True)
#   (1): ELU(alpha=1.0)
#   (2): Linear(in_features=128, out_features=128, bias=True)
#   (3): ELU(alpha=1.0)
#   (4): Linear(in_features=128, out_features=128, bias=True)
#   (5): ELU(alpha=1.0)
#   (6): Linear(in_features=128, out_features=128, bias=True)
#   (7): ELU(alpha=1.0)
#   (8): Linear(in_features=128, out_features=4, bias=True)
# )
# Critic MLP: MLP(
#   (0): Linear(in_features=13, out_features=512, bias=True)
#   (1): ELU(alpha=1.0)
#   (2): Linear(in_features=512, out_features=512, bias=True)
#   (3): ELU(alpha=1.0)
#   (4): Linear(in_features=512, out_features=512, bias=True)
#   (5): ELU(alpha=1.0)
#   (6): Linear(in_features=512, out_features=512, bias=True)
#   (7): ELU(alpha=1.0)
#   (8): Linear(in_features=512, out_features=512, bias=True)
#   (9): ELU(alpha=1.0)
#   (10): Linear(in_features=512, out_features=1, bias=True)
# )
#
# --- Todos los experimentos de test han finalizado ---

# %%
import pandas as pd

df_train = top5_models.copy()
if df_train.index.name == 'id_run_name':
    df_train = df_train.reset_index()

df_train = df_train.rename(columns={
    'reward': 'reward_train',
    'max_reward': 'max_reward_train',
    'std_reward': 'std_train'
})

df_test = df_rewards_play.copy()

df_test = pd.read_csv(path_resultados+'/rewards_play_PPO.csv')
df_test = df_test.rename(columns={
    'reward': 'reward_test',
    'max_reward': 'max_reward_test',
    'std': 'std_test'
})

df_final = pd.merge(
    df_train[['id_run_name', 'num_envs_train', 'reward_train', 'max_reward_train', 'std_train', 'iteration']], 
    df_test[['id_run_name', 'num_envs_test', 'reward_test', 'max_reward_test', 'std_test', 'checkpoint']], 
    on='id_run_name', 
    how='inner'
)

column_order = [
    'id_run_name',
    'num_envs_train',
    'num_envs_test',
    'reward_train', 'reward_test', 
    'max_reward_train', 'max_reward_test', 
    'std_train', 'std_test',
    'iteration'
]
df_final = df_final[column_order]

df_final = df_final.sort_values(by='id_run_name', ascending=False)

# %%
df_rewards_play = df_final.sort_values(by="id_run_name",ascending=False)
df_rewards_play = df_rewards_play.reset_index().drop(columns='index')

df_final = df_rewards_play.copy()

df_final['diff_rw_test_train'] = df_final['reward_test'] - df_final['reward_train']

df_final['diferencia(%)'] = (df_final['diff_rw_test_train'] / df_final['reward_train'].abs()) * 100

df_final['diferencia(%)'] = df_final['diferencia(%)'].apply(lambda x: f"{x:+.2f}%")

df_final
# Out:
#               id_run_name  num_envs_train  num_envs_test  reward_train  \
# 0  ppo_random_command8_11            8196              1    320.285452
# 1  ppo_random_command8_11            8196             64    320.285452
# 2  ppo_random_command8_11            8196            256    320.285452
#
#    reward_test  max_reward_train  max_reward_test  std_train   std_test  \
# 0   123.925476        362.532379       196.593587  26.208705  72.668110
# 1   163.124105        362.532379       276.468541  26.208705  91.628671
# 2   168.124967        362.532379       278.059676  26.208705  86.047806
#
#    iteration  diff_rw_test_train diferencia(%)
# 0        412         -196.359976       -61.31%
# 1        412         -157.161347       -49.07%
# 2        412         -152.160486       -47.51%

# %% [markdown]
# Pruebas con un solo entorno: Vemos cómo se comporta la política para un único agente en una prueba aleatoria.

# %%
df_final[df_final['num_envs_test'] == 1].sort_values(by='reward_test',ascending=False)
# Out:
#               id_run_name  num_envs_train  num_envs_test  reward_train  \
# 0  ppo_random_command8_11            8196              1    320.285452
#
#    reward_test  max_reward_train  max_reward_test  std_train  std_test  \
# 0   123.925476        362.532379       196.593587  26.208705  72.66811
#
#    iteration  diff_rw_test_train diferencia(%)
# 0        412         -196.359976       -61.31%

# %% [markdown]
# ``Interpretación``: Vemos que el modelo 38 se ha estampado en la prueba aleatoria, así que ese modelo no debería usarse para ninguna transferencia real.

# %% [markdown]
# Pruebas con varios entornos: Vemos cómo se comporta la política en múltiples entornos (varias pruebas simuladas en paralelo), teniendo en cuenta cuál es la desviación de cada uno en test, lo que nos permite inferir si la recompensa es estable para todas las pruebas.

# %%
df_final[df_final['num_envs_test'] != 1].sort_values(by='std_test',ascending=True).reset_index().drop(columns="index")
# Out:
#               id_run_name  num_envs_train  num_envs_test  reward_train  \
# 0  ppo_random_command8_11            8196            256    320.285452
# 1  ppo_random_command8_11            8196             64    320.285452
#
#    reward_test  max_reward_train  max_reward_test  std_train   std_test  \
# 0   168.124967        362.532379       278.059676  26.208705  86.047806
# 1   163.124105        362.532379       276.468541  26.208705  91.628671
#
#    iteration  diff_rw_test_train diferencia(%)
# 0        412         -152.160486       -47.51%
# 1        412         -157.161347       -49.07%

# %% [markdown]
# pruebas:

# %% [markdown]
# C:/Users/Teresa/Desktop/RuralData/IsaacLab/IsaacLab/isaaclab.bat -p C:/Users/Teresa/Documents/GitHub/navsim/isaac_lab/rl_v5_1_0/rsl_rl/train.py --task Isaac-Command5-Aerotaxi-RANDOM-11 --num_envs 8196 --headless
