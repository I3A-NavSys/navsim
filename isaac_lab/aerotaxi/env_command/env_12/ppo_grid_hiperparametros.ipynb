# %%
# Parámetros a configurar:
import os
experiment_name = "command8"
task_name = "Command8"
cfg_dir = "C:/Users/Teresa/Documents/GitHub/navsim/isaac_lab/aerotaxi/env_command/env_12/grid_hiperparametros/cfg_files"
path_resultados = "C:/Users/Teresa/Documents/GitHub/navsim/tmp/tmpTeresa/resultados_grid_command_v8"
isaaclab_bat = "C:/Users/Teresa/Desktop/RuralData/IsaacLab/IsaacLab/isaaclab.bat"
train_script = "C:/Users/Teresa/Documents/GitHub/navsim/isaac_lab/rl_v5_1_0/rsl_rl/train.py"
id_task = f"Isaac-{task_name}-Aerotaxi-RANDOM" # luego se le añade el número de task con el guión (Isaac-Command2-Aerotaxi-RANDOM-34)
play_script = "C:/Users/Teresa/Documents/GitHub/navsim/isaac_lab/rl_v5_1_0/rsl_rl/play.py"
num_iter = "1001"
num_steps_per_env = 100
powershell_script = os.path.join(cfg_dir, "run_all.ps1")

# el num_steps_per_env = 100 también está en el env, al final del todo, y deben tener el mismo valor
# Recuerda iniciar en el init todos los experimentos

# %%
import random
import os

# Si los directorios no existen (el último indicado), lo crea
os.makedirs(cfg_dir, exist_ok=True)
os.makedirs(path_resultados, exist_ok=True)
# Opciones de hiperparámetros
param_options = {
    "init_noise_std": [0.0, 0.1, 0.2, 0.5, 0.8, 1.0],
    "actor_hidden_dims": [[64, 64], [128, 128], [256, 256], [128, 64]],
    "critic_hidden_dims": [[64, 64], [128, 128], [256, 256]],
    "activation": ["relu", "tanh", "elu", "gelu"],
    "value_loss_coef": [0.5, 1.0, 2.0],
    "clip_param": [0.1, 0.2, 0.3],
    "entropy_coef": [0.0, 0.001, 0.01, 0.05],
    "num_learning_epochs": [4, 8, 12],
    "num_mini_batches": [2, 4, 8],
    "learning_rate": [5e-05, 1e-4, 3e-4, 1e-3, 3e-3],
    "gamma": [0.95, 0.98, 0.99],
    "lam": [0.90, 0.95, 0.97],
    "max_grad_norm": [0.5, 1.0, 2.0],
    "desired_kl": [0.005, 0.008, 0.01, 0.02],
}

num_trials = 35  # cantidad de configuraciones

cfg_files = []

for i in range(num_trials):
    run_name = f"ppo_random_{experiment_name}_{i+1}"
    sampled = {k: random.choice(v) for k, v in param_options.items()}

    # Convertir listas a string
    actor_dims = sampled["actor_hidden_dims"]
    critic_dims = sampled["critic_hidden_dims"]

    cfg_content = f"""
from isaaclab.utils import configclass
from isaaclab_rl.rsl_rl import RslRlOnPolicyRunnerCfg, RslRlPpoActorCriticCfg, RslRlPpoAlgorithmCfg

@configclass
class {task_name}PPORunnerCfg(RslRlOnPolicyRunnerCfg):
    num_steps_per_env = {num_steps_per_env} 
    max_iterations = {num_iter}
    save_interval = 100
    experiment_name = "{experiment_name}"
    run_name = "{run_name}"
    resume = False
    empirical_normalization = False
    csv_path_metrics = "{path_resultados}"
    callbacks = True
    policy = RslRlPpoActorCriticCfg(
        init_noise_std={sampled['init_noise_std']},
        actor_hidden_dims={actor_dims},
        critic_hidden_dims={critic_dims},
        activation="{sampled['activation']}",
    )
    algorithm = RslRlPpoAlgorithmCfg(
        value_loss_coef={sampled['value_loss_coef']},
        use_clipped_value_loss=True,
        clip_param={sampled['clip_param']},
        entropy_coef={sampled['entropy_coef']},
        num_learning_epochs={sampled['num_learning_epochs']},
        num_mini_batches={sampled['num_mini_batches']},
        learning_rate={sampled['learning_rate']},
        schedule="adaptive",
        gamma={sampled['gamma']},
        lam={sampled['lam']},
        desired_kl={sampled['desired_kl']},
        max_grad_norm={sampled['max_grad_norm']},
    )
"""
    cfg_path = os.path.join(cfg_dir, f"{run_name}_cfg.py")
    with open(cfg_path, "w") as f:
        f.write(cfg_content.strip())
    cfg_files.append((run_name, cfg_path))

# Crear archivo PowerShell para ejecutar todas las configuraciones
powershell_script = os.path.join(cfg_dir, "run_all.ps1")

num_envs =  [64, 128, 512, 1024, 2048, 4096, 8196] #número de entornos para train (paralelizados)

with open(powershell_script, "w") as f:
    f.write("$ErrorActionPreference = 'Stop'\n\n")
    j = 0
    for run_name, cfg_path in cfg_files:
        # Convertir path a módulo Python (reemplazar / y .py)
        num_envs_i = random.choice(num_envs)
        module_path = cfg_path.replace("/", ".").replace("\\", ".").replace(".py", "")
        f.write(f'Write-Host "Ejecutando {run_name}"\n')
        f.write(f'& "{isaaclab_bat}" -p "{train_script}" --task {id_task}-{j+1} --num_envs {num_envs_i} --headless \n\n')
        j += 1
print("Archivos de configuración generados y script PowerShell listo en:", powershell_script)
# Out:
# Archivos de configuración generados y script PowerShell listo en: C:/Users/Teresa/Documents/GitHub/navsim/isaac_lab/aerotaxi/env_command/env_11/grid_hiperparametros/cfg_files\run_all.ps1

# %%
# Ejecuta el entrenamiento de forma automática
# !powershell -ExecutionPolicy Bypass -File "{powershell_script}"
import subprocess
import sys

# Ruta al script que generaste
powershell_script_path = powershell_script 

print(f"Iniciando ejecución de: {powershell_script_path}\n")

# Ejecutamos el proceso capturando la salida en tiempo real
process = subprocess.Popen(
    ["powershell.exe", "-ExecutionPolicy", "Bypass", "-File", powershell_script_path],
    stdout=subprocess.PIPE,
    stderr=subprocess.STDOUT, # Redirigimos errores a la salida estándar para verlos
    text=True,
    bufsize=1
)

# Leemos la salida línea a línea conforme se genera
try:
    for line in process.stdout:
        print(line, end="") # Imprime la salida de PowerShell en la celda
        sys.stdout.flush()   # Fuerza a Jupyter a mostrar la línea inmediatamente
except KeyboardInterrupt:
    process.kill()
    print("\nEntrenamiento cancelado por el usuario.")

process.wait()
print("\n--- Todos los experimentos han finalizado ---")
# Out:
# Iniciando ejecución de: C:/Users/Teresa/Documents/GitHub/navsim/isaac_lab/aerotaxi/env_command/env_12/grid_hiperparametros/cfg_files\run_all.ps1
#
# Ejecutando ppo_random_command8_11
# [INFO] Using python from: C:\Users\Teresa\miniconda3\envs\env_isaaclab\python.exe
# [INFO][AppLauncher]: Using device: cuda:0
# [INFO][AppLauncher]: Loading experience file: C:\Users\Teresa\miniconda3\envs\env_isaaclab\Lib\site-packages\isaaclab\apps\isaaclab.python.headless.kit
# Loading user config located at: 'c:/users/teresa/miniconda3/envs/env_isaaclab/lib/site-packages/isaacsim/kit/data/Kit/Isaac-Sim/5.1/user.config.json'
# [Info] [carb] Logging to file: c:/users/teresa/miniconda3/envs/env_isaaclab/lib/site-packages/isaacsim/kit/logs/Kit/Isaac-Sim/5.1/kit_20260303_133040.log
# 2026-03-03T12:30:40Z s] [Warning] [omni.usd_config.extension] Enable omni.materialx.libs extension to use MaterialX
# 2026-03-03T12:30:41Z s] [Warning] [carb] Acquiring non optional plugin interface which is not listed as dependency: [omni::physx::IPhysxBenchmarks v1.0] (plugin: <default plugin>), by client: omni.physics.physx.plugin. Add it to CARB_PLUGIN_IMPL_DEPS() macro of a client.
# 2026-03-03T12:30:41Z s] [Warning] [omni.isaac.dynamic_control] omni.isaac.dynamic_control is deprecated as of Isaac Sim 4.5. No action is needed from end-users.
# 2026-03-03T12:30:43Z [2,527ms] [Warning] [gpu.foundation.plugin] Skipping unsupported non-NVIDIA GPU: AMD Radeon(TM) Graphics
# 2026-03-03T12:30:43Z [2,528ms] [Warning] [gpu.foundation.plugin] Skipping unsupported non-NVIDIA GPU: AMD Radeon(TM) Graphics
#
# |---------------------------------------------------------------------------------------------|
# | Driver Version: 581.29        | Graphics API: D3D12
# |=============================================================================================|
# | GPU | Name                             | Active | LDA | GPU Memory | Vendor-ID | LUID       |
# |     |                                  |        |     |            | Device-ID | UUID       |
# |     |                                  |        |     |            | Bus-ID    |            |
# |---------------------------------------------------------------------------------------------|
# | 0   | NVIDIA GeForce RTX 5080          | Yes: 0 |     | 15889   MB | 10de      | 295a0100.. |
# |     |                                  |        |     |            | 2c02      | 0          |
# |     |                                  |        |     |            | 1         |            |
# |---------------------------------------------------------------------------------------------|
# | 1   | AMD Radeon(TM) Graphics          |        |     | 1995    MB | 1002      | 876d0100.. |
# |     |                                  |        |     |            | 13c0      | 0          |
# |     |                                  |        |     |            | N/A       |            |
# |=============================================================================================|
# | OS: Windows 11 Pro, Version: 10.0 (25H2), Build: 26200, Kernel: 10.0.26100.7824
# | Processor: AMD Ryzen 9 9950X 16-Core Processor
# | Cores: 16 | Logical Cores: 32
# |---------------------------------------------------------------------------------------------|
# | Total Memory (MB): 128627 | Free Memory: 101717
# | Total Page/Swap (MB): 136819 | Free Page/Swap: 102601
# |---------------------------------------------------------------------------------------------|
# C:\Users\Teresa\Documents\GitHub\navsim\isaac_lab\aerotaxi\env_command\env_12\flight_plan.py:29: UserWarning: Treat the new Tool classes introduced in v1.5 as experimental for now; the API and rcParam may change in future versions.
#   plt.rcParams["toolbar"] = "toolmanager"
# [INFO]: Parsing configuration from: aerotaxi.env_command.env_12.env:UAVEnvCfg
# [INFO]: Parsing configuration from: aerotaxi.env_command.env_12.grid_hiperparametros.cfg_files.ppo_random_command8_11_cfg:Command8PPORunnerCfg
# [INFO] Logging experiment in directory: C:\Users\Teresa\Documents\GitHub\navsim\isaac_lab\aerotaxi\env_command\env_12\logs\rsl_rl\command8
# Exact experiment name requested from command line: 2026-03-03_13-30-44
# Setting seed: 42
# [INFO]: Base environment:
# 	Environment device    : cuda:0
# 	Environment seed      : 42
# 	Physics step-size     : 0.005
# 	Rendering step-size   : 0.02
# 	Environment step-size : 0.02
# [INFO]: Time taken for scene creation : 2.438427 seconds
# [INFO]: Scene manager:  <class InteractiveScene>
# 	Number of environments: 4096
# 	Environment spacing   : 200.0
# 	Source prim name      : /World/envs/env_0
# 	Global prim paths     : []
# 	Replicate physics     : False
# [INFO]: Starting the simulation. This may take a few seconds. Please wait...
# [INFO]: Time taken for simulation start : 2.890357 seconds
# [INFO] Command Manager:  <CommandManager> contains 1 active terms.
# +--------------------------------------+
# |         Active Command Terms         |
# +-------+-------------+----------------+
# | Index | Name        |      Type      |
# +-------+-------------+----------------+
# |   0   | vel_command | UAVcommandTerm |
# +-------+-------------+----------------+
#
# [INFO] Event Manager:  <EventManager> contains 1 active terms.
# +-----------------------------------+
# | Active Event Terms in Mode: 'reset' |
# +----------+------------------------+
# |  Index   | Name                   |
# +----------+------------------------+
# |    0     | reset_pos              |
# |    1     | randomize_mass         |
# |    2     | randomize_wind         |
# +----------+------------------------+
#
# [INFO] Recorder Manager:  <RecorderManager> contains 0 active terms.
# +---------------------+
# | Active Recorder Terms |
# +-----------+---------+
# |   Index   | Name    |
# +-----------+---------+
# +-----------+---------+
#
# [INFO] Action Manager:  <ActionManager> contains 1 active terms.
# +-----------------------------------+
# |   Active Action Terms (shape: 4)  |
# +--------+-------------+------------+
# | Index  | Name        |  Dimension |
# +--------+-------------+------------+
# |   0    | rotors_vel  |          4 |
# +--------+-------------+------------+
#
# [INFO] Observation Manager: <ObservationManager> contains 2 groups.
# +---------------------------------------------------------+
# | Active Observation Terms in Group: 'policy' (shape: (13,)) |
# +-----------+---------------------------------+-----------+
# |   Index   | Name                            |   Shape   |
# +-----------+---------------------------------+-----------+
# |     0     | dist                            |    (3,)   |
# |     1     | lin_vel                         |    (3,)   |
# |     2     | ang_vel                         |    (3,)   |
# |     3     | height                          |    (1,)   |
# |     4     | projected_gravity               |    (3,)   |
# +-----------+---------------------------------+-----------+
# +---------------------------------------------------------+
# | Active Observation Terms in Group: 'critic' (shape: (13,)) |
# +-----------+---------------------------------+-----------+
# |   Index   | Name                            |   Shape   |
# +-----------+---------------------------------+-----------+
# |     0     | dist                            |    (3,)   |
# |     1     | lin_vel                         |    (3,)   |
# |     2     | ang_vel                         |    (3,)   |
# |     3     | height                          |    (1,)   |
# |     4     | projected_gravity               |    (3,)   |
# +-----------+---------------------------------+-----------+
#
# [INFO] Termination Manager:  <TerminationManager> contains 4 active terms.
# +---------------------------------------+
# |        Active Termination Terms       |
# +-------+--------------------+----------+
# | Index | Name               | Time Out |
# +-------+--------------------+----------+
# |   0   | time_out           |   True   |
# |   1   | below_min_altitude |  False   |
# |   2   | bad_attitude       |  False   |
# |   3   | safety_shutdown    |  False   |
# +-------+--------------------+----------+
#
# [INFO] Reward Manager:  <RewardManager> contains 6 active terms.
# +------------------------------------------+
# |           Active Reward Terms            |
# +-------+-------------------------+--------+
# | Index | Name                    | Weight |
# +-------+-------------------------+--------+
# |   0   | rew_attitude_stability2 |    8.0 |
# |   1   | rew_ang_vel_stability4  |    4.0 |
# |   2   | rew_altitude_hold2      |    4.0 |
# |   3   | rew_vel2                |    1.5 |
# |   4   | rew_pos2                |    2.0 |
# |   5   | rew_action_rate         |    3.0 |
# +-------+-------------------------+--------+
#
# [INFO] Curriculum Manager:  <CurriculumManager> contains 0 active terms.
# +----------------------+
# | Active Curriculum Terms |
# +-----------+----------+
# |   Index   | Name     |
# +-----------+----------+
# +-----------+----------+
#
# [INFO]: Completed setting up the environment...
# 2026-03-03T12:30:50Z [9,581ms] [Warning] [omni.physx.fabric.plugin] FabricManager::initializePointInstancer mismatched prototypes on point instancer: /Visuals/target_commands.
# C:\Users\Teresa\miniconda3\envs\env_isaaclab\Lib\site-packages\rsl_rl\utils\utils.py:244: UserWarning: The observation configuration dictionary 'obs_groups' must contain the 'policy' key. As an observation group with the name 'policy' was found, this is assumed to be the observation set. Consider adding the 'policy' key to the 'obs_groups' dictionary for clarity. This behavior will be removed in a future version.
#   warnings.warn(
# C:\Users\Teresa\miniconda3\envs\env_isaaclab\Lib\site-packages\rsl_rl\utils\utils.py:282: UserWarning: The observation configuration dictionary 'obs_groups' must contain the 'critic' key. As an observation group with the name 'critic' was found, this is assumed to be the observation set. Consider adding the 'critic' key to the 'obs_groups' dictionary for clarity. This behavior will be removed in a future version.
#   warnings.warn(
# --------------------------------------------------------------------------------
# Resolved observation sets:
# 	 policy :  ['policy']
# 	 critic :  ['critic']
# --------------------------------------------------------------------------------
# Actor MLP: MLP(
#   (0): Linear(in_features=13, out_features=128, bias=True)
#   (1): ELU(alpha=1.0)
#   (2): Linear(in_features=128, out_features=128, bias=True)
#   (3): ELU(alpha=1.0)
#   (4): Linear(in_features=128, out_features=128, bias=True)
#   (5): ELU(alpha=1.0)
#   (6): Linear(in_features=128, out_features=4, bias=True)
# )
# Critic MLP: MLP(
#   (0): Linear(in_features=13, out_features=256, bias=True)
#   (1): ELU(alpha=1.0)
#   (2): Linear(in_features=256, out_features=256, bias=True)
#   (3): ELU(alpha=1.0)
#   (4): Linear(in_features=256, out_features=256, bias=True)
#   (5): ELU(alpha=1.0)
#   (6): Linear(in_features=256, out_features=1, bias=True)
# )
# ################################################################################
#                        Learning iteration 0/1001
#
#                        Computation: 103284 steps/s (collection: 4.765s, learning 0.312s)
#              Mean action noise std: 0.05
#           Mean value_function loss: 5.8101
#                Mean surrogate loss: 0.1506
#                  Mean entropy loss: -6.2157
#                        Mean reward: 7.55
#                Mean episode length: 32.88
# Episode_Reward/rew_attitude_stability2: 0.0975
# Episode_Reward/rew_ang_vel_stability4: 0.0643
#  Episode_Reward/rew_altitude_hold2: 0.0830
#            Episode_Reward/rew_vel2: 0.0073
#            Episode_Reward/rew_pos2: 0.0446
#     Episode_Reward/rew_action_rate: -0.0000
#       Episode_Termination/time_out: 0.0089
# Episode_Termination/below_min_altitude: 0.0001
#   Episode_Termination/bad_attitude: 0.6370
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 524288
#                     Iteration time: 5.08s
#                       Time elapsed: 00:00:05
#                                ETA: 01:24:41
#
# Could not find git repository in C:\Users\Teresa\miniconda3\envs\env_isaaclab\Lib\site-packages\rsl_rl\__init__.py. Skipping.
# Storing git diff for 'navsim' in: C:\Users\Teresa\Documents\GitHub\navsim\isaac_lab\aerotaxi\env_command\env_12\logs\rsl_rl\command8\2026-03-03_13-30-44_ppo_random_command8_11\git\navsim.diff
# ################################################################################
#                        Learning iteration 1/1001
#
#                        Computation: 143312 steps/s (collection: 3.434s, learning 0.224s)
#              Mean action noise std: 0.05
#           Mean value_function loss: 4.2559
#                Mean surrogate loss: 0.0568
#                  Mean entropy loss: -6.1896
#                        Mean reward: 7.64
#                Mean episode length: 33.00
# Episode_Reward/rew_attitude_stability2: 0.0982
# Episode_Reward/rew_ang_vel_stability4: 0.0584
#  Episode_Reward/rew_altitude_hold2: 0.0899
#            Episode_Reward/rew_vel2: 0.0078
#            Episode_Reward/rew_pos2: 0.0476
#     Episode_Reward/rew_action_rate: -0.0000
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 0.0000
#   Episode_Termination/bad_attitude: 1.0000
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 1048576
#                     Iteration time: 3.66s
#                       Time elapsed: 00:00:08
#                                ETA: 01:12:47
#
# ################################################################################
#                        Learning iteration 2/1001
#
#                        Computation: 144060 steps/s (collection: 3.413s, learning 0.227s)
#              Mean action noise std: 0.05
#           Mean value_function loss: 3.6465
#                Mean surrogate loss: 0.0196
#                  Mean entropy loss: -6.1721
#                        Mean reward: 7.48
#                Mean episode length: 32.62
# Episode_Reward/rew_attitude_stability2: 0.0977
# Episode_Reward/rew_ang_vel_stability4: 0.0576
#  Episode_Reward/rew_altitude_hold2: 0.0893
#            Episode_Reward/rew_vel2: 0.0078
#            Episode_Reward/rew_pos2: 0.0473
#     Episode_Reward/rew_action_rate: -0.0000
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 0.0000
#   Episode_Termination/bad_attitude: 1.0000
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 1572864
#                     Iteration time: 3.64s
#                       Time elapsed: 00:00:12
#                                ETA: 01:08:40
#
# ################################################################################
#                        Learning iteration 3/1001
#
#                        Computation: 142592 steps/s (collection: 3.448s, learning 0.229s)
#              Mean action noise std: 0.05
#           Mean value_function loss: 3.2392
#                Mean surrogate loss: 0.0474
#                  Mean entropy loss: -6.1304
#                        Mean reward: 7.28
#                Mean episode length: 31.84
# Episode_Reward/rew_attitude_stability2: 0.0973
# Episode_Reward/rew_ang_vel_stability4: 0.0576
#  Episode_Reward/rew_altitude_hold2: 0.0893
#            Episode_Reward/rew_vel2: 0.0078
#            Episode_Reward/rew_pos2: 0.0472
#     Episode_Reward/rew_action_rate: -0.0000
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 0.0000
#   Episode_Termination/bad_attitude: 1.0000
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 2097152
#                     Iteration time: 3.68s
#                       Time elapsed: 00:00:16
#                                ETA: 01:06:44
#
# ################################################################################
#                        Learning iteration 4/1001
#
#                        Computation: 140716 steps/s (collection: 3.499s, learning 0.227s)
#              Mean action noise std: 0.05
#           Mean value_function loss: 2.7967
#                Mean surrogate loss: 0.0346
#                  Mean entropy loss: -6.0604
#                        Mean reward: 7.18
#                Mean episode length: 31.51
# Episode_Reward/rew_attitude_stability2: 0.0960
# Episode_Reward/rew_ang_vel_stability4: 0.0564
#  Episode_Reward/rew_altitude_hold2: 0.0883
#            Episode_Reward/rew_vel2: 0.0077
#            Episode_Reward/rew_pos2: 0.0467
#     Episode_Reward/rew_action_rate: -0.0000
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 0.0000
#   Episode_Termination/bad_attitude: 1.0000
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 2621440
#                     Iteration time: 3.73s
#                       Time elapsed: 00:00:19
#                                ETA: 01:05:43
#
# ################################################################################
#                        Learning iteration 5/1001
#
#                        Computation: 141953 steps/s (collection: 3.467s, learning 0.226s)
#              Mean action noise std: 0.05
#           Mean value_function loss: 2.4189
#                Mean surrogate loss: 0.0425
#                  Mean entropy loss: -6.0095
#                        Mean reward: 7.33
#                Mean episode length: 31.91
# Episode_Reward/rew_attitude_stability2: 0.0970
# Episode_Reward/rew_ang_vel_stability4: 0.0570
#  Episode_Reward/rew_altitude_hold2: 0.0891
#            Episode_Reward/rew_vel2: 0.0079
#            Episode_Reward/rew_pos2: 0.0470
#     Episode_Reward/rew_action_rate: -0.0000
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 0.0000
#   Episode_Termination/bad_attitude: 1.0000
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 3145728
#                     Iteration time: 3.69s
#                       Time elapsed: 00:00:23
#                                ETA: 01:04:56
#
# ################################################################################
#                        Learning iteration 6/1001
#
#                        Computation: 142863 steps/s (collection: 3.442s, learning 0.228s)
#              Mean action noise std: 0.05
#           Mean value_function loss: 1.9243
#                Mean surrogate loss: 0.0449
#                  Mean entropy loss: -5.9684
#                        Mean reward: 7.33
#                Mean episode length: 31.71
# Episode_Reward/rew_attitude_stability2: 0.0963
# Episode_Reward/rew_ang_vel_stability4: 0.0562
#  Episode_Reward/rew_altitude_hold2: 0.0888
#            Episode_Reward/rew_vel2: 0.0079
#            Episode_Reward/rew_pos2: 0.0466
#     Episode_Reward/rew_action_rate: -0.0000
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 0.0000
#   Episode_Termination/bad_attitude: 1.0000
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 3670016
#                     Iteration time: 3.67s
#                       Time elapsed: 00:00:27
#                                ETA: 01:04:17
#
# ################################################################################
#                        Learning iteration 7/1001
#
#                        Computation: 143921 steps/s (collection: 3.415s, learning 0.228s)
#              Mean action noise std: 0.06
#           Mean value_function loss: 1.5468
#                Mean surrogate loss: 0.0286
#                  Mean entropy loss: -5.9101
#                        Mean reward: 7.73
#                Mean episode length: 33.13
# Episode_Reward/rew_attitude_stability2: 0.0968
# Episode_Reward/rew_ang_vel_stability4: 0.0572
#  Episode_Reward/rew_altitude_hold2: 0.0896
#            Episode_Reward/rew_vel2: 0.0079
#            Episode_Reward/rew_pos2: 0.0469
#     Episode_Reward/rew_action_rate: -0.0000
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 0.0000
#   Episode_Termination/bad_attitude: 1.0000
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 4194304
#                     Iteration time: 3.64s
#                       Time elapsed: 00:00:30
#                                ETA: 01:03:44
#
# ################################################################################
#                        Learning iteration 8/1001
#
#                        Computation: 143802 steps/s (collection: 3.420s, learning 0.226s)
#              Mean action noise std: 0.06
#           Mean value_function loss: 1.2612
#                Mean surrogate loss: 0.0400
#                  Mean entropy loss: -5.8565
#                        Mean reward: 7.50
#                Mean episode length: 33.28
# Episode_Reward/rew_attitude_stability2: 0.0985
# Episode_Reward/rew_ang_vel_stability4: 0.0586
#  Episode_Reward/rew_altitude_hold2: 0.0905
#            Episode_Reward/rew_vel2: 0.0079
#            Episode_Reward/rew_pos2: 0.0475
#     Episode_Reward/rew_action_rate: -0.0000
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 0.0000
#   Episode_Termination/bad_attitude: 1.0000
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 4718592
#                     Iteration time: 3.65s
#                       Time elapsed: 00:00:34
#                                ETA: 01:03:18
#
# ################################################################################
#                        Learning iteration 9/1001
#
#                        Computation: 143174 steps/s (collection: 3.435s, learning 0.227s)
#              Mean action noise std: 0.06
#           Mean value_function loss: 1.0960
#                Mean surrogate loss: 0.0299
#                  Mean entropy loss: -5.8241
#                        Mean reward: 7.57
#                Mean episode length: 32.76
# Episode_Reward/rew_attitude_stability2: 0.0991
# Episode_Reward/rew_ang_vel_stability4: 0.0591
#  Episode_Reward/rew_altitude_hold2: 0.0909
#            Episode_Reward/rew_vel2: 0.0079
#            Episode_Reward/rew_pos2: 0.0477
#     Episode_Reward/rew_action_rate: -0.0000
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 0.0000
#   Episode_Termination/bad_attitude: 1.0000
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 5242880
#                     Iteration time: 3.66s
#                       Time elapsed: 00:00:38
#                                ETA: 01:02:58
#
# ################################################################################
#                        Learning iteration 10/1001
#
#                        Computation: 143745 steps/s (collection: 3.422s, learning 0.226s)
#              Mean action noise std: 0.06
#           Mean value_function loss: 0.9862
#                Mean surrogate loss: 0.0320
#                  Mean entropy loss: -5.7695
#                        Mean reward: 7.81
#                Mean episode length: 33.71
# Episode_Reward/rew_attitude_stability2: 0.1002
# Episode_Reward/rew_ang_vel_stability4: 0.0599
#  Episode_Reward/rew_altitude_hold2: 0.0914
#            Episode_Reward/rew_vel2: 0.0080
#            Episode_Reward/rew_pos2: 0.0481
#     Episode_Reward/rew_action_rate: -0.0000
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 0.0000
#   Episode_Termination/bad_attitude: 1.0000
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 5767168
#                     Iteration time: 3.65s
#                       Time elapsed: 00:00:41
#                                ETA: 01:02:40
#
# ################################################################################
#                        Learning iteration 11/1001
#
#                        Computation: 145742 steps/s (collection: 3.369s, learning 0.228s)
#              Mean action noise std: 0.06
#           Mean value_function loss: 0.9212
#                Mean surrogate loss: 0.0236
#                  Mean entropy loss: -5.7508
#                        Mean reward: 8.12
#                Mean episode length: 34.92
# Episode_Reward/rew_attitude_stability2: 0.1024
# Episode_Reward/rew_ang_vel_stability4: 0.0619
#  Episode_Reward/rew_altitude_hold2: 0.0928
#            Episode_Reward/rew_vel2: 0.0080
#            Episode_Reward/rew_pos2: 0.0487
#     Episode_Reward/rew_action_rate: -0.0000
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 0.0000
#   Episode_Termination/bad_attitude: 1.0000
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 6291456
#                     Iteration time: 3.60s
#                       Time elapsed: 00:00:45
#                                ETA: 01:02:20
#
# ################################################################################
#                        Learning iteration 12/1001
#
#                        Computation: 143745 steps/s (collection: 3.421s, learning 0.227s)
#              Mean action noise std: 0.06
#           Mean value_function loss: 0.7457
#                Mean surrogate loss: 0.0324
#                  Mean entropy loss: -5.7012
#                        Mean reward: 7.94
#                Mean episode length: 33.87
# Episode_Reward/rew_attitude_stability2: 0.1027
# Episode_Reward/rew_ang_vel_stability4: 0.0623
#  Episode_Reward/rew_altitude_hold2: 0.0929
#            Episode_Reward/rew_vel2: 0.0081
#            Episode_Reward/rew_pos2: 0.0490
#     Episode_Reward/rew_action_rate: -0.0000
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 0.0000
#   Episode_Termination/bad_attitude: 1.0000
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 6815744
#                     Iteration time: 3.65s
#                       Time elapsed: 00:00:48
#                                ETA: 01:02:06
#
# ################################################################################
#                        Learning iteration 13/1001
#
#                        Computation: 144080 steps/s (collection: 3.412s, learning 0.227s)
#              Mean action noise std: 0.06
#           Mean value_function loss: 0.6536
#                Mean surrogate loss: 0.0287
#                  Mean entropy loss: -5.6646
#                        Mean reward: 7.98
#                Mean episode length: 34.34
# Episode_Reward/rew_attitude_stability2: 0.1029
# Episode_Reward/rew_ang_vel_stability4: 0.0624
#  Episode_Reward/rew_altitude_hold2: 0.0931
#            Episode_Reward/rew_vel2: 0.0081
#            Episode_Reward/rew_pos2: 0.0490
#     Episode_Reward/rew_action_rate: -0.0000
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 0.0000
#   Episode_Termination/bad_attitude: 1.0000
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 7340032
#                     Iteration time: 3.64s
#                       Time elapsed: 00:00:52
#                                ETA: 01:01:53
#
# ################################################################################
#                        Learning iteration 14/1001
#
#                        Computation: 144218 steps/s (collection: 3.410s, learning 0.226s)
#              Mean action noise std: 0.06
#           Mean value_function loss: 0.5742
#                Mean surrogate loss: 0.0258
#                  Mean entropy loss: -5.6165
#                        Mean reward: 7.94
#                Mean episode length: 34.53
# Episode_Reward/rew_attitude_stability2: 0.1040
# Episode_Reward/rew_ang_vel_stability4: 0.0633
#  Episode_Reward/rew_altitude_hold2: 0.0936
#            Episode_Reward/rew_vel2: 0.0080
#            Episode_Reward/rew_pos2: 0.0493
#     Episode_Reward/rew_action_rate: -0.0000
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 0.0000
#   Episode_Termination/bad_attitude: 1.0000
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 7864320
#                     Iteration time: 3.64s
#                       Time elapsed: 00:00:56
#                                ETA: 01:01:41
#
# ################################################################################
#                        Learning iteration 15/1001
#
#                        Computation: 142863 steps/s (collection: 3.444s, learning 0.226s)
#              Mean action noise std: 0.06
#           Mean value_function loss: 0.5418
#                Mean surrogate loss: 0.0336
#                  Mean entropy loss: -5.5915
#                        Mean reward: 8.05
#                Mean episode length: 35.13
# Episode_Reward/rew_attitude_stability2: 0.1056
# Episode_Reward/rew_ang_vel_stability4: 0.0650
#  Episode_Reward/rew_altitude_hold2: 0.0942
#            Episode_Reward/rew_vel2: 0.0080
#            Episode_Reward/rew_pos2: 0.0499
#     Episode_Reward/rew_action_rate: -0.0000
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 0.0000
#   Episode_Termination/bad_attitude: 1.0000
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 8388608
#                     Iteration time: 3.67s
#                       Time elapsed: 00:00:59
#                                ETA: 01:01:32
#
# ################################################################################
#                        Learning iteration 16/1001
#
#                        Computation: 143214 steps/s (collection: 3.433s, learning 0.228s)
#              Mean action noise std: 0.06
#           Mean value_function loss: 0.4013
#                Mean surrogate loss: 0.0212
#                  Mean entropy loss: -5.5515
#                        Mean reward: 8.22
#                Mean episode length: 35.02
# Episode_Reward/rew_attitude_stability2: 0.1049
# Episode_Reward/rew_ang_vel_stability4: 0.0642
#  Episode_Reward/rew_altitude_hold2: 0.0938
#            Episode_Reward/rew_vel2: 0.0080
#            Episode_Reward/rew_pos2: 0.0496
#     Episode_Reward/rew_action_rate: -0.0000
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 0.0000
#   Episode_Termination/bad_attitude: 1.0000
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 8912896
#                     Iteration time: 3.66s
#                       Time elapsed: 00:01:03
#                                ETA: 01:01:24
#
# ################################################################################
#                        Learning iteration 17/1001
#
#                        Computation: 143942 steps/s (collection: 3.418s, learning 0.225s)
#              Mean action noise std: 0.06
#           Mean value_function loss: 0.3348
#                Mean surrogate loss: 0.0267
#                  Mean entropy loss: -5.5173
#                        Mean reward: 7.82
#                Mean episode length: 34.32
# Episode_Reward/rew_attitude_stability2: 0.1055
# Episode_Reward/rew_ang_vel_stability4: 0.0647
#  Episode_Reward/rew_altitude_hold2: 0.0944
#            Episode_Reward/rew_vel2: 0.0080
#            Episode_Reward/rew_pos2: 0.0498
#     Episode_Reward/rew_action_rate: -0.0000
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 0.0000
#   Episode_Termination/bad_attitude: 1.0000
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 9437184
#                     Iteration time: 3.64s
#                       Time elapsed: 00:01:07
#                                ETA: 01:01:15
#
# ################################################################################
#                        Learning iteration 18/1001
#
#                        Computation: 142185 steps/s (collection: 3.461s, learning 0.227s)
#              Mean action noise std: 0.06
#           Mean value_function loss: 0.2846
#                Mean surrogate loss: 0.0216
#                  Mean entropy loss: -5.4782
#                        Mean reward: 8.07
#                Mean episode length: 34.78
# Episode_Reward/rew_attitude_stability2: 0.1067
# Episode_Reward/rew_ang_vel_stability4: 0.0658
#  Episode_Reward/rew_altitude_hold2: 0.0949
#            Episode_Reward/rew_vel2: 0.0081
#            Episode_Reward/rew_pos2: 0.0502
#     Episode_Reward/rew_action_rate: -0.0000
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 0.0000
#   Episode_Termination/bad_attitude: 1.0000
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 9961472
#                     Iteration time: 3.69s
#                       Time elapsed: 00:01:10
#                                ETA: 01:01:09
#
# ################################################################################
#                        Learning iteration 19/1001
#
#                        Computation: 145864 steps/s (collection: 3.370s, learning 0.224s)
#              Mean action noise std: 0.06
#           Mean value_function loss: 0.2372
#                Mean surrogate loss: 0.0188
#                  Mean entropy loss: -5.4320
#                        Mean reward: 8.36
#                Mean episode length: 35.93
# Episode_Reward/rew_attitude_stability2: 0.1062
# Episode_Reward/rew_ang_vel_stability4: 0.0655
#  Episode_Reward/rew_altitude_hold2: 0.0951
#            Episode_Reward/rew_vel2: 0.0082
#            Episode_Reward/rew_pos2: 0.0500
#     Episode_Reward/rew_action_rate: -0.0000
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 0.0000
#   Episode_Termination/bad_attitude: 1.0000
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 10485760
#                     Iteration time: 3.59s
#                       Time elapsed: 00:01:14
#                                ETA: 01:00:58
#
# ################################################################################
#                        Learning iteration 20/1001
#
#                        Computation: 144219 steps/s (collection: 3.409s, learning 0.226s)
#              Mean action noise std: 0.06
#           Mean value_function loss: 0.2209
#                Mean surrogate loss: 0.0358
#                  Mean entropy loss: -5.3784
#                        Mean reward: 8.35
#                Mean episode length: 36.22
# Episode_Reward/rew_attitude_stability2: 0.1079
# Episode_Reward/rew_ang_vel_stability4: 0.0667
#  Episode_Reward/rew_altitude_hold2: 0.0957
#            Episode_Reward/rew_vel2: 0.0082
#            Episode_Reward/rew_pos2: 0.0506
#     Episode_Reward/rew_action_rate: -0.0000
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 0.0000
#   Episode_Termination/bad_attitude: 1.0000
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 11010048
#                     Iteration time: 3.64s
#                       Time elapsed: 00:01:18
#                                ETA: 01:00:50
#
# ################################################################################
#                        Learning iteration 21/1001
#
#                        Computation: 144059 steps/s (collection: 3.416s, learning 0.224s)
#              Mean action noise std: 0.06
#           Mean value_function loss: 0.1844
#                Mean surrogate loss: 0.0203
#                  Mean entropy loss: -5.3349
#                        Mean reward: 8.35
#                Mean episode length: 36.35
# Episode_Reward/rew_attitude_stability2: 0.1089
# Episode_Reward/rew_ang_vel_stability4: 0.0676
#  Episode_Reward/rew_altitude_hold2: 0.0963
#            Episode_Reward/rew_vel2: 0.0083
#            Episode_Reward/rew_pos2: 0.0508
#     Episode_Reward/rew_action_rate: -0.0000
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 0.0000
#   Episode_Termination/bad_attitude: 1.0000
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 11534336
#                     Iteration time: 3.64s
#                       Time elapsed: 00:01:21
#                                ETA: 01:00:43
#
# ################################################################################
#                        Learning iteration 22/1001
#
#                        Computation: 144696 steps/s (collection: 3.397s, learning 0.227s)
#              Mean action noise std: 0.06
#           Mean value_function loss: 0.1439
#                Mean surrogate loss: 0.0150
#                  Mean entropy loss: -5.2922
#                        Mean reward: 8.66
#                Mean episode length: 36.94
# Episode_Reward/rew_attitude_stability2: 0.1089
# Episode_Reward/rew_ang_vel_stability4: 0.0673
#  Episode_Reward/rew_altitude_hold2: 0.0963
#            Episode_Reward/rew_vel2: 0.0082
#            Episode_Reward/rew_pos2: 0.0507
#     Episode_Reward/rew_action_rate: -0.0000
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 0.0000
#   Episode_Termination/bad_attitude: 1.0000
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 12058624
#                     Iteration time: 3.62s
#                       Time elapsed: 00:01:25
#                                ETA: 01:00:35
#
# ################################################################################
#                        Learning iteration 23/1001
#
#                        Computation: 145238 steps/s (collection: 3.384s, learning 0.226s)
#              Mean action noise std: 0.07
#           Mean value_function loss: 0.1208
#                Mean surrogate loss: 0.0186
#                  Mean entropy loss: -5.2458
#                        Mean reward: 7.97
#                Mean episode length: 35.45
# Episode_Reward/rew_attitude_stability2: 0.1089
# Episode_Reward/rew_ang_vel_stability4: 0.0677
#  Episode_Reward/rew_altitude_hold2: 0.0962
#            Episode_Reward/rew_vel2: 0.0081
#            Episode_Reward/rew_pos2: 0.0508
#     Episode_Reward/rew_action_rate: -0.0000
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 0.0000
#   Episode_Termination/bad_attitude: 1.0000
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 12582912
#                     Iteration time: 3.61s
#                       Time elapsed: 00:01:29
#                                ETA: 01:00:27
#
# ################################################################################
#                        Learning iteration 24/1001
#
#                        Computation: 142843 steps/s (collection: 3.446s, learning 0.225s)
#              Mean action noise std: 0.07
#           Mean value_function loss: 0.1155
#                Mean surrogate loss: 0.0445
#                  Mean entropy loss: -5.1969
#                        Mean reward: 8.37
#                Mean episode length: 36.53
# Episode_Reward/rew_attitude_stability2: 0.1100
# Episode_Reward/rew_ang_vel_stability4: 0.0689
#  Episode_Reward/rew_altitude_hold2: 0.0968
#            Episode_Reward/rew_vel2: 0.0082
#            Episode_Reward/rew_pos2: 0.0512
#     Episode_Reward/rew_action_rate: -0.0000
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 0.0000
#   Episode_Termination/bad_attitude: 1.0000
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 13107200
#                     Iteration time: 3.67s
#                       Time elapsed: 00:01:32
#                                ETA: 01:00:22
#
# ################################################################################
#                        Learning iteration 25/1001
#
#                        Computation: 145459 steps/s (collection: 3.378s, learning 0.226s)
#              Mean action noise std: 0.07
#           Mean value_function loss: 0.1030
#                Mean surrogate loss: 0.0200
#                  Mean entropy loss: -5.1803
#                        Mean reward: 8.76
#                Mean episode length: 37.42
# Episode_Reward/rew_attitude_stability2: 0.1123
# Episode_Reward/rew_ang_vel_stability4: 0.0701
#  Episode_Reward/rew_altitude_hold2: 0.0974
#            Episode_Reward/rew_vel2: 0.0082
#            Episode_Reward/rew_pos2: 0.0517
#     Episode_Reward/rew_action_rate: -0.0000
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 0.0000
#   Episode_Termination/bad_attitude: 1.0000
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 13631488
#                     Iteration time: 3.60s
#                       Time elapsed: 00:01:36
#                                ETA: 01:00:14
#
# ################################################################################
#                        Learning iteration 26/1001
#
#                        Computation: 143353 steps/s (collection: 3.433s, learning 0.224s)
#              Mean action noise std: 0.07
#           Mean value_function loss: 0.1584
#                Mean surrogate loss: 0.0204
#                  Mean entropy loss: -5.1435
#                        Mean reward: 8.88
#                Mean episode length: 38.53
# Episode_Reward/rew_attitude_stability2: 0.1145
# Episode_Reward/rew_ang_vel_stability4: 0.0732
#  Episode_Reward/rew_altitude_hold2: 0.0988
#            Episode_Reward/rew_vel2: 0.0082
#            Episode_Reward/rew_pos2: 0.0527
#     Episode_Reward/rew_action_rate: -0.0000
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 0.0000
#   Episode_Termination/bad_attitude: 1.0000
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 14155776
#                     Iteration time: 3.66s
#                       Time elapsed: 00:01:39
#                                ETA: 01:00:09
#
# ################################################################################
#                        Learning iteration 27/1001
#
#                        Computation: 140848 steps/s (collection: 3.498s, learning 0.225s)
#              Mean action noise std: 0.07
#           Mean value_function loss: 0.0976
#                Mean surrogate loss: 0.0205
#                  Mean entropy loss: -5.0961
#                        Mean reward: 8.37
#                Mean episode length: 36.98
# Episode_Reward/rew_attitude_stability2: 0.1174
# Episode_Reward/rew_ang_vel_stability4: 0.0750
#  Episode_Reward/rew_altitude_hold2: 0.0997
#            Episode_Reward/rew_vel2: 0.0083
#            Episode_Reward/rew_pos2: 0.0533
#     Episode_Reward/rew_action_rate: -0.0000
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 0.0000
#   Episode_Termination/bad_attitude: 1.0000
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 14680064
#                     Iteration time: 3.72s
#                       Time elapsed: 00:01:43
#                                ETA: 01:00:06
#
# ################################################################################
#                        Learning iteration 28/1001
#
#                        Computation: 141935 steps/s (collection: 3.468s, learning 0.226s)
#              Mean action noise std: 0.07
#           Mean value_function loss: 0.0956
#                Mean surrogate loss: 0.0091
#                  Mean entropy loss: -5.0496
#                        Mean reward: 8.74
#                Mean episode length: 38.92
# Episode_Reward/rew_attitude_stability2: 0.1188
# Episode_Reward/rew_ang_vel_stability4: 0.0764
#  Episode_Reward/rew_altitude_hold2: 0.1001
#            Episode_Reward/rew_vel2: 0.0082
#            Episode_Reward/rew_pos2: 0.0536
#     Episode_Reward/rew_action_rate: -0.0000
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 0.0000
#   Episode_Termination/bad_attitude: 1.0000
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 15204352
#                     Iteration time: 3.69s
#                       Time elapsed: 00:01:47
#                                ETA: 01:00:02
#
# ################################################################################
#                        Learning iteration 29/1001
#
#                        Computation: 144856 steps/s (collection: 3.390s, learning 0.229s)
#              Mean action noise std: 0.07
#           Mean value_function loss: 0.0900
#                Mean surrogate loss: 0.0104
#                  Mean entropy loss: -5.0095
#                        Mean reward: 9.11
#                Mean episode length: 39.08
# Episode_Reward/rew_attitude_stability2: 0.1196
# Episode_Reward/rew_ang_vel_stability4: 0.0768
#  Episode_Reward/rew_altitude_hold2: 0.1007
#            Episode_Reward/rew_vel2: 0.0083
#            Episode_Reward/rew_pos2: 0.0538
#     Episode_Reward/rew_action_rate: -0.0000
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 0.0000
#   Episode_Termination/bad_attitude: 1.0000
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 15728640
#                     Iteration time: 3.62s
#                       Time elapsed: 00:01:50
#                                ETA: 00:59:55
#
# ################################################################################
#                        Learning iteration 30/1001
#
#                        Computation: 141877 steps/s (collection: 3.470s, learning 0.226s)
#              Mean action noise std: 0.07
#           Mean value_function loss: 0.1090
#                Mean surrogate loss: 0.0079
#                  Mean entropy loss: -4.9813
#                        Mean reward: 9.13
#                Mean episode length: 39.91
# Episode_Reward/rew_attitude_stability2: 0.1216
# Episode_Reward/rew_ang_vel_stability4: 0.0794
#  Episode_Reward/rew_altitude_hold2: 0.1012
#            Episode_Reward/rew_vel2: 0.0082
#            Episode_Reward/rew_pos2: 0.0545
#     Episode_Reward/rew_action_rate: -0.0000
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 0.0000
#   Episode_Termination/bad_attitude: 1.0000
# Episode_Termination/safety_shutdown: 0.0000
# ...
# --------------------------------------------------------------------------------
#                    Total timesteps: 517996544
#                     Iteration time: 3.63s
#                       Time elapsed: 00:56:36
#                                ETA: 00:00:48
#
# ################################################################################
#                       Learning iteration 988/1001
#
#                        Computation: 147153 steps/s (collection: 3.344s, learning 0.219s)
#              Mean action noise std: 0.98
#           Mean value_function loss: 0.0313
#                Mean surrogate loss: 0.0008
#                  Mean entropy loss: 5.5637
#                        Mean reward: 453.08
#                Mean episode length: 1250.00
# Episode_Reward/rew_attitude_stability2: 7.9439
# Episode_Reward/rew_ang_vel_stability4: 3.8926
#  Episode_Reward/rew_altitude_hold2: 3.9900
#            Episode_Reward/rew_vel2: 1.4380
#            Episode_Reward/rew_pos2: 1.1181
#     Episode_Reward/rew_action_rate: -0.3027
#       Episode_Termination/time_out: 1.0000
# Episode_Termination/below_min_altitude: 0.0000
#   Episode_Termination/bad_attitude: 0.0000
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 518520832
#                     Iteration time: 3.56s
#                       Time elapsed: 00:56:39
#                                ETA: 00:00:44
#
# ################################################################################
#                       Learning iteration 989/1001
#
#                        Computation: 145856 steps/s (collection: 3.378s, learning 0.217s)
#              Mean action noise std: 0.98
#           Mean value_function loss: 0.0348
#                Mean surrogate loss: 0.0016
#                  Mean entropy loss: 5.5763
#                        Mean reward: 451.08
#                Mean episode length: 1250.00
# Episode_Reward/rew_attitude_stability2: 7.9412
# Episode_Reward/rew_ang_vel_stability4: 3.8908
#  Episode_Reward/rew_altitude_hold2: 3.9898
#            Episode_Reward/rew_vel2: 1.4358
#            Episode_Reward/rew_pos2: 1.1168
#     Episode_Reward/rew_action_rate: -0.3040
#       Episode_Termination/time_out: 1.0000
# Episode_Termination/below_min_altitude: 0.0000
#   Episode_Termination/bad_attitude: 0.0000
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 519045120
#                     Iteration time: 3.59s
#                       Time elapsed: 00:56:43
#                                ETA: 00:00:41
#
# ################################################################################
#                       Learning iteration 990/1001
#
#                        Computation: 142644 steps/s (collection: 3.456s, learning 0.219s)
#              Mean action noise std: 0.99
#           Mean value_function loss: 0.0386
#                Mean surrogate loss: -0.0001
#                  Mean entropy loss: 5.5933
#                        Mean reward: 451.30
#                Mean episode length: 1250.00
# Episode_Reward/rew_attitude_stability2: 7.9447
# Episode_Reward/rew_ang_vel_stability4: 3.8927
#  Episode_Reward/rew_altitude_hold2: 3.9909
#            Episode_Reward/rew_vel2: 1.4374
#            Episode_Reward/rew_pos2: 1.1065
#     Episode_Reward/rew_action_rate: -0.3055
#       Episode_Termination/time_out: 1.0000
# Episode_Termination/below_min_altitude: 0.0000
#   Episode_Termination/bad_attitude: 0.0000
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 519569408
#                     Iteration time: 3.68s
#                       Time elapsed: 00:56:47
#                                ETA: 00:00:37
#
# ################################################################################
#                       Learning iteration 991/1001
#
#                        Computation: 141757 steps/s (collection: 3.480s, learning 0.219s)
#              Mean action noise std: 0.99
#           Mean value_function loss: 0.0367
#                Mean surrogate loss: 0.0008
#                  Mean entropy loss: 5.6050
#                        Mean reward: 452.73
#                Mean episode length: 1250.00
# Episode_Reward/rew_attitude_stability2: 7.9405
# Episode_Reward/rew_ang_vel_stability4: 3.8896
#  Episode_Reward/rew_altitude_hold2: 3.9906
#            Episode_Reward/rew_vel2: 1.4367
#            Episode_Reward/rew_pos2: 1.1030
#     Episode_Reward/rew_action_rate: -0.3080
#       Episode_Termination/time_out: 1.0000
# Episode_Termination/below_min_altitude: 0.0000
#   Episode_Termination/bad_attitude: 0.0000
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 520093696
#                     Iteration time: 3.70s
#                       Time elapsed: 00:56:50
#                                ETA: 00:00:34
#
# ################################################################################
#                       Learning iteration 992/1001
#
#                        Computation: 146718 steps/s (collection: 3.357s, learning 0.217s)
#              Mean action noise std: 0.99
#           Mean value_function loss: 0.0430
#                Mean surrogate loss: 0.0009
#                  Mean entropy loss: 5.6164
#                        Mean reward: 449.61
#                Mean episode length: 1250.00
# Episode_Reward/rew_attitude_stability2: 7.9404
# Episode_Reward/rew_ang_vel_stability4: 3.8900
#  Episode_Reward/rew_altitude_hold2: 3.9904
#            Episode_Reward/rew_vel2: 1.4338
#            Episode_Reward/rew_pos2: 1.0338
#     Episode_Reward/rew_action_rate: -0.3083
#       Episode_Termination/time_out: 1.0000
# Episode_Termination/below_min_altitude: 0.0000
#   Episode_Termination/bad_attitude: 0.0000
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 520617984
#                     Iteration time: 3.57s
#                       Time elapsed: 00:56:54
#                                ETA: 00:00:30
#
# ################################################################################
#                       Learning iteration 993/1001
#
#                        Computation: 145842 steps/s (collection: 3.377s, learning 0.218s)
#              Mean action noise std: 1.00
#           Mean value_function loss: 0.0439
#                Mean surrogate loss: 0.0004
#                  Mean entropy loss: 5.6279
#                        Mean reward: 450.02
#                Mean episode length: 1250.00
# Episode_Reward/rew_attitude_stability2: 7.9415
# Episode_Reward/rew_ang_vel_stability4: 3.8899
#  Episode_Reward/rew_altitude_hold2: 3.9907
#            Episode_Reward/rew_vel2: 1.4358
#            Episode_Reward/rew_pos2: 1.0966
#     Episode_Reward/rew_action_rate: -0.3102
#       Episode_Termination/time_out: 1.0000
# Episode_Termination/below_min_altitude: 0.0000
#   Episode_Termination/bad_attitude: 0.0000
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 521142272
#                     Iteration time: 3.59s
#                       Time elapsed: 00:56:58
#                                ETA: 00:00:27
#
# ################################################################################
#                       Learning iteration 994/1001
#
#                        Computation: 146391 steps/s (collection: 3.362s, learning 0.220s)
#              Mean action noise std: 1.00
#           Mean value_function loss: 0.0388
#                Mean surrogate loss: 0.0005
#                  Mean entropy loss: 5.6437
#                        Mean reward: 450.38
#                Mean episode length: 1250.00
# Episode_Reward/rew_attitude_stability2: 7.9446
# Episode_Reward/rew_ang_vel_stability4: 3.8902
#  Episode_Reward/rew_altitude_hold2: 3.9898
#            Episode_Reward/rew_vel2: 1.4366
#            Episode_Reward/rew_pos2: 1.0868
#     Episode_Reward/rew_action_rate: -0.3114
#       Episode_Termination/time_out: 1.0000
# Episode_Termination/below_min_altitude: 0.0000
#   Episode_Termination/bad_attitude: 0.0000
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 521666560
#                     Iteration time: 3.58s
#                       Time elapsed: 00:57:01
#                                ETA: 00:00:24
#
# ################################################################################
#                       Learning iteration 995/1001
#
#                        Computation: 142507 steps/s (collection: 3.459s, learning 0.220s)
#              Mean action noise std: 1.00
#           Mean value_function loss: 0.0409
#                Mean surrogate loss: 0.0001
#                  Mean entropy loss: 5.6511
#                        Mean reward: 453.38
#                Mean episode length: 1250.00
# Episode_Reward/rew_attitude_stability2: 7.9432
# Episode_Reward/rew_ang_vel_stability4: 3.8903
#  Episode_Reward/rew_altitude_hold2: 3.9893
#            Episode_Reward/rew_vel2: 1.4345
#            Episode_Reward/rew_pos2: 1.0953
#     Episode_Reward/rew_action_rate: -0.3128
#       Episode_Termination/time_out: 1.0000
# Episode_Termination/below_min_altitude: 0.0000
#   Episode_Termination/bad_attitude: 0.0000
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 522190848
#                     Iteration time: 3.68s
#                       Time elapsed: 00:57:05
#                                ETA: 00:00:20
#
# ################################################################################
#                       Learning iteration 996/1001
#
#                        Computation: 145232 steps/s (collection: 3.392s, learning 0.218s)
#              Mean action noise std: 1.00
#           Mean value_function loss: 0.0375
#                Mean surrogate loss: 0.0004
#                  Mean entropy loss: 5.6596
#                        Mean reward: 449.12
#                Mean episode length: 1250.00
# Episode_Reward/rew_attitude_stability2: 7.9443
# Episode_Reward/rew_ang_vel_stability4: 3.8912
#  Episode_Reward/rew_altitude_hold2: 3.9889
#            Episode_Reward/rew_vel2: 1.4370
#            Episode_Reward/rew_pos2: 1.0939
#     Episode_Reward/rew_action_rate: -0.3140
#       Episode_Termination/time_out: 1.0000
# Episode_Termination/below_min_altitude: 0.0000
#   Episode_Termination/bad_attitude: 0.0000
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 522715136
#                     Iteration time: 3.61s
#                       Time elapsed: 00:57:08
#                                ETA: 00:00:17
#
# ################################################################################
#                       Learning iteration 997/1001
#
#                        Computation: 146612 steps/s (collection: 3.356s, learning 0.220s)
#              Mean action noise std: 1.00
#           Mean value_function loss: 0.0355
#                Mean surrogate loss: 0.0002
#                  Mean entropy loss: 5.6671
#                        Mean reward: 451.22
#                Mean episode length: 1250.00
# Episode_Reward/rew_attitude_stability2: 7.9431
# Episode_Reward/rew_ang_vel_stability4: 3.8899
#  Episode_Reward/rew_altitude_hold2: 3.9887
#            Episode_Reward/rew_vel2: 1.4354
#            Episode_Reward/rew_pos2: 1.0785
#     Episode_Reward/rew_action_rate: -0.3152
#       Episode_Termination/time_out: 1.0000
# Episode_Termination/below_min_altitude: 0.0000
#   Episode_Termination/bad_attitude: 0.0000
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 523239424
#                     Iteration time: 3.58s
#                       Time elapsed: 00:57:12
#                                ETA: 00:00:13
#
# ################################################################################
#                       Learning iteration 998/1001
#
#                        Computation: 142179 steps/s (collection: 3.467s, learning 0.221s)
#              Mean action noise std: 1.00
#           Mean value_function loss: 0.0301
#                Mean surrogate loss: 0.0003
#                  Mean entropy loss: 5.6666
#                        Mean reward: 451.38
#                Mean episode length: 1250.00
# Episode_Reward/rew_attitude_stability2: 7.9416
# Episode_Reward/rew_ang_vel_stability4: 3.8876
#  Episode_Reward/rew_altitude_hold2: 3.9896
#            Episode_Reward/rew_vel2: 1.4360
#            Episode_Reward/rew_pos2: 1.1547
#     Episode_Reward/rew_action_rate: -0.3174
#       Episode_Termination/time_out: 1.0000
# Episode_Termination/below_min_altitude: 0.0000
#   Episode_Termination/bad_attitude: 0.0000
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 523763712
#                     Iteration time: 3.69s
#                       Time elapsed: 00:57:16
#                                ETA: 00:00:10
#
# ################################################################################
#                       Learning iteration 999/1001
#
#                        Computation: 143170 steps/s (collection: 3.444s, learning 0.218s)
#              Mean action noise std: 1.00
#           Mean value_function loss: 0.0289
#                Mean surrogate loss: 0.0001
#                  Mean entropy loss: 5.6654
#                        Mean reward: 452.36
#                Mean episode length: 1250.00
# Episode_Reward/rew_attitude_stability2: 7.9428
# Episode_Reward/rew_ang_vel_stability4: 3.8889
#  Episode_Reward/rew_altitude_hold2: 3.9890
#            Episode_Reward/rew_vel2: 1.4390
#            Episode_Reward/rew_pos2: 1.1538
#     Episode_Reward/rew_action_rate: -0.3182
#       Episode_Termination/time_out: 1.0000
# Episode_Termination/below_min_altitude: 0.0000
#   Episode_Termination/bad_attitude: 0.0000
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 524288000
#                     Iteration time: 3.66s
#                       Time elapsed: 00:57:19
#                                ETA: 00:00:06
#
# ################################################################################
#                       Learning iteration 1000/1001
#
#                        Computation: 145290 steps/s (collection: 3.388s, learning 0.221s)
#              Mean action noise std: 1.00
#           Mean value_function loss: 0.0313
#                Mean surrogate loss: -0.0000
#                  Mean entropy loss: 5.6659
#                        Mean reward: 452.22
#                Mean episode length: 1250.00
# Episode_Reward/rew_attitude_stability2: 7.9416
# Episode_Reward/rew_ang_vel_stability4: 3.8887
#  Episode_Reward/rew_altitude_hold2: 3.9889
#            Episode_Reward/rew_vel2: 1.4369
#            Episode_Reward/rew_pos2: 1.1262
#     Episode_Reward/rew_action_rate: -0.3195
#       Episode_Termination/time_out: 1.0000
# Episode_Termination/below_min_altitude: 0.0000
#   Episode_Termination/bad_attitude: 0.0000
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 524812288
#                     Iteration time: 3.61s
#                       Time elapsed: 00:57:23
#                                ETA: 00:00:03
#
#
# --- Todos los experimentos han finalizado ---

# %% [markdown]
# ``Análisis de los datos``

# %%
import csv
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

seed = 42
n=5

df_results_grid_actions = pd.read_csv(path_resultados+"/resultados_grid_PPO.csv")

# %%
def get_group(value):
    if f"_{experiment_name}" in value:
        return task_name

df_results_grid_actions["tarea"] = df_results_grid_actions["id_run_name"].apply(get_group)

# %%
df_copy = df_results_grid_actions.copy()
df_results_grid_actions.sample(n, random_state=seed)
# Out:
#                id_run_name  iteration      reward  max_reward  std_reward  \
# 5   ppo_random_command8_11        500  442.176385  468.004181   14.177326
# 0   ppo_random_command8_11          0    7.546473   10.491874    1.592094
# 9   ppo_random_command8_11        900  453.254882  475.293762   15.521060
# 10  ppo_random_command8_11       1000  452.223993  474.235626   15.316825
# 2   ppo_random_command8_11        200  213.990863  393.506012  116.878920
#
#     num_envs_train  mean_Episode_Reward/rew_attitude_stability2  \
# 5             4096                                     7.932228
# 0             4096                                     0.097475
# 9             4096                                     7.943559
# 10            4096                                     7.941596
# 2             4096                                     4.494939
#
#     mean_Episode_Reward/rew_ang_vel_stability4  \
# 5                                     3.858061
# 0                                     0.064262
# 9                                     3.890726
# 10                                    3.888707
# 2                                     1.875427
#
#     mean_Episode_Reward/rew_altitude_hold2  mean_Episode_Reward/rew_vel2  \
# 5                                 3.981893                      1.396996
# 0                                 0.083001                      0.007283
# 9                                 3.989754                      1.440906
# 10                                3.988876                      1.436890
# 2                                 1.056642                      0.303413
#
#     mean_Episode_Reward/rew_pos2  mean_Episode_Reward/rew_action_rate  \
# 5                       0.809633                            -0.383999
# 0                       0.044600                            -0.000022
# 9                       1.183038                            -0.307499
# 10                      1.126180                            -0.319542
# 2                       0.150522                            -0.008735
#
#     mean_Episode_Termination/time_out  \
# 5                            1.000000
# 0                            0.008947
# 9                            1.000000
# 10                           1.000000
# 2                            0.150900
#
#     mean_Episode_Termination/below_min_altitude  \
# 5                                      0.000000
# 0                                      0.000051
# 9                                      0.000000
# 10                                     0.000000
# 2                                      0.573511
#
#     mean_Episode_Termination/bad_attitude  \
# 5                                0.000000
# 0                                0.637028
# 9                                0.000000
# 10                               0.000000
# 2                                0.275589
#
#     mean_Episode_Termination/safety_shutdown     tarea
# 5                                        0.0  Command8
# 0                                        0.0  Command8
# 9                                        0.0  Command8
# 10                                       0.0  Command8
# 2                                        0.0  Command8

# %%
df_results_grid_actions.set_index(['tarea','id_run_name'],inplace=True)
top5 = (
    df_results_grid_actions.groupby(level="tarea")
      .apply(lambda g: g.sort_values("reward", ascending=False).head(5))
)

# Eliminar el nivel adicional que introduce groupby+apply
top5.index = top5.index.droplevel(0)

top5
# Out:
#                                  iteration      reward  max_reward  \
# tarea    id_run_name
# Command8 ppo_random_command8_11        800  454.716994  474.439636
#          ppo_random_command8_11        900  453.254882  475.293762
#          ppo_random_command8_11       1000  452.223993  474.235626
#          ppo_random_command8_11        600  447.536796  468.856812
#          ppo_random_command8_11        700  446.377137  472.778961
#
#                                  std_reward  num_envs_train  \
# tarea    id_run_name
# Command8 ppo_random_command8_11   14.022881            4096
#          ppo_random_command8_11   15.521060            4096
#          ppo_random_command8_11   15.316825            4096
#          ppo_random_command8_11   14.684716            4096
#          ppo_random_command8_11   14.013052            4096
#
#                                  mean_Episode_Reward/rew_attitude_stability2  \
# tarea    id_run_name
# Command8 ppo_random_command8_11                                     7.945653
#          ppo_random_command8_11                                     7.943559
#          ppo_random_command8_11                                     7.941596
#          ppo_random_command8_11                                     7.941475
#          ppo_random_command8_11                                     7.940984
#
#                                  mean_Episode_Reward/rew_ang_vel_stability4  \
# tarea    id_run_name
# Command8 ppo_random_command8_11                                    3.887332
#          ppo_random_command8_11                                    3.890726
#          ppo_random_command8_11                                    3.888707
#          ppo_random_command8_11                                    3.872237
#          ppo_random_command8_11                                    3.873990
#
#                                  mean_Episode_Reward/rew_altitude_hold2  \
# tarea    id_run_name
# Command8 ppo_random_command8_11                                3.987130
#          ppo_random_command8_11                                3.989754
#          ppo_random_command8_11                                3.988876
#          ppo_random_command8_11                                3.983699
#          ppo_random_command8_11                                3.987027
#
#                                  mean_Episode_Reward/rew_vel2  \
# tarea    id_run_name
# Command8 ppo_random_command8_11                      1.441887
#          ppo_random_command8_11                      1.440906
#          ppo_random_command8_11                      1.436890
#          ppo_random_command8_11                      1.428633
#          ppo_random_command8_11                      1.430613
#
#                                  mean_Episode_Reward/rew_pos2  \
# tarea    id_run_name
# Command8 ppo_random_command8_11                      1.213853
#          ppo_random_command8_11                      1.183038
#          ppo_random_command8_11                      1.126180
#          ppo_random_command8_11                      1.041035
#          ppo_random_command8_11                      1.002056
#
#                                  mean_Episode_Reward/rew_action_rate  \
# tarea    id_run_name
# Command8 ppo_random_command8_11                            -0.334044
#          ppo_random_command8_11                            -0.307499
#          ppo_random_command8_11                            -0.319542
#          ppo_random_command8_11                            -0.432777
#          ppo_random_command8_11                            -0.390166
#
#                                  mean_Episode_Termination/time_out  \
# tarea    id_run_name
# Command8 ppo_random_command8_11                                1.0
#          ppo_random_command8_11                                1.0
#          ppo_random_command8_11                                1.0
#          ppo_random_command8_11                                1.0
#          ppo_random_command8_11                                1.0
#
#                                  mean_Episode_Termination/below_min_altitude  \
# tarea    id_run_name
# Command8 ppo_random_command8_11                                          0.0
#          ppo_random_command8_11                                          0.0
#          ppo_random_command8_11                                          0.0
#          ppo_random_command8_11                                          0.0
#          ppo_random_command8_11                                          0.0
#
#                                  mean_Episode_Termination/bad_attitude  \
# tarea    id_run_name
# Command8 ppo_random_command8_11                                    0.0
#          ppo_random_command8_11                                    0.0
#          ppo_random_command8_11                                    0.0
#          ppo_random_command8_11                                    0.0
#          ppo_random_command8_11                                    0.0
#
#                                  mean_Episode_Termination/safety_shutdown
# tarea    id_run_name
# Command8 ppo_random_command8_11                                       0.0
#          ppo_random_command8_11                                       0.0
#          ppo_random_command8_11                                       0.0
#          ppo_random_command8_11                                       0.0
#          ppo_random_command8_11                                       0.0

# %%
mean_rewards = df_results_grid_actions.groupby(["tarea", "id_run_name"])["reward"].mean()

for tarea, subdf in mean_rewards.groupby(level="tarea"):
    plt.figure(figsize=(12,5))
    
    # Convertir a DataFrame y resetear index para graficar
    plot_df = subdf.reset_index()
    plot_df = plot_df.sort_values("reward", ascending=False)
    
    plt.bar(plot_df["id_run_name"], plot_df["reward"])
    plt.title(f"Reward media por modelo - {tarea}")
    plt.xlabel("id_run_name")
    plt.ylabel("Reward media")
    plt.xticks(rotation=90)
    plt.tight_layout()
    plt.show()

# %%
df_callbacks = pd.read_csv(path_resultados+"/reward_best_models.csv",index_col='id_run_name')
top5_models = df_callbacks.nlargest(5,columns="reward")
top5_models
# Out:
#                         iteration      reward  max_reward  std_reward  \
# id_run_name
# ppo_random_command8_11        972  457.818982  475.656281    13.75502
#
#                         num_envs_train  \
# id_run_name
# ppo_random_command8_11            4096
#
#                         mean_Episode_Reward/rew_attitude_stability2  \
# id_run_name
# ppo_random_command8_11                                     7.946087
#
#                         mean_Episode_Reward/rew_ang_vel_stability4  \
# id_run_name
# ppo_random_command8_11                                    3.889507
#
#                         mean_Episode_Reward/rew_altitude_hold2  \
# id_run_name
# ppo_random_command8_11                                3.988845
#
#                         mean_Episode_Reward/rew_vel2  \
# id_run_name
# ppo_random_command8_11                      1.445463
#
#                         mean_Episode_Reward/rew_pos2  \
# id_run_name
# ppo_random_command8_11                      1.272243
#
#                         mean_Episode_Reward/rew_action_rate  \
# id_run_name
# ppo_random_command8_11                            -0.301338
#
#                         mean_Episode_Termination/time_out  \
# id_run_name
# ppo_random_command8_11                                1.0
#
#                         mean_Episode_Termination/below_min_altitude  \
# id_run_name
# ppo_random_command8_11                                          0.0
#
#                         mean_Episode_Termination/bad_attitude  \
# id_run_name
# ppo_random_command8_11                                    0.0
#
#                         mean_Episode_Termination/safety_shutdown
# id_run_name
# ppo_random_command8_11                                       0.0

# %% [markdown]
# Graficamos cómo fue el entrenamiento para los 5 mejores modelos según los callbacks:

# %%
import matplotlib.pyplot as plt
import numpy as np

# Aseguramos que `top5_auc` tenga 'tarea' e 'id_run_name' como columnas, no solo en el índice
df_callbacks = pd.read_csv(path_resultados+"/reward_best_models.csv",index_col='id_run_name')
top5_models = df_callbacks.nlargest(5,columns="reward")
top5_reset = top5_models.reset_index()
top5_reset["tarea"] = top5_reset["id_run_name"].apply(get_group)


# Convertir el índice jerárquico en columnas (para acceder a 'tarea' y 'id_run_name')
df_copy_reset = df_copy.reset_index()

# Unimos `top5_auc_reset` con `df_copy_reset` en las columnas comunes: 'tarea' y 'id_run_name'
merged_df = pd.merge(df_copy_reset, top5_reset[['tarea', 'id_run_name']], on=['tarea', 'id_run_name'], how='inner')

# Usamos una lista de colores para asignar un color diferente a cada modelo
colors = plt.cm.viridis(np.linspace(0, 1, len(merged_df['id_run_name'].unique())))

# Ahora, procedemos a graficar
for tarea, task_df in merged_df.groupby('tarea'):
    plt.figure(figsize=(10, 6))
    
    # Iteramos sobre los modelos (id_run_name) para esta tarea
    for i, (run_name, subdf) in enumerate(task_df.groupby('id_run_name')):
        # Graficamos la evolución de la recompensa a lo largo de las iteraciones
        plt.plot(subdf['iteration'], subdf['reward'], label=run_name, color=colors[i])
    
    plt.xlabel('Iteración')
    plt.ylabel('Reward')
    plt.title(f'Evolución de la Recompensa - Tarea: {tarea}')
    plt.legend(title="Modelos", bbox_to_anchor=(1.05, 1), loc='upper left')
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ``Cojo los 5 modelos mejores de todos de los callbacks``

# %%
import os
df_callbacks = pd.read_csv(path_resultados+"/reward_best_models.csv",index_col='id_run_name')
top5_models = df_callbacks.nlargest(5,columns="reward")

powershell_script_test = os.path.join(cfg_dir, "run_tests.ps1")

with open(powershell_script_test, "w") as f:
    f.write("$ErrorActionPreference = 'Stop'\n\n")
    
    for run_id, row in top5_models.iterrows():
        # Extraemos el número del id (ej: de 'ppo_random_hover_4' sacamos '4')
        experiment_number = run_id.split('_')[-1]
        
        # Construimos la ruta exacta del checkpoint
        # Nota: Asegúrate de que path_resultados termine en / o usar os.path.join
        checkpoint_path = f"{path_resultados}/best_model_{run_id}_{int(row['num_envs_train'])}.pt"
        f.write(f'Write-Host "Ejecutando Test final para Experimento {experiment_number}..."\n')
        
        # Usamos el experiment_number extraído para la tarea (--task)
        # Se añaden flags típicos de play.py: --num_envs 1 y se quita --headless para ver el visualizador
        f.write(f'& "{isaaclab_bat}" -p "{play_script}" '
                f'--task {id_task}-{experiment_number} '
                f'--num_envs 1 '
                f' --headless '
                f'--checkpoint "{checkpoint_path}"\n\n')
        
print(f"Script de test generado en: {powershell_script_test}")
# Out:
# Script de test generado en: C:/Users/Teresa/Documents/GitHub/navsim/isaac_lab/aerotaxi/env_command/env_12/grid_hiperparametros/cfg_files\run_tests.ps1

# %% [markdown]
# ### Test con 1 entorno

# %%
# Ejecuta el entrenamiento de forma automática
# !powershell -ExecutionPolicy Bypass -File "{powershell_script}"
import subprocess
import sys

# Ruta al script que generaste
powershell_script_path = powershell_script_test 

print(f"Iniciando ejecución de: {powershell_script_path}\n")

# Ejecutamos el proceso capturando la salida en tiempo real
process = subprocess.Popen(
    ["powershell.exe", "-ExecutionPolicy", "Bypass", "-File", powershell_script_path],
    stdout=subprocess.PIPE,
    stderr=subprocess.STDOUT, # Redirigimos errores a la salida estándar para verlos
    text=True,
    bufsize=1
)

# Leemos la salida línea a línea conforme se genera
try:
    for line in process.stdout:
        print(line, end="") # Imprime la salida de PowerShell en la celda
        sys.stdout.flush()   # Fuerza a Jupyter a mostrar la línea inmediatamente
except KeyboardInterrupt:
    process.kill()
    print("\nEntrenamiento cancelado por el usuario.")

process.wait()
print("\n--- Todos los experimentos de test han finalizado ---")
# Out:
# Iniciando ejecución de: C:/Users/Teresa/Documents/GitHub/navsim/isaac_lab/aerotaxi/env_command/env_12/grid_hiperparametros/cfg_files\run_tests.ps1
#
# Ejecutando Test final para Experimento 11...
# [INFO] Using python from: C:\Users\Teresa\miniconda3\envs\env_isaaclab\python.exe
# [INFO][AppLauncher]: Using device: cuda:0
# [INFO][AppLauncher]: Loading experience file: C:\Users\Teresa\miniconda3\envs\env_isaaclab\Lib\site-packages\isaaclab\apps\isaaclab.python.headless.kit
# Loading user config located at: 'c:/users/teresa/miniconda3/envs/env_isaaclab/lib/site-packages/isaacsim/kit/data/Kit/Isaac-Sim/5.1/user.config.json'
# [Info] [carb] Logging to file: c:/users/teresa/miniconda3/envs/env_isaaclab/lib/site-packages/isaacsim/kit/logs/Kit/Isaac-Sim/5.1/kit_20260303_145406.log
# 2026-03-03T13:54:06Z s] [Warning] [omni.usd_config.extension] Enable omni.materialx.libs extension to use MaterialX
# 2026-03-03T13:54:07Z s] [Warning] [carb] Acquiring non optional plugin interface which is not listed as dependency: [omni::physx::IPhysxBenchmarks v1.0] (plugin: <default plugin>), by client: omni.physics.physx.plugin. Add it to CARB_PLUGIN_IMPL_DEPS() macro of a client.
# 2026-03-03T13:54:07Z s] [Warning] [omni.isaac.dynamic_control] omni.isaac.dynamic_control is deprecated as of Isaac Sim 4.5. No action is needed from end-users.
# 2026-03-03T13:54:08Z [2,461ms] [Warning] [gpu.foundation.plugin] Skipping unsupported non-NVIDIA GPU: AMD Radeon(TM) Graphics
# 2026-03-03T13:54:08Z [2,462ms] [Warning] [gpu.foundation.plugin] Skipping unsupported non-NVIDIA GPU: AMD Radeon(TM) Graphics
#
# |---------------------------------------------------------------------------------------------|
# | Driver Version: 581.29        | Graphics API: D3D12
# |=============================================================================================|
# | GPU | Name                             | Active | LDA | GPU Memory | Vendor-ID | LUID       |
# |     |                                  |        |     |            | Device-ID | UUID       |
# |     |                                  |        |     |            | Bus-ID    |            |
# |---------------------------------------------------------------------------------------------|
# | 0   | NVIDIA GeForce RTX 5080          | Yes: 0 |     | 15889   MB | 10de      | 295a0100.. |
# |     |                                  |        |     |            | 2c02      | 0          |
# |     |                                  |        |     |            | 1         |            |
# |---------------------------------------------------------------------------------------------|
# | 1   | AMD Radeon(TM) Graphics          |        |     | 1995    MB | 1002      | 876d0100.. |
# |     |                                  |        |     |            | 13c0      | 0          |
# |     |                                  |        |     |            | N/A       |            |
# |=============================================================================================|
# | OS: Windows 11 Pro, Version: 10.0 (25H2), Build: 26200, Kernel: 10.0.26100.7824
# | Processor: AMD Ryzen 9 9950X 16-Core Processor
# | Cores: 16 | Logical Cores: 32
# |---------------------------------------------------------------------------------------------|
# | Total Memory (MB): 128627 | Free Memory: 101002
# | Total Page/Swap (MB): 136819 | Free Page/Swap: 102327
# |---------------------------------------------------------------------------------------------|
# C:\Users\Teresa\Documents\GitHub\navsim\isaac_lab\aerotaxi\env_command\env_12\flight_plan.py:29: UserWarning: Treat the new Tool classes introduced in v1.5 as experimental for now; the API and rcParam may change in future versions.
#   plt.rcParams["toolbar"] = "toolmanager"
# [INFO]: Parsing configuration from: aerotaxi.env_command.env_12.env:UAVEnvCfg
# [INFO]: Parsing configuration from: aerotaxi.env_command.env_12.grid_hiperparametros.cfg_files.ppo_random_command8_11_cfg:Command8PPORunnerCfg
# [INFO] Loading experiment from directory: C:\Users\Teresa\Documents\GitHub\navsim\isaac_lab\aerotaxi\env_command\env_12\logs\rsl_rl\command8
# Setting seed: 42
# [INFO]: Base environment:
# 	Environment device    : cuda:0
# 	Environment seed      : 42
# 	Physics step-size     : 0.005
# 	Rendering step-size   : 0.02
# 	Environment step-size : 0.02
# [INFO]: Time taken for scene creation : 0.995030 seconds
# [INFO]: Scene manager:  <class InteractiveScene>
# 	Number of environments: 1
# 	Environment spacing   : 200.0
# 	Source prim name      : /World/envs/env_0
# 	Global prim paths     : []
# 	Replicate physics     : False
# [INFO]: Starting the simulation. This may take a few seconds. Please wait...
# [INFO]: Time taken for simulation start : 0.237648 seconds
# [INFO] Command Manager:  <CommandManager> contains 1 active terms.
# +--------------------------------------+
# |         Active Command Terms         |
# +-------+-------------+----------------+
# | Index | Name        |      Type      |
# +-------+-------------+----------------+
# |   0   | vel_command | UAVcommandTerm |
# +-------+-------------+----------------+
#
# [INFO] Event Manager:  <EventManager> contains 1 active terms.
# +-----------------------------------+
# | Active Event Terms in Mode: 'reset' |
# +----------+------------------------+
# |  Index   | Name                   |
# +----------+------------------------+
# |    0     | reset_pos              |
# |    1     | randomize_mass         |
# |    2     | randomize_wind         |
# +----------+------------------------+
#
# [INFO] Recorder Manager:  <RecorderManager> contains 0 active terms.
# +---------------------+
# | Active Recorder Terms |
# +-----------+---------+
# |   Index   | Name    |
# +-----------+---------+
# +-----------+---------+
#
# [INFO] Action Manager:  <ActionManager> contains 1 active terms.
# +-----------------------------------+
# |   Active Action Terms (shape: 4)  |
# +--------+-------------+------------+
# | Index  | Name        |  Dimension |
# +--------+-------------+------------+
# |   0    | rotors_vel  |          4 |
# +--------+-------------+------------+
#
# [INFO] Observation Manager: <ObservationManager> contains 2 groups.
# +---------------------------------------------------------+
# | Active Observation Terms in Group: 'policy' (shape: (13,)) |
# +-----------+---------------------------------+-----------+
# |   Index   | Name                            |   Shape   |
# +-----------+---------------------------------+-----------+
# |     0     | dist                            |    (3,)   |
# |     1     | lin_vel                         |    (3,)   |
# |     2     | ang_vel                         |    (3,)   |
# |     3     | height                          |    (1,)   |
# |     4     | projected_gravity               |    (3,)   |
# +-----------+---------------------------------+-----------+
# +---------------------------------------------------------+
# | Active Observation Terms in Group: 'critic' (shape: (13,)) |
# +-----------+---------------------------------+-----------+
# |   Index   | Name                            |   Shape   |
# +-----------+---------------------------------+-----------+
# |     0     | dist                            |    (3,)   |
# |     1     | lin_vel                         |    (3,)   |
# |     2     | ang_vel                         |    (3,)   |
# |     3     | height                          |    (1,)   |
# |     4     | projected_gravity               |    (3,)   |
# +-----------+---------------------------------+-----------+
#
# [INFO] Termination Manager:  <TerminationManager> contains 4 active terms.
# +---------------------------------------+
# |        Active Termination Terms       |
# +-------+--------------------+----------+
# | Index | Name               | Time Out |
# +-------+--------------------+----------+
# |   0   | time_out           |   True   |
# |   1   | below_min_altitude |  False   |
# |   2   | bad_attitude       |  False   |
# |   3   | safety_shutdown    |  False   |
# +-------+--------------------+----------+
#
# [INFO] Reward Manager:  <RewardManager> contains 6 active terms.
# +------------------------------------------+
# |           Active Reward Terms            |
# +-------+-------------------------+--------+
# | Index | Name                    | Weight |
# +-------+-------------------------+--------+
# |   0   | rew_attitude_stability2 |    8.0 |
# |   1   | rew_ang_vel_stability4  |    4.0 |
# |   2   | rew_altitude_hold2      |    4.0 |
# |   3   | rew_vel2                |    1.5 |
# |   4   | rew_pos2                |    2.0 |
# |   5   | rew_action_rate         |    3.0 |
# +-------+-------------------------+--------+
#
# [INFO] Curriculum Manager:  <CurriculumManager> contains 0 active terms.
# +----------------------+
# | Active Curriculum Terms |
# +-----------+----------+
# |   Index   | Name     |
# +-----------+----------+
# +-----------+----------+
#
# [INFO]: Completed setting up the environment...
# 2026-03-03T13:54:11Z [5,339ms] [Warning] [omni.physx.fabric.plugin] FabricManager::initializePointInstancer mismatched prototypes on point instancer: /Visuals/target_commands.
# [INFO]: Loading model checkpoint from: C:\Users\Teresa\Documents\GitHub\navsim\tmp\tmpTeresa\resultados_grid_command_v8\best_model_ppo_random_command8_11_4096.pt
# C:\Users\Teresa\miniconda3\envs\env_isaaclab\Lib\site-packages\rsl_rl\utils\utils.py:244: UserWarning: The observation configuration dictionary 'obs_groups' must contain the 'policy' key. As an observation group with the name 'policy' was found, this is assumed to be the observation set. Consider adding the 'policy' key to the 'obs_groups' dictionary for clarity. This behavior will be removed in a future version.
#   warnings.warn(
# C:\Users\Teresa\miniconda3\envs\env_isaaclab\Lib\site-packages\rsl_rl\utils\utils.py:282: UserWarning: The observation configuration dictionary 'obs_groups' must contain the 'critic' key. As an observation group with the name 'critic' was found, this is assumed to be the observation set. Consider adding the 'critic' key to the 'obs_groups' dictionary for clarity. This behavior will be removed in a future version.
#   warnings.warn(
# --------------------------------------------------------------------------------
# Resolved observation sets:
# 	 policy :  ['policy']
# 	 critic :  ['critic']
# --------------------------------------------------------------------------------
# Actor MLP: MLP(
#   (0): Linear(in_features=13, out_features=128, bias=True)
#   (1): ELU(alpha=1.0)
#   (2): Linear(in_features=128, out_features=128, bias=True)
#   (3): ELU(alpha=1.0)
#   (4): Linear(in_features=128, out_features=128, bias=True)
#   (5): ELU(alpha=1.0)
#   (6): Linear(in_features=128, out_features=4, bias=True)
# )
# Critic MLP: MLP(
#   (0): Linear(in_features=13, out_features=256, bias=True)
#   (1): ELU(alpha=1.0)
#   (2): Linear(in_features=256, out_features=256, bias=True)
#   (3): ELU(alpha=1.0)
#   (4): Linear(in_features=256, out_features=256, bias=True)
#   (5): ELU(alpha=1.0)
#   (6): Linear(in_features=256, out_features=1, bias=True)
# )
#
# --- Todos los experimentos de test han finalizado ---

# %%
df_callbacks = pd.read_csv(path_resultados+"/reward_best_models.csv",index_col='id_run_name')
top5_models = df_callbacks.nlargest(5,columns="reward")

# %%
df_rewards_play = pd.read_csv(path_resultados+'/rewards_play_PPO.csv')

# %%
df_rewards_play
# Out:
#               id_run_name      reward  max_reward  std  num_envs_test  \
# 0  ppo_random_command8_11  372.686531  372.686531  0.0              1
#
#                                           checkpoint  \
# 0  C:/Users/Teresa/Documents/GitHub/navsim/tmp/tm...
#
#    mean_Episode_Reward/rew_attitude_stability2  \
# 0                                          0.0
#
#    mean_Episode_Reward/rew_ang_vel_stability4  \
# 0                                         0.0
#
#    mean_Episode_Reward/rew_altitude_hold2  mean_Episode_Reward/rew_vel2  \
# 0                                     0.0                           0.0
#
#    mean_Episode_Reward/rew_pos2  mean_Episode_Reward/rew_action_rate  \
# 0                           0.0                                  0.0
#
#    mean_Episode_Termination/time_out  \
# 0                                0.0
#
#    mean_Episode_Termination/below_min_altitude  \
# 0                                          0.0
#
#    mean_Episode_Termination/bad_attitude  \
# 0                                    0.0
#
#    mean_Episode_Termination/safety_shutdown
# 0                                       0.0

# %% [markdown]
# ### Test con 64 entornos

# %%
import os
df_callbacks = pd.read_csv(path_resultados+"/reward_best_models.csv",index_col='id_run_name')
top5_models = df_callbacks.nlargest(5,columns="reward")

powershell_script_test_2 = os.path.join(cfg_dir, "run_tests_2.ps1")

with open(powershell_script_test_2, "w") as f:
    f.write("$ErrorActionPreference = 'Stop'\n\n")
    
    for run_id, row in top5_models.iterrows():
        # Extraemos el número del id (ej: de 'ppo_random_hover_4' sacamos '4')
        experiment_number = run_id.split('_')[-1]
        
        # Construimos la ruta exacta del checkpoint
        # Nota: Asegúrate de que path_resultados termine en / o usar os.path.join
        checkpoint_path = f"{path_resultados}/best_model_{run_id}_{int(row['num_envs_train'])}.pt"
        f.write(f'Write-Host "Ejecutando Test final para Experimento {experiment_number}..."\n')
        
        # Usamos el experiment_number extraído para la tarea (--task)
        # Se añaden flags típicos de play.py: --num_envs 1 y se quita --headless para ver el visualizador
        f.write(f'& "{isaaclab_bat}" -p "{play_script}" '
                f'--task {id_task}-{experiment_number} '
                f'--num_envs 64 '
                f' --headless '
                f'--checkpoint "{checkpoint_path}"\n\n')
        
print(f"Script de test generado en: {powershell_script_test_2}")
# Out:
# Script de test generado en: C:/Users/Teresa/Documents/GitHub/navsim/isaac_lab/aerotaxi/env_command/env_12/grid_hiperparametros/cfg_files\run_tests_2.ps1

# %%
# Ejecuta el entrenamiento de forma automática
# !powershell -ExecutionPolicy Bypass -File "{powershell_script}"
import subprocess
import sys

# Ruta al script que generaste
powershell_script_path = powershell_script_test_2 

print(f"Iniciando ejecución de: {powershell_script_path}\n")

# Ejecutamos el proceso capturando la salida en tiempo real
process = subprocess.Popen(
    ["powershell.exe", "-ExecutionPolicy", "Bypass", "-File", powershell_script_path],
    stdout=subprocess.PIPE,
    stderr=subprocess.STDOUT, # Redirigimos errores a la salida estándar para verlos
    text=True,
    bufsize=1
)

# Leemos la salida línea a línea conforme se genera
try:
    for line in process.stdout:
        print(line, end="") # Imprime la salida de PowerShell en la celda
        sys.stdout.flush()   # Fuerza a Jupyter a mostrar la línea inmediatamente
except KeyboardInterrupt:
    process.kill()
    print("\nEntrenamiento cancelado por el usuario.")

process.wait()
print("\n--- Todos los experimentos de test han finalizado ---")
# Out:
# Iniciando ejecución de: C:/Users/Teresa/Documents/GitHub/navsim/isaac_lab/aerotaxi/env_command/env_12/grid_hiperparametros/cfg_files\run_tests_2.ps1
#
# Ejecutando Test final para Experimento 11...
# [INFO] Using python from: C:\Users\Teresa\miniconda3\envs\env_isaaclab\python.exe
# [INFO][AppLauncher]: Using device: cuda:0
# [INFO][AppLauncher]: Loading experience file: C:\Users\Teresa\miniconda3\envs\env_isaaclab\Lib\site-packages\isaaclab\apps\isaaclab.python.headless.kit
# Loading user config located at: 'c:/users/teresa/miniconda3/envs/env_isaaclab/lib/site-packages/isaacsim/kit/data/Kit/Isaac-Sim/5.1/user.config.json'
# [Info] [carb] Logging to file: c:/users/teresa/miniconda3/envs/env_isaaclab/lib/site-packages/isaacsim/kit/logs/Kit/Isaac-Sim/5.1/kit_20260303_145505.log
# 2026-03-03T13:55:05Z s] [Warning] [omni.usd_config.extension] Enable omni.materialx.libs extension to use MaterialX
# 2026-03-03T13:55:06Z s] [Warning] [carb] Acquiring non optional plugin interface which is not listed as dependency: [omni::physx::IPhysxBenchmarks v1.0] (plugin: <default plugin>), by client: omni.physics.physx.plugin. Add it to CARB_PLUGIN_IMPL_DEPS() macro of a client.
# 2026-03-03T13:55:06Z s] [Warning] [omni.isaac.dynamic_control] omni.isaac.dynamic_control is deprecated as of Isaac Sim 4.5. No action is needed from end-users.
# 2026-03-03T13:55:08Z [2,358ms] [Warning] [gpu.foundation.plugin] Skipping unsupported non-NVIDIA GPU: AMD Radeon(TM) Graphics
# 2026-03-03T13:55:08Z [2,359ms] [Warning] [gpu.foundation.plugin] Skipping unsupported non-NVIDIA GPU: AMD Radeon(TM) Graphics
#
# |---------------------------------------------------------------------------------------------|
# | Driver Version: 581.29        | Graphics API: D3D12
# |=============================================================================================|
# | GPU | Name                             | Active | LDA | GPU Memory | Vendor-ID | LUID       |
# |     |                                  |        |     |            | Device-ID | UUID       |
# |     |                                  |        |     |            | Bus-ID    |            |
# |---------------------------------------------------------------------------------------------|
# | 0   | NVIDIA GeForce RTX 5080          | Yes: 0 |     | 15889   MB | 10de      | 295a0100.. |
# |     |                                  |        |     |            | 2c02      | 0          |
# |     |                                  |        |     |            | 1         |            |
# |---------------------------------------------------------------------------------------------|
# | 1   | AMD Radeon(TM) Graphics          |        |     | 1995    MB | 1002      | 876d0100.. |
# |     |                                  |        |     |            | 13c0      | 0          |
# |     |                                  |        |     |            | N/A       |            |
# |=============================================================================================|
# | OS: Windows 11 Pro, Version: 10.0 (25H2), Build: 26200, Kernel: 10.0.26100.7824
# | Processor: AMD Ryzen 9 9950X 16-Core Processor
# | Cores: 16 | Logical Cores: 32
# |---------------------------------------------------------------------------------------------|
# | Total Memory (MB): 128627 | Free Memory: 100539
# | Total Page/Swap (MB): 136819 | Free Page/Swap: 101875
# |---------------------------------------------------------------------------------------------|
# C:\Users\Teresa\Documents\GitHub\navsim\isaac_lab\aerotaxi\env_command\env_12\flight_plan.py:29: UserWarning: Treat the new Tool classes introduced in v1.5 as experimental for now; the API and rcParam may change in future versions.
#   plt.rcParams["toolbar"] = "toolmanager"
# [INFO]: Parsing configuration from: aerotaxi.env_command.env_12.env:UAVEnvCfg
# [INFO]: Parsing configuration from: aerotaxi.env_command.env_12.grid_hiperparametros.cfg_files.ppo_random_command8_11_cfg:Command8PPORunnerCfg
# [INFO] Loading experiment from directory: C:\Users\Teresa\Documents\GitHub\navsim\isaac_lab\aerotaxi\env_command\env_12\logs\rsl_rl\command8
# Setting seed: 42
# [INFO]: Base environment:
# 	Environment device    : cuda:0
# 	Environment seed      : 42
# 	Physics step-size     : 0.005
# 	Rendering step-size   : 0.02
# 	Environment step-size : 0.02
# [INFO]: Time taken for scene creation : 1.010439 seconds
# [INFO]: Scene manager:  <class InteractiveScene>
# 	Number of environments: 64
# 	Environment spacing   : 200.0
# 	Source prim name      : /World/envs/env_0
# 	Global prim paths     : []
# 	Replicate physics     : False
# [INFO]: Starting the simulation. This may take a few seconds. Please wait...
# [INFO]: Time taken for simulation start : 0.271685 seconds
# [INFO] Command Manager:  <CommandManager> contains 1 active terms.
# +--------------------------------------+
# |         Active Command Terms         |
# +-------+-------------+----------------+
# | Index | Name        |      Type      |
# +-------+-------------+----------------+
# |   0   | vel_command | UAVcommandTerm |
# +-------+-------------+----------------+
#
# [INFO] Event Manager:  <EventManager> contains 1 active terms.
# +-----------------------------------+
# | Active Event Terms in Mode: 'reset' |
# +----------+------------------------+
# |  Index   | Name                   |
# +----------+------------------------+
# |    0     | reset_pos              |
# |    1     | randomize_mass         |
# |    2     | randomize_wind         |
# +----------+------------------------+
#
# [INFO] Recorder Manager:  <RecorderManager> contains 0 active terms.
# +---------------------+
# | Active Recorder Terms |
# +-----------+---------+
# |   Index   | Name    |
# +-----------+---------+
# +-----------+---------+
#
# [INFO] Action Manager:  <ActionManager> contains 1 active terms.
# +-----------------------------------+
# |   Active Action Terms (shape: 4)  |
# +--------+-------------+------------+
# | Index  | Name        |  Dimension |
# +--------+-------------+------------+
# |   0    | rotors_vel  |          4 |
# +--------+-------------+------------+
#
# [INFO] Observation Manager: <ObservationManager> contains 2 groups.
# +---------------------------------------------------------+
# | Active Observation Terms in Group: 'policy' (shape: (13,)) |
# +-----------+---------------------------------+-----------+
# |   Index   | Name                            |   Shape   |
# +-----------+---------------------------------+-----------+
# |     0     | dist                            |    (3,)   |
# |     1     | lin_vel                         |    (3,)   |
# |     2     | ang_vel                         |    (3,)   |
# |     3     | height                          |    (1,)   |
# |     4     | projected_gravity               |    (3,)   |
# +-----------+---------------------------------+-----------+
# +---------------------------------------------------------+
# | Active Observation Terms in Group: 'critic' (shape: (13,)) |
# +-----------+---------------------------------+-----------+
# |   Index   | Name                            |   Shape   |
# +-----------+---------------------------------+-----------+
# |     0     | dist                            |    (3,)   |
# |     1     | lin_vel                         |    (3,)   |
# |     2     | ang_vel                         |    (3,)   |
# |     3     | height                          |    (1,)   |
# |     4     | projected_gravity               |    (3,)   |
# +-----------+---------------------------------+-----------+
#
# [INFO] Termination Manager:  <TerminationManager> contains 4 active terms.
# +---------------------------------------+
# |        Active Termination Terms       |
# +-------+--------------------+----------+
# | Index | Name               | Time Out |
# +-------+--------------------+----------+
# |   0   | time_out           |   True   |
# |   1   | below_min_altitude |  False   |
# |   2   | bad_attitude       |  False   |
# |   3   | safety_shutdown    |  False   |
# +-------+--------------------+----------+
#
# [INFO] Reward Manager:  <RewardManager> contains 6 active terms.
# +------------------------------------------+
# |           Active Reward Terms            |
# +-------+-------------------------+--------+
# | Index | Name                    | Weight |
# +-------+-------------------------+--------+
# |   0   | rew_attitude_stability2 |    8.0 |
# |   1   | rew_ang_vel_stability4  |    4.0 |
# |   2   | rew_altitude_hold2      |    4.0 |
# |   3   | rew_vel2                |    1.5 |
# |   4   | rew_pos2                |    2.0 |
# |   5   | rew_action_rate         |    3.0 |
# +-------+-------------------------+--------+
#
# [INFO] Curriculum Manager:  <CurriculumManager> contains 0 active terms.
# +----------------------+
# | Active Curriculum Terms |
# +-----------+----------+
# |   Index   | Name     |
# +-----------+----------+
# +-----------+----------+
#
# [INFO]: Completed setting up the environment...
# 2026-03-03T13:55:10Z [5,291ms] [Warning] [omni.physx.fabric.plugin] FabricManager::initializePointInstancer mismatched prototypes on point instancer: /Visuals/target_commands.
# [INFO]: Loading model checkpoint from: C:\Users\Teresa\Documents\GitHub\navsim\tmp\tmpTeresa\resultados_grid_command_v8\best_model_ppo_random_command8_11_4096.pt
# C:\Users\Teresa\miniconda3\envs\env_isaaclab\Lib\site-packages\rsl_rl\utils\utils.py:244: UserWarning: The observation configuration dictionary 'obs_groups' must contain the 'policy' key. As an observation group with the name 'policy' was found, this is assumed to be the observation set. Consider adding the 'policy' key to the 'obs_groups' dictionary for clarity. This behavior will be removed in a future version.
#   warnings.warn(
# C:\Users\Teresa\miniconda3\envs\env_isaaclab\Lib\site-packages\rsl_rl\utils\utils.py:282: UserWarning: The observation configuration dictionary 'obs_groups' must contain the 'critic' key. As an observation group with the name 'critic' was found, this is assumed to be the observation set. Consider adding the 'critic' key to the 'obs_groups' dictionary for clarity. This behavior will be removed in a future version.
#   warnings.warn(
# --------------------------------------------------------------------------------
# Resolved observation sets:
# 	 policy :  ['policy']
# 	 critic :  ['critic']
# --------------------------------------------------------------------------------
# Actor MLP: MLP(
#   (0): Linear(in_features=13, out_features=128, bias=True)
#   (1): ELU(alpha=1.0)
#   (2): Linear(in_features=128, out_features=128, bias=True)
#   (3): ELU(alpha=1.0)
#   (4): Linear(in_features=128, out_features=128, bias=True)
#   (5): ELU(alpha=1.0)
#   (6): Linear(in_features=128, out_features=4, bias=True)
# )
# Critic MLP: MLP(
#   (0): Linear(in_features=13, out_features=256, bias=True)
#   (1): ELU(alpha=1.0)
#   (2): Linear(in_features=256, out_features=256, bias=True)
#   (3): ELU(alpha=1.0)
#   (4): Linear(in_features=256, out_features=256, bias=True)
#   (5): ELU(alpha=1.0)
#   (6): Linear(in_features=256, out_features=1, bias=True)
# )
#
# --- Todos los experimentos de test han finalizado ---

# %% [markdown]
# #### Test con 256 entornos

# %%
import os
df_callbacks = pd.read_csv(path_resultados+"/reward_best_models.csv",index_col='id_run_name')
top5_models = df_callbacks.nlargest(5,columns="reward")

powershell_script_test_3 = os.path.join(cfg_dir, "run_tests_3.ps1")

with open(powershell_script_test_3, "w") as f:
    f.write("$ErrorActionPreference = 'Stop'\n\n")
    
    for run_id, row in top5_models.iterrows():
        # Extraemos el número del id (ej: de 'ppo_random_hover_4' sacamos '4')
        experiment_number = run_id.split('_')[-1]
        
        # Construimos la ruta exacta del checkpoint
        # Nota: Asegúrate de que path_resultados termine en / o usar os.path.join
        checkpoint_path = f"{path_resultados}/best_model_{run_id}_{int(row['num_envs_train'])}.pt"
        f.write(f'Write-Host "Ejecutando Test final para Experimento {experiment_number}..."\n')
        
        # Usamos el experiment_number extraído para la tarea (--task)
        # Se añaden flags típicos de play.py: --num_envs 1 y se quita --headless para ver el visualizador
        f.write(f'& "{isaaclab_bat}" -p "{play_script}" '
                f'--task {id_task}-{experiment_number} '
                f'--num_envs 256 '
                f' --headless '
                f'--checkpoint "{checkpoint_path}"\n\n')
        
print(f"Script de test generado en: {powershell_script_test_3}")
# Out:
# Script de test generado en: C:/Users/Teresa/Documents/GitHub/navsim/isaac_lab/aerotaxi/env_command/env_12/grid_hiperparametros/cfg_files\run_tests_3.ps1

# %%
# Ejecuta el entrenamiento de forma automática
# !powershell -ExecutionPolicy Bypass -File "{powershell_script}"
import subprocess
import sys

# Ruta al script que generaste
powershell_script_path = powershell_script_test_3 

print(f"Iniciando ejecución de: {powershell_script_path}\n")

# Ejecutamos el proceso capturando la salida en tiempo real
process = subprocess.Popen(
    ["powershell.exe", "-ExecutionPolicy", "Bypass", "-File", powershell_script_path],
    stdout=subprocess.PIPE,
    stderr=subprocess.STDOUT, # Redirigimos errores a la salida estándar para verlos
    text=True,
    bufsize=1
)

# Leemos la salida línea a línea conforme se genera
try:
    for line in process.stdout:
        print(line, end="") # Imprime la salida de PowerShell en la celda
        sys.stdout.flush()   # Fuerza a Jupyter a mostrar la línea inmediatamente
except KeyboardInterrupt:
    process.kill()
    print("\nEntrenamiento cancelado por el usuario.")

process.wait()
print("\n--- Todos los experimentos de test han finalizado ---")
# Out:
# Iniciando ejecución de: C:/Users/Teresa/Documents/GitHub/navsim/isaac_lab/aerotaxi/env_command/env_12/grid_hiperparametros/cfg_files\run_tests_3.ps1
#
# Ejecutando Test final para Experimento 11...
# [INFO] Using python from: C:\Users\Teresa\miniconda3\envs\env_isaaclab\python.exe
# [INFO][AppLauncher]: Using device: cuda:0
# [INFO][AppLauncher]: Loading experience file: C:\Users\Teresa\miniconda3\envs\env_isaaclab\Lib\site-packages\isaaclab\apps\isaaclab.python.headless.kit
# Loading user config located at: 'c:/users/teresa/miniconda3/envs/env_isaaclab/lib/site-packages/isaacsim/kit/data/Kit/Isaac-Sim/5.1/user.config.json'
# [Info] [carb] Logging to file: c:/users/teresa/miniconda3/envs/env_isaaclab/lib/site-packages/isaacsim/kit/logs/Kit/Isaac-Sim/5.1/kit_20260303_145540.log
# 2026-03-03T13:55:40Z s] [Warning] [omni.usd_config.extension] Enable omni.materialx.libs extension to use MaterialX
# 2026-03-03T13:55:41Z s] [Warning] [carb] Acquiring non optional plugin interface which is not listed as dependency: [omni::physx::IPhysxBenchmarks v1.0] (plugin: <default plugin>), by client: omni.physics.physx.plugin. Add it to CARB_PLUGIN_IMPL_DEPS() macro of a client.
# 2026-03-03T13:55:41Z s] [Warning] [omni.isaac.dynamic_control] omni.isaac.dynamic_control is deprecated as of Isaac Sim 4.5. No action is needed from end-users.
# 2026-03-03T13:55:43Z [2,397ms] [Warning] [gpu.foundation.plugin] Skipping unsupported non-NVIDIA GPU: AMD Radeon(TM) Graphics
# 2026-03-03T13:55:43Z [2,397ms] [Warning] [gpu.foundation.plugin] Skipping unsupported non-NVIDIA GPU: AMD Radeon(TM) Graphics
#
# |---------------------------------------------------------------------------------------------|
# | Driver Version: 581.29        | Graphics API: D3D12
# |=============================================================================================|
# | GPU | Name                             | Active | LDA | GPU Memory | Vendor-ID | LUID       |
# |     |                                  |        |     |            | Device-ID | UUID       |
# |     |                                  |        |     |            | Bus-ID    |            |
# |---------------------------------------------------------------------------------------------|
# | 0   | NVIDIA GeForce RTX 5080          | Yes: 0 |     | 15889   MB | 10de      | 295a0100.. |
# |     |                                  |        |     |            | 2c02      | 0          |
# |     |                                  |        |     |            | 1         |            |
# |---------------------------------------------------------------------------------------------|
# | 1   | AMD Radeon(TM) Graphics          |        |     | 1995    MB | 1002      | 876d0100.. |
# |     |                                  |        |     |            | 13c0      | 0          |
# |     |                                  |        |     |            | N/A       |            |
# |=============================================================================================|
# | OS: Windows 11 Pro, Version: 10.0 (25H2), Build: 26200, Kernel: 10.0.26100.7824
# | Processor: AMD Ryzen 9 9950X 16-Core Processor
# | Cores: 16 | Logical Cores: 32
# |---------------------------------------------------------------------------------------------|
# | Total Memory (MB): 128627 | Free Memory: 100321
# | Total Page/Swap (MB): 136819 | Free Page/Swap: 101671
# |---------------------------------------------------------------------------------------------|
# C:\Users\Teresa\Documents\GitHub\navsim\isaac_lab\aerotaxi\env_command\env_12\flight_plan.py:29: UserWarning: Treat the new Tool classes introduced in v1.5 as experimental for now; the API and rcParam may change in future versions.
#   plt.rcParams["toolbar"] = "toolmanager"
# [INFO]: Parsing configuration from: aerotaxi.env_command.env_12.env:UAVEnvCfg
# [INFO]: Parsing configuration from: aerotaxi.env_command.env_12.grid_hiperparametros.cfg_files.ppo_random_command8_11_cfg:Command8PPORunnerCfg
# [INFO] Loading experiment from directory: C:\Users\Teresa\Documents\GitHub\navsim\isaac_lab\aerotaxi\env_command\env_12\logs\rsl_rl\command8
# Setting seed: 42
# [INFO]: Base environment:
# 	Environment device    : cuda:0
# 	Environment seed      : 42
# 	Physics step-size     : 0.005
# 	Rendering step-size   : 0.02
# 	Environment step-size : 0.02
# [INFO]: Time taken for scene creation : 1.104187 seconds
# [INFO]: Scene manager:  <class InteractiveScene>
# 	Number of environments: 256
# 	Environment spacing   : 200.0
# 	Source prim name      : /World/envs/env_0
# 	Global prim paths     : []
# 	Replicate physics     : False
# [INFO]: Starting the simulation. This may take a few seconds. Please wait...
# [INFO]: Time taken for simulation start : 0.379306 seconds
# [INFO] Command Manager:  <CommandManager> contains 1 active terms.
# +--------------------------------------+
# |         Active Command Terms         |
# +-------+-------------+----------------+
# | Index | Name        |      Type      |
# +-------+-------------+----------------+
# |   0   | vel_command | UAVcommandTerm |
# +-------+-------------+----------------+
#
# [INFO] Event Manager:  <EventManager> contains 1 active terms.
# +-----------------------------------+
# | Active Event Terms in Mode: 'reset' |
# +----------+------------------------+
# |  Index   | Name                   |
# +----------+------------------------+
# |    0     | reset_pos              |
# |    1     | randomize_mass         |
# |    2     | randomize_wind         |
# +----------+------------------------+
#
# [INFO] Recorder Manager:  <RecorderManager> contains 0 active terms.
# +---------------------+
# | Active Recorder Terms |
# +-----------+---------+
# |   Index   | Name    |
# +-----------+---------+
# +-----------+---------+
#
# [INFO] Action Manager:  <ActionManager> contains 1 active terms.
# +-----------------------------------+
# |   Active Action Terms (shape: 4)  |
# +--------+-------------+------------+
# | Index  | Name        |  Dimension |
# +--------+-------------+------------+
# |   0    | rotors_vel  |          4 |
# +--------+-------------+------------+
#
# [INFO] Observation Manager: <ObservationManager> contains 2 groups.
# +---------------------------------------------------------+
# | Active Observation Terms in Group: 'policy' (shape: (13,)) |
# +-----------+---------------------------------+-----------+
# |   Index   | Name                            |   Shape   |
# +-----------+---------------------------------+-----------+
# |     0     | dist                            |    (3,)   |
# |     1     | lin_vel                         |    (3,)   |
# |     2     | ang_vel                         |    (3,)   |
# |     3     | height                          |    (1,)   |
# |     4     | projected_gravity               |    (3,)   |
# +-----------+---------------------------------+-----------+
# +---------------------------------------------------------+
# | Active Observation Terms in Group: 'critic' (shape: (13,)) |
# +-----------+---------------------------------+-----------+
# |   Index   | Name                            |   Shape   |
# +-----------+---------------------------------+-----------+
# |     0     | dist                            |    (3,)   |
# |     1     | lin_vel                         |    (3,)   |
# |     2     | ang_vel                         |    (3,)   |
# |     3     | height                          |    (1,)   |
# |     4     | projected_gravity               |    (3,)   |
# +-----------+---------------------------------+-----------+
#
# [INFO] Termination Manager:  <TerminationManager> contains 4 active terms.
# +---------------------------------------+
# |        Active Termination Terms       |
# +-------+--------------------+----------+
# | Index | Name               | Time Out |
# +-------+--------------------+----------+
# |   0   | time_out           |   True   |
# |   1   | below_min_altitude |  False   |
# |   2   | bad_attitude       |  False   |
# |   3   | safety_shutdown    |  False   |
# +-------+--------------------+----------+
#
# [INFO] Reward Manager:  <RewardManager> contains 6 active terms.
# +------------------------------------------+
# |           Active Reward Terms            |
# +-------+-------------------------+--------+
# | Index | Name                    | Weight |
# +-------+-------------------------+--------+
# |   0   | rew_attitude_stability2 |    8.0 |
# |   1   | rew_ang_vel_stability4  |    4.0 |
# |   2   | rew_altitude_hold2      |    4.0 |
# |   3   | rew_vel2                |    1.5 |
# |   4   | rew_pos2                |    2.0 |
# |   5   | rew_action_rate         |    3.0 |
# +-------+-------------------------+--------+
#
# [INFO] Curriculum Manager:  <CurriculumManager> contains 0 active terms.
# +----------------------+
# | Active Curriculum Terms |
# +-----------+----------+
# |   Index   | Name     |
# +-----------+----------+
# +-----------+----------+
#
# [INFO]: Completed setting up the environment...
# 2026-03-03T13:55:46Z [5,571ms] [Warning] [omni.physx.fabric.plugin] FabricManager::initializePointInstancer mismatched prototypes on point instancer: /Visuals/target_commands.
# [INFO]: Loading model checkpoint from: C:\Users\Teresa\Documents\GitHub\navsim\tmp\tmpTeresa\resultados_grid_command_v8\best_model_ppo_random_command8_11_4096.pt
# C:\Users\Teresa\miniconda3\envs\env_isaaclab\Lib\site-packages\rsl_rl\utils\utils.py:244: UserWarning: The observation configuration dictionary 'obs_groups' must contain the 'policy' key. As an observation group with the name 'policy' was found, this is assumed to be the observation set. Consider adding the 'policy' key to the 'obs_groups' dictionary for clarity. This behavior will be removed in a future version.
#   warnings.warn(
# C:\Users\Teresa\miniconda3\envs\env_isaaclab\Lib\site-packages\rsl_rl\utils\utils.py:282: UserWarning: The observation configuration dictionary 'obs_groups' must contain the 'critic' key. As an observation group with the name 'critic' was found, this is assumed to be the observation set. Consider adding the 'critic' key to the 'obs_groups' dictionary for clarity. This behavior will be removed in a future version.
#   warnings.warn(
# --------------------------------------------------------------------------------
# Resolved observation sets:
# 	 policy :  ['policy']
# 	 critic :  ['critic']
# --------------------------------------------------------------------------------
# Actor MLP: MLP(
#   (0): Linear(in_features=13, out_features=128, bias=True)
#   (1): ELU(alpha=1.0)
#   (2): Linear(in_features=128, out_features=128, bias=True)
#   (3): ELU(alpha=1.0)
#   (4): Linear(in_features=128, out_features=128, bias=True)
#   (5): ELU(alpha=1.0)
#   (6): Linear(in_features=128, out_features=4, bias=True)
# )
# Critic MLP: MLP(
#   (0): Linear(in_features=13, out_features=256, bias=True)
#   (1): ELU(alpha=1.0)
#   (2): Linear(in_features=256, out_features=256, bias=True)
#   (3): ELU(alpha=1.0)
#   (4): Linear(in_features=256, out_features=256, bias=True)
#   (5): ELU(alpha=1.0)
#   (6): Linear(in_features=256, out_features=1, bias=True)
# )
#
# --- Todos los experimentos de test han finalizado ---

# %%
import pandas as pd

df_train = top5_models.copy()
if df_train.index.name == 'id_run_name':
    df_train = df_train.reset_index()

df_train = df_train.rename(columns={
    'reward': 'reward_train',
    'max_reward': 'max_reward_train',
    'std_reward': 'std_train'
})

df_test = df_rewards_play.copy()

df_test = pd.read_csv(path_resultados+'/rewards_play_PPO.csv')
df_test = df_test.rename(columns={
    'reward': 'reward_test',
    'max_reward': 'max_reward_test',
    'std': 'std_test'
})

df_final = pd.merge(
    df_train[['id_run_name', 'num_envs_train', 'reward_train', 'max_reward_train', 'std_train', 'iteration']], 
    df_test[['id_run_name', 'num_envs_test', 'reward_test', 'max_reward_test', 'std_test', 'checkpoint']], 
    on='id_run_name', 
    how='inner'
)

column_order = [
    'id_run_name',
    'num_envs_train',
    'num_envs_test',
    'reward_train', 'reward_test', 
    'max_reward_train', 'max_reward_test', 
    'std_train', 'std_test',
    'iteration'
]
df_final = df_final[column_order]

df_final = df_final.sort_values(by='id_run_name', ascending=False)

# %%
df_rewards_play = df_final.sort_values(by="id_run_name",ascending=False)
df_rewards_play = df_rewards_play.reset_index().drop(columns='index')

df_final = df_rewards_play.copy()

df_final['diff_rw_test_train'] = df_final['reward_test'] - df_final['reward_train']

df_final['diferencia(%)'] = (df_final['diff_rw_test_train'] / df_final['reward_train'].abs()) * 100

df_final['diferencia(%)'] = df_final['diferencia(%)'].apply(lambda x: f"{x:+.2f}%")

df_final
# Out:
#               id_run_name  num_envs_train  num_envs_test  reward_train  \
# 0  ppo_random_command8_11            4096              1    457.818982
# 1  ppo_random_command8_11            4096             64    457.818982
# 2  ppo_random_command8_11            4096            256    457.818982
#
#    reward_test  max_reward_train  max_reward_test  std_train   std_test  \
# 0   372.686531        475.656281       372.686531   13.75502   0.000000
# 1   333.148189        475.656281       378.570446   13.75502  69.823768
# 2   336.611868        475.656281       382.360541   13.75502  63.897914
#
#    iteration  diff_rw_test_train diferencia(%)
# 0        972          -85.132451       -18.60%
# 1        972         -124.670793       -27.23%
# 2        972         -121.207114       -26.47%

# %% [markdown]
# Pruebas con un solo entorno: Vemos cómo se comporta la política para un único agente en una prueba aleatoria.

# %%
df_final[df_final['num_envs_test'] == 1].sort_values(by='reward_test',ascending=False)
# Out:
#               id_run_name  num_envs_train  num_envs_test  reward_train  \
# 0  ppo_random_command8_11            4096              1    457.818982
#
#    reward_test  max_reward_train  max_reward_test  std_train  std_test  \
# 0   372.686531        475.656281       372.686531   13.75502       0.0
#
#    iteration  diff_rw_test_train diferencia(%)
# 0        972          -85.132451       -18.60%

# %% [markdown]
# ``Interpretación``: Vemos que el modelo 38 se ha estampado en la prueba aleatoria, así que ese modelo no debería usarse para ninguna transferencia real.

# %% [markdown]
# Pruebas con varios entornos: Vemos cómo se comporta la política en múltiples entornos (varias pruebas simuladas en paralelo), teniendo en cuenta cuál es la desviación de cada uno en test, lo que nos permite inferir si la recompensa es estable para todas las pruebas.

# %%
df_final[df_final['num_envs_test'] != 1].sort_values(by='std_test',ascending=True).reset_index().drop(columns="index")
# Out:
#               id_run_name  num_envs_train  num_envs_test  reward_train  \
# 0  ppo_random_command8_11            4096            256    457.818982
# 1  ppo_random_command8_11            4096             64    457.818982
#
#    reward_test  max_reward_train  max_reward_test  std_train   std_test  \
# 0   336.611868        475.656281       382.360541   13.75502  63.897914
# 1   333.148189        475.656281       378.570446   13.75502  69.823768
#
#    iteration  diff_rw_test_train diferencia(%)
# 0        972         -121.207114       -26.47%
# 1        972         -124.670793       -27.23%

# %% [markdown]
# pruebas:

# %% [markdown]
# C:/Users/Teresa/Desktop/RuralData/IsaacLab/IsaacLab/isaaclab.bat -p C:/Users/Teresa/Documents/GitHub/navsim/isaac_lab/rl_v5_1_0/rsl_rl/train.py --task Isaac-Command5-Aerotaxi-RANDOM-11 --num_envs 8196 --headless
