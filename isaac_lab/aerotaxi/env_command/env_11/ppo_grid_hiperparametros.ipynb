# %%
# Parámetros a configurar:
import os
experiment_name = "command7"
task_name = "Command7"
cfg_dir = "C:/Users/Teresa/Documents/GitHub/navsim/isaac_lab/aerotaxi/env_command/env_11/grid_hiperparametros/cfg_files"
path_resultados = "C:/Users/Teresa/Documents/GitHub/navsim/tmp/tmpTeresa/resultados_grid_command_v7"
isaaclab_bat = "C:/Users/Teresa/Desktop/RuralData/IsaacLab/IsaacLab/isaaclab.bat"
train_script = "C:/Users/Teresa/Documents/GitHub/navsim/isaac_lab/rl_v5_1_0/rsl_rl/train.py"
id_task = f"Isaac-{task_name}-Aerotaxi-RANDOM" # luego se le añade el número de task con el guión (Isaac-Command2-Aerotaxi-RANDOM-34)
play_script = "C:/Users/Teresa/Documents/GitHub/navsim/isaac_lab/rl_v5_1_0/rsl_rl/play.py"
num_iter = "4001"
num_steps_per_env = 100
powershell_script = os.path.join(cfg_dir, "run_all.ps1")

# el num_steps_per_env = 100 también está en el env, al final del todo, y deben tener el mismo valor
# Recuerda iniciar en el init todos los experimentos

# %%
import random
import os

# Si los directorios no existen (el último indicado), lo crea
os.makedirs(cfg_dir, exist_ok=True)
os.makedirs(path_resultados, exist_ok=True)
# Opciones de hiperparámetros
param_options = {
    "init_noise_std": [0.0, 0.1, 0.2, 0.5, 0.8, 1.0],
    "actor_hidden_dims": [[64, 64], [128, 128], [256, 256], [128, 64]],
    "critic_hidden_dims": [[64, 64], [128, 128], [256, 256]],
    "activation": ["relu", "tanh", "elu", "gelu"],
    "value_loss_coef": [0.5, 1.0, 2.0],
    "clip_param": [0.1, 0.2, 0.3],
    "entropy_coef": [0.0, 0.001, 0.01, 0.05],
    "num_learning_epochs": [4, 8, 12],
    "num_mini_batches": [2, 4, 8],
    "learning_rate": [5e-05, 1e-4, 3e-4, 1e-3, 3e-3],
    "gamma": [0.95, 0.98, 0.99],
    "lam": [0.90, 0.95, 0.97],
    "max_grad_norm": [0.5, 1.0, 2.0],
    "desired_kl": [0.005, 0.008, 0.01, 0.02],
}

num_trials = 35  # cantidad de configuraciones

cfg_files = []

for i in range(num_trials):
    run_name = f"ppo_random_{experiment_name}_{i+1}"
    sampled = {k: random.choice(v) for k, v in param_options.items()}

    # Convertir listas a string
    actor_dims = sampled["actor_hidden_dims"]
    critic_dims = sampled["critic_hidden_dims"]

    cfg_content = f"""
from isaaclab.utils import configclass
from isaaclab_rl.rsl_rl import RslRlOnPolicyRunnerCfg, RslRlPpoActorCriticCfg, RslRlPpoAlgorithmCfg

@configclass
class {task_name}PPORunnerCfg(RslRlOnPolicyRunnerCfg):
    num_steps_per_env = {num_steps_per_env} 
    max_iterations = {num_iter}
    save_interval = 100
    experiment_name = "{experiment_name}"
    run_name = "{run_name}"
    resume = False
    empirical_normalization = False
    csv_path_metrics = "{path_resultados}"
    callbacks = True
    policy = RslRlPpoActorCriticCfg(
        init_noise_std={sampled['init_noise_std']},
        actor_hidden_dims={actor_dims},
        critic_hidden_dims={critic_dims},
        activation="{sampled['activation']}",
    )
    algorithm = RslRlPpoAlgorithmCfg(
        value_loss_coef={sampled['value_loss_coef']},
        use_clipped_value_loss=True,
        clip_param={sampled['clip_param']},
        entropy_coef={sampled['entropy_coef']},
        num_learning_epochs={sampled['num_learning_epochs']},
        num_mini_batches={sampled['num_mini_batches']},
        learning_rate={sampled['learning_rate']},
        schedule="adaptive",
        gamma={sampled['gamma']},
        lam={sampled['lam']},
        desired_kl={sampled['desired_kl']},
        max_grad_norm={sampled['max_grad_norm']},
    )
"""
    cfg_path = os.path.join(cfg_dir, f"{run_name}_cfg.py")
    with open(cfg_path, "w") as f:
        f.write(cfg_content.strip())
    cfg_files.append((run_name, cfg_path))

# Crear archivo PowerShell para ejecutar todas las configuraciones
powershell_script = os.path.join(cfg_dir, "run_all.ps1")

num_envs =  [64, 128, 512, 1024, 2048, 4096, 8196] #número de entornos para train (paralelizados)

with open(powershell_script, "w") as f:
    f.write("$ErrorActionPreference = 'Stop'\n\n")
    j = 0
    for run_name, cfg_path in cfg_files:
        # Convertir path a módulo Python (reemplazar / y .py)
        num_envs_i = random.choice(num_envs)
        module_path = cfg_path.replace("/", ".").replace("\\", ".").replace(".py", "")
        f.write(f'Write-Host "Ejecutando {run_name}"\n')
        f.write(f'& "{isaaclab_bat}" -p "{train_script}" --task {id_task}-{j+1} --num_envs {num_envs_i} --headless \n\n')
        j += 1
print("Archivos de configuración generados y script PowerShell listo en:", powershell_script)
# Out:
# Archivos de configuración generados y script PowerShell listo en: C:/Users/Teresa/Documents/GitHub/navsim/isaac_lab/aerotaxi/env_command/env_10/grid_hiperparametros/cfg_files\run_all.ps1

# %%
# Ejecuta el entrenamiento de forma automática
# !powershell -ExecutionPolicy Bypass -File "{powershell_script}"
import subprocess
import sys

# Ruta al script que generaste
powershell_script_path = powershell_script 

print(f"Iniciando ejecución de: {powershell_script_path}\n")

# Ejecutamos el proceso capturando la salida en tiempo real
process = subprocess.Popen(
    ["powershell.exe", "-ExecutionPolicy", "Bypass", "-File", powershell_script_path],
    stdout=subprocess.PIPE,
    stderr=subprocess.STDOUT, # Redirigimos errores a la salida estándar para verlos
    text=True,
    bufsize=1
)

# Leemos la salida línea a línea conforme se genera
try:
    for line in process.stdout:
        print(line, end="") # Imprime la salida de PowerShell en la celda
        sys.stdout.flush()   # Fuerza a Jupyter a mostrar la línea inmediatamente
except KeyboardInterrupt:
    process.kill()
    print("\nEntrenamiento cancelado por el usuario.")

process.wait()
print("\n--- Todos los experimentos han finalizado ---")
# Out:
# Iniciando ejecución de: C:/Users/Teresa/Documents/GitHub/navsim/isaac_lab/aerotaxi/env_command/env_10/grid_hiperparametros/cfg_files\run_all.ps1
#
# Ejecutando ppo_random_command6_11
# [INFO] Using python from: C:\Users\Teresa\miniconda3\envs\env_isaaclab\python.exe
# [INFO][AppLauncher]: Using device: cuda:0
# [INFO][AppLauncher]: Loading experience file: C:\Users\Teresa\miniconda3\envs\env_isaaclab\Lib\site-packages\isaaclab\apps\isaaclab.python.kit
# Loading user config located at: 'c:/users/teresa/miniconda3/envs/env_isaaclab/lib/site-packages/isaacsim/kit/data/Kit/Isaac-Sim/5.1/user.config.json'
# [Info] [carb] Logging to file: c:/users/teresa/miniconda3/envs/env_isaaclab/lib/site-packages/isaacsim/kit/logs/Kit/Isaac-Sim/5.1/kit_20260211_173050.log
# 2026-02-11T16:30:50Z s] [Warning] [carb.crashreporter-breakpad.plugin] [previous crash] Uploading minidump: file:'c:/users/teresa/miniconda3/envs/env_isaaclab/lib/site-packages/isaacsim/kit/data/Kit/Isaac-Sim/5.1\b7673072-6bea-4abc-83a8-bae9ccfd064f.dmp' svr:'https://services.nvidia.com/submit'
# 2026-02-11T16:30:50Z s] [Warning] [carb.crashreporter-breakpad.plugin] [previous crash] Crash metadata for upload:
# 2026-02-11T16:30:50Z s] [Warning] [carb.crashreporter-breakpad.plugin] [previous crash]   'BuildGitlabJobID' = '209507878'
# 2026-02-11T16:30:50Z s] [Warning] [carb.crashreporter-breakpad.plugin] [previous crash]   'CarbSdkVersion' = '206.6+release.9587.07f17b1b.gl'
# 2026-02-11T16:30:50Z s] [Warning] [carb.crashreporter-breakpad.plugin] [previous crash]   'CrashTime' = 'Wed Feb 11 16:30:48 2026 GMT'
# 2026-02-11T16:30:50Z s] [Warning] [carb.crashreporter-breakpad.plugin] [previous crash]   'DriverShaderCacheWrapper' = 'disabled'
# 2026-02-11T16:30:50Z s] [Warning] [carb.crashreporter-breakpad.plugin] [previous crash]   'DumpId' = 'b7673072-6bea-4abc-83a8-bae9ccfd064f'
# 2026-02-11T16:30:50Z s] [Warning] [carb.crashreporter-breakpad.plugin] [previous crash]   'LastUploadStatus' = ''
# 2026-02-11T16:30:50Z s] [Warning] [carb.crashreporter-breakpad.plugin] [previous crash]   'ProductName' = 'OmniverseKit'
# 2026-02-11T16:30:50Z s] [Warning] [carb.crashreporter-breakpad.plugin] [previous crash]   'PythonTracebackStatus' = ''py-spy.exe' successfully wrote info to c:/users/teresa/miniconda3/envs/env_isaaclab/lib/site-packages/isaacsim/kit/data/Kit/Isaac-Sim/5.1/b7673072-6bea-4abc-83a8-bae9ccfd064f.py.txt'
# 2026-02-11T16:30:50Z s] [Warning] [carb.crashreporter-breakpad.plugin] [previous crash]   'RetryCount' = '0'
# 2026-02-11T16:30:50Z s] [Warning] [carb.crashreporter-breakpad.plugin] [previous crash]   'SentOnLaterRun' = 'true'
# 2026-02-11T16:30:50Z s] [Warning] [carb.crashreporter-breakpad.plugin] [previous crash]   'StartupTime' = '1770826214'
# 2026-02-11T16:30:50Z s] [Warning] [carb.crashreporter-breakpad.plugin] [previous crash]   'UploadSuccessful' = '0'
# 2026-02-11T16:30:50Z s] [Warning] [carb.crashreporter-breakpad.plugin] [previous crash]   'UptimeSeconds' = '1234'
# 2026-02-11T16:30:50Z s] [Warning] [carb.crashreporter-breakpad.plugin] [previous crash]   'UserStory' = ''
# 2026-02-11T16:30:50Z s] [Warning] [carb.crashreporter-breakpad.plugin] [previous crash]   'UserStoryStatus' = ''crashreport.gui.exe' exited with code 2'
# 2026-02-11T16:30:50Z s] [Warning] [carb.crashreporter-breakpad.plugin] [previous crash]   'Version' = '107.3.3+production.229672.69cbf6ad.gl'
# 2026-02-11T16:30:50Z s] [Warning] [carb.crashreporter-breakpad.plugin] [previous crash]   'aftermath_enabled' = '1'
# 2026-02-11T16:30:50Z s] [Warning] [carb.crashreporter-breakpad.plugin] [previous crash]   'aftermath_flags' = '3'
# 2026-02-11T16:30:50Z s] [Warning] [carb.crashreporter-breakpad.plugin] [previous crash]   'aftermath_status' = 'auto-enabled'
# 2026-02-11T16:30:50Z s] [Warning] [carb.crashreporter-breakpad.plugin] [previous crash]   'aftermath_version' = '2024.1'
# 2026-02-11T16:30:50Z s] [Warning] [carb.crashreporter-breakpad.plugin] [previous crash]   'appName' = 'Isaac-Sim'
# 2026-02-11T16:30:50Z s] [Warning] [carb.crashreporter-breakpad.plugin] [previous crash]   'appState' = 'started'
# 2026-02-11T16:30:50Z s] [Warning] [carb.crashreporter-breakpad.plugin] [previous crash]   'appVersion' = '5.1.0'
# 2026-02-11T16:30:50Z s] [Warning] [carb.crashreporter-breakpad.plugin] [previous crash]   'buildBranch' = 'production'
# 2026-02-11T16:30:50Z s] [Warning] [carb.crashreporter-breakpad.plugin] [previous crash]   'buildCi' = 'gl'
# 2026-02-11T16:30:50Z s] [Warning] [carb.crashreporter-breakpad.plugin] [previous crash]   'buildConfig' = 'release'
# 2026-02-11T16:30:50Z s] [Warning] [carb.crashreporter-breakpad.plugin] [previous crash]   'buildGitlabJobName' = 'kit-build-release-windows-x86_64'
# 2026-02-11T16:30:50Z s] [Warning] [carb.crashreporter-breakpad.plugin] [previous crash]   'buildGitlabJobStage' = 'kit-build'
# 2026-02-11T16:30:50Z s] [Warning] [carb.crashreporter-breakpad.plugin] [previous crash]   'buildGitlabPipelineID' = '34875094'
# 2026-02-11T16:30:50Z s] [Warning] [carb.crashreporter-breakpad.plugin] [previous crash]   'buildHash' = '69cbf6ad'
# 2026-02-11T16:30:50Z s] [Warning] [carb.crashreporter-breakpad.plugin] [previous crash]   'buildMajor' = '107'
# 2026-02-11T16:30:50Z s] [Warning] [carb.crashreporter-breakpad.plugin] [previous crash]   'buildMinor' = '3'
# 2026-02-11T16:30:50Z s] [Warning] [carb.crashreporter-breakpad.plugin] [previous crash]   'buildNumber' = '229672'
# 2026-02-11T16:30:50Z s] [Warning] [carb.crashreporter-breakpad.plugin] [previous crash]   'buildPatch' = '3'
# 2026-02-11T16:30:50Z s] [Warning] [carb.crashreporter-breakpad.plugin] [previous crash]   'buildVersion' = '107.3.3'
# 2026-02-11T16:30:50Z s] [Warning] [carb.crashreporter-breakpad.plugin] [previous crash]   'carboniteFrameworkVersion' = '206.6+release.9587.07f17b1b.gl'
# 2026-02-11T16:30:50Z s] [Warning] [carb.crashreporter-breakpad.plugin] [previous crash]   'carboniteSdkVersion' = '206.6+release.9587.07f17b1b.gl'
# 2026-02-11T16:30:50Z s] [Warning] [carb.crashreporter-breakpad.plugin] [previous crash]   'commandLine' = 'C:\Users\<username>\miniconda3\envs\env_isaaclab\python.exe   C:/Users/<username>/Documents/GitHub/navsim/isaac_lab/rl_v5_1_0/rsl_rl/train.py --task Isaac-Command6-Aerotaxi-RANDOM-11 --num_envs 8196'
# 2026-02-11T16:30:50Z s] [Warning] [carb.crashreporter-breakpad.plugin] [previous crash]   'cpuCoreLimited' = '-1'
# 2026-02-11T16:30:50Z s] [Warning] [carb.crashreporter-breakpad.plugin] [previous crash]   'cpuId' = 'AMD64 Family 26 Model 68 Stepping 0'
# 2026-02-11T16:30:50Z s] [Warning] [carb.crashreporter-breakpad.plugin] [previous crash]   'cpuLogicalCoresBareMetal' = '32'
# 2026-02-11T16:30:50Z s] [Warning] [carb.crashreporter-breakpad.plugin] [previous crash]   'cpuName' = 'AMD Ryzen 9 9950X 16-Core Processor            '
# 2026-02-11T16:30:50Z s] [Warning] [carb.crashreporter-breakpad.plugin] [previous crash]   'cpuPhysicalCoresBareMetal' = '16'
# 2026-02-11T16:30:50Z s] [Warning] [carb.crashreporter-breakpad.plugin] [previous crash]   'cpuUsageQuota' = '-1.000000'
# 2026-02-11T16:30:50Z s] [Warning] [carb.crashreporter-breakpad.plugin] [previous crash]   'cpuVendor' = 'AuthenticAMD'
# 2026-02-11T16:30:50Z s] [Warning] [carb.crashreporter-breakpad.plugin] [previous crash]   'crashingThread' = '10676'
# 2026-02-11T16:30:50Z s] [Warning] [carb.crashreporter-breakpad.plugin] [previous crash]   'desktopOrigin' = '(0, 0)'
# 2026-02-11T16:30:50Z s] [Warning] [carb.crashreporter-breakpad.plugin] [previous crash]   'desktopSize' = '1920x1080'
# 2026-02-11T16:30:50Z s] [Warning] [carb.crashreporter-breakpad.plugin] [previous crash]   'displayCount' = '1'
# 2026-02-11T16:30:50Z s] [Warning] [carb.crashreporter-breakpad.plugin] [previous crash]   'displayRes_0' = '1920x1080x32bit@32Hz'
# 2026-02-11T16:30:50Z s] [Warning] [carb.crashreporter-breakpad.plugin] [previous crash]   'environmentName' = 'Individual'
# 2026-02-11T16:30:50Z s] [Warning] [carb.crashreporter-breakpad.plugin] [previous crash]   'externalBuild' = '1'
# 2026-02-11T16:30:50Z s] [Warning] [carb.crashreporter-breakpad.plugin] [previous crash]   'extraExts' = 'omni.physx.fabric-107.3.26'
# 2026-02-11T16:30:50Z s] [Warning] [carb.crashreporter-breakpad.plugin] [previous crash]   'gpuDriver_0' = '581.29'
# 2026-02-11T16:30:50Z s] [Warning] [carb.crashreporter-breakpad.plugin] [previous crash]   'gpuDriver_1' = '0x80014b'
# 2026-02-11T16:30:50Z s] [Warning] [carb.crashreporter-breakpad.plugin] [previous crash]   'gpuVRAM_0' = '16660824064'
# 2026-02-11T16:30:50Z s] [Warning] [carb.crashreporter-breakpad.plugin] [previous crash]   'gpuVRAM_1' = '2147483648'
# 2026-02-11T16:30:50Z s] [Warning] [carb.crashreporter-breakpad.plugin] [previous crash]   'gpu_0' = 'NVIDIA GeForce RTX 5080'
# 2026-02-11T16:30:50Z s] [Warning] [carb.crashreporter-breakpad.plugin] [previous crash]   'gpu_1' = 'AMD Radeon(TM) Graphics'
# 2026-02-11T16:30:50Z s] [Warning] [carb.crashreporter-breakpad.plugin] [previous crash]   'hangDetected' = '1'
# 2026-02-11T16:30:50Z s] [Warning] [carb.crashreporter-breakpad.plugin] [previous crash]   'kitRendererDriverVersion' = '581.29'
# 2026-02-11T16:30:50Z s] [Warning] [carb.crashreporter-breakpad.plugin] [previous crash]   'lastCommand' = 'ChangePropertyCommand(prop_path=/Visuals/target_commands/target/geometry/mesh.primvars:invisibleToSecondaryRays,value=True,prev=?,type_to_create_if_not_exist=?)'
# 2026-02-11T16:30:51Z s] [Warning] [carb.crashreporter-breakpad.plugin] [previous crash]   'lastCommands' = 'ChangePropertyCommand(prop_path=/World/light.inputs:intensity,value=30000,prev=?,type_to_create_if_not_exist=?,usd_context_name=?),ChangePropertyCommand(prop_path=/World/light.inputs:angle,value=0.53,prev=?,type_to_create_if_not_exist=?,usd_context_name=?),CreatePreviewSurfaceMaterialPrim(mtl_path=/Visuals/target_commands/target/geometry/material,select_new_prim=False),ChangePropertyCommand(prop_path=/Visuals/target_commands/target/geometry/material/Shader.inputs:diffuseColor,value=?,prev=?,type_to_create_if_not_exist=?,usd_context_name=?),ChangePropertyCommand(prop_path=/Visuals/target_commands/target/geometry/material/Shader.inputs:emissiveColor,value=?,prev=?,type_to_create_if_not_exist=?,usd_context_name=?),ChangePropertyCommand(prop_path=/Visuals/target_commands/target/geometry/material/Shader.inputs:roughness,value=0.5,prev=?,type_to_create_if_not_exist=?,usd_context_name=?),ChangePropertyCommand(prop_path=/Visuals/target_commands/target/geometry/material/Shader.inputs:metallic,value=0.0,prev=?,type_to_create_if_not_exist=?,usd_context_name=?),ChangePropertyCommand(prop_path=/Visuals/target_commands/target/geometry/material/Shader.inputs:opacity,value=1.0,prev=?,type_to_create_if_not_exist=?,usd_context_name=?),BindMaterialCommand(prim_path=/Visuals/target_commands/target/geometry/mesh,material_path=/Visuals/target_commands/target/geometry/material,strength=strongerThanDescendants,stage=?),ChangePropertyCommand(prop_path=/Visuals/target_commands/target/geometry/mesh.primvars:invisibleToSecondaryRays,value=True,prev=?,type_to_create_if_not_exist=?)'
# 2026-02-11T16:30:51Z s] [Warning] [carb.crashreporter-breakpad.plugin] [previous crash]   'lib_isaacSim_buildBranch' = 'release'
# 2026-02-11T16:30:51Z s] [Warning] [carb.crashreporter-breakpad.plugin] [previous crash]   'lib_isaacSim_buildDate' = 'Fri Oct 17 03:55:10 2025 +0000'
# 2026-02-11T16:30:51Z s] [Warning] [carb.crashreporter-breakpad.plugin] [previous crash]   'lib_isaacSim_buildHash' = '9c81211'
# 2026-02-11T16:30:51Z s] [Warning] [carb.crashreporter-breakpad.plugin] [previous crash]   'lib_isaacSim_buildRepo' = 'https://gitlab-master.nvidia.com/omniverse/isaac/omni_isaac_sim.git'
# 2026-02-11T16:30:51Z s] [Warning] [carb.crashreporter-breakpad.plugin] [previous crash]   'lib_isaacSim_buildVersion' = '5.1.0-rc.19'
# 2026-02-11T16:30:51Z s] [Warning] [carb.crashreporter-breakpad.plugin] [previous crash]   'lib_physx_buildBranch' = 'HEAD'
# 2026-02-11T16:30:51Z s] [Warning] [carb.crashreporter-breakpad.plugin] [previous crash]   'lib_physx_buildDate' = 'Oct-03-2025'
# 2026-02-11T16:30:51Z s] [Warning] [carb.crashreporter-breakpad.plugin] [previous crash]   'lib_physx_buildHash' = '3a61992'
# 2026-02-11T16:30:51Z s] [Warning] [carb.crashreporter-breakpad.plugin] [previous crash]   'lib_physx_buildRepo' = 'gitlab-master.nvidia.com/omniverse/physics'
# 2026-02-11T16:30:51Z s] [Warning] [carb.crashreporter-breakpad.plugin] [previous crash]   'lib_physx_buildVersion' = '107.3.26'
# 2026-02-11T16:30:51Z s] [Warning] [carb.crashreporter-breakpad.plugin] [previous crash]   'memoryStats' = '(avail/total) RAM: 85.8272/125.613GB, Swap: 78.9546/133.613GB, VM: 130840/131072GB'
# 2026-02-11T16:30:51Z s] [Warning] [carb.crashreporter-breakpad.plugin] [previous crash]   'nvidia-smi' = '
# ==============NVSMI LOG==============
#
# Timestamp                                 : Wed Feb 11 17:10:14 2026
# Driver Version                            : 581.29
# CUDA Version                              : 13.0
#
# Attached GPUs                             : 1
# GPU 00000000:01:00.0
#     Product Name                          : NVIDIA GeForce RTX 5080
#     Product Brand                         : GeForce
#     Product Architecture                  : Blackwell
#     Display Mode                          : Requested functionality has been deprecated
#     Display Attached                      : Yes
#     Display Active                        : Enabled
#     Persistence Mode                      : N/A
#     Addressing Mode                       : N/A
#     MIG Mode
#         Current                           : N/A
#         Pending                           : N/A
#     Accounting Mode                       : Disabled
#     Accounting Mode Buffer Size           : 4000
#     Driver Model
#         Current                           : WDDM
#         Pending                           : WDDM
#     Serial Number                         : 0
#     GPU UUID                              : GPU-c7fa9756-fdbd-34e4-d0b8-e816a52c9795
#     GPU PDI                               : 0xc45ccb262b47b4c0
#     Minor Number                          : N/A
#     VBIOS Version                         : 98.03.3b.00.a8
#     MultiGPU Board                        : No
#     Board ID                              : 0x100
#     Board Part Number                     : N/A
#     GPU Part Number                       : 2C02-400-A1
#     FRU Part Number                       : N/A
#     Platform Info
#         Chassis Serial Number             :
#         Slot Number                       : 0
#         Tray Index                        : 0
#         Host ID                           : 1
#         Peer Type                         : Direct Connected
#         Module Id                         : 1
#         GPU Fabric GUID                   : 0x0000000000000000
#     Inforom Version
#         Image Version                     : G005.0000.98.01
#         OEM Object                        : 2.1
#         ECC Object                        : N/A
#         Power Management Object           : N/A
#     Inforom BBX Object Flush
#         Latest Timestamp                  : N/A
#         Latest Duration                   : N/A
#     GPU Operation Mode
#         Current                           : N/A
#         Pending                           : N/A
#     GPU C2C Mode                          : Disabled
#     GPU Virtualization Mode
#         Virtualization Mode               : None
#         Host VGPU Mode                    : N/A
#         vGPU Heterogeneous Mode           : N/A
#     GPU Recovery Action                   : None
#     GSP Firmware Version                  : N/A
#     IBMNPU
#         Relaxed Ordering Mode             : N/A
#     PCI
#         Bus                               : 0x01
#         Device                            : 0x00
#         Domain                            : 0x0000
#         Device Id                         : 0x2C0210DE
#         Bus Id                            : 00000000:01:00.0
#         Sub System Id                     : 0x1435196E
#         GPU Link Info
#             PCIe Generation
#                 Max                       : 5
#                 Current                   : 1
#                 Device Current            : 1
#                 Device Max                : 5
#                 Host Max                  : 5
#             Link Width
#                 Max                       : 16x
#                 Current                   : 16x
#         Bridge Chip
#             Type                          : N/A
#             Firmware                      : N/A
#         Replays Since Reset               : 0
#         Replay Number Rollovers           : 0
#         Tx Throughput                     : 1 KB/s
#         Rx Throughput                     : 2327 KB/s
#         Atomic Caps Outbound              : N/A
#         Atomic Caps Inbound               : FETCHADD_32 FETCHADD_64 SWAP_32 SWAP_64 CAS_32 CAS_64
#     Fan Speed                             : 0 %
#     Performance State                     : P8
#     Clocks Event Reasons
#         Idle                              : Not Active
#         Applications Clocks Setting       : Not Active
#         SW Power Cap                      : Active
#         HW Slowdown                       : Not Active
#             HW Thermal Slowdown           : Not Active
#             HW Power Brake Slowdown       : Not Active
#         Sync Boost                        : Not Active
#         SW Thermal Slowdown               : Not Active
#         Display Clock Setting             : Not Active
#     Clocks Event Reasons Counters
#         SW Power Capping                  : 43784457628 us
#         Sync Boost                        : 0 us
#         SW Thermal Slowdown               : 0 us
#         HW Thermal Slowdown               : 0 us
#         HW Power Braking                  : 0 us
#     Sparse Operation Mode                 : N/A
#     FB Memory Usage
#         Total                             : 16303 MiB
#         Reserved                          : 414 MiB
#         Used                              : 9302 MiB
#         Free                              : 6588 MiB
#     BAR1 Memory Usage
#         Total                             : 16384 MiB
#         Used                              : 16356 MiB
#         Free                              : 28 MiB
#     Conf Compute Protected Memory Usage
#         Total                             : N/A
#         Used                              : N/A
#         Free                              : N/A
#     Compute Mode                          : Default
#     Utilization
#         GPU                               : 2 %
#         Memory                            : 11 %
#         Encoder                           : 0 %
#         Decoder                           : 0 %
#         JPEG                              : 0 %
#         OFA                               : 0 %
#     Encoder Stats
#         Active Sessions                   : 0
#         Average FPS                       : 0
#         Average Latency                   : 0
#     FBC Stats
#         Active Sessions                   : 0
#         Average FPS                       : 0
#         Average Latency                   : 0
#     DRAM Encryption Mode
#         Current                           : Disabled
#         Pending                           : Disabled
#     ECC Mode
#         Current                           : N/A
#         Pending                           : N/A
#     ECC Errors
#         Volatile
#             SRAM Correctable              : N/A
#             SRAM Uncorrectable Parity     : N/A
#             SRAM Uncorrectable SEC-DED    : N/A
#             DRAM Correctable              : N/A
#             DRAM Uncorrectable            : N/A
#         Aggregate
#             SRAM Correctable              : N/A
#             SRAM Uncorrectable Parity     : N/A
#             SRAM Uncorrectable SEC-DED    : N/A
#             DRAM Correctable              : N/A
#             DRAM Uncorrectable            : N/A
#             SRAM Threshold Exceeded       : N/A
#         Aggregate Uncorrectable SRAM Sources
#             SRAM L2                       : N/A
#             SRAM SM                       : N/A
#             SRAM Microcontroller          : N/A
#             SRAM PCIE                     : N/A
#             SRAM Other                    : N/A
#         Channel Repair Pending            : No
#         TPC Repair Pending                : No
#     Retired Pages
#         Single Bit ECC                    : N/A
#         Double Bit ECC                    : N/A
#         Pending Page Blacklist            : N/A
#     Remapped Rows                         : N/A
#     Temperature
#         GPU Current Temp                  : 37 C
#         GPU T.Limit Temp                  : 51 C
#         GPU Shutdown T.Limit Temp         : -5 C
#         GPU Slowdown T.Limit Temp         : -2 C
#         GPU Max Operating T.Limit Temp    : 0 C
#         GPU Target Temperature            : N/A
#         Memory Current Temp               : N/A
#         Memory Max Operating T.Limit Temp : N/A
#     GPU Power Readings
#         Average Power Draw                : 30.57 W
#         Instantaneous Power Draw          : 31.64 W
#         Current Power Limit               : 360.00 W
#         Requested Power Limit             : 360.00 W
#         Default Power Limit               : 360.00 W
#         Min Power Limit                   : 250.00 W
#         Max Power Limit                   : 396.00 W
#     GPU Memory Power Readings
#         Average Power Draw                : N/A
#         Instantaneous Power Draw          : N/A
#     Module Power Readings
#         Average Power Draw                : N/A
#         Instantaneous Power Draw          : N/A
#         Current Power Limit               : N/A
#         Requested Power Limit             : N/A
#         Default Power Limit               : N/A
#         Min Power Limit                   : N/A
#         Max Power Limit                   : N/A
#     Power Smoothing                       : N/A
#     Workload Power Profiles
#         Requested Profiles                : N/A
#         Enforced Profiles                 : N/A
#     Clocks
#         Graphics                          : 570 MHz
#         SM                                : 570 MHz
#         Memory                            : 405 MHz
#         Video                             : 787 MHz
#     Applications Clocks
#         Graphics                          : N/A
#         Memory                            : N/A
#     Default Applications Clocks
#         Graphics                          : N/A
#         Memory                            : N/A
#     Deferred Clocks
#         Memory                            : N/A
#     Max Clocks
#         Graphics                          : 3090 MHz
#         SM                                : 3090 MHz
#         Memory                            : 15001 MHz
#         Video                             : 3090 MHz
#     Max Customer Boost Clocks
#         Graphics                          : N/A
#     Clock Policy
#         Auto Boost                        : N/A
#         Auto Boost Default                : N/A
#     Fabric
#         State                             : N/A
#         Status                            : N/A
#         CliqueId                          : N/A
#         ClusterUUID                       : N/A
#         Health
#             Summary                       : N/A
#             Bandwidth                     : N/A
#             Route Recovery in progress    : N/A
#             Route Unhealthy               : N/A
#             Access Timeout Recovery       : N/A
#             Incorrect Configuration       : N/A
#     Processes
#         GPU instance ID                   : N/A
#         Compute instance ID               : N/A
#         Process ID                        : 2212
#             Type                          : C+G
#             Name                          :
#             Used GPU Memory               : Not available in WDDM driver model
#         GPU instance ID                   : N/A
#         Compute instance ID               : N/A
#         Process ID                        : 2220
#             Type                          : C+G
#             Name                          :
#             Used GPU Memory               : Not available in WDDM driver model
#         GPU instance ID                   : N/A
#         Compute instance ID               : N/A
#         Process ID                        : 3088
#             Type                          : C+G
#             Name                          :
#             Used GPU Memory               : Not available in WDDM driver model
#         GPU instance ID                   : N/A
#         Compute instance ID               : N/A
#         Process ID                        : 7412
#             Type                          : C+G
#             Name                          :
#             Used GPU Memory               : Not available in WDDM driver model
#         GPU instance ID                   : N/A
#         Compute instance ID               : N/A
#         Process ID                        : 8172
#             Type                          : C+G
#             Name                          : .....................................................\GitHubDesktop.exe
#             Used GPU Memory               : Not available in WDDM driver model
#         GPU instance ID                   : N/A
#         Compute instance ID               : N/A
#         Process ID                        : 9252
#             Type                          : C+G
#             Name                          : ................................\logioptionsplus_agent.exe
#             Used GPU Memory               : Not available in WDDM driver model
#         GPU instance ID                   : N/A
#         Compute instance ID               : N/A
#         Process ID                        : 11576
#             Type                          : C+G
#             Name                          : ...................\ShellHost.exe
#             Used GPU Memory               : Not available in WDDM driver model
#         GPU instance ID                   : N/A
#         Compute instance ID               : N/A
#         Process ID                        : 11784
#             Type                          : C+G
#             Name                          : ........................................................\Code.exe
#             Used GPU Memory               : Not available in WDDM driver model
#         GPU instance ID                   : N/A
#         Compute instance ID               : N/A
#         Process ID                        : 12260
#             Type                          : C+G
#             Name                          : ..........\explorer.exe
#             Used GPU Memory               : Not available in WDDM driver model
#         GPU instance ID                   : N/A
#         Compute instance ID               : N/A
#         Process ID                        : 14868
#             Type                          : C+G
#             Name                          : ...............................................................\SearchHost.exe
#             Used GPU Memory               : Not available in WDDM driver model
#         GPU instance ID                   : N/A
#         Compute instance ID               : N/A
#         Process ID                        : 14876
#             Type                          : C+G
#             Name                          : .............................................................................\StartMenuExperienceHost.exe
#             Used GPU Memory               : Not available in WDDM driver model
#         GPU instance ID                   : N/A
#         Compute instance ID               : N/A
#         Process ID                        : 16572
#             Type                          : C+G
#             Name                          : ............................................\python.exe
#             Used GPU Memory               : Not available in WDDM driver model
#         GPU instance ID                   : N/A
#         Compute instance ID               : N/A
#         Process ID                        : 17940
#             Type                          : C+G
#             Name                          : ..\Program
#             Used GPU Memory               : Not available in WDDM driver model
#         GPU instance ID                   : N/A
#         Compute instance ID               : N/A
#         Process ID                        : 19520
#             Type                          : C+G
#             Name                          : ..\Program
#             Used GPU Memory               : Not available in WDDM driver model
#         GPU instance ID                   : N/A
#         Compute instance ID               : N/A
#         Process ID                        : 20432
#             Type                          : C+G
#             Name                          : ...............................................................\TextInputHost.exe
#             Used GPU Memory               : Not available in WDDM driver model
#         GPU instance ID                   : N/A
#         Compute instance ID               : N/A
#         Process ID                        : 21044
#             Type                          : C+G
#             Name                          : ................................................\OneDrive.exe
#             Used GPU Memory               : Not available in WDDM driver model
#         GPU instance ID                   : N/A
#         Compute instance ID               : N/A
#         Process ID                        : 22368
#             Type                          : C+G
#             Name                          : .......................................................\ShellExperienceHost.exe
#             Used GPU Memory               : Not available in WDDM driver model
#         GPU instance ID                   : N/A
#         Compute instance ID               : N/A
#         Process ID                        : 22832
#             Type                          : C+G
#             Name                          : ................................................\LM
#             Used GPU Memory               : Not available in WDDM driver model
#         GPU instance ID                   : N/A
#         Compute instance ID               : N/A
#         Process ID                        : 23644
#             Type                          : C
#             Name                          : ................................................\LM
#             Used GPU Memory               : Not available in WDDM driver model
#         GPU instance ID                   : N/A
#         Compute instance ID               : N/A
#         Process ID                        : 24376
#             Type                          : C+G
#             Name                          : ..................................................\Discord.exe
#             Used GPU Memory               : Not available in WDDM driver model
#         GPU instance ID                   : N/A
#         Compute instance ID               : N/A
#         Process ID                        : 25568
#             Type                          : C+G
#             Name                          : ..\Program
#             Used GPU Memory               : Not available in WDDM driver model
#         GPU instance ID                   : N/A
#         Compute instance ID               : N/A
#         Process ID                        : 27328
#             Type                          : C+G
#             Name                          : ..\Program
#             Used GPU Memory               : Not available in WDDM driver model
#         GPU instance ID                   : N/A
#         Compute instance ID               : N/A
#         Process ID                        : 27408
#             Type                          : C
#             Name                          : ................................................\LM
#             Used GPU Memory               : Not available in WDDM driver model
#         GPU instance ID                   : N/A
#         Compute instance ID               : N/A
#         Process ID                        : 28012
#             Type                          : C
#             Name                          : ................................................\LM
#             Used GPU Memory               : Not available in WDDM driver model
#         GPU instance ID                   : N/A
#         Compute instance ID               : N/A
#         Process ID                        : 28396
#             Type                          : C+G
#             Name                          : ............................................................................................\M365Copilot.exe
#             Used GPU Memory               : Not available in WDDM driver model
#         GPU instance ID                   : N/A
#         Compute instance ID               : N/A
#         Process ID                        : 28796
#             Type                          : C+G
#             Name                          : ..\Program
#             Used GPU Memory               : Not available in WDDM driver model
#         GPU instance ID                   : N/A
#         Compute instance ID               : N/A
#         Process ID                        : 30552
#             Type                          : C+G
#             Name                          : ..............................................................................\Copilot.exe
#             Used GPU Memory               : Not available in WDDM driver model
#         GPU instance ID                   : N/A
#         Compute instance ID               : N/A
#         Process ID                        : 31396
#             Type                          : C+G
#             Name                          : ........................................................\brave.exe
#             Used GPU Memory               : Not available in WDDM driver model
#         GPU instance ID                   : N/A
#         Compute instance ID               : N/A
#         Process ID                        : 33692
#             Type                          : C+G
#             Name                          : ........................................................\brave.exe
#             Used GPU Memory               : Not available in WDDM driver model
#     Capabilities
#         EGM                               : disabled
#
# '
# 2026-02-11T16:30:51Z s] [Warning] [carb.crashreporter-breakpad.plugin] [previous crash]   'osDistro' = '24H2'
# 2026-02-11T16:30:51Z s] [Warning] [carb.crashreporter-breakpad.plugin] [previous crash]   'osName' = 'Windows 11 Pro'
# 2026-02-11T16:30:51Z s] [Warning] [carb.crashreporter-breakpad.plugin] [previous crash]   'osVersion' = '10.00.26100'
# 2026-02-11T16:30:51Z s] [Warning] [carb.crashreporter-breakpad.plugin] [previous crash]   'portableMode' = '1'
# 2026-02-11T16:30:51Z s] [Warning] [carb.crashreporter-breakpad.plugin] [previous crash]   'primaryDisplayRes' = '1920x1080x32bit@32Hz'
# 2026-02-11T16:30:51Z s] [Warning] [carb.crashreporter-breakpad.plugin] [previous crash]   'runEnvironment' = 'Individual'
# 2026-02-11T16:30:51Z s] [Warning] [carb.crashreporter-breakpad.plugin] [previous crash]   'runningInContainer' = '0'
# 2026-02-11T16:30:51Z s] [Warning] [carb.crashreporter-breakpad.plugin] [previous crash]   'shaderdb_debugSymbols' = '0'
# 2026-02-11T16:30:51Z s] [Warning] [carb.crashreporter-breakpad.plugin] [previous crash]   'shaderdb_dumpIncludeOverrides' = '0'
# 2026-02-11T16:30:51Z s] [Warning] [carb.crashreporter-breakpad.plugin] [previous crash]   'shaderdb_dumpIntermediates' = '0'
# 2026-02-11T16:30:51Z s] [Warning] [carb.crashreporter-breakpad.plugin] [previous crash]   'shaderdb_obfuscateCode' = '1'
# 2026-02-11T16:30:51Z s] [Warning] [carb.crashreporter-breakpad.plugin] [previous crash]   'shaderdb_optimizationLevel' = '1'
# 2026-02-11T16:30:51Z s] [Warning] [carb.crashreporter-breakpad.plugin] [previous crash]   'systemInfo' = '
# |---------------------------------------------------------------------------------------------|
# | Driver Version: 581.29        | Graphics API: Vulkan
# |=============================================================================================|
# | GPU | Name                             | Active | LDA | GPU Memory | Vendor-ID | LUID       |
# |     |                                  |        |     |            | Device-ID | UUID       |
# |     |                                  |        |     |            | Bus-ID    |            |
# |---------------------------------------------------------------------------------------------|
# | 0   | NVIDIA GeForce RTX 5080          | Yes: 0 |     | 15889   MB | 10de      | d5560100.. |
# |     |                                  |        |     |            | 2c02      | c7fa9756.. |
# |     |                                  |        |     |            | 1         |            |
# |---------------------------------------------------------------------------------------------|
# | 1   | AMD Radeon(TM) Graphics          |        |     | 2048    MB | 1002      | 336a0100.. |
# |     |                                  |        |     |            | 13c0      | 00000000.. |
# |     |                                  |        |     |            | N/A       |            |
# |=============================================================================================|
# | OS: Windows 11 Pro, Version: 10.0 (24H2), Build: 26100, Kernel: 10.0.26100.7824
# | Processor: AMD Ryzen 9 9950X 16-Core Processor
# | Cores: 16 | Logical Cores: 32
# |---------------------------------------------------------------------------------------------|
# | Total Memory (MB): 128627 | Free Memory: 92546
# | Total Page/Swap (MB): 136819 | Free Page/Swap: 86298
# |---------------------------------------------------------------------------------------------|
# '
# 2026-02-11T16:30:51Z s] [Warning] [carb.crashreporter-breakpad.plugin] [previous crash]   'telemetrySessionId' = '1812735713482020911'
# 2026-02-11T16:30:51Z s] [Warning] [carb.crashreporter-breakpad.plugin] [previous crash]   'terminatedByAbort' = '0'
# 2026-02-11T16:30:51Z s] [Warning] [carb.crashreporter-breakpad.plugin] [previous crash]   'totalRamBareMetalMB' = '128627'
# 2026-02-11T16:30:51Z s] [Warning] [carb.crashreporter-breakpad.plugin] [previous crash]   'totalRamLimitedMB' = '128627'
# 2026-02-11T16:30:51Z s] [Warning] [carb.crashreporter-breakpad.plugin] [previous crash]   'totalSwapBareMetalMB' = '136819'
# 2026-02-11T16:30:51Z s] [Warning] [carb.crashreporter-breakpad.plugin] [previous crash]   'totalSwapLimitedMB' = '136819'
# 2026-02-11T16:30:51Z s] [Warning] [carb.crashreporter-breakpad.plugin] [previous crash]   'userId' = 'default'
# 2026-02-11T16:30:51Z s] [Warning] [carb.crashreporter-breakpad.plugin] [previous crash]   'workingDirectory' = 'C:\Users\<username>\Documents\GitHub\navsim\isaac_lab\aerotaxi\env_command\env_10'
# 2026-02-11T16:30:51Z s] [Warning] [carb.crashreporter-breakpad.plugin] [previous crash] Crash report files for upload:
# 2026-02-11T16:30:51Z s] [Warning] [carb.crashreporter-breakpad.plugin] [previous crash]   'metadataFile' = 'c:/users/teresa/miniconda3/envs/env_isaaclab/lib/site-packages/isaacsim/kit/data/Kit/Isaac-Sim/5.1\b7673072-6bea-4abc-83a8-bae9ccfd064f.dmp.toml'
# 2026-02-11T16:30:51Z s] [Warning] [carb.crashreporter-breakpad.plugin] [previous crash]   'upload_file_minidump' = 'c:/users/teresa/miniconda3/envs/env_isaaclab/lib/site-packages/isaacsim/kit/data/Kit/Isaac-Sim/5.1\b7673072-6bea-4abc-83a8-bae9ccfd064f.dmp'
# 2026-02-11T16:30:51Z s] [Warning] [carb.crashreporter-breakpad.plugin] [previous crash]   'upload_file_traceback' = 'c:/users/teresa/miniconda3/envs/env_isaaclab/lib/site-packages/isaacsim/kit/data/Kit/Isaac-Sim/5.1/b7673072-6bea-4abc-83a8-bae9ccfd064f.py.txt'
# [0.243s] [ext: omni.kit.async_engine-0.0.3] startup
# [0.353s] [ext: omni.metrics.core-0.0.3] startup
# [0.355s] [ext: omni.client.lib-1.1.0] startup
# [0.370s] [ext: omni.blobkey-1.1.2] startup
# [0.372s] [ext: omni.stats-1.0.1] startup
# [0.375s] [ext: omni.datastore-0.0.0] startup
# [0.377s] [ext: omni.client-1.3.0] startup
# [0.384s] [ext: omni.ujitso.default-1.0.0] startup
# [0.388s] [ext: omni.hsscclient-1.1.2] startup
# [0.397s] [ext: omni.gpu_foundation.shadercache.vulkan-1.0.0] startup
# [0.402s] [ext: omni.assets.plugins-0.0.0] startup
# [0.406s] [ext: omni.gpu_foundation-0.0.0] startup
# [0.432s] [ext: carb.windowing.plugins-1.0.0] startup
# [0.546s] [ext: omni.kit.renderer.init-0.0.0] startup
# [0.549s] [ext: omni.materialx.libs-1.0.7] startup
# [0.563s] [ext: omni.kit.telemetry-0.5.2] startup
# [0.575s] [ext: omni.usd.config-1.0.6] startup
# [0.587s] [ext: omni.gpucompute.plugins-0.0.0] startup
# [0.591s] [ext: omni.usd.libs-1.0.1] startup
# [0.704s] [ext: omni.kit.pipapi-0.0.0] startup
# [0.706s] [ext: omni.mdl-56.0.3] startup
# [0.733s] [ext: omni.iray.libs-0.0.0] startup
# [0.752s] [ext: omni.mdl.neuraylib-0.2.12] startup
# [0.760s] [ext: omni.kit.usd.mdl-1.1.5] startup
# 2026-02-11T16:30:51Z s] [Warning] [gpu.foundation.plugin] Skipping unsupported non-NVIDIA GPU: AMD Radeon(TM) Graphics
# 2026-02-11T16:30:51Z s] [Warning] [gpu.foundation.plugin] Skipping unsupported non-NVIDIA GPU: AMD Radeon(TM) Graphics
# [0.874s] [ext: omni.kit.loop-isaac-1.3.7] startup
# [0.896s] [ext: omni.kit.test-2.0.1] startup
# [0.955s] [ext: omni.appwindow-1.1.10] startup
# [0.981s] [ext: omni.kit.renderer.core-1.1.0] startup
# [0.991s] [ext: omni.kit.renderer.capture-0.0.0] startup
# [0.999s] [ext: omni.kit.renderer.imgui-2.0.5] startup
# [1.017s] [ext: omni.ui-2.27.1] startup
# [1.033s] [ext: omni.kit.mainwindow-1.0.3] startup
# [1.035s] [ext: carb.audio-0.1.0] startup
# [1.039s] [ext: omni.uiaudio-1.0.0] startup
# [1.043s] [ext: omni.kit.uiapp-0.0.0] startup
# [1.043s] [ext: omni.usd.schema.metrics.assembler-107.3.1] startup
# [1.053s] [ext: omni.usd.schema.audio-0.0.0] startup
# [1.064s] [ext: isaacsim.robot.schema-3.6.0] startup
# [1.089s] [ext: omni.usd.schema.anim-0.0.0] startup
#
# |---------------------------------------------------------------------------------------------|
# | Driver Version: 581.29        | Graphics API: Vulkan
# |=============================================================================================|
# | GPU | Name                             | Active | LDA | GPU Memory | Vendor-ID | LUID       |
# |     |                                  |        |     |            | Device-ID | UUID       |
# |     |                                  |        |     |            | Bus-ID    |            |
# |---------------------------------------------------------------------------------------------|
# | 0   | NVIDIA GeForce RTX 5080          | Yes: 0 |     | 15889   MB | 10de      | d5560100.. |
# |     |                                  |        |     |            | 2c02      | c7fa9756.. |
# |     |                                  |        |     |            | 1         |            |
# |---------------------------------------------------------------------------------------------|
# | 1   | AMD Radeon(TM) Graphics          |        |     | 2048    MB | 1002      | 336a0100.. |
# |     |                                  |        |     |            | 13c0      | 00000000.. |
# |     |                                  |        |     |            | N/A       |            |
# |=============================================================================================|
# | OS: Windows 11 Pro, Version: 10.0 (24H2), Build: 26100, Kernel: 10.0.26100.7824
# | Processor: AMD Ryzen 9 9950X 16-Core Processor
# | Cores: 16 | Logical Cores: 32
# |---------------------------------------------------------------------------------------------|
# | Total Memory (MB): 128627 | Free Memory: 86787
# | Total Page/Swap (MB): 136819 | Free Page/Swap: 78068
# |---------------------------------------------------------------------------------------------|
# [1.123s] [ext: omni.usd_resolver-1.0.0] startup
# [1.134s] [ext: omni.usd.core-1.5.3] startup
# [1.138s] [ext: omni.usd.schema.omni_sensors-0.0.0] startup
# [1.199s] [ext: omni.usd.schema.physx-107.3.26] startup
# [1.229s] [ext: omni.usd.schema.omniscripting-1.0.0] startup
# [1.238s] [ext: omni.usd.schema.omnigraph-1.0.0] startup
# [1.248s] [ext: omni.usd.schema.semantics-0.0.0] startup
# [1.254s] [ext: omni.usd.schema.geospatial-0.0.0] startup
# [1.259s] [ext: omni.kit.window.popup_dialog-2.0.24] startup
# [1.266s] [ext: omni.activity.core-1.0.3] startup
# [1.270s] [ext: omni.kit.widget.nucleus_connector-2.0.1] startup
# [1.275s] [ext: omni.kit.usd_undo-0.1.8] startup
# [1.276s] [ext: omni.graph.exec-0.9.6] startup
# [1.277s] [ext: omni.kit.actions.core-1.0.0] startup
# [1.283s] [ext: usdrt.scenegraph-7.6.1] startup
# [1.441s] [ext: omni.resourcemonitor-107.0.1] startup
# [1.453s] [ext: omni.kit.exec.core-0.13.4] startup
# [1.459s] [ext: omni.timeline-1.0.14] startup
# [1.463s] [ext: omni.kit.commands-1.4.10] startup
# [1.471s] [ext: omni.kit.audiodeviceenum-1.0.2] startup
# [1.476s] [ext: omni.hydra.usdrt_delegate-7.5.1] startup
# [1.487s] [ext: omni.hydra.scene_delegate-0.3.4] startup
# [1.492s] [ext: omni.usd-1.13.10] startup
# [1.588s] [ext: omni.kit.asset_converter-5.0.17] startup
# [1.601s] [ext: omni.usd.schema.omni_lens_distortion-0.0.0] startup
# [1.603s] [ext: omni.usd.schema.render_settings.rtx-0.0.0] startup
# [1.605s] [ext: omni.index.libs-380600.8087.0] startup
# [1.606s] [ext: omni.volume-0.5.2] startup
# [1.614s] [ext: omni.ujitso.client-0.0.0] startup
# [1.616s] [ext: omni.index-1.0.1] startup
# [1.618s] [ext: omni.hydra.rtx.shadercache.vulkan-1.0.0] startup
# [1.620s] [ext: omni.hydra.rtx-1.0.0] startup
# [1.663s] [ext: omni.kit.notification_manager-1.0.10] startup
# [1.667s] [ext: omni.kit.clipboard-1.0.5] startup
# [1.669s] [ext: omni.kit.viewport.legacy_gizmos-1.0.19] startup
# [1.671s] [ext: omni.kit.raycast.query-1.1.0] startup
# [1.676s] [ext: omni.kit.menu.core-1.1.2] startup
# [1.677s] [ext: omni.kit.widget.options_menu-1.1.6] startup
# [1.683s] [ext: omni.kit.helper.file_utils-0.1.9] startup
# [1.685s] [ext: omni.kit.widget.path_field-2.0.11] startup
# [1.687s] [ext: omni.kit.widget.context_menu-1.2.5] startup
# [1.690s] [ext: omni.kit.widget.options_button-1.0.3] startup
# [1.691s] [ext: omni.kit.widget.filebrowser-2.12.3] startup
# [1.699s] [ext: omni.kit.widget.browser_bar-2.0.10] startup
# [1.701s] [ext: omni.kit.usd.layers-2.2.11] startup
# [1.712s] [ext: omni.ui.scene-1.11.5] startup
# [1.717s] [ext: omni.kit.viewport.registry-104.0.6] startup
# [1.719s] [ext: omni.kit.window.filepicker-2.13.4] startup
# [1.739s] [ext: omni.kit.menu.utils-2.0.5] startup
# [1.750s] [ext: omni.kit.context_menu-1.8.6] startup
# [1.754s] [ext: omni.kit.viewport.scene_camera_model-1.0.6] startup
# [1.758s] [ext: omni.kit.hydra_texture-1.4.6] startup
# [1.762s] [ext: omni.kit.window.file_importer-1.1.18] startup
# [1.768s] [ext: omni.kit.widget.searchable_combobox-1.0.6] startup
# [1.771s] [ext: omni.kit.window.drop_support-1.0.5] startup
# [1.772s] [ext: omni.kit.widget.viewport-107.1.3] startup
# [1.781s] [ext: omni.kit.material.library-2.0.7] startup
# [1.789s] [ext: omni.hydra.engine.stats-1.0.3] startup
# [1.791s] [ext: omni.kit.widget.settings-1.2.6] startup
# [1.794s] [ext: omni.kit.viewport.window-107.2.0] startup
# [2.049s] [ext: omni.kit.window.preferences-1.8.0] startup
# [2.061s] [ext: omni.kit.widget.toolbar-2.0.1] startup
# [2.072s] [ext: omni.kit.viewport.utility-1.1.2] startup
# [2.073s] [ext: omni.kit.manipulator.transform-107.0.0] startup
# [2.080s] [ext: omni.kit.manipulator.tool.snap-1.5.13] startup
# [2.087s] [ext: omni.kit.manipulator.selector-1.1.3] startup
# [2.089s] [ext: omni.kit.viewport.manipulator.transform-107.0.4] startup
# [2.093s] [ext: omni.kit.manipulator.viewport-107.0.1] startup
# [2.095s] [ext: omni.kit.primitive.mesh-1.0.17] startup
# [2.102s] [ext: omni.kit.manipulator.prim.core-107.0.8] startup
# [2.113s] [ext: omni.fabric.commands-1.1.6] startup
# [2.118s] [ext: omni.kit.manipulator.prim.usd-107.0.3] startup
# [2.120s] [ext: omni.kit.manipulator.prim.fabric-107.0.4] startup
# [2.122s] [ext: omni.debugdraw-0.1.4] startup
# [2.126s] [ext: omni.kit.property.adapter.core-1.0.2] startup
# [2.130s] [ext: omni.kit.manipulator.prim-107.0.0] startup
# [2.130s] [ext: omni.usdphysics-107.3.26] startup
# [2.134s] [ext: omni.kit.manipulator.selection-106.0.1] startup
# [2.136s] [ext: omni.kit.hotkeys.core-1.3.10] startup
# [2.138s] [ext: omni.kit.property.adapter.usd-1.0.2] startup
# [2.140s] [ext: omni.kit.widget.searchfield-1.1.8] startup
# [2.142s] [ext: omni.kit.widget.filter-1.1.4] startup
# [2.144s] [ext: omni.kit.property.adapter.fabric-1.0.3] startup
# [2.146s] [ext: omni.kit.widget.highlight_label-1.0.3] startup
# [2.148s] [ext: omni.kit.window.file_exporter-1.0.33] startup
# ...
#                       Learning iteration 824/4001
#
#                        Computation: 48022 steps/s (collection: 16.863s, learning 0.204s)
#              Mean action noise std: 3.93
#           Mean value_function loss: 0.0231
#                Mean surrogate loss: 0.0086
#                  Mean entropy loss: 9.0270
#                        Mean reward: 34.06
#                Mean episode length: 64.56
#               Episode_Reward/alive: 0.7609
#         Episode_Reward/action_rate: -0.0025
#         Episode_Reward/terminating: -0.0160
#        Episode_Reward/rew_pos_diff: -0.0041
# Episode_Reward/rew_pos_diff_fine_grained: 0.3859
#    Episode_Reward/rew_lin_vel_diff: -0.3501
# Episode_Reward/rew_lin_vel_diff_fine_grained: 0.0025
#  Episode_Reward/rew_ang_vel_z_diff: -0.0260
# Episode_Reward/rew_ang_vel_z_diff_fine_grained: 0.0172
#       Episode_Reward/rew_roll_diff: -0.0025
# Episode_Reward/rew_roll_diff_fine_grained: 0.0520
#      Episode_Reward/rew_pitch_diff: -0.0063
# Episode_Reward/rew_pitch_diff_fine_grained: 0.0146
#        Episode_Reward/rew_hovering: 0.5298
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 1.0000
#   Episode_Termination/bad_attitude: 0.0000
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 676170000
#                     Iteration time: 17.07s
#                       Time elapsed: 04:13:03
#                                ETA: 16:14:31
#
# ################################################################################
#                       Learning iteration 825/4001
#
#                        Computation: 47904 steps/s (collection: 16.908s, learning 0.202s)
#              Mean action noise std: 3.94
#           Mean value_function loss: 0.0259
#                Mean surrogate loss: 0.0023
#                  Mean entropy loss: 9.0315
#                        Mean reward: 33.37
#                Mean episode length: 63.65
#               Episode_Reward/alive: 0.7609
#         Episode_Reward/action_rate: -0.0025
#         Episode_Reward/terminating: -0.0160
#        Episode_Reward/rew_pos_diff: -0.0041
# Episode_Reward/rew_pos_diff_fine_grained: 0.3859
#    Episode_Reward/rew_lin_vel_diff: -0.3499
# Episode_Reward/rew_lin_vel_diff_fine_grained: 0.0025
#  Episode_Reward/rew_ang_vel_z_diff: -0.0256
# Episode_Reward/rew_ang_vel_z_diff_fine_grained: 0.0176
#       Episode_Reward/rew_roll_diff: -0.0025
# Episode_Reward/rew_roll_diff_fine_grained: 0.0516
#      Episode_Reward/rew_pitch_diff: -0.0062
# Episode_Reward/rew_pitch_diff_fine_grained: 0.0149
#        Episode_Reward/rew_hovering: 0.5293
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 1.0000
#   Episode_Termination/bad_attitude: 0.0000
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 676989600
#                     Iteration time: 17.11s
#                       Time elapsed: 04:13:20
#                                ETA: 16:14:07
#
# ################################################################################
#                       Learning iteration 826/4001
#
#                        Computation: 48151 steps/s (collection: 16.831s, learning 0.190s)
#              Mean action noise std: 3.95
#           Mean value_function loss: 0.0319
#                Mean surrogate loss: 0.0063
#                  Mean entropy loss: 9.0394
#                        Mean reward: 34.77
#                Mean episode length: 65.81
#               Episode_Reward/alive: 0.7607
#         Episode_Reward/action_rate: -0.0025
#         Episode_Reward/terminating: -0.0160
#        Episode_Reward/rew_pos_diff: -0.0041
# Episode_Reward/rew_pos_diff_fine_grained: 0.3857
#    Episode_Reward/rew_lin_vel_diff: -0.3498
# Episode_Reward/rew_lin_vel_diff_fine_grained: 0.0025
#  Episode_Reward/rew_ang_vel_z_diff: -0.0257
# Episode_Reward/rew_ang_vel_z_diff_fine_grained: 0.0174
#       Episode_Reward/rew_roll_diff: -0.0026
# Episode_Reward/rew_roll_diff_fine_grained: 0.0508
#      Episode_Reward/rew_pitch_diff: -0.0063
# Episode_Reward/rew_pitch_diff_fine_grained: 0.0147
#        Episode_Reward/rew_hovering: 0.5291
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 1.0000
#   Episode_Termination/bad_attitude: 0.0000
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 677809200
#                     Iteration time: 17.02s
#                       Time elapsed: 04:13:37
#                                ETA: 16:13:43
#
# ################################################################################
#                       Learning iteration 827/4001
#
#                        Computation: 48325 steps/s (collection: 16.777s, learning 0.183s)
#              Mean action noise std: 3.95
#           Mean value_function loss: 0.0259
#                Mean surrogate loss: 0.0055
#                  Mean entropy loss: 9.0401
#                        Mean reward: 33.52
#                Mean episode length: 63.83
#               Episode_Reward/alive: 0.7612
#         Episode_Reward/action_rate: -0.0025
#         Episode_Reward/terminating: -0.0160
#        Episode_Reward/rew_pos_diff: -0.0041
# Episode_Reward/rew_pos_diff_fine_grained: 0.3863
#    Episode_Reward/rew_lin_vel_diff: -0.3500
# Episode_Reward/rew_lin_vel_diff_fine_grained: 0.0025
#  Episode_Reward/rew_ang_vel_z_diff: -0.0257
# Episode_Reward/rew_ang_vel_z_diff_fine_grained: 0.0175
#       Episode_Reward/rew_roll_diff: -0.0026
# Episode_Reward/rew_roll_diff_fine_grained: 0.0498
#      Episode_Reward/rew_pitch_diff: -0.0063
# Episode_Reward/rew_pitch_diff_fine_grained: 0.0148
#        Episode_Reward/rew_hovering: 0.5299
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 1.0000
#   Episode_Termination/bad_attitude: 0.0000
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 678628800
#                     Iteration time: 16.96s
#                       Time elapsed: 04:13:54
#                                ETA: 16:13:20
#
# ################################################################################
#                       Learning iteration 828/4001
#
#                        Computation: 48125 steps/s (collection: 16.825s, learning 0.205s)
#              Mean action noise std: 3.97
#           Mean value_function loss: 0.0463
#                Mean surrogate loss: 0.0033
#                  Mean entropy loss: 9.0515
#                        Mean reward: 34.69
#                Mean episode length: 65.77
#               Episode_Reward/alive: 0.7602
#         Episode_Reward/action_rate: -0.0025
#         Episode_Reward/terminating: -0.0160
#        Episode_Reward/rew_pos_diff: -0.0041
# Episode_Reward/rew_pos_diff_fine_grained: 0.3857
#    Episode_Reward/rew_lin_vel_diff: -0.3494
# Episode_Reward/rew_lin_vel_diff_fine_grained: 0.0025
#  Episode_Reward/rew_ang_vel_z_diff: -0.0261
# Episode_Reward/rew_ang_vel_z_diff_fine_grained: 0.0171
#       Episode_Reward/rew_roll_diff: -0.0027
# Episode_Reward/rew_roll_diff_fine_grained: 0.0491
#      Episode_Reward/rew_pitch_diff: -0.0062
# Episode_Reward/rew_pitch_diff_fine_grained: 0.0149
#        Episode_Reward/rew_hovering: 0.5283
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 1.0000
#   Episode_Termination/bad_attitude: 0.0000
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 679448400
#                     Iteration time: 17.03s
#                       Time elapsed: 04:14:11
#                                ETA: 16:12:56
#
# ################################################################################
#                       Learning iteration 829/4001
#
#                        Computation: 47955 steps/s (collection: 16.905s, learning 0.186s)
#              Mean action noise std: 3.98
#           Mean value_function loss: 0.0372
#                Mean surrogate loss: 0.0047
#                  Mean entropy loss: 9.0575
#                        Mean reward: 33.33
#                Mean episode length: 64.04
#               Episode_Reward/alive: 0.7634
#         Episode_Reward/action_rate: -0.0025
#         Episode_Reward/terminating: -0.0160
#        Episode_Reward/rew_pos_diff: -0.0041
# Episode_Reward/rew_pos_diff_fine_grained: 0.3867
#    Episode_Reward/rew_lin_vel_diff: -0.3513
# Episode_Reward/rew_lin_vel_diff_fine_grained: 0.0025
#  Episode_Reward/rew_ang_vel_z_diff: -0.0260
# Episode_Reward/rew_ang_vel_z_diff_fine_grained: 0.0173
#       Episode_Reward/rew_roll_diff: -0.0027
# Episode_Reward/rew_roll_diff_fine_grained: 0.0491
#      Episode_Reward/rew_pitch_diff: -0.0063
# Episode_Reward/rew_pitch_diff_fine_grained: 0.0147
#        Episode_Reward/rew_hovering: 0.5323
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 1.0000
#   Episode_Termination/bad_attitude: 0.0000
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 680268000
#                     Iteration time: 17.09s
#                       Time elapsed: 04:14:28
#                                ETA: 16:12:33
#
# ################################################################################
#                       Learning iteration 830/4001
#
#                        Computation: 48220 steps/s (collection: 16.795s, learning 0.202s)
#              Mean action noise std: 4.00
#           Mean value_function loss: 0.0375
#                Mean surrogate loss: 0.0021
#                  Mean entropy loss: 9.0751
#                        Mean reward: 33.11
#                Mean episode length: 63.12
#               Episode_Reward/alive: 0.7611
#         Episode_Reward/action_rate: -0.0025
#         Episode_Reward/terminating: -0.0160
#        Episode_Reward/rew_pos_diff: -0.0041
# Episode_Reward/rew_pos_diff_fine_grained: 0.3857
#    Episode_Reward/rew_lin_vel_diff: -0.3502
# Episode_Reward/rew_lin_vel_diff_fine_grained: 0.0025
#  Episode_Reward/rew_ang_vel_z_diff: -0.0258
# Episode_Reward/rew_ang_vel_z_diff_fine_grained: 0.0175
#       Episode_Reward/rew_roll_diff: -0.0027
# Episode_Reward/rew_roll_diff_fine_grained: 0.0487
#      Episode_Reward/rew_pitch_diff: -0.0062
# Episode_Reward/rew_pitch_diff_fine_grained: 0.0151
#        Episode_Reward/rew_hovering: 0.5294
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 1.0000
#   Episode_Termination/bad_attitude: 0.0000
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 681087600
#                     Iteration time: 17.00s
#                       Time elapsed: 04:14:45
#                                ETA: 16:12:09
#
# ################################################################################
#                       Learning iteration 831/4001
#
#                        Computation: 48207 steps/s (collection: 16.801s, learning 0.201s)
#              Mean action noise std: 4.01
#           Mean value_function loss: 0.1071
#                Mean surrogate loss: 0.0035
#                  Mean entropy loss: 9.0965
#                        Mean reward: 33.61
#                Mean episode length: 64.27
#               Episode_Reward/alive: 0.7634
#         Episode_Reward/action_rate: -0.0025
#         Episode_Reward/terminating: -0.0160
#        Episode_Reward/rew_pos_diff: -0.0041
# Episode_Reward/rew_pos_diff_fine_grained: 0.3871
#    Episode_Reward/rew_lin_vel_diff: -0.3511
# Episode_Reward/rew_lin_vel_diff_fine_grained: 0.0025
#  Episode_Reward/rew_ang_vel_z_diff: -0.0260
# Episode_Reward/rew_ang_vel_z_diff_fine_grained: 0.0174
#       Episode_Reward/rew_roll_diff: -0.0027
# Episode_Reward/rew_roll_diff_fine_grained: 0.0484
#      Episode_Reward/rew_pitch_diff: -0.0063
# Episode_Reward/rew_pitch_diff_fine_grained: 0.0151
#        Episode_Reward/rew_hovering: 0.5322
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 1.0000
#   Episode_Termination/bad_attitude: 0.0000
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 681907200
#                     Iteration time: 17.00s
#                       Time elapsed: 04:15:02
#                                ETA: 16:11:45
#
# ################################################################################
#                       Learning iteration 832/4001
#
#                        Computation: 48371 steps/s (collection: 16.742s, learning 0.202s)
#              Mean action noise std: 4.02
#           Mean value_function loss: 0.0755
#                Mean surrogate loss: 0.0069
#                  Mean entropy loss: 9.1108
#                        Mean reward: 33.33
#                Mean episode length: 63.29
#               Episode_Reward/alive: 0.7623
#         Episode_Reward/action_rate: -0.0025
#         Episode_Reward/terminating: -0.0160
#        Episode_Reward/rew_pos_diff: -0.0041
# Episode_Reward/rew_pos_diff_fine_grained: 0.3866
#    Episode_Reward/rew_lin_vel_diff: -0.3504
# Episode_Reward/rew_lin_vel_diff_fine_grained: 0.0025
#  Episode_Reward/rew_ang_vel_z_diff: -0.0256
# Episode_Reward/rew_ang_vel_z_diff_fine_grained: 0.0176
#       Episode_Reward/rew_roll_diff: -0.0026
# Episode_Reward/rew_roll_diff_fine_grained: 0.0489
#      Episode_Reward/rew_pitch_diff: -0.0063
# Episode_Reward/rew_pitch_diff_fine_grained: 0.0148
#        Episode_Reward/rew_hovering: 0.5307
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 1.0000
#   Episode_Termination/bad_attitude: 0.0000
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 682726800
#                     Iteration time: 16.94s
#                       Time elapsed: 04:15:19
#                                ETA: 16:11:21
#
# ################################################################################
#                       Learning iteration 833/4001
#
#                        Computation: 48076 steps/s (collection: 16.878s, learning 0.170s)
#              Mean action noise std: 4.02
#           Mean value_function loss: 0.0257
#                Mean surrogate loss: 0.0033
#                  Mean entropy loss: 9.1212
#                        Mean reward: 34.38
#                Mean episode length: 65.33
#               Episode_Reward/alive: 0.7618
#         Episode_Reward/action_rate: -0.0025
#         Episode_Reward/terminating: -0.0160
#        Episode_Reward/rew_pos_diff: -0.0041
# Episode_Reward/rew_pos_diff_fine_grained: 0.3864
#    Episode_Reward/rew_lin_vel_diff: -0.3501
# Episode_Reward/rew_lin_vel_diff_fine_grained: 0.0025
#  Episode_Reward/rew_ang_vel_z_diff: -0.0259
# Episode_Reward/rew_ang_vel_z_diff_fine_grained: 0.0174
#       Episode_Reward/rew_roll_diff: -0.0026
# Episode_Reward/rew_roll_diff_fine_grained: 0.0498
#      Episode_Reward/rew_pitch_diff: -0.0063
# Episode_Reward/rew_pitch_diff_fine_grained: 0.0152
#        Episode_Reward/rew_hovering: 0.5302
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 1.0000
#   Episode_Termination/bad_attitude: 0.0000
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 683546400
#                     Iteration time: 17.05s
#                       Time elapsed: 04:15:36
#                                ETA: 16:10:58
#
#
# [Early Stopping] No ha habido mejora en 500 iteraciones. Deteniendo entrenamiento en iteración 833...
# [15512.867s] Simulation App Shutting Down
#
# --- Todos los experimentos han finalizado ---

# %% [markdown]
# ``Análisis de los datos``

# %%
import csv
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

seed = 42
n=5

df_results_grid_actions = pd.read_csv(path_resultados+"/resultados_grid_PPO.csv")

# %%
def get_group(value):
    if f"_{experiment_name}" in value:
        return task_name

df_results_grid_actions["tarea"] = df_results_grid_actions["id_run_name"].apply(get_group)

# %%
df_copy = df_results_grid_actions.copy()
df_results_grid_actions.sample(n, random_state=seed)
# Out:
#               id_run_name  iteration     reward  max_reward  std_reward  \
# 0  ppo_random_command5_11          0  -2.420788   28.929943   11.037044
# 1  ppo_random_command5_11        100   0.069266   27.518446    6.282837
# 8  ppo_random_command5_11        800  96.731036  564.745300  118.674819
# 5  ppo_random_command5_11        500  45.248518  449.829529   95.919549
# 3  ppo_random_command5_11        300  18.817899  178.520355   46.518866
#
#    num_envs_train  mean_Episode_Reward/alive  mean_Episode_Reward/action_rate  \
# 0            8196                   0.297308                        -0.004342
# 1            8196                   0.187469                        -0.003808
# 8            8196                   1.936564                        -0.077961
# 5            8196                   1.280472                        -0.043600
# 3            8196                   0.584474                        -0.017433
#
#    mean_Episode_Reward/terminating  mean_Episode_Reward/rew_pos_diff  ...  \
# 0                        -0.018723                         -0.398911  ...
# 1                        -0.020000                         -0.209163  ...
# 8                        -0.019991                         -1.186707  ...
# 5                        -0.019999                         -0.841125  ...
# 3                        -0.020000                         -0.480084  ...
#
#    mean_Episode_Reward/rew_roll_diff  \
# 0                          -0.003313
# 1                          -0.002345
# 8                          -0.013668
# 5                          -0.007725
# 3                          -0.003992
#
#    mean_Episode_Reward/rew_roll_diff_fine_grained  \
# 0                                        0.004749
# 1                                        0.002929
# 8                                        0.050434
# 5                                        0.039402
# 3                                        0.017101
#
#    mean_Episode_Reward/rew_pitch_diff  \
# 0                           -0.002472
# 1                           -0.001550
# 8                           -0.012553
# 5                           -0.007925
# 3                           -0.003494
#
#    mean_Episode_Reward/rew_pitch_diff_fine_grained  \
# 0                                         0.005721
# 1                                         0.003735
# 8                                         0.052967
# 5                                         0.036866
# 3                                         0.017664
#
#    mean_Episode_Reward/rew_heading_alignment_fine_grained  \
# 0                                           0.021445
# 1                                           0.015808
# 8                                           0.179734
# 5                                           0.132950
# 3                                           0.088294
#
#    mean_Episode_Termination/time_out  \
# 0                           0.002533
# 1                           0.000000
# 8                           0.000429
# 5                           0.000004
# 3                           0.000000
#
#    mean_Episode_Termination/below_min_altitude  \
# 0                                     0.709719
# 1                                     0.295867
# 8                                     0.192017
# 5                                     0.251283
# 3                                     0.300422
#
#    mean_Episode_Termination/bad_attitude  \
# 0                               0.179223
# 1                               0.704133
# 8                               0.807554
# 5                               0.748713
# 3                               0.699578
#
#    mean_Episode_Termination/safety_shutdown     tarea
# 0                                       0.0  Command5
# 1                                       0.0  Command5
# 8                                       0.0  Command5
# 5                                       0.0  Command5
# 3                                       0.0  Command5
#
# [5 rows x 25 columns]

# %%
df_results_grid_actions.set_index(['tarea','id_run_name'],inplace=True)
top5 = (
    df_results_grid_actions.groupby(level="tarea")
      .apply(lambda g: g.sort_values("reward", ascending=False).head(5))
)

# Eliminar el nivel adicional que introduce groupby+apply
top5.index = top5.index.droplevel(0)

top5
# Out:
#                                  iteration      reward  max_reward  \
# tarea    id_run_name
# Command5 ppo_random_command5_11       1500  148.359473  820.291809
#          ppo_random_command5_11       1200  116.045358  747.452820
#          ppo_random_command5_11       1300   98.483841  758.258545
#          ppo_random_command5_11        800   96.731036  564.745300
#          ppo_random_command5_11       1400   88.791428  773.788818
#
#                                  std_reward  num_envs_train  \
# tarea    id_run_name
# Command5 ppo_random_command5_11  164.720314            8196
#          ppo_random_command5_11  155.794705            8196
#          ppo_random_command5_11  140.834091            8196
#          ppo_random_command5_11  118.674819            8196
#          ppo_random_command5_11  146.511362            8196
#
#                                  mean_Episode_Reward/alive  \
# tarea    id_run_name
# Command5 ppo_random_command5_11                   2.645218
#          ppo_random_command5_11                   2.575988
#          ppo_random_command5_11                   2.726593
#          ppo_random_command5_11                   1.936564
#          ppo_random_command5_11                   2.175446
#
#                                  mean_Episode_Reward/action_rate  \
# tarea    id_run_name
# Command5 ppo_random_command5_11                        -0.170349
#          ppo_random_command5_11                        -0.140482
#          ppo_random_command5_11                        -0.160750
#          ppo_random_command5_11                        -0.077961
#          ppo_random_command5_11                        -0.136057
#
#                                  mean_Episode_Reward/terminating  \
# tarea    id_run_name
# Command5 ppo_random_command5_11                        -0.019928
#          ppo_random_command5_11                        -0.019937
#          ppo_random_command5_11                        -0.019934
#          ppo_random_command5_11                        -0.019991
#          ppo_random_command5_11                        -0.019967
#
#                                  mean_Episode_Reward/rew_pos_diff  \
# tarea    id_run_name
# Command5 ppo_random_command5_11                         -1.648187
#          ppo_random_command5_11                         -1.556682
#          ppo_random_command5_11                         -1.733619
#          ppo_random_command5_11                         -1.186707
#          ppo_random_command5_11                         -1.334910
#
#                                  mean_Episode_Reward/rew_pos_diff_fine_grained  \
# tarea    id_run_name
# Command5 ppo_random_command5_11                                       0.961597
#          ppo_random_command5_11                                       0.979989
#          ppo_random_command5_11                                       0.983936
#          ppo_random_command5_11                                       0.703882
#          ppo_random_command5_11                                       0.796941
#
#                                  ...  \
# tarea    id_run_name             ...
# Command5 ppo_random_command5_11  ...
#          ppo_random_command5_11  ...
#          ppo_random_command5_11  ...
#          ppo_random_command5_11  ...
#          ppo_random_command5_11  ...
#
#                                  mean_Episode_Reward/rew_ang_vel_z_diff_fine_grained  \
# tarea    id_run_name
# Command5 ppo_random_command5_11                                           0.108495
#          ppo_random_command5_11                                           0.102867
#          ppo_random_command5_11                                           0.108917
#          ppo_random_command5_11                                           0.076896
#          ppo_random_command5_11                                           0.087503
#
#                                  mean_Episode_Reward/rew_roll_diff  \
# tarea    id_run_name
# Command5 ppo_random_command5_11                          -0.022003
#          ppo_random_command5_11                          -0.021002
#          ppo_random_command5_11                          -0.021859
#          ppo_random_command5_11                          -0.013668
#          ppo_random_command5_11                          -0.018389
#
#                                  mean_Episode_Reward/rew_roll_diff_fine_grained  \
# tarea    id_run_name
# Command5 ppo_random_command5_11                                        0.060470
#          ppo_random_command5_11                                        0.058830
#          ppo_random_command5_11                                        0.063690
#          ppo_random_command5_11                                        0.050434
#          ppo_random_command5_11                                        0.048583
#
#                                  mean_Episode_Reward/rew_pitch_diff  \
# tarea    id_run_name
# Command5 ppo_random_command5_11                           -0.015581
#          ppo_random_command5_11                           -0.016021
#          ppo_random_command5_11                           -0.017357
#          ppo_random_command5_11                           -0.012553
#          ppo_random_command5_11                           -0.013517
#
#                                  mean_Episode_Reward/rew_pitch_diff_fine_grained  \
# tarea    id_run_name
# Command5 ppo_random_command5_11                                         0.081116
#          ppo_random_command5_11                                         0.073842
#          ppo_random_command5_11                                         0.078244
#          ppo_random_command5_11                                         0.052967
#          ppo_random_command5_11                                         0.063434
#
#                                  mean_Episode_Reward/rew_heading_alignment_fine_grained  \
# tarea    id_run_name
# Command5 ppo_random_command5_11                                           0.318173
#          ppo_random_command5_11                                           0.274126
#          ppo_random_command5_11                                           0.322139
#          ppo_random_command5_11                                           0.179734
#          ppo_random_command5_11                                           0.239702
#
#                                  mean_Episode_Termination/time_out  \
# tarea    id_run_name
# Command5 ppo_random_command5_11                           0.003009
#          ppo_random_command5_11                           0.002590
#          ppo_random_command5_11                           0.003723
#          ppo_random_command5_11                           0.000429
#          ppo_random_command5_11                           0.001653
#
#                                  mean_Episode_Termination/below_min_altitude  \
# tarea    id_run_name
# Command5 ppo_random_command5_11                                     0.103489
#          ppo_random_command5_11                                     0.152105
#          ppo_random_command5_11                                     0.121192
#          ppo_random_command5_11                                     0.192017
#          ppo_random_command5_11                                     0.094360
#
#                                  mean_Episode_Termination/bad_attitude  \
# tarea    id_run_name
# Command5 ppo_random_command5_11                               0.893503
#          ppo_random_command5_11                               0.845305
#          ppo_random_command5_11                               0.875084
#          ppo_random_command5_11                               0.807554
#          ppo_random_command5_11                               0.903987
#
#                                  mean_Episode_Termination/safety_shutdown
# tarea    id_run_name
# Command5 ppo_random_command5_11                                       0.0
#          ppo_random_command5_11                                       0.0
#          ppo_random_command5_11                                       0.0
#          ppo_random_command5_11                                       0.0
#          ppo_random_command5_11                                       0.0
#
# [5 rows x 23 columns]

# %%
mean_rewards = df_results_grid_actions.groupby(["tarea", "id_run_name"])["reward"].mean()

for tarea, subdf in mean_rewards.groupby(level="tarea"):
    plt.figure(figsize=(12,5))
    
    # Convertir a DataFrame y resetear index para graficar
    plot_df = subdf.reset_index()
    plot_df = plot_df.sort_values("reward", ascending=False)
    
    plt.bar(plot_df["id_run_name"], plot_df["reward"])
    plt.title(f"Reward media por modelo - {tarea}")
    plt.xlabel("id_run_name")
    plt.ylabel("Reward media")
    plt.xticks(rotation=90)
    plt.tight_layout()
    plt.show()

# %%
df_callbacks = pd.read_csv(path_resultados+"/reward_best_models.csv",index_col='id_run_name')
top5_models = df_callbacks.nlargest(5,columns="reward")
top5_models
# Out:
#                         iteration      reward  max_reward  std_reward  \
# id_run_name
# ppo_random_command5_11       1289  154.030015  616.214417   170.69982
#
#                         num_envs_train  mean_Episode_Reward/alive  \
# id_run_name
# ppo_random_command5_11            8196                    2.90881
#
#                         mean_Episode_Reward/action_rate  \
# id_run_name
# ppo_random_command5_11                        -0.170342
#
#                         mean_Episode_Reward/terminating  \
# id_run_name
# ppo_random_command5_11                        -0.019911
#
#                         mean_Episode_Reward/rew_pos_diff  \
# id_run_name
# ppo_random_command5_11                         -1.788109
#
#                         mean_Episode_Reward/rew_pos_diff_fine_grained  ...  \
# id_run_name                                                            ...
# ppo_random_command5_11                                       1.092515  ...
#
#                         mean_Episode_Reward/rew_ang_vel_z_diff_fine_grained  \
# id_run_name
# ppo_random_command5_11                                           0.118949
#
#                         mean_Episode_Reward/rew_roll_diff  \
# id_run_name
# ppo_random_command5_11                          -0.023586
#
#                         mean_Episode_Reward/rew_roll_diff_fine_grained  \
# id_run_name
# ppo_random_command5_11                                        0.067315
#
#                         mean_Episode_Reward/rew_pitch_diff  \
# id_run_name
# ppo_random_command5_11                           -0.017664
#
#                         mean_Episode_Reward/rew_pitch_diff_fine_grained  \
# id_run_name
# ppo_random_command5_11                                         0.085878
#
#                         mean_Episode_Reward/rew_heading_alignment_fine_grained  \
# id_run_name
# ppo_random_command5_11                                           0.349344
#
#                         mean_Episode_Termination/time_out  \
# id_run_name
# ppo_random_command5_11                           0.005447
#
#                         mean_Episode_Termination/below_min_altitude  \
# id_run_name
# ppo_random_command5_11                                     0.144526
#
#                         mean_Episode_Termination/bad_attitude  \
# id_run_name
# ppo_random_command5_11                               0.850027
#
#                         mean_Episode_Termination/safety_shutdown
# id_run_name
# ppo_random_command5_11                                       0.0
#
# [1 rows x 23 columns]

# %% [markdown]
# Graficamos cómo fue el entrenamiento para los 5 mejores modelos según los callbacks:

# %%
import matplotlib.pyplot as plt
import numpy as np

# Aseguramos que `top5_auc` tenga 'tarea' e 'id_run_name' como columnas, no solo en el índice
df_callbacks = pd.read_csv(path_resultados+"/reward_best_models.csv",index_col='id_run_name')
top5_models = df_callbacks.nlargest(5,columns="reward")
top5_reset = top5_models.reset_index()
top5_reset["tarea"] = top5_reset["id_run_name"].apply(get_group)


# Convertir el índice jerárquico en columnas (para acceder a 'tarea' y 'id_run_name')
df_copy_reset = df_copy.reset_index()

# Unimos `top5_auc_reset` con `df_copy_reset` en las columnas comunes: 'tarea' y 'id_run_name'
merged_df = pd.merge(df_copy_reset, top5_reset[['tarea', 'id_run_name']], on=['tarea', 'id_run_name'], how='inner')

# Usamos una lista de colores para asignar un color diferente a cada modelo
colors = plt.cm.viridis(np.linspace(0, 1, len(merged_df['id_run_name'].unique())))

# Ahora, procedemos a graficar
for tarea, task_df in merged_df.groupby('tarea'):
    plt.figure(figsize=(10, 6))
    
    # Iteramos sobre los modelos (id_run_name) para esta tarea
    for i, (run_name, subdf) in enumerate(task_df.groupby('id_run_name')):
        # Graficamos la evolución de la recompensa a lo largo de las iteraciones
        plt.plot(subdf['iteration'], subdf['reward'], label=run_name, color=colors[i])
    
    plt.xlabel('Iteración')
    plt.ylabel('Reward')
    plt.title(f'Evolución de la Recompensa - Tarea: {tarea}')
    plt.legend(title="Modelos", bbox_to_anchor=(1.05, 1), loc='upper left')
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ``Cojo los 5 modelos mejores de todos de los callbacks``

# %%
import os
df_callbacks = pd.read_csv(path_resultados+"/reward_best_models.csv",index_col='id_run_name')
top5_models = df_callbacks.nlargest(5,columns="reward")

powershell_script_test = os.path.join(cfg_dir, "run_tests.ps1")

with open(powershell_script_test, "w") as f:
    f.write("$ErrorActionPreference = 'Stop'\n\n")
    
    for run_id, row in top5_models.iterrows():
        # Extraemos el número del id (ej: de 'ppo_random_hover_4' sacamos '4')
        experiment_number = run_id.split('_')[-1]
        
        # Construimos la ruta exacta del checkpoint
        # Nota: Asegúrate de que path_resultados termine en / o usar os.path.join
        checkpoint_path = f"{path_resultados}/best_model_{run_id}_{int(row['num_envs_train'])}.pt"
        f.write(f'Write-Host "Ejecutando Test final para Experimento {experiment_number}..."\n')
        
        # Usamos el experiment_number extraído para la tarea (--task)
        # Se añaden flags típicos de play.py: --num_envs 1 y se quita --headless para ver el visualizador
        f.write(f'& "{isaaclab_bat}" -p "{play_script}" '
                f'--task {id_task}-{experiment_number} '
                f'--num_envs 1 '
                f' --headless '
                f'--checkpoint "{checkpoint_path}"\n\n')
        
print(f"Script de test generado en: {powershell_script_test}")
# Out:
# Script de test generado en: C:/Users/Teresa/Documents/GitHub/navsim/isaac_lab/aerotaxi/env_command/env_9/grid_hiperparametros/cfg_files\run_tests.ps1

# %% [markdown]
# ### Test con 1 entorno

# %%
# Ejecuta el entrenamiento de forma automática
# !powershell -ExecutionPolicy Bypass -File "{powershell_script}"
import subprocess
import sys

# Ruta al script que generaste
powershell_script_path = powershell_script_test 

print(f"Iniciando ejecución de: {powershell_script_path}\n")

# Ejecutamos el proceso capturando la salida en tiempo real
process = subprocess.Popen(
    ["powershell.exe", "-ExecutionPolicy", "Bypass", "-File", powershell_script_path],
    stdout=subprocess.PIPE,
    stderr=subprocess.STDOUT, # Redirigimos errores a la salida estándar para verlos
    text=True,
    bufsize=1
)

# Leemos la salida línea a línea conforme se genera
try:
    for line in process.stdout:
        print(line, end="") # Imprime la salida de PowerShell en la celda
        sys.stdout.flush()   # Fuerza a Jupyter a mostrar la línea inmediatamente
except KeyboardInterrupt:
    process.kill()
    print("\nEntrenamiento cancelado por el usuario.")

process.wait()
print("\n--- Todos los experimentos de test han finalizado ---")
# Out:
# Iniciando ejecución de: C:/Users/Teresa/Documents/GitHub/navsim/isaac_lab/aerotaxi/env_command/env_9/grid_hiperparametros/cfg_files\run_tests.ps1
#
# Ejecutando Test final para Experimento 11...
# [INFO] Using python from: C:\Users\Teresa\miniconda3\envs\env_isaaclab\python.exe
# [INFO][AppLauncher]: Using device: cuda:0
# [INFO][AppLauncher]: Loading experience file: C:\Users\Teresa\miniconda3\envs\env_isaaclab\Lib\site-packages\isaaclab\apps\isaaclab.python.headless.kit
# Loading user config located at: 'c:/users/teresa/miniconda3/envs/env_isaaclab/lib/site-packages/isaacsim/kit/data/Kit/Isaac-Sim/5.1/user.config.json'
# [Info] [carb] Logging to file: c:/users/teresa/miniconda3/envs/env_isaaclab/lib/site-packages/isaacsim/kit/logs/Kit/Isaac-Sim/5.1/kit_20260205_114728.log
# 2026-02-05T10:47:28Z s] [Warning] [omni.usd_config.extension] Enable omni.materialx.libs extension to use MaterialX
# 2026-02-05T10:47:29Z s] [Warning] [carb] Acquiring non optional plugin interface which is not listed as dependency: [omni::physx::IPhysxBenchmarks v1.0] (plugin: <default plugin>), by client: omni.physics.physx.plugin. Add it to CARB_PLUGIN_IMPL_DEPS() macro of a client.
# 2026-02-05T10:47:29Z s] [Warning] [omni.isaac.dynamic_control] omni.isaac.dynamic_control is deprecated as of Isaac Sim 4.5. No action is needed from end-users.
# 2026-02-05T10:47:31Z [2,717ms] [Warning] [gpu.foundation.plugin] Skipping unsupported non-NVIDIA GPU: AMD Radeon(TM) Graphics
# 2026-02-05T10:47:31Z [2,718ms] [Warning] [gpu.foundation.plugin] Skipping unsupported non-NVIDIA GPU: AMD Radeon(TM) Graphics
#
# |---------------------------------------------------------------------------------------------|
# | Driver Version: 581.29        | Graphics API: D3D12
# |=============================================================================================|
# | GPU | Name                             | Active | LDA | GPU Memory | Vendor-ID | LUID       |
# |     |                                  |        |     |            | Device-ID | UUID       |
# |     |                                  |        |     |            | Bus-ID    |            |
# |---------------------------------------------------------------------------------------------|
# | 0   | NVIDIA GeForce RTX 5080          | Yes: 0 |     | 15889   MB | 10de      | fa570100.. |
# |     |                                  |        |     |            | 2c02      | 0          |
# |     |                                  |        |     |            | 1         |            |
# |---------------------------------------------------------------------------------------------|
# | 1   | AMD Radeon(TM) Graphics          |        |     | 1995    MB | 1002      | d7690100.. |
# |     |                                  |        |     |            | 13c0      | 0          |
# |     |                                  |        |     |            | N/A       |            |
# |=============================================================================================|
# | OS: Windows 11 Pro, Version: 10.0 (24H2), Build: 26100, Kernel: 10.0.26100.7623
# | Processor: AMD Ryzen 9 9950X 16-Core Processor
# | Cores: 16 | Logical Cores: 32
# |---------------------------------------------------------------------------------------------|
# | Total Memory (MB): 128627 | Free Memory: 94896
# | Total Page/Swap (MB): 136819 | Free Page/Swap: 92165
# |---------------------------------------------------------------------------------------------|
# C:\Users\Teresa\Documents\GitHub\navsim\isaac_lab\aerotaxi\env_command\env_9\flight_plan.py:29: UserWarning: Treat the new Tool classes introduced in v1.5 as experimental for now; the API and rcParam may change in future versions.
#   plt.rcParams["toolbar"] = "toolmanager"
# [INFO]: Parsing configuration from: aerotaxi.env_command.env_9.env:UAVEnvCfg
# [INFO]: Parsing configuration from: aerotaxi.env_command.env_9.grid_hiperparametros.cfg_files.ppo_random_command5_11_cfg:Command5PPORunnerCfg
# [INFO] Loading experiment from directory: C:\Users\Teresa\Documents\GitHub\navsim\isaac_lab\aerotaxi\env_command\env_9\logs\rsl_rl\command5
# Setting seed: 42
# [INFO]: Base environment:
# 	Environment device    : cuda:0
# 	Environment seed      : 42
# 	Physics step-size     : 0.005
# 	Rendering step-size   : 0.02
# 	Environment step-size : 0.02
# [INFO]: Time taken for scene creation : 1.011839 seconds
# [INFO]: Scene manager:  <class InteractiveScene>
# 	Number of environments: 1
# 	Environment spacing   : 100.0
# 	Source prim name      : /World/envs/env_0
# 	Global prim paths     : []
# 	Replicate physics     : False
# [INFO]: Starting the simulation. This may take a few seconds. Please wait...
# [INFO]: Time taken for simulation start : 0.251751 seconds
# [INFO] Command Manager:  <CommandManager> contains 1 active terms.
# +--------------------------------------+
# |         Active Command Terms         |
# +-------+-------------+----------------+
# | Index | Name        |      Type      |
# +-------+-------------+----------------+
# |   0   | vel_command | UAVcommandTerm |
# +-------+-------------+----------------+
#
# [INFO] Event Manager:  <EventManager> contains 1 active terms.
# +-----------------------------------+
# | Active Event Terms in Mode: 'reset' |
# +----------+------------------------+
# |  Index   | Name                   |
# +----------+------------------------+
# |    0     | reset_pos              |
# |    1     | randomize_mass         |
# |    2     | randomize_wind         |
# +----------+------------------------+
#
# [INFO] Recorder Manager:  <RecorderManager> contains 0 active terms.
# +---------------------+
# | Active Recorder Terms |
# +-----------+---------+
# |   Index   | Name    |
# +-----------+---------+
# +-----------+---------+
#
# [INFO] Action Manager:  <ActionManager> contains 1 active terms.
# +-----------------------------------+
# |   Active Action Terms (shape: 4)  |
# +--------+-------------+------------+
# | Index  | Name        |  Dimension |
# +--------+-------------+------------+
# |   0    | rotors_vel  |          4 |
# +--------+-------------+------------+
#
# [INFO] Observation Manager: <ObservationManager> contains 1 groups.
# +----------------------------------------------------+
# | Active Observation Terms in Group: 'policy' (shape: (11,)) |
# +---------------+--------------------+---------------+
# |     Index     | Name               |     Shape     |
# +---------------+--------------------+---------------+
# |       0       | pos                |      (3,)     |
# |       1       | lin_vel            |      (3,)     |
# |       2       | ang_vel            |      (3,)     |
# |       3       | roll               |      (1,)     |
# |       4       | pitch              |      (1,)     |
# +---------------+--------------------+---------------+
#
# [INFO] Termination Manager:  <TerminationManager> contains 4 active terms.
# +---------------------------------------+
# |        Active Termination Terms       |
# +-------+--------------------+----------+
# | Index | Name               | Time Out |
# +-------+--------------------+----------+
# |   0   | time_out           |   True   |
# |   1   | below_min_altitude |  False   |
# |   2   | bad_attitude       |  False   |
# |   3   | safety_shutdown    |  False   |
# +-------+--------------------+----------+
#
# [INFO] Reward Manager:  <RewardManager> contains 14 active terms.
# +-----------------------------------------------------+
# |                 Active Reward Terms                 |
# +-------+------------------------------------+--------+
# | Index | Name                               | Weight |
# +-------+------------------------------------+--------+
# |   0   | alive                              |   15.0 |
# |   1   | action_rate                        |   -0.1 |
# |   2   | terminating                        |  -50.0 |
# |   3   | rew_pos_diff                       |   -0.5 |
# |   4   | rew_pos_diff_fine_grained          |   15.0 |
# |   5   | rew_lin_vel_diff                   |   -0.1 |
# |   6   | rew_lin_vel_diff_fine_grained      |    2.0 |
# |   7   | rew_ang_vel_z_diff                 |   -1.0 |
# |   8   | rew_ang_vel_z_diff_fine_grained    |    1.0 |
# |   9   | rew_roll_diff                      |   -0.5 |
# |   10  | rew_roll_diff_fine_grained         |    1.0 |
# |   11  | rew_pitch_diff                     |   -0.5 |
# |   12  | rew_pitch_diff_fine_grained        |    1.0 |
# |   13  | rew_heading_alignment_fine_grained |    5.0 |
# +-------+------------------------------------+--------+
#
# [INFO] Curriculum Manager:  <CurriculumManager> contains 0 active terms.
# +----------------------+
# | Active Curriculum Terms |
# +-----------+----------+
# |   Index   | Name     |
# +-----------+----------+
# +-----------+----------+
#
# [INFO]: Completed setting up the environment...
# 2026-02-05T10:47:33Z [5,684ms] [Warning] [omni.physx.fabric.plugin] FabricManager::initializePointInstancer mismatched prototypes on point instancer: /Visuals/target_commands.
# [INFO]: Loading model checkpoint from: C:\Users\Teresa\Documents\GitHub\navsim\tmp\tmpTeresa\resultados_grid_command_v5\best_model_ppo_random_command5_11_8196.pt
# C:\Users\Teresa\miniconda3\envs\env_isaaclab\Lib\site-packages\rsl_rl\utils\utils.py:244: UserWarning: The observation configuration dictionary 'obs_groups' must contain the 'policy' key. As an observation group with the name 'policy' was found, this is assumed to be the observation set. Consider adding the 'policy' key to the 'obs_groups' dictionary for clarity. This behavior will be removed in a future version.
#   warnings.warn(
# C:\Users\Teresa\miniconda3\envs\env_isaaclab\Lib\site-packages\rsl_rl\utils\utils.py:290: UserWarning: The observation configuration dictionary 'obs_groups' must contain the 'critic' key. As the configuration for 'critic' is missing, the observations from the 'policy' set are used. Consider adding the 'critic' key to the 'obs_groups' dictionary for clarity. This behavior will be removed in a future version.
#   warnings.warn(
# --------------------------------------------------------------------------------
# Resolved observation sets:
# 	 policy :  ['policy']
# 	 critic :  ['policy']
# --------------------------------------------------------------------------------
# Actor MLP: MLP(
#   (0): Linear(in_features=11, out_features=64, bias=True)
#   (1): ELU(alpha=1.0)
#   (2): Linear(in_features=64, out_features=64, bias=True)
#   (3): ELU(alpha=1.0)
#   (4): Linear(in_features=64, out_features=4, bias=True)
# )
# Critic MLP: MLP(
#   (0): Linear(in_features=11, out_features=128, bias=True)
#   (1): ELU(alpha=1.0)
#   (2): Linear(in_features=128, out_features=128, bias=True)
#   (3): ELU(alpha=1.0)
#   (4): Linear(in_features=128, out_features=1, bias=True)
# )
#
# --- Todos los experimentos de test han finalizado ---

# %%
df_callbacks = pd.read_csv(path_resultados+"/reward_best_models.csv",index_col='id_run_name')
top5_models = df_callbacks.nlargest(5,columns="reward")

# %%
df_rewards_play = pd.read_csv(path_resultados+'/rewards_play_PPO.csv')

# %% [markdown]
# ### Test con 64 entornos

# %%
import os
df_callbacks = pd.read_csv(path_resultados+"/reward_best_models.csv",index_col='id_run_name')
top5_models = df_callbacks.nlargest(5,columns="reward")

powershell_script_test_2 = os.path.join(cfg_dir, "run_tests_2.ps1")

with open(powershell_script_test_2, "w") as f:
    f.write("$ErrorActionPreference = 'Stop'\n\n")
    
    for run_id, row in top5_models.iterrows():
        # Extraemos el número del id (ej: de 'ppo_random_hover_4' sacamos '4')
        experiment_number = run_id.split('_')[-1]
        
        # Construimos la ruta exacta del checkpoint
        # Nota: Asegúrate de que path_resultados termine en / o usar os.path.join
        checkpoint_path = f"{path_resultados}/best_model_{run_id}_{int(row['num_envs_train'])}.pt"
        f.write(f'Write-Host "Ejecutando Test final para Experimento {experiment_number}..."\n')
        
        # Usamos el experiment_number extraído para la tarea (--task)
        # Se añaden flags típicos de play.py: --num_envs 1 y se quita --headless para ver el visualizador
        f.write(f'& "{isaaclab_bat}" -p "{play_script}" '
                f'--task {id_task}-{experiment_number} '
                f'--num_envs 64 '
                f' --headless '
                f'--checkpoint "{checkpoint_path}"\n\n')
        
print(f"Script de test generado en: {powershell_script_test_2}")
# Out:
# Script de test generado en: C:/Users/Teresa/Documents/GitHub/navsim/isaac_lab/aerotaxi/env_command/env_9/grid_hiperparametros/cfg_files\run_tests_2.ps1

# %%
# Ejecuta el entrenamiento de forma automática
# !powershell -ExecutionPolicy Bypass -File "{powershell_script}"
import subprocess
import sys

# Ruta al script que generaste
powershell_script_path = powershell_script_test_2 

print(f"Iniciando ejecución de: {powershell_script_path}\n")

# Ejecutamos el proceso capturando la salida en tiempo real
process = subprocess.Popen(
    ["powershell.exe", "-ExecutionPolicy", "Bypass", "-File", powershell_script_path],
    stdout=subprocess.PIPE,
    stderr=subprocess.STDOUT, # Redirigimos errores a la salida estándar para verlos
    text=True,
    bufsize=1
)

# Leemos la salida línea a línea conforme se genera
try:
    for line in process.stdout:
        print(line, end="") # Imprime la salida de PowerShell en la celda
        sys.stdout.flush()   # Fuerza a Jupyter a mostrar la línea inmediatamente
except KeyboardInterrupt:
    process.kill()
    print("\nEntrenamiento cancelado por el usuario.")

process.wait()
print("\n--- Todos los experimentos de test han finalizado ---")
# Out:
# Iniciando ejecución de: C:/Users/Teresa/Documents/GitHub/navsim/isaac_lab/aerotaxi/env_command/env_9/grid_hiperparametros/cfg_files\run_tests_2.ps1
#
# Ejecutando Test final para Experimento 11...
# [INFO] Using python from: C:\Users\Teresa\miniconda3\envs\env_isaaclab\python.exe
# [INFO][AppLauncher]: Using device: cuda:0
# [INFO][AppLauncher]: Loading experience file: C:\Users\Teresa\miniconda3\envs\env_isaaclab\Lib\site-packages\isaaclab\apps\isaaclab.python.headless.kit
# Loading user config located at: 'c:/users/teresa/miniconda3/envs/env_isaaclab/lib/site-packages/isaacsim/kit/data/Kit/Isaac-Sim/5.1/user.config.json'
# [Info] [carb] Logging to file: c:/users/teresa/miniconda3/envs/env_isaaclab/lib/site-packages/isaacsim/kit/logs/Kit/Isaac-Sim/5.1/kit_20260205_115133.log
# 2026-02-05T10:51:34Z s] [Warning] [omni.usd_config.extension] Enable omni.materialx.libs extension to use MaterialX
# 2026-02-05T10:51:34Z s] [Warning] [carb] Acquiring non optional plugin interface which is not listed as dependency: [omni::physx::IPhysxBenchmarks v1.0] (plugin: <default plugin>), by client: omni.physics.physx.plugin. Add it to CARB_PLUGIN_IMPL_DEPS() macro of a client.
# 2026-02-05T10:51:34Z s] [Warning] [omni.isaac.dynamic_control] omni.isaac.dynamic_control is deprecated as of Isaac Sim 4.5. No action is needed from end-users.
# 2026-02-05T10:51:36Z [2,374ms] [Warning] [gpu.foundation.plugin] Skipping unsupported non-NVIDIA GPU: AMD Radeon(TM) Graphics
# 2026-02-05T10:51:36Z [2,375ms] [Warning] [gpu.foundation.plugin] Skipping unsupported non-NVIDIA GPU: AMD Radeon(TM) Graphics
#
# |---------------------------------------------------------------------------------------------|
# | Driver Version: 581.29        | Graphics API: D3D12
# |=============================================================================================|
# | GPU | Name                             | Active | LDA | GPU Memory | Vendor-ID | LUID       |
# |     |                                  |        |     |            | Device-ID | UUID       |
# |     |                                  |        |     |            | Bus-ID    |            |
# |---------------------------------------------------------------------------------------------|
# | 0   | NVIDIA GeForce RTX 5080          | Yes: 0 |     | 15889   MB | 10de      | fa570100.. |
# |     |                                  |        |     |            | 2c02      | 0          |
# |     |                                  |        |     |            | 1         |            |
# |---------------------------------------------------------------------------------------------|
# | 1   | AMD Radeon(TM) Graphics          |        |     | 1995    MB | 1002      | d7690100.. |
# |     |                                  |        |     |            | 13c0      | 0          |
# |     |                                  |        |     |            | N/A       |            |
# |=============================================================================================|
# | OS: Windows 11 Pro, Version: 10.0 (24H2), Build: 26100, Kernel: 10.0.26100.7623
# | Processor: AMD Ryzen 9 9950X 16-Core Processor
# | Cores: 16 | Logical Cores: 32
# |---------------------------------------------------------------------------------------------|
# | Total Memory (MB): 128627 | Free Memory: 94331
# | Total Page/Swap (MB): 136819 | Free Page/Swap: 91707
# |---------------------------------------------------------------------------------------------|
# C:\Users\Teresa\Documents\GitHub\navsim\isaac_lab\aerotaxi\env_command\env_9\flight_plan.py:29: UserWarning: Treat the new Tool classes introduced in v1.5 as experimental for now; the API and rcParam may change in future versions.
#   plt.rcParams["toolbar"] = "toolmanager"
# [INFO]: Parsing configuration from: aerotaxi.env_command.env_9.env:UAVEnvCfg
# [INFO]: Parsing configuration from: aerotaxi.env_command.env_9.grid_hiperparametros.cfg_files.ppo_random_command5_11_cfg:Command5PPORunnerCfg
# [INFO] Loading experiment from directory: C:\Users\Teresa\Documents\GitHub\navsim\isaac_lab\aerotaxi\env_command\env_9\logs\rsl_rl\command5
# Setting seed: 42
# [INFO]: Base environment:
# 	Environment device    : cuda:0
# 	Environment seed      : 42
# 	Physics step-size     : 0.005
# 	Rendering step-size   : 0.02
# 	Environment step-size : 0.02
# [INFO]: Time taken for scene creation : 1.099795 seconds
# [INFO]: Scene manager:  <class InteractiveScene>
# 	Number of environments: 64
# 	Environment spacing   : 100.0
# 	Source prim name      : /World/envs/env_0
# 	Global prim paths     : []
# 	Replicate physics     : False
# [INFO]: Starting the simulation. This may take a few seconds. Please wait...
# [INFO]: Time taken for simulation start : 0.282446 seconds
# [INFO] Command Manager:  <CommandManager> contains 1 active terms.
# +--------------------------------------+
# |         Active Command Terms         |
# +-------+-------------+----------------+
# | Index | Name        |      Type      |
# +-------+-------------+----------------+
# |   0   | vel_command | UAVcommandTerm |
# +-------+-------------+----------------+
#
# [INFO] Event Manager:  <EventManager> contains 1 active terms.
# +-----------------------------------+
# | Active Event Terms in Mode: 'reset' |
# +----------+------------------------+
# |  Index   | Name                   |
# +----------+------------------------+
# |    0     | reset_pos              |
# |    1     | randomize_mass         |
# |    2     | randomize_wind         |
# +----------+------------------------+
#
# [INFO] Recorder Manager:  <RecorderManager> contains 0 active terms.
# +---------------------+
# | Active Recorder Terms |
# +-----------+---------+
# |   Index   | Name    |
# +-----------+---------+
# +-----------+---------+
#
# [INFO] Action Manager:  <ActionManager> contains 1 active terms.
# +-----------------------------------+
# |   Active Action Terms (shape: 4)  |
# +--------+-------------+------------+
# | Index  | Name        |  Dimension |
# +--------+-------------+------------+
# |   0    | rotors_vel  |          4 |
# +--------+-------------+------------+
#
# [INFO] Observation Manager: <ObservationManager> contains 1 groups.
# +----------------------------------------------------+
# | Active Observation Terms in Group: 'policy' (shape: (11,)) |
# +---------------+--------------------+---------------+
# |     Index     | Name               |     Shape     |
# +---------------+--------------------+---------------+
# |       0       | pos                |      (3,)     |
# |       1       | lin_vel            |      (3,)     |
# |       2       | ang_vel            |      (3,)     |
# |       3       | roll               |      (1,)     |
# |       4       | pitch              |      (1,)     |
# +---------------+--------------------+---------------+
#
# [INFO] Termination Manager:  <TerminationManager> contains 4 active terms.
# +---------------------------------------+
# |        Active Termination Terms       |
# +-------+--------------------+----------+
# | Index | Name               | Time Out |
# +-------+--------------------+----------+
# |   0   | time_out           |   True   |
# |   1   | below_min_altitude |  False   |
# |   2   | bad_attitude       |  False   |
# |   3   | safety_shutdown    |  False   |
# +-------+--------------------+----------+
#
# [INFO] Reward Manager:  <RewardManager> contains 14 active terms.
# +-----------------------------------------------------+
# |                 Active Reward Terms                 |
# +-------+------------------------------------+--------+
# | Index | Name                               | Weight |
# +-------+------------------------------------+--------+
# |   0   | alive                              |   15.0 |
# |   1   | action_rate                        |   -0.1 |
# |   2   | terminating                        |  -50.0 |
# |   3   | rew_pos_diff                       |   -0.5 |
# |   4   | rew_pos_diff_fine_grained          |   15.0 |
# |   5   | rew_lin_vel_diff                   |   -0.1 |
# |   6   | rew_lin_vel_diff_fine_grained      |    2.0 |
# |   7   | rew_ang_vel_z_diff                 |   -1.0 |
# |   8   | rew_ang_vel_z_diff_fine_grained    |    1.0 |
# |   9   | rew_roll_diff                      |   -0.5 |
# |   10  | rew_roll_diff_fine_grained         |    1.0 |
# |   11  | rew_pitch_diff                     |   -0.5 |
# |   12  | rew_pitch_diff_fine_grained        |    1.0 |
# |   13  | rew_heading_alignment_fine_grained |    5.0 |
# +-------+------------------------------------+--------+
#
# [INFO] Curriculum Manager:  <CurriculumManager> contains 0 active terms.
# +----------------------+
# | Active Curriculum Terms |
# +-----------+----------+
# |   Index   | Name     |
# +-----------+----------+
# +-----------+----------+
#
# [INFO]: Completed setting up the environment...
# 2026-02-05T10:51:39Z [5,393ms] [Warning] [omni.physx.fabric.plugin] FabricManager::initializePointInstancer mismatched prototypes on point instancer: /Visuals/target_commands.
# [INFO]: Loading model checkpoint from: C:\Users\Teresa\Documents\GitHub\navsim\tmp\tmpTeresa\resultados_grid_command_v5\best_model_ppo_random_command5_11_8196.pt
# C:\Users\Teresa\miniconda3\envs\env_isaaclab\Lib\site-packages\rsl_rl\utils\utils.py:244: UserWarning: The observation configuration dictionary 'obs_groups' must contain the 'policy' key. As an observation group with the name 'policy' was found, this is assumed to be the observation set. Consider adding the 'policy' key to the 'obs_groups' dictionary for clarity. This behavior will be removed in a future version.
#   warnings.warn(
# C:\Users\Teresa\miniconda3\envs\env_isaaclab\Lib\site-packages\rsl_rl\utils\utils.py:290: UserWarning: The observation configuration dictionary 'obs_groups' must contain the 'critic' key. As the configuration for 'critic' is missing, the observations from the 'policy' set are used. Consider adding the 'critic' key to the 'obs_groups' dictionary for clarity. This behavior will be removed in a future version.
#   warnings.warn(
# --------------------------------------------------------------------------------
# Resolved observation sets:
# 	 policy :  ['policy']
# 	 critic :  ['policy']
# --------------------------------------------------------------------------------
# Actor MLP: MLP(
#   (0): Linear(in_features=11, out_features=64, bias=True)
#   (1): ELU(alpha=1.0)
#   (2): Linear(in_features=64, out_features=64, bias=True)
#   (3): ELU(alpha=1.0)
#   (4): Linear(in_features=64, out_features=4, bias=True)
# )
# Critic MLP: MLP(
#   (0): Linear(in_features=11, out_features=128, bias=True)
#   (1): ELU(alpha=1.0)
#   (2): Linear(in_features=128, out_features=128, bias=True)
#   (3): ELU(alpha=1.0)
#   (4): Linear(in_features=128, out_features=1, bias=True)
# )
#
# --- Todos los experimentos de test han finalizado ---

# %% [markdown]
# #### Test con 256 entornos

# %%
import os
df_callbacks = pd.read_csv(path_resultados+"/reward_best_models.csv",index_col='id_run_name')
top5_models = df_callbacks.nlargest(5,columns="reward")

powershell_script_test_3 = os.path.join(cfg_dir, "run_tests_3.ps1")

with open(powershell_script_test_3, "w") as f:
    f.write("$ErrorActionPreference = 'Stop'\n\n")
    
    for run_id, row in top5_models.iterrows():
        # Extraemos el número del id (ej: de 'ppo_random_hover_4' sacamos '4')
        experiment_number = run_id.split('_')[-1]
        
        # Construimos la ruta exacta del checkpoint
        # Nota: Asegúrate de que path_resultados termine en / o usar os.path.join
        checkpoint_path = f"{path_resultados}/best_model_{run_id}_{int(row['num_envs_train'])}.pt"
        f.write(f'Write-Host "Ejecutando Test final para Experimento {experiment_number}..."\n')
        
        # Usamos el experiment_number extraído para la tarea (--task)
        # Se añaden flags típicos de play.py: --num_envs 1 y se quita --headless para ver el visualizador
        f.write(f'& "{isaaclab_bat}" -p "{play_script}" '
                f'--task {id_task}-{experiment_number} '
                f'--num_envs 256 '
                f' --headless '
                f'--checkpoint "{checkpoint_path}"\n\n')
        
print(f"Script de test generado en: {powershell_script_test_3}")
# Out:
# Script de test generado en: C:/Users/Teresa/Documents/GitHub/navsim/isaac_lab/aerotaxi/env_command/env_9/grid_hiperparametros/cfg_files\run_tests_3.ps1

# %%
# Ejecuta el entrenamiento de forma automática
# !powershell -ExecutionPolicy Bypass -File "{powershell_script}"
import subprocess
import sys

# Ruta al script que generaste
powershell_script_path = powershell_script_test_3 

print(f"Iniciando ejecución de: {powershell_script_path}\n")

# Ejecutamos el proceso capturando la salida en tiempo real
process = subprocess.Popen(
    ["powershell.exe", "-ExecutionPolicy", "Bypass", "-File", powershell_script_path],
    stdout=subprocess.PIPE,
    stderr=subprocess.STDOUT, # Redirigimos errores a la salida estándar para verlos
    text=True,
    bufsize=1
)

# Leemos la salida línea a línea conforme se genera
try:
    for line in process.stdout:
        print(line, end="") # Imprime la salida de PowerShell en la celda
        sys.stdout.flush()   # Fuerza a Jupyter a mostrar la línea inmediatamente
except KeyboardInterrupt:
    process.kill()
    print("\nEntrenamiento cancelado por el usuario.")

process.wait()
print("\n--- Todos los experimentos de test han finalizado ---")
# Out:
# Iniciando ejecución de: C:/Users/Teresa/Documents/GitHub/navsim/isaac_lab/aerotaxi/env_command/env_9/grid_hiperparametros/cfg_files\run_tests_3.ps1
#
# Ejecutando Test final para Experimento 11...
# [INFO] Using python from: C:\Users\Teresa\miniconda3\envs\env_isaaclab\python.exe
# [INFO][AppLauncher]: Using device: cuda:0
# [INFO][AppLauncher]: Loading experience file: C:\Users\Teresa\miniconda3\envs\env_isaaclab\Lib\site-packages\isaaclab\apps\isaaclab.python.headless.kit
# Loading user config located at: 'c:/users/teresa/miniconda3/envs/env_isaaclab/lib/site-packages/isaacsim/kit/data/Kit/Isaac-Sim/5.1/user.config.json'
# [Info] [carb] Logging to file: c:/users/teresa/miniconda3/envs/env_isaaclab/lib/site-packages/isaacsim/kit/logs/Kit/Isaac-Sim/5.1/kit_20260205_115402.log
# 2026-02-05T10:54:03Z s] [Warning] [omni.usd_config.extension] Enable omni.materialx.libs extension to use MaterialX
# 2026-02-05T10:54:03Z s] [Warning] [carb] Acquiring non optional plugin interface which is not listed as dependency: [omni::physx::IPhysxBenchmarks v1.0] (plugin: <default plugin>), by client: omni.physics.physx.plugin. Add it to CARB_PLUGIN_IMPL_DEPS() macro of a client.
# 2026-02-05T10:54:03Z s] [Warning] [omni.isaac.dynamic_control] omni.isaac.dynamic_control is deprecated as of Isaac Sim 4.5. No action is needed from end-users.
# 2026-02-05T10:54:05Z [2,384ms] [Warning] [gpu.foundation.plugin] Skipping unsupported non-NVIDIA GPU: AMD Radeon(TM) Graphics
# 2026-02-05T10:54:05Z [2,385ms] [Warning] [gpu.foundation.plugin] Skipping unsupported non-NVIDIA GPU: AMD Radeon(TM) Graphics
#
# |---------------------------------------------------------------------------------------------|
# | Driver Version: 581.29        | Graphics API: D3D12
# |=============================================================================================|
# | GPU | Name                             | Active | LDA | GPU Memory | Vendor-ID | LUID       |
# |     |                                  |        |     |            | Device-ID | UUID       |
# |     |                                  |        |     |            | Bus-ID    |            |
# |---------------------------------------------------------------------------------------------|
# | 0   | NVIDIA GeForce RTX 5080          | Yes: 0 |     | 15889   MB | 10de      | fa570100.. |
# |     |                                  |        |     |            | 2c02      | 0          |
# |     |                                  |        |     |            | 1         |            |
# |---------------------------------------------------------------------------------------------|
# | 1   | AMD Radeon(TM) Graphics          |        |     | 1995    MB | 1002      | d7690100.. |
# |     |                                  |        |     |            | 13c0      | 0          |
# |     |                                  |        |     |            | N/A       |            |
# |=============================================================================================|
# | OS: Windows 11 Pro, Version: 10.0 (24H2), Build: 26100, Kernel: 10.0.26100.7623
# | Processor: AMD Ryzen 9 9950X 16-Core Processor
# | Cores: 16 | Logical Cores: 32
# |---------------------------------------------------------------------------------------------|
# | Total Memory (MB): 128627 | Free Memory: 94040
# | Total Page/Swap (MB): 136819 | Free Page/Swap: 91401
# |---------------------------------------------------------------------------------------------|
# C:\Users\Teresa\Documents\GitHub\navsim\isaac_lab\aerotaxi\env_command\env_9\flight_plan.py:29: UserWarning: Treat the new Tool classes introduced in v1.5 as experimental for now; the API and rcParam may change in future versions.
#   plt.rcParams["toolbar"] = "toolmanager"
# [INFO]: Parsing configuration from: aerotaxi.env_command.env_9.env:UAVEnvCfg
# [INFO]: Parsing configuration from: aerotaxi.env_command.env_9.grid_hiperparametros.cfg_files.ppo_random_command5_11_cfg:Command5PPORunnerCfg
# [INFO] Loading experiment from directory: C:\Users\Teresa\Documents\GitHub\navsim\isaac_lab\aerotaxi\env_command\env_9\logs\rsl_rl\command5
# Setting seed: 42
# [INFO]: Base environment:
# 	Environment device    : cuda:0
# 	Environment seed      : 42
# 	Physics step-size     : 0.005
# 	Rendering step-size   : 0.02
# 	Environment step-size : 0.02
# [INFO]: Time taken for scene creation : 1.113053 seconds
# [INFO]: Scene manager:  <class InteractiveScene>
# 	Number of environments: 256
# 	Environment spacing   : 100.0
# 	Source prim name      : /World/envs/env_0
# 	Global prim paths     : []
# 	Replicate physics     : False
# [INFO]: Starting the simulation. This may take a few seconds. Please wait...
# [INFO]: Time taken for simulation start : 0.381035 seconds
# [INFO] Command Manager:  <CommandManager> contains 1 active terms.
# +--------------------------------------+
# |         Active Command Terms         |
# +-------+-------------+----------------+
# | Index | Name        |      Type      |
# +-------+-------------+----------------+
# |   0   | vel_command | UAVcommandTerm |
# +-------+-------------+----------------+
#
# [INFO] Event Manager:  <EventManager> contains 1 active terms.
# +-----------------------------------+
# | Active Event Terms in Mode: 'reset' |
# +----------+------------------------+
# |  Index   | Name                   |
# +----------+------------------------+
# |    0     | reset_pos              |
# |    1     | randomize_mass         |
# |    2     | randomize_wind         |
# +----------+------------------------+
#
# [INFO] Recorder Manager:  <RecorderManager> contains 0 active terms.
# +---------------------+
# | Active Recorder Terms |
# +-----------+---------+
# |   Index   | Name    |
# +-----------+---------+
# +-----------+---------+
#
# [INFO] Action Manager:  <ActionManager> contains 1 active terms.
# +-----------------------------------+
# |   Active Action Terms (shape: 4)  |
# +--------+-------------+------------+
# | Index  | Name        |  Dimension |
# +--------+-------------+------------+
# |   0    | rotors_vel  |          4 |
# +--------+-------------+------------+
#
# [INFO] Observation Manager: <ObservationManager> contains 1 groups.
# +----------------------------------------------------+
# | Active Observation Terms in Group: 'policy' (shape: (11,)) |
# +---------------+--------------------+---------------+
# |     Index     | Name               |     Shape     |
# +---------------+--------------------+---------------+
# |       0       | pos                |      (3,)     |
# |       1       | lin_vel            |      (3,)     |
# |       2       | ang_vel            |      (3,)     |
# |       3       | roll               |      (1,)     |
# |       4       | pitch              |      (1,)     |
# +---------------+--------------------+---------------+
#
# [INFO] Termination Manager:  <TerminationManager> contains 4 active terms.
# +---------------------------------------+
# |        Active Termination Terms       |
# +-------+--------------------+----------+
# | Index | Name               | Time Out |
# +-------+--------------------+----------+
# |   0   | time_out           |   True   |
# |   1   | below_min_altitude |  False   |
# |   2   | bad_attitude       |  False   |
# |   3   | safety_shutdown    |  False   |
# +-------+--------------------+----------+
#
# [INFO] Reward Manager:  <RewardManager> contains 14 active terms.
# +-----------------------------------------------------+
# |                 Active Reward Terms                 |
# +-------+------------------------------------+--------+
# | Index | Name                               | Weight |
# +-------+------------------------------------+--------+
# |   0   | alive                              |   15.0 |
# |   1   | action_rate                        |   -0.1 |
# |   2   | terminating                        |  -50.0 |
# |   3   | rew_pos_diff                       |   -0.5 |
# |   4   | rew_pos_diff_fine_grained          |   15.0 |
# |   5   | rew_lin_vel_diff                   |   -0.1 |
# |   6   | rew_lin_vel_diff_fine_grained      |    2.0 |
# |   7   | rew_ang_vel_z_diff                 |   -1.0 |
# |   8   | rew_ang_vel_z_diff_fine_grained    |    1.0 |
# |   9   | rew_roll_diff                      |   -0.5 |
# |   10  | rew_roll_diff_fine_grained         |    1.0 |
# |   11  | rew_pitch_diff                     |   -0.5 |
# |   12  | rew_pitch_diff_fine_grained        |    1.0 |
# |   13  | rew_heading_alignment_fine_grained |    5.0 |
# +-------+------------------------------------+--------+
#
# [INFO] Curriculum Manager:  <CurriculumManager> contains 0 active terms.
# +----------------------+
# | Active Curriculum Terms |
# +-----------+----------+
# |   Index   | Name     |
# +-----------+----------+
# +-----------+----------+
#
# [INFO]: Completed setting up the environment...
# 2026-02-05T10:54:08Z [5,536ms] [Warning] [omni.physx.fabric.plugin] FabricManager::initializePointInstancer mismatched prototypes on point instancer: /Visuals/target_commands.
# [INFO]: Loading model checkpoint from: C:\Users\Teresa\Documents\GitHub\navsim\tmp\tmpTeresa\resultados_grid_command_v5\best_model_ppo_random_command5_11_8196.pt
# C:\Users\Teresa\miniconda3\envs\env_isaaclab\Lib\site-packages\rsl_rl\utils\utils.py:244: UserWarning: The observation configuration dictionary 'obs_groups' must contain the 'policy' key. As an observation group with the name 'policy' was found, this is assumed to be the observation set. Consider adding the 'policy' key to the 'obs_groups' dictionary for clarity. This behavior will be removed in a future version.
#   warnings.warn(
# C:\Users\Teresa\miniconda3\envs\env_isaaclab\Lib\site-packages\rsl_rl\utils\utils.py:290: UserWarning: The observation configuration dictionary 'obs_groups' must contain the 'critic' key. As the configuration for 'critic' is missing, the observations from the 'policy' set are used. Consider adding the 'critic' key to the 'obs_groups' dictionary for clarity. This behavior will be removed in a future version.
#   warnings.warn(
# --------------------------------------------------------------------------------
# Resolved observation sets:
# 	 policy :  ['policy']
# 	 critic :  ['policy']
# --------------------------------------------------------------------------------
# Actor MLP: MLP(
#   (0): Linear(in_features=11, out_features=64, bias=True)
#   (1): ELU(alpha=1.0)
#   (2): Linear(in_features=64, out_features=64, bias=True)
#   (3): ELU(alpha=1.0)
#   (4): Linear(in_features=64, out_features=4, bias=True)
# )
# Critic MLP: MLP(
#   (0): Linear(in_features=11, out_features=128, bias=True)
#   (1): ELU(alpha=1.0)
#   (2): Linear(in_features=128, out_features=128, bias=True)
#   (3): ELU(alpha=1.0)
#   (4): Linear(in_features=128, out_features=1, bias=True)
# )
#
# --- Todos los experimentos de test han finalizado ---

# %%
import pandas as pd

df_train = top5_models.copy()
if df_train.index.name == 'id_run_name':
    df_train = df_train.reset_index()

df_train = df_train.rename(columns={
    'reward': 'reward_train',
    'max_reward': 'max_reward_train',
    'std_reward': 'std_train'
})

df_test = df_rewards_play.copy()

df_test = pd.read_csv(path_resultados+'/rewards_play_PPO.csv')
df_test = df_test.rename(columns={
    'reward': 'reward_test',
    'max_reward': 'max_reward_test',
    'std': 'std_test'
})

df_final = pd.merge(
    df_train[['id_run_name', 'num_envs_train', 'reward_train', 'max_reward_train', 'std_train', 'iteration']], 
    df_test[['id_run_name', 'num_envs_test', 'reward_test', 'max_reward_test', 'std_test', 'checkpoint']], 
    on='id_run_name', 
    how='inner'
)

column_order = [
    'id_run_name',
    'num_envs_train',
    'num_envs_test',
    'reward_train', 'reward_test', 
    'max_reward_train', 'max_reward_test', 
    'std_train', 'std_test',
    'iteration'
]
df_final = df_final[column_order]

df_final = df_final.sort_values(by='id_run_name', ascending=False)

# %%
df_rewards_play = df_final.sort_values(by="id_run_name",ascending=False)
df_rewards_play = df_rewards_play.reset_index().drop(columns='index')

df_final = df_rewards_play.copy()

df_final['diff_rw_test_train'] = df_final['reward_test'] - df_final['reward_train']

df_final['diferencia(%)'] = (df_final['diff_rw_test_train'] / df_final['reward_train'].abs()) * 100

df_final['diferencia(%)'] = df_final['diferencia(%)'].apply(lambda x: f"{x:+.2f}%")

df_final
# Out:
#               id_run_name  num_envs_train  num_envs_test  reward_train  \
# 0  ppo_random_command5_11            8196              1    154.030015
# 1  ppo_random_command5_11            8196             64    154.030015
# 2  ppo_random_command5_11            8196             64    154.030015
# 3  ppo_random_command5_11            8196            256    154.030015
#
#    reward_test  max_reward_train  max_reward_test  std_train    std_test  \
# 0   223.073972        616.214417       373.655934  170.69982  150.581962
# 1   112.457990        616.214417       388.230930  170.69982  120.609010
# 2   112.457990        616.214417       388.230930  170.69982  120.609010
# 3   122.212913        616.214417       423.071395  170.69982  113.751531
#
#    iteration  diff_rw_test_train diferencia(%)
# 0       1289           69.043957       +44.83%
# 1       1289          -41.572025       -26.99%
# 2       1289          -41.572025       -26.99%
# 3       1289          -31.817102       -20.66%

# %% [markdown]
# Pruebas con un solo entorno: Vemos cómo se comporta la política para un único agente en una prueba aleatoria.

# %%
df_final[df_final['num_envs_test'] == 1].sort_values(by='reward_test',ascending=False)
# Out:
#               id_run_name  num_envs_train  num_envs_test  reward_train  \
# 0  ppo_random_command5_11            8196              1    154.030015
#
#    reward_test  max_reward_train  max_reward_test  std_train    std_test  \
# 0   223.073972        616.214417       373.655934  170.69982  150.581962
#
#    iteration  diff_rw_test_train diferencia(%)
# 0       1289           69.043957       +44.83%

# %% [markdown]
# ``Interpretación``: Vemos que el modelo 38 se ha estampado en la prueba aleatoria, así que ese modelo no debería usarse para ninguna transferencia real.

# %% [markdown]
# Pruebas con varios entornos: Vemos cómo se comporta la política en múltiples entornos (varias pruebas simuladas en paralelo), teniendo en cuenta cuál es la desviación de cada uno en test, lo que nos permite inferir si la recompensa es estable para todas las pruebas.

# %%
df_final[df_final['num_envs_test'] != 1].sort_values(by='std_test',ascending=True).reset_index().drop(columns="index")
# Out:
#               id_run_name  num_envs_train  num_envs_test  reward_train  \
# 0  ppo_random_command5_11            8196            256    154.030015
# 1  ppo_random_command5_11            8196             64    154.030015
# 2  ppo_random_command5_11            8196             64    154.030015
#
#    reward_test  max_reward_train  max_reward_test  std_train    std_test  \
# 0   122.212913        616.214417       423.071395  170.69982  113.751531
# 1   112.457990        616.214417       388.230930  170.69982  120.609010
# 2   112.457990        616.214417       388.230930  170.69982  120.609010
#
#    iteration  diff_rw_test_train diferencia(%)
# 0       1289          -31.817102       -20.66%
# 1       1289          -41.572025       -26.99%
# 2       1289          -41.572025       -26.99%

# %% [markdown]
# pruebas:

# %% [markdown]
# C:/Users/Teresa/Desktop/RuralData/IsaacLab/IsaacLab/isaaclab.bat -p C:/Users/Teresa/Documents/GitHub/navsim/isaac_lab/rl_v5_1_0/rsl_rl/train.py --task Isaac-Command5-Aerotaxi-RANDOM-11 --num_envs 8196 --headless
