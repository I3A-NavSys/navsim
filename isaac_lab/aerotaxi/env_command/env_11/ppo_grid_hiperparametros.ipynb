# %%
# Parámetros a configurar:
import os
experiment_name = "command7"
task_name = "Command7"
cfg_dir = "C:/Users/Teresa/Documents/GitHub/navsim/isaac_lab/aerotaxi/env_command/env_11/grid_hiperparametros/cfg_files"
path_resultados = "C:/Users/Teresa/Documents/GitHub/navsim/tmp/tmpTeresa/resultados_grid_command_v7"
isaaclab_bat = "C:/Users/Teresa/Desktop/RuralData/IsaacLab/IsaacLab/isaaclab.bat"
train_script = "C:/Users/Teresa/Documents/GitHub/navsim/isaac_lab/rl_v5_1_0/rsl_rl/train.py"
id_task = f"Isaac-{task_name}-Aerotaxi-RANDOM" # luego se le añade el número de task con el guión (Isaac-Command2-Aerotaxi-RANDOM-34)
play_script = "C:/Users/Teresa/Documents/GitHub/navsim/isaac_lab/rl_v5_1_0/rsl_rl/play.py"
num_iter = "4001"
num_steps_per_env = 100
powershell_script = os.path.join(cfg_dir, "run_all.ps1")

# el num_steps_per_env = 100 también está en el env, al final del todo, y deben tener el mismo valor
# Recuerda iniciar en el init todos los experimentos

# %%
import random
import os

# Si los directorios no existen (el último indicado), lo crea
os.makedirs(cfg_dir, exist_ok=True)
os.makedirs(path_resultados, exist_ok=True)
# Opciones de hiperparámetros
param_options = {
    "init_noise_std": [0.0, 0.1, 0.2, 0.5, 0.8, 1.0],
    "actor_hidden_dims": [[64, 64], [128, 128], [256, 256], [128, 64]],
    "critic_hidden_dims": [[64, 64], [128, 128], [256, 256]],
    "activation": ["relu", "tanh", "elu", "gelu"],
    "value_loss_coef": [0.5, 1.0, 2.0],
    "clip_param": [0.1, 0.2, 0.3],
    "entropy_coef": [0.0, 0.001, 0.01, 0.05],
    "num_learning_epochs": [4, 8, 12],
    "num_mini_batches": [2, 4, 8],
    "learning_rate": [5e-05, 1e-4, 3e-4, 1e-3, 3e-3],
    "gamma": [0.95, 0.98, 0.99],
    "lam": [0.90, 0.95, 0.97],
    "max_grad_norm": [0.5, 1.0, 2.0],
    "desired_kl": [0.005, 0.008, 0.01, 0.02],
}

num_trials = 35  # cantidad de configuraciones

cfg_files = []

for i in range(num_trials):
    run_name = f"ppo_random_{experiment_name}_{i+1}"
    sampled = {k: random.choice(v) for k, v in param_options.items()}

    # Convertir listas a string
    actor_dims = sampled["actor_hidden_dims"]
    critic_dims = sampled["critic_hidden_dims"]

    cfg_content = f"""
from isaaclab.utils import configclass
from isaaclab_rl.rsl_rl import RslRlOnPolicyRunnerCfg, RslRlPpoActorCriticCfg, RslRlPpoAlgorithmCfg

@configclass
class {task_name}PPORunnerCfg(RslRlOnPolicyRunnerCfg):
    num_steps_per_env = {num_steps_per_env} 
    max_iterations = {num_iter}
    save_interval = 100
    experiment_name = "{experiment_name}"
    run_name = "{run_name}"
    resume = False
    empirical_normalization = False
    csv_path_metrics = "{path_resultados}"
    callbacks = True
    policy = RslRlPpoActorCriticCfg(
        init_noise_std={sampled['init_noise_std']},
        actor_hidden_dims={actor_dims},
        critic_hidden_dims={critic_dims},
        activation="{sampled['activation']}",
    )
    algorithm = RslRlPpoAlgorithmCfg(
        value_loss_coef={sampled['value_loss_coef']},
        use_clipped_value_loss=True,
        clip_param={sampled['clip_param']},
        entropy_coef={sampled['entropy_coef']},
        num_learning_epochs={sampled['num_learning_epochs']},
        num_mini_batches={sampled['num_mini_batches']},
        learning_rate={sampled['learning_rate']},
        schedule="adaptive",
        gamma={sampled['gamma']},
        lam={sampled['lam']},
        desired_kl={sampled['desired_kl']},
        max_grad_norm={sampled['max_grad_norm']},
    )
"""
    cfg_path = os.path.join(cfg_dir, f"{run_name}_cfg.py")
    with open(cfg_path, "w") as f:
        f.write(cfg_content.strip())
    cfg_files.append((run_name, cfg_path))

# Crear archivo PowerShell para ejecutar todas las configuraciones
powershell_script = os.path.join(cfg_dir, "run_all.ps1")

num_envs =  [64, 128, 512, 1024, 2048, 4096, 8196] #número de entornos para train (paralelizados)

with open(powershell_script, "w") as f:
    f.write("$ErrorActionPreference = 'Stop'\n\n")
    j = 0
    for run_name, cfg_path in cfg_files:
        # Convertir path a módulo Python (reemplazar / y .py)
        num_envs_i = random.choice(num_envs)
        module_path = cfg_path.replace("/", ".").replace("\\", ".").replace(".py", "")
        f.write(f'Write-Host "Ejecutando {run_name}"\n')
        f.write(f'& "{isaaclab_bat}" -p "{train_script}" --task {id_task}-{j+1} --num_envs {num_envs_i} --headless \n\n')
        j += 1
print("Archivos de configuración generados y script PowerShell listo en:", powershell_script)
# Out:
# Archivos de configuración generados y script PowerShell listo en: C:/Users/Teresa/Documents/GitHub/navsim/isaac_lab/aerotaxi/env_command/env_11/grid_hiperparametros/cfg_files\run_all.ps1

# %%
# Ejecuta el entrenamiento de forma automática
# !powershell -ExecutionPolicy Bypass -File "{powershell_script}"
import subprocess
import sys

# Ruta al script que generaste
powershell_script_path = powershell_script 

print(f"Iniciando ejecución de: {powershell_script_path}\n")

# Ejecutamos el proceso capturando la salida en tiempo real
process = subprocess.Popen(
    ["powershell.exe", "-ExecutionPolicy", "Bypass", "-File", powershell_script_path],
    stdout=subprocess.PIPE,
    stderr=subprocess.STDOUT, # Redirigimos errores a la salida estándar para verlos
    text=True,
    bufsize=1
)

# Leemos la salida línea a línea conforme se genera
try:
    for line in process.stdout:
        print(line, end="") # Imprime la salida de PowerShell en la celda
        sys.stdout.flush()   # Fuerza a Jupyter a mostrar la línea inmediatamente
except KeyboardInterrupt:
    process.kill()
    print("\nEntrenamiento cancelado por el usuario.")

process.wait()
print("\n--- Todos los experimentos han finalizado ---")
# Out:
# Iniciando ejecución de: C:/Users/Teresa/Documents/GitHub/navsim/isaac_lab/aerotaxi/env_command/env_11/grid_hiperparametros/cfg_files\run_all.ps1
#
# Ejecutando ppo_random_command7_11
# [INFO] Using python from: C:\Users\Teresa\miniconda3\envs\env_isaaclab\python.exe
# [INFO][AppLauncher]: Using device: cuda:0
# [INFO][AppLauncher]: Loading experience file: C:\Users\Teresa\miniconda3\envs\env_isaaclab\Lib\site-packages\isaaclab\apps\isaaclab.python.headless.kit
# Loading user config located at: 'c:/users/teresa/miniconda3/envs/env_isaaclab/lib/site-packages/isaacsim/kit/data/Kit/Isaac-Sim/5.1/user.config.json'
# [Info] [carb] Logging to file: c:/users/teresa/miniconda3/envs/env_isaaclab/lib/site-packages/isaacsim/kit/logs/Kit/Isaac-Sim/5.1/kit_20260301_120353.log
# 2026-03-01T11:03:53Z s] [Warning] [omni.usd_config.extension] Enable omni.materialx.libs extension to use MaterialX
# 2026-03-01T11:03:53Z s] [Warning] [carb] Acquiring non optional plugin interface which is not listed as dependency: [omni::physx::IPhysxBenchmarks v1.0] (plugin: <default plugin>), by client: omni.physics.physx.plugin. Add it to CARB_PLUGIN_IMPL_DEPS() macro of a client.
# 2026-03-01T11:03:53Z s] [Warning] [omni.isaac.dynamic_control] omni.isaac.dynamic_control is deprecated as of Isaac Sim 4.5. No action is needed from end-users.
# 2026-03-01T11:03:55Z [2,526ms] [Warning] [gpu.foundation.plugin] Skipping unsupported non-NVIDIA GPU: AMD Radeon(TM) Graphics
# 2026-03-01T11:03:55Z [2,527ms] [Warning] [gpu.foundation.plugin] Skipping unsupported non-NVIDIA GPU: AMD Radeon(TM) Graphics
#
# |---------------------------------------------------------------------------------------------|
# | Driver Version: 581.29        | Graphics API: D3D12
# |=============================================================================================|
# | GPU | Name                             | Active | LDA | GPU Memory | Vendor-ID | LUID       |
# |     |                                  |        |     |            | Device-ID | UUID       |
# |     |                                  |        |     |            | Bus-ID    |            |
# |---------------------------------------------------------------------------------------------|
# | 0   | NVIDIA GeForce RTX 5080          | Yes: 0 |     | 15889   MB | 10de      | 295a0100.. |
# |     |                                  |        |     |            | 2c02      | 0          |
# |     |                                  |        |     |            | 1         |            |
# |---------------------------------------------------------------------------------------------|
# | 1   | AMD Radeon(TM) Graphics          |        |     | 1995    MB | 1002      | 876d0100.. |
# |     |                                  |        |     |            | 13c0      | 0          |
# |     |                                  |        |     |            | N/A       |            |
# |=============================================================================================|
# | OS: Windows 11 Pro, Version: 10.0 (25H2), Build: 26200, Kernel: 10.0.26100.7824
# | Processor: AMD Ryzen 9 9950X 16-Core Processor
# | Cores: 16 | Logical Cores: 32
# |---------------------------------------------------------------------------------------------|
# | Total Memory (MB): 128627 | Free Memory: 101928
# | Total Page/Swap (MB): 136819 | Free Page/Swap: 104623
# |---------------------------------------------------------------------------------------------|
# C:\Users\Teresa\Documents\GitHub\navsim\isaac_lab\aerotaxi\env_command\env_11\flight_plan.py:29: UserWarning: Treat the new Tool classes introduced in v1.5 as experimental for now; the API and rcParam may change in future versions.
#   plt.rcParams["toolbar"] = "toolmanager"
# [INFO]: Parsing configuration from: aerotaxi.env_command.env_11.env:UAVEnvCfg
# [INFO]: Parsing configuration from: aerotaxi.env_command.env_11.grid_hiperparametros.cfg_files.ppo_random_command7_11_cfg:Command7PPORunnerCfg
# [INFO] Logging experiment in directory: C:\Users\Teresa\Documents\GitHub\navsim\isaac_lab\aerotaxi\env_command\env_11\logs\rsl_rl\command7
# Exact experiment name requested from command line: 2026-03-01_12-03-56
# Setting seed: 42
# [INFO]: Base environment:
# 	Environment device    : cuda:0
# 	Environment seed      : 42
# 	Physics step-size     : 0.005
# 	Rendering step-size   : 0.02
# 	Environment step-size : 0.02
# [INFO]: Time taken for scene creation : 1.773303 seconds
# [INFO]: Scene manager:  <class InteractiveScene>
# 	Number of environments: 2048
# 	Environment spacing   : 200.0
# 	Source prim name      : /World/envs/env_0
# 	Global prim paths     : []
# 	Replicate physics     : False
# [INFO]: Starting the simulation. This may take a few seconds. Please wait...
# [INFO]: Time taken for simulation start : 1.568115 seconds
# [INFO] Command Manager:  <CommandManager> contains 1 active terms.
# +--------------------------------------+
# |         Active Command Terms         |
# +-------+-------------+----------------+
# | Index | Name        |      Type      |
# +-------+-------------+----------------+
# |   0   | vel_command | UAVcommandTerm |
# +-------+-------------+----------------+
#
# [INFO] Event Manager:  <EventManager> contains 1 active terms.
# +-----------------------------------+
# | Active Event Terms in Mode: 'reset' |
# +----------+------------------------+
# |  Index   | Name                   |
# +----------+------------------------+
# |    0     | reset_pos              |
# |    1     | randomize_mass         |
# |    2     | randomize_wind         |
# +----------+------------------------+
#
# [INFO] Recorder Manager:  <RecorderManager> contains 0 active terms.
# +---------------------+
# | Active Recorder Terms |
# +-----------+---------+
# |   Index   | Name    |
# +-----------+---------+
# +-----------+---------+
#
# [INFO] Action Manager:  <ActionManager> contains 1 active terms.
# +-----------------------------------+
# |   Active Action Terms (shape: 4)  |
# +--------+-------------+------------+
# | Index  | Name        |  Dimension |
# +--------+-------------+------------+
# |   0    | rotors_vel  |          4 |
# +--------+-------------+------------+
#
# [INFO] Observation Manager: <ObservationManager> contains 2 groups.
# +---------------------------------------------------------+
# | Active Observation Terms in Group: 'policy' (shape: (13,)) |
# +-----------+---------------------------------+-----------+
# |   Index   | Name                            |   Shape   |
# +-----------+---------------------------------+-----------+
# |     0     | dist                            |    (3,)   |
# |     1     | lin_vel                         |    (3,)   |
# |     2     | ang_vel                         |    (3,)   |
# |     3     | height                          |    (1,)   |
# |     4     | projected_gravity               |    (3,)   |
# +-----------+---------------------------------+-----------+
# +---------------------------------------------------------+
# | Active Observation Terms in Group: 'critic' (shape: (13,)) |
# +-----------+---------------------------------+-----------+
# |   Index   | Name                            |   Shape   |
# +-----------+---------------------------------+-----------+
# |     0     | dist                            |    (3,)   |
# |     1     | lin_vel                         |    (3,)   |
# |     2     | ang_vel                         |    (3,)   |
# |     3     | height                          |    (1,)   |
# |     4     | projected_gravity               |    (3,)   |
# +-----------+---------------------------------+-----------+
#
# [INFO] Termination Manager:  <TerminationManager> contains 4 active terms.
# +---------------------------------------+
# |        Active Termination Terms       |
# +-------+--------------------+----------+
# | Index | Name               | Time Out |
# +-------+--------------------+----------+
# |   0   | time_out           |   True   |
# |   1   | below_min_altitude |  False   |
# |   2   | bad_attitude       |  False   |
# |   3   | safety_shutdown    |  False   |
# +-------+--------------------+----------+
#
# [INFO] Reward Manager:  <RewardManager> contains 6 active terms.
# +------------------------------------------+
# |           Active Reward Terms            |
# +-------+-------------------------+--------+
# | Index | Name                    | Weight |
# +-------+-------------------------+--------+
# |   0   | rew_attitude_stability2 |    6.0 |
# |   1   | rew_ang_vel_stability2  |    2.0 |
# |   2   | rew_altitude_hold2      |    4.0 |
# |   3   | rew_vel2                |    2.0 |
# |   4   | rew_pos2                |    1.0 |
# |   5   | rew_action_rate         |    1.0 |
# +-------+-------------------------+--------+
#
# [INFO] Curriculum Manager:  <CurriculumManager> contains 0 active terms.
# +----------------------+
# | Active Curriculum Terms |
# +-----------+----------+
# |   Index   | Name     |
# +-----------+----------+
# +-----------+----------+
#
# [INFO]: Completed setting up the environment...
# 2026-03-01T11:04:00Z [7,578ms] [Warning] [omni.physx.fabric.plugin] FabricManager::initializePointInstancer mismatched prototypes on point instancer: /Visuals/target_commands.
# C:\Users\Teresa\miniconda3\envs\env_isaaclab\Lib\site-packages\rsl_rl\utils\utils.py:244: UserWarning: The observation configuration dictionary 'obs_groups' must contain the 'policy' key. As an observation group with the name 'policy' was found, this is assumed to be the observation set. Consider adding the 'policy' key to the 'obs_groups' dictionary for clarity. This behavior will be removed in a future version.
#   warnings.warn(
# C:\Users\Teresa\miniconda3\envs\env_isaaclab\Lib\site-packages\rsl_rl\utils\utils.py:282: UserWarning: The observation configuration dictionary 'obs_groups' must contain the 'critic' key. As an observation group with the name 'critic' was found, this is assumed to be the observation set. Consider adding the 'critic' key to the 'obs_groups' dictionary for clarity. This behavior will be removed in a future version.
#   warnings.warn(
# --------------------------------------------------------------------------------
# Resolved observation sets:
# 	 policy :  ['policy']
# 	 critic :  ['critic']
# --------------------------------------------------------------------------------
# Actor MLP: MLP(
#   (0): Linear(in_features=13, out_features=128, bias=True)
#   (1): ELU(alpha=1.0)
#   (2): Linear(in_features=128, out_features=128, bias=True)
#   (3): ELU(alpha=1.0)
#   (4): Linear(in_features=128, out_features=128, bias=True)
#   (5): ELU(alpha=1.0)
#   (6): Linear(in_features=128, out_features=128, bias=True)
#   (7): ELU(alpha=1.0)
#   (8): Linear(in_features=128, out_features=4, bias=True)
# )
# Critic MLP: MLP(
#   (0): Linear(in_features=13, out_features=512, bias=True)
#   (1): ELU(alpha=1.0)
#   (2): Linear(in_features=512, out_features=512, bias=True)
#   (3): ELU(alpha=1.0)
#   (4): Linear(in_features=512, out_features=512, bias=True)
#   (5): ELU(alpha=1.0)
#   (6): Linear(in_features=512, out_features=512, bias=True)
#   (7): ELU(alpha=1.0)
#   (8): Linear(in_features=512, out_features=512, bias=True)
#   (9): ELU(alpha=1.0)
#   (10): Linear(in_features=512, out_features=1, bias=True)
# )
# ################################################################################
#                        Learning iteration 0/4001
#
#                        Computation: 54764 steps/s (collection: 4.366s, learning 0.421s)
#              Mean action noise std: 0.05
#           Mean value_function loss: 4.5362
#                Mean surrogate loss: 0.0966
#                  Mean entropy loss: -6.1690
#                        Mean reward: 15.16
#                Mean episode length: 126.18
# Episode_Reward/rew_attitude_stability2: 0.1198
# Episode_Reward/rew_ang_vel_stability2: 0.0790
#  Episode_Reward/rew_altitude_hold2: 0.1346
#            Episode_Reward/rew_vel2: 0.0326
#            Episode_Reward/rew_pos2: 0.0008
#     Episode_Reward/rew_action_rate: -0.0000
#       Episode_Termination/time_out: 0.0520
# Episode_Termination/below_min_altitude: 0.0200
#   Episode_Termination/bad_attitude: 0.0446
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 262144
#                     Iteration time: 4.79s
#                       Time elapsed: 00:00:04
#                                ETA: 05:19:11
#
# Could not find git repository in C:\Users\Teresa\miniconda3\envs\env_isaaclab\Lib\site-packages\rsl_rl\__init__.py. Skipping.
# Storing git diff for 'navsim' in: C:\Users\Teresa\Documents\GitHub\navsim\isaac_lab\aerotaxi\env_command\env_11\logs\rsl_rl\command7\2026-03-01_12-03-56_ppo_random_command7_11\git\navsim.diff
# ################################################################################
#                        Learning iteration 1/4001
#
#                        Computation: 85723 steps/s (collection: 2.712s, learning 0.346s)
#              Mean action noise std: 0.05
#           Mean value_function loss: 3.2810
#                Mean surrogate loss: 0.0248
#                  Mean entropy loss: -6.1605
#                        Mean reward: 17.17
#                Mean episode length: 138.78
# Episode_Reward/rew_attitude_stability2: 0.2918
# Episode_Reward/rew_ang_vel_stability2: 0.1970
#  Episode_Reward/rew_altitude_hold2: 0.2190
#            Episode_Reward/rew_vel2: 0.0441
#            Episode_Reward/rew_pos2: 0.0005
#     Episode_Reward/rew_action_rate: -0.0000
#       Episode_Termination/time_out: 0.0696
# Episode_Termination/below_min_altitude: 0.4720
#   Episode_Termination/bad_attitude: 0.2766
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 524288
#                     Iteration time: 3.06s
#                       Time elapsed: 00:00:07
#                                ETA: 04:21:29
#
# ################################################################################
#                        Learning iteration 2/4001
#
#                        Computation: 87120 steps/s (collection: 2.664s, learning 0.345s)
#              Mean action noise std: 0.05
#           Mean value_function loss: 3.1247
#                Mean surrogate loss: 0.0317
#                  Mean entropy loss: -6.0991
#                        Mean reward: 18.09
#                Mean episode length: 146.34
# Episode_Reward/rew_attitude_stability2: 0.2815
# Episode_Reward/rew_ang_vel_stability2: 0.1877
#  Episode_Reward/rew_altitude_hold2: 0.2110
#            Episode_Reward/rew_vel2: 0.0434
#            Episode_Reward/rew_pos2: 0.0000
#     Episode_Reward/rew_action_rate: -0.0000
#       Episode_Termination/time_out: 0.0141
# Episode_Termination/below_min_altitude: 0.7197
#   Episode_Termination/bad_attitude: 0.2600
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 786432
#                     Iteration time: 3.01s
#                       Time elapsed: 00:00:10
#                                ETA: 04:01:08
#
# ################################################################################
#                        Learning iteration 3/4001
#
#                        Computation: 86085 steps/s (collection: 2.699s, learning 0.346s)
#              Mean action noise std: 0.05
#           Mean value_function loss: 3.0391
#                Mean surrogate loss: 0.0156
#                  Mean entropy loss: -6.0198
#                        Mean reward: 18.10
#                Mean episode length: 149.21
# Episode_Reward/rew_attitude_stability2: 0.2840
# Episode_Reward/rew_ang_vel_stability2: 0.1919
#  Episode_Reward/rew_altitude_hold2: 0.2149
#            Episode_Reward/rew_vel2: 0.0428
#            Episode_Reward/rew_pos2: 0.0000
#     Episode_Reward/rew_action_rate: -0.0000
#       Episode_Termination/time_out: 0.0007
# Episode_Termination/below_min_altitude: 0.7646
#   Episode_Termination/bad_attitude: 0.2347
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 1048576
#                     Iteration time: 3.05s
#                       Time elapsed: 00:00:13
#                                ETA: 03:51:32
#
# ################################################################################
#                        Learning iteration 4/4001
#
#                        Computation: 86684 steps/s (collection: 2.677s, learning 0.347s)
#              Mean action noise std: 0.05
#           Mean value_function loss: 2.9496
#                Mean surrogate loss: 0.0182
#                  Mean entropy loss: -5.9432
#                        Mean reward: 19.66
#                Mean episode length: 157.66
# Episode_Reward/rew_attitude_stability2: 0.2862
# Episode_Reward/rew_ang_vel_stability2: 0.1925
#  Episode_Reward/rew_altitude_hold2: 0.2146
#            Episode_Reward/rew_vel2: 0.0424
#            Episode_Reward/rew_pos2: 0.0000
#     Episode_Reward/rew_action_rate: -0.0000
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 0.7856
#   Episode_Termination/bad_attitude: 0.2144
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 1310720
#                     Iteration time: 3.02s
#                       Time elapsed: 00:00:16
#                                ETA: 03:45:28
#
# ################################################################################
#                        Learning iteration 5/4001
#
#                        Computation: 85437 steps/s (collection: 2.722s, learning 0.347s)
#              Mean action noise std: 0.06
#           Mean value_function loss: 2.8249
#                Mean surrogate loss: 0.0143
#                  Mean entropy loss: -5.8845
#                        Mean reward: 19.11
#                Mean episode length: 156.74
# Episode_Reward/rew_attitude_stability2: 0.3035
# Episode_Reward/rew_ang_vel_stability2: 0.2019
#  Episode_Reward/rew_altitude_hold2: 0.2151
#            Episode_Reward/rew_vel2: 0.0420
#            Episode_Reward/rew_pos2: 0.0000
#     Episode_Reward/rew_action_rate: -0.0000
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 0.7880
#   Episode_Termination/bad_attitude: 0.2120
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 1572864
#                     Iteration time: 3.07s
#                       Time elapsed: 00:00:19
#                                ETA: 03:41:54
#
# ################################################################################
#                        Learning iteration 6/4001
#
#                        Computation: 85439 steps/s (collection: 2.722s, learning 0.347s)
#              Mean action noise std: 0.06
#           Mean value_function loss: 2.7016
#                Mean surrogate loss: 0.0167
#                  Mean entropy loss: -5.8121
#                        Mean reward: 18.27
#                Mean episode length: 148.52
# Episode_Reward/rew_attitude_stability2: 0.2979
# Episode_Reward/rew_ang_vel_stability2: 0.1991
#  Episode_Reward/rew_altitude_hold2: 0.2149
#            Episode_Reward/rew_vel2: 0.0432
#            Episode_Reward/rew_pos2: 0.0000
#     Episode_Reward/rew_action_rate: -0.0000
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 0.7919
#   Episode_Termination/bad_attitude: 0.2081
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 1835008
#                     Iteration time: 3.07s
#                       Time elapsed: 00:00:23
#                                ETA: 03:39:20
#
# ################################################################################
#                        Learning iteration 7/4001
#
#                        Computation: 86125 steps/s (collection: 2.698s, learning 0.346s)
#              Mean action noise std: 0.06
#           Mean value_function loss: 2.5503
#                Mean surrogate loss: 0.0081
#                  Mean entropy loss: -5.7438
#                        Mean reward: 18.50
#                Mean episode length: 153.67
# Episode_Reward/rew_attitude_stability2: 0.2882
# Episode_Reward/rew_ang_vel_stability2: 0.1941
#  Episode_Reward/rew_altitude_hold2: 0.2129
#            Episode_Reward/rew_vel2: 0.0430
#            Episode_Reward/rew_pos2: 0.0000
#     Episode_Reward/rew_action_rate: -0.0000
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 0.7869
#   Episode_Termination/bad_attitude: 0.2131
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 2097152
#                     Iteration time: 3.04s
#                       Time elapsed: 00:00:26
#                                ETA: 03:37:12
#
# ################################################################################
#                        Learning iteration 8/4001
#
#                        Computation: 86402 steps/s (collection: 2.688s, learning 0.346s)
#              Mean action noise std: 0.06
#           Mean value_function loss: 2.5095
#                Mean surrogate loss: 0.0102
#                  Mean entropy loss: -5.6706
#                        Mean reward: 18.80
#                Mean episode length: 150.31
# Episode_Reward/rew_attitude_stability2: 0.2890
# Episode_Reward/rew_ang_vel_stability2: 0.1941
#  Episode_Reward/rew_altitude_hold2: 0.2104
#            Episode_Reward/rew_vel2: 0.0423
#            Episode_Reward/rew_pos2: 0.0000
#     Episode_Reward/rew_action_rate: -0.0000
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 0.7891
#   Episode_Termination/bad_attitude: 0.2109
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 2359296
#                     Iteration time: 3.03s
#                       Time elapsed: 00:00:29
#                                ETA: 03:35:27
#
# ################################################################################
#                        Learning iteration 9/4001
#
#                        Computation: 87076 steps/s (collection: 2.663s, learning 0.347s)
#              Mean action noise std: 0.06
#           Mean value_function loss: 2.3593
#                Mean surrogate loss: 0.0109
#                  Mean entropy loss: -5.6061
#                        Mean reward: 19.01
#                Mean episode length: 152.60
# Episode_Reward/rew_attitude_stability2: 0.2947
# Episode_Reward/rew_ang_vel_stability2: 0.1991
#  Episode_Reward/rew_altitude_hold2: 0.2113
#            Episode_Reward/rew_vel2: 0.0434
#            Episode_Reward/rew_pos2: 0.0000
#     Episode_Reward/rew_action_rate: -0.0000
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 0.7865
#   Episode_Termination/bad_attitude: 0.2135
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 2621440
#                     Iteration time: 3.01s
#                       Time elapsed: 00:00:32
#                                ETA: 03:33:53
#
# ################################################################################
#                        Learning iteration 10/4001
#
#                        Computation: 87118 steps/s (collection: 2.664s, learning 0.345s)
#              Mean action noise std: 0.06
#           Mean value_function loss: 2.2465
#                Mean surrogate loss: 0.0111
#                  Mean entropy loss: -5.5434
#                        Mean reward: 18.85
#                Mean episode length: 156.91
# Episode_Reward/rew_attitude_stability2: 0.3043
# Episode_Reward/rew_ang_vel_stability2: 0.2009
#  Episode_Reward/rew_altitude_hold2: 0.2132
#            Episode_Reward/rew_vel2: 0.0419
#            Episode_Reward/rew_pos2: 0.0000
#     Episode_Reward/rew_action_rate: -0.0000
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 0.7979
#   Episode_Termination/bad_attitude: 0.2021
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 2883584
#                     Iteration time: 3.01s
#                       Time elapsed: 00:00:35
#                                ETA: 03:32:35
#
# ################################################################################
#                        Learning iteration 11/4001
#
#                        Computation: 86038 steps/s (collection: 2.701s, learning 0.346s)
#              Mean action noise std: 0.06
#           Mean value_function loss: 2.0382
#                Mean surrogate loss: 0.0083
#                  Mean entropy loss: -5.4809
#                        Mean reward: 18.29
#                Mean episode length: 149.91
# Episode_Reward/rew_attitude_stability2: 0.3074
# Episode_Reward/rew_ang_vel_stability2: 0.2047
#  Episode_Reward/rew_altitude_hold2: 0.2186
#            Episode_Reward/rew_vel2: 0.0425
#            Episode_Reward/rew_pos2: 0.0000
#     Episode_Reward/rew_action_rate: -0.0000
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 0.7941
#   Episode_Termination/bad_attitude: 0.2059
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 3145728
#                     Iteration time: 3.05s
#                       Time elapsed: 00:00:38
#                                ETA: 03:31:42
#
# ################################################################################
#                        Learning iteration 12/4001
#
#                        Computation: 86111 steps/s (collection: 2.699s, learning 0.345s)
#              Mean action noise std: 0.06
#           Mean value_function loss: 1.8863
#                Mean surrogate loss: 0.0121
#                  Mean entropy loss: -5.4088
#                        Mean reward: 18.69
#                Mean episode length: 150.05
# Episode_Reward/rew_attitude_stability2: 0.3046
# Episode_Reward/rew_ang_vel_stability2: 0.2021
#  Episode_Reward/rew_altitude_hold2: 0.2131
#            Episode_Reward/rew_vel2: 0.0431
#            Episode_Reward/rew_pos2: 0.0000
#     Episode_Reward/rew_action_rate: -0.0000
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 0.7943
#   Episode_Termination/bad_attitude: 0.2057
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 3407872
#                     Iteration time: 3.04s
#                       Time elapsed: 00:00:41
#                                ETA: 03:30:56
#
# ################################################################################
#                        Learning iteration 13/4001
#
#                        Computation: 85256 steps/s (collection: 2.728s, learning 0.347s)
#              Mean action noise std: 0.06
#           Mean value_function loss: 1.6791
#                Mean surrogate loss: 0.0087
#                  Mean entropy loss: -5.3513
#                        Mean reward: 17.96
#                Mean episode length: 146.41
# Episode_Reward/rew_attitude_stability2: 0.2935
# Episode_Reward/rew_ang_vel_stability2: 0.1964
#  Episode_Reward/rew_altitude_hold2: 0.2105
#            Episode_Reward/rew_vel2: 0.0426
#            Episode_Reward/rew_pos2: 0.0000
#     Episode_Reward/rew_action_rate: -0.0000
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 0.7949
#   Episode_Termination/bad_attitude: 0.2051
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 3670016
#                     Iteration time: 3.07s
#                       Time elapsed: 00:00:44
#                                ETA: 03:30:25
#
# ################################################################################
#                        Learning iteration 14/4001
#
#                        Computation: 85839 steps/s (collection: 2.705s, learning 0.349s)
#              Mean action noise std: 0.06
#           Mean value_function loss: 1.5765
#                Mean surrogate loss: 0.0079
#                  Mean entropy loss: -5.3020
#                        Mean reward: 18.93
#                Mean episode length: 150.37
# Episode_Reward/rew_attitude_stability2: 0.2845
# Episode_Reward/rew_ang_vel_stability2: 0.1935
#  Episode_Reward/rew_altitude_hold2: 0.2120
#            Episode_Reward/rew_vel2: 0.0433
#            Episode_Reward/rew_pos2: 0.0000
#     Episode_Reward/rew_action_rate: -0.0000
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 0.7921
#   Episode_Termination/bad_attitude: 0.2079
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 3932160
#                     Iteration time: 3.05s
#                       Time elapsed: 00:00:47
#                                ETA: 03:29:52
#
# ################################################################################
#                        Learning iteration 15/4001
#
#                        Computation: 86630 steps/s (collection: 2.680s, learning 0.346s)
#              Mean action noise std: 0.07
#           Mean value_function loss: 1.5105
#                Mean surrogate loss: 0.0111
#                  Mean entropy loss: -5.2387
#                        Mean reward: 18.87
#                Mean episode length: 153.51
# Episode_Reward/rew_attitude_stability2: 0.2879
# Episode_Reward/rew_ang_vel_stability2: 0.1976
#  Episode_Reward/rew_altitude_hold2: 0.2132
#            Episode_Reward/rew_vel2: 0.0429
#            Episode_Reward/rew_pos2: 0.0000
#     Episode_Reward/rew_action_rate: -0.0000
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 0.7988
#   Episode_Termination/bad_attitude: 0.2012
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 4194304
#                     Iteration time: 3.03s
#                       Time elapsed: 00:00:50
#                                ETA: 03:29:16
#
# ################################################################################
#                        Learning iteration 16/4001
#
#                        Computation: 86046 steps/s (collection: 2.702s, learning 0.345s)
#              Mean action noise std: 0.07
#           Mean value_function loss: 1.3475
#                Mean surrogate loss: 0.0067
#                  Mean entropy loss: -5.1780
#                        Mean reward: 20.14
#                Mean episode length: 157.36
# Episode_Reward/rew_attitude_stability2: 0.3137
# Episode_Reward/rew_ang_vel_stability2: 0.2092
#  Episode_Reward/rew_altitude_hold2: 0.2152
#            Episode_Reward/rew_vel2: 0.0420
#            Episode_Reward/rew_pos2: 0.0000
#     Episode_Reward/rew_action_rate: -0.0000
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 0.8244
#   Episode_Termination/bad_attitude: 0.1756
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 4456448
#                     Iteration time: 3.05s
#                       Time elapsed: 00:00:53
#                                ETA: 03:28:49
#
# ################################################################################
#                        Learning iteration 17/4001
#
#                        Computation: 87176 steps/s (collection: 2.662s, learning 0.345s)
#              Mean action noise std: 0.07
#           Mean value_function loss: 1.2684
#                Mean surrogate loss: 0.0075
#                  Mean entropy loss: -5.1203
#                        Mean reward: 20.82
#                Mean episode length: 166.38
# Episode_Reward/rew_attitude_stability2: 0.3156
# Episode_Reward/rew_ang_vel_stability2: 0.2104
#  Episode_Reward/rew_altitude_hold2: 0.2204
#            Episode_Reward/rew_vel2: 0.0438
#            Episode_Reward/rew_pos2: 0.0000
#     Episode_Reward/rew_action_rate: -0.0000
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 0.8153
#   Episode_Termination/bad_attitude: 0.1847
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 4718592
#                     Iteration time: 3.01s
#                       Time elapsed: 00:00:56
#                                ETA: 03:28:15
#
# ################################################################################
#                        Learning iteration 18/4001
#
#                        Computation: 85970 steps/s (collection: 2.703s, learning 0.347s)
#              Mean action noise std: 0.07
#           Mean value_function loss: 1.1358
#                Mean surrogate loss: 0.0079
#                  Mean entropy loss: -5.0706
#                        Mean reward: 21.43
#                Mean episode length: 168.41
# Episode_Reward/rew_attitude_stability2: 0.3334
# Episode_Reward/rew_ang_vel_stability2: 0.2190
#  Episode_Reward/rew_altitude_hold2: 0.2231
#            Episode_Reward/rew_vel2: 0.0426
#            Episode_Reward/rew_pos2: 0.0000
#     Episode_Reward/rew_action_rate: -0.0000
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 0.8167
#   Episode_Termination/bad_attitude: 0.1833
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 4980736
#                     Iteration time: 3.05s
#                       Time elapsed: 00:00:59
#                                ETA: 03:27:54
#
# ################################################################################
#                        Learning iteration 19/4001
#
#                        Computation: 86195 steps/s (collection: 2.694s, learning 0.348s)
#              Mean action noise std: 0.07
#           Mean value_function loss: 0.9922
#                Mean surrogate loss: 0.0060
#                  Mean entropy loss: -5.0097
#                        Mean reward: 20.65
#                Mean episode length: 164.75
# Episode_Reward/rew_attitude_stability2: 0.3314
# Episode_Reward/rew_ang_vel_stability2: 0.2172
#  Episode_Reward/rew_altitude_hold2: 0.2210
#            Episode_Reward/rew_vel2: 0.0430
#            Episode_Reward/rew_pos2: 0.0000
#     Episode_Reward/rew_action_rate: -0.0000
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 0.8089
#   Episode_Termination/bad_attitude: 0.1911
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 5242880
#                     Iteration time: 3.04s
#                       Time elapsed: 00:01:02
#                                ETA: 03:27:33
#
# ################################################################################
#                        Learning iteration 20/4001
#
#                        Computation: 86114 steps/s (collection: 2.698s, learning 0.346s)
#              Mean action noise std: 0.07
#           Mean value_function loss: 0.9360
#                Mean surrogate loss: 0.0067
#                  Mean entropy loss: -4.9517
#                        Mean reward: 22.11
#                Mean episode length: 175.08
# Episode_Reward/rew_attitude_stability2: 0.3390
# Episode_Reward/rew_ang_vel_stability2: 0.2203
#  Episode_Reward/rew_altitude_hold2: 0.2219
#            Episode_Reward/rew_vel2: 0.0432
#            Episode_Reward/rew_pos2: 0.0000
#     Episode_Reward/rew_action_rate: -0.0000
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 0.8029
#   Episode_Termination/bad_attitude: 0.1971
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 5505024
#                     Iteration time: 3.04s
#                       Time elapsed: 00:01:05
#                                ETA: 03:27:14
#
# ################################################################################
#                        Learning iteration 21/4001
#
#                        Computation: 85477 steps/s (collection: 2.721s, learning 0.346s)
#              Mean action noise std: 0.07
#           Mean value_function loss: 0.8931
#                Mean surrogate loss: 0.0066
#                  Mean entropy loss: -4.8854
#                        Mean reward: 21.69
#                Mean episode length: 169.93
# Episode_Reward/rew_attitude_stability2: 0.3324
# Episode_Reward/rew_ang_vel_stability2: 0.2180
#  Episode_Reward/rew_altitude_hold2: 0.2186
#            Episode_Reward/rew_vel2: 0.0428
#            Episode_Reward/rew_pos2: 0.0000
#     Episode_Reward/rew_action_rate: -0.0001
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 0.8082
#   Episode_Termination/bad_attitude: 0.1918
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 5767168
#                     Iteration time: 3.07s
#                       Time elapsed: 00:01:08
#                                ETA: 03:27:00
#
# ################################################################################
#                        Learning iteration 22/4001
#
#                        Computation: 87095 steps/s (collection: 2.664s, learning 0.346s)
#              Mean action noise std: 0.07
#           Mean value_function loss: 0.9261
#                Mean surrogate loss: 0.0047
#                  Mean entropy loss: -4.8308
#                        Mean reward: 20.63
#                Mean episode length: 167.09
# Episode_Reward/rew_attitude_stability2: 0.3431
# Episode_Reward/rew_ang_vel_stability2: 0.2243
#  Episode_Reward/rew_altitude_hold2: 0.2271
#            Episode_Reward/rew_vel2: 0.0434
#            Episode_Reward/rew_pos2: 0.0000
#     Episode_Reward/rew_action_rate: -0.0001
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 0.8125
#   Episode_Termination/bad_attitude: 0.1875
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 6029312
#                     Iteration time: 3.01s
#                       Time elapsed: 00:01:11
#                                ETA: 03:26:38
#
# ################################################################################
#                        Learning iteration 23/4001
#
#                        Computation: 86256 steps/s (collection: 2.694s, learning 0.345s)
#              Mean action noise std: 0.07
#           Mean value_function loss: 0.8267
#                Mean surrogate loss: 0.0076
#                  Mean entropy loss: -4.7706
#                        Mean reward: 23.13
#                Mean episode length: 180.93
# Episode_Reward/rew_attitude_stability2: 0.3591
# Episode_Reward/rew_ang_vel_stability2: 0.2314
#  Episode_Reward/rew_altitude_hold2: 0.2278
#            Episode_Reward/rew_vel2: 0.0436
#            Episode_Reward/rew_pos2: 0.0000
#     Episode_Reward/rew_action_rate: -0.0001
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 0.8181
#   Episode_Termination/bad_attitude: 0.1819
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 6291456
#                     Iteration time: 3.04s
#                       Time elapsed: 00:01:14
#                                ETA: 03:26:22
#
# ################################################################################
#                        Learning iteration 24/4001
#
#                        Computation: 86599 steps/s (collection: 2.677s, learning 0.350s)
#              Mean action noise std: 0.07
#           Mean value_function loss: 0.8431
#                Mean surrogate loss: 0.0103
#                  Mean entropy loss: -4.7068
#                        Mean reward: 22.24
#                Mean episode length: 180.60
# Episode_Reward/rew_attitude_stability2: 0.3652
# Episode_Reward/rew_ang_vel_stability2: 0.2355
#  Episode_Reward/rew_altitude_hold2: 0.2284
#            Episode_Reward/rew_vel2: 0.0446
#            Episode_Reward/rew_pos2: 0.0000
#     Episode_Reward/rew_action_rate: -0.0001
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 0.7831
#   Episode_Termination/bad_attitude: 0.2169
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 6553600
#                     Iteration time: 3.03s
#                       Time elapsed: 00:01:17
#                                ETA: 03:26:05
#
# ################################################################################
#                        Learning iteration 25/4001
#
#                        Computation: 86583 steps/s (collection: 2.681s, learning 0.347s)
#              Mean action noise std: 0.08
#           Mean value_function loss: 0.7304
#                Mean surrogate loss: 0.0062
#                  Mean entropy loss: -4.6385
#                        Mean reward: 20.38
#                Mean episode length: 164.21
# Episode_Reward/rew_attitude_stability2: 0.3811
# Episode_Reward/rew_ang_vel_stability2: 0.2411
#  Episode_Reward/rew_altitude_hold2: 0.2285
#            Episode_Reward/rew_vel2: 0.0440
#            Episode_Reward/rew_pos2: 0.0000
#     Episode_Reward/rew_action_rate: -0.0001
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 0.7715
#   Episode_Termination/bad_attitude: 0.2285
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 6815744
#                     Iteration time: 3.03s
#                       Time elapsed: 00:01:20
#                                ETA: 03:25:50
#
# ################################################################################
#                        Learning iteration 26/4001
#
#                        Computation: 85104 steps/s (collection: 2.735s, learning 0.345s)
#              Mean action noise std: 0.08
#           Mean value_function loss: 0.7510
#                Mean surrogate loss: 0.0042
#                  Mean entropy loss: -4.5707
#                        Mean reward: 22.66
#                Mean episode length: 180.32
# Episode_Reward/rew_attitude_stability2: 0.3959
# Episode_Reward/rew_ang_vel_stability2: 0.2461
#  Episode_Reward/rew_altitude_hold2: 0.2360
#            Episode_Reward/rew_vel2: 0.0445
#            Episode_Reward/rew_pos2: 0.0000
#     Episode_Reward/rew_action_rate: -0.0001
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 0.7566
#   Episode_Termination/bad_attitude: 0.2434
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 7077888
#                     Iteration time: 3.08s
#                       Time elapsed: 00:01:23
#                                ETA: 03:25:43
#
# ################################################################################
#                        Learning iteration 27/4001
#
#                        Computation: 85818 steps/s (collection: 2.708s, learning 0.346s)
#              Mean action noise std: 0.08
#           Mean value_function loss: 0.7086
#                Mean surrogate loss: 0.0049
#                  Mean entropy loss: -4.5113
#                        Mean reward: 25.17
#                Mean episode length: 195.55
# Episode_Reward/rew_attitude_stability2: 0.4061
# Episode_Reward/rew_ang_vel_stability2: 0.2534
#  Episode_Reward/rew_altitude_hold2: 0.2335
#            Episode_Reward/rew_vel2: 0.0435
#            Episode_Reward/rew_pos2: 0.0000
#     Episode_Reward/rew_action_rate: -0.0001
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 0.7429
#   Episode_Termination/bad_attitude: 0.2571
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 7340032
#                     Iteration time: 3.05s
#                       Time elapsed: 00:01:26
#                                ETA: 03:25:33
#
# ################################################################################
#                        Learning iteration 28/4001
#
#                        Computation: 85324 steps/s (collection: 2.726s, learning 0.346s)
#              Mean action noise std: 0.08
#           Mean value_function loss: 0.6708
#                Mean surrogate loss: 0.0044
#                  Mean entropy loss: -4.4523
#                        Mean reward: 22.56
#                Mean episode length: 176.62
# Episode_Reward/rew_attitude_stability2: 0.4096
# Episode_Reward/rew_ang_vel_stability2: 0.2549
#  Episode_Reward/rew_altitude_hold2: 0.2342
#            Episode_Reward/rew_vel2: 0.0469
#            Episode_Reward/rew_pos2: 0.0000
#     Episode_Reward/rew_action_rate: -0.0001
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 0.7159
#   Episode_Termination/bad_attitude: 0.2841
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 7602176
#                     Iteration time: 3.07s
#                       Time elapsed: 00:01:29
#                                ETA: 03:25:25
#
# ################################################################################
#                        Learning iteration 29/4001
#
#                        Computation: 86540 steps/s (collection: 2.682s, learning 0.347s)
#              Mean action noise std: 0.08
#           Mean value_function loss: 0.6282
#                Mean surrogate loss: 0.0046
#                  Mean entropy loss: -4.4008
#                        Mean reward: 23.28
#                Mean episode length: 183.46
# Episode_Reward/rew_attitude_stability2: 0.4094
# Episode_Reward/rew_ang_vel_stability2: 0.2537
#  Episode_Reward/rew_altitude_hold2: 0.2329
#            Episode_Reward/rew_vel2: 0.0452
#            Episode_Reward/rew_pos2: 0.0000
#     Episode_Reward/rew_action_rate: -0.0001
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 0.6990
#   Episode_Termination/bad_attitude: 0.3010
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 7864320
#                     Iteration time: 3.03s
#                       Time elapsed: 00:01:32
#                                ETA: 03:25:12
#
# ################################################################################
#                        Learning iteration 30/4001
#
#                        Computation: 86726 steps/s (collection: 2.677s, learning 0.346s)
#              Mean action noise std: 0.08
#           Mean value_function loss: 0.6162
#                Mean surrogate loss: 0.0037
#                  Mean entropy loss: -4.3405
#                        Mean reward: 22.34
#                Mean episode length: 180.39
# Episode_Reward/rew_attitude_stability2: 0.4090
# Episode_Reward/rew_ang_vel_stability2: 0.2554
#  Episode_Reward/rew_altitude_hold2: 0.2391
#            Episode_Reward/rew_vel2: 0.0452
# ...
# --------------------------------------------------------------------------------
#                    Total timesteps: 1045430272
#                     Iteration time: 3.37s
#                       Time elapsed: 03:40:18
#                                ETA: 00:00:46
#
# ################################################################################
#                       Learning iteration 3988/4001
#
#                        Computation: 76574 steps/s (collection: 3.077s, learning 0.346s)
#              Mean action noise std: 2.92
#           Mean value_function loss: 0.0180
#                Mean surrogate loss: -0.0003
#                  Mean entropy loss: 9.9548
#                        Mean reward: 318.37
#                Mean episode length: 1240.80
# Episode_Reward/rew_attitude_stability2: 5.8681
# Episode_Reward/rew_ang_vel_stability2: 1.9360
#  Episode_Reward/rew_altitude_hold2: 3.7868
#            Episode_Reward/rew_vel2: 1.8619
#            Episode_Reward/rew_pos2: 0.0000
#     Episode_Reward/rew_action_rate: -0.7555
#       Episode_Termination/time_out: 0.9757
# Episode_Termination/below_min_altitude: 0.0243
#   Episode_Termination/bad_attitude: 0.0000
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 1045692416
#                     Iteration time: 3.42s
#                       Time elapsed: 03:40:21
#                                ETA: 00:00:43
#
# ################################################################################
#                       Learning iteration 3989/4001
#
#                        Computation: 76742 steps/s (collection: 3.071s, learning 0.345s)
#              Mean action noise std: 2.91
#           Mean value_function loss: 0.0172
#                Mean surrogate loss: -0.0004
#                  Mean entropy loss: 9.9548
#                        Mean reward: 316.61
#                Mean episode length: 1241.73
# Episode_Reward/rew_attitude_stability2: 5.8698
# Episode_Reward/rew_ang_vel_stability2: 1.9335
#  Episode_Reward/rew_altitude_hold2: 3.7876
#            Episode_Reward/rew_vel2: 1.8750
#            Episode_Reward/rew_pos2: 0.0000
#     Episode_Reward/rew_action_rate: -0.7528
#       Episode_Termination/time_out: 0.9772
# Episode_Termination/below_min_altitude: 0.0228
#   Episode_Termination/bad_attitude: 0.0000
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 1045954560
#                     Iteration time: 3.42s
#                       Time elapsed: 03:40:25
#                                ETA: 00:00:39
#
# ################################################################################
#                       Learning iteration 3990/4001
#
#                        Computation: 76945 steps/s (collection: 3.061s, learning 0.346s)
#              Mean action noise std: 2.92
#           Mean value_function loss: 0.0216
#                Mean surrogate loss: -0.0005
#                  Mean entropy loss: 9.9539
#                        Mean reward: 311.76
#                Mean episode length: 1222.29
# Episode_Reward/rew_attitude_stability2: 5.8123
# Episode_Reward/rew_ang_vel_stability2: 1.9160
#  Episode_Reward/rew_altitude_hold2: 3.7148
#            Episode_Reward/rew_vel2: 1.8418
#            Episode_Reward/rew_pos2: 0.0000
#     Episode_Reward/rew_action_rate: -0.7471
#       Episode_Termination/time_out: 0.9783
# Episode_Termination/below_min_altitude: 0.0217
#   Episode_Termination/bad_attitude: 0.0000
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 1046216704
#                     Iteration time: 3.41s
#                       Time elapsed: 03:40:28
#                                ETA: 00:00:36
#
# ################################################################################
#                       Learning iteration 3991/4001
#
#                        Computation: 77478 steps/s (collection: 3.037s, learning 0.347s)
#              Mean action noise std: 2.91
#           Mean value_function loss: 0.0149
#                Mean surrogate loss: -0.0004
#                  Mean entropy loss: 9.9537
#                        Mean reward: 321.01
#                Mean episode length: 1250.00
# Episode_Reward/rew_attitude_stability2: 5.9210
# Episode_Reward/rew_ang_vel_stability2: 1.9515
#  Episode_Reward/rew_altitude_hold2: 3.8445
#            Episode_Reward/rew_vel2: 1.8847
#            Episode_Reward/rew_pos2: 0.0000
#     Episode_Reward/rew_action_rate: -0.7602
#       Episode_Termination/time_out: 0.9787
# Episode_Termination/below_min_altitude: 0.0213
#   Episode_Termination/bad_attitude: 0.0000
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 1046478848
#                     Iteration time: 3.38s
#                       Time elapsed: 03:40:32
#                                ETA: 00:00:33
#
# ################################################################################
#                       Learning iteration 3992/4001
#
#                        Computation: 77753 steps/s (collection: 3.028s, learning 0.343s)
#              Mean action noise std: 2.92
#           Mean value_function loss: 0.0279
#                Mean surrogate loss: 0.0006
#                  Mean entropy loss: 9.9534
#                        Mean reward: 319.00
#                Mean episode length: 1246.48
# Episode_Reward/rew_attitude_stability2: 5.9208
# Episode_Reward/rew_ang_vel_stability2: 1.9538
#  Episode_Reward/rew_altitude_hold2: 3.8028
#            Episode_Reward/rew_vel2: 1.8738
#            Episode_Reward/rew_pos2: 0.0000
#     Episode_Reward/rew_action_rate: -0.7577
#       Episode_Termination/time_out: 0.9793
# Episode_Termination/below_min_altitude: 0.0207
#   Episode_Termination/bad_attitude: 0.0000
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 1046740992
#                     Iteration time: 3.37s
#                       Time elapsed: 03:40:35
#                                ETA: 00:00:29
#
# ################################################################################
#                       Learning iteration 3993/4001
#
#                        Computation: 77080 steps/s (collection: 3.056s, learning 0.345s)
#              Mean action noise std: 2.92
#           Mean value_function loss: 0.0316
#                Mean surrogate loss: -0.0002
#                  Mean entropy loss: 9.9597
#                        Mean reward: 322.78
#                Mean episode length: 1250.00
# Episode_Reward/rew_attitude_stability2: 5.8818
# Episode_Reward/rew_ang_vel_stability2: 1.9382
#  Episode_Reward/rew_altitude_hold2: 3.8488
#            Episode_Reward/rew_vel2: 1.8825
#            Episode_Reward/rew_pos2: 0.0000
#     Episode_Reward/rew_action_rate: -0.7501
#       Episode_Termination/time_out: 0.9799
# Episode_Termination/below_min_altitude: 0.0201
#   Episode_Termination/bad_attitude: 0.0000
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 1047003136
#                     Iteration time: 3.40s
#                       Time elapsed: 03:40:38
#                                ETA: 00:00:26
#
# ################################################################################
#                       Learning iteration 3994/4001
#
#                        Computation: 77455 steps/s (collection: 3.039s, learning 0.345s)
#              Mean action noise std: 2.92
#           Mean value_function loss: 0.0196
#                Mean surrogate loss: 0.0000
#                  Mean entropy loss: 9.9650
#                        Mean reward: 316.22
#                Mean episode length: 1232.39
# Episode_Reward/rew_attitude_stability2: 5.8461
# Episode_Reward/rew_ang_vel_stability2: 1.9283
#  Episode_Reward/rew_altitude_hold2: 3.7465
#            Episode_Reward/rew_vel2: 1.8598
#            Episode_Reward/rew_pos2: 0.0000
#     Episode_Reward/rew_action_rate: -0.7505
#       Episode_Termination/time_out: 0.9822
# Episode_Termination/below_min_altitude: 0.0178
#   Episode_Termination/bad_attitude: 0.0000
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 1047265280
#                     Iteration time: 3.38s
#                       Time elapsed: 03:40:42
#                                ETA: 00:00:23
#
# ################################################################################
#                       Learning iteration 3995/4001
#
#                        Computation: 77318 steps/s (collection: 3.046s, learning 0.345s)
#              Mean action noise std: 2.92
#           Mean value_function loss: 0.0179
#                Mean surrogate loss: -0.0003
#                  Mean entropy loss: 9.9649
#                        Mean reward: 312.34
#                Mean episode length: 1226.58
# Episode_Reward/rew_attitude_stability2: 5.8919
# Episode_Reward/rew_ang_vel_stability2: 1.9442
#  Episode_Reward/rew_altitude_hold2: 3.7565
#            Episode_Reward/rew_vel2: 1.8664
#            Episode_Reward/rew_pos2: 0.0000
#     Episode_Reward/rew_action_rate: -0.7535
#       Episode_Termination/time_out: 0.9836
# Episode_Termination/below_min_altitude: 0.0164
#   Episode_Termination/bad_attitude: 0.0000
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 1047527424
#                     Iteration time: 3.39s
#                       Time elapsed: 03:40:45
#                                ETA: 00:00:19
#
# ################################################################################
#                       Learning iteration 3996/4001
#
#                        Computation: 77975 steps/s (collection: 3.013s, learning 0.349s)
#              Mean action noise std: 2.92
#           Mean value_function loss: 0.0223
#                Mean surrogate loss: -0.0003
#                  Mean entropy loss: 9.9658
#                        Mean reward: 319.69
#                Mean episode length: 1243.29
# Episode_Reward/rew_attitude_stability2: 5.9176
# Episode_Reward/rew_ang_vel_stability2: 1.9511
#  Episode_Reward/rew_altitude_hold2: 3.8410
#            Episode_Reward/rew_vel2: 1.8777
#            Episode_Reward/rew_pos2: 0.0000
#     Episode_Reward/rew_action_rate: -0.7596
#       Episode_Termination/time_out: 0.9843
# Episode_Termination/below_min_altitude: 0.0157
#   Episode_Termination/bad_attitude: 0.0000
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 1047789568
#                     Iteration time: 3.36s
#                       Time elapsed: 03:40:49
#                                ETA: 00:00:16
#
# ################################################################################
#                       Learning iteration 3997/4001
#
#                        Computation: 76976 steps/s (collection: 3.061s, learning 0.345s)
#              Mean action noise std: 2.93
#           Mean value_function loss: 0.0207
#                Mean surrogate loss: -0.0000
#                  Mean entropy loss: 9.9691
#                        Mean reward: 315.84
#                Mean episode length: 1231.97
# Episode_Reward/rew_attitude_stability2: 5.7653
# Episode_Reward/rew_ang_vel_stability2: 1.9025
#  Episode_Reward/rew_altitude_hold2: 3.6586
#            Episode_Reward/rew_vel2: 1.8255
#            Episode_Reward/rew_pos2: 0.0000
#     Episode_Reward/rew_action_rate: -0.7371
#       Episode_Termination/time_out: 0.9842
# Episode_Termination/below_min_altitude: 0.0158
#   Episode_Termination/bad_attitude: 0.0000
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 1048051712
#                     Iteration time: 3.41s
#                       Time elapsed: 03:40:52
#                                ETA: 00:00:13
#
# ################################################################################
#                       Learning iteration 3998/4001
#
#                        Computation: 76539 steps/s (collection: 3.078s, learning 0.347s)
#              Mean action noise std: 2.93
#           Mean value_function loss: 0.0268
#                Mean surrogate loss: -0.0003
#                  Mean entropy loss: 9.9733
#                        Mean reward: 322.35
#                Mean episode length: 1250.00
# Episode_Reward/rew_attitude_stability2: 5.8765
# Episode_Reward/rew_ang_vel_stability2: 1.9391
#  Episode_Reward/rew_altitude_hold2: 3.7946
#            Episode_Reward/rew_vel2: 1.8537
#            Episode_Reward/rew_pos2: 0.0000
#     Episode_Reward/rew_action_rate: -0.7520
#       Episode_Termination/time_out: 0.9833
# Episode_Termination/below_min_altitude: 0.0167
#   Episode_Termination/bad_attitude: 0.0000
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 1048313856
#                     Iteration time: 3.42s
#                       Time elapsed: 03:40:55
#                                ETA: 00:00:09
#
# ################################################################################
#                       Learning iteration 3999/4001
#
#                        Computation: 76899 steps/s (collection: 3.063s, learning 0.346s)
#              Mean action noise std: 2.92
#           Mean value_function loss: 0.0107
#                Mean surrogate loss: -0.0007
#                  Mean entropy loss: 9.9720
#                        Mean reward: 318.52
#                Mean episode length: 1242.19
# Episode_Reward/rew_attitude_stability2: 5.8808
# Episode_Reward/rew_ang_vel_stability2: 1.9398
#  Episode_Reward/rew_altitude_hold2: 3.7678
#            Episode_Reward/rew_vel2: 1.8657
#            Episode_Reward/rew_pos2: 0.0000
#     Episode_Reward/rew_action_rate: -0.7532
#       Episode_Termination/time_out: 0.9840
# Episode_Termination/below_min_altitude: 0.0160
#   Episode_Termination/bad_attitude: 0.0000
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 1048576000
#                     Iteration time: 3.41s
#                       Time elapsed: 03:40:59
#                                ETA: 00:00:06
#
# ################################################################################
#                       Learning iteration 4000/4001
#
#                        Computation: 77365 steps/s (collection: 3.042s, learning 0.346s)
#              Mean action noise std: 2.92
#           Mean value_function loss: 0.0316
#                Mean surrogate loss: -0.0006
#                  Mean entropy loss: 9.9661
#                        Mean reward: 314.48
#                Mean episode length: 1227.99
# Episode_Reward/rew_attitude_stability2: 5.8227
# Episode_Reward/rew_ang_vel_stability2: 1.9206
#  Episode_Reward/rew_altitude_hold2: 3.7069
#            Episode_Reward/rew_vel2: 1.8506
#            Episode_Reward/rew_pos2: 0.0000
#     Episode_Reward/rew_action_rate: -0.7483
#       Episode_Termination/time_out: 0.9848
# Episode_Termination/below_min_altitude: 0.0152
#   Episode_Termination/bad_attitude: 0.0000
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 1048838144
#                     Iteration time: 3.39s
#                       Time elapsed: 03:41:02
#                                ETA: 00:00:03
#
#
# --- Todos los experimentos han finalizado ---

# %% [markdown]
# ``Análisis de los datos``

# %%
import csv
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

seed = 42
n=5

df_results_grid_actions = pd.read_csv(path_resultados+"/resultados_grid_PPO.csv")

# %%
def get_group(value):
    if f"_{experiment_name}" in value:
        return task_name

df_results_grid_actions["tarea"] = df_results_grid_actions["id_run_name"].apply(get_group)

# %%
df_copy = df_results_grid_actions.copy()
df_results_grid_actions.sample(n, random_state=seed)
# Out:
#                id_run_name  iteration      reward  max_reward  std_reward  \
# 24  ppo_random_command7_11       2400  316.331909  329.643433   39.047092
# 13  ppo_random_command7_11       1300  318.197281  328.741150   35.534513
# 8   ppo_random_command7_11        800  318.185742  327.868378   14.813929
# 25  ppo_random_command7_11       2500  320.139480  329.485565   30.123975
# 4   ppo_random_command7_11        400  307.165823  339.062775   74.940726
#
#     num_envs_train     tarea
# 24            2048  Command7
# 13            2048  Command7
# 8             2048  Command7
# 25            2048  Command7
# 4             2048  Command7

# %%
df_results_grid_actions.set_index(['tarea','id_run_name'],inplace=True)
top5 = (
    df_results_grid_actions.groupby(level="tarea")
      .apply(lambda g: g.sort_values("reward", ascending=False).head(5))
)

# Eliminar el nivel adicional que introduce groupby+apply
top5.index = top5.index.droplevel(0)

top5
# Out:
#                                  iteration      reward  max_reward  \
# tarea    id_run_name
# Command7 ppo_random_command7_11       2800  321.760587  329.663086
#          ppo_random_command7_11       3100  321.572717  329.906860
#          ppo_random_command7_11       1400  320.865510  329.116119
#          ppo_random_command7_11       3700  320.536234  330.050446
#          ppo_random_command7_11       2500  320.139480  329.485565
#
#                                  std_reward  num_envs_train
# tarea    id_run_name
# Command7 ppo_random_command7_11   22.040092            2048
#          ppo_random_command7_11   28.965817            2048
#          ppo_random_command7_11   13.458162            2048
#          ppo_random_command7_11   30.508634            2048
#          ppo_random_command7_11   30.123975            2048

# %%
mean_rewards = df_results_grid_actions.groupby(["tarea", "id_run_name"])["reward"].mean()

for tarea, subdf in mean_rewards.groupby(level="tarea"):
    plt.figure(figsize=(12,5))
    
    # Convertir a DataFrame y resetear index para graficar
    plot_df = subdf.reset_index()
    plot_df = plot_df.sort_values("reward", ascending=False)
    
    plt.bar(plot_df["id_run_name"], plot_df["reward"])
    plt.title(f"Reward media por modelo - {tarea}")
    plt.xlabel("id_run_name")
    plt.ylabel("Reward media")
    plt.xticks(rotation=90)
    plt.tight_layout()
    plt.show()

# %%
df_callbacks = pd.read_csv(path_resultados+"/reward_best_models.csv",index_col='id_run_name')
top5_models = df_callbacks.nlargest(5,columns="reward")
top5_models
# Out:
#                         iteration      reward  max_reward  std_reward  \
# id_run_name
# ppo_random_command7_11        373  332.939269  340.529236   13.861933
#
#                         num_envs_train
# id_run_name
# ppo_random_command7_11            2048

# %% [markdown]
# Graficamos cómo fue el entrenamiento para los 5 mejores modelos según los callbacks:

# %%
import matplotlib.pyplot as plt
import numpy as np

# Aseguramos que `top5_auc` tenga 'tarea' e 'id_run_name' como columnas, no solo en el índice
df_callbacks = pd.read_csv(path_resultados+"/reward_best_models.csv",index_col='id_run_name')
top5_models = df_callbacks.nlargest(5,columns="reward")
top5_reset = top5_models.reset_index()
top5_reset["tarea"] = top5_reset["id_run_name"].apply(get_group)


# Convertir el índice jerárquico en columnas (para acceder a 'tarea' y 'id_run_name')
df_copy_reset = df_copy.reset_index()

# Unimos `top5_auc_reset` con `df_copy_reset` en las columnas comunes: 'tarea' y 'id_run_name'
merged_df = pd.merge(df_copy_reset, top5_reset[['tarea', 'id_run_name']], on=['tarea', 'id_run_name'], how='inner')

# Usamos una lista de colores para asignar un color diferente a cada modelo
colors = plt.cm.viridis(np.linspace(0, 1, len(merged_df['id_run_name'].unique())))

# Ahora, procedemos a graficar
for tarea, task_df in merged_df.groupby('tarea'):
    plt.figure(figsize=(10, 6))
    
    # Iteramos sobre los modelos (id_run_name) para esta tarea
    for i, (run_name, subdf) in enumerate(task_df.groupby('id_run_name')):
        # Graficamos la evolución de la recompensa a lo largo de las iteraciones
        plt.plot(subdf['iteration'], subdf['reward'], label=run_name, color=colors[i])
    
    plt.xlabel('Iteración')
    plt.ylabel('Reward')
    plt.title(f'Evolución de la Recompensa - Tarea: {tarea}')
    plt.legend(title="Modelos", bbox_to_anchor=(1.05, 1), loc='upper left')
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ``Cojo los 5 modelos mejores de todos de los callbacks``

# %%
import os
df_callbacks = pd.read_csv(path_resultados+"/reward_best_models.csv",index_col='id_run_name')
top5_models = df_callbacks.nlargest(5,columns="reward")

powershell_script_test = os.path.join(cfg_dir, "run_tests.ps1")

with open(powershell_script_test, "w") as f:
    f.write("$ErrorActionPreference = 'Stop'\n\n")
    
    for run_id, row in top5_models.iterrows():
        # Extraemos el número del id (ej: de 'ppo_random_hover_4' sacamos '4')
        experiment_number = run_id.split('_')[-1]
        
        # Construimos la ruta exacta del checkpoint
        # Nota: Asegúrate de que path_resultados termine en / o usar os.path.join
        checkpoint_path = f"{path_resultados}/best_model_{run_id}_{int(row['num_envs_train'])}.pt"
        f.write(f'Write-Host "Ejecutando Test final para Experimento {experiment_number}..."\n')
        
        # Usamos el experiment_number extraído para la tarea (--task)
        # Se añaden flags típicos de play.py: --num_envs 1 y se quita --headless para ver el visualizador
        f.write(f'& "{isaaclab_bat}" -p "{play_script}" '
                f'--task {id_task}-{experiment_number} '
                f'--num_envs 1 '
                f' --headless '
                f'--checkpoint "{checkpoint_path}"\n\n')
        
print(f"Script de test generado en: {powershell_script_test}")
# Out:
# Script de test generado en: C:/Users/Teresa/Documents/GitHub/navsim/isaac_lab/aerotaxi/env_command/env_11/grid_hiperparametros/cfg_files\run_tests.ps1

# %% [markdown]
# ### Test con 1 entorno

# %%
# Ejecuta el entrenamiento de forma automática
# !powershell -ExecutionPolicy Bypass -File "{powershell_script}"
import subprocess
import sys

# Ruta al script que generaste
powershell_script_path = powershell_script_test 

print(f"Iniciando ejecución de: {powershell_script_path}\n")

# Ejecutamos el proceso capturando la salida en tiempo real
process = subprocess.Popen(
    ["powershell.exe", "-ExecutionPolicy", "Bypass", "-File", powershell_script_path],
    stdout=subprocess.PIPE,
    stderr=subprocess.STDOUT, # Redirigimos errores a la salida estándar para verlos
    text=True,
    bufsize=1
)

# Leemos la salida línea a línea conforme se genera
try:
    for line in process.stdout:
        print(line, end="") # Imprime la salida de PowerShell en la celda
        sys.stdout.flush()   # Fuerza a Jupyter a mostrar la línea inmediatamente
except KeyboardInterrupt:
    process.kill()
    print("\nEntrenamiento cancelado por el usuario.")

process.wait()
print("\n--- Todos los experimentos de test han finalizado ---")
# Out:
# Iniciando ejecución de: C:/Users/Teresa/Documents/GitHub/navsim/isaac_lab/aerotaxi/env_command/env_11/grid_hiperparametros/cfg_files\run_tests.ps1
#
# Ejecutando Test final para Experimento 11...
# [INFO] Using python from: C:\Users\Teresa\miniconda3\envs\env_isaaclab\python.exe
# [INFO][AppLauncher]: Using device: cuda:0
# [INFO][AppLauncher]: Loading experience file: C:\Users\Teresa\miniconda3\envs\env_isaaclab\Lib\site-packages\isaaclab\apps\isaaclab.python.headless.kit
# Loading user config located at: 'c:/users/teresa/miniconda3/envs/env_isaaclab/lib/site-packages/isaacsim/kit/data/Kit/Isaac-Sim/5.1/user.config.json'
# [Info] [carb] Logging to file: c:/users/teresa/miniconda3/envs/env_isaaclab/lib/site-packages/isaacsim/kit/logs/Kit/Isaac-Sim/5.1/kit_20260301_165303.log
# 2026-03-01T15:53:04Z s] [Warning] [omni.usd_config.extension] Enable omni.materialx.libs extension to use MaterialX
# 2026-03-01T15:53:04Z s] [Warning] [carb] Acquiring non optional plugin interface which is not listed as dependency: [omni::physx::IPhysxBenchmarks v1.0] (plugin: <default plugin>), by client: omni.physics.physx.plugin. Add it to CARB_PLUGIN_IMPL_DEPS() macro of a client.
# 2026-03-01T15:53:04Z s] [Warning] [omni.isaac.dynamic_control] omni.isaac.dynamic_control is deprecated as of Isaac Sim 4.5. No action is needed from end-users.
# 2026-03-01T15:53:06Z [2,470ms] [Warning] [gpu.foundation.plugin] Skipping unsupported non-NVIDIA GPU: AMD Radeon(TM) Graphics
# 2026-03-01T15:53:06Z [2,470ms] [Warning] [gpu.foundation.plugin] Skipping unsupported non-NVIDIA GPU: AMD Radeon(TM) Graphics
#
# |---------------------------------------------------------------------------------------------|
# | Driver Version: 581.29        | Graphics API: D3D12
# |=============================================================================================|
# | GPU | Name                             | Active | LDA | GPU Memory | Vendor-ID | LUID       |
# |     |                                  |        |     |            | Device-ID | UUID       |
# |     |                                  |        |     |            | Bus-ID    |            |
# |---------------------------------------------------------------------------------------------|
# | 0   | NVIDIA GeForce RTX 5080          | Yes: 0 |     | 15889   MB | 10de      | 295a0100.. |
# |     |                                  |        |     |            | 2c02      | 0          |
# |     |                                  |        |     |            | 1         |            |
# |---------------------------------------------------------------------------------------------|
# | 1   | AMD Radeon(TM) Graphics          |        |     | 1995    MB | 1002      | 876d0100.. |
# |     |                                  |        |     |            | 13c0      | 0          |
# |     |                                  |        |     |            | N/A       |            |
# |=============================================================================================|
# | OS: Windows 11 Pro, Version: 10.0 (25H2), Build: 26200, Kernel: 10.0.26100.7824
# | Processor: AMD Ryzen 9 9950X 16-Core Processor
# | Cores: 16 | Logical Cores: 32
# |---------------------------------------------------------------------------------------------|
# | Total Memory (MB): 128627 | Free Memory: 101552
# | Total Page/Swap (MB): 136819 | Free Page/Swap: 103784
# |---------------------------------------------------------------------------------------------|
# C:\Users\Teresa\Documents\GitHub\navsim\isaac_lab\aerotaxi\env_command\env_11\flight_plan.py:29: UserWarning: Treat the new Tool classes introduced in v1.5 as experimental for now; the API and rcParam may change in future versions.
#   plt.rcParams["toolbar"] = "toolmanager"
# [INFO]: Parsing configuration from: aerotaxi.env_command.env_11.env:UAVEnvCfg
# [INFO]: Parsing configuration from: aerotaxi.env_command.env_11.grid_hiperparametros.cfg_files.ppo_random_command7_11_cfg:Command7PPORunnerCfg
# [INFO] Loading experiment from directory: C:\Users\Teresa\Documents\GitHub\navsim\isaac_lab\aerotaxi\env_command\env_11\logs\rsl_rl\command7
# Setting seed: 42
# [INFO]: Base environment:
# 	Environment device    : cuda:0
# 	Environment seed      : 42
# 	Physics step-size     : 0.005
# 	Rendering step-size   : 0.02
# 	Environment step-size : 0.02
# [INFO]: Time taken for scene creation : 0.988024 seconds
# [INFO]: Scene manager:  <class InteractiveScene>
# 	Number of environments: 1
# 	Environment spacing   : 200.0
# 	Source prim name      : /World/envs/env_0
# 	Global prim paths     : []
# 	Replicate physics     : False
# [INFO]: Starting the simulation. This may take a few seconds. Please wait...
# [INFO]: Time taken for simulation start : 0.232220 seconds
# [INFO] Command Manager:  <CommandManager> contains 1 active terms.
# +--------------------------------------+
# |         Active Command Terms         |
# +-------+-------------+----------------+
# | Index | Name        |      Type      |
# +-------+-------------+----------------+
# |   0   | vel_command | UAVcommandTerm |
# +-------+-------------+----------------+
#
# [INFO] Event Manager:  <EventManager> contains 1 active terms.
# +-----------------------------------+
# | Active Event Terms in Mode: 'reset' |
# +----------+------------------------+
# |  Index   | Name                   |
# +----------+------------------------+
# |    0     | reset_pos              |
# |    1     | randomize_mass         |
# |    2     | randomize_wind         |
# +----------+------------------------+
#
# [INFO] Recorder Manager:  <RecorderManager> contains 0 active terms.
# +---------------------+
# | Active Recorder Terms |
# +-----------+---------+
# |   Index   | Name    |
# +-----------+---------+
# +-----------+---------+
#
# [INFO] Action Manager:  <ActionManager> contains 1 active terms.
# +-----------------------------------+
# |   Active Action Terms (shape: 4)  |
# +--------+-------------+------------+
# | Index  | Name        |  Dimension |
# +--------+-------------+------------+
# |   0    | rotors_vel  |          4 |
# +--------+-------------+------------+
#
# [INFO] Observation Manager: <ObservationManager> contains 2 groups.
# +---------------------------------------------------------+
# | Active Observation Terms in Group: 'policy' (shape: (13,)) |
# +-----------+---------------------------------+-----------+
# |   Index   | Name                            |   Shape   |
# +-----------+---------------------------------+-----------+
# |     0     | dist                            |    (3,)   |
# |     1     | lin_vel                         |    (3,)   |
# |     2     | ang_vel                         |    (3,)   |
# |     3     | height                          |    (1,)   |
# |     4     | projected_gravity               |    (3,)   |
# +-----------+---------------------------------+-----------+
# +---------------------------------------------------------+
# | Active Observation Terms in Group: 'critic' (shape: (13,)) |
# +-----------+---------------------------------+-----------+
# |   Index   | Name                            |   Shape   |
# +-----------+---------------------------------+-----------+
# |     0     | dist                            |    (3,)   |
# |     1     | lin_vel                         |    (3,)   |
# |     2     | ang_vel                         |    (3,)   |
# |     3     | height                          |    (1,)   |
# |     4     | projected_gravity               |    (3,)   |
# +-----------+---------------------------------+-----------+
#
# [INFO] Termination Manager:  <TerminationManager> contains 4 active terms.
# +---------------------------------------+
# |        Active Termination Terms       |
# +-------+--------------------+----------+
# | Index | Name               | Time Out |
# +-------+--------------------+----------+
# |   0   | time_out           |   True   |
# |   1   | below_min_altitude |  False   |
# |   2   | bad_attitude       |  False   |
# |   3   | safety_shutdown    |  False   |
# +-------+--------------------+----------+
#
# [INFO] Reward Manager:  <RewardManager> contains 6 active terms.
# +------------------------------------------+
# |           Active Reward Terms            |
# +-------+-------------------------+--------+
# | Index | Name                    | Weight |
# +-------+-------------------------+--------+
# |   0   | rew_attitude_stability2 |    6.0 |
# |   1   | rew_ang_vel_stability2  |    2.0 |
# |   2   | rew_altitude_hold2      |    4.0 |
# |   3   | rew_vel2                |    2.0 |
# |   4   | rew_pos2                |    1.0 |
# |   5   | rew_action_rate         |    1.0 |
# +-------+-------------------------+--------+
#
# [INFO] Curriculum Manager:  <CurriculumManager> contains 0 active terms.
# +----------------------+
# | Active Curriculum Terms |
# +-----------+----------+
# |   Index   | Name     |
# +-----------+----------+
# +-----------+----------+
#
# [INFO]: Completed setting up the environment...
# 2026-03-01T15:53:09Z [5,296ms] [Warning] [omni.physx.fabric.plugin] FabricManager::initializePointInstancer mismatched prototypes on point instancer: /Visuals/target_commands.
# [INFO]: Loading model checkpoint from: C:\Users\Teresa\Documents\GitHub\navsim\tmp\tmpTeresa\resultados_grid_command_v7\best_model_ppo_random_command7_11_2048.pt
# C:\Users\Teresa\miniconda3\envs\env_isaaclab\Lib\site-packages\rsl_rl\utils\utils.py:244: UserWarning: The observation configuration dictionary 'obs_groups' must contain the 'policy' key. As an observation group with the name 'policy' was found, this is assumed to be the observation set. Consider adding the 'policy' key to the 'obs_groups' dictionary for clarity. This behavior will be removed in a future version.
#   warnings.warn(
# C:\Users\Teresa\miniconda3\envs\env_isaaclab\Lib\site-packages\rsl_rl\utils\utils.py:282: UserWarning: The observation configuration dictionary 'obs_groups' must contain the 'critic' key. As an observation group with the name 'critic' was found, this is assumed to be the observation set. Consider adding the 'critic' key to the 'obs_groups' dictionary for clarity. This behavior will be removed in a future version.
#   warnings.warn(
# --------------------------------------------------------------------------------
# Resolved observation sets:
# 	 policy :  ['policy']
# 	 critic :  ['critic']
# --------------------------------------------------------------------------------
# Actor MLP: MLP(
#   (0): Linear(in_features=13, out_features=128, bias=True)
#   (1): ELU(alpha=1.0)
#   (2): Linear(in_features=128, out_features=128, bias=True)
#   (3): ELU(alpha=1.0)
#   (4): Linear(in_features=128, out_features=128, bias=True)
#   (5): ELU(alpha=1.0)
#   (6): Linear(in_features=128, out_features=128, bias=True)
#   (7): ELU(alpha=1.0)
#   (8): Linear(in_features=128, out_features=4, bias=True)
# )
# Critic MLP: MLP(
#   (0): Linear(in_features=13, out_features=512, bias=True)
#   (1): ELU(alpha=1.0)
#   (2): Linear(in_features=512, out_features=512, bias=True)
#   (3): ELU(alpha=1.0)
#   (4): Linear(in_features=512, out_features=512, bias=True)
#   (5): ELU(alpha=1.0)
#   (6): Linear(in_features=512, out_features=512, bias=True)
#   (7): ELU(alpha=1.0)
#   (8): Linear(in_features=512, out_features=512, bias=True)
#   (9): ELU(alpha=1.0)
#   (10): Linear(in_features=512, out_features=1, bias=True)
# )
#
# --- Todos los experimentos de test han finalizado ---

# %%
df_callbacks = pd.read_csv(path_resultados+"/reward_best_models.csv",index_col='id_run_name')
top5_models = df_callbacks.nlargest(5,columns="reward")

# %%
df_rewards_play = pd.read_csv(path_resultados+'/rewards_play_PPO.csv')

# %% [markdown]
# ### Test con 64 entornos

# %%
import os
df_callbacks = pd.read_csv(path_resultados+"/reward_best_models.csv",index_col='id_run_name')
top5_models = df_callbacks.nlargest(5,columns="reward")

powershell_script_test_2 = os.path.join(cfg_dir, "run_tests_2.ps1")

with open(powershell_script_test_2, "w") as f:
    f.write("$ErrorActionPreference = 'Stop'\n\n")
    
    for run_id, row in top5_models.iterrows():
        # Extraemos el número del id (ej: de 'ppo_random_hover_4' sacamos '4')
        experiment_number = run_id.split('_')[-1]
        
        # Construimos la ruta exacta del checkpoint
        # Nota: Asegúrate de que path_resultados termine en / o usar os.path.join
        checkpoint_path = f"{path_resultados}/best_model_{run_id}_{int(row['num_envs_train'])}.pt"
        f.write(f'Write-Host "Ejecutando Test final para Experimento {experiment_number}..."\n')
        
        # Usamos el experiment_number extraído para la tarea (--task)
        # Se añaden flags típicos de play.py: --num_envs 1 y se quita --headless para ver el visualizador
        f.write(f'& "{isaaclab_bat}" -p "{play_script}" '
                f'--task {id_task}-{experiment_number} '
                f'--num_envs 64 '
                f' --headless '
                f'--checkpoint "{checkpoint_path}"\n\n')
        
print(f"Script de test generado en: {powershell_script_test_2}")
# Out:
# Script de test generado en: C:/Users/Teresa/Documents/GitHub/navsim/isaac_lab/aerotaxi/env_command/env_11/grid_hiperparametros/cfg_files\run_tests_2.ps1

# %%
# Ejecuta el entrenamiento de forma automática
# !powershell -ExecutionPolicy Bypass -File "{powershell_script}"
import subprocess
import sys

# Ruta al script que generaste
powershell_script_path = powershell_script_test_2 

print(f"Iniciando ejecución de: {powershell_script_path}\n")

# Ejecutamos el proceso capturando la salida en tiempo real
process = subprocess.Popen(
    ["powershell.exe", "-ExecutionPolicy", "Bypass", "-File", powershell_script_path],
    stdout=subprocess.PIPE,
    stderr=subprocess.STDOUT, # Redirigimos errores a la salida estándar para verlos
    text=True,
    bufsize=1
)

# Leemos la salida línea a línea conforme se genera
try:
    for line in process.stdout:
        print(line, end="") # Imprime la salida de PowerShell en la celda
        sys.stdout.flush()   # Fuerza a Jupyter a mostrar la línea inmediatamente
except KeyboardInterrupt:
    process.kill()
    print("\nEntrenamiento cancelado por el usuario.")

process.wait()
print("\n--- Todos los experimentos de test han finalizado ---")
# Out:
# Iniciando ejecución de: C:/Users/Teresa/Documents/GitHub/navsim/isaac_lab/aerotaxi/env_command/env_11/grid_hiperparametros/cfg_files\run_tests_2.ps1
#
# Ejecutando Test final para Experimento 11...
# [INFO] Using python from: C:\Users\Teresa\miniconda3\envs\env_isaaclab\python.exe
# [INFO][AppLauncher]: Using device: cuda:0
# [INFO][AppLauncher]: Loading experience file: C:\Users\Teresa\miniconda3\envs\env_isaaclab\Lib\site-packages\isaaclab\apps\isaaclab.python.headless.kit
# Loading user config located at: 'c:/users/teresa/miniconda3/envs/env_isaaclab/lib/site-packages/isaacsim/kit/data/Kit/Isaac-Sim/5.1/user.config.json'
# [Info] [carb] Logging to file: c:/users/teresa/miniconda3/envs/env_isaaclab/lib/site-packages/isaacsim/kit/logs/Kit/Isaac-Sim/5.1/kit_20260301_165340.log
# 2026-03-01T15:53:40Z s] [Warning] [omni.usd_config.extension] Enable omni.materialx.libs extension to use MaterialX
# 2026-03-01T15:53:40Z s] [Warning] [carb] Acquiring non optional plugin interface which is not listed as dependency: [omni::physx::IPhysxBenchmarks v1.0] (plugin: <default plugin>), by client: omni.physics.physx.plugin. Add it to CARB_PLUGIN_IMPL_DEPS() macro of a client.
# 2026-03-01T15:53:41Z s] [Warning] [omni.isaac.dynamic_control] omni.isaac.dynamic_control is deprecated as of Isaac Sim 4.5. No action is needed from end-users.
# 2026-03-01T15:53:42Z [2,432ms] [Warning] [gpu.foundation.plugin] Skipping unsupported non-NVIDIA GPU: AMD Radeon(TM) Graphics
# 2026-03-01T15:53:42Z [2,432ms] [Warning] [gpu.foundation.plugin] Skipping unsupported non-NVIDIA GPU: AMD Radeon(TM) Graphics
#
# |---------------------------------------------------------------------------------------------|
# | Driver Version: 581.29        | Graphics API: D3D12
# |=============================================================================================|
# | GPU | Name                             | Active | LDA | GPU Memory | Vendor-ID | LUID       |
# |     |                                  |        |     |            | Device-ID | UUID       |
# |     |                                  |        |     |            | Bus-ID    |            |
# |---------------------------------------------------------------------------------------------|
# | 0   | NVIDIA GeForce RTX 5080          | Yes: 0 |     | 15889   MB | 10de      | 295a0100.. |
# |     |                                  |        |     |            | 2c02      | 0          |
# |     |                                  |        |     |            | 1         |            |
# |---------------------------------------------------------------------------------------------|
# | 1   | AMD Radeon(TM) Graphics          |        |     | 1995    MB | 1002      | 876d0100.. |
# |     |                                  |        |     |            | 13c0      | 0          |
# |     |                                  |        |     |            | N/A       |            |
# |=============================================================================================|
# | OS: Windows 11 Pro, Version: 10.0 (25H2), Build: 26200, Kernel: 10.0.26100.7824
# | Processor: AMD Ryzen 9 9950X 16-Core Processor
# | Cores: 16 | Logical Cores: 32
# |---------------------------------------------------------------------------------------------|
# | Total Memory (MB): 128627 | Free Memory: 101143
# | Total Page/Swap (MB): 136819 | Free Page/Swap: 103409
# |---------------------------------------------------------------------------------------------|
# C:\Users\Teresa\Documents\GitHub\navsim\isaac_lab\aerotaxi\env_command\env_11\flight_plan.py:29: UserWarning: Treat the new Tool classes introduced in v1.5 as experimental for now; the API and rcParam may change in future versions.
#   plt.rcParams["toolbar"] = "toolmanager"
# [INFO]: Parsing configuration from: aerotaxi.env_command.env_11.env:UAVEnvCfg
# [INFO]: Parsing configuration from: aerotaxi.env_command.env_11.grid_hiperparametros.cfg_files.ppo_random_command7_11_cfg:Command7PPORunnerCfg
# [INFO] Loading experiment from directory: C:\Users\Teresa\Documents\GitHub\navsim\isaac_lab\aerotaxi\env_command\env_11\logs\rsl_rl\command7
# Setting seed: 42
# [INFO]: Base environment:
# 	Environment device    : cuda:0
# 	Environment seed      : 42
# 	Physics step-size     : 0.005
# 	Rendering step-size   : 0.02
# 	Environment step-size : 0.02
# [INFO]: Time taken for scene creation : 0.988642 seconds
# [INFO]: Scene manager:  <class InteractiveScene>
# 	Number of environments: 64
# 	Environment spacing   : 200.0
# 	Source prim name      : /World/envs/env_0
# 	Global prim paths     : []
# 	Replicate physics     : False
# [INFO]: Starting the simulation. This may take a few seconds. Please wait...
# [INFO]: Time taken for simulation start : 0.269150 seconds
# [INFO] Command Manager:  <CommandManager> contains 1 active terms.
# +--------------------------------------+
# |         Active Command Terms         |
# +-------+-------------+----------------+
# | Index | Name        |      Type      |
# +-------+-------------+----------------+
# |   0   | vel_command | UAVcommandTerm |
# +-------+-------------+----------------+
#
# [INFO] Event Manager:  <EventManager> contains 1 active terms.
# +-----------------------------------+
# | Active Event Terms in Mode: 'reset' |
# +----------+------------------------+
# |  Index   | Name                   |
# +----------+------------------------+
# |    0     | reset_pos              |
# |    1     | randomize_mass         |
# |    2     | randomize_wind         |
# +----------+------------------------+
#
# [INFO] Recorder Manager:  <RecorderManager> contains 0 active terms.
# +---------------------+
# | Active Recorder Terms |
# +-----------+---------+
# |   Index   | Name    |
# +-----------+---------+
# +-----------+---------+
#
# [INFO] Action Manager:  <ActionManager> contains 1 active terms.
# +-----------------------------------+
# |   Active Action Terms (shape: 4)  |
# +--------+-------------+------------+
# | Index  | Name        |  Dimension |
# +--------+-------------+------------+
# |   0    | rotors_vel  |          4 |
# +--------+-------------+------------+
#
# [INFO] Observation Manager: <ObservationManager> contains 2 groups.
# +---------------------------------------------------------+
# | Active Observation Terms in Group: 'policy' (shape: (13,)) |
# +-----------+---------------------------------+-----------+
# |   Index   | Name                            |   Shape   |
# +-----------+---------------------------------+-----------+
# |     0     | dist                            |    (3,)   |
# |     1     | lin_vel                         |    (3,)   |
# |     2     | ang_vel                         |    (3,)   |
# |     3     | height                          |    (1,)   |
# |     4     | projected_gravity               |    (3,)   |
# +-----------+---------------------------------+-----------+
# +---------------------------------------------------------+
# | Active Observation Terms in Group: 'critic' (shape: (13,)) |
# +-----------+---------------------------------+-----------+
# |   Index   | Name                            |   Shape   |
# +-----------+---------------------------------+-----------+
# |     0     | dist                            |    (3,)   |
# |     1     | lin_vel                         |    (3,)   |
# |     2     | ang_vel                         |    (3,)   |
# |     3     | height                          |    (1,)   |
# |     4     | projected_gravity               |    (3,)   |
# +-----------+---------------------------------+-----------+
#
# [INFO] Termination Manager:  <TerminationManager> contains 4 active terms.
# +---------------------------------------+
# |        Active Termination Terms       |
# +-------+--------------------+----------+
# | Index | Name               | Time Out |
# +-------+--------------------+----------+
# |   0   | time_out           |   True   |
# |   1   | below_min_altitude |  False   |
# |   2   | bad_attitude       |  False   |
# |   3   | safety_shutdown    |  False   |
# +-------+--------------------+----------+
#
# [INFO] Reward Manager:  <RewardManager> contains 6 active terms.
# +------------------------------------------+
# |           Active Reward Terms            |
# +-------+-------------------------+--------+
# | Index | Name                    | Weight |
# +-------+-------------------------+--------+
# |   0   | rew_attitude_stability2 |    6.0 |
# |   1   | rew_ang_vel_stability2  |    2.0 |
# |   2   | rew_altitude_hold2      |    4.0 |
# |   3   | rew_vel2                |    2.0 |
# |   4   | rew_pos2                |    1.0 |
# |   5   | rew_action_rate         |    1.0 |
# +-------+-------------------------+--------+
#
# [INFO] Curriculum Manager:  <CurriculumManager> contains 0 active terms.
# +----------------------+
# | Active Curriculum Terms |
# +-----------+----------+
# |   Index   | Name     |
# +-----------+----------+
# +-----------+----------+
#
# [INFO]: Completed setting up the environment...
# 2026-03-01T15:53:45Z [5,338ms] [Warning] [omni.physx.fabric.plugin] FabricManager::initializePointInstancer mismatched prototypes on point instancer: /Visuals/target_commands.
# [INFO]: Loading model checkpoint from: C:\Users\Teresa\Documents\GitHub\navsim\tmp\tmpTeresa\resultados_grid_command_v7\best_model_ppo_random_command7_11_2048.pt
# C:\Users\Teresa\miniconda3\envs\env_isaaclab\Lib\site-packages\rsl_rl\utils\utils.py:244: UserWarning: The observation configuration dictionary 'obs_groups' must contain the 'policy' key. As an observation group with the name 'policy' was found, this is assumed to be the observation set. Consider adding the 'policy' key to the 'obs_groups' dictionary for clarity. This behavior will be removed in a future version.
#   warnings.warn(
# C:\Users\Teresa\miniconda3\envs\env_isaaclab\Lib\site-packages\rsl_rl\utils\utils.py:282: UserWarning: The observation configuration dictionary 'obs_groups' must contain the 'critic' key. As an observation group with the name 'critic' was found, this is assumed to be the observation set. Consider adding the 'critic' key to the 'obs_groups' dictionary for clarity. This behavior will be removed in a future version.
#   warnings.warn(
# --------------------------------------------------------------------------------
# Resolved observation sets:
# 	 policy :  ['policy']
# 	 critic :  ['critic']
# --------------------------------------------------------------------------------
# Actor MLP: MLP(
#   (0): Linear(in_features=13, out_features=128, bias=True)
#   (1): ELU(alpha=1.0)
#   (2): Linear(in_features=128, out_features=128, bias=True)
#   (3): ELU(alpha=1.0)
#   (4): Linear(in_features=128, out_features=128, bias=True)
#   (5): ELU(alpha=1.0)
#   (6): Linear(in_features=128, out_features=128, bias=True)
#   (7): ELU(alpha=1.0)
#   (8): Linear(in_features=128, out_features=4, bias=True)
# )
# Critic MLP: MLP(
#   (0): Linear(in_features=13, out_features=512, bias=True)
#   (1): ELU(alpha=1.0)
#   (2): Linear(in_features=512, out_features=512, bias=True)
#   (3): ELU(alpha=1.0)
#   (4): Linear(in_features=512, out_features=512, bias=True)
#   (5): ELU(alpha=1.0)
#   (6): Linear(in_features=512, out_features=512, bias=True)
#   (7): ELU(alpha=1.0)
#   (8): Linear(in_features=512, out_features=512, bias=True)
#   (9): ELU(alpha=1.0)
#   (10): Linear(in_features=512, out_features=1, bias=True)
# )
#
# --- Todos los experimentos de test han finalizado ---

# %% [markdown]
# #### Test con 256 entornos

# %%
import os
df_callbacks = pd.read_csv(path_resultados+"/reward_best_models.csv",index_col='id_run_name')
top5_models = df_callbacks.nlargest(5,columns="reward")

powershell_script_test_3 = os.path.join(cfg_dir, "run_tests_3.ps1")

with open(powershell_script_test_3, "w") as f:
    f.write("$ErrorActionPreference = 'Stop'\n\n")
    
    for run_id, row in top5_models.iterrows():
        # Extraemos el número del id (ej: de 'ppo_random_hover_4' sacamos '4')
        experiment_number = run_id.split('_')[-1]
        
        # Construimos la ruta exacta del checkpoint
        # Nota: Asegúrate de que path_resultados termine en / o usar os.path.join
        checkpoint_path = f"{path_resultados}/best_model_{run_id}_{int(row['num_envs_train'])}.pt"
        f.write(f'Write-Host "Ejecutando Test final para Experimento {experiment_number}..."\n')
        
        # Usamos el experiment_number extraído para la tarea (--task)
        # Se añaden flags típicos de play.py: --num_envs 1 y se quita --headless para ver el visualizador
        f.write(f'& "{isaaclab_bat}" -p "{play_script}" '
                f'--task {id_task}-{experiment_number} '
                f'--num_envs 256 '
                f' --headless '
                f'--checkpoint "{checkpoint_path}"\n\n')
        
print(f"Script de test generado en: {powershell_script_test_3}")
# Out:
# Script de test generado en: C:/Users/Teresa/Documents/GitHub/navsim/isaac_lab/aerotaxi/env_command/env_11/grid_hiperparametros/cfg_files\run_tests_3.ps1

# %%
# Ejecuta el entrenamiento de forma automática
# !powershell -ExecutionPolicy Bypass -File "{powershell_script}"
import subprocess
import sys

# Ruta al script que generaste
powershell_script_path = powershell_script_test_3 

print(f"Iniciando ejecución de: {powershell_script_path}\n")

# Ejecutamos el proceso capturando la salida en tiempo real
process = subprocess.Popen(
    ["powershell.exe", "-ExecutionPolicy", "Bypass", "-File", powershell_script_path],
    stdout=subprocess.PIPE,
    stderr=subprocess.STDOUT, # Redirigimos errores a la salida estándar para verlos
    text=True,
    bufsize=1
)

# Leemos la salida línea a línea conforme se genera
try:
    for line in process.stdout:
        print(line, end="") # Imprime la salida de PowerShell en la celda
        sys.stdout.flush()   # Fuerza a Jupyter a mostrar la línea inmediatamente
except KeyboardInterrupt:
    process.kill()
    print("\nEntrenamiento cancelado por el usuario.")

process.wait()
print("\n--- Todos los experimentos de test han finalizado ---")
# Out:
# Iniciando ejecución de: C:/Users/Teresa/Documents/GitHub/navsim/isaac_lab/aerotaxi/env_command/env_11/grid_hiperparametros/cfg_files\run_tests_3.ps1
#
# Ejecutando Test final para Experimento 11...
# [INFO] Using python from: C:\Users\Teresa\miniconda3\envs\env_isaaclab\python.exe
# [INFO][AppLauncher]: Using device: cuda:0
# [INFO][AppLauncher]: Loading experience file: C:\Users\Teresa\miniconda3\envs\env_isaaclab\Lib\site-packages\isaaclab\apps\isaaclab.python.headless.kit
# Loading user config located at: 'c:/users/teresa/miniconda3/envs/env_isaaclab/lib/site-packages/isaacsim/kit/data/Kit/Isaac-Sim/5.1/user.config.json'
# [Info] [carb] Logging to file: c:/users/teresa/miniconda3/envs/env_isaaclab/lib/site-packages/isaacsim/kit/logs/Kit/Isaac-Sim/5.1/kit_20260301_165410.log
# 2026-03-01T15:54:10Z s] [Warning] [omni.usd_config.extension] Enable omni.materialx.libs extension to use MaterialX
# 2026-03-01T15:54:11Z s] [Warning] [carb] Acquiring non optional plugin interface which is not listed as dependency: [omni::physx::IPhysxBenchmarks v1.0] (plugin: <default plugin>), by client: omni.physics.physx.plugin. Add it to CARB_PLUGIN_IMPL_DEPS() macro of a client.
# 2026-03-01T15:54:11Z s] [Warning] [omni.isaac.dynamic_control] omni.isaac.dynamic_control is deprecated as of Isaac Sim 4.5. No action is needed from end-users.
# 2026-03-01T15:54:13Z [2,447ms] [Warning] [gpu.foundation.plugin] Skipping unsupported non-NVIDIA GPU: AMD Radeon(TM) Graphics
# 2026-03-01T15:54:13Z [2,448ms] [Warning] [gpu.foundation.plugin] Skipping unsupported non-NVIDIA GPU: AMD Radeon(TM) Graphics
#
# |---------------------------------------------------------------------------------------------|
# | Driver Version: 581.29        | Graphics API: D3D12
# |=============================================================================================|
# | GPU | Name                             | Active | LDA | GPU Memory | Vendor-ID | LUID       |
# |     |                                  |        |     |            | Device-ID | UUID       |
# |     |                                  |        |     |            | Bus-ID    |            |
# |---------------------------------------------------------------------------------------------|
# | 0   | NVIDIA GeForce RTX 5080          | Yes: 0 |     | 15889   MB | 10de      | 295a0100.. |
# |     |                                  |        |     |            | 2c02      | 0          |
# |     |                                  |        |     |            | 1         |            |
# |---------------------------------------------------------------------------------------------|
# | 1   | AMD Radeon(TM) Graphics          |        |     | 1995    MB | 1002      | 876d0100.. |
# |     |                                  |        |     |            | 13c0      | 0          |
# |     |                                  |        |     |            | N/A       |            |
# |=============================================================================================|
# | OS: Windows 11 Pro, Version: 10.0 (25H2), Build: 26200, Kernel: 10.0.26100.7824
# | Processor: AMD Ryzen 9 9950X 16-Core Processor
# | Cores: 16 | Logical Cores: 32
# |---------------------------------------------------------------------------------------------|
# | Total Memory (MB): 128627 | Free Memory: 101288
# | Total Page/Swap (MB): 136819 | Free Page/Swap: 103502
# |---------------------------------------------------------------------------------------------|
# C:\Users\Teresa\Documents\GitHub\navsim\isaac_lab\aerotaxi\env_command\env_11\flight_plan.py:29: UserWarning: Treat the new Tool classes introduced in v1.5 as experimental for now; the API and rcParam may change in future versions.
#   plt.rcParams["toolbar"] = "toolmanager"
# [INFO]: Parsing configuration from: aerotaxi.env_command.env_11.env:UAVEnvCfg
# [INFO]: Parsing configuration from: aerotaxi.env_command.env_11.grid_hiperparametros.cfg_files.ppo_random_command7_11_cfg:Command7PPORunnerCfg
# [INFO] Loading experiment from directory: C:\Users\Teresa\Documents\GitHub\navsim\isaac_lab\aerotaxi\env_command\env_11\logs\rsl_rl\command7
# Setting seed: 42
# [INFO]: Base environment:
# 	Environment device    : cuda:0
# 	Environment seed      : 42
# 	Physics step-size     : 0.005
# 	Rendering step-size   : 0.02
# 	Environment step-size : 0.02
# [INFO]: Time taken for scene creation : 1.084923 seconds
# [INFO]: Scene manager:  <class InteractiveScene>
# 	Number of environments: 256
# 	Environment spacing   : 200.0
# 	Source prim name      : /World/envs/env_0
# 	Global prim paths     : []
# 	Replicate physics     : False
# [INFO]: Starting the simulation. This may take a few seconds. Please wait...
# [INFO]: Time taken for simulation start : 0.383825 seconds
# [INFO] Command Manager:  <CommandManager> contains 1 active terms.
# +--------------------------------------+
# |         Active Command Terms         |
# +-------+-------------+----------------+
# | Index | Name        |      Type      |
# +-------+-------------+----------------+
# |   0   | vel_command | UAVcommandTerm |
# +-------+-------------+----------------+
#
# [INFO] Event Manager:  <EventManager> contains 1 active terms.
# +-----------------------------------+
# | Active Event Terms in Mode: 'reset' |
# +----------+------------------------+
# |  Index   | Name                   |
# +----------+------------------------+
# |    0     | reset_pos              |
# |    1     | randomize_mass         |
# |    2     | randomize_wind         |
# +----------+------------------------+
#
# [INFO] Recorder Manager:  <RecorderManager> contains 0 active terms.
# +---------------------+
# | Active Recorder Terms |
# +-----------+---------+
# |   Index   | Name    |
# +-----------+---------+
# +-----------+---------+
#
# [INFO] Action Manager:  <ActionManager> contains 1 active terms.
# +-----------------------------------+
# |   Active Action Terms (shape: 4)  |
# +--------+-------------+------------+
# | Index  | Name        |  Dimension |
# +--------+-------------+------------+
# |   0    | rotors_vel  |          4 |
# +--------+-------------+------------+
#
# [INFO] Observation Manager: <ObservationManager> contains 2 groups.
# +---------------------------------------------------------+
# | Active Observation Terms in Group: 'policy' (shape: (13,)) |
# +-----------+---------------------------------+-----------+
# |   Index   | Name                            |   Shape   |
# +-----------+---------------------------------+-----------+
# |     0     | dist                            |    (3,)   |
# |     1     | lin_vel                         |    (3,)   |
# |     2     | ang_vel                         |    (3,)   |
# |     3     | height                          |    (1,)   |
# |     4     | projected_gravity               |    (3,)   |
# +-----------+---------------------------------+-----------+
# +---------------------------------------------------------+
# | Active Observation Terms in Group: 'critic' (shape: (13,)) |
# +-----------+---------------------------------+-----------+
# |   Index   | Name                            |   Shape   |
# +-----------+---------------------------------+-----------+
# |     0     | dist                            |    (3,)   |
# |     1     | lin_vel                         |    (3,)   |
# |     2     | ang_vel                         |    (3,)   |
# |     3     | height                          |    (1,)   |
# |     4     | projected_gravity               |    (3,)   |
# +-----------+---------------------------------+-----------+
#
# [INFO] Termination Manager:  <TerminationManager> contains 4 active terms.
# +---------------------------------------+
# |        Active Termination Terms       |
# +-------+--------------------+----------+
# | Index | Name               | Time Out |
# +-------+--------------------+----------+
# |   0   | time_out           |   True   |
# |   1   | below_min_altitude |  False   |
# |   2   | bad_attitude       |  False   |
# |   3   | safety_shutdown    |  False   |
# +-------+--------------------+----------+
#
# [INFO] Reward Manager:  <RewardManager> contains 6 active terms.
# +------------------------------------------+
# |           Active Reward Terms            |
# +-------+-------------------------+--------+
# | Index | Name                    | Weight |
# +-------+-------------------------+--------+
# |   0   | rew_attitude_stability2 |    6.0 |
# |   1   | rew_ang_vel_stability2  |    2.0 |
# |   2   | rew_altitude_hold2      |    4.0 |
# |   3   | rew_vel2                |    2.0 |
# |   4   | rew_pos2                |    1.0 |
# |   5   | rew_action_rate         |    1.0 |
# +-------+-------------------------+--------+
#
# [INFO] Curriculum Manager:  <CurriculumManager> contains 0 active terms.
# +----------------------+
# | Active Curriculum Terms |
# +-----------+----------+
# |   Index   | Name     |
# +-----------+----------+
# +-----------+----------+
#
# [INFO]: Completed setting up the environment...
# 2026-03-01T15:54:16Z [5,730ms] [Warning] [omni.physx.fabric.plugin] FabricManager::initializePointInstancer mismatched prototypes on point instancer: /Visuals/target_commands.
# [INFO]: Loading model checkpoint from: C:\Users\Teresa\Documents\GitHub\navsim\tmp\tmpTeresa\resultados_grid_command_v7\best_model_ppo_random_command7_11_2048.pt
# C:\Users\Teresa\miniconda3\envs\env_isaaclab\Lib\site-packages\rsl_rl\utils\utils.py:244: UserWarning: The observation configuration dictionary 'obs_groups' must contain the 'policy' key. As an observation group with the name 'policy' was found, this is assumed to be the observation set. Consider adding the 'policy' key to the 'obs_groups' dictionary for clarity. This behavior will be removed in a future version.
#   warnings.warn(
# C:\Users\Teresa\miniconda3\envs\env_isaaclab\Lib\site-packages\rsl_rl\utils\utils.py:282: UserWarning: The observation configuration dictionary 'obs_groups' must contain the 'critic' key. As an observation group with the name 'critic' was found, this is assumed to be the observation set. Consider adding the 'critic' key to the 'obs_groups' dictionary for clarity. This behavior will be removed in a future version.
#   warnings.warn(
# --------------------------------------------------------------------------------
# Resolved observation sets:
# 	 policy :  ['policy']
# 	 critic :  ['critic']
# --------------------------------------------------------------------------------
# Actor MLP: MLP(
#   (0): Linear(in_features=13, out_features=128, bias=True)
#   (1): ELU(alpha=1.0)
#   (2): Linear(in_features=128, out_features=128, bias=True)
#   (3): ELU(alpha=1.0)
#   (4): Linear(in_features=128, out_features=128, bias=True)
#   (5): ELU(alpha=1.0)
#   (6): Linear(in_features=128, out_features=128, bias=True)
#   (7): ELU(alpha=1.0)
#   (8): Linear(in_features=128, out_features=4, bias=True)
# )
# Critic MLP: MLP(
#   (0): Linear(in_features=13, out_features=512, bias=True)
#   (1): ELU(alpha=1.0)
#   (2): Linear(in_features=512, out_features=512, bias=True)
#   (3): ELU(alpha=1.0)
#   (4): Linear(in_features=512, out_features=512, bias=True)
#   (5): ELU(alpha=1.0)
#   (6): Linear(in_features=512, out_features=512, bias=True)
#   (7): ELU(alpha=1.0)
#   (8): Linear(in_features=512, out_features=512, bias=True)
#   (9): ELU(alpha=1.0)
#   (10): Linear(in_features=512, out_features=1, bias=True)
# )
#
# --- Todos los experimentos de test han finalizado ---

# %%
import pandas as pd

df_train = top5_models.copy()
if df_train.index.name == 'id_run_name':
    df_train = df_train.reset_index()

df_train = df_train.rename(columns={
    'reward': 'reward_train',
    'max_reward': 'max_reward_train',
    'std_reward': 'std_train'
})

df_test = df_rewards_play.copy()

df_test = pd.read_csv(path_resultados+'/rewards_play_PPO.csv')
df_test = df_test.rename(columns={
    'reward': 'reward_test',
    'max_reward': 'max_reward_test',
    'std': 'std_test'
})

df_final = pd.merge(
    df_train[['id_run_name', 'num_envs_train', 'reward_train', 'max_reward_train', 'std_train', 'iteration']], 
    df_test[['id_run_name', 'num_envs_test', 'reward_test', 'max_reward_test', 'std_test', 'checkpoint']], 
    on='id_run_name', 
    how='inner'
)

column_order = [
    'id_run_name',
    'num_envs_train',
    'num_envs_test',
    'reward_train', 'reward_test', 
    'max_reward_train', 'max_reward_test', 
    'std_train', 'std_test',
    'iteration'
]
df_final = df_final[column_order]

df_final = df_final.sort_values(by='id_run_name', ascending=False)

# %%
df_rewards_play = df_final.sort_values(by="id_run_name",ascending=False)
df_rewards_play = df_rewards_play.reset_index().drop(columns='index')

df_final = df_rewards_play.copy()

df_final['diff_rw_test_train'] = df_final['reward_test'] - df_final['reward_train']

df_final['diferencia(%)'] = (df_final['diff_rw_test_train'] / df_final['reward_train'].abs()) * 100

df_final['diferencia(%)'] = df_final['diferencia(%)'].apply(lambda x: f"{x:+.2f}%")

df_final
# Out:
#               id_run_name  num_envs_train  num_envs_test  reward_train  \
# 0  ppo_random_command7_11            2048              1    332.939269
# 1  ppo_random_command7_11            2048             64    332.939269
# 2  ppo_random_command7_11            2048            256    332.939269
#
#    reward_test  max_reward_train  max_reward_test  std_train   std_test  \
# 0   150.628531        340.529236       223.553903  13.861933  72.925371
# 1   210.905293        340.529236       277.284970  13.861933  89.000722
# 2   220.375893        340.529236       277.760710  13.861933  86.757288
#
#    iteration  diff_rw_test_train diferencia(%)
# 0        373         -182.310738       -54.76%
# 1        373         -122.033976       -36.65%
# 2        373         -112.563376       -33.81%

# %% [markdown]
# Pruebas con un solo entorno: Vemos cómo se comporta la política para un único agente en una prueba aleatoria.

# %%
df_final[df_final['num_envs_test'] == 1].sort_values(by='reward_test',ascending=False)
# Out:
#               id_run_name  num_envs_train  num_envs_test  reward_train  \
# 0  ppo_random_command7_11            2048              1    332.939269
#
#    reward_test  max_reward_train  max_reward_test  std_train   std_test  \
# 0   150.628531        340.529236       223.553903  13.861933  72.925371
#
#    iteration  diff_rw_test_train diferencia(%)
# 0        373         -182.310738       -54.76%

# %% [markdown]
# ``Interpretación``: Vemos que el modelo 38 se ha estampado en la prueba aleatoria, así que ese modelo no debería usarse para ninguna transferencia real.

# %% [markdown]
# Pruebas con varios entornos: Vemos cómo se comporta la política en múltiples entornos (varias pruebas simuladas en paralelo), teniendo en cuenta cuál es la desviación de cada uno en test, lo que nos permite inferir si la recompensa es estable para todas las pruebas.

# %%
df_final[df_final['num_envs_test'] != 1].sort_values(by='std_test',ascending=True).reset_index().drop(columns="index")
# Out:
#               id_run_name  num_envs_train  num_envs_test  reward_train  \
# 0  ppo_random_command7_11            2048            256    332.939269
# 1  ppo_random_command7_11            2048             64    332.939269
#
#    reward_test  max_reward_train  max_reward_test  std_train   std_test  \
# 0   220.375893        340.529236        277.76071  13.861933  86.757288
# 1   210.905293        340.529236        277.28497  13.861933  89.000722
#
#    iteration  diff_rw_test_train diferencia(%)
# 0        373         -112.563376       -33.81%
# 1        373         -122.033976       -36.65%

# %% [markdown]
# pruebas:

# %% [markdown]
# C:/Users/Teresa/Desktop/RuralData/IsaacLab/IsaacLab/isaaclab.bat -p C:/Users/Teresa/Documents/GitHub/navsim/isaac_lab/rl_v5_1_0/rsl_rl/train.py --task Isaac-Command5-Aerotaxi-RANDOM-11 --num_envs 8196 --headless
