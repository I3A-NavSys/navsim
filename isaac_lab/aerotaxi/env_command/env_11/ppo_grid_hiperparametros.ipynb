# %%
# Parámetros a configurar:
import os
experiment_name = "command7"
task_name = "Command7"
cfg_dir = "C:/Users/Teresa/Documents/GitHub/navsim/isaac_lab/aerotaxi/env_command/env_11/grid_hiperparametros/cfg_files"
path_resultados = "C:/Users/Teresa/Documents/GitHub/navsim/tmp/tmpTeresa/resultados_grid_command_v7"
isaaclab_bat = "C:/Users/Teresa/Desktop/RuralData/IsaacLab/IsaacLab/isaaclab.bat"
train_script = "C:/Users/Teresa/Documents/GitHub/navsim/isaac_lab/rl_v5_1_0/rsl_rl/train.py"
id_task = f"Isaac-{task_name}-Aerotaxi-RANDOM" # luego se le añade el número de task con el guión (Isaac-Command2-Aerotaxi-RANDOM-34)
play_script = "C:/Users/Teresa/Documents/GitHub/navsim/isaac_lab/rl_v5_1_0/rsl_rl/play.py"
num_iter = "4001"
num_steps_per_env = 100
powershell_script = os.path.join(cfg_dir, "run_all.ps1")

# el num_steps_per_env = 100 también está en el env, al final del todo, y deben tener el mismo valor
# Recuerda iniciar en el init todos los experimentos

# %%
import random
import os

# Si los directorios no existen (el último indicado), lo crea
os.makedirs(cfg_dir, exist_ok=True)
os.makedirs(path_resultados, exist_ok=True)
# Opciones de hiperparámetros
param_options = {
    "init_noise_std": [0.0, 0.1, 0.2, 0.5, 0.8, 1.0],
    "actor_hidden_dims": [[64, 64], [128, 128], [256, 256], [128, 64]],
    "critic_hidden_dims": [[64, 64], [128, 128], [256, 256]],
    "activation": ["relu", "tanh", "elu", "gelu"],
    "value_loss_coef": [0.5, 1.0, 2.0],
    "clip_param": [0.1, 0.2, 0.3],
    "entropy_coef": [0.0, 0.001, 0.01, 0.05],
    "num_learning_epochs": [4, 8, 12],
    "num_mini_batches": [2, 4, 8],
    "learning_rate": [5e-05, 1e-4, 3e-4, 1e-3, 3e-3],
    "gamma": [0.95, 0.98, 0.99],
    "lam": [0.90, 0.95, 0.97],
    "max_grad_norm": [0.5, 1.0, 2.0],
    "desired_kl": [0.005, 0.008, 0.01, 0.02],
}

num_trials = 35  # cantidad de configuraciones

cfg_files = []

for i in range(num_trials):
    run_name = f"ppo_random_{experiment_name}_{i+1}"
    sampled = {k: random.choice(v) for k, v in param_options.items()}

    # Convertir listas a string
    actor_dims = sampled["actor_hidden_dims"]
    critic_dims = sampled["critic_hidden_dims"]

    cfg_content = f"""
from isaaclab.utils import configclass
from isaaclab_rl.rsl_rl import RslRlOnPolicyRunnerCfg, RslRlPpoActorCriticCfg, RslRlPpoAlgorithmCfg

@configclass
class {task_name}PPORunnerCfg(RslRlOnPolicyRunnerCfg):
    num_steps_per_env = {num_steps_per_env} 
    max_iterations = {num_iter}
    save_interval = 100
    experiment_name = "{experiment_name}"
    run_name = "{run_name}"
    resume = False
    empirical_normalization = False
    csv_path_metrics = "{path_resultados}"
    callbacks = True
    policy = RslRlPpoActorCriticCfg(
        init_noise_std={sampled['init_noise_std']},
        actor_hidden_dims={actor_dims},
        critic_hidden_dims={critic_dims},
        activation="{sampled['activation']}",
    )
    algorithm = RslRlPpoAlgorithmCfg(
        value_loss_coef={sampled['value_loss_coef']},
        use_clipped_value_loss=True,
        clip_param={sampled['clip_param']},
        entropy_coef={sampled['entropy_coef']},
        num_learning_epochs={sampled['num_learning_epochs']},
        num_mini_batches={sampled['num_mini_batches']},
        learning_rate={sampled['learning_rate']},
        schedule="adaptive",
        gamma={sampled['gamma']},
        lam={sampled['lam']},
        desired_kl={sampled['desired_kl']},
        max_grad_norm={sampled['max_grad_norm']},
    )
"""
    cfg_path = os.path.join(cfg_dir, f"{run_name}_cfg.py")
    with open(cfg_path, "w") as f:
        f.write(cfg_content.strip())
    cfg_files.append((run_name, cfg_path))

# Crear archivo PowerShell para ejecutar todas las configuraciones
powershell_script = os.path.join(cfg_dir, "run_all.ps1")

num_envs =  [64, 128, 512, 1024, 2048, 4096, 8196] #número de entornos para train (paralelizados)

with open(powershell_script, "w") as f:
    f.write("$ErrorActionPreference = 'Stop'\n\n")
    j = 0
    for run_name, cfg_path in cfg_files:
        # Convertir path a módulo Python (reemplazar / y .py)
        num_envs_i = random.choice(num_envs)
        module_path = cfg_path.replace("/", ".").replace("\\", ".").replace(".py", "")
        f.write(f'Write-Host "Ejecutando {run_name}"\n')
        f.write(f'& "{isaaclab_bat}" -p "{train_script}" --task {id_task}-{j+1} --num_envs {num_envs_i} --headless \n\n')
        j += 1
print("Archivos de configuración generados y script PowerShell listo en:", powershell_script)
# Out:
# Archivos de configuración generados y script PowerShell listo en: C:/Users/Teresa/Documents/GitHub/navsim/isaac_lab/aerotaxi/env_command/env_11/grid_hiperparametros/cfg_files\run_all.ps1

# %%
# Ejecuta el entrenamiento de forma automática
# !powershell -ExecutionPolicy Bypass -File "{powershell_script}"
import subprocess
import sys

# Ruta al script que generaste
powershell_script_path = powershell_script 

print(f"Iniciando ejecución de: {powershell_script_path}\n")

# Ejecutamos el proceso capturando la salida en tiempo real
process = subprocess.Popen(
    ["powershell.exe", "-ExecutionPolicy", "Bypass", "-File", powershell_script_path],
    stdout=subprocess.PIPE,
    stderr=subprocess.STDOUT, # Redirigimos errores a la salida estándar para verlos
    text=True,
    bufsize=1
)

# Leemos la salida línea a línea conforme se genera
try:
    for line in process.stdout:
        print(line, end="") # Imprime la salida de PowerShell en la celda
        sys.stdout.flush()   # Fuerza a Jupyter a mostrar la línea inmediatamente
except KeyboardInterrupt:
    process.kill()
    print("\nEntrenamiento cancelado por el usuario.")

process.wait()
print("\n--- Todos los experimentos han finalizado ---")
# Out:
# Iniciando ejecución de: C:/Users/Teresa/Documents/GitHub/navsim/isaac_lab/aerotaxi/env_command/env_11/grid_hiperparametros/cfg_files\run_all.ps1
#
# Ejecutando ppo_random_command7_11
# [INFO] Using python from: C:\Users\Teresa\miniconda3\envs\env_isaaclab\python.exe
# [INFO][AppLauncher]: Using device: cuda:0
# [INFO][AppLauncher]: Loading experience file: C:\Users\Teresa\miniconda3\envs\env_isaaclab\Lib\site-packages\isaaclab\apps\isaaclab.python.headless.kit
# Loading user config located at: 'c:/users/teresa/miniconda3/envs/env_isaaclab/lib/site-packages/isaacsim/kit/data/Kit/Isaac-Sim/5.1/user.config.json'
# [Info] [carb] Logging to file: c:/users/teresa/miniconda3/envs/env_isaaclab/lib/site-packages/isaacsim/kit/logs/Kit/Isaac-Sim/5.1/kit_20260228_090924.log
# 2026-02-28T08:09:24Z s] [Warning] [omni.usd_config.extension] Enable omni.materialx.libs extension to use MaterialX
# 2026-02-28T08:09:24Z s] [Warning] [carb] Acquiring non optional plugin interface which is not listed as dependency: [omni::physx::IPhysxBenchmarks v1.0] (plugin: <default plugin>), by client: omni.physics.physx.plugin. Add it to CARB_PLUGIN_IMPL_DEPS() macro of a client.
# 2026-02-28T08:09:24Z s] [Warning] [omni.isaac.dynamic_control] omni.isaac.dynamic_control is deprecated as of Isaac Sim 4.5. No action is needed from end-users.
# 2026-02-28T08:09:26Z [2,502ms] [Warning] [gpu.foundation.plugin] Skipping unsupported non-NVIDIA GPU: AMD Radeon(TM) Graphics
# 2026-02-28T08:09:26Z [2,502ms] [Warning] [gpu.foundation.plugin] Skipping unsupported non-NVIDIA GPU: AMD Radeon(TM) Graphics
#
# |---------------------------------------------------------------------------------------------|
# | Driver Version: 581.29        | Graphics API: D3D12
# |=============================================================================================|
# | GPU | Name                             | Active | LDA | GPU Memory | Vendor-ID | LUID       |
# |     |                                  |        |     |            | Device-ID | UUID       |
# |     |                                  |        |     |            | Bus-ID    |            |
# |---------------------------------------------------------------------------------------------|
# | 0   | NVIDIA GeForce RTX 5080          | Yes: 0 |     | 15889   MB | 10de      | 295a0100.. |
# |     |                                  |        |     |            | 2c02      | 0          |
# |     |                                  |        |     |            | 1         |            |
# |---------------------------------------------------------------------------------------------|
# | 1   | AMD Radeon(TM) Graphics          |        |     | 1995    MB | 1002      | 876d0100.. |
# |     |                                  |        |     |            | 13c0      | 0          |
# |     |                                  |        |     |            | N/A       |            |
# |=============================================================================================|
# | OS: Windows 11 Pro, Version: 10.0 (25H2), Build: 26200, Kernel: 10.0.26100.7824
# | Processor: AMD Ryzen 9 9950X 16-Core Processor
# | Cores: 16 | Logical Cores: 32
# |---------------------------------------------------------------------------------------------|
# | Total Memory (MB): 128627 | Free Memory: 101808
# | Total Page/Swap (MB): 136819 | Free Page/Swap: 104218
# |---------------------------------------------------------------------------------------------|
# C:\Users\Teresa\Documents\GitHub\navsim\isaac_lab\aerotaxi\env_command\env_11\flight_plan.py:29: UserWarning: Treat the new Tool classes introduced in v1.5 as experimental for now; the API and rcParam may change in future versions.
#   plt.rcParams["toolbar"] = "toolmanager"
# [INFO]: Parsing configuration from: aerotaxi.env_command.env_11.env:UAVEnvCfg
# [INFO]: Parsing configuration from: aerotaxi.env_command.env_11.grid_hiperparametros.cfg_files.ppo_random_command7_11_cfg:Command7PPORunnerCfg
# [INFO] Logging experiment in directory: C:\Users\Teresa\Documents\GitHub\navsim\isaac_lab\aerotaxi\env_command\env_11\logs\rsl_rl\command7
# Exact experiment name requested from command line: 2026-02-28_09-09-27
# Setting seed: 42
# [INFO]: Base environment:
# 	Environment device    : cuda:0
# 	Environment seed      : 42
# 	Physics step-size     : 0.005
# 	Rendering step-size   : 0.02
# 	Environment step-size : 0.02
# [INFO]: Time taken for scene creation : 1.690808 seconds
# [INFO]: Scene manager:  <class InteractiveScene>
# 	Number of environments: 2048
# 	Environment spacing   : 200.0
# 	Source prim name      : /World/envs/env_0
# 	Global prim paths     : []
# 	Replicate physics     : False
# [INFO]: Starting the simulation. This may take a few seconds. Please wait...
# [INFO]: Time taken for simulation start : 1.492944 seconds
# [INFO] Command Manager:  <CommandManager> contains 1 active terms.
# +--------------------------------------+
# |         Active Command Terms         |
# +-------+-------------+----------------+
# | Index | Name        |      Type      |
# +-------+-------------+----------------+
# |   0   | vel_command | UAVcommandTerm |
# +-------+-------------+----------------+
#
# [INFO] Event Manager:  <EventManager> contains 1 active terms.
# +-----------------------------------+
# | Active Event Terms in Mode: 'reset' |
# +----------+------------------------+
# |  Index   | Name                   |
# +----------+------------------------+
# |    0     | reset_pos              |
# |    1     | randomize_mass         |
# |    2     | randomize_wind         |
# +----------+------------------------+
#
# [INFO] Recorder Manager:  <RecorderManager> contains 0 active terms.
# +---------------------+
# | Active Recorder Terms |
# +-----------+---------+
# |   Index   | Name    |
# +-----------+---------+
# +-----------+---------+
#
# [INFO] Action Manager:  <ActionManager> contains 1 active terms.
# +-----------------------------------+
# |   Active Action Terms (shape: 4)  |
# +--------+-------------+------------+
# | Index  | Name        |  Dimension |
# +--------+-------------+------------+
# |   0    | rotors_vel  |          4 |
# +--------+-------------+------------+
#
# [INFO] Observation Manager: <ObservationManager> contains 2 groups.
# +---------------------------------------------------------+
# | Active Observation Terms in Group: 'policy' (shape: (13,)) |
# +-----------+---------------------------------+-----------+
# |   Index   | Name                            |   Shape   |
# +-----------+---------------------------------+-----------+
# |     0     | dist                            |    (3,)   |
# |     1     | lin_vel                         |    (3,)   |
# |     2     | ang_vel                         |    (3,)   |
# |     3     | height                          |    (1,)   |
# |     4     | projected_gravity               |    (3,)   |
# +-----------+---------------------------------+-----------+
# +---------------------------------------------------------+
# | Active Observation Terms in Group: 'critic' (shape: (13,)) |
# +-----------+---------------------------------+-----------+
# |   Index   | Name                            |   Shape   |
# +-----------+---------------------------------+-----------+
# |     0     | dist                            |    (3,)   |
# |     1     | lin_vel                         |    (3,)   |
# |     2     | ang_vel                         |    (3,)   |
# |     3     | height                          |    (1,)   |
# |     4     | projected_gravity               |    (3,)   |
# +-----------+---------------------------------+-----------+
#
# [INFO] Termination Manager:  <TerminationManager> contains 4 active terms.
# +---------------------------------------+
# |        Active Termination Terms       |
# +-------+--------------------+----------+
# | Index | Name               | Time Out |
# +-------+--------------------+----------+
# |   0   | time_out           |   True   |
# |   1   | below_min_altitude |  False   |
# |   2   | bad_attitude       |  False   |
# |   3   | safety_shutdown    |  False   |
# +-------+--------------------+----------+
#
# [INFO] Reward Manager:  <RewardManager> contains 7 active terms.
# +------------------------------------------+
# |           Active Reward Terms            |
# +-------+-------------------------+--------+
# | Index | Name                    | Weight |
# +-------+-------------------------+--------+
# |   0   | rew_attitude_stability2 |    2.0 |
# |   1   | rew_ang_vel_stability2  |    2.0 |
# |   2   | rew_altitude_hold3      |    8.0 |
# |   3   | rew_vel2                |    2.0 |
# |   4   | rew_vel_z               |    6.0 |
# |   5   | rew_pos2                |    1.0 |
# |   6   | rew_action_rate         |    1.0 |
# +-------+-------------------------+--------+
#
# [INFO] Curriculum Manager:  <CurriculumManager> contains 0 active terms.
# +----------------------+
# | Active Curriculum Terms |
# +-----------+----------+
# |   Index   | Name     |
# +-----------+----------+
# +-----------+----------+
#
# [INFO]: Completed setting up the environment...
# 2026-02-28T08:09:31Z [7,367ms] [Warning] [omni.physx.fabric.plugin] FabricManager::initializePointInstancer mismatched prototypes on point instancer: /Visuals/target_commands.
# C:\Users\Teresa\miniconda3\envs\env_isaaclab\Lib\site-packages\rsl_rl\utils\utils.py:244: UserWarning: The observation configuration dictionary 'obs_groups' must contain the 'policy' key. As an observation group with the name 'policy' was found, this is assumed to be the observation set. Consider adding the 'policy' key to the 'obs_groups' dictionary for clarity. This behavior will be removed in a future version.
#   warnings.warn(
# C:\Users\Teresa\miniconda3\envs\env_isaaclab\Lib\site-packages\rsl_rl\utils\utils.py:282: UserWarning: The observation configuration dictionary 'obs_groups' must contain the 'critic' key. As an observation group with the name 'critic' was found, this is assumed to be the observation set. Consider adding the 'critic' key to the 'obs_groups' dictionary for clarity. This behavior will be removed in a future version.
#   warnings.warn(
# --------------------------------------------------------------------------------
# Resolved observation sets:
# 	 policy :  ['policy']
# 	 critic :  ['critic']
# --------------------------------------------------------------------------------
# Actor MLP: MLP(
#   (0): Linear(in_features=13, out_features=128, bias=True)
#   (1): ELU(alpha=1.0)
#   (2): Linear(in_features=128, out_features=128, bias=True)
#   (3): ELU(alpha=1.0)
#   (4): Linear(in_features=128, out_features=128, bias=True)
#   (5): ELU(alpha=1.0)
#   (6): Linear(in_features=128, out_features=128, bias=True)
#   (7): ELU(alpha=1.0)
#   (8): Linear(in_features=128, out_features=4, bias=True)
# )
# Critic MLP: MLP(
#   (0): Linear(in_features=13, out_features=512, bias=True)
#   (1): ELU(alpha=1.0)
#   (2): Linear(in_features=512, out_features=512, bias=True)
#   (3): ELU(alpha=1.0)
#   (4): Linear(in_features=512, out_features=512, bias=True)
#   (5): ELU(alpha=1.0)
#   (6): Linear(in_features=512, out_features=512, bias=True)
#   (7): ELU(alpha=1.0)
#   (8): Linear(in_features=512, out_features=512, bias=True)
#   (9): ELU(alpha=1.0)
#   (10): Linear(in_features=512, out_features=1, bias=True)
# )
# ################################################################################
#                        Learning iteration 0/4001
#
#                        Computation: 52120 steps/s (collection: 4.553s, learning 0.476s)
#              Mean action noise std: 0.05
#           Mean value_function loss: 55171.5379
#                Mean surrogate loss: 0.1210
#                  Mean entropy loss: -6.1628
#                        Mean reward: -1547.65
#                Mean episode length: 104.39
# Episode_Reward/rew_attitude_stability2: 0.0499
# Episode_Reward/rew_ang_vel_stability2: 0.0816
#  Episode_Reward/rew_altitude_hold3: -13.3239
#            Episode_Reward/rew_vel2: 0.0279
#           Episode_Reward/rew_vel_z: -12.7653
#            Episode_Reward/rew_pos2: 0.0008
#     Episode_Reward/rew_action_rate: -0.0000
#       Episode_Termination/time_out: 0.0427
# Episode_Termination/below_min_altitude: 0.2510
#   Episode_Termination/bad_attitude: 0.0255
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 262144
#                     Iteration time: 5.03s
#                       Time elapsed: 00:00:05
#                                ETA: 05:35:23
#
# Could not find git repository in C:\Users\Teresa\miniconda3\envs\env_isaaclab\Lib\site-packages\rsl_rl\__init__.py. Skipping.
# Storing git diff for 'navsim' in: C:\Users\Teresa\Documents\GitHub\navsim\isaac_lab\aerotaxi\env_command\env_11\logs\rsl_rl\command7\2026-02-28_09-09-27_ppo_random_command7_11\git\navsim.diff
# ################################################################################
#                        Learning iteration 1/4001
#
#                        Computation: 72274 steps/s (collection: 3.270s, learning 0.357s)
#              Mean action noise std: 0.05
#           Mean value_function loss: 55214.7052
#                Mean surrogate loss: 0.0266
#                  Mean entropy loss: -6.1254
#                        Mean reward: -1013.92
#                Mean episode length: 82.51
# Episode_Reward/rew_attitude_stability2: 0.0504
# Episode_Reward/rew_ang_vel_stability2: 0.0874
#  Episode_Reward/rew_altitude_hold3: -17.9680
#            Episode_Reward/rew_vel2: 0.0295
#           Episode_Reward/rew_vel_z: -21.6186
#            Episode_Reward/rew_pos2: 0.0000
#     Episode_Reward/rew_action_rate: -0.0000
#       Episode_Termination/time_out: 0.0072
# Episode_Termination/below_min_altitude: 0.6085
#   Episode_Termination/bad_attitude: 0.3843
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 524288
#                     Iteration time: 3.63s
#                       Time elapsed: 00:00:08
#                                ETA: 04:48:33
#
# ################################################################################
#                        Learning iteration 2/4001
#
#                        Computation: 82194 steps/s (collection: 2.842s, learning 0.347s)
#              Mean action noise std: 0.05
#           Mean value_function loss: 44699.2590
#                Mean surrogate loss: 0.0170
#                  Mean entropy loss: -6.0425
#                        Mean reward: -1137.11
#                Mean episode length: 87.85
# Episode_Reward/rew_attitude_stability2: 0.0539
# Episode_Reward/rew_ang_vel_stability2: 0.0876
#  Episode_Reward/rew_altitude_hold3: -19.3755
#            Episode_Reward/rew_vel2: 0.0306
#           Episode_Reward/rew_vel_z: -22.3423
#            Episode_Reward/rew_pos2: 0.0000
#     Episode_Reward/rew_action_rate: -0.0000
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 0.4524
#   Episode_Termination/bad_attitude: 0.5476
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 786432
#                     Iteration time: 3.19s
#                       Time elapsed: 00:00:11
#                                ETA: 04:23:10
#
# ################################################################################
#                        Learning iteration 3/4001
#
#                        Computation: 84473 steps/s (collection: 2.757s, learning 0.347s)
#              Mean action noise std: 0.05
#           Mean value_function loss: 54553.0631
#                Mean surrogate loss: 0.0126
#                  Mean entropy loss: -5.9774
#                        Mean reward: -1016.82
#                Mean episode length: 84.82
# Episode_Reward/rew_attitude_stability2: 0.0501
# Episode_Reward/rew_ang_vel_stability2: 0.0873
#  Episode_Reward/rew_altitude_hold3: -18.5030
#            Episode_Reward/rew_vel2: 0.0295
#           Episode_Reward/rew_vel_z: -22.0099
#            Episode_Reward/rew_pos2: 0.0000
#     Episode_Reward/rew_action_rate: -0.0000
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 0.4535
#   Episode_Termination/bad_attitude: 0.5465
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 1048576
#                     Iteration time: 3.10s
#                       Time elapsed: 00:00:14
#                                ETA: 04:09:01
#
# ################################################################################
#                        Learning iteration 4/4001
#
#                        Computation: 84557 steps/s (collection: 2.755s, learning 0.345s)
#              Mean action noise std: 0.06
#           Mean value_function loss: 47834.3467
#                Mean surrogate loss: 0.0155
#                  Mean entropy loss: -5.9092
#                        Mean reward: -1046.42
#                Mean episode length: 85.45
# Episode_Reward/rew_attitude_stability2: 0.0525
# Episode_Reward/rew_ang_vel_stability2: 0.0881
#  Episode_Reward/rew_altitude_hold3: -19.5100
#            Episode_Reward/rew_vel2: 0.0306
#           Episode_Reward/rew_vel_z: -22.5790
#            Episode_Reward/rew_pos2: 0.0000
#     Episode_Reward/rew_action_rate: -0.0000
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 0.4562
#   Episode_Termination/bad_attitude: 0.5438
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 1310720
#                     Iteration time: 3.10s
#                       Time elapsed: 00:00:18
#                                ETA: 04:00:28
#
# ################################################################################
#                        Learning iteration 5/4001
#
#                        Computation: 84821 steps/s (collection: 2.742s, learning 0.349s)
#              Mean action noise std: 0.06
#           Mean value_function loss: 53373.2389
#                Mean surrogate loss: 0.0135
#                  Mean entropy loss: -5.8473
#                        Mean reward: -988.44
#                Mean episode length: 83.76
# Episode_Reward/rew_attitude_stability2: 0.0513
# Episode_Reward/rew_ang_vel_stability2: 0.0879
#  Episode_Reward/rew_altitude_hold3: -18.7622
#            Episode_Reward/rew_vel2: 0.0301
#           Episode_Reward/rew_vel_z: -22.0969
#            Episode_Reward/rew_pos2: 0.0000
#     Episode_Reward/rew_action_rate: -0.0000
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 0.4655
#   Episode_Termination/bad_attitude: 0.5345
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 1572864
#                     Iteration time: 3.09s
#                       Time elapsed: 00:00:21
#                                ETA: 03:54:39
#
# ################################################################################
#                        Learning iteration 6/4001
#
#                        Computation: 84957 steps/s (collection: 2.740s, learning 0.345s)
#              Mean action noise std: 0.06
#           Mean value_function loss: 46699.5740
#                Mean surrogate loss: 0.0237
#                  Mean entropy loss: -5.7813
#                        Mean reward: -1004.89
#                Mean episode length: 84.50
# Episode_Reward/rew_attitude_stability2: 0.0528
# Episode_Reward/rew_ang_vel_stability2: 0.0877
#  Episode_Reward/rew_altitude_hold3: -19.2373
#            Episode_Reward/rew_vel2: 0.0304
#           Episode_Reward/rew_vel_z: -22.3181
#            Episode_Reward/rew_pos2: 0.0000
#     Episode_Reward/rew_action_rate: -0.0000
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 0.4553
#   Episode_Termination/bad_attitude: 0.5447
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 1835008
#                     Iteration time: 3.09s
#                       Time elapsed: 00:00:24
#                                ETA: 03:50:25
#
# ################################################################################
#                        Learning iteration 7/4001
#
#                        Computation: 84216 steps/s (collection: 2.767s, learning 0.346s)
#              Mean action noise std: 0.06
#           Mean value_function loss: 50683.5773
#                Mean surrogate loss: 0.0276
#                  Mean entropy loss: -5.6905
#                        Mean reward: -1066.29
#                Mean episode length: 84.71
# Episode_Reward/rew_attitude_stability2: 0.0522
# Episode_Reward/rew_ang_vel_stability2: 0.0875
#  Episode_Reward/rew_altitude_hold3: -18.5797
#            Episode_Reward/rew_vel2: 0.0304
#           Episode_Reward/rew_vel_z: -21.9854
#            Episode_Reward/rew_pos2: 0.0000
#     Episode_Reward/rew_action_rate: -0.0000
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 0.4680
#   Episode_Termination/bad_attitude: 0.5320
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 2097152
#                     Iteration time: 3.11s
#                       Time elapsed: 00:00:27
#                                ETA: 03:47:28
#
# ################################################################################
#                        Learning iteration 8/4001
#
#                        Computation: 84270 steps/s (collection: 2.764s, learning 0.347s)
#              Mean action noise std: 0.06
#           Mean value_function loss: 46266.7261
#                Mean surrogate loss: 0.0120
#                  Mean entropy loss: -5.6227
#                        Mean reward: -936.20
#                Mean episode length: 84.06
# Episode_Reward/rew_attitude_stability2: 0.0528
# Episode_Reward/rew_ang_vel_stability2: 0.0873
#  Episode_Reward/rew_altitude_hold3: -18.9623
#            Episode_Reward/rew_vel2: 0.0307
#           Episode_Reward/rew_vel_z: -22.1982
#            Episode_Reward/rew_pos2: 0.0000
#     Episode_Reward/rew_action_rate: -0.0000
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 0.4588
#   Episode_Termination/bad_attitude: 0.5412
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 2359296
#                     Iteration time: 3.11s
#                       Time elapsed: 00:00:30
#                                ETA: 03:45:09
#
# ################################################################################
#                        Learning iteration 9/4001
#
#                        Computation: 84616 steps/s (collection: 2.753s, learning 0.345s)
#              Mean action noise std: 0.06
#           Mean value_function loss: 46917.7959
#                Mean surrogate loss: 0.0208
#                  Mean entropy loss: -5.5524
#                        Mean reward: -977.70
#                Mean episode length: 84.29
# Episode_Reward/rew_attitude_stability2: 0.0513
# Episode_Reward/rew_ang_vel_stability2: 0.0868
#  Episode_Reward/rew_altitude_hold3: -18.1909
#            Episode_Reward/rew_vel2: 0.0304
#           Episode_Reward/rew_vel_z: -21.7642
#            Episode_Reward/rew_pos2: 0.0000
#     Episode_Reward/rew_action_rate: -0.0000
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 0.4413
#   Episode_Termination/bad_attitude: 0.5587
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 2621440
#                     Iteration time: 3.10s
#                       Time elapsed: 00:00:33
#                                ETA: 03:43:11
#
# ################################################################################
#                        Learning iteration 10/4001
#
#                        Computation: 84664 steps/s (collection: 2.751s, learning 0.345s)
#              Mean action noise std: 0.06
#           Mean value_function loss: 44926.9152
#                Mean surrogate loss: 0.0209
#                  Mean entropy loss: -5.4738
#                        Mean reward: -960.76
#                Mean episode length: 83.72
# Episode_Reward/rew_attitude_stability2: 0.0524
# Episode_Reward/rew_ang_vel_stability2: 0.0867
#  Episode_Reward/rew_altitude_hold3: -18.4755
#            Episode_Reward/rew_vel2: 0.0307
#           Episode_Reward/rew_vel_z: -21.8836
#            Episode_Reward/rew_pos2: 0.0000
#     Episode_Reward/rew_action_rate: -0.0000
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 0.4363
#   Episode_Termination/bad_attitude: 0.5637
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 2883584
#                     Iteration time: 3.10s
#                       Time elapsed: 00:00:36
#                                ETA: 03:41:34
#
# ################################################################################
#                        Learning iteration 11/4001
#
#                        Computation: 84968 steps/s (collection: 2.741s, learning 0.345s)
#              Mean action noise std: 0.06
#           Mean value_function loss: 45849.2618
#                Mean surrogate loss: 0.0716
#                  Mean entropy loss: -5.4045
#                        Mean reward: -975.86
#                Mean episode length: 83.48
# Episode_Reward/rew_attitude_stability2: 0.0510
# Episode_Reward/rew_ang_vel_stability2: 0.0861
#  Episode_Reward/rew_altitude_hold3: -18.2549
#            Episode_Reward/rew_vel2: 0.0303
#           Episode_Reward/rew_vel_z: -21.8559
#            Episode_Reward/rew_pos2: 0.0000
#     Episode_Reward/rew_action_rate: -0.0000
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 0.4218
#   Episode_Termination/bad_attitude: 0.5782
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 3145728
#                     Iteration time: 3.09s
#                       Time elapsed: 00:00:39
#                                ETA: 03:40:09
#
# ################################################################################
#                        Learning iteration 12/4001
#
#                        Computation: 84835 steps/s (collection: 2.744s, learning 0.346s)
#              Mean action noise std: 0.07
#           Mean value_function loss: 42217.3789
#                Mean surrogate loss: 0.0427
#                  Mean entropy loss: -5.2572
#                        Mean reward: -949.09
#                Mean episode length: 83.57
# Episode_Reward/rew_attitude_stability2: 0.0510
# Episode_Reward/rew_ang_vel_stability2: 0.0849
#  Episode_Reward/rew_altitude_hold3: -17.8584
#            Episode_Reward/rew_vel2: 0.0305
#           Episode_Reward/rew_vel_z: -21.5606
#            Episode_Reward/rew_pos2: 0.0000
#     Episode_Reward/rew_action_rate: -0.0000
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 0.4226
#   Episode_Termination/bad_attitude: 0.5774
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 3407872
#                     Iteration time: 3.09s
#                       Time elapsed: 00:00:42
#                                ETA: 03:38:58
#
# ################################################################################
#                        Learning iteration 13/4001
#
#                        Computation: 85259 steps/s (collection: 2.729s, learning 0.346s)
#              Mean action noise std: 0.07
#           Mean value_function loss: 42706.8258
#                Mean surrogate loss: 0.0804
#                  Mean entropy loss: -5.1099
#                        Mean reward: -1012.30
#                Mean episode length: 85.26
# Episode_Reward/rew_attitude_stability2: 0.0510
# Episode_Reward/rew_ang_vel_stability2: 0.0837
#  Episode_Reward/rew_altitude_hold3: -17.4982
#            Episode_Reward/rew_vel2: 0.0304
#           Episode_Reward/rew_vel_z: -21.2501
#            Episode_Reward/rew_pos2: 0.0000
#     Episode_Reward/rew_action_rate: -0.0000
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 0.4037
#   Episode_Termination/bad_attitude: 0.5963
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 3670016
#                     Iteration time: 3.07s
#                       Time elapsed: 00:00:45
#                                ETA: 03:37:52
#
# ################################################################################
#                        Learning iteration 14/4001
#
#                        Computation: 84914 steps/s (collection: 2.740s, learning 0.347s)
#              Mean action noise std: 0.07
#           Mean value_function loss: 36514.2186
#                Mean surrogate loss: 0.0168
#                  Mean entropy loss: -4.9796
#                        Mean reward: -964.65
#                Mean episode length: 81.82
# Episode_Reward/rew_attitude_stability2: 0.0500
# Episode_Reward/rew_ang_vel_stability2: 0.0810
#  Episode_Reward/rew_altitude_hold3: -16.3722
#            Episode_Reward/rew_vel2: 0.0304
#           Episode_Reward/rew_vel_z: -20.4601
#            Episode_Reward/rew_pos2: 0.0000
#     Episode_Reward/rew_action_rate: -0.0000
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 0.3723
#   Episode_Termination/bad_attitude: 0.6277
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 3932160
#                     Iteration time: 3.09s
#                       Time elapsed: 00:00:48
#                                ETA: 03:36:58
#
# ################################################################################
#                        Learning iteration 15/4001
#
#                        Computation: 84502 steps/s (collection: 2.757s, learning 0.346s)
#              Mean action noise std: 0.07
#           Mean value_function loss: 35932.3781
#                Mean surrogate loss: 0.0250
#                  Mean entropy loss: -4.8983
#                        Mean reward: -888.31
#                Mean episode length: 81.77
# Episode_Reward/rew_attitude_stability2: 0.0493
# Episode_Reward/rew_ang_vel_stability2: 0.0797
#  Episode_Reward/rew_altitude_hold3: -15.7644
#            Episode_Reward/rew_vel2: 0.0306
#           Episode_Reward/rew_vel_z: -20.0527
#            Episode_Reward/rew_pos2: 0.0000
#     Episode_Reward/rew_action_rate: -0.0000
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 0.3364
#   Episode_Termination/bad_attitude: 0.6636
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 4194304
#                     Iteration time: 3.10s
#                       Time elapsed: 00:00:52
#                                ETA: 03:36:15
#
# ################################################################################
#                        Learning iteration 16/4001
#
#                        Computation: 84449 steps/s (collection: 2.759s, learning 0.346s)
#              Mean action noise std: 0.07
#           Mean value_function loss: 36332.0772
#                Mean surrogate loss: 0.0124
#                  Mean entropy loss: -4.8146
#                        Mean reward: -970.34
#                Mean episode length: 82.23
# Episode_Reward/rew_attitude_stability2: 0.0493
# Episode_Reward/rew_ang_vel_stability2: 0.0810
#  Episode_Reward/rew_altitude_hold3: -15.9755
#            Episode_Reward/rew_vel2: 0.0305
#           Episode_Reward/rew_vel_z: -20.2471
#            Episode_Reward/rew_pos2: 0.0000
#     Episode_Reward/rew_action_rate: -0.0000
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 0.3295
#   Episode_Termination/bad_attitude: 0.6705
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 4456448
#                     Iteration time: 3.10s
#                       Time elapsed: 00:00:55
#                                ETA: 03:35:36
#
# ################################################################################
#                        Learning iteration 17/4001
#
#                        Computation: 84512 steps/s (collection: 2.756s, learning 0.346s)
#              Mean action noise std: 0.07
#           Mean value_function loss: 39734.4752
#                Mean surrogate loss: 0.0291
#                  Mean entropy loss: -4.7384
#                        Mean reward: -982.76
#                Mean episode length: 83.70
# Episode_Reward/rew_attitude_stability2: 0.0506
# Episode_Reward/rew_ang_vel_stability2: 0.0835
#  Episode_Reward/rew_altitude_hold3: -17.2494
#            Episode_Reward/rew_vel2: 0.0304
#           Episode_Reward/rew_vel_z: -21.1174
#            Episode_Reward/rew_pos2: 0.0000
#     Episode_Reward/rew_action_rate: -0.0000
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 0.3883
#   Episode_Termination/bad_attitude: 0.6117
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 4718592
#                     Iteration time: 3.10s
#                       Time elapsed: 00:00:58
#                                ETA: 03:35:01
#
# ################################################################################
#                        Learning iteration 18/4001
#
#                        Computation: 85734 steps/s (collection: 2.712s, learning 0.345s)
#              Mean action noise std: 0.08
#           Mean value_function loss: 40845.4508
#                Mean surrogate loss: 0.0013
#                  Mean entropy loss: -4.6461
#                        Mean reward: -987.78
#                Mean episode length: 83.20
# Episode_Reward/rew_attitude_stability2: 0.0513
# Episode_Reward/rew_ang_vel_stability2: 0.0848
#  Episode_Reward/rew_altitude_hold3: -17.7732
#            Episode_Reward/rew_vel2: 0.0307
#           Episode_Reward/rew_vel_z: -21.3998
#            Episode_Reward/rew_pos2: 0.0000
#     Episode_Reward/rew_action_rate: -0.0000
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 0.3982
#   Episode_Termination/bad_attitude: 0.6018
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 4980736
#                     Iteration time: 3.06s
#                       Time elapsed: 00:01:01
#                                ETA: 03:34:20
#
# ################################################################################
#                        Learning iteration 19/4001
#
#                        Computation: 85040 steps/s (collection: 2.737s, learning 0.346s)
#              Mean action noise std: 0.08
#           Mean value_function loss: 40266.8935
#                Mean surrogate loss: 0.0017
#                  Mean entropy loss: -4.5799
#                        Mean reward: -954.71
#                Mean episode length: 83.53
# Episode_Reward/rew_attitude_stability2: 0.0513
# Episode_Reward/rew_ang_vel_stability2: 0.0850
#  Episode_Reward/rew_altitude_hold3: -17.9462
#            Episode_Reward/rew_vel2: 0.0305
#           Episode_Reward/rew_vel_z: -21.5014
#            Episode_Reward/rew_pos2: 0.0000
#     Episode_Reward/rew_action_rate: -0.0000
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 0.4216
#   Episode_Termination/bad_attitude: 0.5784
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 5242880
#                     Iteration time: 3.08s
#                       Time elapsed: 00:01:04
#                                ETA: 03:33:47
#
# ################################################################################
#                        Learning iteration 20/4001
#
#                        Computation: 85052 steps/s (collection: 2.734s, learning 0.348s)
#              Mean action noise std: 0.08
#           Mean value_function loss: 38784.0868
#                Mean surrogate loss: 0.0216
#                  Mean entropy loss: -4.5143
#                        Mean reward: -961.88
#                Mean episode length: 82.99
# Episode_Reward/rew_attitude_stability2: 0.0516
# Episode_Reward/rew_ang_vel_stability2: 0.0844
#  Episode_Reward/rew_altitude_hold3: -17.5709
#            Episode_Reward/rew_vel2: 0.0309
#           Episode_Reward/rew_vel_z: -21.2318
#            Episode_Reward/rew_pos2: 0.0000
#     Episode_Reward/rew_action_rate: -0.0000
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 0.4235
#   Episode_Termination/bad_attitude: 0.5765
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 5505024
#                     Iteration time: 3.08s
#                       Time elapsed: 00:01:07
#                                ETA: 03:33:18
#
# ################################################################################
#                        Learning iteration 21/4001
#
#                        Computation: 84971 steps/s (collection: 2.738s, learning 0.347s)
#              Mean action noise std: 0.08
#           Mean value_function loss: 37718.7087
#                Mean surrogate loss: 0.0033
#                  Mean entropy loss: -4.4372
#                        Mean reward: -985.67
#                Mean episode length: 83.76
# Episode_Reward/rew_attitude_stability2: 0.0508
# Episode_Reward/rew_ang_vel_stability2: 0.0840
#  Episode_Reward/rew_altitude_hold3: -17.3852
#            Episode_Reward/rew_vel2: 0.0304
#           Episode_Reward/rew_vel_z: -21.1889
#            Episode_Reward/rew_pos2: 0.0000
#     Episode_Reward/rew_action_rate: -0.0000
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 0.3961
#   Episode_Termination/bad_attitude: 0.6039
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 5767168
#                     Iteration time: 3.09s
#                       Time elapsed: 00:01:10
#                                ETA: 03:32:51
#
# ################################################################################
#                        Learning iteration 22/4001
#
#                        Computation: 84243 steps/s (collection: 2.766s, learning 0.346s)
#              Mean action noise std: 0.08
#           Mean value_function loss: 37968.6072
#                Mean surrogate loss: 0.0093
#                  Mean entropy loss: -4.3875
#                        Mean reward: -953.23
#                Mean episode length: 83.58
# Episode_Reward/rew_attitude_stability2: 0.0502
# Episode_Reward/rew_ang_vel_stability2: 0.0840
#  Episode_Reward/rew_altitude_hold3: -17.5520
#            Episode_Reward/rew_vel2: 0.0301
#           Episode_Reward/rew_vel_z: -21.3905
#            Episode_Reward/rew_pos2: 0.0000
#     Episode_Reward/rew_action_rate: -0.0000
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 0.3890
#   Episode_Termination/bad_attitude: 0.6110
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 6029312
#                     Iteration time: 3.11s
#                       Time elapsed: 00:01:13
#                                ETA: 03:32:31
#
# ################################################################################
#                        Learning iteration 23/4001
#
#                        Computation: 84627 steps/s (collection: 2.751s, learning 0.347s)
#              Mean action noise std: 0.08
#           Mean value_function loss: 37864.8693
#                Mean surrogate loss: 0.0005
#                  Mean entropy loss: -4.3312
#                        Mean reward: -1007.50
#                Mean episode length: 83.87
# Episode_Reward/rew_attitude_stability2: 0.0508
# Episode_Reward/rew_ang_vel_stability2: 0.0845
#  Episode_Reward/rew_altitude_hold3: -17.7554
#            Episode_Reward/rew_vel2: 0.0305
#           Episode_Reward/rew_vel_z: -21.4615
#            Episode_Reward/rew_pos2: 0.0000
#     Episode_Reward/rew_action_rate: -0.0000
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 0.3927
#   Episode_Termination/bad_attitude: 0.6073
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 6291456
#                     Iteration time: 3.10s
#                       Time elapsed: 00:01:16
#                                ETA: 03:32:10
#
# ################################################################################
#                        Learning iteration 24/4001
#
#                        Computation: 84028 steps/s (collection: 2.774s, learning 0.346s)
#              Mean action noise std: 0.08
#           Mean value_function loss: 37171.5441
#                Mean surrogate loss: 0.0003
#                  Mean entropy loss: -4.2699
#                        Mean reward: -994.02
#                Mean episode length: 83.61
# Episode_Reward/rew_attitude_stability2: 0.0510
# Episode_Reward/rew_ang_vel_stability2: 0.0847
#  Episode_Reward/rew_altitude_hold3: -17.7505
#            Episode_Reward/rew_vel2: 0.0305
#           Episode_Reward/rew_vel_z: -21.4133
#            Episode_Reward/rew_pos2: 0.0000
#     Episode_Reward/rew_action_rate: -0.0000
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 0.4095
#   Episode_Termination/bad_attitude: 0.5905
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 6553600
#                     Iteration time: 3.12s
#                       Time elapsed: 00:01:19
#                                ETA: 03:31:54
#
# ################################################################################
#                        Learning iteration 25/4001
#
#                        Computation: 85455 steps/s (collection: 2.719s, learning 0.349s)
#              Mean action noise std: 0.08
#           Mean value_function loss: 36787.8201
#                Mean surrogate loss: 0.0000
#                  Mean entropy loss: -4.2188
#                        Mean reward: -938.68
#                Mean episode length: 83.23
# Episode_Reward/rew_attitude_stability2: 0.0509
# Episode_Reward/rew_ang_vel_stability2: 0.0847
#  Episode_Reward/rew_altitude_hold3: -17.6710
#            Episode_Reward/rew_vel2: 0.0302
#           Episode_Reward/rew_vel_z: -21.4040
#            Episode_Reward/rew_pos2: 0.0000
#     Episode_Reward/rew_action_rate: -0.0000
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 0.4090
#   Episode_Termination/bad_attitude: 0.5910
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 6815744
#                     Iteration time: 3.07s
#                       Time elapsed: 00:01:22
#                                ETA: 03:31:31
#
# ################################################################################
#                        Learning iteration 26/4001
#
#                        Computation: 85763 steps/s (collection: 2.712s, learning 0.345s)
#              Mean action noise std: 0.09
#           Mean value_function loss: 35827.2898
#                Mean surrogate loss: -0.0000
#                  Mean entropy loss: -4.1683
#                        Mean reward: -1000.12
#                Mean episode length: 83.31
# Episode_Reward/rew_attitude_stability2: 0.0513
# Episode_Reward/rew_ang_vel_stability2: 0.0846
#  Episode_Reward/rew_altitude_hold3: -17.8950
#            Episode_Reward/rew_vel2: 0.0302
#           Episode_Reward/rew_vel_z: -21.4749
#            Episode_Reward/rew_pos2: 0.0000
#     Episode_Reward/rew_action_rate: -0.0000
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 0.4163
#   Episode_Termination/bad_attitude: 0.5837
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 7077888
#                     Iteration time: 3.06s
#                       Time elapsed: 00:01:26
#                                ETA: 03:31:08
#
# ################################################################################
#                        Learning iteration 27/4001
#
#                        Computation: 84709 steps/s (collection: 2.749s, learning 0.346s)
#              Mean action noise std: 0.09
#           Mean value_function loss: 35202.9637
#                Mean surrogate loss: 0.0001
#                  Mean entropy loss: -4.1207
#                        Mean reward: -965.33
#                Mean episode length: 84.09
# Episode_Reward/rew_attitude_stability2: 0.0508
# Episode_Reward/rew_ang_vel_stability2: 0.0846
#  Episode_Reward/rew_altitude_hold3: -17.7521
#            Episode_Reward/rew_vel2: 0.0306
#           Episode_Reward/rew_vel_z: -21.4397
#            Episode_Reward/rew_pos2: 0.0000
#     Episode_Reward/rew_action_rate: -0.0000
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 0.3996
#   Episode_Termination/bad_attitude: 0.6004
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 7340032
#                     Iteration time: 3.09s
#                       Time elapsed: 00:01:29
#                                ETA: 03:30:52
#
# ################################################################################
#                        Learning iteration 28/4001
#
#                        Computation: 85372 steps/s (collection: 2.724s, learning 0.346s)
#              Mean action noise std: 0.09
#           Mean value_function loss: 33512.3439
#                Mean surrogate loss: 0.0000
#                  Mean entropy loss: -4.0659
#                        Mean reward: -956.38
#                Mean episode length: 83.07
# Episode_Reward/rew_attitude_stability2: 0.0517
# Episode_Reward/rew_ang_vel_stability2: 0.0847
#  Episode_Reward/rew_altitude_hold3: -17.3960
#            Episode_Reward/rew_vel2: 0.0308
#           Episode_Reward/rew_vel_z: -21.0652
#            Episode_Reward/rew_pos2: 0.0000
#     Episode_Reward/rew_action_rate: -0.0000
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 0.4002
#   Episode_Termination/bad_attitude: 0.5998
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 7602176
#                     Iteration time: 3.07s
#                       Time elapsed: 00:01:32
#                                ETA: 03:30:33
#
# ################################################################################
#                        Learning iteration 29/4001
#
#                        Computation: 84460 steps/s (collection: 2.758s, learning 0.346s)
#              Mean action noise std: 0.09
# ...
#                Mean surrogate loss: -0.0002
#                  Mean entropy loss: 15.5918
#                        Mean reward: -52.28
#                Mean episode length: 30.16
# Episode_Reward/rew_attitude_stability2: 0.0173
# Episode_Reward/rew_ang_vel_stability2: 0.0094
#  Episode_Reward/rew_altitude_hold3: -0.2023
#            Episode_Reward/rew_vel2: 0.0232
#           Episode_Reward/rew_vel_z: -1.6281
#            Episode_Reward/rew_pos2: 0.0000
#     Episode_Reward/rew_action_rate: -0.2920
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 0.0000
#   Episode_Termination/bad_attitude: 1.0000
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 1045692416
#                     Iteration time: 3.91s
#                       Time elapsed: 04:15:09
#                                ETA: 00:00:49
#
# ################################################################################
#                       Learning iteration 3989/4001
#
#                        Computation: 66033 steps/s (collection: 3.617s, learning 0.353s)
#              Mean action noise std: 11.92
#           Mean value_function loss: 5.3657
#                Mean surrogate loss: -0.0002
#                  Mean entropy loss: 15.5906
#                        Mean reward: -49.84
#                Mean episode length: 30.04
# Episode_Reward/rew_attitude_stability2: 0.0172
# Episode_Reward/rew_ang_vel_stability2: 0.0094
#  Episode_Reward/rew_altitude_hold3: -0.2020
#            Episode_Reward/rew_vel2: 0.0232
#           Episode_Reward/rew_vel_z: -1.6260
#            Episode_Reward/rew_pos2: 0.0000
#     Episode_Reward/rew_action_rate: -0.2920
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 0.0000
#   Episode_Termination/bad_attitude: 1.0000
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 1045954560
#                     Iteration time: 3.97s
#                       Time elapsed: 04:15:13
#                                ETA: 00:00:46
#
# ################################################################################
#                       Learning iteration 3990/4001
#
#                        Computation: 66875 steps/s (collection: 3.566s, learning 0.354s)
#              Mean action noise std: 11.92
#           Mean value_function loss: 5.5331
#                Mean surrogate loss: -0.0001
#                  Mean entropy loss: 15.5895
#                        Mean reward: -51.58
#                Mean episode length: 30.09
# Episode_Reward/rew_attitude_stability2: 0.0172
# Episode_Reward/rew_ang_vel_stability2: 0.0094
#  Episode_Reward/rew_altitude_hold3: -0.2041
#            Episode_Reward/rew_vel2: 0.0229
#           Episode_Reward/rew_vel_z: -1.6393
#            Episode_Reward/rew_pos2: 0.0000
#     Episode_Reward/rew_action_rate: -0.2917
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 0.0000
#   Episode_Termination/bad_attitude: 1.0000
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 1046216704
#                     Iteration time: 3.92s
#                       Time elapsed: 04:15:17
#                                ETA: 00:00:42
#
# ################################################################################
#                       Learning iteration 3991/4001
#
#                        Computation: 66292 steps/s (collection: 3.600s, learning 0.355s)
#              Mean action noise std: 11.92
#           Mean value_function loss: 5.6893
#                Mean surrogate loss: -0.0001
#                  Mean entropy loss: 15.5888
#                        Mean reward: -48.67
#                Mean episode length: 30.08
# Episode_Reward/rew_attitude_stability2: 0.0170
# Episode_Reward/rew_ang_vel_stability2: 0.0093
#  Episode_Reward/rew_altitude_hold3: -0.2018
#            Episode_Reward/rew_vel2: 0.0231
#           Episode_Reward/rew_vel_z: -1.6258
#            Episode_Reward/rew_pos2: 0.0000
#     Episode_Reward/rew_action_rate: -0.2912
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 0.0000
#   Episode_Termination/bad_attitude: 1.0000
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 1046478848
#                     Iteration time: 3.95s
#                       Time elapsed: 04:15:21
#                                ETA: 00:00:38
#
# ################################################################################
#                       Learning iteration 3992/4001
#
#                        Computation: 67739 steps/s (collection: 3.517s, learning 0.353s)
#              Mean action noise std: 11.92
#           Mean value_function loss: 6.1192
#                Mean surrogate loss: -0.0001
#                  Mean entropy loss: 15.5882
#                        Mean reward: -53.41
#                Mean episode length: 30.48
# Episode_Reward/rew_attitude_stability2: 0.0171
# Episode_Reward/rew_ang_vel_stability2: 0.0094
#  Episode_Reward/rew_altitude_hold3: -0.2038
#            Episode_Reward/rew_vel2: 0.0230
#           Episode_Reward/rew_vel_z: -1.6372
#            Episode_Reward/rew_pos2: 0.0000
#     Episode_Reward/rew_action_rate: -0.2923
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 0.0000
#   Episode_Termination/bad_attitude: 1.0000
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 1046740992
#                     Iteration time: 3.87s
#                       Time elapsed: 04:15:25
#                                ETA: 00:00:34
#
# ################################################################################
#                       Learning iteration 3993/4001
#
#                        Computation: 67331 steps/s (collection: 3.538s, learning 0.356s)
#              Mean action noise std: 11.92
#           Mean value_function loss: 6.3552
#                Mean surrogate loss: -0.0001
#                  Mean entropy loss: 15.5879
#                        Mean reward: -54.02
#                Mean episode length: 30.29
# Episode_Reward/rew_attitude_stability2: 0.0171
# Episode_Reward/rew_ang_vel_stability2: 0.0094
#  Episode_Reward/rew_altitude_hold3: -0.2027
#            Episode_Reward/rew_vel2: 0.0232
#           Episode_Reward/rew_vel_z: -1.6335
#            Episode_Reward/rew_pos2: 0.0000
#     Episode_Reward/rew_action_rate: -0.2927
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 0.0000
#   Episode_Termination/bad_attitude: 1.0000
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 1047003136
#                     Iteration time: 3.89s
#                       Time elapsed: 04:15:29
#                                ETA: 00:00:30
#
# ################################################################################
#                       Learning iteration 3994/4001
#
#                        Computation: 66058 steps/s (collection: 3.610s, learning 0.358s)
#              Mean action noise std: 11.92
#           Mean value_function loss: 6.7575
#                Mean surrogate loss: -0.0002
#                  Mean entropy loss: 15.5876
#                        Mean reward: -50.17
#                Mean episode length: 29.86
# Episode_Reward/rew_attitude_stability2: 0.0172
# Episode_Reward/rew_ang_vel_stability2: 0.0093
#  Episode_Reward/rew_altitude_hold3: -0.2005
#            Episode_Reward/rew_vel2: 0.0232
#           Episode_Reward/rew_vel_z: -1.6202
#            Episode_Reward/rew_pos2: 0.0000
#     Episode_Reward/rew_action_rate: -0.2926
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 0.0000
#   Episode_Termination/bad_attitude: 1.0000
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 1047265280
#                     Iteration time: 3.97s
#                       Time elapsed: 04:15:33
#                                ETA: 00:00:26
#
# ################################################################################
#                       Learning iteration 3995/4001
#
#                        Computation: 65252 steps/s (collection: 3.612s, learning 0.405s)
#              Mean action noise std: 11.93
#           Mean value_function loss: 7.3816
#                Mean surrogate loss: 0.0035
#                  Mean entropy loss: 15.5886
#                        Mean reward: -53.62
#                Mean episode length: 30.33
# Episode_Reward/rew_attitude_stability2: 0.0172
# Episode_Reward/rew_ang_vel_stability2: 0.0093
#  Episode_Reward/rew_altitude_hold3: -0.2034
#            Episode_Reward/rew_vel2: 0.0231
#           Episode_Reward/rew_vel_z: -1.6340
#            Episode_Reward/rew_pos2: 0.0000
#     Episode_Reward/rew_action_rate: -0.2919
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 0.0000
#   Episode_Termination/bad_attitude: 1.0000
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 1047527424
#                     Iteration time: 4.02s
#                       Time elapsed: 04:15:37
#                                ETA: 00:00:23
#
# ################################################################################
#                       Learning iteration 3996/4001
#
#                        Computation: 65891 steps/s (collection: 3.624s, learning 0.354s)
#              Mean action noise std: 11.93
#           Mean value_function loss: 6.8233
#                Mean surrogate loss: 0.0001
#                  Mean entropy loss: 15.5913
#                        Mean reward: -50.94
#                Mean episode length: 29.93
# Episode_Reward/rew_attitude_stability2: 0.0172
# Episode_Reward/rew_ang_vel_stability2: 0.0094
#  Episode_Reward/rew_altitude_hold3: -0.2037
#            Episode_Reward/rew_vel2: 0.0231
#           Episode_Reward/rew_vel_z: -1.6342
#            Episode_Reward/rew_pos2: 0.0000
#     Episode_Reward/rew_action_rate: -0.2929
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 0.0000
#   Episode_Termination/bad_attitude: 1.0000
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 1047789568
#                     Iteration time: 3.98s
#                       Time elapsed: 04:15:41
#                                ETA: 00:00:19
#
# ################################################################################
#                       Learning iteration 3997/4001
#
#                        Computation: 67443 steps/s (collection: 3.533s, learning 0.354s)
#              Mean action noise std: 11.93
#           Mean value_function loss: 5.6077
#                Mean surrogate loss: -0.0001
#                  Mean entropy loss: 15.5911
#                        Mean reward: -48.67
#                Mean episode length: 30.32
# Episode_Reward/rew_attitude_stability2: 0.0172
# Episode_Reward/rew_ang_vel_stability2: 0.0094
#  Episode_Reward/rew_altitude_hold3: -0.2028
#            Episode_Reward/rew_vel2: 0.0232
#           Episode_Reward/rew_vel_z: -1.6279
#            Episode_Reward/rew_pos2: 0.0000
#     Episode_Reward/rew_action_rate: -0.2932
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 0.0000
#   Episode_Termination/bad_attitude: 1.0000
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 1048051712
#                     Iteration time: 3.89s
#                       Time elapsed: 04:15:45
#                                ETA: 00:00:15
#
# ################################################################################
#                       Learning iteration 3998/4001
#
#                        Computation: 67748 steps/s (collection: 3.513s, learning 0.357s)
#              Mean action noise std: 11.92
#           Mean value_function loss: 5.7280
#                Mean surrogate loss: -0.0002
#                  Mean entropy loss: 15.5900
#                        Mean reward: -51.10
#                Mean episode length: 30.48
# Episode_Reward/rew_attitude_stability2: 0.0171
# Episode_Reward/rew_ang_vel_stability2: 0.0094
#  Episode_Reward/rew_altitude_hold3: -0.2062
#            Episode_Reward/rew_vel2: 0.0230
#           Episode_Reward/rew_vel_z: -1.6462
#            Episode_Reward/rew_pos2: 0.0000
#     Episode_Reward/rew_action_rate: -0.2927
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 0.0000
#   Episode_Termination/bad_attitude: 1.0000
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 1048313856
#                     Iteration time: 3.87s
#                       Time elapsed: 04:15:49
#                                ETA: 00:00:11
#
# ################################################################################
#                       Learning iteration 3999/4001
#
#                        Computation: 66426 steps/s (collection: 3.587s, learning 0.359s)
#              Mean action noise std: 11.92
#           Mean value_function loss: 5.4757
#                Mean surrogate loss: -0.0002
#                  Mean entropy loss: 15.5893
#                        Mean reward: -50.50
#                Mean episode length: 30.21
# Episode_Reward/rew_attitude_stability2: 0.0171
# Episode_Reward/rew_ang_vel_stability2: 0.0094
#  Episode_Reward/rew_altitude_hold3: -0.2039
#            Episode_Reward/rew_vel2: 0.0231
#           Episode_Reward/rew_vel_z: -1.6370
#            Episode_Reward/rew_pos2: 0.0000
#     Episode_Reward/rew_action_rate: -0.2917
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 0.0000
#   Episode_Termination/bad_attitude: 1.0000
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 1048576000
#                     Iteration time: 3.95s
#                       Time elapsed: 04:15:53
#                                ETA: 00:00:07
#
# ################################################################################
#                       Learning iteration 4000/4001
#
#                        Computation: 68012 steps/s (collection: 3.501s, learning 0.353s)
#              Mean action noise std: 11.92
#           Mean value_function loss: 5.5585
#                Mean surrogate loss: -0.0001
#                  Mean entropy loss: 15.5890
#                        Mean reward: -52.48
#                Mean episode length: 30.03
# Episode_Reward/rew_attitude_stability2: 0.0173
# Episode_Reward/rew_ang_vel_stability2: 0.0094
#  Episode_Reward/rew_altitude_hold3: -0.2048
#            Episode_Reward/rew_vel2: 0.0232
#           Episode_Reward/rew_vel_z: -1.6378
#            Episode_Reward/rew_pos2: 0.0000
#     Episode_Reward/rew_action_rate: -0.2920
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 0.0000
#   Episode_Termination/bad_attitude: 1.0000
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 1048838144
#                     Iteration time: 3.85s
#                       Time elapsed: 04:15:57
#                                ETA: 00:00:03
#
#
# --- Todos los experimentos han finalizado ---

# %% [markdown]
# ``Análisis de los datos``

# %%
import csv
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

seed = 42
n=5

df_results_grid_actions = pd.read_csv(path_resultados+"/resultados_grid_PPO.csv")

# %%
def get_group(value):
    if f"_{experiment_name}" in value:
        return task_name

df_results_grid_actions["tarea"] = df_results_grid_actions["id_run_name"].apply(get_group)

# %%
df_copy = df_results_grid_actions.copy()
df_results_grid_actions.sample(n, random_state=seed)
# Out:
#               id_run_name  iteration     reward  max_reward  std_reward  \
# 0  ppo_random_command5_11          0  -2.420788   28.929943   11.037044
# 1  ppo_random_command5_11        100   0.069266   27.518446    6.282837
# 8  ppo_random_command5_11        800  96.731036  564.745300  118.674819
# 5  ppo_random_command5_11        500  45.248518  449.829529   95.919549
# 3  ppo_random_command5_11        300  18.817899  178.520355   46.518866
#
#    num_envs_train  mean_Episode_Reward/alive  mean_Episode_Reward/action_rate  \
# 0            8196                   0.297308                        -0.004342
# 1            8196                   0.187469                        -0.003808
# 8            8196                   1.936564                        -0.077961
# 5            8196                   1.280472                        -0.043600
# 3            8196                   0.584474                        -0.017433
#
#    mean_Episode_Reward/terminating  mean_Episode_Reward/rew_pos_diff  ...  \
# 0                        -0.018723                         -0.398911  ...
# 1                        -0.020000                         -0.209163  ...
# 8                        -0.019991                         -1.186707  ...
# 5                        -0.019999                         -0.841125  ...
# 3                        -0.020000                         -0.480084  ...
#
#    mean_Episode_Reward/rew_roll_diff  \
# 0                          -0.003313
# 1                          -0.002345
# 8                          -0.013668
# 5                          -0.007725
# 3                          -0.003992
#
#    mean_Episode_Reward/rew_roll_diff_fine_grained  \
# 0                                        0.004749
# 1                                        0.002929
# 8                                        0.050434
# 5                                        0.039402
# 3                                        0.017101
#
#    mean_Episode_Reward/rew_pitch_diff  \
# 0                           -0.002472
# 1                           -0.001550
# 8                           -0.012553
# 5                           -0.007925
# 3                           -0.003494
#
#    mean_Episode_Reward/rew_pitch_diff_fine_grained  \
# 0                                         0.005721
# 1                                         0.003735
# 8                                         0.052967
# 5                                         0.036866
# 3                                         0.017664
#
#    mean_Episode_Reward/rew_heading_alignment_fine_grained  \
# 0                                           0.021445
# 1                                           0.015808
# 8                                           0.179734
# 5                                           0.132950
# 3                                           0.088294
#
#    mean_Episode_Termination/time_out  \
# 0                           0.002533
# 1                           0.000000
# 8                           0.000429
# 5                           0.000004
# 3                           0.000000
#
#    mean_Episode_Termination/below_min_altitude  \
# 0                                     0.709719
# 1                                     0.295867
# 8                                     0.192017
# 5                                     0.251283
# 3                                     0.300422
#
#    mean_Episode_Termination/bad_attitude  \
# 0                               0.179223
# 1                               0.704133
# 8                               0.807554
# 5                               0.748713
# 3                               0.699578
#
#    mean_Episode_Termination/safety_shutdown     tarea
# 0                                       0.0  Command5
# 1                                       0.0  Command5
# 8                                       0.0  Command5
# 5                                       0.0  Command5
# 3                                       0.0  Command5
#
# [5 rows x 25 columns]

# %%
df_results_grid_actions.set_index(['tarea','id_run_name'],inplace=True)
top5 = (
    df_results_grid_actions.groupby(level="tarea")
      .apply(lambda g: g.sort_values("reward", ascending=False).head(5))
)

# Eliminar el nivel adicional que introduce groupby+apply
top5.index = top5.index.droplevel(0)

top5
# Out:
#                                  iteration      reward  max_reward  \
# tarea    id_run_name
# Command5 ppo_random_command5_11       1500  148.359473  820.291809
#          ppo_random_command5_11       1200  116.045358  747.452820
#          ppo_random_command5_11       1300   98.483841  758.258545
#          ppo_random_command5_11        800   96.731036  564.745300
#          ppo_random_command5_11       1400   88.791428  773.788818
#
#                                  std_reward  num_envs_train  \
# tarea    id_run_name
# Command5 ppo_random_command5_11  164.720314            8196
#          ppo_random_command5_11  155.794705            8196
#          ppo_random_command5_11  140.834091            8196
#          ppo_random_command5_11  118.674819            8196
#          ppo_random_command5_11  146.511362            8196
#
#                                  mean_Episode_Reward/alive  \
# tarea    id_run_name
# Command5 ppo_random_command5_11                   2.645218
#          ppo_random_command5_11                   2.575988
#          ppo_random_command5_11                   2.726593
#          ppo_random_command5_11                   1.936564
#          ppo_random_command5_11                   2.175446
#
#                                  mean_Episode_Reward/action_rate  \
# tarea    id_run_name
# Command5 ppo_random_command5_11                        -0.170349
#          ppo_random_command5_11                        -0.140482
#          ppo_random_command5_11                        -0.160750
#          ppo_random_command5_11                        -0.077961
#          ppo_random_command5_11                        -0.136057
#
#                                  mean_Episode_Reward/terminating  \
# tarea    id_run_name
# Command5 ppo_random_command5_11                        -0.019928
#          ppo_random_command5_11                        -0.019937
#          ppo_random_command5_11                        -0.019934
#          ppo_random_command5_11                        -0.019991
#          ppo_random_command5_11                        -0.019967
#
#                                  mean_Episode_Reward/rew_pos_diff  \
# tarea    id_run_name
# Command5 ppo_random_command5_11                         -1.648187
#          ppo_random_command5_11                         -1.556682
#          ppo_random_command5_11                         -1.733619
#          ppo_random_command5_11                         -1.186707
#          ppo_random_command5_11                         -1.334910
#
#                                  mean_Episode_Reward/rew_pos_diff_fine_grained  \
# tarea    id_run_name
# Command5 ppo_random_command5_11                                       0.961597
#          ppo_random_command5_11                                       0.979989
#          ppo_random_command5_11                                       0.983936
#          ppo_random_command5_11                                       0.703882
#          ppo_random_command5_11                                       0.796941
#
#                                  ...  \
# tarea    id_run_name             ...
# Command5 ppo_random_command5_11  ...
#          ppo_random_command5_11  ...
#          ppo_random_command5_11  ...
#          ppo_random_command5_11  ...
#          ppo_random_command5_11  ...
#
#                                  mean_Episode_Reward/rew_ang_vel_z_diff_fine_grained  \
# tarea    id_run_name
# Command5 ppo_random_command5_11                                           0.108495
#          ppo_random_command5_11                                           0.102867
#          ppo_random_command5_11                                           0.108917
#          ppo_random_command5_11                                           0.076896
#          ppo_random_command5_11                                           0.087503
#
#                                  mean_Episode_Reward/rew_roll_diff  \
# tarea    id_run_name
# Command5 ppo_random_command5_11                          -0.022003
#          ppo_random_command5_11                          -0.021002
#          ppo_random_command5_11                          -0.021859
#          ppo_random_command5_11                          -0.013668
#          ppo_random_command5_11                          -0.018389
#
#                                  mean_Episode_Reward/rew_roll_diff_fine_grained  \
# tarea    id_run_name
# Command5 ppo_random_command5_11                                        0.060470
#          ppo_random_command5_11                                        0.058830
#          ppo_random_command5_11                                        0.063690
#          ppo_random_command5_11                                        0.050434
#          ppo_random_command5_11                                        0.048583
#
#                                  mean_Episode_Reward/rew_pitch_diff  \
# tarea    id_run_name
# Command5 ppo_random_command5_11                           -0.015581
#          ppo_random_command5_11                           -0.016021
#          ppo_random_command5_11                           -0.017357
#          ppo_random_command5_11                           -0.012553
#          ppo_random_command5_11                           -0.013517
#
#                                  mean_Episode_Reward/rew_pitch_diff_fine_grained  \
# tarea    id_run_name
# Command5 ppo_random_command5_11                                         0.081116
#          ppo_random_command5_11                                         0.073842
#          ppo_random_command5_11                                         0.078244
#          ppo_random_command5_11                                         0.052967
#          ppo_random_command5_11                                         0.063434
#
#                                  mean_Episode_Reward/rew_heading_alignment_fine_grained  \
# tarea    id_run_name
# Command5 ppo_random_command5_11                                           0.318173
#          ppo_random_command5_11                                           0.274126
#          ppo_random_command5_11                                           0.322139
#          ppo_random_command5_11                                           0.179734
#          ppo_random_command5_11                                           0.239702
#
#                                  mean_Episode_Termination/time_out  \
# tarea    id_run_name
# Command5 ppo_random_command5_11                           0.003009
#          ppo_random_command5_11                           0.002590
#          ppo_random_command5_11                           0.003723
#          ppo_random_command5_11                           0.000429
#          ppo_random_command5_11                           0.001653
#
#                                  mean_Episode_Termination/below_min_altitude  \
# tarea    id_run_name
# Command5 ppo_random_command5_11                                     0.103489
#          ppo_random_command5_11                                     0.152105
#          ppo_random_command5_11                                     0.121192
#          ppo_random_command5_11                                     0.192017
#          ppo_random_command5_11                                     0.094360
#
#                                  mean_Episode_Termination/bad_attitude  \
# tarea    id_run_name
# Command5 ppo_random_command5_11                               0.893503
#          ppo_random_command5_11                               0.845305
#          ppo_random_command5_11                               0.875084
#          ppo_random_command5_11                               0.807554
#          ppo_random_command5_11                               0.903987
#
#                                  mean_Episode_Termination/safety_shutdown
# tarea    id_run_name
# Command5 ppo_random_command5_11                                       0.0
#          ppo_random_command5_11                                       0.0
#          ppo_random_command5_11                                       0.0
#          ppo_random_command5_11                                       0.0
#          ppo_random_command5_11                                       0.0
#
# [5 rows x 23 columns]

# %%
mean_rewards = df_results_grid_actions.groupby(["tarea", "id_run_name"])["reward"].mean()

for tarea, subdf in mean_rewards.groupby(level="tarea"):
    plt.figure(figsize=(12,5))
    
    # Convertir a DataFrame y resetear index para graficar
    plot_df = subdf.reset_index()
    plot_df = plot_df.sort_values("reward", ascending=False)
    
    plt.bar(plot_df["id_run_name"], plot_df["reward"])
    plt.title(f"Reward media por modelo - {tarea}")
    plt.xlabel("id_run_name")
    plt.ylabel("Reward media")
    plt.xticks(rotation=90)
    plt.tight_layout()
    plt.show()

# %%
df_callbacks = pd.read_csv(path_resultados+"/reward_best_models.csv",index_col='id_run_name')
top5_models = df_callbacks.nlargest(5,columns="reward")
top5_models
# Out:
#                         iteration      reward  max_reward  std_reward  \
# id_run_name
# ppo_random_command5_11       1289  154.030015  616.214417   170.69982
#
#                         num_envs_train  mean_Episode_Reward/alive  \
# id_run_name
# ppo_random_command5_11            8196                    2.90881
#
#                         mean_Episode_Reward/action_rate  \
# id_run_name
# ppo_random_command5_11                        -0.170342
#
#                         mean_Episode_Reward/terminating  \
# id_run_name
# ppo_random_command5_11                        -0.019911
#
#                         mean_Episode_Reward/rew_pos_diff  \
# id_run_name
# ppo_random_command5_11                         -1.788109
#
#                         mean_Episode_Reward/rew_pos_diff_fine_grained  ...  \
# id_run_name                                                            ...
# ppo_random_command5_11                                       1.092515  ...
#
#                         mean_Episode_Reward/rew_ang_vel_z_diff_fine_grained  \
# id_run_name
# ppo_random_command5_11                                           0.118949
#
#                         mean_Episode_Reward/rew_roll_diff  \
# id_run_name
# ppo_random_command5_11                          -0.023586
#
#                         mean_Episode_Reward/rew_roll_diff_fine_grained  \
# id_run_name
# ppo_random_command5_11                                        0.067315
#
#                         mean_Episode_Reward/rew_pitch_diff  \
# id_run_name
# ppo_random_command5_11                           -0.017664
#
#                         mean_Episode_Reward/rew_pitch_diff_fine_grained  \
# id_run_name
# ppo_random_command5_11                                         0.085878
#
#                         mean_Episode_Reward/rew_heading_alignment_fine_grained  \
# id_run_name
# ppo_random_command5_11                                           0.349344
#
#                         mean_Episode_Termination/time_out  \
# id_run_name
# ppo_random_command5_11                           0.005447
#
#                         mean_Episode_Termination/below_min_altitude  \
# id_run_name
# ppo_random_command5_11                                     0.144526
#
#                         mean_Episode_Termination/bad_attitude  \
# id_run_name
# ppo_random_command5_11                               0.850027
#
#                         mean_Episode_Termination/safety_shutdown
# id_run_name
# ppo_random_command5_11                                       0.0
#
# [1 rows x 23 columns]

# %% [markdown]
# Graficamos cómo fue el entrenamiento para los 5 mejores modelos según los callbacks:

# %%
import matplotlib.pyplot as plt
import numpy as np

# Aseguramos que `top5_auc` tenga 'tarea' e 'id_run_name' como columnas, no solo en el índice
df_callbacks = pd.read_csv(path_resultados+"/reward_best_models.csv",index_col='id_run_name')
top5_models = df_callbacks.nlargest(5,columns="reward")
top5_reset = top5_models.reset_index()
top5_reset["tarea"] = top5_reset["id_run_name"].apply(get_group)


# Convertir el índice jerárquico en columnas (para acceder a 'tarea' y 'id_run_name')
df_copy_reset = df_copy.reset_index()

# Unimos `top5_auc_reset` con `df_copy_reset` en las columnas comunes: 'tarea' y 'id_run_name'
merged_df = pd.merge(df_copy_reset, top5_reset[['tarea', 'id_run_name']], on=['tarea', 'id_run_name'], how='inner')

# Usamos una lista de colores para asignar un color diferente a cada modelo
colors = plt.cm.viridis(np.linspace(0, 1, len(merged_df['id_run_name'].unique())))

# Ahora, procedemos a graficar
for tarea, task_df in merged_df.groupby('tarea'):
    plt.figure(figsize=(10, 6))
    
    # Iteramos sobre los modelos (id_run_name) para esta tarea
    for i, (run_name, subdf) in enumerate(task_df.groupby('id_run_name')):
        # Graficamos la evolución de la recompensa a lo largo de las iteraciones
        plt.plot(subdf['iteration'], subdf['reward'], label=run_name, color=colors[i])
    
    plt.xlabel('Iteración')
    plt.ylabel('Reward')
    plt.title(f'Evolución de la Recompensa - Tarea: {tarea}')
    plt.legend(title="Modelos", bbox_to_anchor=(1.05, 1), loc='upper left')
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ``Cojo los 5 modelos mejores de todos de los callbacks``

# %%
import os
df_callbacks = pd.read_csv(path_resultados+"/reward_best_models.csv",index_col='id_run_name')
top5_models = df_callbacks.nlargest(5,columns="reward")

powershell_script_test = os.path.join(cfg_dir, "run_tests.ps1")

with open(powershell_script_test, "w") as f:
    f.write("$ErrorActionPreference = 'Stop'\n\n")
    
    for run_id, row in top5_models.iterrows():
        # Extraemos el número del id (ej: de 'ppo_random_hover_4' sacamos '4')
        experiment_number = run_id.split('_')[-1]
        
        # Construimos la ruta exacta del checkpoint
        # Nota: Asegúrate de que path_resultados termine en / o usar os.path.join
        checkpoint_path = f"{path_resultados}/best_model_{run_id}_{int(row['num_envs_train'])}.pt"
        f.write(f'Write-Host "Ejecutando Test final para Experimento {experiment_number}..."\n')
        
        # Usamos el experiment_number extraído para la tarea (--task)
        # Se añaden flags típicos de play.py: --num_envs 1 y se quita --headless para ver el visualizador
        f.write(f'& "{isaaclab_bat}" -p "{play_script}" '
                f'--task {id_task}-{experiment_number} '
                f'--num_envs 1 '
                f' --headless '
                f'--checkpoint "{checkpoint_path}"\n\n')
        
print(f"Script de test generado en: {powershell_script_test}")
# Out:
# Script de test generado en: C:/Users/Teresa/Documents/GitHub/navsim/isaac_lab/aerotaxi/env_command/env_9/grid_hiperparametros/cfg_files\run_tests.ps1

# %% [markdown]
# ### Test con 1 entorno

# %%
# Ejecuta el entrenamiento de forma automática
# !powershell -ExecutionPolicy Bypass -File "{powershell_script}"
import subprocess
import sys

# Ruta al script que generaste
powershell_script_path = powershell_script_test 

print(f"Iniciando ejecución de: {powershell_script_path}\n")

# Ejecutamos el proceso capturando la salida en tiempo real
process = subprocess.Popen(
    ["powershell.exe", "-ExecutionPolicy", "Bypass", "-File", powershell_script_path],
    stdout=subprocess.PIPE,
    stderr=subprocess.STDOUT, # Redirigimos errores a la salida estándar para verlos
    text=True,
    bufsize=1
)

# Leemos la salida línea a línea conforme se genera
try:
    for line in process.stdout:
        print(line, end="") # Imprime la salida de PowerShell en la celda
        sys.stdout.flush()   # Fuerza a Jupyter a mostrar la línea inmediatamente
except KeyboardInterrupt:
    process.kill()
    print("\nEntrenamiento cancelado por el usuario.")

process.wait()
print("\n--- Todos los experimentos de test han finalizado ---")
# Out:
# Iniciando ejecución de: C:/Users/Teresa/Documents/GitHub/navsim/isaac_lab/aerotaxi/env_command/env_9/grid_hiperparametros/cfg_files\run_tests.ps1
#
# Ejecutando Test final para Experimento 11...
# [INFO] Using python from: C:\Users\Teresa\miniconda3\envs\env_isaaclab\python.exe
# [INFO][AppLauncher]: Using device: cuda:0
# [INFO][AppLauncher]: Loading experience file: C:\Users\Teresa\miniconda3\envs\env_isaaclab\Lib\site-packages\isaaclab\apps\isaaclab.python.headless.kit
# Loading user config located at: 'c:/users/teresa/miniconda3/envs/env_isaaclab/lib/site-packages/isaacsim/kit/data/Kit/Isaac-Sim/5.1/user.config.json'
# [Info] [carb] Logging to file: c:/users/teresa/miniconda3/envs/env_isaaclab/lib/site-packages/isaacsim/kit/logs/Kit/Isaac-Sim/5.1/kit_20260205_114728.log
# 2026-02-05T10:47:28Z s] [Warning] [omni.usd_config.extension] Enable omni.materialx.libs extension to use MaterialX
# 2026-02-05T10:47:29Z s] [Warning] [carb] Acquiring non optional plugin interface which is not listed as dependency: [omni::physx::IPhysxBenchmarks v1.0] (plugin: <default plugin>), by client: omni.physics.physx.plugin. Add it to CARB_PLUGIN_IMPL_DEPS() macro of a client.
# 2026-02-05T10:47:29Z s] [Warning] [omni.isaac.dynamic_control] omni.isaac.dynamic_control is deprecated as of Isaac Sim 4.5. No action is needed from end-users.
# 2026-02-05T10:47:31Z [2,717ms] [Warning] [gpu.foundation.plugin] Skipping unsupported non-NVIDIA GPU: AMD Radeon(TM) Graphics
# 2026-02-05T10:47:31Z [2,718ms] [Warning] [gpu.foundation.plugin] Skipping unsupported non-NVIDIA GPU: AMD Radeon(TM) Graphics
#
# |---------------------------------------------------------------------------------------------|
# | Driver Version: 581.29        | Graphics API: D3D12
# |=============================================================================================|
# | GPU | Name                             | Active | LDA | GPU Memory | Vendor-ID | LUID       |
# |     |                                  |        |     |            | Device-ID | UUID       |
# |     |                                  |        |     |            | Bus-ID    |            |
# |---------------------------------------------------------------------------------------------|
# | 0   | NVIDIA GeForce RTX 5080          | Yes: 0 |     | 15889   MB | 10de      | fa570100.. |
# |     |                                  |        |     |            | 2c02      | 0          |
# |     |                                  |        |     |            | 1         |            |
# |---------------------------------------------------------------------------------------------|
# | 1   | AMD Radeon(TM) Graphics          |        |     | 1995    MB | 1002      | d7690100.. |
# |     |                                  |        |     |            | 13c0      | 0          |
# |     |                                  |        |     |            | N/A       |            |
# |=============================================================================================|
# | OS: Windows 11 Pro, Version: 10.0 (24H2), Build: 26100, Kernel: 10.0.26100.7623
# | Processor: AMD Ryzen 9 9950X 16-Core Processor
# | Cores: 16 | Logical Cores: 32
# |---------------------------------------------------------------------------------------------|
# | Total Memory (MB): 128627 | Free Memory: 94896
# | Total Page/Swap (MB): 136819 | Free Page/Swap: 92165
# |---------------------------------------------------------------------------------------------|
# C:\Users\Teresa\Documents\GitHub\navsim\isaac_lab\aerotaxi\env_command\env_9\flight_plan.py:29: UserWarning: Treat the new Tool classes introduced in v1.5 as experimental for now; the API and rcParam may change in future versions.
#   plt.rcParams["toolbar"] = "toolmanager"
# [INFO]: Parsing configuration from: aerotaxi.env_command.env_9.env:UAVEnvCfg
# [INFO]: Parsing configuration from: aerotaxi.env_command.env_9.grid_hiperparametros.cfg_files.ppo_random_command5_11_cfg:Command5PPORunnerCfg
# [INFO] Loading experiment from directory: C:\Users\Teresa\Documents\GitHub\navsim\isaac_lab\aerotaxi\env_command\env_9\logs\rsl_rl\command5
# Setting seed: 42
# [INFO]: Base environment:
# 	Environment device    : cuda:0
# 	Environment seed      : 42
# 	Physics step-size     : 0.005
# 	Rendering step-size   : 0.02
# 	Environment step-size : 0.02
# [INFO]: Time taken for scene creation : 1.011839 seconds
# [INFO]: Scene manager:  <class InteractiveScene>
# 	Number of environments: 1
# 	Environment spacing   : 100.0
# 	Source prim name      : /World/envs/env_0
# 	Global prim paths     : []
# 	Replicate physics     : False
# [INFO]: Starting the simulation. This may take a few seconds. Please wait...
# [INFO]: Time taken for simulation start : 0.251751 seconds
# [INFO] Command Manager:  <CommandManager> contains 1 active terms.
# +--------------------------------------+
# |         Active Command Terms         |
# +-------+-------------+----------------+
# | Index | Name        |      Type      |
# +-------+-------------+----------------+
# |   0   | vel_command | UAVcommandTerm |
# +-------+-------------+----------------+
#
# [INFO] Event Manager:  <EventManager> contains 1 active terms.
# +-----------------------------------+
# | Active Event Terms in Mode: 'reset' |
# +----------+------------------------+
# |  Index   | Name                   |
# +----------+------------------------+
# |    0     | reset_pos              |
# |    1     | randomize_mass         |
# |    2     | randomize_wind         |
# +----------+------------------------+
#
# [INFO] Recorder Manager:  <RecorderManager> contains 0 active terms.
# +---------------------+
# | Active Recorder Terms |
# +-----------+---------+
# |   Index   | Name    |
# +-----------+---------+
# +-----------+---------+
#
# [INFO] Action Manager:  <ActionManager> contains 1 active terms.
# +-----------------------------------+
# |   Active Action Terms (shape: 4)  |
# +--------+-------------+------------+
# | Index  | Name        |  Dimension |
# +--------+-------------+------------+
# |   0    | rotors_vel  |          4 |
# +--------+-------------+------------+
#
# [INFO] Observation Manager: <ObservationManager> contains 1 groups.
# +----------------------------------------------------+
# | Active Observation Terms in Group: 'policy' (shape: (11,)) |
# +---------------+--------------------+---------------+
# |     Index     | Name               |     Shape     |
# +---------------+--------------------+---------------+
# |       0       | pos                |      (3,)     |
# |       1       | lin_vel            |      (3,)     |
# |       2       | ang_vel            |      (3,)     |
# |       3       | roll               |      (1,)     |
# |       4       | pitch              |      (1,)     |
# +---------------+--------------------+---------------+
#
# [INFO] Termination Manager:  <TerminationManager> contains 4 active terms.
# +---------------------------------------+
# |        Active Termination Terms       |
# +-------+--------------------+----------+
# | Index | Name               | Time Out |
# +-------+--------------------+----------+
# |   0   | time_out           |   True   |
# |   1   | below_min_altitude |  False   |
# |   2   | bad_attitude       |  False   |
# |   3   | safety_shutdown    |  False   |
# +-------+--------------------+----------+
#
# [INFO] Reward Manager:  <RewardManager> contains 14 active terms.
# +-----------------------------------------------------+
# |                 Active Reward Terms                 |
# +-------+------------------------------------+--------+
# | Index | Name                               | Weight |
# +-------+------------------------------------+--------+
# |   0   | alive                              |   15.0 |
# |   1   | action_rate                        |   -0.1 |
# |   2   | terminating                        |  -50.0 |
# |   3   | rew_pos_diff                       |   -0.5 |
# |   4   | rew_pos_diff_fine_grained          |   15.0 |
# |   5   | rew_lin_vel_diff                   |   -0.1 |
# |   6   | rew_lin_vel_diff_fine_grained      |    2.0 |
# |   7   | rew_ang_vel_z_diff                 |   -1.0 |
# |   8   | rew_ang_vel_z_diff_fine_grained    |    1.0 |
# |   9   | rew_roll_diff                      |   -0.5 |
# |   10  | rew_roll_diff_fine_grained         |    1.0 |
# |   11  | rew_pitch_diff                     |   -0.5 |
# |   12  | rew_pitch_diff_fine_grained        |    1.0 |
# |   13  | rew_heading_alignment_fine_grained |    5.0 |
# +-------+------------------------------------+--------+
#
# [INFO] Curriculum Manager:  <CurriculumManager> contains 0 active terms.
# +----------------------+
# | Active Curriculum Terms |
# +-----------+----------+
# |   Index   | Name     |
# +-----------+----------+
# +-----------+----------+
#
# [INFO]: Completed setting up the environment...
# 2026-02-05T10:47:33Z [5,684ms] [Warning] [omni.physx.fabric.plugin] FabricManager::initializePointInstancer mismatched prototypes on point instancer: /Visuals/target_commands.
# [INFO]: Loading model checkpoint from: C:\Users\Teresa\Documents\GitHub\navsim\tmp\tmpTeresa\resultados_grid_command_v5\best_model_ppo_random_command5_11_8196.pt
# C:\Users\Teresa\miniconda3\envs\env_isaaclab\Lib\site-packages\rsl_rl\utils\utils.py:244: UserWarning: The observation configuration dictionary 'obs_groups' must contain the 'policy' key. As an observation group with the name 'policy' was found, this is assumed to be the observation set. Consider adding the 'policy' key to the 'obs_groups' dictionary for clarity. This behavior will be removed in a future version.
#   warnings.warn(
# C:\Users\Teresa\miniconda3\envs\env_isaaclab\Lib\site-packages\rsl_rl\utils\utils.py:290: UserWarning: The observation configuration dictionary 'obs_groups' must contain the 'critic' key. As the configuration for 'critic' is missing, the observations from the 'policy' set are used. Consider adding the 'critic' key to the 'obs_groups' dictionary for clarity. This behavior will be removed in a future version.
#   warnings.warn(
# --------------------------------------------------------------------------------
# Resolved observation sets:
# 	 policy :  ['policy']
# 	 critic :  ['policy']
# --------------------------------------------------------------------------------
# Actor MLP: MLP(
#   (0): Linear(in_features=11, out_features=64, bias=True)
#   (1): ELU(alpha=1.0)
#   (2): Linear(in_features=64, out_features=64, bias=True)
#   (3): ELU(alpha=1.0)
#   (4): Linear(in_features=64, out_features=4, bias=True)
# )
# Critic MLP: MLP(
#   (0): Linear(in_features=11, out_features=128, bias=True)
#   (1): ELU(alpha=1.0)
#   (2): Linear(in_features=128, out_features=128, bias=True)
#   (3): ELU(alpha=1.0)
#   (4): Linear(in_features=128, out_features=1, bias=True)
# )
#
# --- Todos los experimentos de test han finalizado ---

# %%
df_callbacks = pd.read_csv(path_resultados+"/reward_best_models.csv",index_col='id_run_name')
top5_models = df_callbacks.nlargest(5,columns="reward")

# %%
df_rewards_play = pd.read_csv(path_resultados+'/rewards_play_PPO.csv')

# %% [markdown]
# ### Test con 64 entornos

# %%
import os
df_callbacks = pd.read_csv(path_resultados+"/reward_best_models.csv",index_col='id_run_name')
top5_models = df_callbacks.nlargest(5,columns="reward")

powershell_script_test_2 = os.path.join(cfg_dir, "run_tests_2.ps1")

with open(powershell_script_test_2, "w") as f:
    f.write("$ErrorActionPreference = 'Stop'\n\n")
    
    for run_id, row in top5_models.iterrows():
        # Extraemos el número del id (ej: de 'ppo_random_hover_4' sacamos '4')
        experiment_number = run_id.split('_')[-1]
        
        # Construimos la ruta exacta del checkpoint
        # Nota: Asegúrate de que path_resultados termine en / o usar os.path.join
        checkpoint_path = f"{path_resultados}/best_model_{run_id}_{int(row['num_envs_train'])}.pt"
        f.write(f'Write-Host "Ejecutando Test final para Experimento {experiment_number}..."\n')
        
        # Usamos el experiment_number extraído para la tarea (--task)
        # Se añaden flags típicos de play.py: --num_envs 1 y se quita --headless para ver el visualizador
        f.write(f'& "{isaaclab_bat}" -p "{play_script}" '
                f'--task {id_task}-{experiment_number} '
                f'--num_envs 64 '
                f' --headless '
                f'--checkpoint "{checkpoint_path}"\n\n')
        
print(f"Script de test generado en: {powershell_script_test_2}")
# Out:
# Script de test generado en: C:/Users/Teresa/Documents/GitHub/navsim/isaac_lab/aerotaxi/env_command/env_9/grid_hiperparametros/cfg_files\run_tests_2.ps1

# %%
# Ejecuta el entrenamiento de forma automática
# !powershell -ExecutionPolicy Bypass -File "{powershell_script}"
import subprocess
import sys

# Ruta al script que generaste
powershell_script_path = powershell_script_test_2 

print(f"Iniciando ejecución de: {powershell_script_path}\n")

# Ejecutamos el proceso capturando la salida en tiempo real
process = subprocess.Popen(
    ["powershell.exe", "-ExecutionPolicy", "Bypass", "-File", powershell_script_path],
    stdout=subprocess.PIPE,
    stderr=subprocess.STDOUT, # Redirigimos errores a la salida estándar para verlos
    text=True,
    bufsize=1
)

# Leemos la salida línea a línea conforme se genera
try:
    for line in process.stdout:
        print(line, end="") # Imprime la salida de PowerShell en la celda
        sys.stdout.flush()   # Fuerza a Jupyter a mostrar la línea inmediatamente
except KeyboardInterrupt:
    process.kill()
    print("\nEntrenamiento cancelado por el usuario.")

process.wait()
print("\n--- Todos los experimentos de test han finalizado ---")
# Out:
# Iniciando ejecución de: C:/Users/Teresa/Documents/GitHub/navsim/isaac_lab/aerotaxi/env_command/env_9/grid_hiperparametros/cfg_files\run_tests_2.ps1
#
# Ejecutando Test final para Experimento 11...
# [INFO] Using python from: C:\Users\Teresa\miniconda3\envs\env_isaaclab\python.exe
# [INFO][AppLauncher]: Using device: cuda:0
# [INFO][AppLauncher]: Loading experience file: C:\Users\Teresa\miniconda3\envs\env_isaaclab\Lib\site-packages\isaaclab\apps\isaaclab.python.headless.kit
# Loading user config located at: 'c:/users/teresa/miniconda3/envs/env_isaaclab/lib/site-packages/isaacsim/kit/data/Kit/Isaac-Sim/5.1/user.config.json'
# [Info] [carb] Logging to file: c:/users/teresa/miniconda3/envs/env_isaaclab/lib/site-packages/isaacsim/kit/logs/Kit/Isaac-Sim/5.1/kit_20260205_115133.log
# 2026-02-05T10:51:34Z s] [Warning] [omni.usd_config.extension] Enable omni.materialx.libs extension to use MaterialX
# 2026-02-05T10:51:34Z s] [Warning] [carb] Acquiring non optional plugin interface which is not listed as dependency: [omni::physx::IPhysxBenchmarks v1.0] (plugin: <default plugin>), by client: omni.physics.physx.plugin. Add it to CARB_PLUGIN_IMPL_DEPS() macro of a client.
# 2026-02-05T10:51:34Z s] [Warning] [omni.isaac.dynamic_control] omni.isaac.dynamic_control is deprecated as of Isaac Sim 4.5. No action is needed from end-users.
# 2026-02-05T10:51:36Z [2,374ms] [Warning] [gpu.foundation.plugin] Skipping unsupported non-NVIDIA GPU: AMD Radeon(TM) Graphics
# 2026-02-05T10:51:36Z [2,375ms] [Warning] [gpu.foundation.plugin] Skipping unsupported non-NVIDIA GPU: AMD Radeon(TM) Graphics
#
# |---------------------------------------------------------------------------------------------|
# | Driver Version: 581.29        | Graphics API: D3D12
# |=============================================================================================|
# | GPU | Name                             | Active | LDA | GPU Memory | Vendor-ID | LUID       |
# |     |                                  |        |     |            | Device-ID | UUID       |
# |     |                                  |        |     |            | Bus-ID    |            |
# |---------------------------------------------------------------------------------------------|
# | 0   | NVIDIA GeForce RTX 5080          | Yes: 0 |     | 15889   MB | 10de      | fa570100.. |
# |     |                                  |        |     |            | 2c02      | 0          |
# |     |                                  |        |     |            | 1         |            |
# |---------------------------------------------------------------------------------------------|
# | 1   | AMD Radeon(TM) Graphics          |        |     | 1995    MB | 1002      | d7690100.. |
# |     |                                  |        |     |            | 13c0      | 0          |
# |     |                                  |        |     |            | N/A       |            |
# |=============================================================================================|
# | OS: Windows 11 Pro, Version: 10.0 (24H2), Build: 26100, Kernel: 10.0.26100.7623
# | Processor: AMD Ryzen 9 9950X 16-Core Processor
# | Cores: 16 | Logical Cores: 32
# |---------------------------------------------------------------------------------------------|
# | Total Memory (MB): 128627 | Free Memory: 94331
# | Total Page/Swap (MB): 136819 | Free Page/Swap: 91707
# |---------------------------------------------------------------------------------------------|
# C:\Users\Teresa\Documents\GitHub\navsim\isaac_lab\aerotaxi\env_command\env_9\flight_plan.py:29: UserWarning: Treat the new Tool classes introduced in v1.5 as experimental for now; the API and rcParam may change in future versions.
#   plt.rcParams["toolbar"] = "toolmanager"
# [INFO]: Parsing configuration from: aerotaxi.env_command.env_9.env:UAVEnvCfg
# [INFO]: Parsing configuration from: aerotaxi.env_command.env_9.grid_hiperparametros.cfg_files.ppo_random_command5_11_cfg:Command5PPORunnerCfg
# [INFO] Loading experiment from directory: C:\Users\Teresa\Documents\GitHub\navsim\isaac_lab\aerotaxi\env_command\env_9\logs\rsl_rl\command5
# Setting seed: 42
# [INFO]: Base environment:
# 	Environment device    : cuda:0
# 	Environment seed      : 42
# 	Physics step-size     : 0.005
# 	Rendering step-size   : 0.02
# 	Environment step-size : 0.02
# [INFO]: Time taken for scene creation : 1.099795 seconds
# [INFO]: Scene manager:  <class InteractiveScene>
# 	Number of environments: 64
# 	Environment spacing   : 100.0
# 	Source prim name      : /World/envs/env_0
# 	Global prim paths     : []
# 	Replicate physics     : False
# [INFO]: Starting the simulation. This may take a few seconds. Please wait...
# [INFO]: Time taken for simulation start : 0.282446 seconds
# [INFO] Command Manager:  <CommandManager> contains 1 active terms.
# +--------------------------------------+
# |         Active Command Terms         |
# +-------+-------------+----------------+
# | Index | Name        |      Type      |
# +-------+-------------+----------------+
# |   0   | vel_command | UAVcommandTerm |
# +-------+-------------+----------------+
#
# [INFO] Event Manager:  <EventManager> contains 1 active terms.
# +-----------------------------------+
# | Active Event Terms in Mode: 'reset' |
# +----------+------------------------+
# |  Index   | Name                   |
# +----------+------------------------+
# |    0     | reset_pos              |
# |    1     | randomize_mass         |
# |    2     | randomize_wind         |
# +----------+------------------------+
#
# [INFO] Recorder Manager:  <RecorderManager> contains 0 active terms.
# +---------------------+
# | Active Recorder Terms |
# +-----------+---------+
# |   Index   | Name    |
# +-----------+---------+
# +-----------+---------+
#
# [INFO] Action Manager:  <ActionManager> contains 1 active terms.
# +-----------------------------------+
# |   Active Action Terms (shape: 4)  |
# +--------+-------------+------------+
# | Index  | Name        |  Dimension |
# +--------+-------------+------------+
# |   0    | rotors_vel  |          4 |
# +--------+-------------+------------+
#
# [INFO] Observation Manager: <ObservationManager> contains 1 groups.
# +----------------------------------------------------+
# | Active Observation Terms in Group: 'policy' (shape: (11,)) |
# +---------------+--------------------+---------------+
# |     Index     | Name               |     Shape     |
# +---------------+--------------------+---------------+
# |       0       | pos                |      (3,)     |
# |       1       | lin_vel            |      (3,)     |
# |       2       | ang_vel            |      (3,)     |
# |       3       | roll               |      (1,)     |
# |       4       | pitch              |      (1,)     |
# +---------------+--------------------+---------------+
#
# [INFO] Termination Manager:  <TerminationManager> contains 4 active terms.
# +---------------------------------------+
# |        Active Termination Terms       |
# +-------+--------------------+----------+
# | Index | Name               | Time Out |
# +-------+--------------------+----------+
# |   0   | time_out           |   True   |
# |   1   | below_min_altitude |  False   |
# |   2   | bad_attitude       |  False   |
# |   3   | safety_shutdown    |  False   |
# +-------+--------------------+----------+
#
# [INFO] Reward Manager:  <RewardManager> contains 14 active terms.
# +-----------------------------------------------------+
# |                 Active Reward Terms                 |
# +-------+------------------------------------+--------+
# | Index | Name                               | Weight |
# +-------+------------------------------------+--------+
# |   0   | alive                              |   15.0 |
# |   1   | action_rate                        |   -0.1 |
# |   2   | terminating                        |  -50.0 |
# |   3   | rew_pos_diff                       |   -0.5 |
# |   4   | rew_pos_diff_fine_grained          |   15.0 |
# |   5   | rew_lin_vel_diff                   |   -0.1 |
# |   6   | rew_lin_vel_diff_fine_grained      |    2.0 |
# |   7   | rew_ang_vel_z_diff                 |   -1.0 |
# |   8   | rew_ang_vel_z_diff_fine_grained    |    1.0 |
# |   9   | rew_roll_diff                      |   -0.5 |
# |   10  | rew_roll_diff_fine_grained         |    1.0 |
# |   11  | rew_pitch_diff                     |   -0.5 |
# |   12  | rew_pitch_diff_fine_grained        |    1.0 |
# |   13  | rew_heading_alignment_fine_grained |    5.0 |
# +-------+------------------------------------+--------+
#
# [INFO] Curriculum Manager:  <CurriculumManager> contains 0 active terms.
# +----------------------+
# | Active Curriculum Terms |
# +-----------+----------+
# |   Index   | Name     |
# +-----------+----------+
# +-----------+----------+
#
# [INFO]: Completed setting up the environment...
# 2026-02-05T10:51:39Z [5,393ms] [Warning] [omni.physx.fabric.plugin] FabricManager::initializePointInstancer mismatched prototypes on point instancer: /Visuals/target_commands.
# [INFO]: Loading model checkpoint from: C:\Users\Teresa\Documents\GitHub\navsim\tmp\tmpTeresa\resultados_grid_command_v5\best_model_ppo_random_command5_11_8196.pt
# C:\Users\Teresa\miniconda3\envs\env_isaaclab\Lib\site-packages\rsl_rl\utils\utils.py:244: UserWarning: The observation configuration dictionary 'obs_groups' must contain the 'policy' key. As an observation group with the name 'policy' was found, this is assumed to be the observation set. Consider adding the 'policy' key to the 'obs_groups' dictionary for clarity. This behavior will be removed in a future version.
#   warnings.warn(
# C:\Users\Teresa\miniconda3\envs\env_isaaclab\Lib\site-packages\rsl_rl\utils\utils.py:290: UserWarning: The observation configuration dictionary 'obs_groups' must contain the 'critic' key. As the configuration for 'critic' is missing, the observations from the 'policy' set are used. Consider adding the 'critic' key to the 'obs_groups' dictionary for clarity. This behavior will be removed in a future version.
#   warnings.warn(
# --------------------------------------------------------------------------------
# Resolved observation sets:
# 	 policy :  ['policy']
# 	 critic :  ['policy']
# --------------------------------------------------------------------------------
# Actor MLP: MLP(
#   (0): Linear(in_features=11, out_features=64, bias=True)
#   (1): ELU(alpha=1.0)
#   (2): Linear(in_features=64, out_features=64, bias=True)
#   (3): ELU(alpha=1.0)
#   (4): Linear(in_features=64, out_features=4, bias=True)
# )
# Critic MLP: MLP(
#   (0): Linear(in_features=11, out_features=128, bias=True)
#   (1): ELU(alpha=1.0)
#   (2): Linear(in_features=128, out_features=128, bias=True)
#   (3): ELU(alpha=1.0)
#   (4): Linear(in_features=128, out_features=1, bias=True)
# )
#
# --- Todos los experimentos de test han finalizado ---

# %% [markdown]
# #### Test con 256 entornos

# %%
import os
df_callbacks = pd.read_csv(path_resultados+"/reward_best_models.csv",index_col='id_run_name')
top5_models = df_callbacks.nlargest(5,columns="reward")

powershell_script_test_3 = os.path.join(cfg_dir, "run_tests_3.ps1")

with open(powershell_script_test_3, "w") as f:
    f.write("$ErrorActionPreference = 'Stop'\n\n")
    
    for run_id, row in top5_models.iterrows():
        # Extraemos el número del id (ej: de 'ppo_random_hover_4' sacamos '4')
        experiment_number = run_id.split('_')[-1]
        
        # Construimos la ruta exacta del checkpoint
        # Nota: Asegúrate de que path_resultados termine en / o usar os.path.join
        checkpoint_path = f"{path_resultados}/best_model_{run_id}_{int(row['num_envs_train'])}.pt"
        f.write(f'Write-Host "Ejecutando Test final para Experimento {experiment_number}..."\n')
        
        # Usamos el experiment_number extraído para la tarea (--task)
        # Se añaden flags típicos de play.py: --num_envs 1 y se quita --headless para ver el visualizador
        f.write(f'& "{isaaclab_bat}" -p "{play_script}" '
                f'--task {id_task}-{experiment_number} '
                f'--num_envs 256 '
                f' --headless '
                f'--checkpoint "{checkpoint_path}"\n\n')
        
print(f"Script de test generado en: {powershell_script_test_3}")
# Out:
# Script de test generado en: C:/Users/Teresa/Documents/GitHub/navsim/isaac_lab/aerotaxi/env_command/env_9/grid_hiperparametros/cfg_files\run_tests_3.ps1

# %%
# Ejecuta el entrenamiento de forma automática
# !powershell -ExecutionPolicy Bypass -File "{powershell_script}"
import subprocess
import sys

# Ruta al script que generaste
powershell_script_path = powershell_script_test_3 

print(f"Iniciando ejecución de: {powershell_script_path}\n")

# Ejecutamos el proceso capturando la salida en tiempo real
process = subprocess.Popen(
    ["powershell.exe", "-ExecutionPolicy", "Bypass", "-File", powershell_script_path],
    stdout=subprocess.PIPE,
    stderr=subprocess.STDOUT, # Redirigimos errores a la salida estándar para verlos
    text=True,
    bufsize=1
)

# Leemos la salida línea a línea conforme se genera
try:
    for line in process.stdout:
        print(line, end="") # Imprime la salida de PowerShell en la celda
        sys.stdout.flush()   # Fuerza a Jupyter a mostrar la línea inmediatamente
except KeyboardInterrupt:
    process.kill()
    print("\nEntrenamiento cancelado por el usuario.")

process.wait()
print("\n--- Todos los experimentos de test han finalizado ---")
# Out:
# Iniciando ejecución de: C:/Users/Teresa/Documents/GitHub/navsim/isaac_lab/aerotaxi/env_command/env_9/grid_hiperparametros/cfg_files\run_tests_3.ps1
#
# Ejecutando Test final para Experimento 11...
# [INFO] Using python from: C:\Users\Teresa\miniconda3\envs\env_isaaclab\python.exe
# [INFO][AppLauncher]: Using device: cuda:0
# [INFO][AppLauncher]: Loading experience file: C:\Users\Teresa\miniconda3\envs\env_isaaclab\Lib\site-packages\isaaclab\apps\isaaclab.python.headless.kit
# Loading user config located at: 'c:/users/teresa/miniconda3/envs/env_isaaclab/lib/site-packages/isaacsim/kit/data/Kit/Isaac-Sim/5.1/user.config.json'
# [Info] [carb] Logging to file: c:/users/teresa/miniconda3/envs/env_isaaclab/lib/site-packages/isaacsim/kit/logs/Kit/Isaac-Sim/5.1/kit_20260205_115402.log
# 2026-02-05T10:54:03Z s] [Warning] [omni.usd_config.extension] Enable omni.materialx.libs extension to use MaterialX
# 2026-02-05T10:54:03Z s] [Warning] [carb] Acquiring non optional plugin interface which is not listed as dependency: [omni::physx::IPhysxBenchmarks v1.0] (plugin: <default plugin>), by client: omni.physics.physx.plugin. Add it to CARB_PLUGIN_IMPL_DEPS() macro of a client.
# 2026-02-05T10:54:03Z s] [Warning] [omni.isaac.dynamic_control] omni.isaac.dynamic_control is deprecated as of Isaac Sim 4.5. No action is needed from end-users.
# 2026-02-05T10:54:05Z [2,384ms] [Warning] [gpu.foundation.plugin] Skipping unsupported non-NVIDIA GPU: AMD Radeon(TM) Graphics
# 2026-02-05T10:54:05Z [2,385ms] [Warning] [gpu.foundation.plugin] Skipping unsupported non-NVIDIA GPU: AMD Radeon(TM) Graphics
#
# |---------------------------------------------------------------------------------------------|
# | Driver Version: 581.29        | Graphics API: D3D12
# |=============================================================================================|
# | GPU | Name                             | Active | LDA | GPU Memory | Vendor-ID | LUID       |
# |     |                                  |        |     |            | Device-ID | UUID       |
# |     |                                  |        |     |            | Bus-ID    |            |
# |---------------------------------------------------------------------------------------------|
# | 0   | NVIDIA GeForce RTX 5080          | Yes: 0 |     | 15889   MB | 10de      | fa570100.. |
# |     |                                  |        |     |            | 2c02      | 0          |
# |     |                                  |        |     |            | 1         |            |
# |---------------------------------------------------------------------------------------------|
# | 1   | AMD Radeon(TM) Graphics          |        |     | 1995    MB | 1002      | d7690100.. |
# |     |                                  |        |     |            | 13c0      | 0          |
# |     |                                  |        |     |            | N/A       |            |
# |=============================================================================================|
# | OS: Windows 11 Pro, Version: 10.0 (24H2), Build: 26100, Kernel: 10.0.26100.7623
# | Processor: AMD Ryzen 9 9950X 16-Core Processor
# | Cores: 16 | Logical Cores: 32
# |---------------------------------------------------------------------------------------------|
# | Total Memory (MB): 128627 | Free Memory: 94040
# | Total Page/Swap (MB): 136819 | Free Page/Swap: 91401
# |---------------------------------------------------------------------------------------------|
# C:\Users\Teresa\Documents\GitHub\navsim\isaac_lab\aerotaxi\env_command\env_9\flight_plan.py:29: UserWarning: Treat the new Tool classes introduced in v1.5 as experimental for now; the API and rcParam may change in future versions.
#   plt.rcParams["toolbar"] = "toolmanager"
# [INFO]: Parsing configuration from: aerotaxi.env_command.env_9.env:UAVEnvCfg
# [INFO]: Parsing configuration from: aerotaxi.env_command.env_9.grid_hiperparametros.cfg_files.ppo_random_command5_11_cfg:Command5PPORunnerCfg
# [INFO] Loading experiment from directory: C:\Users\Teresa\Documents\GitHub\navsim\isaac_lab\aerotaxi\env_command\env_9\logs\rsl_rl\command5
# Setting seed: 42
# [INFO]: Base environment:
# 	Environment device    : cuda:0
# 	Environment seed      : 42
# 	Physics step-size     : 0.005
# 	Rendering step-size   : 0.02
# 	Environment step-size : 0.02
# [INFO]: Time taken for scene creation : 1.113053 seconds
# [INFO]: Scene manager:  <class InteractiveScene>
# 	Number of environments: 256
# 	Environment spacing   : 100.0
# 	Source prim name      : /World/envs/env_0
# 	Global prim paths     : []
# 	Replicate physics     : False
# [INFO]: Starting the simulation. This may take a few seconds. Please wait...
# [INFO]: Time taken for simulation start : 0.381035 seconds
# [INFO] Command Manager:  <CommandManager> contains 1 active terms.
# +--------------------------------------+
# |         Active Command Terms         |
# +-------+-------------+----------------+
# | Index | Name        |      Type      |
# +-------+-------------+----------------+
# |   0   | vel_command | UAVcommandTerm |
# +-------+-------------+----------------+
#
# [INFO] Event Manager:  <EventManager> contains 1 active terms.
# +-----------------------------------+
# | Active Event Terms in Mode: 'reset' |
# +----------+------------------------+
# |  Index   | Name                   |
# +----------+------------------------+
# |    0     | reset_pos              |
# |    1     | randomize_mass         |
# |    2     | randomize_wind         |
# +----------+------------------------+
#
# [INFO] Recorder Manager:  <RecorderManager> contains 0 active terms.
# +---------------------+
# | Active Recorder Terms |
# +-----------+---------+
# |   Index   | Name    |
# +-----------+---------+
# +-----------+---------+
#
# [INFO] Action Manager:  <ActionManager> contains 1 active terms.
# +-----------------------------------+
# |   Active Action Terms (shape: 4)  |
# +--------+-------------+------------+
# | Index  | Name        |  Dimension |
# +--------+-------------+------------+
# |   0    | rotors_vel  |          4 |
# +--------+-------------+------------+
#
# [INFO] Observation Manager: <ObservationManager> contains 1 groups.
# +----------------------------------------------------+
# | Active Observation Terms in Group: 'policy' (shape: (11,)) |
# +---------------+--------------------+---------------+
# |     Index     | Name               |     Shape     |
# +---------------+--------------------+---------------+
# |       0       | pos                |      (3,)     |
# |       1       | lin_vel            |      (3,)     |
# |       2       | ang_vel            |      (3,)     |
# |       3       | roll               |      (1,)     |
# |       4       | pitch              |      (1,)     |
# +---------------+--------------------+---------------+
#
# [INFO] Termination Manager:  <TerminationManager> contains 4 active terms.
# +---------------------------------------+
# |        Active Termination Terms       |
# +-------+--------------------+----------+
# | Index | Name               | Time Out |
# +-------+--------------------+----------+
# |   0   | time_out           |   True   |
# |   1   | below_min_altitude |  False   |
# |   2   | bad_attitude       |  False   |
# |   3   | safety_shutdown    |  False   |
# +-------+--------------------+----------+
#
# [INFO] Reward Manager:  <RewardManager> contains 14 active terms.
# +-----------------------------------------------------+
# |                 Active Reward Terms                 |
# +-------+------------------------------------+--------+
# | Index | Name                               | Weight |
# +-------+------------------------------------+--------+
# |   0   | alive                              |   15.0 |
# |   1   | action_rate                        |   -0.1 |
# |   2   | terminating                        |  -50.0 |
# |   3   | rew_pos_diff                       |   -0.5 |
# |   4   | rew_pos_diff_fine_grained          |   15.0 |
# |   5   | rew_lin_vel_diff                   |   -0.1 |
# |   6   | rew_lin_vel_diff_fine_grained      |    2.0 |
# |   7   | rew_ang_vel_z_diff                 |   -1.0 |
# |   8   | rew_ang_vel_z_diff_fine_grained    |    1.0 |
# |   9   | rew_roll_diff                      |   -0.5 |
# |   10  | rew_roll_diff_fine_grained         |    1.0 |
# |   11  | rew_pitch_diff                     |   -0.5 |
# |   12  | rew_pitch_diff_fine_grained        |    1.0 |
# |   13  | rew_heading_alignment_fine_grained |    5.0 |
# +-------+------------------------------------+--------+
#
# [INFO] Curriculum Manager:  <CurriculumManager> contains 0 active terms.
# +----------------------+
# | Active Curriculum Terms |
# +-----------+----------+
# |   Index   | Name     |
# +-----------+----------+
# +-----------+----------+
#
# [INFO]: Completed setting up the environment...
# 2026-02-05T10:54:08Z [5,536ms] [Warning] [omni.physx.fabric.plugin] FabricManager::initializePointInstancer mismatched prototypes on point instancer: /Visuals/target_commands.
# [INFO]: Loading model checkpoint from: C:\Users\Teresa\Documents\GitHub\navsim\tmp\tmpTeresa\resultados_grid_command_v5\best_model_ppo_random_command5_11_8196.pt
# C:\Users\Teresa\miniconda3\envs\env_isaaclab\Lib\site-packages\rsl_rl\utils\utils.py:244: UserWarning: The observation configuration dictionary 'obs_groups' must contain the 'policy' key. As an observation group with the name 'policy' was found, this is assumed to be the observation set. Consider adding the 'policy' key to the 'obs_groups' dictionary for clarity. This behavior will be removed in a future version.
#   warnings.warn(
# C:\Users\Teresa\miniconda3\envs\env_isaaclab\Lib\site-packages\rsl_rl\utils\utils.py:290: UserWarning: The observation configuration dictionary 'obs_groups' must contain the 'critic' key. As the configuration for 'critic' is missing, the observations from the 'policy' set are used. Consider adding the 'critic' key to the 'obs_groups' dictionary for clarity. This behavior will be removed in a future version.
#   warnings.warn(
# --------------------------------------------------------------------------------
# Resolved observation sets:
# 	 policy :  ['policy']
# 	 critic :  ['policy']
# --------------------------------------------------------------------------------
# Actor MLP: MLP(
#   (0): Linear(in_features=11, out_features=64, bias=True)
#   (1): ELU(alpha=1.0)
#   (2): Linear(in_features=64, out_features=64, bias=True)
#   (3): ELU(alpha=1.0)
#   (4): Linear(in_features=64, out_features=4, bias=True)
# )
# Critic MLP: MLP(
#   (0): Linear(in_features=11, out_features=128, bias=True)
#   (1): ELU(alpha=1.0)
#   (2): Linear(in_features=128, out_features=128, bias=True)
#   (3): ELU(alpha=1.0)
#   (4): Linear(in_features=128, out_features=1, bias=True)
# )
#
# --- Todos los experimentos de test han finalizado ---

# %%
import pandas as pd

df_train = top5_models.copy()
if df_train.index.name == 'id_run_name':
    df_train = df_train.reset_index()

df_train = df_train.rename(columns={
    'reward': 'reward_train',
    'max_reward': 'max_reward_train',
    'std_reward': 'std_train'
})

df_test = df_rewards_play.copy()

df_test = pd.read_csv(path_resultados+'/rewards_play_PPO.csv')
df_test = df_test.rename(columns={
    'reward': 'reward_test',
    'max_reward': 'max_reward_test',
    'std': 'std_test'
})

df_final = pd.merge(
    df_train[['id_run_name', 'num_envs_train', 'reward_train', 'max_reward_train', 'std_train', 'iteration']], 
    df_test[['id_run_name', 'num_envs_test', 'reward_test', 'max_reward_test', 'std_test', 'checkpoint']], 
    on='id_run_name', 
    how='inner'
)

column_order = [
    'id_run_name',
    'num_envs_train',
    'num_envs_test',
    'reward_train', 'reward_test', 
    'max_reward_train', 'max_reward_test', 
    'std_train', 'std_test',
    'iteration'
]
df_final = df_final[column_order]

df_final = df_final.sort_values(by='id_run_name', ascending=False)

# %%
df_rewards_play = df_final.sort_values(by="id_run_name",ascending=False)
df_rewards_play = df_rewards_play.reset_index().drop(columns='index')

df_final = df_rewards_play.copy()

df_final['diff_rw_test_train'] = df_final['reward_test'] - df_final['reward_train']

df_final['diferencia(%)'] = (df_final['diff_rw_test_train'] / df_final['reward_train'].abs()) * 100

df_final['diferencia(%)'] = df_final['diferencia(%)'].apply(lambda x: f"{x:+.2f}%")

df_final
# Out:
#               id_run_name  num_envs_train  num_envs_test  reward_train  \
# 0  ppo_random_command5_11            8196              1    154.030015
# 1  ppo_random_command5_11            8196             64    154.030015
# 2  ppo_random_command5_11            8196             64    154.030015
# 3  ppo_random_command5_11            8196            256    154.030015
#
#    reward_test  max_reward_train  max_reward_test  std_train    std_test  \
# 0   223.073972        616.214417       373.655934  170.69982  150.581962
# 1   112.457990        616.214417       388.230930  170.69982  120.609010
# 2   112.457990        616.214417       388.230930  170.69982  120.609010
# 3   122.212913        616.214417       423.071395  170.69982  113.751531
#
#    iteration  diff_rw_test_train diferencia(%)
# 0       1289           69.043957       +44.83%
# 1       1289          -41.572025       -26.99%
# 2       1289          -41.572025       -26.99%
# 3       1289          -31.817102       -20.66%

# %% [markdown]
# Pruebas con un solo entorno: Vemos cómo se comporta la política para un único agente en una prueba aleatoria.

# %%
df_final[df_final['num_envs_test'] == 1].sort_values(by='reward_test',ascending=False)
# Out:
#               id_run_name  num_envs_train  num_envs_test  reward_train  \
# 0  ppo_random_command5_11            8196              1    154.030015
#
#    reward_test  max_reward_train  max_reward_test  std_train    std_test  \
# 0   223.073972        616.214417       373.655934  170.69982  150.581962
#
#    iteration  diff_rw_test_train diferencia(%)
# 0       1289           69.043957       +44.83%

# %% [markdown]
# ``Interpretación``: Vemos que el modelo 38 se ha estampado en la prueba aleatoria, así que ese modelo no debería usarse para ninguna transferencia real.

# %% [markdown]
# Pruebas con varios entornos: Vemos cómo se comporta la política en múltiples entornos (varias pruebas simuladas en paralelo), teniendo en cuenta cuál es la desviación de cada uno en test, lo que nos permite inferir si la recompensa es estable para todas las pruebas.

# %%
df_final[df_final['num_envs_test'] != 1].sort_values(by='std_test',ascending=True).reset_index().drop(columns="index")
# Out:
#               id_run_name  num_envs_train  num_envs_test  reward_train  \
# 0  ppo_random_command5_11            8196            256    154.030015
# 1  ppo_random_command5_11            8196             64    154.030015
# 2  ppo_random_command5_11            8196             64    154.030015
#
#    reward_test  max_reward_train  max_reward_test  std_train    std_test  \
# 0   122.212913        616.214417       423.071395  170.69982  113.751531
# 1   112.457990        616.214417       388.230930  170.69982  120.609010
# 2   112.457990        616.214417       388.230930  170.69982  120.609010
#
#    iteration  diff_rw_test_train diferencia(%)
# 0       1289          -31.817102       -20.66%
# 1       1289          -41.572025       -26.99%
# 2       1289          -41.572025       -26.99%

# %% [markdown]
# pruebas:

# %% [markdown]
# C:/Users/Teresa/Desktop/RuralData/IsaacLab/IsaacLab/isaaclab.bat -p C:/Users/Teresa/Documents/GitHub/navsim/isaac_lab/rl_v5_1_0/rsl_rl/train.py --task Isaac-Command5-Aerotaxi-RANDOM-11 --num_envs 8196 --headless
