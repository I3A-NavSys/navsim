# %%
# Parámetros a configurar:
import os
experiment_name = "command7"
task_name = "Command7"
cfg_dir = "C:/Users/Teresa/Documents/GitHub/navsim/isaac_lab/aerotaxi/env_command/env_11/grid_hiperparametros/cfg_files"
path_resultados = "C:/Users/Teresa/Documents/GitHub/navsim/tmp/tmpTeresa/resultados_grid_command_v7"
isaaclab_bat = "C:/Users/Teresa/Desktop/RuralData/IsaacLab/IsaacLab/isaaclab.bat"
train_script = "C:/Users/Teresa/Documents/GitHub/navsim/isaac_lab/rl_v5_1_0/rsl_rl/train.py"
id_task = f"Isaac-{task_name}-Aerotaxi-RANDOM" # luego se le añade el número de task con el guión (Isaac-Command2-Aerotaxi-RANDOM-34)
play_script = "C:/Users/Teresa/Documents/GitHub/navsim/isaac_lab/rl_v5_1_0/rsl_rl/play.py"
num_iter = "4001"
num_steps_per_env = 100
powershell_script = os.path.join(cfg_dir, "run_all.ps1")

# el num_steps_per_env = 100 también está en el env, al final del todo, y deben tener el mismo valor
# Recuerda iniciar en el init todos los experimentos

# %%
import random
import os

# Si los directorios no existen (el último indicado), lo crea
os.makedirs(cfg_dir, exist_ok=True)
os.makedirs(path_resultados, exist_ok=True)
# Opciones de hiperparámetros
param_options = {
    "init_noise_std": [0.0, 0.1, 0.2, 0.5, 0.8, 1.0],
    "actor_hidden_dims": [[64, 64], [128, 128], [256, 256], [128, 64]],
    "critic_hidden_dims": [[64, 64], [128, 128], [256, 256]],
    "activation": ["relu", "tanh", "elu", "gelu"],
    "value_loss_coef": [0.5, 1.0, 2.0],
    "clip_param": [0.1, 0.2, 0.3],
    "entropy_coef": [0.0, 0.001, 0.01, 0.05],
    "num_learning_epochs": [4, 8, 12],
    "num_mini_batches": [2, 4, 8],
    "learning_rate": [5e-05, 1e-4, 3e-4, 1e-3, 3e-3],
    "gamma": [0.95, 0.98, 0.99],
    "lam": [0.90, 0.95, 0.97],
    "max_grad_norm": [0.5, 1.0, 2.0],
    "desired_kl": [0.005, 0.008, 0.01, 0.02],
}

num_trials = 35  # cantidad de configuraciones

cfg_files = []

for i in range(num_trials):
    run_name = f"ppo_random_{experiment_name}_{i+1}"
    sampled = {k: random.choice(v) for k, v in param_options.items()}

    # Convertir listas a string
    actor_dims = sampled["actor_hidden_dims"]
    critic_dims = sampled["critic_hidden_dims"]

    cfg_content = f"""
from isaaclab.utils import configclass
from isaaclab_rl.rsl_rl import RslRlOnPolicyRunnerCfg, RslRlPpoActorCriticCfg, RslRlPpoAlgorithmCfg

@configclass
class {task_name}PPORunnerCfg(RslRlOnPolicyRunnerCfg):
    num_steps_per_env = {num_steps_per_env} 
    max_iterations = {num_iter}
    save_interval = 100
    experiment_name = "{experiment_name}"
    run_name = "{run_name}"
    resume = False
    empirical_normalization = False
    csv_path_metrics = "{path_resultados}"
    callbacks = True
    policy = RslRlPpoActorCriticCfg(
        init_noise_std={sampled['init_noise_std']},
        actor_hidden_dims={actor_dims},
        critic_hidden_dims={critic_dims},
        activation="{sampled['activation']}",
    )
    algorithm = RslRlPpoAlgorithmCfg(
        value_loss_coef={sampled['value_loss_coef']},
        use_clipped_value_loss=True,
        clip_param={sampled['clip_param']},
        entropy_coef={sampled['entropy_coef']},
        num_learning_epochs={sampled['num_learning_epochs']},
        num_mini_batches={sampled['num_mini_batches']},
        learning_rate={sampled['learning_rate']},
        schedule="adaptive",
        gamma={sampled['gamma']},
        lam={sampled['lam']},
        desired_kl={sampled['desired_kl']},
        max_grad_norm={sampled['max_grad_norm']},
    )
"""
    cfg_path = os.path.join(cfg_dir, f"{run_name}_cfg.py")
    with open(cfg_path, "w") as f:
        f.write(cfg_content.strip())
    cfg_files.append((run_name, cfg_path))

# Crear archivo PowerShell para ejecutar todas las configuraciones
powershell_script = os.path.join(cfg_dir, "run_all.ps1")

num_envs =  [64, 128, 512, 1024, 2048, 4096, 8196] #número de entornos para train (paralelizados)

with open(powershell_script, "w") as f:
    f.write("$ErrorActionPreference = 'Stop'\n\n")
    j = 0
    for run_name, cfg_path in cfg_files:
        # Convertir path a módulo Python (reemplazar / y .py)
        num_envs_i = random.choice(num_envs)
        module_path = cfg_path.replace("/", ".").replace("\\", ".").replace(".py", "")
        f.write(f'Write-Host "Ejecutando {run_name}"\n')
        f.write(f'& "{isaaclab_bat}" -p "{train_script}" --task {id_task}-{j+1} --num_envs {num_envs_i} --headless \n\n')
        j += 1
print("Archivos de configuración generados y script PowerShell listo en:", powershell_script)
# Out:
# Archivos de configuración generados y script PowerShell listo en: C:/Users/Teresa/Documents/GitHub/navsim/isaac_lab/aerotaxi/env_command/env_10/grid_hiperparametros/cfg_files\run_all.ps1

# %%
# Ejecuta el entrenamiento de forma automática
# !powershell -ExecutionPolicy Bypass -File "{powershell_script}"
import subprocess
import sys

# Ruta al script que generaste
powershell_script_path = powershell_script 

print(f"Iniciando ejecución de: {powershell_script_path}\n")

# Ejecutamos el proceso capturando la salida en tiempo real
process = subprocess.Popen(
    ["powershell.exe", "-ExecutionPolicy", "Bypass", "-File", powershell_script_path],
    stdout=subprocess.PIPE,
    stderr=subprocess.STDOUT, # Redirigimos errores a la salida estándar para verlos
    text=True,
    bufsize=1
)

# Leemos la salida línea a línea conforme se genera
try:
    for line in process.stdout:
        print(line, end="") # Imprime la salida de PowerShell en la celda
        sys.stdout.flush()   # Fuerza a Jupyter a mostrar la línea inmediatamente
except KeyboardInterrupt:
    process.kill()
    print("\nEntrenamiento cancelado por el usuario.")

process.wait()
print("\n--- Todos los experimentos han finalizado ---")
# Out:
# Iniciando ejecución de: C:/Users/Teresa/Documents/GitHub/navsim/isaac_lab/aerotaxi/env_command/env_11/grid_hiperparametros/cfg_files\run_all.ps1
#
# Ejecutando ppo_random_command7_11
# [INFO] Using python from: C:\Users\Teresa\miniconda3\envs\env_isaaclab\python.exe
# [INFO][AppLauncher]: Using device: cuda:0
# [INFO][AppLauncher]: Loading experience file: C:\Users\Teresa\miniconda3\envs\env_isaaclab\Lib\site-packages\isaaclab\apps\isaaclab.python.headless.kit
# Loading user config located at: 'c:/users/teresa/miniconda3/envs/env_isaaclab/lib/site-packages/isaacsim/kit/data/Kit/Isaac-Sim/5.1/user.config.json'
# [Info] [carb] Logging to file: c:/users/teresa/miniconda3/envs/env_isaaclab/lib/site-packages/isaacsim/kit/logs/Kit/Isaac-Sim/5.1/kit_20260217_160443.log
# 2026-02-17T15:04:43Z s] [Warning] [carb.crashreporter-breakpad.plugin] Failed to parse toml file 'c:/users/teresa/miniconda3/envs/env_isaaclab/lib/site-packages/isaacsim/kit/data/Kit/Isaac-Sim/5.1/2f4e0829-22ed-4519-b3a8-f06aac3b95d7.dmp.toml': c:/users/teresa/miniconda3/envs/env_isaaclab/lib/site-packages/isaacsim/kit/data/Kit/Isaac-Sim/5.1/2f4e0829-22ed-4519-b3a8-f06aac3b95d7.dmp.toml could not be opened for parsing
# 2026-02-17T15:04:43Z s] [Warning] [carb.crashreporter-breakpad.plugin] [previous crash] preventing upload of minidump due to user opt-out: 'c:/users/teresa/miniconda3/envs/env_isaaclab/lib/site-packages/isaacsim/kit/data/Kit/Isaac-Sim/5.1/2f4e0829-22ed-4519-b3a8-f06aac3b95d7.dmp'
# 2026-02-17T15:04:44Z s] [Warning] [omni.usd_config.extension] Enable omni.materialx.libs extension to use MaterialX
# 2026-02-17T15:04:44Z s] [Warning] [carb] Acquiring non optional plugin interface which is not listed as dependency: [omni::physx::IPhysxBenchmarks v1.0] (plugin: <default plugin>), by client: omni.physics.physx.plugin. Add it to CARB_PLUGIN_IMPL_DEPS() macro of a client.
# 2026-02-17T15:04:45Z [1,125ms] [Warning] [omni.isaac.dynamic_control] omni.isaac.dynamic_control is deprecated as of Isaac Sim 4.5. No action is needed from end-users.
# 2026-02-17T15:04:47Z [3,339ms] [Warning] [gpu.foundation.plugin] Skipping unsupported non-NVIDIA GPU: AMD Radeon(TM) Graphics
# 2026-02-17T15:04:47Z [3,339ms] [Warning] [gpu.foundation.plugin] Skipping unsupported non-NVIDIA GPU: AMD Radeon(TM) Graphics
#
# |---------------------------------------------------------------------------------------------|
# | Driver Version: 581.29        | Graphics API: D3D12
# |=============================================================================================|
# | GPU | Name                             | Active | LDA | GPU Memory | Vendor-ID | LUID       |
# |     |                                  |        |     |            | Device-ID | UUID       |
# |     |                                  |        |     |            | Bus-ID    |            |
# |---------------------------------------------------------------------------------------------|
# | 0   | NVIDIA GeForce RTX 5080          | Yes: 0 |     | 15889   MB | 10de      | 745b0100.. |
# |     |                                  |        |     |            | 2c02      | 0          |
# |     |                                  |        |     |            | 1         |            |
# |---------------------------------------------------------------------------------------------|
# | 1   | AMD Radeon(TM) Graphics          |        |     | 1995    MB | 1002      | d66e0100.. |
# |     |                                  |        |     |            | 13c0      | 0          |
# |     |                                  |        |     |            | N/A       |            |
# |=============================================================================================|
# | OS: Windows 11 Pro, Version: 10.0 (24H2), Build: 26100, Kernel: 10.0.26100.7824
# | Processor: AMD Ryzen 9 9950X 16-Core Processor
# | Cores: 16 | Logical Cores: 32
# |---------------------------------------------------------------------------------------------|
# | Total Memory (MB): 128627 | Free Memory: 73268
# | Total Page/Swap (MB): 136819 | Free Page/Swap: 76146
# |---------------------------------------------------------------------------------------------|
# C:\Users\Teresa\Documents\GitHub\navsim\isaac_lab\aerotaxi\env_command\env_11\flight_plan.py:29: UserWarning: Treat the new Tool classes introduced in v1.5 as experimental for now; the API and rcParam may change in future versions.
#   plt.rcParams["toolbar"] = "toolmanager"
# [INFO]: Parsing configuration from: aerotaxi.env_command.env_11.env:UAVEnvCfg
# [INFO]: Parsing configuration from: aerotaxi.env_command.env_11.grid_hiperparametros.cfg_files.ppo_random_command7_11_cfg:Command7PPORunnerCfg
# [INFO] Logging experiment in directory: C:\Users\Teresa\Documents\GitHub\navsim\isaac_lab\aerotaxi\env_command\env_11\logs\rsl_rl\command7
# Exact experiment name requested from command line: 2026-02-17_16-04-48
# Setting seed: 42
# [INFO]: Base environment:
# 	Environment device    : cuda:0
# 	Environment seed      : 42
# 	Physics step-size     : 0.005
# 	Rendering step-size   : 0.02
# 	Environment step-size : 0.02
# [INFO]: Time taken for scene creation : 4.887344 seconds
# [INFO]: Scene manager:  <class InteractiveScene>
# 	Number of environments: 8196
# 	Environment spacing   : 200.0
# 	Source prim name      : /World/envs/env_0
# 	Global prim paths     : []
# 	Replicate physics     : False
# [INFO]: Starting the simulation. This may take a few seconds. Please wait...
# [INFO]: Time taken for simulation start : 7.454151 seconds
# [INFO] Command Manager:  <CommandManager> contains 1 active terms.
# +--------------------------------------+
# |         Active Command Terms         |
# +-------+-------------+----------------+
# | Index | Name        |      Type      |
# +-------+-------------+----------------+
# |   0   | vel_command | UAVcommandTerm |
# +-------+-------------+----------------+
#
# [INFO] Event Manager:  <EventManager> contains 1 active terms.
# +-----------------------------------+
# | Active Event Terms in Mode: 'reset' |
# +----------+------------------------+
# |  Index   | Name                   |
# +----------+------------------------+
# |    0     | reset_pos              |
# |    1     | randomize_mass         |
# |    2     | randomize_wind         |
# +----------+------------------------+
#
# [INFO] Recorder Manager:  <RecorderManager> contains 0 active terms.
# +---------------------+
# | Active Recorder Terms |
# +-----------+---------+
# |   Index   | Name    |
# +-----------+---------+
# +-----------+---------+
#
# [INFO] Action Manager:  <ActionManager> contains 1 active terms.
# +-----------------------------------+
# |   Active Action Terms (shape: 4)  |
# +--------+-------------+------------+
# | Index  | Name        |  Dimension |
# +--------+-------------+------------+
# |   0    | rotors_vel  |          4 |
# +--------+-------------+------------+
#
# [INFO] Observation Manager: <ObservationManager> contains 2 groups.
# +----------------------------------------------------+
# | Active Observation Terms in Group: 'policy' (shape: (12,)) |
# +---------------+--------------------+---------------+
# |     Index     | Name               |     Shape     |
# +---------------+--------------------+---------------+
# |       0       | pos                |      (3,)     |
# |       1       | lin_vel            |      (3,)     |
# |       2       | ang_vel            |      (3,)     |
# |       3       | roll               |      (1,)     |
# |       4       | pitch              |      (1,)     |
# |       5       | yaw                |      (1,)     |
# +---------------+--------------------+---------------+
# +----------------------------------------------------+
# | Active Observation Terms in Group: 'critic' (shape: (12,)) |
# +---------------+--------------------+---------------+
# |     Index     | Name               |     Shape     |
# +---------------+--------------------+---------------+
# |       0       | pos                |      (3,)     |
# |       1       | lin_vel            |      (3,)     |
# |       2       | ang_vel            |      (3,)     |
# |       3       | roll               |      (1,)     |
# |       4       | pitch              |      (1,)     |
# |       5       | yaw                |      (1,)     |
# +---------------+--------------------+---------------+
#
# [INFO] Termination Manager:  <TerminationManager> contains 4 active terms.
# +---------------------------------------+
# |        Active Termination Terms       |
# +-------+--------------------+----------+
# | Index | Name               | Time Out |
# +-------+--------------------+----------+
# |   0   | time_out           |   True   |
# |   1   | below_min_altitude |  False   |
# |   2   | bad_attitude       |  False   |
# |   3   | safety_shutdown    |  False   |
# +-------+--------------------+----------+
#
# [INFO] Reward Manager:  <RewardManager> contains 13 active terms.
# +--------------------------------------------------+
# |               Active Reward Terms                |
# +-------+---------------------------------+--------+
# | Index | Name                            | Weight |
# +-------+---------------------------------+--------+
# |   0   | alive                           |   15.0 |
# |   1   | action_rate                     |  -0.01 |
# |   2   | terminating                     |  -10.0 |
# |   3   | rew_pos_diff                    |  -0.02 |
# |   4   | rew_pos_diff_fine_grained       |   10.0 |
# |   5   | rew_lin_vel_diff                |   -1.0 |
# |   6   | rew_lin_vel_diff_fine_grained   |    2.0 |
# |   7   | rew_ang_vel_z_diff              |   -1.0 |
# |   8   | rew_ang_vel_z_diff_fine_grained |    1.0 |
# |   9   | rew_roll_diff                   |   -0.5 |
# |   10  | rew_roll_diff_fine_grained      |    1.0 |
# |   11  | rew_pitch_diff                  |   -0.5 |
# |   12  | rew_pitch_diff_fine_grained     |    1.0 |
# +-------+---------------------------------+--------+
#
# [INFO] Curriculum Manager:  <CurriculumManager> contains 0 active terms.
# +----------------------+
# | Active Curriculum Terms |
# +-----------+----------+
# |   Index   | Name     |
# +-----------+----------+
# +-----------+----------+
#
# [INFO]: Completed setting up the environment...
# 2026-02-17T15:05:02Z [18,051ms] [Warning] [omni.physx.fabric.plugin] FabricManager::initializePointInstancer mismatched prototypes on point instancer: /Visuals/target_commands.
# C:\Users\Teresa\miniconda3\envs\env_isaaclab\Lib\site-packages\rsl_rl\utils\utils.py:244: UserWarning: The observation configuration dictionary 'obs_groups' must contain the 'policy' key. As an observation group with the name 'policy' was found, this is assumed to be the observation set. Consider adding the 'policy' key to the 'obs_groups' dictionary for clarity. This behavior will be removed in a future version.
#   warnings.warn(
# C:\Users\Teresa\miniconda3\envs\env_isaaclab\Lib\site-packages\rsl_rl\utils\utils.py:282: UserWarning: The observation configuration dictionary 'obs_groups' must contain the 'critic' key. As an observation group with the name 'critic' was found, this is assumed to be the observation set. Consider adding the 'critic' key to the 'obs_groups' dictionary for clarity. This behavior will be removed in a future version.
#   warnings.warn(
# --------------------------------------------------------------------------------
# Resolved observation sets:
# 	 policy :  ['policy']
# 	 critic :  ['critic']
# --------------------------------------------------------------------------------
# Actor MLP: MLP(
#   (0): Linear(in_features=12, out_features=64, bias=True)
#   (1): ELU(alpha=1.0)
#   (2): Linear(in_features=64, out_features=64, bias=True)
#   (3): ELU(alpha=1.0)
#   (4): Linear(in_features=64, out_features=4, bias=True)
# )
# Critic MLP: MLP(
#   (0): Linear(in_features=12, out_features=128, bias=True)
#   (1): ELU(alpha=1.0)
#   (2): Linear(in_features=128, out_features=128, bias=True)
#   (3): ELU(alpha=1.0)
#   (4): Linear(in_features=128, out_features=1, bias=True)
# )
# ################################################################################
#                        Learning iteration 0/4001
#
#                        Computation: 156160 steps/s (collection: 26.164s, learning 0.708s)
#              Mean action noise std: 0.20
#           Mean value_function loss: 7.5852
#                Mean surrogate loss: 0.0016
#                  Mean entropy loss: -0.7363
#                        Mean reward: 17.52
#                Mean episode length: 46.69
#               Episode_Reward/alive: 0.8860
#         Episode_Reward/action_rate: -0.0003
#         Episode_Reward/terminating: -0.0125
#        Episode_Reward/rew_pos_diff: -0.0020
# Episode_Reward/rew_pos_diff_fine_grained: 0.5392
#    Episode_Reward/rew_lin_vel_diff: -0.3369
# Episode_Reward/rew_lin_vel_diff_fine_grained: 0.0043
#  Episode_Reward/rew_ang_vel_z_diff: -0.0044
# Episode_Reward/rew_ang_vel_z_diff_fine_grained: 0.0517
#       Episode_Reward/rew_roll_diff: -0.0118
# Episode_Reward/rew_roll_diff_fine_grained: 0.0122
#      Episode_Reward/rew_pitch_diff: -0.0076
# Episode_Reward/rew_pitch_diff_fine_grained: 0.0165
#       Episode_Termination/time_out: 0.0062
# Episode_Termination/below_min_altitude: 0.4725
#   Episode_Termination/bad_attitude: 0.4210
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 4196352
#                     Iteration time: 26.87s
#                       Time elapsed: 00:00:26
#                                ETA: 05:51:54
#
# Could not find git repository in C:\Users\Teresa\miniconda3\envs\env_isaaclab\Lib\site-packages\rsl_rl\__init__.py. Skipping.
# Storing git diff for 'navsim' in: C:\Users\Teresa\Documents\GitHub\navsim\isaac_lab\aerotaxi\env_command\env_11\logs\rsl_rl\command7\2026-02-17_16-04-48_ppo_random_command7_11\git\navsim.diff
# ################################################################################
#                        Learning iteration 1/4001
#
#                        Computation: 162106 steps/s (collection: 25.243s, learning 0.644s)
#              Mean action noise std: 0.20
#           Mean value_function loss: 6.2570
#                Mean surrogate loss: 0.0021
#                  Mean entropy loss: -0.7121
#                        Mean reward: 17.85
#                Mean episode length: 47.30
#               Episode_Reward/alive: 0.9285
#         Episode_Reward/action_rate: -0.0003
#         Episode_Reward/terminating: -0.0133
#        Episode_Reward/rew_pos_diff: -0.0021
# Episode_Reward/rew_pos_diff_fine_grained: 0.5640
#    Episode_Reward/rew_lin_vel_diff: -0.3591
# Episode_Reward/rew_lin_vel_diff_fine_grained: 0.0043
#  Episode_Reward/rew_ang_vel_z_diff: -0.0041
# Episode_Reward/rew_ang_vel_z_diff_fine_grained: 0.0552
#       Episode_Reward/rew_roll_diff: -0.0124
# Episode_Reward/rew_roll_diff_fine_grained: 0.0129
#      Episode_Reward/rew_pitch_diff: -0.0079
# Episode_Reward/rew_pitch_diff_fine_grained: 0.0175
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 0.5018
#   Episode_Termination/bad_attitude: 0.4982
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 8392704
#                     Iteration time: 25.89s
#                       Time elapsed: 00:00:52
#                                ETA: 05:18:36
#
# ################################################################################
#                        Learning iteration 2/4001
#
#                        Computation: 162873 steps/s (collection: 25.143s, learning 0.622s)
#              Mean action noise std: 0.20
#           Mean value_function loss: 5.8829
#                Mean surrogate loss: 0.0020
#                  Mean entropy loss: -0.6724
#                        Mean reward: 18.42
#                Mean episode length: 49.22
#               Episode_Reward/alive: 0.9522
#         Episode_Reward/action_rate: -0.0004
#         Episode_Reward/terminating: -0.0133
#        Episode_Reward/rew_pos_diff: -0.0022
# Episode_Reward/rew_pos_diff_fine_grained: 0.5754
#    Episode_Reward/rew_lin_vel_diff: -0.3750
# Episode_Reward/rew_lin_vel_diff_fine_grained: 0.0043
#  Episode_Reward/rew_ang_vel_z_diff: -0.0038
# Episode_Reward/rew_ang_vel_z_diff_fine_grained: 0.0572
#       Episode_Reward/rew_roll_diff: -0.0124
# Episode_Reward/rew_roll_diff_fine_grained: 0.0135
#      Episode_Reward/rew_pitch_diff: -0.0081
# Episode_Reward/rew_pitch_diff_fine_grained: 0.0178
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 0.5577
#   Episode_Termination/bad_attitude: 0.4423
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 12589056
#                     Iteration time: 25.76s
#                       Time elapsed: 00:01:18
#                                ETA: 05:04:30
#
# ################################################################################
#                        Learning iteration 3/4001
#
#                        Computation: 159405 steps/s (collection: 25.647s, learning 0.678s)
#              Mean action noise std: 0.21
#           Mean value_function loss: 5.1811
#                Mean surrogate loss: 0.0053
#                  Mean entropy loss: -0.6459
#                        Mean reward: 18.27
#                Mean episode length: 49.33
#               Episode_Reward/alive: 0.9662
#         Episode_Reward/action_rate: -0.0004
#         Episode_Reward/terminating: -0.0133
#        Episode_Reward/rew_pos_diff: -0.0023
# Episode_Reward/rew_pos_diff_fine_grained: 0.5822
#    Episode_Reward/rew_lin_vel_diff: -0.3843
# Episode_Reward/rew_lin_vel_diff_fine_grained: 0.0043
#  Episode_Reward/rew_ang_vel_z_diff: -0.0038
# Episode_Reward/rew_ang_vel_z_diff_fine_grained: 0.0583
#       Episode_Reward/rew_roll_diff: -0.0125
# Episode_Reward/rew_roll_diff_fine_grained: 0.0139
#      Episode_Reward/rew_pitch_diff: -0.0082
# Episode_Reward/rew_pitch_diff_fine_grained: 0.0181
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 0.5895
#   Episode_Termination/bad_attitude: 0.4105
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 16785408
#                     Iteration time: 26.33s
#                       Time elapsed: 00:01:44
#                                ETA: 05:06:35
#
# ################################################################################
#                        Learning iteration 4/4001
#
#                        Computation: 156224 steps/s (collection: 26.211s, learning 0.650s)
#              Mean action noise std: 0.21
#           Mean value_function loss: 4.2293
#                Mean surrogate loss: 0.0040
#                  Mean entropy loss: -0.6393
#                        Mean reward: 18.27
#                Mean episode length: 49.12
#               Episode_Reward/alive: 0.9596
#         Episode_Reward/action_rate: -0.0004
#         Episode_Reward/terminating: -0.0133
#        Episode_Reward/rew_pos_diff: -0.0023
# Episode_Reward/rew_pos_diff_fine_grained: 0.5791
#    Episode_Reward/rew_lin_vel_diff: -0.3797
# Episode_Reward/rew_lin_vel_diff_fine_grained: 0.0043
#  Episode_Reward/rew_ang_vel_z_diff: -0.0038
# Episode_Reward/rew_ang_vel_z_diff_fine_grained: 0.0577
#       Episode_Reward/rew_roll_diff: -0.0125
# Episode_Reward/rew_roll_diff_fine_grained: 0.0136
#      Episode_Reward/rew_pitch_diff: -0.0082
# Episode_Reward/rew_pitch_diff_fine_grained: 0.0179
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 0.5754
#   Episode_Termination/bad_attitude: 0.4246
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 20981760
#                     Iteration time: 26.86s
#                       Time elapsed: 00:02:11
#                                ETA: 05:14:48
#
# ################################################################################
#                        Learning iteration 5/4001
#
#                        Computation: 161767 steps/s (collection: 25.297s, learning 0.643s)
#              Mean action noise std: 0.21
#           Mean value_function loss: 4.0772
#                Mean surrogate loss: 0.0038
#                  Mean entropy loss: -0.6322
#                        Mean reward: 18.21
#                Mean episode length: 49.16
#               Episode_Reward/alive: 0.9638
#         Episode_Reward/action_rate: -0.0004
#         Episode_Reward/terminating: -0.0133
#        Episode_Reward/rew_pos_diff: -0.0023
# Episode_Reward/rew_pos_diff_fine_grained: 0.5811
#    Episode_Reward/rew_lin_vel_diff: -0.3826
# Episode_Reward/rew_lin_vel_diff_fine_grained: 0.0043
#  Episode_Reward/rew_ang_vel_z_diff: -0.0038
# Episode_Reward/rew_ang_vel_z_diff_fine_grained: 0.0581
#       Episode_Reward/rew_roll_diff: -0.0125
# Episode_Reward/rew_roll_diff_fine_grained: 0.0138
#      Episode_Reward/rew_pitch_diff: -0.0082
# Episode_Reward/rew_pitch_diff_fine_grained: 0.0180
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 0.5863
#   Episode_Termination/bad_attitude: 0.4137
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 25178112
#                     Iteration time: 25.94s
#                       Time elapsed: 00:02:37
#                                ETA: 05:09:54
#
# ################################################################################
#                        Learning iteration 6/4001
#
#                        Computation: 161954 steps/s (collection: 25.265s, learning 0.646s)
#              Mean action noise std: 0.21
#           Mean value_function loss: 3.9551
#                Mean surrogate loss: 0.0042
#                  Mean entropy loss: -0.6257
#                        Mean reward: 19.16
#                Mean episode length: 52.47
#               Episode_Reward/alive: 0.9838
#         Episode_Reward/action_rate: -0.0004
#         Episode_Reward/terminating: -0.0133
#        Episode_Reward/rew_pos_diff: -0.0024
# Episode_Reward/rew_pos_diff_fine_grained: 0.5906
#    Episode_Reward/rew_lin_vel_diff: -0.3958
# Episode_Reward/rew_lin_vel_diff_fine_grained: 0.0043
#  Episode_Reward/rew_ang_vel_z_diff: -0.0036
# Episode_Reward/rew_ang_vel_z_diff_fine_grained: 0.0599
#       Episode_Reward/rew_roll_diff: -0.0124
# Episode_Reward/rew_roll_diff_fine_grained: 0.0144
#      Episode_Reward/rew_pitch_diff: -0.0084
# Episode_Reward/rew_pitch_diff_fine_grained: 0.0184
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 0.6380
#   Episode_Termination/bad_attitude: 0.3620
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 29374464
#                     Iteration time: 25.91s
#                       Time elapsed: 00:03:03
#                                ETA: 05:06:00
#
# ################################################################################
#                        Learning iteration 7/4001
#
#                        Computation: 160726 steps/s (collection: 25.500s, learning 0.609s)
#              Mean action noise std: 0.21
#           Mean value_function loss: 3.7917
#                Mean surrogate loss: 0.0038
#                  Mean entropy loss: -0.6204
#                        Mean reward: 18.50
#                Mean episode length: 50.22
#               Episode_Reward/alive: 1.0106
#         Episode_Reward/action_rate: -0.0004
#         Episode_Reward/terminating: -0.0133
#        Episode_Reward/rew_pos_diff: -0.0026
# Episode_Reward/rew_pos_diff_fine_grained: 0.6032
#    Episode_Reward/rew_lin_vel_diff: -0.4143
# Episode_Reward/rew_lin_vel_diff_fine_grained: 0.0043
#  Episode_Reward/rew_ang_vel_z_diff: -0.0032
# Episode_Reward/rew_ang_vel_z_diff_fine_grained: 0.0623
#       Episode_Reward/rew_roll_diff: -0.0122
# Episode_Reward/rew_roll_diff_fine_grained: 0.0155
#      Episode_Reward/rew_pitch_diff: -0.0086
# Episode_Reward/rew_pitch_diff_fine_grained: 0.0187
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 0.7106
#   Episode_Termination/bad_attitude: 0.2894
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 33570816
#                     Iteration time: 26.11s
#                       Time elapsed: 00:03:29
#                                ETA: 05:04:37
#
# ################################################################################
#                        Learning iteration 8/4001
#
#                        Computation: 162654 steps/s (collection: 25.222s, learning 0.577s)
#              Mean action noise std: 0.21
#           Mean value_function loss: 3.6637
#                Mean surrogate loss: 0.0008
#                  Mean entropy loss: -0.5921
#                        Mean reward: 19.44
#                Mean episode length: 53.52
#               Episode_Reward/alive: 1.0370
#         Episode_Reward/action_rate: -0.0004
#         Episode_Reward/terminating: -0.0133
#        Episode_Reward/rew_pos_diff: -0.0027
# Episode_Reward/rew_pos_diff_fine_grained: 0.6155
#    Episode_Reward/rew_lin_vel_diff: -0.4328
# Episode_Reward/rew_lin_vel_diff_fine_grained: 0.0042
#  Episode_Reward/rew_ang_vel_z_diff: -0.0029
# Episode_Reward/rew_ang_vel_z_diff_fine_grained: 0.0648
#       Episode_Reward/rew_roll_diff: -0.0117
# Episode_Reward/rew_roll_diff_fine_grained: 0.0168
#      Episode_Reward/rew_pitch_diff: -0.0088
# Episode_Reward/rew_pitch_diff_fine_grained: 0.0194
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 0.7900
#   Episode_Termination/bad_attitude: 0.2100
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 37767168
#                     Iteration time: 25.80s
#                       Time elapsed: 00:03:55
#                                ETA: 05:01:09
#
# ################################################################################
#                        Learning iteration 9/4001
#
#                        Computation: 162311 steps/s (collection: 25.215s, learning 0.638s)
#              Mean action noise std: 0.21
#           Mean value_function loss: 2.8072
#                Mean surrogate loss: 0.0047
#                  Mean entropy loss: -0.5717
#                        Mean reward: 19.43
#                Mean episode length: 53.05
#               Episode_Reward/alive: 1.0369
#         Episode_Reward/action_rate: -0.0004
#         Episode_Reward/terminating: -0.0133
#        Episode_Reward/rew_pos_diff: -0.0027
# Episode_Reward/rew_pos_diff_fine_grained: 0.6155
#    Episode_Reward/rew_lin_vel_diff: -0.4325
# Episode_Reward/rew_lin_vel_diff_fine_grained: 0.0042
#  Episode_Reward/rew_ang_vel_z_diff: -0.0029
# Episode_Reward/rew_ang_vel_z_diff_fine_grained: 0.0647
#       Episode_Reward/rew_roll_diff: -0.0118
# Episode_Reward/rew_roll_diff_fine_grained: 0.0168
#      Episode_Reward/rew_pitch_diff: -0.0088
# Episode_Reward/rew_pitch_diff_fine_grained: 0.0193
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 0.7946
#   Episode_Termination/bad_attitude: 0.2054
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 41963520
#                     Iteration time: 25.85s
#                       Time elapsed: 00:04:21
#                                ETA: 04:58:39
#
# ################################################################################
#                        Learning iteration 10/4001
#
#                        Computation: 161751 steps/s (collection: 25.328s, learning 0.615s)
#              Mean action noise std: 0.21
#           Mean value_function loss: 2.5279
#                Mean surrogate loss: 0.0022
#                  Mean entropy loss: -0.5095
#                        Mean reward: 19.44
#                Mean episode length: 53.47
#               Episode_Reward/alive: 1.0452
#         Episode_Reward/action_rate: -0.0004
#         Episode_Reward/terminating: -0.0133
#        Episode_Reward/rew_pos_diff: -0.0028
# Episode_Reward/rew_pos_diff_fine_grained: 0.6193
#    Episode_Reward/rew_lin_vel_diff: -0.4382
# Episode_Reward/rew_lin_vel_diff_fine_grained: 0.0042
#  Episode_Reward/rew_ang_vel_z_diff: -0.0028
# Episode_Reward/rew_ang_vel_z_diff_fine_grained: 0.0655
#       Episode_Reward/rew_roll_diff: -0.0117
# Episode_Reward/rew_roll_diff_fine_grained: 0.0170
#      Episode_Reward/rew_pitch_diff: -0.0089
# Episode_Reward/rew_pitch_diff_fine_grained: 0.0194
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 0.8162
#   Episode_Termination/bad_attitude: 0.1838
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 46159872
#                     Iteration time: 25.94s
#                       Time elapsed: 00:04:47
#                                ETA: 04:57:04
#
# ################################################################################
#                        Learning iteration 11/4001
#
#                        Computation: 162782 steps/s (collection: 25.191s, learning 0.588s)
#              Mean action noise std: 0.22
#           Mean value_function loss: 2.2649
#                Mean surrogate loss: 0.0009
#                  Mean entropy loss: -0.4692
#                        Mean reward: 19.78
#                Mean episode length: 54.48
#               Episode_Reward/alive: 1.0495
#         Episode_Reward/action_rate: -0.0004
#         Episode_Reward/terminating: -0.0133
#        Episode_Reward/rew_pos_diff: -0.0028
# Episode_Reward/rew_pos_diff_fine_grained: 0.6214
#    Episode_Reward/rew_lin_vel_diff: -0.4410
# Episode_Reward/rew_lin_vel_diff_fine_grained: 0.0042
#  Episode_Reward/rew_ang_vel_z_diff: -0.0027
# Episode_Reward/rew_ang_vel_z_diff_fine_grained: 0.0659
#       Episode_Reward/rew_roll_diff: -0.0117
# Episode_Reward/rew_roll_diff_fine_grained: 0.0172
#      Episode_Reward/rew_pitch_diff: -0.0089
# Episode_Reward/rew_pitch_diff_fine_grained: 0.0196
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 0.8284
#   Episode_Termination/bad_attitude: 0.1716
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 50356224
#                     Iteration time: 25.78s
#                       Time elapsed: 00:05:13
#                                ETA: 04:54:47
#
# ################################################################################
#                        Learning iteration 12/4001
#
#                        Computation: 161087 steps/s (collection: 25.397s, learning 0.653s)
#              Mean action noise std: 0.22
#           Mean value_function loss: 2.0581
#                Mean surrogate loss: 0.0036
#                  Mean entropy loss: -0.4327
#                        Mean reward: 19.91
#                Mean episode length: 55.02
#               Episode_Reward/alive: 1.0611
#         Episode_Reward/action_rate: -0.0004
#         Episode_Reward/terminating: -0.0133
#        Episode_Reward/rew_pos_diff: -0.0029
# Episode_Reward/rew_pos_diff_fine_grained: 0.6267
#    Episode_Reward/rew_lin_vel_diff: -0.4489
# Episode_Reward/rew_lin_vel_diff_fine_grained: 0.0042
#  Episode_Reward/rew_ang_vel_z_diff: -0.0026
# Episode_Reward/rew_ang_vel_z_diff_fine_grained: 0.0669
#       Episode_Reward/rew_roll_diff: -0.0114
# Episode_Reward/rew_roll_diff_fine_grained: 0.0179
#      Episode_Reward/rew_pitch_diff: -0.0090
# Episode_Reward/rew_pitch_diff_fine_grained: 0.0199
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 0.8644
#   Episode_Termination/bad_attitude: 0.1356
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 54552576
#                     Iteration time: 26.05s
#                       Time elapsed: 00:05:39
#                                ETA: 04:54:09
#
# ################################################################################
#                        Learning iteration 13/4001
#
#                        Computation: 161460 steps/s (collection: 25.405s, learning 0.585s)
#              Mean action noise std: 0.22
#           Mean value_function loss: 1.8151
#                Mean surrogate loss: 0.0114
#                  Mean entropy loss: -0.4135
#                        Mean reward: 19.71
#                Mean episode length: 54.09
#               Episode_Reward/alive: 1.0643
#         Episode_Reward/action_rate: -0.0004
#         Episode_Reward/terminating: -0.0133
#        Episode_Reward/rew_pos_diff: -0.0029
# Episode_Reward/rew_pos_diff_fine_grained: 0.6282
#    Episode_Reward/rew_lin_vel_diff: -0.4510
# Episode_Reward/rew_lin_vel_diff_fine_grained: 0.0042
#  Episode_Reward/rew_ang_vel_z_diff: -0.0026
# Episode_Reward/rew_ang_vel_z_diff_fine_grained: 0.0672
#       Episode_Reward/rew_roll_diff: -0.0113
# Episode_Reward/rew_roll_diff_fine_grained: 0.0181
#      Episode_Reward/rew_pitch_diff: -0.0091
# Episode_Reward/rew_pitch_diff_fine_grained: 0.0198
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 0.8747
#   Episode_Termination/bad_attitude: 0.1253
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 58748928
#                     Iteration time: 25.99s
#                       Time elapsed: 00:06:05
#                                ETA: 04:53:16
#
# ################################################################################
#                        Learning iteration 14/4001
#
#                        Computation: 163023 steps/s (collection: 25.160s, learning 0.581s)
#              Mean action noise std: 0.22
#           Mean value_function loss: 1.7587
#                Mean surrogate loss: -0.0000
#                  Mean entropy loss: -0.3738
#                        Mean reward: 19.67
#                Mean episode length: 54.22
#               Episode_Reward/alive: 1.0750
#         Episode_Reward/action_rate: -0.0004
#         Episode_Reward/terminating: -0.0133
#        Episode_Reward/rew_pos_diff: -0.0030
# Episode_Reward/rew_pos_diff_fine_grained: 0.6330
#    Episode_Reward/rew_lin_vel_diff: -0.4588
# Episode_Reward/rew_lin_vel_diff_fine_grained: 0.0042
#  Episode_Reward/rew_ang_vel_z_diff: -0.0024
# Episode_Reward/rew_ang_vel_z_diff_fine_grained: 0.0682
#       Episode_Reward/rew_roll_diff: -0.0109
# Episode_Reward/rew_roll_diff_fine_grained: 0.0188
#      Episode_Reward/rew_pitch_diff: -0.0092
# Episode_Reward/rew_pitch_diff_fine_grained: 0.0199
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 0.9116
#   Episode_Termination/bad_attitude: 0.0884
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 62945280
#                     Iteration time: 25.74s
#                       Time elapsed: 00:06:30
#                                ETA: 04:51:21
#
# ################################################################################
#                        Learning iteration 15/4001
#
#                        Computation: 162257 steps/s (collection: 25.227s, learning 0.635s)
#              Mean action noise std: 0.22
#           Mean value_function loss: 1.1302
#                Mean surrogate loss: 0.0019
#                  Mean entropy loss: -0.3529
#                        Mean reward: 19.92
#                Mean episode length: 55.40
#               Episode_Reward/alive: 1.0800
#         Episode_Reward/action_rate: -0.0004
#         Episode_Reward/terminating: -0.0133
#        Episode_Reward/rew_pos_diff: -0.0030
# Episode_Reward/rew_pos_diff_fine_grained: 0.6352
#    Episode_Reward/rew_lin_vel_diff: -0.4621
# Episode_Reward/rew_lin_vel_diff_fine_grained: 0.0042
#  Episode_Reward/rew_ang_vel_z_diff: -0.0024
# Episode_Reward/rew_ang_vel_z_diff_fine_grained: 0.0686
#       Episode_Reward/rew_roll_diff: -0.0108
# Episode_Reward/rew_roll_diff_fine_grained: 0.0191
#      Episode_Reward/rew_pitch_diff: -0.0092
# Episode_Reward/rew_pitch_diff_fine_grained: 0.0201
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 0.9279
#   Episode_Termination/bad_attitude: 0.0721
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 67141632
#                     Iteration time: 25.86s
#                       Time elapsed: 00:06:56
#                                ETA: 04:50:07
#
# ################################################################################
#                        Learning iteration 16/4001
#
#                        Computation: 164021 steps/s (collection: 25.017s, learning 0.567s)
#              Mean action noise std: 0.23
#           Mean value_function loss: 0.8431
#                Mean surrogate loss: 0.0018
#                  Mean entropy loss: -0.3101
#                        Mean reward: 19.89
#                Mean episode length: 54.58
#               Episode_Reward/alive: 1.0829
#         Episode_Reward/action_rate: -0.0004
#         Episode_Reward/terminating: -0.0133
#        Episode_Reward/rew_pos_diff: -0.0030
# Episode_Reward/rew_pos_diff_fine_grained: 0.6366
#    Episode_Reward/rew_lin_vel_diff: -0.4642
# Episode_Reward/rew_lin_vel_diff_fine_grained: 0.0042
#  Episode_Reward/rew_ang_vel_z_diff: -0.0024
# Episode_Reward/rew_ang_vel_z_diff_fine_grained: 0.0688
#       Episode_Reward/rew_roll_diff: -0.0108
# Episode_Reward/rew_roll_diff_fine_grained: 0.0192
#      Episode_Reward/rew_pitch_diff: -0.0093
# Episode_Reward/rew_pitch_diff_fine_grained: 0.0201
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 0.9381
#   Episode_Termination/bad_attitude: 0.0619
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 71337984
#                     Iteration time: 25.58s
#                       Time elapsed: 00:07:22
#                                ETA: 04:47:53
#
# ################################################################################
#                        Learning iteration 17/4001
#
#                        Computation: 162036 steps/s (collection: 25.312s, learning 0.586s)
#              Mean action noise std: 0.23
#           Mean value_function loss: 0.6136
#                Mean surrogate loss: 0.0002
#                  Mean entropy loss: -0.2645
#                        Mean reward: 20.13
#                Mean episode length: 55.89
#               Episode_Reward/alive: 1.0866
#         Episode_Reward/action_rate: -0.0004
#         Episode_Reward/terminating: -0.0133
#        Episode_Reward/rew_pos_diff: -0.0031
# Episode_Reward/rew_pos_diff_fine_grained: 0.6383
#    Episode_Reward/rew_lin_vel_diff: -0.4663
# Episode_Reward/rew_lin_vel_diff_fine_grained: 0.0042
#  Episode_Reward/rew_ang_vel_z_diff: -0.0024
# Episode_Reward/rew_ang_vel_z_diff_fine_grained: 0.0689
#       Episode_Reward/rew_roll_diff: -0.0107
# Episode_Reward/rew_roll_diff_fine_grained: 0.0194
#      Episode_Reward/rew_pitch_diff: -0.0093
# Episode_Reward/rew_pitch_diff_fine_grained: 0.0202
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 0.9457
#   Episode_Termination/bad_attitude: 0.0543
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 75534336
#                     Iteration time: 25.90s
#                       Time elapsed: 00:07:48
#                                ETA: 04:47:01
#
# ################################################################################
#                        Learning iteration 18/4001
#
#                        Computation: 162043 steps/s (collection: 25.268s, learning 0.628s)
#              Mean action noise std: 0.23
#           Mean value_function loss: 0.4859
#                Mean surrogate loss: 0.0003
#                  Mean entropy loss: -0.2205
#                        Mean reward: 20.25
#                Mean episode length: 56.19
#               Episode_Reward/alive: 1.0885
#         Episode_Reward/action_rate: -0.0004
#         Episode_Reward/terminating: -0.0133
#        Episode_Reward/rew_pos_diff: -0.0031
# Episode_Reward/rew_pos_diff_fine_grained: 0.6393
#    Episode_Reward/rew_lin_vel_diff: -0.4675
# Episode_Reward/rew_lin_vel_diff_fine_grained: 0.0042
#  Episode_Reward/rew_ang_vel_z_diff: -0.0024
# Episode_Reward/rew_ang_vel_z_diff_fine_grained: 0.0690
#       Episode_Reward/rew_roll_diff: -0.0106
# Episode_Reward/rew_roll_diff_fine_grained: 0.0196
#      Episode_Reward/rew_pitch_diff: -0.0094
# Episode_Reward/rew_pitch_diff_fine_grained: 0.0200
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 0.9534
#   Episode_Termination/bad_attitude: 0.0466
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 79730688
#                     Iteration time: 25.90s
#                       Time elapsed: 00:08:14
#                                ETA: 04:46:11
#
# ################################################################################
#                        Learning iteration 19/4001
#
#                        Computation: 160799 steps/s (collection: 25.453s, learning 0.643s)
#              Mean action noise std: 0.23
#           Mean value_function loss: 0.3859
#                Mean surrogate loss: 0.0008
#                  Mean entropy loss: -0.1871
#                        Mean reward: 20.28
#                Mean episode length: 56.15
#               Episode_Reward/alive: 1.0916
#         Episode_Reward/action_rate: -0.0005
#         Episode_Reward/terminating: -0.0133
#        Episode_Reward/rew_pos_diff: -0.0031
# Episode_Reward/rew_pos_diff_fine_grained: 0.6408
#    Episode_Reward/rew_lin_vel_diff: -0.4690
# Episode_Reward/rew_lin_vel_diff_fine_grained: 0.0042
#  Episode_Reward/rew_ang_vel_z_diff: -0.0025
# Episode_Reward/rew_ang_vel_z_diff_fine_grained: 0.0691
#       Episode_Reward/rew_roll_diff: -0.0106
# Episode_Reward/rew_roll_diff_fine_grained: 0.0197
#      Episode_Reward/rew_pitch_diff: -0.0094
# Episode_Reward/rew_pitch_diff_fine_grained: 0.0202
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 0.9559
#   Episode_Termination/bad_attitude: 0.0441
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 83927040
#                     Iteration time: 26.10s
#                       Time elapsed: 00:08:40
#                                ETA: 04:46:04
#
# ################################################################################
#                        Learning iteration 20/4001
#
#                        Computation: 164128 steps/s (collection: 24.992s, learning 0.576s)
#              Mean action noise std: 0.24
#           Mean value_function loss: 0.2478
#                Mean surrogate loss: -0.0011
#                  Mean entropy loss: -0.1246
#                        Mean reward: 19.94
#                Mean episode length: 55.36
#               Episode_Reward/alive: 1.0956
#         Episode_Reward/action_rate: -0.0005
#         Episode_Reward/terminating: -0.0133
#        Episode_Reward/rew_pos_diff: -0.0031
# Episode_Reward/rew_pos_diff_fine_grained: 0.6427
#    Episode_Reward/rew_lin_vel_diff: -0.4716
# Episode_Reward/rew_lin_vel_diff_fine_grained: 0.0042
#  Episode_Reward/rew_ang_vel_z_diff: -0.0026
# Episode_Reward/rew_ang_vel_z_diff_fine_grained: 0.0692
#       Episode_Reward/rew_roll_diff: -0.0103
# Episode_Reward/rew_roll_diff_fine_grained: 0.0201
#      Episode_Reward/rew_pitch_diff: -0.0094
# Episode_Reward/rew_pitch_diff_fine_grained: 0.0202
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 0.9635
#   Episode_Termination/bad_attitude: 0.0365
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 88123392
#                     Iteration time: 25.57s
#                       Time elapsed: 00:09:05
#                                ETA: 04:44:14
#
# ################################################################################
#                        Learning iteration 21/4001
#
#                        Computation: 155918 steps/s (collection: 26.331s, learning 0.582s)
#              Mean action noise std: 0.24
#           Mean value_function loss: 0.1836
#                Mean surrogate loss: -0.0004
#                  Mean entropy loss: -0.0800
#                        Mean reward: 20.12
#                Mean episode length: 55.76
#               Episode_Reward/alive: 1.0970
#         Episode_Reward/action_rate: -0.0005
#         Episode_Reward/terminating: -0.0133
#        Episode_Reward/rew_pos_diff: -0.0031
# Episode_Reward/rew_pos_diff_fine_grained: 0.6433
#    Episode_Reward/rew_lin_vel_diff: -0.4726
# Episode_Reward/rew_lin_vel_diff_fine_grained: 0.0042
#  Episode_Reward/rew_ang_vel_z_diff: -0.0028
# Episode_Reward/rew_ang_vel_z_diff_fine_grained: 0.0690
#       Episode_Reward/rew_roll_diff: -0.0104
# Episode_Reward/rew_roll_diff_fine_grained: 0.0199
#      Episode_Reward/rew_pitch_diff: -0.0094
# Episode_Reward/rew_pitch_diff_fine_grained: 0.0202
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 0.9560
#   Episode_Termination/bad_attitude: 0.0440
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 92319744
#                     Iteration time: 26.91s
#                       Time elapsed: 00:09:32
#                                ETA: 04:46:36
#
# ################################################################################
#                        Learning iteration 22/4001
#
#                        Computation: 158410 steps/s (collection: 25.842s, learning 0.648s)
#              Mean action noise std: 0.24
#           Mean value_function loss: 0.1359
#                Mean surrogate loss: -0.0011
#                  Mean entropy loss: -0.0303
#                        Mean reward: 19.91
#                Mean episode length: 55.01
#               Episode_Reward/alive: 1.0985
#         Episode_Reward/action_rate: -0.0005
#         Episode_Reward/terminating: -0.0133
#        Episode_Reward/rew_pos_diff: -0.0031
# Episode_Reward/rew_pos_diff_fine_grained: 0.6443
#    Episode_Reward/rew_lin_vel_diff: -0.4730
# Episode_Reward/rew_lin_vel_diff_fine_grained: 0.0042
#  Episode_Reward/rew_ang_vel_z_diff: -0.0030
# Episode_Reward/rew_ang_vel_z_diff_fine_grained: 0.0686
#       Episode_Reward/rew_roll_diff: -0.0105
# Episode_Reward/rew_roll_diff_fine_grained: 0.0198
#      Episode_Reward/rew_pitch_diff: -0.0095
# Episode_Reward/rew_pitch_diff_fine_grained: 0.0202
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 0.9395
#   Episode_Termination/bad_attitude: 0.0605
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 96516096
#                     Iteration time: 26.49s
#                       Time elapsed: 00:09:59
#                                ETA: 04:47:30
#
# ################################################################################
#                        Learning iteration 23/4001
#
#                        Computation: 164540 steps/s (collection: 24.866s, learning 0.638s)
#              Mean action noise std: 0.25
#           Mean value_function loss: 0.1070
# ...
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 0.9509
#   Episode_Termination/bad_attitude: 0.0491
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 893822976
#                     Iteration time: 26.89s
#                       Time elapsed: 01:32:36
#                                ETA: 03:27:16
#
# ################################################################################
#                       Learning iteration 213/4001
#
#                        Computation: 154992 steps/s (collection: 26.451s, learning 0.624s)
#              Mean action noise std: 0.28
#           Mean value_function loss: 0.0354
#                Mean surrogate loss: 0.0021
#                  Mean entropy loss: 0.3588
#                        Mean reward: 33.42
#                Mean episode length: 86.10
#               Episode_Reward/alive: 1.7236
#         Episode_Reward/action_rate: -0.0009
#         Episode_Reward/terminating: -0.0133
#        Episode_Reward/rew_pos_diff: -0.0051
# Episode_Reward/rew_pos_diff_fine_grained: 0.9952
#    Episode_Reward/rew_lin_vel_diff: -0.6290
# Episode_Reward/rew_lin_vel_diff_fine_grained: 0.0087
#  Episode_Reward/rew_ang_vel_z_diff: -0.0045
# Episode_Reward/rew_ang_vel_z_diff_fine_grained: 0.1073
#       Episode_Reward/rew_roll_diff: -0.0056
# Episode_Reward/rew_roll_diff_fine_grained: 0.0725
#      Episode_Reward/rew_pitch_diff: -0.0203
# Episode_Reward/rew_pitch_diff_fine_grained: 0.0240
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 0.9506
#   Episode_Termination/bad_attitude: 0.0494
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 898019328
#                     Iteration time: 27.07s
#                       Time elapsed: 01:33:03
#                                ETA: 03:27:08
#
# ################################################################################
#                       Learning iteration 214/4001
#
#                        Computation: 157932 steps/s (collection: 25.987s, learning 0.584s)
#              Mean action noise std: 0.28
#           Mean value_function loss: 0.0371
#                Mean surrogate loss: 0.0036
#                  Mean entropy loss: 0.3515
#                        Mean reward: 34.13
#                Mean episode length: 87.52
#               Episode_Reward/alive: 1.7261
#         Episode_Reward/action_rate: -0.0009
#         Episode_Reward/terminating: -0.0133
#        Episode_Reward/rew_pos_diff: -0.0052
# Episode_Reward/rew_pos_diff_fine_grained: 0.9961
#    Episode_Reward/rew_lin_vel_diff: -0.6309
# Episode_Reward/rew_lin_vel_diff_fine_grained: 0.0087
#  Episode_Reward/rew_ang_vel_z_diff: -0.0044
# Episode_Reward/rew_ang_vel_z_diff_fine_grained: 0.1076
#       Episode_Reward/rew_roll_diff: -0.0055
# Episode_Reward/rew_roll_diff_fine_grained: 0.0729
#      Episode_Reward/rew_pitch_diff: -0.0202
# Episode_Reward/rew_pitch_diff_fine_grained: 0.0243
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 0.9519
#   Episode_Termination/bad_attitude: 0.0481
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 902215680
#                     Iteration time: 26.57s
#                       Time elapsed: 01:33:29
#                                ETA: 03:26:50
#
# ################################################################################
#                       Learning iteration 215/4001
#
#                        Computation: 156349 steps/s (collection: 26.219s, learning 0.621s)
#              Mean action noise std: 0.28
#           Mean value_function loss: 0.0664
#                Mean surrogate loss: 0.0019
#                  Mean entropy loss: 0.3466
#                        Mean reward: 34.48
#                Mean episode length: 88.74
#               Episode_Reward/alive: 1.7273
#         Episode_Reward/action_rate: -0.0009
#         Episode_Reward/terminating: -0.0133
#        Episode_Reward/rew_pos_diff: -0.0052
# Episode_Reward/rew_pos_diff_fine_grained: 0.9967
#    Episode_Reward/rew_lin_vel_diff: -0.6313
# Episode_Reward/rew_lin_vel_diff_fine_grained: 0.0087
#  Episode_Reward/rew_ang_vel_z_diff: -0.0044
# Episode_Reward/rew_ang_vel_z_diff_fine_grained: 0.1078
#       Episode_Reward/rew_roll_diff: -0.0055
# Episode_Reward/rew_roll_diff_fine_grained: 0.0732
#      Episode_Reward/rew_pitch_diff: -0.0202
# Episode_Reward/rew_pitch_diff_fine_grained: 0.0245
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 0.9522
#   Episode_Termination/bad_attitude: 0.0478
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 906412032
#                     Iteration time: 26.84s
#                       Time elapsed: 01:33:56
#                                ETA: 03:26:37
#
# ################################################################################
#                       Learning iteration 216/4001
#
#                        Computation: 156944 steps/s (collection: 26.116s, learning 0.622s)
#              Mean action noise std: 0.28
#           Mean value_function loss: 0.2690
#                Mean surrogate loss: 0.0108
#                  Mean entropy loss: 0.3672
#                        Mean reward: 33.50
#                Mean episode length: 87.24
#               Episode_Reward/alive: 1.7259
#         Episode_Reward/action_rate: -0.0009
#         Episode_Reward/terminating: -0.0133
#        Episode_Reward/rew_pos_diff: -0.0052
# Episode_Reward/rew_pos_diff_fine_grained: 0.9961
#    Episode_Reward/rew_lin_vel_diff: -0.6306
# Episode_Reward/rew_lin_vel_diff_fine_grained: 0.0087
#  Episode_Reward/rew_ang_vel_z_diff: -0.0043
# Episode_Reward/rew_ang_vel_z_diff_fine_grained: 0.1078
#       Episode_Reward/rew_roll_diff: -0.0055
# Episode_Reward/rew_roll_diff_fine_grained: 0.0732
#      Episode_Reward/rew_pitch_diff: -0.0203
# Episode_Reward/rew_pitch_diff_fine_grained: 0.0242
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 0.9501
#   Episode_Termination/bad_attitude: 0.0499
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 910608384
#                     Iteration time: 26.74s
#                       Time elapsed: 01:34:23
#                                ETA: 03:26:22
#
# ################################################################################
#                       Learning iteration 217/4001
#
#                        Computation: 157052 steps/s (collection: 26.144s, learning 0.575s)
#              Mean action noise std: 0.28
#           Mean value_function loss: 0.0260
#                Mean surrogate loss: 0.0043
#                  Mean entropy loss: 0.3668
#                        Mean reward: 33.79
#                Mean episode length: 87.61
#               Episode_Reward/alive: 1.7266
#         Episode_Reward/action_rate: -0.0010
#         Episode_Reward/terminating: -0.0133
#        Episode_Reward/rew_pos_diff: -0.0052
# Episode_Reward/rew_pos_diff_fine_grained: 0.9966
#    Episode_Reward/rew_lin_vel_diff: -0.6305
# Episode_Reward/rew_lin_vel_diff_fine_grained: 0.0087
#  Episode_Reward/rew_ang_vel_z_diff: -0.0043
# Episode_Reward/rew_ang_vel_z_diff_fine_grained: 0.1078
#       Episode_Reward/rew_roll_diff: -0.0055
# Episode_Reward/rew_roll_diff_fine_grained: 0.0732
#      Episode_Reward/rew_pitch_diff: -0.0204
# Episode_Reward/rew_pitch_diff_fine_grained: 0.0241
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 0.9496
#   Episode_Termination/bad_attitude: 0.0504
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 914804736
#                     Iteration time: 26.72s
#                       Time elapsed: 01:34:50
#                                ETA: 03:26:07
#
# ################################################################################
#                       Learning iteration 218/4001
#
#                        Computation: 160845 steps/s (collection: 25.527s, learning 0.563s)
#              Mean action noise std: 0.28
#           Mean value_function loss: 0.0317
#                Mean surrogate loss: 0.0019
#                  Mean entropy loss: 0.3672
#                        Mean reward: 33.70
#                Mean episode length: 86.96
#               Episode_Reward/alive: 1.7268
#         Episode_Reward/action_rate: -0.0010
#         Episode_Reward/terminating: -0.0133
#        Episode_Reward/rew_pos_diff: -0.0052
# Episode_Reward/rew_pos_diff_fine_grained: 0.9968
#    Episode_Reward/rew_lin_vel_diff: -0.6302
# Episode_Reward/rew_lin_vel_diff_fine_grained: 0.0087
#  Episode_Reward/rew_ang_vel_z_diff: -0.0044
# Episode_Reward/rew_ang_vel_z_diff_fine_grained: 0.1078
#       Episode_Reward/rew_roll_diff: -0.0055
# Episode_Reward/rew_roll_diff_fine_grained: 0.0734
#      Episode_Reward/rew_pitch_diff: -0.0204
# Episode_Reward/rew_pitch_diff_fine_grained: 0.0241
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 0.9478
#   Episode_Termination/bad_attitude: 0.0522
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 919001088
#                     Iteration time: 26.09s
#                       Time elapsed: 01:35:16
#                                ETA: 03:25:41
#
# ################################################################################
#                       Learning iteration 219/4001
#
#                        Computation: 160619 steps/s (collection: 25.548s, learning 0.578s)
#              Mean action noise std: 0.28
#           Mean value_function loss: 0.0660
#                Mean surrogate loss: 0.0019
#                  Mean entropy loss: 0.3707
#                        Mean reward: 33.17
#                Mean episode length: 86.09
#               Episode_Reward/alive: 1.7268
#         Episode_Reward/action_rate: -0.0010
#         Episode_Reward/terminating: -0.0133
#        Episode_Reward/rew_pos_diff: -0.0052
# Episode_Reward/rew_pos_diff_fine_grained: 0.9966
#    Episode_Reward/rew_lin_vel_diff: -0.6307
# Episode_Reward/rew_lin_vel_diff_fine_grained: 0.0087
#  Episode_Reward/rew_ang_vel_z_diff: -0.0043
# Episode_Reward/rew_ang_vel_z_diff_fine_grained: 0.1079
#       Episode_Reward/rew_roll_diff: -0.0055
# Episode_Reward/rew_roll_diff_fine_grained: 0.0733
#      Episode_Reward/rew_pitch_diff: -0.0203
# Episode_Reward/rew_pitch_diff_fine_grained: 0.0242
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 0.9504
#   Episode_Termination/bad_attitude: 0.0496
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 923197440
#                     Iteration time: 26.13s
#                       Time elapsed: 01:35:42
#                                ETA: 03:25:15
#
# ################################################################################
#                       Learning iteration 220/4001
#
#                        Computation: 156934 steps/s (collection: 26.095s, learning 0.645s)
#              Mean action noise std: 0.28
#           Mean value_function loss: 0.0865
#                Mean surrogate loss: 0.0044
#                  Mean entropy loss: 0.3763
#                        Mean reward: 33.75
#                Mean episode length: 87.73
#               Episode_Reward/alive: 1.7263
#         Episode_Reward/action_rate: -0.0010
#         Episode_Reward/terminating: -0.0133
#        Episode_Reward/rew_pos_diff: -0.0052
# Episode_Reward/rew_pos_diff_fine_grained: 0.9966
#    Episode_Reward/rew_lin_vel_diff: -0.6299
# Episode_Reward/rew_lin_vel_diff_fine_grained: 0.0088
#  Episode_Reward/rew_ang_vel_z_diff: -0.0043
# Episode_Reward/rew_ang_vel_z_diff_fine_grained: 0.1080
#       Episode_Reward/rew_roll_diff: -0.0055
# Episode_Reward/rew_roll_diff_fine_grained: 0.0735
#      Episode_Reward/rew_pitch_diff: -0.0203
# Episode_Reward/rew_pitch_diff_fine_grained: 0.0242
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 0.9513
#   Episode_Termination/bad_attitude: 0.0487
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 927393792
#                     Iteration time: 26.74s
#                       Time elapsed: 01:36:09
#                                ETA: 03:25:00
#
# ################################################################################
#                       Learning iteration 221/4001
#
#                        Computation: 159501 steps/s (collection: 25.684s, learning 0.625s)
#              Mean action noise std: 0.28
#           Mean value_function loss: 0.0601
#                Mean surrogate loss: 0.0032
#                  Mean entropy loss: 0.3734
#                        Mean reward: 33.87
#                Mean episode length: 87.56
#               Episode_Reward/alive: 1.7283
#         Episode_Reward/action_rate: -0.0010
#         Episode_Reward/terminating: -0.0133
#        Episode_Reward/rew_pos_diff: -0.0052
# Episode_Reward/rew_pos_diff_fine_grained: 0.9972
#    Episode_Reward/rew_lin_vel_diff: -0.6315
# Episode_Reward/rew_lin_vel_diff_fine_grained: 0.0086
#  Episode_Reward/rew_ang_vel_z_diff: -0.0043
# Episode_Reward/rew_ang_vel_z_diff_fine_grained: 0.1081
#       Episode_Reward/rew_roll_diff: -0.0055
# Episode_Reward/rew_roll_diff_fine_grained: 0.0734
#      Episode_Reward/rew_pitch_diff: -0.0202
# Episode_Reward/rew_pitch_diff_fine_grained: 0.0245
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 0.9530
#   Episode_Termination/bad_attitude: 0.0470
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 931590144
#                     Iteration time: 26.31s
#                       Time elapsed: 01:36:35
#                                ETA: 03:24:37
#
# ################################################################################
#                       Learning iteration 222/4001
#
#                        Computation: 159137 steps/s (collection: 25.785s, learning 0.584s)
#              Mean action noise std: 0.28
#           Mean value_function loss: 0.0397
#                Mean surrogate loss: 0.0035
#                  Mean entropy loss: 0.3761
#                        Mean reward: 33.33
#                Mean episode length: 85.61
#               Episode_Reward/alive: 1.7276
#         Episode_Reward/action_rate: -0.0010
#         Episode_Reward/terminating: -0.0133
#        Episode_Reward/rew_pos_diff: -0.0052
# Episode_Reward/rew_pos_diff_fine_grained: 0.9969
#    Episode_Reward/rew_lin_vel_diff: -0.6313
# Episode_Reward/rew_lin_vel_diff_fine_grained: 0.0086
#  Episode_Reward/rew_ang_vel_z_diff: -0.0042
# Episode_Reward/rew_ang_vel_z_diff_fine_grained: 0.1082
#       Episode_Reward/rew_roll_diff: -0.0054
# Episode_Reward/rew_roll_diff_fine_grained: 0.0738
#      Episode_Reward/rew_pitch_diff: -0.0202
# Episode_Reward/rew_pitch_diff_fine_grained: 0.0245
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 0.9546
#   Episode_Termination/bad_attitude: 0.0454
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 935786496
#                     Iteration time: 26.37s
#                       Time elapsed: 01:37:01
#                                ETA: 03:24:15
#
#
# Entrenamiento cancelado por el usuario.
#
# --- Todos los experimentos han finalizado ---

# %% [markdown]
# ``Análisis de los datos``

# %%
import csv
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

seed = 42
n=5

df_results_grid_actions = pd.read_csv(path_resultados+"/resultados_grid_PPO.csv")

# %%
def get_group(value):
    if f"_{experiment_name}" in value:
        return task_name

df_results_grid_actions["tarea"] = df_results_grid_actions["id_run_name"].apply(get_group)

# %%
df_copy = df_results_grid_actions.copy()
df_results_grid_actions.sample(n, random_state=seed)
# Out:
#               id_run_name  iteration     reward  max_reward  std_reward  \
# 0  ppo_random_command5_11          0  -2.420788   28.929943   11.037044
# 1  ppo_random_command5_11        100   0.069266   27.518446    6.282837
# 8  ppo_random_command5_11        800  96.731036  564.745300  118.674819
# 5  ppo_random_command5_11        500  45.248518  449.829529   95.919549
# 3  ppo_random_command5_11        300  18.817899  178.520355   46.518866
#
#    num_envs_train  mean_Episode_Reward/alive  mean_Episode_Reward/action_rate  \
# 0            8196                   0.297308                        -0.004342
# 1            8196                   0.187469                        -0.003808
# 8            8196                   1.936564                        -0.077961
# 5            8196                   1.280472                        -0.043600
# 3            8196                   0.584474                        -0.017433
#
#    mean_Episode_Reward/terminating  mean_Episode_Reward/rew_pos_diff  ...  \
# 0                        -0.018723                         -0.398911  ...
# 1                        -0.020000                         -0.209163  ...
# 8                        -0.019991                         -1.186707  ...
# 5                        -0.019999                         -0.841125  ...
# 3                        -0.020000                         -0.480084  ...
#
#    mean_Episode_Reward/rew_roll_diff  \
# 0                          -0.003313
# 1                          -0.002345
# 8                          -0.013668
# 5                          -0.007725
# 3                          -0.003992
#
#    mean_Episode_Reward/rew_roll_diff_fine_grained  \
# 0                                        0.004749
# 1                                        0.002929
# 8                                        0.050434
# 5                                        0.039402
# 3                                        0.017101
#
#    mean_Episode_Reward/rew_pitch_diff  \
# 0                           -0.002472
# 1                           -0.001550
# 8                           -0.012553
# 5                           -0.007925
# 3                           -0.003494
#
#    mean_Episode_Reward/rew_pitch_diff_fine_grained  \
# 0                                         0.005721
# 1                                         0.003735
# 8                                         0.052967
# 5                                         0.036866
# 3                                         0.017664
#
#    mean_Episode_Reward/rew_heading_alignment_fine_grained  \
# 0                                           0.021445
# 1                                           0.015808
# 8                                           0.179734
# 5                                           0.132950
# 3                                           0.088294
#
#    mean_Episode_Termination/time_out  \
# 0                           0.002533
# 1                           0.000000
# 8                           0.000429
# 5                           0.000004
# 3                           0.000000
#
#    mean_Episode_Termination/below_min_altitude  \
# 0                                     0.709719
# 1                                     0.295867
# 8                                     0.192017
# 5                                     0.251283
# 3                                     0.300422
#
#    mean_Episode_Termination/bad_attitude  \
# 0                               0.179223
# 1                               0.704133
# 8                               0.807554
# 5                               0.748713
# 3                               0.699578
#
#    mean_Episode_Termination/safety_shutdown     tarea
# 0                                       0.0  Command5
# 1                                       0.0  Command5
# 8                                       0.0  Command5
# 5                                       0.0  Command5
# 3                                       0.0  Command5
#
# [5 rows x 25 columns]

# %%
df_results_grid_actions.set_index(['tarea','id_run_name'],inplace=True)
top5 = (
    df_results_grid_actions.groupby(level="tarea")
      .apply(lambda g: g.sort_values("reward", ascending=False).head(5))
)

# Eliminar el nivel adicional que introduce groupby+apply
top5.index = top5.index.droplevel(0)

top5
# Out:
#                                  iteration      reward  max_reward  \
# tarea    id_run_name
# Command5 ppo_random_command5_11       1500  148.359473  820.291809
#          ppo_random_command5_11       1200  116.045358  747.452820
#          ppo_random_command5_11       1300   98.483841  758.258545
#          ppo_random_command5_11        800   96.731036  564.745300
#          ppo_random_command5_11       1400   88.791428  773.788818
#
#                                  std_reward  num_envs_train  \
# tarea    id_run_name
# Command5 ppo_random_command5_11  164.720314            8196
#          ppo_random_command5_11  155.794705            8196
#          ppo_random_command5_11  140.834091            8196
#          ppo_random_command5_11  118.674819            8196
#          ppo_random_command5_11  146.511362            8196
#
#                                  mean_Episode_Reward/alive  \
# tarea    id_run_name
# Command5 ppo_random_command5_11                   2.645218
#          ppo_random_command5_11                   2.575988
#          ppo_random_command5_11                   2.726593
#          ppo_random_command5_11                   1.936564
#          ppo_random_command5_11                   2.175446
#
#                                  mean_Episode_Reward/action_rate  \
# tarea    id_run_name
# Command5 ppo_random_command5_11                        -0.170349
#          ppo_random_command5_11                        -0.140482
#          ppo_random_command5_11                        -0.160750
#          ppo_random_command5_11                        -0.077961
#          ppo_random_command5_11                        -0.136057
#
#                                  mean_Episode_Reward/terminating  \
# tarea    id_run_name
# Command5 ppo_random_command5_11                        -0.019928
#          ppo_random_command5_11                        -0.019937
#          ppo_random_command5_11                        -0.019934
#          ppo_random_command5_11                        -0.019991
#          ppo_random_command5_11                        -0.019967
#
#                                  mean_Episode_Reward/rew_pos_diff  \
# tarea    id_run_name
# Command5 ppo_random_command5_11                         -1.648187
#          ppo_random_command5_11                         -1.556682
#          ppo_random_command5_11                         -1.733619
#          ppo_random_command5_11                         -1.186707
#          ppo_random_command5_11                         -1.334910
#
#                                  mean_Episode_Reward/rew_pos_diff_fine_grained  \
# tarea    id_run_name
# Command5 ppo_random_command5_11                                       0.961597
#          ppo_random_command5_11                                       0.979989
#          ppo_random_command5_11                                       0.983936
#          ppo_random_command5_11                                       0.703882
#          ppo_random_command5_11                                       0.796941
#
#                                  ...  \
# tarea    id_run_name             ...
# Command5 ppo_random_command5_11  ...
#          ppo_random_command5_11  ...
#          ppo_random_command5_11  ...
#          ppo_random_command5_11  ...
#          ppo_random_command5_11  ...
#
#                                  mean_Episode_Reward/rew_ang_vel_z_diff_fine_grained  \
# tarea    id_run_name
# Command5 ppo_random_command5_11                                           0.108495
#          ppo_random_command5_11                                           0.102867
#          ppo_random_command5_11                                           0.108917
#          ppo_random_command5_11                                           0.076896
#          ppo_random_command5_11                                           0.087503
#
#                                  mean_Episode_Reward/rew_roll_diff  \
# tarea    id_run_name
# Command5 ppo_random_command5_11                          -0.022003
#          ppo_random_command5_11                          -0.021002
#          ppo_random_command5_11                          -0.021859
#          ppo_random_command5_11                          -0.013668
#          ppo_random_command5_11                          -0.018389
#
#                                  mean_Episode_Reward/rew_roll_diff_fine_grained  \
# tarea    id_run_name
# Command5 ppo_random_command5_11                                        0.060470
#          ppo_random_command5_11                                        0.058830
#          ppo_random_command5_11                                        0.063690
#          ppo_random_command5_11                                        0.050434
#          ppo_random_command5_11                                        0.048583
#
#                                  mean_Episode_Reward/rew_pitch_diff  \
# tarea    id_run_name
# Command5 ppo_random_command5_11                           -0.015581
#          ppo_random_command5_11                           -0.016021
#          ppo_random_command5_11                           -0.017357
#          ppo_random_command5_11                           -0.012553
#          ppo_random_command5_11                           -0.013517
#
#                                  mean_Episode_Reward/rew_pitch_diff_fine_grained  \
# tarea    id_run_name
# Command5 ppo_random_command5_11                                         0.081116
#          ppo_random_command5_11                                         0.073842
#          ppo_random_command5_11                                         0.078244
#          ppo_random_command5_11                                         0.052967
#          ppo_random_command5_11                                         0.063434
#
#                                  mean_Episode_Reward/rew_heading_alignment_fine_grained  \
# tarea    id_run_name
# Command5 ppo_random_command5_11                                           0.318173
#          ppo_random_command5_11                                           0.274126
#          ppo_random_command5_11                                           0.322139
#          ppo_random_command5_11                                           0.179734
#          ppo_random_command5_11                                           0.239702
#
#                                  mean_Episode_Termination/time_out  \
# tarea    id_run_name
# Command5 ppo_random_command5_11                           0.003009
#          ppo_random_command5_11                           0.002590
#          ppo_random_command5_11                           0.003723
#          ppo_random_command5_11                           0.000429
#          ppo_random_command5_11                           0.001653
#
#                                  mean_Episode_Termination/below_min_altitude  \
# tarea    id_run_name
# Command5 ppo_random_command5_11                                     0.103489
#          ppo_random_command5_11                                     0.152105
#          ppo_random_command5_11                                     0.121192
#          ppo_random_command5_11                                     0.192017
#          ppo_random_command5_11                                     0.094360
#
#                                  mean_Episode_Termination/bad_attitude  \
# tarea    id_run_name
# Command5 ppo_random_command5_11                               0.893503
#          ppo_random_command5_11                               0.845305
#          ppo_random_command5_11                               0.875084
#          ppo_random_command5_11                               0.807554
#          ppo_random_command5_11                               0.903987
#
#                                  mean_Episode_Termination/safety_shutdown
# tarea    id_run_name
# Command5 ppo_random_command5_11                                       0.0
#          ppo_random_command5_11                                       0.0
#          ppo_random_command5_11                                       0.0
#          ppo_random_command5_11                                       0.0
#          ppo_random_command5_11                                       0.0
#
# [5 rows x 23 columns]

# %%
mean_rewards = df_results_grid_actions.groupby(["tarea", "id_run_name"])["reward"].mean()

for tarea, subdf in mean_rewards.groupby(level="tarea"):
    plt.figure(figsize=(12,5))
    
    # Convertir a DataFrame y resetear index para graficar
    plot_df = subdf.reset_index()
    plot_df = plot_df.sort_values("reward", ascending=False)
    
    plt.bar(plot_df["id_run_name"], plot_df["reward"])
    plt.title(f"Reward media por modelo - {tarea}")
    plt.xlabel("id_run_name")
    plt.ylabel("Reward media")
    plt.xticks(rotation=90)
    plt.tight_layout()
    plt.show()

# %%
df_callbacks = pd.read_csv(path_resultados+"/reward_best_models.csv",index_col='id_run_name')
top5_models = df_callbacks.nlargest(5,columns="reward")
top5_models
# Out:
#                         iteration      reward  max_reward  std_reward  \
# id_run_name
# ppo_random_command5_11       1289  154.030015  616.214417   170.69982
#
#                         num_envs_train  mean_Episode_Reward/alive  \
# id_run_name
# ppo_random_command5_11            8196                    2.90881
#
#                         mean_Episode_Reward/action_rate  \
# id_run_name
# ppo_random_command5_11                        -0.170342
#
#                         mean_Episode_Reward/terminating  \
# id_run_name
# ppo_random_command5_11                        -0.019911
#
#                         mean_Episode_Reward/rew_pos_diff  \
# id_run_name
# ppo_random_command5_11                         -1.788109
#
#                         mean_Episode_Reward/rew_pos_diff_fine_grained  ...  \
# id_run_name                                                            ...
# ppo_random_command5_11                                       1.092515  ...
#
#                         mean_Episode_Reward/rew_ang_vel_z_diff_fine_grained  \
# id_run_name
# ppo_random_command5_11                                           0.118949
#
#                         mean_Episode_Reward/rew_roll_diff  \
# id_run_name
# ppo_random_command5_11                          -0.023586
#
#                         mean_Episode_Reward/rew_roll_diff_fine_grained  \
# id_run_name
# ppo_random_command5_11                                        0.067315
#
#                         mean_Episode_Reward/rew_pitch_diff  \
# id_run_name
# ppo_random_command5_11                           -0.017664
#
#                         mean_Episode_Reward/rew_pitch_diff_fine_grained  \
# id_run_name
# ppo_random_command5_11                                         0.085878
#
#                         mean_Episode_Reward/rew_heading_alignment_fine_grained  \
# id_run_name
# ppo_random_command5_11                                           0.349344
#
#                         mean_Episode_Termination/time_out  \
# id_run_name
# ppo_random_command5_11                           0.005447
#
#                         mean_Episode_Termination/below_min_altitude  \
# id_run_name
# ppo_random_command5_11                                     0.144526
#
#                         mean_Episode_Termination/bad_attitude  \
# id_run_name
# ppo_random_command5_11                               0.850027
#
#                         mean_Episode_Termination/safety_shutdown
# id_run_name
# ppo_random_command5_11                                       0.0
#
# [1 rows x 23 columns]

# %% [markdown]
# Graficamos cómo fue el entrenamiento para los 5 mejores modelos según los callbacks:

# %%
import matplotlib.pyplot as plt
import numpy as np

# Aseguramos que `top5_auc` tenga 'tarea' e 'id_run_name' como columnas, no solo en el índice
df_callbacks = pd.read_csv(path_resultados+"/reward_best_models.csv",index_col='id_run_name')
top5_models = df_callbacks.nlargest(5,columns="reward")
top5_reset = top5_models.reset_index()
top5_reset["tarea"] = top5_reset["id_run_name"].apply(get_group)


# Convertir el índice jerárquico en columnas (para acceder a 'tarea' y 'id_run_name')
df_copy_reset = df_copy.reset_index()

# Unimos `top5_auc_reset` con `df_copy_reset` en las columnas comunes: 'tarea' y 'id_run_name'
merged_df = pd.merge(df_copy_reset, top5_reset[['tarea', 'id_run_name']], on=['tarea', 'id_run_name'], how='inner')

# Usamos una lista de colores para asignar un color diferente a cada modelo
colors = plt.cm.viridis(np.linspace(0, 1, len(merged_df['id_run_name'].unique())))

# Ahora, procedemos a graficar
for tarea, task_df in merged_df.groupby('tarea'):
    plt.figure(figsize=(10, 6))
    
    # Iteramos sobre los modelos (id_run_name) para esta tarea
    for i, (run_name, subdf) in enumerate(task_df.groupby('id_run_name')):
        # Graficamos la evolución de la recompensa a lo largo de las iteraciones
        plt.plot(subdf['iteration'], subdf['reward'], label=run_name, color=colors[i])
    
    plt.xlabel('Iteración')
    plt.ylabel('Reward')
    plt.title(f'Evolución de la Recompensa - Tarea: {tarea}')
    plt.legend(title="Modelos", bbox_to_anchor=(1.05, 1), loc='upper left')
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ``Cojo los 5 modelos mejores de todos de los callbacks``

# %%
import os
df_callbacks = pd.read_csv(path_resultados+"/reward_best_models.csv",index_col='id_run_name')
top5_models = df_callbacks.nlargest(5,columns="reward")

powershell_script_test = os.path.join(cfg_dir, "run_tests.ps1")

with open(powershell_script_test, "w") as f:
    f.write("$ErrorActionPreference = 'Stop'\n\n")
    
    for run_id, row in top5_models.iterrows():
        # Extraemos el número del id (ej: de 'ppo_random_hover_4' sacamos '4')
        experiment_number = run_id.split('_')[-1]
        
        # Construimos la ruta exacta del checkpoint
        # Nota: Asegúrate de que path_resultados termine en / o usar os.path.join
        checkpoint_path = f"{path_resultados}/best_model_{run_id}_{int(row['num_envs_train'])}.pt"
        f.write(f'Write-Host "Ejecutando Test final para Experimento {experiment_number}..."\n')
        
        # Usamos el experiment_number extraído para la tarea (--task)
        # Se añaden flags típicos de play.py: --num_envs 1 y se quita --headless para ver el visualizador
        f.write(f'& "{isaaclab_bat}" -p "{play_script}" '
                f'--task {id_task}-{experiment_number} '
                f'--num_envs 1 '
                f' --headless '
                f'--checkpoint "{checkpoint_path}"\n\n')
        
print(f"Script de test generado en: {powershell_script_test}")
# Out:
# Script de test generado en: C:/Users/Teresa/Documents/GitHub/navsim/isaac_lab/aerotaxi/env_command/env_9/grid_hiperparametros/cfg_files\run_tests.ps1

# %% [markdown]
# ### Test con 1 entorno

# %%
# Ejecuta el entrenamiento de forma automática
# !powershell -ExecutionPolicy Bypass -File "{powershell_script}"
import subprocess
import sys

# Ruta al script que generaste
powershell_script_path = powershell_script_test 

print(f"Iniciando ejecución de: {powershell_script_path}\n")

# Ejecutamos el proceso capturando la salida en tiempo real
process = subprocess.Popen(
    ["powershell.exe", "-ExecutionPolicy", "Bypass", "-File", powershell_script_path],
    stdout=subprocess.PIPE,
    stderr=subprocess.STDOUT, # Redirigimos errores a la salida estándar para verlos
    text=True,
    bufsize=1
)

# Leemos la salida línea a línea conforme se genera
try:
    for line in process.stdout:
        print(line, end="") # Imprime la salida de PowerShell en la celda
        sys.stdout.flush()   # Fuerza a Jupyter a mostrar la línea inmediatamente
except KeyboardInterrupt:
    process.kill()
    print("\nEntrenamiento cancelado por el usuario.")

process.wait()
print("\n--- Todos los experimentos de test han finalizado ---")
# Out:
# Iniciando ejecución de: C:/Users/Teresa/Documents/GitHub/navsim/isaac_lab/aerotaxi/env_command/env_9/grid_hiperparametros/cfg_files\run_tests.ps1
#
# Ejecutando Test final para Experimento 11...
# [INFO] Using python from: C:\Users\Teresa\miniconda3\envs\env_isaaclab\python.exe
# [INFO][AppLauncher]: Using device: cuda:0
# [INFO][AppLauncher]: Loading experience file: C:\Users\Teresa\miniconda3\envs\env_isaaclab\Lib\site-packages\isaaclab\apps\isaaclab.python.headless.kit
# Loading user config located at: 'c:/users/teresa/miniconda3/envs/env_isaaclab/lib/site-packages/isaacsim/kit/data/Kit/Isaac-Sim/5.1/user.config.json'
# [Info] [carb] Logging to file: c:/users/teresa/miniconda3/envs/env_isaaclab/lib/site-packages/isaacsim/kit/logs/Kit/Isaac-Sim/5.1/kit_20260205_114728.log
# 2026-02-05T10:47:28Z s] [Warning] [omni.usd_config.extension] Enable omni.materialx.libs extension to use MaterialX
# 2026-02-05T10:47:29Z s] [Warning] [carb] Acquiring non optional plugin interface which is not listed as dependency: [omni::physx::IPhysxBenchmarks v1.0] (plugin: <default plugin>), by client: omni.physics.physx.plugin. Add it to CARB_PLUGIN_IMPL_DEPS() macro of a client.
# 2026-02-05T10:47:29Z s] [Warning] [omni.isaac.dynamic_control] omni.isaac.dynamic_control is deprecated as of Isaac Sim 4.5. No action is needed from end-users.
# 2026-02-05T10:47:31Z [2,717ms] [Warning] [gpu.foundation.plugin] Skipping unsupported non-NVIDIA GPU: AMD Radeon(TM) Graphics
# 2026-02-05T10:47:31Z [2,718ms] [Warning] [gpu.foundation.plugin] Skipping unsupported non-NVIDIA GPU: AMD Radeon(TM) Graphics
#
# |---------------------------------------------------------------------------------------------|
# | Driver Version: 581.29        | Graphics API: D3D12
# |=============================================================================================|
# | GPU | Name                             | Active | LDA | GPU Memory | Vendor-ID | LUID       |
# |     |                                  |        |     |            | Device-ID | UUID       |
# |     |                                  |        |     |            | Bus-ID    |            |
# |---------------------------------------------------------------------------------------------|
# | 0   | NVIDIA GeForce RTX 5080          | Yes: 0 |     | 15889   MB | 10de      | fa570100.. |
# |     |                                  |        |     |            | 2c02      | 0          |
# |     |                                  |        |     |            | 1         |            |
# |---------------------------------------------------------------------------------------------|
# | 1   | AMD Radeon(TM) Graphics          |        |     | 1995    MB | 1002      | d7690100.. |
# |     |                                  |        |     |            | 13c0      | 0          |
# |     |                                  |        |     |            | N/A       |            |
# |=============================================================================================|
# | OS: Windows 11 Pro, Version: 10.0 (24H2), Build: 26100, Kernel: 10.0.26100.7623
# | Processor: AMD Ryzen 9 9950X 16-Core Processor
# | Cores: 16 | Logical Cores: 32
# |---------------------------------------------------------------------------------------------|
# | Total Memory (MB): 128627 | Free Memory: 94896
# | Total Page/Swap (MB): 136819 | Free Page/Swap: 92165
# |---------------------------------------------------------------------------------------------|
# C:\Users\Teresa\Documents\GitHub\navsim\isaac_lab\aerotaxi\env_command\env_9\flight_plan.py:29: UserWarning: Treat the new Tool classes introduced in v1.5 as experimental for now; the API and rcParam may change in future versions.
#   plt.rcParams["toolbar"] = "toolmanager"
# [INFO]: Parsing configuration from: aerotaxi.env_command.env_9.env:UAVEnvCfg
# [INFO]: Parsing configuration from: aerotaxi.env_command.env_9.grid_hiperparametros.cfg_files.ppo_random_command5_11_cfg:Command5PPORunnerCfg
# [INFO] Loading experiment from directory: C:\Users\Teresa\Documents\GitHub\navsim\isaac_lab\aerotaxi\env_command\env_9\logs\rsl_rl\command5
# Setting seed: 42
# [INFO]: Base environment:
# 	Environment device    : cuda:0
# 	Environment seed      : 42
# 	Physics step-size     : 0.005
# 	Rendering step-size   : 0.02
# 	Environment step-size : 0.02
# [INFO]: Time taken for scene creation : 1.011839 seconds
# [INFO]: Scene manager:  <class InteractiveScene>
# 	Number of environments: 1
# 	Environment spacing   : 100.0
# 	Source prim name      : /World/envs/env_0
# 	Global prim paths     : []
# 	Replicate physics     : False
# [INFO]: Starting the simulation. This may take a few seconds. Please wait...
# [INFO]: Time taken for simulation start : 0.251751 seconds
# [INFO] Command Manager:  <CommandManager> contains 1 active terms.
# +--------------------------------------+
# |         Active Command Terms         |
# +-------+-------------+----------------+
# | Index | Name        |      Type      |
# +-------+-------------+----------------+
# |   0   | vel_command | UAVcommandTerm |
# +-------+-------------+----------------+
#
# [INFO] Event Manager:  <EventManager> contains 1 active terms.
# +-----------------------------------+
# | Active Event Terms in Mode: 'reset' |
# +----------+------------------------+
# |  Index   | Name                   |
# +----------+------------------------+
# |    0     | reset_pos              |
# |    1     | randomize_mass         |
# |    2     | randomize_wind         |
# +----------+------------------------+
#
# [INFO] Recorder Manager:  <RecorderManager> contains 0 active terms.
# +---------------------+
# | Active Recorder Terms |
# +-----------+---------+
# |   Index   | Name    |
# +-----------+---------+
# +-----------+---------+
#
# [INFO] Action Manager:  <ActionManager> contains 1 active terms.
# +-----------------------------------+
# |   Active Action Terms (shape: 4)  |
# +--------+-------------+------------+
# | Index  | Name        |  Dimension |
# +--------+-------------+------------+
# |   0    | rotors_vel  |          4 |
# +--------+-------------+------------+
#
# [INFO] Observation Manager: <ObservationManager> contains 1 groups.
# +----------------------------------------------------+
# | Active Observation Terms in Group: 'policy' (shape: (11,)) |
# +---------------+--------------------+---------------+
# |     Index     | Name               |     Shape     |
# +---------------+--------------------+---------------+
# |       0       | pos                |      (3,)     |
# |       1       | lin_vel            |      (3,)     |
# |       2       | ang_vel            |      (3,)     |
# |       3       | roll               |      (1,)     |
# |       4       | pitch              |      (1,)     |
# +---------------+--------------------+---------------+
#
# [INFO] Termination Manager:  <TerminationManager> contains 4 active terms.
# +---------------------------------------+
# |        Active Termination Terms       |
# +-------+--------------------+----------+
# | Index | Name               | Time Out |
# +-------+--------------------+----------+
# |   0   | time_out           |   True   |
# |   1   | below_min_altitude |  False   |
# |   2   | bad_attitude       |  False   |
# |   3   | safety_shutdown    |  False   |
# +-------+--------------------+----------+
#
# [INFO] Reward Manager:  <RewardManager> contains 14 active terms.
# +-----------------------------------------------------+
# |                 Active Reward Terms                 |
# +-------+------------------------------------+--------+
# | Index | Name                               | Weight |
# +-------+------------------------------------+--------+
# |   0   | alive                              |   15.0 |
# |   1   | action_rate                        |   -0.1 |
# |   2   | terminating                        |  -50.0 |
# |   3   | rew_pos_diff                       |   -0.5 |
# |   4   | rew_pos_diff_fine_grained          |   15.0 |
# |   5   | rew_lin_vel_diff                   |   -0.1 |
# |   6   | rew_lin_vel_diff_fine_grained      |    2.0 |
# |   7   | rew_ang_vel_z_diff                 |   -1.0 |
# |   8   | rew_ang_vel_z_diff_fine_grained    |    1.0 |
# |   9   | rew_roll_diff                      |   -0.5 |
# |   10  | rew_roll_diff_fine_grained         |    1.0 |
# |   11  | rew_pitch_diff                     |   -0.5 |
# |   12  | rew_pitch_diff_fine_grained        |    1.0 |
# |   13  | rew_heading_alignment_fine_grained |    5.0 |
# +-------+------------------------------------+--------+
#
# [INFO] Curriculum Manager:  <CurriculumManager> contains 0 active terms.
# +----------------------+
# | Active Curriculum Terms |
# +-----------+----------+
# |   Index   | Name     |
# +-----------+----------+
# +-----------+----------+
#
# [INFO]: Completed setting up the environment...
# 2026-02-05T10:47:33Z [5,684ms] [Warning] [omni.physx.fabric.plugin] FabricManager::initializePointInstancer mismatched prototypes on point instancer: /Visuals/target_commands.
# [INFO]: Loading model checkpoint from: C:\Users\Teresa\Documents\GitHub\navsim\tmp\tmpTeresa\resultados_grid_command_v5\best_model_ppo_random_command5_11_8196.pt
# C:\Users\Teresa\miniconda3\envs\env_isaaclab\Lib\site-packages\rsl_rl\utils\utils.py:244: UserWarning: The observation configuration dictionary 'obs_groups' must contain the 'policy' key. As an observation group with the name 'policy' was found, this is assumed to be the observation set. Consider adding the 'policy' key to the 'obs_groups' dictionary for clarity. This behavior will be removed in a future version.
#   warnings.warn(
# C:\Users\Teresa\miniconda3\envs\env_isaaclab\Lib\site-packages\rsl_rl\utils\utils.py:290: UserWarning: The observation configuration dictionary 'obs_groups' must contain the 'critic' key. As the configuration for 'critic' is missing, the observations from the 'policy' set are used. Consider adding the 'critic' key to the 'obs_groups' dictionary for clarity. This behavior will be removed in a future version.
#   warnings.warn(
# --------------------------------------------------------------------------------
# Resolved observation sets:
# 	 policy :  ['policy']
# 	 critic :  ['policy']
# --------------------------------------------------------------------------------
# Actor MLP: MLP(
#   (0): Linear(in_features=11, out_features=64, bias=True)
#   (1): ELU(alpha=1.0)
#   (2): Linear(in_features=64, out_features=64, bias=True)
#   (3): ELU(alpha=1.0)
#   (4): Linear(in_features=64, out_features=4, bias=True)
# )
# Critic MLP: MLP(
#   (0): Linear(in_features=11, out_features=128, bias=True)
#   (1): ELU(alpha=1.0)
#   (2): Linear(in_features=128, out_features=128, bias=True)
#   (3): ELU(alpha=1.0)
#   (4): Linear(in_features=128, out_features=1, bias=True)
# )
#
# --- Todos los experimentos de test han finalizado ---

# %%
df_callbacks = pd.read_csv(path_resultados+"/reward_best_models.csv",index_col='id_run_name')
top5_models = df_callbacks.nlargest(5,columns="reward")

# %%
df_rewards_play = pd.read_csv(path_resultados+'/rewards_play_PPO.csv')

# %% [markdown]
# ### Test con 64 entornos

# %%
import os
df_callbacks = pd.read_csv(path_resultados+"/reward_best_models.csv",index_col='id_run_name')
top5_models = df_callbacks.nlargest(5,columns="reward")

powershell_script_test_2 = os.path.join(cfg_dir, "run_tests_2.ps1")

with open(powershell_script_test_2, "w") as f:
    f.write("$ErrorActionPreference = 'Stop'\n\n")
    
    for run_id, row in top5_models.iterrows():
        # Extraemos el número del id (ej: de 'ppo_random_hover_4' sacamos '4')
        experiment_number = run_id.split('_')[-1]
        
        # Construimos la ruta exacta del checkpoint
        # Nota: Asegúrate de que path_resultados termine en / o usar os.path.join
        checkpoint_path = f"{path_resultados}/best_model_{run_id}_{int(row['num_envs_train'])}.pt"
        f.write(f'Write-Host "Ejecutando Test final para Experimento {experiment_number}..."\n')
        
        # Usamos el experiment_number extraído para la tarea (--task)
        # Se añaden flags típicos de play.py: --num_envs 1 y se quita --headless para ver el visualizador
        f.write(f'& "{isaaclab_bat}" -p "{play_script}" '
                f'--task {id_task}-{experiment_number} '
                f'--num_envs 64 '
                f' --headless '
                f'--checkpoint "{checkpoint_path}"\n\n')
        
print(f"Script de test generado en: {powershell_script_test_2}")
# Out:
# Script de test generado en: C:/Users/Teresa/Documents/GitHub/navsim/isaac_lab/aerotaxi/env_command/env_9/grid_hiperparametros/cfg_files\run_tests_2.ps1

# %%
# Ejecuta el entrenamiento de forma automática
# !powershell -ExecutionPolicy Bypass -File "{powershell_script}"
import subprocess
import sys

# Ruta al script que generaste
powershell_script_path = powershell_script_test_2 

print(f"Iniciando ejecución de: {powershell_script_path}\n")

# Ejecutamos el proceso capturando la salida en tiempo real
process = subprocess.Popen(
    ["powershell.exe", "-ExecutionPolicy", "Bypass", "-File", powershell_script_path],
    stdout=subprocess.PIPE,
    stderr=subprocess.STDOUT, # Redirigimos errores a la salida estándar para verlos
    text=True,
    bufsize=1
)

# Leemos la salida línea a línea conforme se genera
try:
    for line in process.stdout:
        print(line, end="") # Imprime la salida de PowerShell en la celda
        sys.stdout.flush()   # Fuerza a Jupyter a mostrar la línea inmediatamente
except KeyboardInterrupt:
    process.kill()
    print("\nEntrenamiento cancelado por el usuario.")

process.wait()
print("\n--- Todos los experimentos de test han finalizado ---")
# Out:
# Iniciando ejecución de: C:/Users/Teresa/Documents/GitHub/navsim/isaac_lab/aerotaxi/env_command/env_9/grid_hiperparametros/cfg_files\run_tests_2.ps1
#
# Ejecutando Test final para Experimento 11...
# [INFO] Using python from: C:\Users\Teresa\miniconda3\envs\env_isaaclab\python.exe
# [INFO][AppLauncher]: Using device: cuda:0
# [INFO][AppLauncher]: Loading experience file: C:\Users\Teresa\miniconda3\envs\env_isaaclab\Lib\site-packages\isaaclab\apps\isaaclab.python.headless.kit
# Loading user config located at: 'c:/users/teresa/miniconda3/envs/env_isaaclab/lib/site-packages/isaacsim/kit/data/Kit/Isaac-Sim/5.1/user.config.json'
# [Info] [carb] Logging to file: c:/users/teresa/miniconda3/envs/env_isaaclab/lib/site-packages/isaacsim/kit/logs/Kit/Isaac-Sim/5.1/kit_20260205_115133.log
# 2026-02-05T10:51:34Z s] [Warning] [omni.usd_config.extension] Enable omni.materialx.libs extension to use MaterialX
# 2026-02-05T10:51:34Z s] [Warning] [carb] Acquiring non optional plugin interface which is not listed as dependency: [omni::physx::IPhysxBenchmarks v1.0] (plugin: <default plugin>), by client: omni.physics.physx.plugin. Add it to CARB_PLUGIN_IMPL_DEPS() macro of a client.
# 2026-02-05T10:51:34Z s] [Warning] [omni.isaac.dynamic_control] omni.isaac.dynamic_control is deprecated as of Isaac Sim 4.5. No action is needed from end-users.
# 2026-02-05T10:51:36Z [2,374ms] [Warning] [gpu.foundation.plugin] Skipping unsupported non-NVIDIA GPU: AMD Radeon(TM) Graphics
# 2026-02-05T10:51:36Z [2,375ms] [Warning] [gpu.foundation.plugin] Skipping unsupported non-NVIDIA GPU: AMD Radeon(TM) Graphics
#
# |---------------------------------------------------------------------------------------------|
# | Driver Version: 581.29        | Graphics API: D3D12
# |=============================================================================================|
# | GPU | Name                             | Active | LDA | GPU Memory | Vendor-ID | LUID       |
# |     |                                  |        |     |            | Device-ID | UUID       |
# |     |                                  |        |     |            | Bus-ID    |            |
# |---------------------------------------------------------------------------------------------|
# | 0   | NVIDIA GeForce RTX 5080          | Yes: 0 |     | 15889   MB | 10de      | fa570100.. |
# |     |                                  |        |     |            | 2c02      | 0          |
# |     |                                  |        |     |            | 1         |            |
# |---------------------------------------------------------------------------------------------|
# | 1   | AMD Radeon(TM) Graphics          |        |     | 1995    MB | 1002      | d7690100.. |
# |     |                                  |        |     |            | 13c0      | 0          |
# |     |                                  |        |     |            | N/A       |            |
# |=============================================================================================|
# | OS: Windows 11 Pro, Version: 10.0 (24H2), Build: 26100, Kernel: 10.0.26100.7623
# | Processor: AMD Ryzen 9 9950X 16-Core Processor
# | Cores: 16 | Logical Cores: 32
# |---------------------------------------------------------------------------------------------|
# | Total Memory (MB): 128627 | Free Memory: 94331
# | Total Page/Swap (MB): 136819 | Free Page/Swap: 91707
# |---------------------------------------------------------------------------------------------|
# C:\Users\Teresa\Documents\GitHub\navsim\isaac_lab\aerotaxi\env_command\env_9\flight_plan.py:29: UserWarning: Treat the new Tool classes introduced in v1.5 as experimental for now; the API and rcParam may change in future versions.
#   plt.rcParams["toolbar"] = "toolmanager"
# [INFO]: Parsing configuration from: aerotaxi.env_command.env_9.env:UAVEnvCfg
# [INFO]: Parsing configuration from: aerotaxi.env_command.env_9.grid_hiperparametros.cfg_files.ppo_random_command5_11_cfg:Command5PPORunnerCfg
# [INFO] Loading experiment from directory: C:\Users\Teresa\Documents\GitHub\navsim\isaac_lab\aerotaxi\env_command\env_9\logs\rsl_rl\command5
# Setting seed: 42
# [INFO]: Base environment:
# 	Environment device    : cuda:0
# 	Environment seed      : 42
# 	Physics step-size     : 0.005
# 	Rendering step-size   : 0.02
# 	Environment step-size : 0.02
# [INFO]: Time taken for scene creation : 1.099795 seconds
# [INFO]: Scene manager:  <class InteractiveScene>
# 	Number of environments: 64
# 	Environment spacing   : 100.0
# 	Source prim name      : /World/envs/env_0
# 	Global prim paths     : []
# 	Replicate physics     : False
# [INFO]: Starting the simulation. This may take a few seconds. Please wait...
# [INFO]: Time taken for simulation start : 0.282446 seconds
# [INFO] Command Manager:  <CommandManager> contains 1 active terms.
# +--------------------------------------+
# |         Active Command Terms         |
# +-------+-------------+----------------+
# | Index | Name        |      Type      |
# +-------+-------------+----------------+
# |   0   | vel_command | UAVcommandTerm |
# +-------+-------------+----------------+
#
# [INFO] Event Manager:  <EventManager> contains 1 active terms.
# +-----------------------------------+
# | Active Event Terms in Mode: 'reset' |
# +----------+------------------------+
# |  Index   | Name                   |
# +----------+------------------------+
# |    0     | reset_pos              |
# |    1     | randomize_mass         |
# |    2     | randomize_wind         |
# +----------+------------------------+
#
# [INFO] Recorder Manager:  <RecorderManager> contains 0 active terms.
# +---------------------+
# | Active Recorder Terms |
# +-----------+---------+
# |   Index   | Name    |
# +-----------+---------+
# +-----------+---------+
#
# [INFO] Action Manager:  <ActionManager> contains 1 active terms.
# +-----------------------------------+
# |   Active Action Terms (shape: 4)  |
# +--------+-------------+------------+
# | Index  | Name        |  Dimension |
# +--------+-------------+------------+
# |   0    | rotors_vel  |          4 |
# +--------+-------------+------------+
#
# [INFO] Observation Manager: <ObservationManager> contains 1 groups.
# +----------------------------------------------------+
# | Active Observation Terms in Group: 'policy' (shape: (11,)) |
# +---------------+--------------------+---------------+
# |     Index     | Name               |     Shape     |
# +---------------+--------------------+---------------+
# |       0       | pos                |      (3,)     |
# |       1       | lin_vel            |      (3,)     |
# |       2       | ang_vel            |      (3,)     |
# |       3       | roll               |      (1,)     |
# |       4       | pitch              |      (1,)     |
# +---------------+--------------------+---------------+
#
# [INFO] Termination Manager:  <TerminationManager> contains 4 active terms.
# +---------------------------------------+
# |        Active Termination Terms       |
# +-------+--------------------+----------+
# | Index | Name               | Time Out |
# +-------+--------------------+----------+
# |   0   | time_out           |   True   |
# |   1   | below_min_altitude |  False   |
# |   2   | bad_attitude       |  False   |
# |   3   | safety_shutdown    |  False   |
# +-------+--------------------+----------+
#
# [INFO] Reward Manager:  <RewardManager> contains 14 active terms.
# +-----------------------------------------------------+
# |                 Active Reward Terms                 |
# +-------+------------------------------------+--------+
# | Index | Name                               | Weight |
# +-------+------------------------------------+--------+
# |   0   | alive                              |   15.0 |
# |   1   | action_rate                        |   -0.1 |
# |   2   | terminating                        |  -50.0 |
# |   3   | rew_pos_diff                       |   -0.5 |
# |   4   | rew_pos_diff_fine_grained          |   15.0 |
# |   5   | rew_lin_vel_diff                   |   -0.1 |
# |   6   | rew_lin_vel_diff_fine_grained      |    2.0 |
# |   7   | rew_ang_vel_z_diff                 |   -1.0 |
# |   8   | rew_ang_vel_z_diff_fine_grained    |    1.0 |
# |   9   | rew_roll_diff                      |   -0.5 |
# |   10  | rew_roll_diff_fine_grained         |    1.0 |
# |   11  | rew_pitch_diff                     |   -0.5 |
# |   12  | rew_pitch_diff_fine_grained        |    1.0 |
# |   13  | rew_heading_alignment_fine_grained |    5.0 |
# +-------+------------------------------------+--------+
#
# [INFO] Curriculum Manager:  <CurriculumManager> contains 0 active terms.
# +----------------------+
# | Active Curriculum Terms |
# +-----------+----------+
# |   Index   | Name     |
# +-----------+----------+
# +-----------+----------+
#
# [INFO]: Completed setting up the environment...
# 2026-02-05T10:51:39Z [5,393ms] [Warning] [omni.physx.fabric.plugin] FabricManager::initializePointInstancer mismatched prototypes on point instancer: /Visuals/target_commands.
# [INFO]: Loading model checkpoint from: C:\Users\Teresa\Documents\GitHub\navsim\tmp\tmpTeresa\resultados_grid_command_v5\best_model_ppo_random_command5_11_8196.pt
# C:\Users\Teresa\miniconda3\envs\env_isaaclab\Lib\site-packages\rsl_rl\utils\utils.py:244: UserWarning: The observation configuration dictionary 'obs_groups' must contain the 'policy' key. As an observation group with the name 'policy' was found, this is assumed to be the observation set. Consider adding the 'policy' key to the 'obs_groups' dictionary for clarity. This behavior will be removed in a future version.
#   warnings.warn(
# C:\Users\Teresa\miniconda3\envs\env_isaaclab\Lib\site-packages\rsl_rl\utils\utils.py:290: UserWarning: The observation configuration dictionary 'obs_groups' must contain the 'critic' key. As the configuration for 'critic' is missing, the observations from the 'policy' set are used. Consider adding the 'critic' key to the 'obs_groups' dictionary for clarity. This behavior will be removed in a future version.
#   warnings.warn(
# --------------------------------------------------------------------------------
# Resolved observation sets:
# 	 policy :  ['policy']
# 	 critic :  ['policy']
# --------------------------------------------------------------------------------
# Actor MLP: MLP(
#   (0): Linear(in_features=11, out_features=64, bias=True)
#   (1): ELU(alpha=1.0)
#   (2): Linear(in_features=64, out_features=64, bias=True)
#   (3): ELU(alpha=1.0)
#   (4): Linear(in_features=64, out_features=4, bias=True)
# )
# Critic MLP: MLP(
#   (0): Linear(in_features=11, out_features=128, bias=True)
#   (1): ELU(alpha=1.0)
#   (2): Linear(in_features=128, out_features=128, bias=True)
#   (3): ELU(alpha=1.0)
#   (4): Linear(in_features=128, out_features=1, bias=True)
# )
#
# --- Todos los experimentos de test han finalizado ---

# %% [markdown]
# #### Test con 256 entornos

# %%
import os
df_callbacks = pd.read_csv(path_resultados+"/reward_best_models.csv",index_col='id_run_name')
top5_models = df_callbacks.nlargest(5,columns="reward")

powershell_script_test_3 = os.path.join(cfg_dir, "run_tests_3.ps1")

with open(powershell_script_test_3, "w") as f:
    f.write("$ErrorActionPreference = 'Stop'\n\n")
    
    for run_id, row in top5_models.iterrows():
        # Extraemos el número del id (ej: de 'ppo_random_hover_4' sacamos '4')
        experiment_number = run_id.split('_')[-1]
        
        # Construimos la ruta exacta del checkpoint
        # Nota: Asegúrate de que path_resultados termine en / o usar os.path.join
        checkpoint_path = f"{path_resultados}/best_model_{run_id}_{int(row['num_envs_train'])}.pt"
        f.write(f'Write-Host "Ejecutando Test final para Experimento {experiment_number}..."\n')
        
        # Usamos el experiment_number extraído para la tarea (--task)
        # Se añaden flags típicos de play.py: --num_envs 1 y se quita --headless para ver el visualizador
        f.write(f'& "{isaaclab_bat}" -p "{play_script}" '
                f'--task {id_task}-{experiment_number} '
                f'--num_envs 256 '
                f' --headless '
                f'--checkpoint "{checkpoint_path}"\n\n')
        
print(f"Script de test generado en: {powershell_script_test_3}")
# Out:
# Script de test generado en: C:/Users/Teresa/Documents/GitHub/navsim/isaac_lab/aerotaxi/env_command/env_9/grid_hiperparametros/cfg_files\run_tests_3.ps1

# %%
# Ejecuta el entrenamiento de forma automática
# !powershell -ExecutionPolicy Bypass -File "{powershell_script}"
import subprocess
import sys

# Ruta al script que generaste
powershell_script_path = powershell_script_test_3 

print(f"Iniciando ejecución de: {powershell_script_path}\n")

# Ejecutamos el proceso capturando la salida en tiempo real
process = subprocess.Popen(
    ["powershell.exe", "-ExecutionPolicy", "Bypass", "-File", powershell_script_path],
    stdout=subprocess.PIPE,
    stderr=subprocess.STDOUT, # Redirigimos errores a la salida estándar para verlos
    text=True,
    bufsize=1
)

# Leemos la salida línea a línea conforme se genera
try:
    for line in process.stdout:
        print(line, end="") # Imprime la salida de PowerShell en la celda
        sys.stdout.flush()   # Fuerza a Jupyter a mostrar la línea inmediatamente
except KeyboardInterrupt:
    process.kill()
    print("\nEntrenamiento cancelado por el usuario.")

process.wait()
print("\n--- Todos los experimentos de test han finalizado ---")
# Out:
# Iniciando ejecución de: C:/Users/Teresa/Documents/GitHub/navsim/isaac_lab/aerotaxi/env_command/env_9/grid_hiperparametros/cfg_files\run_tests_3.ps1
#
# Ejecutando Test final para Experimento 11...
# [INFO] Using python from: C:\Users\Teresa\miniconda3\envs\env_isaaclab\python.exe
# [INFO][AppLauncher]: Using device: cuda:0
# [INFO][AppLauncher]: Loading experience file: C:\Users\Teresa\miniconda3\envs\env_isaaclab\Lib\site-packages\isaaclab\apps\isaaclab.python.headless.kit
# Loading user config located at: 'c:/users/teresa/miniconda3/envs/env_isaaclab/lib/site-packages/isaacsim/kit/data/Kit/Isaac-Sim/5.1/user.config.json'
# [Info] [carb] Logging to file: c:/users/teresa/miniconda3/envs/env_isaaclab/lib/site-packages/isaacsim/kit/logs/Kit/Isaac-Sim/5.1/kit_20260205_115402.log
# 2026-02-05T10:54:03Z s] [Warning] [omni.usd_config.extension] Enable omni.materialx.libs extension to use MaterialX
# 2026-02-05T10:54:03Z s] [Warning] [carb] Acquiring non optional plugin interface which is not listed as dependency: [omni::physx::IPhysxBenchmarks v1.0] (plugin: <default plugin>), by client: omni.physics.physx.plugin. Add it to CARB_PLUGIN_IMPL_DEPS() macro of a client.
# 2026-02-05T10:54:03Z s] [Warning] [omni.isaac.dynamic_control] omni.isaac.dynamic_control is deprecated as of Isaac Sim 4.5. No action is needed from end-users.
# 2026-02-05T10:54:05Z [2,384ms] [Warning] [gpu.foundation.plugin] Skipping unsupported non-NVIDIA GPU: AMD Radeon(TM) Graphics
# 2026-02-05T10:54:05Z [2,385ms] [Warning] [gpu.foundation.plugin] Skipping unsupported non-NVIDIA GPU: AMD Radeon(TM) Graphics
#
# |---------------------------------------------------------------------------------------------|
# | Driver Version: 581.29        | Graphics API: D3D12
# |=============================================================================================|
# | GPU | Name                             | Active | LDA | GPU Memory | Vendor-ID | LUID       |
# |     |                                  |        |     |            | Device-ID | UUID       |
# |     |                                  |        |     |            | Bus-ID    |            |
# |---------------------------------------------------------------------------------------------|
# | 0   | NVIDIA GeForce RTX 5080          | Yes: 0 |     | 15889   MB | 10de      | fa570100.. |
# |     |                                  |        |     |            | 2c02      | 0          |
# |     |                                  |        |     |            | 1         |            |
# |---------------------------------------------------------------------------------------------|
# | 1   | AMD Radeon(TM) Graphics          |        |     | 1995    MB | 1002      | d7690100.. |
# |     |                                  |        |     |            | 13c0      | 0          |
# |     |                                  |        |     |            | N/A       |            |
# |=============================================================================================|
# | OS: Windows 11 Pro, Version: 10.0 (24H2), Build: 26100, Kernel: 10.0.26100.7623
# | Processor: AMD Ryzen 9 9950X 16-Core Processor
# | Cores: 16 | Logical Cores: 32
# |---------------------------------------------------------------------------------------------|
# | Total Memory (MB): 128627 | Free Memory: 94040
# | Total Page/Swap (MB): 136819 | Free Page/Swap: 91401
# |---------------------------------------------------------------------------------------------|
# C:\Users\Teresa\Documents\GitHub\navsim\isaac_lab\aerotaxi\env_command\env_9\flight_plan.py:29: UserWarning: Treat the new Tool classes introduced in v1.5 as experimental for now; the API and rcParam may change in future versions.
#   plt.rcParams["toolbar"] = "toolmanager"
# [INFO]: Parsing configuration from: aerotaxi.env_command.env_9.env:UAVEnvCfg
# [INFO]: Parsing configuration from: aerotaxi.env_command.env_9.grid_hiperparametros.cfg_files.ppo_random_command5_11_cfg:Command5PPORunnerCfg
# [INFO] Loading experiment from directory: C:\Users\Teresa\Documents\GitHub\navsim\isaac_lab\aerotaxi\env_command\env_9\logs\rsl_rl\command5
# Setting seed: 42
# [INFO]: Base environment:
# 	Environment device    : cuda:0
# 	Environment seed      : 42
# 	Physics step-size     : 0.005
# 	Rendering step-size   : 0.02
# 	Environment step-size : 0.02
# [INFO]: Time taken for scene creation : 1.113053 seconds
# [INFO]: Scene manager:  <class InteractiveScene>
# 	Number of environments: 256
# 	Environment spacing   : 100.0
# 	Source prim name      : /World/envs/env_0
# 	Global prim paths     : []
# 	Replicate physics     : False
# [INFO]: Starting the simulation. This may take a few seconds. Please wait...
# [INFO]: Time taken for simulation start : 0.381035 seconds
# [INFO] Command Manager:  <CommandManager> contains 1 active terms.
# +--------------------------------------+
# |         Active Command Terms         |
# +-------+-------------+----------------+
# | Index | Name        |      Type      |
# +-------+-------------+----------------+
# |   0   | vel_command | UAVcommandTerm |
# +-------+-------------+----------------+
#
# [INFO] Event Manager:  <EventManager> contains 1 active terms.
# +-----------------------------------+
# | Active Event Terms in Mode: 'reset' |
# +----------+------------------------+
# |  Index   | Name                   |
# +----------+------------------------+
# |    0     | reset_pos              |
# |    1     | randomize_mass         |
# |    2     | randomize_wind         |
# +----------+------------------------+
#
# [INFO] Recorder Manager:  <RecorderManager> contains 0 active terms.
# +---------------------+
# | Active Recorder Terms |
# +-----------+---------+
# |   Index   | Name    |
# +-----------+---------+
# +-----------+---------+
#
# [INFO] Action Manager:  <ActionManager> contains 1 active terms.
# +-----------------------------------+
# |   Active Action Terms (shape: 4)  |
# +--------+-------------+------------+
# | Index  | Name        |  Dimension |
# +--------+-------------+------------+
# |   0    | rotors_vel  |          4 |
# +--------+-------------+------------+
#
# [INFO] Observation Manager: <ObservationManager> contains 1 groups.
# +----------------------------------------------------+
# | Active Observation Terms in Group: 'policy' (shape: (11,)) |
# +---------------+--------------------+---------------+
# |     Index     | Name               |     Shape     |
# +---------------+--------------------+---------------+
# |       0       | pos                |      (3,)     |
# |       1       | lin_vel            |      (3,)     |
# |       2       | ang_vel            |      (3,)     |
# |       3       | roll               |      (1,)     |
# |       4       | pitch              |      (1,)     |
# +---------------+--------------------+---------------+
#
# [INFO] Termination Manager:  <TerminationManager> contains 4 active terms.
# +---------------------------------------+
# |        Active Termination Terms       |
# +-------+--------------------+----------+
# | Index | Name               | Time Out |
# +-------+--------------------+----------+
# |   0   | time_out           |   True   |
# |   1   | below_min_altitude |  False   |
# |   2   | bad_attitude       |  False   |
# |   3   | safety_shutdown    |  False   |
# +-------+--------------------+----------+
#
# [INFO] Reward Manager:  <RewardManager> contains 14 active terms.
# +-----------------------------------------------------+
# |                 Active Reward Terms                 |
# +-------+------------------------------------+--------+
# | Index | Name                               | Weight |
# +-------+------------------------------------+--------+
# |   0   | alive                              |   15.0 |
# |   1   | action_rate                        |   -0.1 |
# |   2   | terminating                        |  -50.0 |
# |   3   | rew_pos_diff                       |   -0.5 |
# |   4   | rew_pos_diff_fine_grained          |   15.0 |
# |   5   | rew_lin_vel_diff                   |   -0.1 |
# |   6   | rew_lin_vel_diff_fine_grained      |    2.0 |
# |   7   | rew_ang_vel_z_diff                 |   -1.0 |
# |   8   | rew_ang_vel_z_diff_fine_grained    |    1.0 |
# |   9   | rew_roll_diff                      |   -0.5 |
# |   10  | rew_roll_diff_fine_grained         |    1.0 |
# |   11  | rew_pitch_diff                     |   -0.5 |
# |   12  | rew_pitch_diff_fine_grained        |    1.0 |
# |   13  | rew_heading_alignment_fine_grained |    5.0 |
# +-------+------------------------------------+--------+
#
# [INFO] Curriculum Manager:  <CurriculumManager> contains 0 active terms.
# +----------------------+
# | Active Curriculum Terms |
# +-----------+----------+
# |   Index   | Name     |
# +-----------+----------+
# +-----------+----------+
#
# [INFO]: Completed setting up the environment...
# 2026-02-05T10:54:08Z [5,536ms] [Warning] [omni.physx.fabric.plugin] FabricManager::initializePointInstancer mismatched prototypes on point instancer: /Visuals/target_commands.
# [INFO]: Loading model checkpoint from: C:\Users\Teresa\Documents\GitHub\navsim\tmp\tmpTeresa\resultados_grid_command_v5\best_model_ppo_random_command5_11_8196.pt
# C:\Users\Teresa\miniconda3\envs\env_isaaclab\Lib\site-packages\rsl_rl\utils\utils.py:244: UserWarning: The observation configuration dictionary 'obs_groups' must contain the 'policy' key. As an observation group with the name 'policy' was found, this is assumed to be the observation set. Consider adding the 'policy' key to the 'obs_groups' dictionary for clarity. This behavior will be removed in a future version.
#   warnings.warn(
# C:\Users\Teresa\miniconda3\envs\env_isaaclab\Lib\site-packages\rsl_rl\utils\utils.py:290: UserWarning: The observation configuration dictionary 'obs_groups' must contain the 'critic' key. As the configuration for 'critic' is missing, the observations from the 'policy' set are used. Consider adding the 'critic' key to the 'obs_groups' dictionary for clarity. This behavior will be removed in a future version.
#   warnings.warn(
# --------------------------------------------------------------------------------
# Resolved observation sets:
# 	 policy :  ['policy']
# 	 critic :  ['policy']
# --------------------------------------------------------------------------------
# Actor MLP: MLP(
#   (0): Linear(in_features=11, out_features=64, bias=True)
#   (1): ELU(alpha=1.0)
#   (2): Linear(in_features=64, out_features=64, bias=True)
#   (3): ELU(alpha=1.0)
#   (4): Linear(in_features=64, out_features=4, bias=True)
# )
# Critic MLP: MLP(
#   (0): Linear(in_features=11, out_features=128, bias=True)
#   (1): ELU(alpha=1.0)
#   (2): Linear(in_features=128, out_features=128, bias=True)
#   (3): ELU(alpha=1.0)
#   (4): Linear(in_features=128, out_features=1, bias=True)
# )
#
# --- Todos los experimentos de test han finalizado ---

# %%
import pandas as pd

df_train = top5_models.copy()
if df_train.index.name == 'id_run_name':
    df_train = df_train.reset_index()

df_train = df_train.rename(columns={
    'reward': 'reward_train',
    'max_reward': 'max_reward_train',
    'std_reward': 'std_train'
})

df_test = df_rewards_play.copy()

df_test = pd.read_csv(path_resultados+'/rewards_play_PPO.csv')
df_test = df_test.rename(columns={
    'reward': 'reward_test',
    'max_reward': 'max_reward_test',
    'std': 'std_test'
})

df_final = pd.merge(
    df_train[['id_run_name', 'num_envs_train', 'reward_train', 'max_reward_train', 'std_train', 'iteration']], 
    df_test[['id_run_name', 'num_envs_test', 'reward_test', 'max_reward_test', 'std_test', 'checkpoint']], 
    on='id_run_name', 
    how='inner'
)

column_order = [
    'id_run_name',
    'num_envs_train',
    'num_envs_test',
    'reward_train', 'reward_test', 
    'max_reward_train', 'max_reward_test', 
    'std_train', 'std_test',
    'iteration'
]
df_final = df_final[column_order]

df_final = df_final.sort_values(by='id_run_name', ascending=False)

# %%
df_rewards_play = df_final.sort_values(by="id_run_name",ascending=False)
df_rewards_play = df_rewards_play.reset_index().drop(columns='index')

df_final = df_rewards_play.copy()

df_final['diff_rw_test_train'] = df_final['reward_test'] - df_final['reward_train']

df_final['diferencia(%)'] = (df_final['diff_rw_test_train'] / df_final['reward_train'].abs()) * 100

df_final['diferencia(%)'] = df_final['diferencia(%)'].apply(lambda x: f"{x:+.2f}%")

df_final
# Out:
#               id_run_name  num_envs_train  num_envs_test  reward_train  \
# 0  ppo_random_command5_11            8196              1    154.030015
# 1  ppo_random_command5_11            8196             64    154.030015
# 2  ppo_random_command5_11            8196             64    154.030015
# 3  ppo_random_command5_11            8196            256    154.030015
#
#    reward_test  max_reward_train  max_reward_test  std_train    std_test  \
# 0   223.073972        616.214417       373.655934  170.69982  150.581962
# 1   112.457990        616.214417       388.230930  170.69982  120.609010
# 2   112.457990        616.214417       388.230930  170.69982  120.609010
# 3   122.212913        616.214417       423.071395  170.69982  113.751531
#
#    iteration  diff_rw_test_train diferencia(%)
# 0       1289           69.043957       +44.83%
# 1       1289          -41.572025       -26.99%
# 2       1289          -41.572025       -26.99%
# 3       1289          -31.817102       -20.66%

# %% [markdown]
# Pruebas con un solo entorno: Vemos cómo se comporta la política para un único agente en una prueba aleatoria.

# %%
df_final[df_final['num_envs_test'] == 1].sort_values(by='reward_test',ascending=False)
# Out:
#               id_run_name  num_envs_train  num_envs_test  reward_train  \
# 0  ppo_random_command5_11            8196              1    154.030015
#
#    reward_test  max_reward_train  max_reward_test  std_train    std_test  \
# 0   223.073972        616.214417       373.655934  170.69982  150.581962
#
#    iteration  diff_rw_test_train diferencia(%)
# 0       1289           69.043957       +44.83%

# %% [markdown]
# ``Interpretación``: Vemos que el modelo 38 se ha estampado en la prueba aleatoria, así que ese modelo no debería usarse para ninguna transferencia real.

# %% [markdown]
# Pruebas con varios entornos: Vemos cómo se comporta la política en múltiples entornos (varias pruebas simuladas en paralelo), teniendo en cuenta cuál es la desviación de cada uno en test, lo que nos permite inferir si la recompensa es estable para todas las pruebas.

# %%
df_final[df_final['num_envs_test'] != 1].sort_values(by='std_test',ascending=True).reset_index().drop(columns="index")
# Out:
#               id_run_name  num_envs_train  num_envs_test  reward_train  \
# 0  ppo_random_command5_11            8196            256    154.030015
# 1  ppo_random_command5_11            8196             64    154.030015
# 2  ppo_random_command5_11            8196             64    154.030015
#
#    reward_test  max_reward_train  max_reward_test  std_train    std_test  \
# 0   122.212913        616.214417       423.071395  170.69982  113.751531
# 1   112.457990        616.214417       388.230930  170.69982  120.609010
# 2   112.457990        616.214417       388.230930  170.69982  120.609010
#
#    iteration  diff_rw_test_train diferencia(%)
# 0       1289          -31.817102       -20.66%
# 1       1289          -41.572025       -26.99%
# 2       1289          -41.572025       -26.99%

# %% [markdown]
# pruebas:

# %% [markdown]
# C:/Users/Teresa/Desktop/RuralData/IsaacLab/IsaacLab/isaaclab.bat -p C:/Users/Teresa/Documents/GitHub/navsim/isaac_lab/rl_v5_1_0/rsl_rl/train.py --task Isaac-Command5-Aerotaxi-RANDOM-11 --num_envs 8196 --headless
