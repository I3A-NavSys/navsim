# %%
# Parámetros a configurar:
import os
experiment_name = "command7"
task_name = "Command7"
cfg_dir = "C:/Users/Teresa/Documents/GitHub/navsim/isaac_lab/aerotaxi/env_command/env_11/grid_hiperparametros/cfg_files"
path_resultados = "C:/Users/Teresa/Documents/GitHub/navsim/tmp/tmpTeresa/resultados_grid_command_v7"
isaaclab_bat = "C:/Users/Teresa/Desktop/RuralData/IsaacLab/IsaacLab/isaaclab.bat"
train_script = "C:/Users/Teresa/Documents/GitHub/navsim/isaac_lab/rl_v5_1_0/rsl_rl/train.py"
id_task = f"Isaac-{task_name}-Aerotaxi-RANDOM" # luego se le añade el número de task con el guión (Isaac-Command2-Aerotaxi-RANDOM-34)
play_script = "C:/Users/Teresa/Documents/GitHub/navsim/isaac_lab/rl_v5_1_0/rsl_rl/play.py"
num_iter = "4001"
num_steps_per_env = 100
powershell_script = os.path.join(cfg_dir, "run_all.ps1")

# el num_steps_per_env = 100 también está en el env, al final del todo, y deben tener el mismo valor
# Recuerda iniciar en el init todos los experimentos

# %%
import random
import os

# Si los directorios no existen (el último indicado), lo crea
os.makedirs(cfg_dir, exist_ok=True)
os.makedirs(path_resultados, exist_ok=True)
# Opciones de hiperparámetros
param_options = {
    "init_noise_std": [0.0, 0.1, 0.2, 0.5, 0.8, 1.0],
    "actor_hidden_dims": [[64, 64], [128, 128], [256, 256], [128, 64]],
    "critic_hidden_dims": [[64, 64], [128, 128], [256, 256]],
    "activation": ["relu", "tanh", "elu", "gelu"],
    "value_loss_coef": [0.5, 1.0, 2.0],
    "clip_param": [0.1, 0.2, 0.3],
    "entropy_coef": [0.0, 0.001, 0.01, 0.05],
    "num_learning_epochs": [4, 8, 12],
    "num_mini_batches": [2, 4, 8],
    "learning_rate": [5e-05, 1e-4, 3e-4, 1e-3, 3e-3],
    "gamma": [0.95, 0.98, 0.99],
    "lam": [0.90, 0.95, 0.97],
    "max_grad_norm": [0.5, 1.0, 2.0],
    "desired_kl": [0.005, 0.008, 0.01, 0.02],
}

num_trials = 35  # cantidad de configuraciones

cfg_files = []

for i in range(num_trials):
    run_name = f"ppo_random_{experiment_name}_{i+1}"
    sampled = {k: random.choice(v) for k, v in param_options.items()}

    # Convertir listas a string
    actor_dims = sampled["actor_hidden_dims"]
    critic_dims = sampled["critic_hidden_dims"]

    cfg_content = f"""
from isaaclab.utils import configclass
from isaaclab_rl.rsl_rl import RslRlOnPolicyRunnerCfg, RslRlPpoActorCriticCfg, RslRlPpoAlgorithmCfg

@configclass
class {task_name}PPORunnerCfg(RslRlOnPolicyRunnerCfg):
    num_steps_per_env = {num_steps_per_env} 
    max_iterations = {num_iter}
    save_interval = 100
    experiment_name = "{experiment_name}"
    run_name = "{run_name}"
    resume = False
    empirical_normalization = False
    csv_path_metrics = "{path_resultados}"
    callbacks = True
    policy = RslRlPpoActorCriticCfg(
        init_noise_std={sampled['init_noise_std']},
        actor_hidden_dims={actor_dims},
        critic_hidden_dims={critic_dims},
        activation="{sampled['activation']}",
    )
    algorithm = RslRlPpoAlgorithmCfg(
        value_loss_coef={sampled['value_loss_coef']},
        use_clipped_value_loss=True,
        clip_param={sampled['clip_param']},
        entropy_coef={sampled['entropy_coef']},
        num_learning_epochs={sampled['num_learning_epochs']},
        num_mini_batches={sampled['num_mini_batches']},
        learning_rate={sampled['learning_rate']},
        schedule="adaptive",
        gamma={sampled['gamma']},
        lam={sampled['lam']},
        desired_kl={sampled['desired_kl']},
        max_grad_norm={sampled['max_grad_norm']},
    )
"""
    cfg_path = os.path.join(cfg_dir, f"{run_name}_cfg.py")
    with open(cfg_path, "w") as f:
        f.write(cfg_content.strip())
    cfg_files.append((run_name, cfg_path))

# Crear archivo PowerShell para ejecutar todas las configuraciones
powershell_script = os.path.join(cfg_dir, "run_all.ps1")

num_envs =  [64, 128, 512, 1024, 2048, 4096, 8196] #número de entornos para train (paralelizados)

with open(powershell_script, "w") as f:
    f.write("$ErrorActionPreference = 'Stop'\n\n")
    j = 0
    for run_name, cfg_path in cfg_files:
        # Convertir path a módulo Python (reemplazar / y .py)
        num_envs_i = random.choice(num_envs)
        module_path = cfg_path.replace("/", ".").replace("\\", ".").replace(".py", "")
        f.write(f'Write-Host "Ejecutando {run_name}"\n')
        f.write(f'& "{isaaclab_bat}" -p "{train_script}" --task {id_task}-{j+1} --num_envs {num_envs_i} --headless \n\n')
        j += 1
print("Archivos de configuración generados y script PowerShell listo en:", powershell_script)
# Out:
# Archivos de configuración generados y script PowerShell listo en: C:/Users/Teresa/Documents/GitHub/navsim/isaac_lab/aerotaxi/env_command/env_10/grid_hiperparametros/cfg_files\run_all.ps1

# %%
# Ejecuta el entrenamiento de forma automática
# !powershell -ExecutionPolicy Bypass -File "{powershell_script}"
import subprocess
import sys

# Ruta al script que generaste
powershell_script_path = powershell_script 

print(f"Iniciando ejecución de: {powershell_script_path}\n")

# Ejecutamos el proceso capturando la salida en tiempo real
process = subprocess.Popen(
    ["powershell.exe", "-ExecutionPolicy", "Bypass", "-File", powershell_script_path],
    stdout=subprocess.PIPE,
    stderr=subprocess.STDOUT, # Redirigimos errores a la salida estándar para verlos
    text=True,
    bufsize=1
)

# Leemos la salida línea a línea conforme se genera
try:
    for line in process.stdout:
        print(line, end="") # Imprime la salida de PowerShell en la celda
        sys.stdout.flush()   # Fuerza a Jupyter a mostrar la línea inmediatamente
except KeyboardInterrupt:
    process.kill()
    print("\nEntrenamiento cancelado por el usuario.")

process.wait()
print("\n--- Todos los experimentos han finalizado ---")
# Out:
# Iniciando ejecución de: C:/Users/Teresa/Documents/GitHub/navsim/isaac_lab/aerotaxi/env_command/env_11/grid_hiperparametros/cfg_files\run_all.ps1
#
# Ejecutando ppo_random_command7_11
# [INFO] Using python from: C:\Users\Teresa\miniconda3\envs\env_isaaclab\python.exe
# [INFO][AppLauncher]: Using device: cuda:0
# [INFO][AppLauncher]: Loading experience file: C:\Users\Teresa\miniconda3\envs\env_isaaclab\Lib\site-packages\isaaclab\apps\isaaclab.python.kit
# Loading user config located at: 'c:/users/teresa/miniconda3/envs/env_isaaclab/lib/site-packages/isaacsim/kit/data/Kit/Isaac-Sim/5.1/user.config.json'
# [Info] [carb] Logging to file: c:/users/teresa/miniconda3/envs/env_isaaclab/lib/site-packages/isaacsim/kit/logs/Kit/Isaac-Sim/5.1/kit_20260212_162341.log
# [0.149s] [ext: omni.kit.async_engine-0.0.3] startup
# [0.283s] [ext: omni.metrics.core-0.0.3] startup
# [0.285s] [ext: omni.client.lib-1.1.0] startup
# [0.305s] [ext: omni.blobkey-1.1.2] startup
# [0.306s] [ext: omni.stats-1.0.1] startup
# [0.310s] [ext: omni.datastore-0.0.0] startup
# [0.314s] [ext: omni.client-1.3.0] startup
# [0.323s] [ext: omni.ujitso.default-1.0.0] startup
# [0.329s] [ext: omni.hsscclient-1.1.2] startup
# [0.341s] [ext: omni.gpu_foundation.shadercache.vulkan-1.0.0] startup
# [0.347s] [ext: omni.assets.plugins-0.0.0] startup
# [0.353s] [ext: omni.gpu_foundation-0.0.0] startup
# [0.388s] [ext: carb.windowing.plugins-1.0.0] startup
# [0.514s] [ext: omni.kit.renderer.init-0.0.0] startup
# [0.516s] [ext: omni.materialx.libs-1.0.7] startup
# [0.538s] [ext: omni.kit.telemetry-0.5.2] startup
# [0.552s] [ext: omni.usd.config-1.0.6] startup
# [0.568s] [ext: omni.gpucompute.plugins-0.0.0] startup
# [0.573s] [ext: omni.usd.libs-1.0.1] startup
# [0.711s] [ext: omni.kit.pipapi-0.0.0] startup
# [0.714s] [ext: omni.mdl-56.0.3] startup
# [0.740s] [ext: omni.iray.libs-0.0.0] startup
# [0.768s] [ext: omni.mdl.neuraylib-0.2.12] startup
# [0.781s] [ext: omni.kit.usd.mdl-1.1.5] startup
# 2026-02-12T15:23:41Z s] [Warning] [gpu.foundation.plugin] Skipping unsupported non-NVIDIA GPU: AMD Radeon(TM) Graphics
# 2026-02-12T15:23:41Z s] [Warning] [gpu.foundation.plugin] Skipping unsupported non-NVIDIA GPU: AMD Radeon(TM) Graphics
# [0.931s] [ext: omni.kit.loop-isaac-1.3.7] startup
# [0.937s] [ext: omni.kit.test-2.0.1] startup
# [1.010s] [ext: omni.appwindow-1.1.10] startup
# [1.043s] [ext: omni.kit.renderer.core-1.1.0] startup
# [1.054s] [ext: omni.kit.renderer.capture-0.0.0] startup
# [1.063s] [ext: omni.kit.renderer.imgui-2.0.5] startup
# [1.085s] [ext: omni.ui-2.27.1] startup
# [1.104s] [ext: omni.kit.mainwindow-1.0.3] startup
# [1.106s] [ext: carb.audio-0.1.0] startup
# [1.109s] [ext: omni.uiaudio-1.0.0] startup
# [1.115s] [ext: omni.kit.uiapp-0.0.0] startup
# [1.115s] [ext: omni.usd.schema.metrics.assembler-107.3.1] startup
#
# |---------------------------------------------------------------------------------------------|
# | Driver Version: 581.29        | Graphics API: Vulkan
# |=============================================================================================|
# | GPU | Name                             | Active | LDA | GPU Memory | Vendor-ID | LUID       |
# |     |                                  |        |     |            | Device-ID | UUID       |
# |     |                                  |        |     |            | Bus-ID    |            |
# |---------------------------------------------------------------------------------------------|
# | 0   | NVIDIA GeForce RTX 5080          | Yes: 0 |     | 15889   MB | 10de      | d5560100.. |
# |     |                                  |        |     |            | 2c02      | c7fa9756.. |
# |     |                                  |        |     |            | 1         |            |
# |---------------------------------------------------------------------------------------------|
# | 1   | AMD Radeon(TM) Graphics          |        |     | 2048    MB | 1002      | 336a0100.. |
# |     |                                  |        |     |            | 13c0      | 00000000.. |
# |     |                                  |        |     |            | N/A       |            |
# |=============================================================================================|
# | OS: Windows 11 Pro, Version: 10.0 (24H2), Build: 26100, Kernel: 10.0.26100.7824
# | Processor: AMD Ryzen 9 9950X 16-Core Processor
# | Cores: 16 | Logical Cores: 32
# |---------------------------------------------------------------------------------------------|
# | Total Memory (MB): 128627 | Free Memory: 69118
# | Total Page/Swap (MB): 136819 | Free Page/Swap: 67520
# |---------------------------------------------------------------------------------------------|
# [1.124s] [ext: omni.usd.schema.audio-0.0.0] startup
# [1.139s] [ext: isaacsim.robot.schema-3.6.0] startup
# [1.167s] [ext: omni.usd.schema.anim-0.0.0] startup
# [1.210s] [ext: omni.usd_resolver-1.0.0] startup
# [1.221s] [ext: omni.usd.core-1.5.3] startup
# [1.223s] [ext: omni.usd.schema.omni_sensors-0.0.0] startup
# [1.252s] [ext: omni.usd.schema.physx-107.3.26] startup
# [1.285s] [ext: omni.usd.schema.omniscripting-1.0.0] startup
# [1.298s] [ext: omni.usd.schema.omnigraph-1.0.0] startup
# [1.310s] [ext: omni.usd.schema.semantics-0.0.0] startup
# [1.319s] [ext: omni.usd.schema.geospatial-0.0.0] startup
# [1.325s] [ext: omni.kit.window.popup_dialog-2.0.24] startup
# [1.333s] [ext: omni.activity.core-1.0.3] startup
# [1.338s] [ext: omni.kit.widget.nucleus_connector-2.0.1] startup
# [1.344s] [ext: omni.kit.usd_undo-0.1.8] startup
# [1.345s] [ext: omni.graph.exec-0.9.6] startup
# [1.348s] [ext: omni.kit.actions.core-1.0.0] startup
# [1.355s] [ext: usdrt.scenegraph-7.6.1] startup
# [1.433s] [ext: omni.resourcemonitor-107.0.1] startup
# [1.440s] [ext: omni.kit.exec.core-0.13.4] startup
# [1.445s] [ext: omni.timeline-1.0.14] startup
# [1.449s] [ext: omni.kit.commands-1.4.10] startup
# [1.461s] [ext: omni.kit.audiodeviceenum-1.0.2] startup
# [1.467s] [ext: omni.hydra.usdrt_delegate-7.5.1] startup
# [1.483s] [ext: omni.hydra.scene_delegate-0.3.4] startup
# [1.489s] [ext: omni.usd-1.13.10] startup
# [1.584s] [ext: omni.kit.asset_converter-5.0.17] startup
# [1.601s] [ext: omni.usd.schema.omni_lens_distortion-0.0.0] startup
# [1.605s] [ext: omni.usd.schema.render_settings.rtx-0.0.0] startup
# [1.608s] [ext: omni.index.libs-380600.8087.0] startup
# [1.608s] [ext: omni.volume-0.5.2] startup
# [1.624s] [ext: omni.ujitso.client-0.0.0] startup
# [1.626s] [ext: omni.index-1.0.1] startup
# [1.628s] [ext: omni.hydra.rtx.shadercache.vulkan-1.0.0] startup
# [1.631s] [ext: omni.hydra.rtx-1.0.0] startup
# [1.694s] [ext: omni.kit.notification_manager-1.0.10] startup
# [1.699s] [ext: omni.kit.clipboard-1.0.5] startup
# [1.701s] [ext: omni.kit.viewport.legacy_gizmos-1.0.19] startup
# [1.704s] [ext: omni.kit.raycast.query-1.1.0] startup
# [1.710s] [ext: omni.kit.menu.core-1.1.2] startup
# [1.712s] [ext: omni.kit.widget.options_menu-1.1.6] startup
# [1.720s] [ext: omni.kit.helper.file_utils-0.1.9] startup
# [1.723s] [ext: omni.kit.widget.path_field-2.0.11] startup
# [1.725s] [ext: omni.kit.widget.context_menu-1.2.5] startup
# [1.728s] [ext: omni.kit.widget.options_button-1.0.3] startup
# [1.731s] [ext: omni.kit.widget.filebrowser-2.12.3] startup
# [1.742s] [ext: omni.kit.widget.browser_bar-2.0.10] startup
# [1.745s] [ext: omni.kit.usd.layers-2.2.11] startup
# [1.760s] [ext: omni.ui.scene-1.11.5] startup
# [1.769s] [ext: omni.kit.viewport.registry-104.0.6] startup
# [1.770s] [ext: omni.kit.window.filepicker-2.13.4] startup
# [1.802s] [ext: omni.kit.menu.utils-2.0.5] startup
# [1.818s] [ext: omni.kit.context_menu-1.8.6] startup
# [1.822s] [ext: omni.kit.viewport.scene_camera_model-1.0.6] startup
# [1.826s] [ext: omni.kit.hydra_texture-1.4.6] startup
# [1.833s] [ext: omni.kit.window.file_importer-1.1.18] startup
# [1.840s] [ext: omni.kit.widget.searchable_combobox-1.0.6] startup
# [1.843s] [ext: omni.kit.window.drop_support-1.0.5] startup
# [1.845s] [ext: omni.kit.widget.viewport-107.1.3] startup
# [1.855s] [ext: omni.kit.material.library-2.0.7] startup
# [1.867s] [ext: omni.hydra.engine.stats-1.0.3] startup
# [1.870s] [ext: omni.kit.widget.settings-1.2.6] startup
# [1.873s] [ext: omni.kit.viewport.window-107.2.0] startup
# [2.176s] [ext: omni.kit.window.preferences-1.8.0] startup
# [2.194s] [ext: omni.kit.widget.toolbar-2.0.1] startup
# [2.211s] [ext: omni.kit.viewport.utility-1.1.2] startup
# [2.212s] [ext: omni.kit.manipulator.transform-107.0.0] startup
# [2.220s] [ext: omni.kit.manipulator.tool.snap-1.5.13] startup
# [2.231s] [ext: omni.kit.manipulator.selector-1.1.3] startup
# [2.233s] [ext: omni.kit.viewport.manipulator.transform-107.0.4] startup
# [2.238s] [ext: omni.kit.manipulator.viewport-107.0.1] startup
# [2.241s] [ext: omni.kit.primitive.mesh-1.0.17] startup
# [2.250s] [ext: omni.kit.manipulator.prim.core-107.0.8] startup
# [2.265s] [ext: omni.fabric.commands-1.1.6] startup
# [2.272s] [ext: omni.kit.manipulator.prim.usd-107.0.3] startup
# [2.274s] [ext: omni.kit.manipulator.prim.fabric-107.0.4] startup
# [2.277s] [ext: omni.debugdraw-0.1.4] startup
# [2.284s] [ext: omni.kit.property.adapter.core-1.0.2] startup
# [2.290s] [ext: omni.kit.manipulator.prim-107.0.0] startup
# [2.290s] [ext: omni.usdphysics-107.3.26] startup
# [2.293s] [ext: omni.kit.manipulator.selection-106.0.1] startup
# [2.296s] [ext: omni.kit.hotkeys.core-1.3.10] startup
# [2.298s] [ext: omni.kit.property.adapter.usd-1.0.2] startup
# [2.302s] [ext: omni.kit.widget.searchfield-1.1.8] startup
# [2.306s] [ext: omni.kit.widget.filter-1.1.4] startup
# [2.308s] [ext: omni.kit.property.adapter.fabric-1.0.3] startup
# [2.311s] [ext: omni.kit.widget.highlight_label-1.0.3] startup
# [2.313s] [ext: omni.kit.window.file_exporter-1.0.33] startup
# [2.316s] [ext: omni.kit.stage_template.core-1.1.22] startup
# [2.317s] [ext: omni.kit.widget.stage-3.1.4] startup
# [2.344s] [ext: omni.kit.widget.prompt-1.0.7] startup
# [2.346s] [ext: omni.kit.window.property-1.12.1] startup
# [2.354s] [ext: omni.kvdb-107.3.26] startup
# [2.359s] [ext: omni.kit.window.file-2.0.5] startup
# [2.367s] [ext: omni.kit.window.content_browser_registry-0.0.6] startup
# [2.368s] [ext: omni.kit.viewport.menubar.core-107.2.1] startup
# [2.400s] [ext: omni.kit.viewport.actions-107.0.2] startup
# [2.405s] [ext: omni.kit.window.content_browser-3.1.3] startup
# [2.422s] [ext: omni.kit.viewport.menubar.display-107.0.3] startup
# [2.425s] [ext: omni.kit.widget.layers-1.8.6] startup
# [2.452s] [ext: omni.kit.property.usd-4.5.12] startup
# [2.474s] [ext: omni.physx.foundation-107.3.26] startup
# [2.491s] [ext: omni.localcache-107.3.26] startup
# [2.498s] [ext: omni.convexdecomposition-107.3.26] startup
# [2.504s] [ext: omni.usdphysics.ui-107.3.26] startup
# [2.535s] [ext: omni.physx.cooking-107.3.26] startup
# [2.540s] [ext: omni.usd.metrics.assembler-107.3.1] startup
# [2.551s] [ext: omni.physx-107.3.26] startup
# [2.570s] [ext: omni.physics-107.3.26] startup
# [2.578s] [ext: omni.physx.commands-107.3.26] startup
# [2.586s] [ext: omni.physics.stageupdate-107.3.26] startup
# [2.592s] [ext: omni.inspect-1.0.2] startup
# [2.599s] [ext: omni.physx.ui-107.3.26] startup
# [2.645s] [ext: omni.graph.core-2.184.5] startup
# [2.650s] [ext: omni.physics.physx-107.3.26] startup
# 2026-02-12T15:23:43Z [2,552ms] [Warning] [carb] Acquiring non optional plugin interface which is not listed as dependency: [omni::physx::IPhysxBenchmarks v1.0] (plugin: <default plugin>), by client: omni.physics.physx.plugin. Add it to CARB_PLUGIN_IMPL_DEPS() macro of a client.
# [2.654s] [ext: isaacsim.core.deprecation_manager-0.2.7] startup
# [2.656s] [ext: omni.physics.tensors-107.3.26] startup
# [2.665s] [ext: omni.kit.numpy.common-0.1.3] startup
# [2.668s] [ext: isaacsim.core.version-2.0.6] startup
# [2.669s] [ext: omni.warp.core-1.8.2] startup
# [2.838s] [ext: omni.usd.metrics.assembler.physics-107.3.26] startup
# [2.842s] [ext: omni.isaac.dynamic_control-2.0.7] startup
# 2026-02-12T15:23:43Z [2,750ms] [Warning] [omni.isaac.dynamic_control] omni.isaac.dynamic_control is deprecated as of Isaac Sim 4.5. No action is needed from end-users.
# [2.851s] [ext: isaacsim.storage.native-1.5.1] startup
# [2.855s] [ext: isaacsim.core.utils-3.5.1] startup
# [2.861s] [ext: omni.graph.tools-1.79.2] startup
# [2.914s] [ext: omni.graph.action_core-1.1.7] startup
# [2.920s] [ext: omni.graph-1.141.2] startup
# [2.991s] [ext: omni.physx.tensors-107.3.26] startup
# [2.997s] [ext: omni.graph.action_nodes-1.50.4] startup
# [3.004s] [ext: isaacsim.core.simulation_manager-1.4.4] startup
# [3.370s] [ext: omni.kit.usd.collect-2.4.5] startup
# [3.377s] [ext: omni.kit.stage_templates-2.0.0] startup
# [3.383s] [ext: isaacsim.core.prims-0.6.1] startup
# [3.414s] [ext: omni.kit.usdz_export-1.0.9] startup
# [3.421s] [ext: isaacsim.core.api-4.8.0] startup
# [3.452s] [ext: omni.kit.tool.asset_importer-4.3.2] startup
# [3.464s] [ext: omni.graph.action-1.130.0] startup
# [3.467s] [ext: omni.kit.selection-0.1.6] startup
# [3.470s] [ext: omni.ui_query-1.1.8] startup
# [3.472s] [ext: omni.kit.stagerecorder.core-107.0.3] startup
# [3.480s] [ext: omni.kit.widget.text_editor-1.1.1] startup
# [3.484s] [ext: omni.kit.ui_test-1.3.7] startup
# [3.491s] [ext: omni.kit.stagerecorder.ui-107.0.1] startup
# [3.498s] [ext: omni.kit.window.extensions-1.4.27] startup
# [3.513s] [ext: omni.graph.visualization.nodes-2.1.3] startup
# [3.526s] [ext: omni.kit.stagerecorder.bundle-105.0.2] startup
# [3.529s] [ext: isaacsim.gui.components-1.2.1] startup
# [3.541s] [ext: isaacsim.gui.menu-2.4.4] startup
# [3.641s] [ext: isaacsim.app.about-2.0.11] startup
# [3.647s] [ext: isaacsim.asset.importer.mjcf-2.5.13] startup
# [3.660s] [ext: semantics.schema.editor-2.0.2] startup
# 2026-02-12T15:23:44Z [3,571ms] [Warning] [pxr.Semantics] pxr.Semantics is deprecated - please use Semantics instead
# [3.674s] [ext: omni.kit.widget.graph-2.0.0] startup
# [3.687s] [ext: semantics.schema.property-2.0.1] startup
# [3.691s] [ext: omni.kit.graph.delegate.default-1.2.3] startup
# [3.695s] [ext: isaacsim.core.cloner-1.4.10] startup
# [3.700s] [ext: omni.kit.graph.editor.core-1.5.3] startup
# [3.706s] [ext: omni.kit.graph.usd.commands-1.3.1] startup
# [3.709s] [ext: omni.kit.widget.material_preview-1.0.16] startup
# [3.713s] [ext: omni.graph.image.core-0.6.1] startup
# [3.716s] [ext: omni.graph.scriptnode-1.50.0] startup
# [3.719s] [ext: omni.kit.widget.stage_icons-1.0.8] startup
# [3.725s] [ext: omni.kit.window.material_graph-1.9.1] startup
# [3.749s] [ext: omni.graph.image.nodes-1.3.1] startup
# [3.752s] [ext: omni.kit.menu.create-2.0.1] startup
# [3.755s] [ext: omni.kit.window.stage-2.6.1] startup
# [3.762s] [ext: omni.kit.viewport.menubar.settings-107.0.3] startup
# [3.772s] [ext: omni.graph.nodes-1.170.10] startup
# [3.789s] [ext: omni.graph.ui_nodes-1.50.5] startup
# [3.797s] [ext: isaacsim.util.debug_draw-3.1.0] startup
# [3.807s] [ext: omni.syntheticdata-0.6.13] startup
# [3.833s] [ext: omni.kit.scripting-107.3.2] startup
# [3.851s] [ext: omni.videoencoding-0.1.2] startup
# [3.862s] [ext: omni.warp-1.8.2] startup
# [3.881s] [ext: omni.sensors.nv.common-3.0.0] startup
# [3.924s] [ext: isaacsim.sensors.physx-2.3.2] startup
# [3.942s] [ext: isaacsim.replicator.behavior-1.1.16] startup
# [3.949s] [ext: omni.sensors.net-1.0.0] startup
# [3.975s] [ext: omni.replicator.core-1.12.27] startup
# 2026-02-12T15:23:45Z [4,043ms] [Warning] [omni.graph.core.plugin] Found duplicate of category 'Replicator' - was 'Annotators', adding 'Fabric Reader'
# 2026-02-12T15:23:45Z [4,043ms] [Warning] [omni.graph.core.plugin] Category 'Replicator' not accepted on node type 'omni.replicator.core.FabricReader' in extension 'omni.replicator.core'
# 2026-02-12T15:23:45Z [4,044ms] [Warning] [omni.replicator.core.scripts.extension] No material configuration file, adding configuration to material settings directly.
# [4.148s] [ext: omni.sensors.nv.materials-2.0.0] startup
# [4.185s] [ext: isaacsim.simulation_app-2.12.2] startup
# [4.186s] [ext: omni.anim.curve.core-1.3.1] startup
# [4.206s] [ext: omni.kit.manipulator.camera-106.0.4] startup
# [4.219s] [ext: isaacsim.core.nodes-3.4.3] startup
# [4.236s] [ext: omni.sensors.nv.ids-2.0.0] startup
# [4.246s] [ext: omni.sensors.nv.lidar-3.0.0] startup
# [4.279s] [ext: omni.sensors.nv.wpm-3.0.0] startup
# [4.288s] [ext: omni.kit.property.audio-1.0.16] startup
# [4.295s] [ext: omni.kit.property.camera-1.0.10] startup
# [4.303s] [ext: omni.kit.property.light-1.0.12] startup
# [4.325s] [ext: omni.kit.property.geometry-2.0.4] startup
# [4.339s] [ext: omni.sensors.nv.radar-3.0.0] startup
# [4.362s] [ext: isaacsim.gui.property-1.1.3] startup
# [4.380s] [ext: omni.kit.property.render-1.2.1] startup
# [4.390s] [ext: omni.hydra.scene_api-0.1.2] startup
# [4.398s] [ext: isaacsim.test.docstring-1.1.0] startup
# [4.411s] [ext: isaacsim.core.experimental.utils-0.3.0] startup
# [4.421s] [ext: omni.kit.widget.zoombar-1.0.6] startup
# [4.431s] [ext: omni.kit.property.transform-1.5.13] startup
# [4.453s] [ext: omni.kit.property.material-1.11.9] startup
# [4.513s] [ext: isaacsim.core.experimental.prims-0.8.1] startup
# [4.630s] [ext: omni.kit.browser.core-2.3.13] startup
# [4.694s] [ext: omni.kit.property.bundle-1.4.1] startup
# [4.713s] [ext: isaacsim.sensors.rtx-15.8.4] startup
# [4.753s] [ext: omni.kit.viewport.menubar.camera-107.0.6] startup
# [4.808s] [ext: isaacsim.robot.surface_gripper-3.3.1] startup
# [4.842s] [ext: omni.kit.browser.folder.core-1.10.9] startup
# [4.945s] [ext: isaacsim.sensors.physics-0.4.3] startup
# [4.984s] [ext: omni.kit.tool.collect-2.2.18] startup
# [4.995s] [ext: omni.kit.menu.stage-1.2.7] startup
# [5.001s] [ext: isaacsim.robot.manipulators-3.3.6] startup
# [5.011s] [ext: omni.kit.viewport.menubar.lighting-107.3.1] startup
# [5.027s] [ext: omni.kit.viewport.menubar.render-107.0.10] startup
# [5.041s] [ext: isaacsim.robot.policy.examples-4.1.11] startup
# [5.051s] [ext: isaacsim.examples.browser-0.2.1] startup
# [5.069s] [ext: isaacsim.asset.importer.urdf-2.4.30] startup
# [5.113s] [ext: omni.kit.window.console-1.1.4] startup
# [5.136s] [ext: omni.physx.demos-107.3.26] startup
# [5.206s] [ext: omni.kit.property.physx-107.3.26] startup
# [5.232s] [ext: omni.rtx.window.settings-0.6.19] startup
# [5.245s] [ext: omni.ocio-0.1.1] startup
# [5.250s] [ext: omni.replicator.replicator_yaml-2.0.11] startup
# [5.276s] [ext: omni.asset_validator.core-1.1.6] startup
# [5.354s] [ext: omni.physx.vehicle-107.3.26] startup
# [5.386s] [ext: omni.rtx.settings.core-0.6.5] startup
# [5.395s] [ext: omni.kit.window.script_editor-2.0.1] startup
# [5.402s] [ext: isaacsim.robot.wheeled_robots-4.0.24] startup
# [5.420s] [ext: omni.kit.window.toolbar-2.0.0] startup
# [5.429s] [ext: omni.physx.asset_validator-107.3.26] startup
# [5.448s] [ext: omni.physx.camera-107.3.26] startup
# [5.465s] [ext: omni.physx.cct-107.3.26] startup
# [5.486s] [ext: omni.physx.graph-107.3.26] startup
# [5.519s] [ext: omni.physx.supportui-107.3.26] startup
# [5.552s] [ext: omni.physx.telemetry-107.3.26] startup
# [5.558s] [ext: omni.kit.window.status_bar-0.1.9] startup
# [5.567s] [ext: omni.usd.metrics.assembler.ui-107.3.1] startup
# [5.587s] [ext: isaacsim.asset.browser-1.3.23] startup
# [5.839s] [ext: isaacsim.core.throttling-2.2.2] startup
# [5.846s] [ext: omni.kit.ui.actions-1.0.5] startup
# [5.850s] [ext: omni.physx.bundle-107.3.26] startup
# [5.851s] [ext: isaacsim.sensors.camera-1.3.6] startup
# [5.859s] [ext: isaaclab-0.47.2] startup
# [6.114s] [ext: isaaclab_assets-0.2.3] startup
# [6.403s] [ext: isaaclab_tasks-0.11.6] startup
# [7.320s] [ext: omni.kit.menu.common-2.0.1] startup
# [7.323s] [ext: isaaclab_rl-0.4.4] startup
# [7.324s] [ext: isaaclab_mimic-1.0.15] startup
# [7.325s] [ext: isaaclab.python-2.3.0] startup
# [7.329s] Simulation App Starting
# 2026-02-12T15:23:48Z [7,585ms] [Warning] [omni.fabric.plugin] Warning: attribute overrideClipRange not found for bucket id 9
#
# [7.945s] app ready
# [12.351s] Simulation App Startup Complete
# C:\Users\Teresa\Documents\GitHub\navsim\isaac_lab\aerotaxi\env_command\env_11\flight_plan.py:29: UserWarning: Treat the new Tool classes introduced in v1.5 as experimental for now; the API and rcParam may change in future versions.
#   plt.rcParams["toolbar"] = "toolmanager"
# [INFO]: Parsing configuration from: aerotaxi.env_command.env_11.env:UAVEnvCfg
# [INFO]: Parsing configuration from: aerotaxi.env_command.env_11.grid_hiperparametros.cfg_files.ppo_random_command7_11_cfg:Command7PPORunnerCfg
# [INFO] Logging experiment in directory: C:\Users\Teresa\Documents\GitHub\navsim\isaac_lab\aerotaxi\env_command\env_11\logs\rsl_rl\command7
# Exact experiment name requested from command line: 2026-02-12_16-23-54
# Setting seed: 42
# [13.618s] [ext: omni.physx.fabric-107.3.26] startup
# [2026-02-12 16:23:54,616][ogn_registration][INFO] - Looking for Python nodes to register in omni.physx.fabric-107.3.26
# [2026-02-12 16:23:54,616][ogn_registration][INFO] -  -> Registered nodes from module omni.physxfabric at c:\users\teresa\miniconda3\envs\env_isaaclab\lib\site-packages\isaacsim\extscache\omni.physx.fabric-107.3.26+107.3.3.wx64.r.cp311.u353
# [2026-02-12 16:23:54,616][ogn_registration][INFO] - Registering nodes in c:\users\teresa\miniconda3\envs\env_isaaclab\lib\site-packages\isaacsim\extscache\omni.physx.fabric-107.3.26+107.3.3.wx64.r.cp311.u353 imported as omni.physxfabric with AutoNode config {}
# [2026-02-12 16:23:54,616][ogn_registration][INFO] - Registering Python Node Types from omni.physxfabric at c:\users\teresa\miniconda3\envs\env_isaaclab\lib\site-packages\isaacsim\extscache\omni.physx.fabric-107.3.26+107.3.3.wx64.r.cp311.u353 in omni.physx.fabric
# [2026-02-12 16:23:54,616][ogn_registration][INFO] - ========================================================================================================================
# [2026-02-12 16:23:54,618][ogn_registration][INFO] - No dependency on omni.graph, therefore no nodes to register in omni.physx.fabric
# [2026-02-12 16:23:54,618][ogn_registration][INFO] - ...None found, no registration to do
# [2026-02-12 16:23:54,618][ogn_registration][INFO] - ...Skipping: No OmniGraph presence in the module omni.physxfabric - No nodes in this module, do not remember it
# [2026-02-12 16:23:54,618][ogn_registration][INFO] - Destroying registration record for omni.physx.fabric
# [2026-02-12 16:23:54,618][ogn_registration][INFO] - OGN register omni.physx.fabric-107.3.26 took 2722200.000000
# [INFO]: Base environment:
# 	Environment device    : cuda:0
# 	Environment seed      : 42
# 	Physics step-size     : 0.005
# 	Rendering step-size   : 0.02
# 	Environment step-size : 0.02
# [INFO]: Time taken for scene creation : 6.386654 seconds
# [INFO]: Scene manager:  <class InteractiveScene>
# 	Number of environments: 8196
# 	Environment spacing   : 200.0
# 	Source prim name      : /World/envs/env_0
# 	Global prim paths     : []
# 	Replicate physics     : False
# [INFO]: Starting the simulation. This may take a few seconds. Please wait...
# [INFO]: Time taken for simulation start : 120.296866 seconds
# [INFO] Command Manager:  <CommandManager> contains 1 active terms.
# +--------------------------------------+
# |         Active Command Terms         |
# +-------+-------------+----------------+
# | Index | Name        |      Type      |
# +-------+-------------+----------------+
# |   0   | vel_command | UAVcommandTerm |
# +-------+-------------+----------------+
#
# [INFO] Event Manager:  <EventManager> contains 1 active terms.
# +-----------------------------------+
# | Active Event Terms in Mode: 'reset' |
# +----------+------------------------+
# |  Index   | Name                   |
# +----------+------------------------+
# |    0     | reset_pos              |
# |    1     | randomize_mass         |
# |    2     | randomize_wind         |
# +----------+------------------------+
#
# [INFO] Recorder Manager:  <RecorderManager> contains 0 active terms.
# +---------------------+
# | Active Recorder Terms |
# +-----------+---------+
# |   Index   | Name    |
# +-----------+---------+
# +-----------+---------+
#
# [INFO] Action Manager:  <ActionManager> contains 1 active terms.
# +-----------------------------------+
# |   Active Action Terms (shape: 4)  |
# +--------+-------------+------------+
# | Index  | Name        |  Dimension |
# +--------+-------------+------------+
# |   0    | rotors_vel  |          4 |
# +--------+-------------+------------+
#
# [INFO] Observation Manager: <ObservationManager> contains 2 groups.
# +----------------------------------------------------+
# | Active Observation Terms in Group: 'policy' (shape: (39,)) |
# +---------------+--------------------+---------------+
# |     Index     | Name               |     Shape     |
# +---------------+--------------------+---------------+
# |       0       | dist               |      (9,)     |
# |       1       | lin_vel            |      (9,)     |
# |       2       | ang_vel            |      (9,)     |
# |       3       | roll               |      (3,)     |
# |       4       | pitch              |      (3,)     |
# |       5       | yaw                |      (3,)     |
# |       6       | height             |      (3,)     |
# +---------------+--------------------+---------------+
# +-------------------------------------------------------+
# | Active Observation Terms in Group: 'critic' (shape: (16,)) |
# +--------------+-------------------------+--------------+
# |    Index     | Name                    |    Shape     |
# +--------------+-------------------------+--------------+
# |      0       | dist                    |     (3,)     |
# |      1       | lin_vel                 |     (3,)     |
# |      2       | ang_vel                 |     (3,)     |
# |      3       | roll                    |     (1,)     |
# |      4       | pitch                   |     (1,)     |
# |      5       | yaw                     |     (1,)     |
# |      6       | height                  |     (1,)     |
# |      7       | target_vel              |     (3,)     |
# +--------------+-------------------------+--------------+
#
# [INFO] Termination Manager:  <TerminationManager> contains 4 active terms.
# +---------------------------------------+
# |        Active Termination Terms       |
# +-------+--------------------+----------+
# | Index | Name               | Time Out |
# +-------+--------------------+----------+
# |   0   | time_out           |   True   |
# |   1   | below_min_altitude |  False   |
# |   2   | bad_attitude       |  False   |
# |   3   | safety_shutdown    |  False   |
# +-------+--------------------+----------+
#
# [INFO] Reward Manager:  <RewardManager> contains 14 active terms.
# +--------------------------------------------------+
# |               Active Reward Terms                |
# +-------+---------------------------------+--------+
# | Index | Name                            | Weight |
# +-------+---------------------------------+--------+
# |   0   | alive                           |    2.0 |
# |   1   | action_rate                     |  -0.01 |
# |   2   | terminating                     |  -20.0 |
# |   3   | rew_pos_diff                    |  -0.02 |
# |   4   | rew_pos_diff_fine_grained       |    2.0 |
# |   5   | rew_lin_vel_diff                |   -1.0 |
# |   6   | rew_lin_vel_diff_fine_grained   |    2.0 |
# |   7   | rew_ang_vel_z_diff              |   -1.0 |
# |   8   | rew_ang_vel_z_diff_fine_grained |    1.0 |
# |   9   | rew_roll_diff                   |   -0.5 |
# |   10  | rew_roll_diff_fine_grained      |    2.0 |
# |   11  | rew_pitch_diff                  |   -0.5 |
# |   12  | rew_pitch_diff_fine_grained     |    2.0 |
# |   13  | rew_hovering                    |    2.0 |
# +-------+---------------------------------+--------+
#
# [INFO] Curriculum Manager:  <CurriculumManager> contains 0 active terms.
# +----------------------+
# | Active Curriculum Terms |
# +-----------+----------+
# |   Index   | Name     |
# +-----------+----------+
# +-----------+----------+
#
# Creating window for environment.
# [INFO]: Completed setting up the environment...
# 2026-02-12T15:26:02Z [141,170ms] [Warning] [omni.physx.fabric.plugin] FabricManager::initializePointInstancer mismatched prototypes on point instancer: /Visuals/target_commands.
# C:\Users\Teresa\miniconda3\envs\env_isaaclab\Lib\site-packages\rsl_rl\utils\utils.py:244: UserWarning: The observation configuration dictionary 'obs_groups' must contain the 'policy' key. As an observation group with the name 'policy' was found, this is assumed to be the observation set. Consider adding the 'policy' key to the 'obs_groups' dictionary for clarity. This behavior will be removed in a future version.
#   warnings.warn(
# C:\Users\Teresa\miniconda3\envs\env_isaaclab\Lib\site-packages\rsl_rl\utils\utils.py:282: UserWarning: The observation configuration dictionary 'obs_groups' must contain the 'critic' key. As an observation group with the name 'critic' was found, this is assumed to be the observation set. Consider adding the 'critic' key to the 'obs_groups' dictionary for clarity. This behavior will be removed in a future version.
#   warnings.warn(
# --------------------------------------------------------------------------------
# Resolved observation sets:
# 	 policy :  ['policy']
# 	 critic :  ['critic']
# --------------------------------------------------------------------------------
# Actor MLP: MLP(
#   (0): Linear(in_features=39, out_features=64, bias=True)
#   (1): ELU(alpha=1.0)
#   (2): Linear(in_features=64, out_features=64, bias=True)
#   (3): ELU(alpha=1.0)
#   (4): Linear(in_features=64, out_features=4, bias=True)
# )
# Critic MLP: MLP(
#   (0): Linear(in_features=16, out_features=128, bias=True)
#   (1): ELU(alpha=1.0)
#   (2): Linear(in_features=128, out_features=128, bias=True)
#   (3): ELU(alpha=1.0)
#   (4): Linear(in_features=128, out_features=1, bias=True)
# )
# 2026-02-12T15:26:16Z [155,741ms] [Warning] [carb] Client gpu.foundation.plugin has acquired [gpu::unstable::IMemoryBudgetManagerFactory v0.1] 100 times. Consider accessing this interface with carb::getCachedInterface() (Performance warning)
# ################################################################################
#                        Learning iteration 0/4001
#
#                        Computation: 55293 steps/s (collection: 14.498s, learning 0.325s)
#              Mean action noise std: 0.20
#           Mean value_function loss: 0.2745
#                Mean surrogate loss: 0.0011
#                  Mean entropy loss: -0.7318
#                        Mean reward: -1.75
#                Mean episode length: 51.13
#               Episode_Reward/alive: 0.0658
#         Episode_Reward/action_rate: -0.0002
#         Episode_Reward/terminating: -0.0089
#        Episode_Reward/rew_pos_diff: -0.0013
# Episode_Reward/rew_pos_diff_fine_grained: 0.0583
#    Episode_Reward/rew_lin_vel_diff: -0.1992
# Episode_Reward/rew_lin_vel_diff_fine_grained: 0.0022
#  Episode_Reward/rew_ang_vel_z_diff: -0.0014
# Episode_Reward/rew_ang_vel_z_diff_fine_grained: 0.0306
#       Episode_Reward/rew_roll_diff: -0.0042
# Episode_Reward/rew_roll_diff_fine_grained: 0.0092
#      Episode_Reward/rew_pitch_diff: -0.0043
# Episode_Reward/rew_pitch_diff_fine_grained: 0.0089
#        Episode_Reward/rew_hovering: 0.0327
#       Episode_Termination/time_out: 0.0255
# Episode_Termination/below_min_altitude: 0.4172
#   Episode_Termination/bad_attitude: 0.0000
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 819600
#                     Iteration time: 14.82s
#                       Time elapsed: 00:00:14
#                                ETA: 16:28:25
#
# Could not find git repository in C:\Users\Teresa\miniconda3\envs\env_isaaclab\Lib\site-packages\rsl_rl\__init__.py. Skipping.
# Storing git diff for 'navsim' in: C:\Users\Teresa\Documents\GitHub\navsim\isaac_lab\aerotaxi\env_command\env_11\logs\rsl_rl\command7\2026-02-12_16-23-54_ppo_random_command7_11\git\navsim.diff
# ################################################################################
#                        Learning iteration 1/4001
#
#                        Computation: 72953 steps/s (collection: 11.053s, learning 0.181s)
#              Mean action noise std: 0.20
#           Mean value_function loss: 0.2774
#                Mean surrogate loss: 0.0016
#                  Mean entropy loss: -0.7004
#                        Mean reward: -1.55
#                Mean episode length: 61.67
#               Episode_Reward/alive: 0.0916
#         Episode_Reward/action_rate: -0.0003
#         Episode_Reward/terminating: -0.0160
#        Episode_Reward/rew_pos_diff: -0.0022
# Episode_Reward/rew_pos_diff_fine_grained: 0.0788
#    Episode_Reward/rew_lin_vel_diff: -0.3106
# Episode_Reward/rew_lin_vel_diff_fine_grained: 0.0024
#  Episode_Reward/rew_ang_vel_z_diff: -0.0021
# Episode_Reward/rew_ang_vel_z_diff_fine_grained: 0.0424
#       Episode_Reward/rew_roll_diff: -0.0058
# Episode_Reward/rew_roll_diff_fine_grained: 0.0131
#      Episode_Reward/rew_pitch_diff: -0.0059
# Episode_Reward/rew_pitch_diff_fine_grained: 0.0123
#        Episode_Reward/rew_hovering: 0.0345
#       Episode_Termination/time_out: 0.0011
# Episode_Termination/below_min_altitude: 0.9989
#   Episode_Termination/bad_attitude: 0.0000
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 1639200
#                     Iteration time: 11.23s
#                       Time elapsed: 00:00:26
#                                ETA: 14:28:34
#
# ################################################################################
#                        Learning iteration 2/4001
#
#                        Computation: 76198 steps/s (collection: 10.556s, learning 0.200s)
#              Mean action noise std: 0.20
#           Mean value_function loss: 0.2024
#                Mean surrogate loss: 0.0021
#                  Mean entropy loss: -0.6838
#                        Mean reward: -1.66
#                Mean episode length: 59.99
#               Episode_Reward/alive: 0.0900
#         Episode_Reward/action_rate: -0.0002
#         Episode_Reward/terminating: -0.0160
#        Episode_Reward/rew_pos_diff: -0.0021
# Episode_Reward/rew_pos_diff_fine_grained: 0.0778
#    Episode_Reward/rew_lin_vel_diff: -0.3041
# Episode_Reward/rew_lin_vel_diff_fine_grained: 0.0023
#  Episode_Reward/rew_ang_vel_z_diff: -0.0003
# Episode_Reward/rew_ang_vel_z_diff_fine_grained: 0.0453
#       Episode_Reward/rew_roll_diff: -0.0058
# Episode_Reward/rew_roll_diff_fine_grained: 0.0122
#      Episode_Reward/rew_pitch_diff: -0.0057
# Episode_Reward/rew_pitch_diff_fine_grained: 0.0127
#        Episode_Reward/rew_hovering: 0.0321
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 1.0000
#   Episode_Termination/bad_attitude: 0.0000
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 2458800
#                     Iteration time: 10.76s
#                       Time elapsed: 00:00:36
#                                ETA: 13:37:52
#
# ################################################################################
#                        Learning iteration 3/4001
#
#                        Computation: 76181 steps/s (collection: 10.559s, learning 0.200s)
#              Mean action noise std: 0.21
#           Mean value_function loss: 0.1318
#                Mean surrogate loss: 0.0018
#                  Mean entropy loss: -0.6617
#                        Mean reward: -1.51
#                Mean episode length: 56.96
#               Episode_Reward/alive: 0.0913
#         Episode_Reward/action_rate: -0.0003
#         Episode_Reward/terminating: -0.0160
#        Episode_Reward/rew_pos_diff: -0.0022
# Episode_Reward/rew_pos_diff_fine_grained: 0.0786
#    Episode_Reward/rew_lin_vel_diff: -0.3097
# Episode_Reward/rew_lin_vel_diff_fine_grained: 0.0024
#  Episode_Reward/rew_ang_vel_z_diff: -0.0002
# Episode_Reward/rew_ang_vel_z_diff_fine_grained: 0.0460
#       Episode_Reward/rew_roll_diff: -0.0058
# Episode_Reward/rew_roll_diff_fine_grained: 0.0130
#      Episode_Reward/rew_pitch_diff: -0.0058
# Episode_Reward/rew_pitch_diff_fine_grained: 0.0130
#        Episode_Reward/rew_hovering: 0.0342
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 1.0000
#   Episode_Termination/bad_attitude: 0.0000
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 3278400
#                     Iteration time: 10.76s
#                       Time elapsed: 00:00:47
#                                ETA: 13:12:28
#
# ################################################################################
#                        Learning iteration 4/4001
#
#                        Computation: 74537 steps/s (collection: 10.764s, learning 0.232s)
#              Mean action noise std: 0.21
#           Mean value_function loss: 0.0921
#                Mean surrogate loss: 0.0018
#                  Mean entropy loss: -0.6364
#                        Mean reward: -1.37
#                Mean episode length: 56.72
#               Episode_Reward/alive: 0.0917
#         Episode_Reward/action_rate: -0.0003
#         Episode_Reward/terminating: -0.0160
#        Episode_Reward/rew_pos_diff: -0.0022
# Episode_Reward/rew_pos_diff_fine_grained: 0.0789
#    Episode_Reward/rew_lin_vel_diff: -0.3117
# Episode_Reward/rew_lin_vel_diff_fine_grained: 0.0024
#  Episode_Reward/rew_ang_vel_z_diff: -0.0002
# Episode_Reward/rew_ang_vel_z_diff_fine_grained: 0.0462
#       Episode_Reward/rew_roll_diff: -0.0058
# Episode_Reward/rew_roll_diff_fine_grained: 0.0128
#      Episode_Reward/rew_pitch_diff: -0.0058
# Episode_Reward/rew_pitch_diff_fine_grained: 0.0131
#        Episode_Reward/rew_hovering: 0.0349
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 1.0000
#   Episode_Termination/bad_attitude: 0.0000
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 4098000
#                     Iteration time: 11.00s
#                       Time elapsed: 00:00:58
#                                ETA: 13:00:19
#
# ################################################################################
#                        Learning iteration 5/4001
#
#                        Computation: 73143 steps/s (collection: 10.985s, learning 0.220s)
#              Mean action noise std: 0.21
#           Mean value_function loss: 0.0978
#                Mean surrogate loss: 0.0037
#                  Mean entropy loss: -0.6272
#                        Mean reward: -1.57
#                Mean episode length: 59.61
#               Episode_Reward/alive: 0.0912
#         Episode_Reward/action_rate: -0.0003
#         Episode_Reward/terminating: -0.0160
#        Episode_Reward/rew_pos_diff: -0.0022
# Episode_Reward/rew_pos_diff_fine_grained: 0.0786
#    Episode_Reward/rew_lin_vel_diff: -0.3098
# Episode_Reward/rew_lin_vel_diff_fine_grained: 0.0023
#  Episode_Reward/rew_ang_vel_z_diff: -0.0002
# Episode_Reward/rew_ang_vel_z_diff_fine_grained: 0.0459
#       Episode_Reward/rew_roll_diff: -0.0058
# Episode_Reward/rew_roll_diff_fine_grained: 0.0131
#      Episode_Reward/rew_pitch_diff: -0.0058
# Episode_Reward/rew_pitch_diff_fine_grained: 0.0130
#        Episode_Reward/rew_hovering: 0.0342
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 1.0000
#   Episode_Termination/bad_attitude: 0.0000
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 4917600
#                     Iteration time: 11.21s
#                       Time elapsed: 00:01:09
#                                ETA: 12:54:28
#
# ################################################################################
#                        Learning iteration 6/4001
#
#                        Computation: 72451 steps/s (collection: 11.095s, learning 0.217s)
#              Mean action noise std: 0.21
#           Mean value_function loss: 0.0704
#                Mean surrogate loss: 0.0020
#                  Mean entropy loss: -0.5863
#                        Mean reward: -1.43
#                Mean episode length: 58.15
#               Episode_Reward/alive: 0.0910
#         Episode_Reward/action_rate: -0.0003
#         Episode_Reward/terminating: -0.0160
#        Episode_Reward/rew_pos_diff: -0.0022
# Episode_Reward/rew_pos_diff_fine_grained: 0.0784
#    Episode_Reward/rew_lin_vel_diff: -0.3087
# Episode_Reward/rew_lin_vel_diff_fine_grained: 0.0023
#  Episode_Reward/rew_ang_vel_z_diff: -0.0002
# Episode_Reward/rew_ang_vel_z_diff_fine_grained: 0.0459
#       Episode_Reward/rew_roll_diff: -0.0058
# Episode_Reward/rew_roll_diff_fine_grained: 0.0130
#      Episode_Reward/rew_pitch_diff: -0.0058
# Episode_Reward/rew_pitch_diff_fine_grained: 0.0125
#        Episode_Reward/rew_hovering: 0.0338
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 1.0000
#   Episode_Termination/bad_attitude: 0.0000
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 5737200
#                     Iteration time: 11.31s
#                       Time elapsed: 00:01:21
#                                ETA: 12:51:16
#
# ################################################################################
#                        Learning iteration 7/4001
#
#                        Computation: 72518 steps/s (collection: 11.068s, learning 0.234s)
#              Mean action noise std: 0.21
#           Mean value_function loss: 0.0693
#                Mean surrogate loss: 0.0052
#                  Mean entropy loss: -0.5687
#                        Mean reward: -1.58
#                Mean episode length: 56.79
#               Episode_Reward/alive: 0.0913
#         Episode_Reward/action_rate: -0.0003
#         Episode_Reward/terminating: -0.0160
#        Episode_Reward/rew_pos_diff: -0.0022
# Episode_Reward/rew_pos_diff_fine_grained: 0.0786
#    Episode_Reward/rew_lin_vel_diff: -0.3097
# Episode_Reward/rew_lin_vel_diff_fine_grained: 0.0024
#  Episode_Reward/rew_ang_vel_z_diff: -0.0002
# Episode_Reward/rew_ang_vel_z_diff_fine_grained: 0.0460
#       Episode_Reward/rew_roll_diff: -0.0058
# Episode_Reward/rew_roll_diff_fine_grained: 0.0127
#      Episode_Reward/rew_pitch_diff: -0.0058
# Episode_Reward/rew_pitch_diff_fine_grained: 0.0129
#        Episode_Reward/rew_hovering: 0.0342
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 1.0000
#   Episode_Termination/bad_attitude: 0.0000
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 6556800
#                     Iteration time: 11.30s
#                       Time elapsed: 00:01:32
#                                ETA: 12:48:44
#
# ################################################################################
#                        Learning iteration 8/4001
#
#                        Computation: 72940 steps/s (collection: 11.039s, learning 0.198s)
#              Mean action noise std: 0.21
#           Mean value_function loss: 0.0576
#                Mean surrogate loss: 0.0019
#                  Mean entropy loss: -0.5460
#                        Mean reward: -1.49
#                Mean episode length: 57.66
#               Episode_Reward/alive: 0.0912
#         Episode_Reward/action_rate: -0.0003
#         Episode_Reward/terminating: -0.0160
#        Episode_Reward/rew_pos_diff: -0.0022
# Episode_Reward/rew_pos_diff_fine_grained: 0.0786
#    Episode_Reward/rew_lin_vel_diff: -0.3099
# Episode_Reward/rew_lin_vel_diff_fine_grained: 0.0023
#  Episode_Reward/rew_ang_vel_z_diff: -0.0002
# Episode_Reward/rew_ang_vel_z_diff_fine_grained: 0.0460
#       Episode_Reward/rew_roll_diff: -0.0058
# Episode_Reward/rew_roll_diff_fine_grained: 0.0129
#      Episode_Reward/rew_pitch_diff: -0.0058
# Episode_Reward/rew_pitch_diff_fine_grained: 0.0129
#        Episode_Reward/rew_hovering: 0.0342
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 1.0000
#   Episode_Termination/bad_attitude: 0.0000
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 7376400
#                     Iteration time: 11.24s
#                       Time elapsed: 00:01:43
#                                ETA: 12:46:14
#
# ################################################################################
#                        Learning iteration 9/4001
#
#                        Computation: 72792 steps/s (collection: 11.048s, learning 0.211s)
#              Mean action noise std: 0.21
#           Mean value_function loss: 0.0655
#                Mean surrogate loss: 0.0032
#                  Mean entropy loss: -0.5040
#                        Mean reward: -1.65
#                Mean episode length: 59.65
#               Episode_Reward/alive: 0.0913
#         Episode_Reward/action_rate: -0.0003
#         Episode_Reward/terminating: -0.0160
#        Episode_Reward/rew_pos_diff: -0.0022
# Episode_Reward/rew_pos_diff_fine_grained: 0.0786
#    Episode_Reward/rew_lin_vel_diff: -0.3097
# Episode_Reward/rew_lin_vel_diff_fine_grained: 0.0024
#  Episode_Reward/rew_ang_vel_z_diff: -0.0002
# Episode_Reward/rew_ang_vel_z_diff_fine_grained: 0.0460
#       Episode_Reward/rew_roll_diff: -0.0058
# Episode_Reward/rew_roll_diff_fine_grained: 0.0130
#      Episode_Reward/rew_pitch_diff: -0.0058
# Episode_Reward/rew_pitch_diff_fine_grained: 0.0131
#        Episode_Reward/rew_hovering: 0.0342
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 1.0000
#   Episode_Termination/bad_attitude: 0.0000
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 8196000
#                     Iteration time: 11.26s
#                       Time elapsed: 00:01:54
#                                ETA: 12:44:21
#
# ################################################################################
#                        Learning iteration 10/4001
#
#                        Computation: 72696 steps/s (collection: 11.037s, learning 0.237s)
#              Mean action noise std: 0.21
#           Mean value_function loss: 0.0466
#                Mean surrogate loss: 0.0015
#                  Mean entropy loss: -0.4833
#                        Mean reward: -1.38
#                Mean episode length: 58.30
#               Episode_Reward/alive: 0.0912
#         Episode_Reward/action_rate: -0.0003
#         Episode_Reward/terminating: -0.0160
#        Episode_Reward/rew_pos_diff: -0.0022
# Episode_Reward/rew_pos_diff_fine_grained: 0.0786
#    Episode_Reward/rew_lin_vel_diff: -0.3098
# Episode_Reward/rew_lin_vel_diff_fine_grained: 0.0024
#  Episode_Reward/rew_ang_vel_z_diff: -0.0002
# Episode_Reward/rew_ang_vel_z_diff_fine_grained: 0.0460
#       Episode_Reward/rew_roll_diff: -0.0058
# Episode_Reward/rew_roll_diff_fine_grained: 0.0128
#      Episode_Reward/rew_pitch_diff: -0.0058
# Episode_Reward/rew_pitch_diff_fine_grained: 0.0127
#        Episode_Reward/rew_hovering: 0.0342
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 1.0000
#   Episode_Termination/bad_attitude: 0.0000
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 9015600
#                     Iteration time: 11.27s
#                       Time elapsed: 00:02:06
#                                ETA: 12:42:52
#
# ################################################################################
#                        Learning iteration 11/4001
#
#                        Computation: 72882 steps/s (collection: 11.043s, learning 0.202s)
#              Mean action noise std: 0.22
#           Mean value_function loss: 0.0407
#                Mean surrogate loss: 0.0018
#                  Mean entropy loss: -0.4619
#                        Mean reward: -1.62
#                Mean episode length: 58.29
#               Episode_Reward/alive: 0.0912
#         Episode_Reward/action_rate: -0.0003
#         Episode_Reward/terminating: -0.0160
#        Episode_Reward/rew_pos_diff: -0.0022
# Episode_Reward/rew_pos_diff_fine_grained: 0.0786
#    Episode_Reward/rew_lin_vel_diff: -0.3094
# Episode_Reward/rew_lin_vel_diff_fine_grained: 0.0023
#  Episode_Reward/rew_ang_vel_z_diff: -0.0002
# Episode_Reward/rew_ang_vel_z_diff_fine_grained: 0.0460
# ...
#                       Time elapsed: 00:34:18
#                                ETA: 12:04:11
#
# ################################################################################
#                       Learning iteration 181/4001
#
#                        Computation: 70236 steps/s (collection: 11.433s, learning 0.236s)
#              Mean action noise std: 0.46
#           Mean value_function loss: 0.0021
#                Mean surrogate loss: -0.0002
#                  Mean entropy loss: 2.4666
#                        Mean reward: -0.06
#                Mean episode length: 61.40
#               Episode_Reward/alive: 0.0962
#         Episode_Reward/action_rate: -0.0006
#         Episode_Reward/terminating: -0.0160
#        Episode_Reward/rew_pos_diff: -0.0023
# Episode_Reward/rew_pos_diff_fine_grained: 0.0829
#    Episode_Reward/rew_lin_vel_diff: -0.3182
# Episode_Reward/rew_lin_vel_diff_fine_grained: 0.0027
#  Episode_Reward/rew_ang_vel_z_diff: -0.0011
# Episode_Reward/rew_ang_vel_z_diff_fine_grained: 0.0467
#       Episode_Reward/rew_roll_diff: -0.0018
# Episode_Reward/rew_roll_diff_fine_grained: 0.0620
#      Episode_Reward/rew_pitch_diff: -0.0054
# Episode_Reward/rew_pitch_diff_fine_grained: 0.0158
#        Episode_Reward/rew_hovering: 0.0376
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 1.0000
#   Episode_Termination/bad_attitude: 0.0000
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 149167200
#                     Iteration time: 11.67s
#                       Time elapsed: 00:34:29
#                                ETA: 12:04:06
#
# ################################################################################
#                       Learning iteration 182/4001
#
#                        Computation: 71203 steps/s (collection: 11.274s, learning 0.237s)
#              Mean action noise std: 0.46
#           Mean value_function loss: 0.0022
#                Mean surrogate loss: -0.0011
#                  Mean entropy loss: 2.4546
#                        Mean reward: -0.09
#                Mean episode length: 61.17
#               Episode_Reward/alive: 0.0961
#         Episode_Reward/action_rate: -0.0006
#         Episode_Reward/terminating: -0.0160
#        Episode_Reward/rew_pos_diff: -0.0023
# Episode_Reward/rew_pos_diff_fine_grained: 0.0828
#    Episode_Reward/rew_lin_vel_diff: -0.3179
# Episode_Reward/rew_lin_vel_diff_fine_grained: 0.0026
#  Episode_Reward/rew_ang_vel_z_diff: -0.0011
# Episode_Reward/rew_ang_vel_z_diff_fine_grained: 0.0467
#       Episode_Reward/rew_roll_diff: -0.0018
# Episode_Reward/rew_roll_diff_fine_grained: 0.0621
#      Episode_Reward/rew_pitch_diff: -0.0053
# Episode_Reward/rew_pitch_diff_fine_grained: 0.0163
#        Episode_Reward/rew_hovering: 0.0375
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 1.0000
#   Episode_Termination/bad_attitude: 0.0000
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 149986800
#                     Iteration time: 11.51s
#                       Time elapsed: 00:34:41
#                                ETA: 12:03:58
#
# ################################################################################
#                       Learning iteration 183/4001
#
#                        Computation: 71916 steps/s (collection: 11.177s, learning 0.220s)
#              Mean action noise std: 0.46
#           Mean value_function loss: 0.0036
#                Mean surrogate loss: -0.0006
#                  Mean entropy loss: 2.4526
#                        Mean reward: 0.05
#                Mean episode length: 59.93
#               Episode_Reward/alive: 0.0963
#         Episode_Reward/action_rate: -0.0006
#         Episode_Reward/terminating: -0.0160
#        Episode_Reward/rew_pos_diff: -0.0023
# Episode_Reward/rew_pos_diff_fine_grained: 0.0830
#    Episode_Reward/rew_lin_vel_diff: -0.3182
# Episode_Reward/rew_lin_vel_diff_fine_grained: 0.0027
#  Episode_Reward/rew_ang_vel_z_diff: -0.0011
# Episode_Reward/rew_ang_vel_z_diff_fine_grained: 0.0467
#       Episode_Reward/rew_roll_diff: -0.0018
# Episode_Reward/rew_roll_diff_fine_grained: 0.0621
#      Episode_Reward/rew_pitch_diff: -0.0054
# Episode_Reward/rew_pitch_diff_fine_grained: 0.0159
#        Episode_Reward/rew_hovering: 0.0377
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 1.0000
#   Episode_Termination/bad_attitude: 0.0000
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 150806400
#                     Iteration time: 11.40s
#                       Time elapsed: 00:34:52
#                                ETA: 12:03:47
#
# ################################################################################
#                       Learning iteration 184/4001
#
#                        Computation: 70644 steps/s (collection: 11.396s, learning 0.206s)
#              Mean action noise std: 0.46
#           Mean value_function loss: 0.0068
#                Mean surrogate loss: 0.0001
#                  Mean entropy loss: 2.4387
#                        Mean reward: 0.01
#                Mean episode length: 60.60
#               Episode_Reward/alive: 0.0961
#         Episode_Reward/action_rate: -0.0006
#         Episode_Reward/terminating: -0.0160
#        Episode_Reward/rew_pos_diff: -0.0023
# Episode_Reward/rew_pos_diff_fine_grained: 0.0829
#    Episode_Reward/rew_lin_vel_diff: -0.3174
# Episode_Reward/rew_lin_vel_diff_fine_grained: 0.0027
#  Episode_Reward/rew_ang_vel_z_diff: -0.0011
# Episode_Reward/rew_ang_vel_z_diff_fine_grained: 0.0467
#       Episode_Reward/rew_roll_diff: -0.0018
# Episode_Reward/rew_roll_diff_fine_grained: 0.0625
#      Episode_Reward/rew_pitch_diff: -0.0054
# Episode_Reward/rew_pitch_diff_fine_grained: 0.0158
#        Episode_Reward/rew_hovering: 0.0374
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 1.0000
#   Episode_Termination/bad_attitude: 0.0000
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 151626000
#                     Iteration time: 11.60s
#                       Time elapsed: 00:35:04
#                                ETA: 12:03:40
#
# ################################################################################
#                       Learning iteration 185/4001
#
#                        Computation: 70396 steps/s (collection: 11.427s, learning 0.216s)
#              Mean action noise std: 0.46
#           Mean value_function loss: 0.0155
#                Mean surrogate loss: 0.0021
#                  Mean entropy loss: 2.4359
#                        Mean reward: 0.03
#                Mean episode length: 61.24
#               Episode_Reward/alive: 0.0961
#         Episode_Reward/action_rate: -0.0006
#         Episode_Reward/terminating: -0.0160
#        Episode_Reward/rew_pos_diff: -0.0023
# Episode_Reward/rew_pos_diff_fine_grained: 0.0829
#    Episode_Reward/rew_lin_vel_diff: -0.3175
# Episode_Reward/rew_lin_vel_diff_fine_grained: 0.0027
#  Episode_Reward/rew_ang_vel_z_diff: -0.0011
# Episode_Reward/rew_ang_vel_z_diff_fine_grained: 0.0467
#       Episode_Reward/rew_roll_diff: -0.0018
# Episode_Reward/rew_roll_diff_fine_grained: 0.0626
#      Episode_Reward/rew_pitch_diff: -0.0054
# Episode_Reward/rew_pitch_diff_fine_grained: 0.0159
#        Episode_Reward/rew_hovering: 0.0374
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 1.0000
#   Episode_Termination/bad_attitude: 0.0000
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 152445600
#                     Iteration time: 11.64s
#                       Time elapsed: 00:35:16
#                                ETA: 12:03:34
#
# ################################################################################
#                       Learning iteration 186/4001
#
#                        Computation: 69699 steps/s (collection: 11.541s, learning 0.218s)
#              Mean action noise std: 0.46
#           Mean value_function loss: 0.0109
#                Mean surrogate loss: 0.0008
#                  Mean entropy loss: 2.4413
#                        Mean reward: 0.09
#                Mean episode length: 61.62
#               Episode_Reward/alive: 0.0963
#         Episode_Reward/action_rate: -0.0006
#         Episode_Reward/terminating: -0.0160
#        Episode_Reward/rew_pos_diff: -0.0023
# Episode_Reward/rew_pos_diff_fine_grained: 0.0830
#    Episode_Reward/rew_lin_vel_diff: -0.3183
# Episode_Reward/rew_lin_vel_diff_fine_grained: 0.0027
#  Episode_Reward/rew_ang_vel_z_diff: -0.0011
# Episode_Reward/rew_ang_vel_z_diff_fine_grained: 0.0468
#       Episode_Reward/rew_roll_diff: -0.0017
# Episode_Reward/rew_roll_diff_fine_grained: 0.0629
#      Episode_Reward/rew_pitch_diff: -0.0053
# Episode_Reward/rew_pitch_diff_fine_grained: 0.0162
#        Episode_Reward/rew_hovering: 0.0377
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 1.0000
#   Episode_Termination/bad_attitude: 0.0000
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 153265200
#                     Iteration time: 11.76s
#                       Time elapsed: 00:35:27
#                                ETA: 12:03:31
#
# ################################################################################
#                       Learning iteration 187/4001
#
#                        Computation: 72231 steps/s (collection: 11.141s, learning 0.206s)
#              Mean action noise std: 0.46
#           Mean value_function loss: 0.0081
#                Mean surrogate loss: 0.0020
#                  Mean entropy loss: 2.4494
#                        Mean reward: -0.04
#                Mean episode length: 61.24
#               Episode_Reward/alive: 0.0964
#         Episode_Reward/action_rate: -0.0006
#         Episode_Reward/terminating: -0.0160
#        Episode_Reward/rew_pos_diff: -0.0023
# Episode_Reward/rew_pos_diff_fine_grained: 0.0831
#    Episode_Reward/rew_lin_vel_diff: -0.3186
# Episode_Reward/rew_lin_vel_diff_fine_grained: 0.0027
#  Episode_Reward/rew_ang_vel_z_diff: -0.0011
# Episode_Reward/rew_ang_vel_z_diff_fine_grained: 0.0468
#       Episode_Reward/rew_roll_diff: -0.0018
# Episode_Reward/rew_roll_diff_fine_grained: 0.0627
#      Episode_Reward/rew_pitch_diff: -0.0053
# Episode_Reward/rew_pitch_diff_fine_grained: 0.0163
#        Episode_Reward/rew_hovering: 0.0377
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 1.0000
#   Episode_Termination/bad_attitude: 0.0000
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 154084800
#                     Iteration time: 11.35s
#                       Time elapsed: 00:35:39
#                                ETA: 12:03:19
#
# ################################################################################
#                       Learning iteration 188/4001
#
#                        Computation: 71088 steps/s (collection: 11.323s, learning 0.207s)
#              Mean action noise std: 0.46
#           Mean value_function loss: 0.0039
#                Mean surrogate loss: 0.0016
#                  Mean entropy loss: 2.4549
#                        Mean reward: 0.05
#                Mean episode length: 61.72
#               Episode_Reward/alive: 0.0965
#         Episode_Reward/action_rate: -0.0006
#         Episode_Reward/terminating: -0.0160
#        Episode_Reward/rew_pos_diff: -0.0023
# Episode_Reward/rew_pos_diff_fine_grained: 0.0832
#    Episode_Reward/rew_lin_vel_diff: -0.3184
# Episode_Reward/rew_lin_vel_diff_fine_grained: 0.0027
#  Episode_Reward/rew_ang_vel_z_diff: -0.0011
# Episode_Reward/rew_ang_vel_z_diff_fine_grained: 0.0469
#       Episode_Reward/rew_roll_diff: -0.0018
# Episode_Reward/rew_roll_diff_fine_grained: 0.0631
#      Episode_Reward/rew_pitch_diff: -0.0053
# Episode_Reward/rew_pitch_diff_fine_grained: 0.0166
#        Episode_Reward/rew_hovering: 0.0377
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 1.0000
#   Episode_Termination/bad_attitude: 0.0000
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 154904400
#                     Iteration time: 11.53s
#                       Time elapsed: 00:35:50
#                                ETA: 12:03:10
#
# ################################################################################
#                       Learning iteration 189/4001
#
#                        Computation: 72309 steps/s (collection: 11.133s, learning 0.202s)
#              Mean action noise std: 0.46
#           Mean value_function loss: 0.0025
#                Mean surrogate loss: -0.0004
#                  Mean entropy loss: 2.4653
#                        Mean reward: 0.11
#                Mean episode length: 61.77
#               Episode_Reward/alive: 0.0966
#         Episode_Reward/action_rate: -0.0006
#         Episode_Reward/terminating: -0.0160
#        Episode_Reward/rew_pos_diff: -0.0023
# Episode_Reward/rew_pos_diff_fine_grained: 0.0833
#    Episode_Reward/rew_lin_vel_diff: -0.3189
# Episode_Reward/rew_lin_vel_diff_fine_grained: 0.0027
#  Episode_Reward/rew_ang_vel_z_diff: -0.0011
# Episode_Reward/rew_ang_vel_z_diff_fine_grained: 0.0469
#       Episode_Reward/rew_roll_diff: -0.0018
# Episode_Reward/rew_roll_diff_fine_grained: 0.0631
#      Episode_Reward/rew_pitch_diff: -0.0054
# Episode_Reward/rew_pitch_diff_fine_grained: 0.0162
#        Episode_Reward/rew_hovering: 0.0379
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 1.0000
#   Episode_Termination/bad_attitude: 0.0000
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 155724000
#                     Iteration time: 11.33s
#                       Time elapsed: 00:36:02
#                                ETA: 12:02:58
#
# ################################################################################
#                       Learning iteration 190/4001
#
#                        Computation: 70991 steps/s (collection: 11.336s, learning 0.209s)
#              Mean action noise std: 0.46
#           Mean value_function loss: 0.0027
#                Mean surrogate loss: 0.0010
#                  Mean entropy loss: 2.4597
#                        Mean reward: 0.09
#                Mean episode length: 61.93
#               Episode_Reward/alive: 0.0966
#         Episode_Reward/action_rate: -0.0006
#         Episode_Reward/terminating: -0.0160
#        Episode_Reward/rew_pos_diff: -0.0023
# Episode_Reward/rew_pos_diff_fine_grained: 0.0833
#    Episode_Reward/rew_lin_vel_diff: -0.3187
# Episode_Reward/rew_lin_vel_diff_fine_grained: 0.0027
#  Episode_Reward/rew_ang_vel_z_diff: -0.0011
# Episode_Reward/rew_ang_vel_z_diff_fine_grained: 0.0469
#       Episode_Reward/rew_roll_diff: -0.0018
# Episode_Reward/rew_roll_diff_fine_grained: 0.0631
#      Episode_Reward/rew_pitch_diff: -0.0054
# Episode_Reward/rew_pitch_diff_fine_grained: 0.0164
#        Episode_Reward/rew_hovering: 0.0378
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 1.0000
#   Episode_Termination/bad_attitude: 0.0000
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 156543600
#                     Iteration time: 11.55s
#                       Time elapsed: 00:36:13
#                                ETA: 12:02:50

# %% [markdown]
# ``Análisis de los datos``

# %%
import csv
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

seed = 42
n=5

df_results_grid_actions = pd.read_csv(path_resultados+"/resultados_grid_PPO.csv")

# %%
def get_group(value):
    if f"_{experiment_name}" in value:
        return task_name

df_results_grid_actions["tarea"] = df_results_grid_actions["id_run_name"].apply(get_group)

# %%
df_copy = df_results_grid_actions.copy()
df_results_grid_actions.sample(n, random_state=seed)
# Out:
#               id_run_name  iteration     reward  max_reward  std_reward  \
# 0  ppo_random_command5_11          0  -2.420788   28.929943   11.037044
# 1  ppo_random_command5_11        100   0.069266   27.518446    6.282837
# 8  ppo_random_command5_11        800  96.731036  564.745300  118.674819
# 5  ppo_random_command5_11        500  45.248518  449.829529   95.919549
# 3  ppo_random_command5_11        300  18.817899  178.520355   46.518866
#
#    num_envs_train  mean_Episode_Reward/alive  mean_Episode_Reward/action_rate  \
# 0            8196                   0.297308                        -0.004342
# 1            8196                   0.187469                        -0.003808
# 8            8196                   1.936564                        -0.077961
# 5            8196                   1.280472                        -0.043600
# 3            8196                   0.584474                        -0.017433
#
#    mean_Episode_Reward/terminating  mean_Episode_Reward/rew_pos_diff  ...  \
# 0                        -0.018723                         -0.398911  ...
# 1                        -0.020000                         -0.209163  ...
# 8                        -0.019991                         -1.186707  ...
# 5                        -0.019999                         -0.841125  ...
# 3                        -0.020000                         -0.480084  ...
#
#    mean_Episode_Reward/rew_roll_diff  \
# 0                          -0.003313
# 1                          -0.002345
# 8                          -0.013668
# 5                          -0.007725
# 3                          -0.003992
#
#    mean_Episode_Reward/rew_roll_diff_fine_grained  \
# 0                                        0.004749
# 1                                        0.002929
# 8                                        0.050434
# 5                                        0.039402
# 3                                        0.017101
#
#    mean_Episode_Reward/rew_pitch_diff  \
# 0                           -0.002472
# 1                           -0.001550
# 8                           -0.012553
# 5                           -0.007925
# 3                           -0.003494
#
#    mean_Episode_Reward/rew_pitch_diff_fine_grained  \
# 0                                         0.005721
# 1                                         0.003735
# 8                                         0.052967
# 5                                         0.036866
# 3                                         0.017664
#
#    mean_Episode_Reward/rew_heading_alignment_fine_grained  \
# 0                                           0.021445
# 1                                           0.015808
# 8                                           0.179734
# 5                                           0.132950
# 3                                           0.088294
#
#    mean_Episode_Termination/time_out  \
# 0                           0.002533
# 1                           0.000000
# 8                           0.000429
# 5                           0.000004
# 3                           0.000000
#
#    mean_Episode_Termination/below_min_altitude  \
# 0                                     0.709719
# 1                                     0.295867
# 8                                     0.192017
# 5                                     0.251283
# 3                                     0.300422
#
#    mean_Episode_Termination/bad_attitude  \
# 0                               0.179223
# 1                               0.704133
# 8                               0.807554
# 5                               0.748713
# 3                               0.699578
#
#    mean_Episode_Termination/safety_shutdown     tarea
# 0                                       0.0  Command5
# 1                                       0.0  Command5
# 8                                       0.0  Command5
# 5                                       0.0  Command5
# 3                                       0.0  Command5
#
# [5 rows x 25 columns]

# %%
df_results_grid_actions.set_index(['tarea','id_run_name'],inplace=True)
top5 = (
    df_results_grid_actions.groupby(level="tarea")
      .apply(lambda g: g.sort_values("reward", ascending=False).head(5))
)

# Eliminar el nivel adicional que introduce groupby+apply
top5.index = top5.index.droplevel(0)

top5
# Out:
#                                  iteration      reward  max_reward  \
# tarea    id_run_name
# Command5 ppo_random_command5_11       1500  148.359473  820.291809
#          ppo_random_command5_11       1200  116.045358  747.452820
#          ppo_random_command5_11       1300   98.483841  758.258545
#          ppo_random_command5_11        800   96.731036  564.745300
#          ppo_random_command5_11       1400   88.791428  773.788818
#
#                                  std_reward  num_envs_train  \
# tarea    id_run_name
# Command5 ppo_random_command5_11  164.720314            8196
#          ppo_random_command5_11  155.794705            8196
#          ppo_random_command5_11  140.834091            8196
#          ppo_random_command5_11  118.674819            8196
#          ppo_random_command5_11  146.511362            8196
#
#                                  mean_Episode_Reward/alive  \
# tarea    id_run_name
# Command5 ppo_random_command5_11                   2.645218
#          ppo_random_command5_11                   2.575988
#          ppo_random_command5_11                   2.726593
#          ppo_random_command5_11                   1.936564
#          ppo_random_command5_11                   2.175446
#
#                                  mean_Episode_Reward/action_rate  \
# tarea    id_run_name
# Command5 ppo_random_command5_11                        -0.170349
#          ppo_random_command5_11                        -0.140482
#          ppo_random_command5_11                        -0.160750
#          ppo_random_command5_11                        -0.077961
#          ppo_random_command5_11                        -0.136057
#
#                                  mean_Episode_Reward/terminating  \
# tarea    id_run_name
# Command5 ppo_random_command5_11                        -0.019928
#          ppo_random_command5_11                        -0.019937
#          ppo_random_command5_11                        -0.019934
#          ppo_random_command5_11                        -0.019991
#          ppo_random_command5_11                        -0.019967
#
#                                  mean_Episode_Reward/rew_pos_diff  \
# tarea    id_run_name
# Command5 ppo_random_command5_11                         -1.648187
#          ppo_random_command5_11                         -1.556682
#          ppo_random_command5_11                         -1.733619
#          ppo_random_command5_11                         -1.186707
#          ppo_random_command5_11                         -1.334910
#
#                                  mean_Episode_Reward/rew_pos_diff_fine_grained  \
# tarea    id_run_name
# Command5 ppo_random_command5_11                                       0.961597
#          ppo_random_command5_11                                       0.979989
#          ppo_random_command5_11                                       0.983936
#          ppo_random_command5_11                                       0.703882
#          ppo_random_command5_11                                       0.796941
#
#                                  ...  \
# tarea    id_run_name             ...
# Command5 ppo_random_command5_11  ...
#          ppo_random_command5_11  ...
#          ppo_random_command5_11  ...
#          ppo_random_command5_11  ...
#          ppo_random_command5_11  ...
#
#                                  mean_Episode_Reward/rew_ang_vel_z_diff_fine_grained  \
# tarea    id_run_name
# Command5 ppo_random_command5_11                                           0.108495
#          ppo_random_command5_11                                           0.102867
#          ppo_random_command5_11                                           0.108917
#          ppo_random_command5_11                                           0.076896
#          ppo_random_command5_11                                           0.087503
#
#                                  mean_Episode_Reward/rew_roll_diff  \
# tarea    id_run_name
# Command5 ppo_random_command5_11                          -0.022003
#          ppo_random_command5_11                          -0.021002
#          ppo_random_command5_11                          -0.021859
#          ppo_random_command5_11                          -0.013668
#          ppo_random_command5_11                          -0.018389
#
#                                  mean_Episode_Reward/rew_roll_diff_fine_grained  \
# tarea    id_run_name
# Command5 ppo_random_command5_11                                        0.060470
#          ppo_random_command5_11                                        0.058830
#          ppo_random_command5_11                                        0.063690
#          ppo_random_command5_11                                        0.050434
#          ppo_random_command5_11                                        0.048583
#
#                                  mean_Episode_Reward/rew_pitch_diff  \
# tarea    id_run_name
# Command5 ppo_random_command5_11                           -0.015581
#          ppo_random_command5_11                           -0.016021
#          ppo_random_command5_11                           -0.017357
#          ppo_random_command5_11                           -0.012553
#          ppo_random_command5_11                           -0.013517
#
#                                  mean_Episode_Reward/rew_pitch_diff_fine_grained  \
# tarea    id_run_name
# Command5 ppo_random_command5_11                                         0.081116
#          ppo_random_command5_11                                         0.073842
#          ppo_random_command5_11                                         0.078244
#          ppo_random_command5_11                                         0.052967
#          ppo_random_command5_11                                         0.063434
#
#                                  mean_Episode_Reward/rew_heading_alignment_fine_grained  \
# tarea    id_run_name
# Command5 ppo_random_command5_11                                           0.318173
#          ppo_random_command5_11                                           0.274126
#          ppo_random_command5_11                                           0.322139
#          ppo_random_command5_11                                           0.179734
#          ppo_random_command5_11                                           0.239702
#
#                                  mean_Episode_Termination/time_out  \
# tarea    id_run_name
# Command5 ppo_random_command5_11                           0.003009
#          ppo_random_command5_11                           0.002590
#          ppo_random_command5_11                           0.003723
#          ppo_random_command5_11                           0.000429
#          ppo_random_command5_11                           0.001653
#
#                                  mean_Episode_Termination/below_min_altitude  \
# tarea    id_run_name
# Command5 ppo_random_command5_11                                     0.103489
#          ppo_random_command5_11                                     0.152105
#          ppo_random_command5_11                                     0.121192
#          ppo_random_command5_11                                     0.192017
#          ppo_random_command5_11                                     0.094360
#
#                                  mean_Episode_Termination/bad_attitude  \
# tarea    id_run_name
# Command5 ppo_random_command5_11                               0.893503
#          ppo_random_command5_11                               0.845305
#          ppo_random_command5_11                               0.875084
#          ppo_random_command5_11                               0.807554
#          ppo_random_command5_11                               0.903987
#
#                                  mean_Episode_Termination/safety_shutdown
# tarea    id_run_name
# Command5 ppo_random_command5_11                                       0.0
#          ppo_random_command5_11                                       0.0
#          ppo_random_command5_11                                       0.0
#          ppo_random_command5_11                                       0.0
#          ppo_random_command5_11                                       0.0
#
# [5 rows x 23 columns]

# %%
mean_rewards = df_results_grid_actions.groupby(["tarea", "id_run_name"])["reward"].mean()

for tarea, subdf in mean_rewards.groupby(level="tarea"):
    plt.figure(figsize=(12,5))
    
    # Convertir a DataFrame y resetear index para graficar
    plot_df = subdf.reset_index()
    plot_df = plot_df.sort_values("reward", ascending=False)
    
    plt.bar(plot_df["id_run_name"], plot_df["reward"])
    plt.title(f"Reward media por modelo - {tarea}")
    plt.xlabel("id_run_name")
    plt.ylabel("Reward media")
    plt.xticks(rotation=90)
    plt.tight_layout()
    plt.show()

# %%
df_callbacks = pd.read_csv(path_resultados+"/reward_best_models.csv",index_col='id_run_name')
top5_models = df_callbacks.nlargest(5,columns="reward")
top5_models
# Out:
#                         iteration      reward  max_reward  std_reward  \
# id_run_name
# ppo_random_command5_11       1289  154.030015  616.214417   170.69982
#
#                         num_envs_train  mean_Episode_Reward/alive  \
# id_run_name
# ppo_random_command5_11            8196                    2.90881
#
#                         mean_Episode_Reward/action_rate  \
# id_run_name
# ppo_random_command5_11                        -0.170342
#
#                         mean_Episode_Reward/terminating  \
# id_run_name
# ppo_random_command5_11                        -0.019911
#
#                         mean_Episode_Reward/rew_pos_diff  \
# id_run_name
# ppo_random_command5_11                         -1.788109
#
#                         mean_Episode_Reward/rew_pos_diff_fine_grained  ...  \
# id_run_name                                                            ...
# ppo_random_command5_11                                       1.092515  ...
#
#                         mean_Episode_Reward/rew_ang_vel_z_diff_fine_grained  \
# id_run_name
# ppo_random_command5_11                                           0.118949
#
#                         mean_Episode_Reward/rew_roll_diff  \
# id_run_name
# ppo_random_command5_11                          -0.023586
#
#                         mean_Episode_Reward/rew_roll_diff_fine_grained  \
# id_run_name
# ppo_random_command5_11                                        0.067315
#
#                         mean_Episode_Reward/rew_pitch_diff  \
# id_run_name
# ppo_random_command5_11                           -0.017664
#
#                         mean_Episode_Reward/rew_pitch_diff_fine_grained  \
# id_run_name
# ppo_random_command5_11                                         0.085878
#
#                         mean_Episode_Reward/rew_heading_alignment_fine_grained  \
# id_run_name
# ppo_random_command5_11                                           0.349344
#
#                         mean_Episode_Termination/time_out  \
# id_run_name
# ppo_random_command5_11                           0.005447
#
#                         mean_Episode_Termination/below_min_altitude  \
# id_run_name
# ppo_random_command5_11                                     0.144526
#
#                         mean_Episode_Termination/bad_attitude  \
# id_run_name
# ppo_random_command5_11                               0.850027
#
#                         mean_Episode_Termination/safety_shutdown
# id_run_name
# ppo_random_command5_11                                       0.0
#
# [1 rows x 23 columns]

# %% [markdown]
# Graficamos cómo fue el entrenamiento para los 5 mejores modelos según los callbacks:

# %%
import matplotlib.pyplot as plt
import numpy as np

# Aseguramos que `top5_auc` tenga 'tarea' e 'id_run_name' como columnas, no solo en el índice
df_callbacks = pd.read_csv(path_resultados+"/reward_best_models.csv",index_col='id_run_name')
top5_models = df_callbacks.nlargest(5,columns="reward")
top5_reset = top5_models.reset_index()
top5_reset["tarea"] = top5_reset["id_run_name"].apply(get_group)


# Convertir el índice jerárquico en columnas (para acceder a 'tarea' y 'id_run_name')
df_copy_reset = df_copy.reset_index()

# Unimos `top5_auc_reset` con `df_copy_reset` en las columnas comunes: 'tarea' y 'id_run_name'
merged_df = pd.merge(df_copy_reset, top5_reset[['tarea', 'id_run_name']], on=['tarea', 'id_run_name'], how='inner')

# Usamos una lista de colores para asignar un color diferente a cada modelo
colors = plt.cm.viridis(np.linspace(0, 1, len(merged_df['id_run_name'].unique())))

# Ahora, procedemos a graficar
for tarea, task_df in merged_df.groupby('tarea'):
    plt.figure(figsize=(10, 6))
    
    # Iteramos sobre los modelos (id_run_name) para esta tarea
    for i, (run_name, subdf) in enumerate(task_df.groupby('id_run_name')):
        # Graficamos la evolución de la recompensa a lo largo de las iteraciones
        plt.plot(subdf['iteration'], subdf['reward'], label=run_name, color=colors[i])
    
    plt.xlabel('Iteración')
    plt.ylabel('Reward')
    plt.title(f'Evolución de la Recompensa - Tarea: {tarea}')
    plt.legend(title="Modelos", bbox_to_anchor=(1.05, 1), loc='upper left')
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ``Cojo los 5 modelos mejores de todos de los callbacks``

# %%
import os
df_callbacks = pd.read_csv(path_resultados+"/reward_best_models.csv",index_col='id_run_name')
top5_models = df_callbacks.nlargest(5,columns="reward")

powershell_script_test = os.path.join(cfg_dir, "run_tests.ps1")

with open(powershell_script_test, "w") as f:
    f.write("$ErrorActionPreference = 'Stop'\n\n")
    
    for run_id, row in top5_models.iterrows():
        # Extraemos el número del id (ej: de 'ppo_random_hover_4' sacamos '4')
        experiment_number = run_id.split('_')[-1]
        
        # Construimos la ruta exacta del checkpoint
        # Nota: Asegúrate de que path_resultados termine en / o usar os.path.join
        checkpoint_path = f"{path_resultados}/best_model_{run_id}_{int(row['num_envs_train'])}.pt"
        f.write(f'Write-Host "Ejecutando Test final para Experimento {experiment_number}..."\n')
        
        # Usamos el experiment_number extraído para la tarea (--task)
        # Se añaden flags típicos de play.py: --num_envs 1 y se quita --headless para ver el visualizador
        f.write(f'& "{isaaclab_bat}" -p "{play_script}" '
                f'--task {id_task}-{experiment_number} '
                f'--num_envs 1 '
                f' --headless '
                f'--checkpoint "{checkpoint_path}"\n\n')
        
print(f"Script de test generado en: {powershell_script_test}")
# Out:
# Script de test generado en: C:/Users/Teresa/Documents/GitHub/navsim/isaac_lab/aerotaxi/env_command/env_9/grid_hiperparametros/cfg_files\run_tests.ps1

# %% [markdown]
# ### Test con 1 entorno

# %%
# Ejecuta el entrenamiento de forma automática
# !powershell -ExecutionPolicy Bypass -File "{powershell_script}"
import subprocess
import sys

# Ruta al script que generaste
powershell_script_path = powershell_script_test 

print(f"Iniciando ejecución de: {powershell_script_path}\n")

# Ejecutamos el proceso capturando la salida en tiempo real
process = subprocess.Popen(
    ["powershell.exe", "-ExecutionPolicy", "Bypass", "-File", powershell_script_path],
    stdout=subprocess.PIPE,
    stderr=subprocess.STDOUT, # Redirigimos errores a la salida estándar para verlos
    text=True,
    bufsize=1
)

# Leemos la salida línea a línea conforme se genera
try:
    for line in process.stdout:
        print(line, end="") # Imprime la salida de PowerShell en la celda
        sys.stdout.flush()   # Fuerza a Jupyter a mostrar la línea inmediatamente
except KeyboardInterrupt:
    process.kill()
    print("\nEntrenamiento cancelado por el usuario.")

process.wait()
print("\n--- Todos los experimentos de test han finalizado ---")
# Out:
# Iniciando ejecución de: C:/Users/Teresa/Documents/GitHub/navsim/isaac_lab/aerotaxi/env_command/env_9/grid_hiperparametros/cfg_files\run_tests.ps1
#
# Ejecutando Test final para Experimento 11...
# [INFO] Using python from: C:\Users\Teresa\miniconda3\envs\env_isaaclab\python.exe
# [INFO][AppLauncher]: Using device: cuda:0
# [INFO][AppLauncher]: Loading experience file: C:\Users\Teresa\miniconda3\envs\env_isaaclab\Lib\site-packages\isaaclab\apps\isaaclab.python.headless.kit
# Loading user config located at: 'c:/users/teresa/miniconda3/envs/env_isaaclab/lib/site-packages/isaacsim/kit/data/Kit/Isaac-Sim/5.1/user.config.json'
# [Info] [carb] Logging to file: c:/users/teresa/miniconda3/envs/env_isaaclab/lib/site-packages/isaacsim/kit/logs/Kit/Isaac-Sim/5.1/kit_20260205_114728.log
# 2026-02-05T10:47:28Z s] [Warning] [omni.usd_config.extension] Enable omni.materialx.libs extension to use MaterialX
# 2026-02-05T10:47:29Z s] [Warning] [carb] Acquiring non optional plugin interface which is not listed as dependency: [omni::physx::IPhysxBenchmarks v1.0] (plugin: <default plugin>), by client: omni.physics.physx.plugin. Add it to CARB_PLUGIN_IMPL_DEPS() macro of a client.
# 2026-02-05T10:47:29Z s] [Warning] [omni.isaac.dynamic_control] omni.isaac.dynamic_control is deprecated as of Isaac Sim 4.5. No action is needed from end-users.
# 2026-02-05T10:47:31Z [2,717ms] [Warning] [gpu.foundation.plugin] Skipping unsupported non-NVIDIA GPU: AMD Radeon(TM) Graphics
# 2026-02-05T10:47:31Z [2,718ms] [Warning] [gpu.foundation.plugin] Skipping unsupported non-NVIDIA GPU: AMD Radeon(TM) Graphics
#
# |---------------------------------------------------------------------------------------------|
# | Driver Version: 581.29        | Graphics API: D3D12
# |=============================================================================================|
# | GPU | Name                             | Active | LDA | GPU Memory | Vendor-ID | LUID       |
# |     |                                  |        |     |            | Device-ID | UUID       |
# |     |                                  |        |     |            | Bus-ID    |            |
# |---------------------------------------------------------------------------------------------|
# | 0   | NVIDIA GeForce RTX 5080          | Yes: 0 |     | 15889   MB | 10de      | fa570100.. |
# |     |                                  |        |     |            | 2c02      | 0          |
# |     |                                  |        |     |            | 1         |            |
# |---------------------------------------------------------------------------------------------|
# | 1   | AMD Radeon(TM) Graphics          |        |     | 1995    MB | 1002      | d7690100.. |
# |     |                                  |        |     |            | 13c0      | 0          |
# |     |                                  |        |     |            | N/A       |            |
# |=============================================================================================|
# | OS: Windows 11 Pro, Version: 10.0 (24H2), Build: 26100, Kernel: 10.0.26100.7623
# | Processor: AMD Ryzen 9 9950X 16-Core Processor
# | Cores: 16 | Logical Cores: 32
# |---------------------------------------------------------------------------------------------|
# | Total Memory (MB): 128627 | Free Memory: 94896
# | Total Page/Swap (MB): 136819 | Free Page/Swap: 92165
# |---------------------------------------------------------------------------------------------|
# C:\Users\Teresa\Documents\GitHub\navsim\isaac_lab\aerotaxi\env_command\env_9\flight_plan.py:29: UserWarning: Treat the new Tool classes introduced in v1.5 as experimental for now; the API and rcParam may change in future versions.
#   plt.rcParams["toolbar"] = "toolmanager"
# [INFO]: Parsing configuration from: aerotaxi.env_command.env_9.env:UAVEnvCfg
# [INFO]: Parsing configuration from: aerotaxi.env_command.env_9.grid_hiperparametros.cfg_files.ppo_random_command5_11_cfg:Command5PPORunnerCfg
# [INFO] Loading experiment from directory: C:\Users\Teresa\Documents\GitHub\navsim\isaac_lab\aerotaxi\env_command\env_9\logs\rsl_rl\command5
# Setting seed: 42
# [INFO]: Base environment:
# 	Environment device    : cuda:0
# 	Environment seed      : 42
# 	Physics step-size     : 0.005
# 	Rendering step-size   : 0.02
# 	Environment step-size : 0.02
# [INFO]: Time taken for scene creation : 1.011839 seconds
# [INFO]: Scene manager:  <class InteractiveScene>
# 	Number of environments: 1
# 	Environment spacing   : 100.0
# 	Source prim name      : /World/envs/env_0
# 	Global prim paths     : []
# 	Replicate physics     : False
# [INFO]: Starting the simulation. This may take a few seconds. Please wait...
# [INFO]: Time taken for simulation start : 0.251751 seconds
# [INFO] Command Manager:  <CommandManager> contains 1 active terms.
# +--------------------------------------+
# |         Active Command Terms         |
# +-------+-------------+----------------+
# | Index | Name        |      Type      |
# +-------+-------------+----------------+
# |   0   | vel_command | UAVcommandTerm |
# +-------+-------------+----------------+
#
# [INFO] Event Manager:  <EventManager> contains 1 active terms.
# +-----------------------------------+
# | Active Event Terms in Mode: 'reset' |
# +----------+------------------------+
# |  Index   | Name                   |
# +----------+------------------------+
# |    0     | reset_pos              |
# |    1     | randomize_mass         |
# |    2     | randomize_wind         |
# +----------+------------------------+
#
# [INFO] Recorder Manager:  <RecorderManager> contains 0 active terms.
# +---------------------+
# | Active Recorder Terms |
# +-----------+---------+
# |   Index   | Name    |
# +-----------+---------+
# +-----------+---------+
#
# [INFO] Action Manager:  <ActionManager> contains 1 active terms.
# +-----------------------------------+
# |   Active Action Terms (shape: 4)  |
# +--------+-------------+------------+
# | Index  | Name        |  Dimension |
# +--------+-------------+------------+
# |   0    | rotors_vel  |          4 |
# +--------+-------------+------------+
#
# [INFO] Observation Manager: <ObservationManager> contains 1 groups.
# +----------------------------------------------------+
# | Active Observation Terms in Group: 'policy' (shape: (11,)) |
# +---------------+--------------------+---------------+
# |     Index     | Name               |     Shape     |
# +---------------+--------------------+---------------+
# |       0       | pos                |      (3,)     |
# |       1       | lin_vel            |      (3,)     |
# |       2       | ang_vel            |      (3,)     |
# |       3       | roll               |      (1,)     |
# |       4       | pitch              |      (1,)     |
# +---------------+--------------------+---------------+
#
# [INFO] Termination Manager:  <TerminationManager> contains 4 active terms.
# +---------------------------------------+
# |        Active Termination Terms       |
# +-------+--------------------+----------+
# | Index | Name               | Time Out |
# +-------+--------------------+----------+
# |   0   | time_out           |   True   |
# |   1   | below_min_altitude |  False   |
# |   2   | bad_attitude       |  False   |
# |   3   | safety_shutdown    |  False   |
# +-------+--------------------+----------+
#
# [INFO] Reward Manager:  <RewardManager> contains 14 active terms.
# +-----------------------------------------------------+
# |                 Active Reward Terms                 |
# +-------+------------------------------------+--------+
# | Index | Name                               | Weight |
# +-------+------------------------------------+--------+
# |   0   | alive                              |   15.0 |
# |   1   | action_rate                        |   -0.1 |
# |   2   | terminating                        |  -50.0 |
# |   3   | rew_pos_diff                       |   -0.5 |
# |   4   | rew_pos_diff_fine_grained          |   15.0 |
# |   5   | rew_lin_vel_diff                   |   -0.1 |
# |   6   | rew_lin_vel_diff_fine_grained      |    2.0 |
# |   7   | rew_ang_vel_z_diff                 |   -1.0 |
# |   8   | rew_ang_vel_z_diff_fine_grained    |    1.0 |
# |   9   | rew_roll_diff                      |   -0.5 |
# |   10  | rew_roll_diff_fine_grained         |    1.0 |
# |   11  | rew_pitch_diff                     |   -0.5 |
# |   12  | rew_pitch_diff_fine_grained        |    1.0 |
# |   13  | rew_heading_alignment_fine_grained |    5.0 |
# +-------+------------------------------------+--------+
#
# [INFO] Curriculum Manager:  <CurriculumManager> contains 0 active terms.
# +----------------------+
# | Active Curriculum Terms |
# +-----------+----------+
# |   Index   | Name     |
# +-----------+----------+
# +-----------+----------+
#
# [INFO]: Completed setting up the environment...
# 2026-02-05T10:47:33Z [5,684ms] [Warning] [omni.physx.fabric.plugin] FabricManager::initializePointInstancer mismatched prototypes on point instancer: /Visuals/target_commands.
# [INFO]: Loading model checkpoint from: C:\Users\Teresa\Documents\GitHub\navsim\tmp\tmpTeresa\resultados_grid_command_v5\best_model_ppo_random_command5_11_8196.pt
# C:\Users\Teresa\miniconda3\envs\env_isaaclab\Lib\site-packages\rsl_rl\utils\utils.py:244: UserWarning: The observation configuration dictionary 'obs_groups' must contain the 'policy' key. As an observation group with the name 'policy' was found, this is assumed to be the observation set. Consider adding the 'policy' key to the 'obs_groups' dictionary for clarity. This behavior will be removed in a future version.
#   warnings.warn(
# C:\Users\Teresa\miniconda3\envs\env_isaaclab\Lib\site-packages\rsl_rl\utils\utils.py:290: UserWarning: The observation configuration dictionary 'obs_groups' must contain the 'critic' key. As the configuration for 'critic' is missing, the observations from the 'policy' set are used. Consider adding the 'critic' key to the 'obs_groups' dictionary for clarity. This behavior will be removed in a future version.
#   warnings.warn(
# --------------------------------------------------------------------------------
# Resolved observation sets:
# 	 policy :  ['policy']
# 	 critic :  ['policy']
# --------------------------------------------------------------------------------
# Actor MLP: MLP(
#   (0): Linear(in_features=11, out_features=64, bias=True)
#   (1): ELU(alpha=1.0)
#   (2): Linear(in_features=64, out_features=64, bias=True)
#   (3): ELU(alpha=1.0)
#   (4): Linear(in_features=64, out_features=4, bias=True)
# )
# Critic MLP: MLP(
#   (0): Linear(in_features=11, out_features=128, bias=True)
#   (1): ELU(alpha=1.0)
#   (2): Linear(in_features=128, out_features=128, bias=True)
#   (3): ELU(alpha=1.0)
#   (4): Linear(in_features=128, out_features=1, bias=True)
# )
#
# --- Todos los experimentos de test han finalizado ---

# %%
df_callbacks = pd.read_csv(path_resultados+"/reward_best_models.csv",index_col='id_run_name')
top5_models = df_callbacks.nlargest(5,columns="reward")

# %%
df_rewards_play = pd.read_csv(path_resultados+'/rewards_play_PPO.csv')

# %% [markdown]
# ### Test con 64 entornos

# %%
import os
df_callbacks = pd.read_csv(path_resultados+"/reward_best_models.csv",index_col='id_run_name')
top5_models = df_callbacks.nlargest(5,columns="reward")

powershell_script_test_2 = os.path.join(cfg_dir, "run_tests_2.ps1")

with open(powershell_script_test_2, "w") as f:
    f.write("$ErrorActionPreference = 'Stop'\n\n")
    
    for run_id, row in top5_models.iterrows():
        # Extraemos el número del id (ej: de 'ppo_random_hover_4' sacamos '4')
        experiment_number = run_id.split('_')[-1]
        
        # Construimos la ruta exacta del checkpoint
        # Nota: Asegúrate de que path_resultados termine en / o usar os.path.join
        checkpoint_path = f"{path_resultados}/best_model_{run_id}_{int(row['num_envs_train'])}.pt"
        f.write(f'Write-Host "Ejecutando Test final para Experimento {experiment_number}..."\n')
        
        # Usamos el experiment_number extraído para la tarea (--task)
        # Se añaden flags típicos de play.py: --num_envs 1 y se quita --headless para ver el visualizador
        f.write(f'& "{isaaclab_bat}" -p "{play_script}" '
                f'--task {id_task}-{experiment_number} '
                f'--num_envs 64 '
                f' --headless '
                f'--checkpoint "{checkpoint_path}"\n\n')
        
print(f"Script de test generado en: {powershell_script_test_2}")
# Out:
# Script de test generado en: C:/Users/Teresa/Documents/GitHub/navsim/isaac_lab/aerotaxi/env_command/env_9/grid_hiperparametros/cfg_files\run_tests_2.ps1

# %%
# Ejecuta el entrenamiento de forma automática
# !powershell -ExecutionPolicy Bypass -File "{powershell_script}"
import subprocess
import sys

# Ruta al script que generaste
powershell_script_path = powershell_script_test_2 

print(f"Iniciando ejecución de: {powershell_script_path}\n")

# Ejecutamos el proceso capturando la salida en tiempo real
process = subprocess.Popen(
    ["powershell.exe", "-ExecutionPolicy", "Bypass", "-File", powershell_script_path],
    stdout=subprocess.PIPE,
    stderr=subprocess.STDOUT, # Redirigimos errores a la salida estándar para verlos
    text=True,
    bufsize=1
)

# Leemos la salida línea a línea conforme se genera
try:
    for line in process.stdout:
        print(line, end="") # Imprime la salida de PowerShell en la celda
        sys.stdout.flush()   # Fuerza a Jupyter a mostrar la línea inmediatamente
except KeyboardInterrupt:
    process.kill()
    print("\nEntrenamiento cancelado por el usuario.")

process.wait()
print("\n--- Todos los experimentos de test han finalizado ---")
# Out:
# Iniciando ejecución de: C:/Users/Teresa/Documents/GitHub/navsim/isaac_lab/aerotaxi/env_command/env_9/grid_hiperparametros/cfg_files\run_tests_2.ps1
#
# Ejecutando Test final para Experimento 11...
# [INFO] Using python from: C:\Users\Teresa\miniconda3\envs\env_isaaclab\python.exe
# [INFO][AppLauncher]: Using device: cuda:0
# [INFO][AppLauncher]: Loading experience file: C:\Users\Teresa\miniconda3\envs\env_isaaclab\Lib\site-packages\isaaclab\apps\isaaclab.python.headless.kit
# Loading user config located at: 'c:/users/teresa/miniconda3/envs/env_isaaclab/lib/site-packages/isaacsim/kit/data/Kit/Isaac-Sim/5.1/user.config.json'
# [Info] [carb] Logging to file: c:/users/teresa/miniconda3/envs/env_isaaclab/lib/site-packages/isaacsim/kit/logs/Kit/Isaac-Sim/5.1/kit_20260205_115133.log
# 2026-02-05T10:51:34Z s] [Warning] [omni.usd_config.extension] Enable omni.materialx.libs extension to use MaterialX
# 2026-02-05T10:51:34Z s] [Warning] [carb] Acquiring non optional plugin interface which is not listed as dependency: [omni::physx::IPhysxBenchmarks v1.0] (plugin: <default plugin>), by client: omni.physics.physx.plugin. Add it to CARB_PLUGIN_IMPL_DEPS() macro of a client.
# 2026-02-05T10:51:34Z s] [Warning] [omni.isaac.dynamic_control] omni.isaac.dynamic_control is deprecated as of Isaac Sim 4.5. No action is needed from end-users.
# 2026-02-05T10:51:36Z [2,374ms] [Warning] [gpu.foundation.plugin] Skipping unsupported non-NVIDIA GPU: AMD Radeon(TM) Graphics
# 2026-02-05T10:51:36Z [2,375ms] [Warning] [gpu.foundation.plugin] Skipping unsupported non-NVIDIA GPU: AMD Radeon(TM) Graphics
#
# |---------------------------------------------------------------------------------------------|
# | Driver Version: 581.29        | Graphics API: D3D12
# |=============================================================================================|
# | GPU | Name                             | Active | LDA | GPU Memory | Vendor-ID | LUID       |
# |     |                                  |        |     |            | Device-ID | UUID       |
# |     |                                  |        |     |            | Bus-ID    |            |
# |---------------------------------------------------------------------------------------------|
# | 0   | NVIDIA GeForce RTX 5080          | Yes: 0 |     | 15889   MB | 10de      | fa570100.. |
# |     |                                  |        |     |            | 2c02      | 0          |
# |     |                                  |        |     |            | 1         |            |
# |---------------------------------------------------------------------------------------------|
# | 1   | AMD Radeon(TM) Graphics          |        |     | 1995    MB | 1002      | d7690100.. |
# |     |                                  |        |     |            | 13c0      | 0          |
# |     |                                  |        |     |            | N/A       |            |
# |=============================================================================================|
# | OS: Windows 11 Pro, Version: 10.0 (24H2), Build: 26100, Kernel: 10.0.26100.7623
# | Processor: AMD Ryzen 9 9950X 16-Core Processor
# | Cores: 16 | Logical Cores: 32
# |---------------------------------------------------------------------------------------------|
# | Total Memory (MB): 128627 | Free Memory: 94331
# | Total Page/Swap (MB): 136819 | Free Page/Swap: 91707
# |---------------------------------------------------------------------------------------------|
# C:\Users\Teresa\Documents\GitHub\navsim\isaac_lab\aerotaxi\env_command\env_9\flight_plan.py:29: UserWarning: Treat the new Tool classes introduced in v1.5 as experimental for now; the API and rcParam may change in future versions.
#   plt.rcParams["toolbar"] = "toolmanager"
# [INFO]: Parsing configuration from: aerotaxi.env_command.env_9.env:UAVEnvCfg
# [INFO]: Parsing configuration from: aerotaxi.env_command.env_9.grid_hiperparametros.cfg_files.ppo_random_command5_11_cfg:Command5PPORunnerCfg
# [INFO] Loading experiment from directory: C:\Users\Teresa\Documents\GitHub\navsim\isaac_lab\aerotaxi\env_command\env_9\logs\rsl_rl\command5
# Setting seed: 42
# [INFO]: Base environment:
# 	Environment device    : cuda:0
# 	Environment seed      : 42
# 	Physics step-size     : 0.005
# 	Rendering step-size   : 0.02
# 	Environment step-size : 0.02
# [INFO]: Time taken for scene creation : 1.099795 seconds
# [INFO]: Scene manager:  <class InteractiveScene>
# 	Number of environments: 64
# 	Environment spacing   : 100.0
# 	Source prim name      : /World/envs/env_0
# 	Global prim paths     : []
# 	Replicate physics     : False
# [INFO]: Starting the simulation. This may take a few seconds. Please wait...
# [INFO]: Time taken for simulation start : 0.282446 seconds
# [INFO] Command Manager:  <CommandManager> contains 1 active terms.
# +--------------------------------------+
# |         Active Command Terms         |
# +-------+-------------+----------------+
# | Index | Name        |      Type      |
# +-------+-------------+----------------+
# |   0   | vel_command | UAVcommandTerm |
# +-------+-------------+----------------+
#
# [INFO] Event Manager:  <EventManager> contains 1 active terms.
# +-----------------------------------+
# | Active Event Terms in Mode: 'reset' |
# +----------+------------------------+
# |  Index   | Name                   |
# +----------+------------------------+
# |    0     | reset_pos              |
# |    1     | randomize_mass         |
# |    2     | randomize_wind         |
# +----------+------------------------+
#
# [INFO] Recorder Manager:  <RecorderManager> contains 0 active terms.
# +---------------------+
# | Active Recorder Terms |
# +-----------+---------+
# |   Index   | Name    |
# +-----------+---------+
# +-----------+---------+
#
# [INFO] Action Manager:  <ActionManager> contains 1 active terms.
# +-----------------------------------+
# |   Active Action Terms (shape: 4)  |
# +--------+-------------+------------+
# | Index  | Name        |  Dimension |
# +--------+-------------+------------+
# |   0    | rotors_vel  |          4 |
# +--------+-------------+------------+
#
# [INFO] Observation Manager: <ObservationManager> contains 1 groups.
# +----------------------------------------------------+
# | Active Observation Terms in Group: 'policy' (shape: (11,)) |
# +---------------+--------------------+---------------+
# |     Index     | Name               |     Shape     |
# +---------------+--------------------+---------------+
# |       0       | pos                |      (3,)     |
# |       1       | lin_vel            |      (3,)     |
# |       2       | ang_vel            |      (3,)     |
# |       3       | roll               |      (1,)     |
# |       4       | pitch              |      (1,)     |
# +---------------+--------------------+---------------+
#
# [INFO] Termination Manager:  <TerminationManager> contains 4 active terms.
# +---------------------------------------+
# |        Active Termination Terms       |
# +-------+--------------------+----------+
# | Index | Name               | Time Out |
# +-------+--------------------+----------+
# |   0   | time_out           |   True   |
# |   1   | below_min_altitude |  False   |
# |   2   | bad_attitude       |  False   |
# |   3   | safety_shutdown    |  False   |
# +-------+--------------------+----------+
#
# [INFO] Reward Manager:  <RewardManager> contains 14 active terms.
# +-----------------------------------------------------+
# |                 Active Reward Terms                 |
# +-------+------------------------------------+--------+
# | Index | Name                               | Weight |
# +-------+------------------------------------+--------+
# |   0   | alive                              |   15.0 |
# |   1   | action_rate                        |   -0.1 |
# |   2   | terminating                        |  -50.0 |
# |   3   | rew_pos_diff                       |   -0.5 |
# |   4   | rew_pos_diff_fine_grained          |   15.0 |
# |   5   | rew_lin_vel_diff                   |   -0.1 |
# |   6   | rew_lin_vel_diff_fine_grained      |    2.0 |
# |   7   | rew_ang_vel_z_diff                 |   -1.0 |
# |   8   | rew_ang_vel_z_diff_fine_grained    |    1.0 |
# |   9   | rew_roll_diff                      |   -0.5 |
# |   10  | rew_roll_diff_fine_grained         |    1.0 |
# |   11  | rew_pitch_diff                     |   -0.5 |
# |   12  | rew_pitch_diff_fine_grained        |    1.0 |
# |   13  | rew_heading_alignment_fine_grained |    5.0 |
# +-------+------------------------------------+--------+
#
# [INFO] Curriculum Manager:  <CurriculumManager> contains 0 active terms.
# +----------------------+
# | Active Curriculum Terms |
# +-----------+----------+
# |   Index   | Name     |
# +-----------+----------+
# +-----------+----------+
#
# [INFO]: Completed setting up the environment...
# 2026-02-05T10:51:39Z [5,393ms] [Warning] [omni.physx.fabric.plugin] FabricManager::initializePointInstancer mismatched prototypes on point instancer: /Visuals/target_commands.
# [INFO]: Loading model checkpoint from: C:\Users\Teresa\Documents\GitHub\navsim\tmp\tmpTeresa\resultados_grid_command_v5\best_model_ppo_random_command5_11_8196.pt
# C:\Users\Teresa\miniconda3\envs\env_isaaclab\Lib\site-packages\rsl_rl\utils\utils.py:244: UserWarning: The observation configuration dictionary 'obs_groups' must contain the 'policy' key. As an observation group with the name 'policy' was found, this is assumed to be the observation set. Consider adding the 'policy' key to the 'obs_groups' dictionary for clarity. This behavior will be removed in a future version.
#   warnings.warn(
# C:\Users\Teresa\miniconda3\envs\env_isaaclab\Lib\site-packages\rsl_rl\utils\utils.py:290: UserWarning: The observation configuration dictionary 'obs_groups' must contain the 'critic' key. As the configuration for 'critic' is missing, the observations from the 'policy' set are used. Consider adding the 'critic' key to the 'obs_groups' dictionary for clarity. This behavior will be removed in a future version.
#   warnings.warn(
# --------------------------------------------------------------------------------
# Resolved observation sets:
# 	 policy :  ['policy']
# 	 critic :  ['policy']
# --------------------------------------------------------------------------------
# Actor MLP: MLP(
#   (0): Linear(in_features=11, out_features=64, bias=True)
#   (1): ELU(alpha=1.0)
#   (2): Linear(in_features=64, out_features=64, bias=True)
#   (3): ELU(alpha=1.0)
#   (4): Linear(in_features=64, out_features=4, bias=True)
# )
# Critic MLP: MLP(
#   (0): Linear(in_features=11, out_features=128, bias=True)
#   (1): ELU(alpha=1.0)
#   (2): Linear(in_features=128, out_features=128, bias=True)
#   (3): ELU(alpha=1.0)
#   (4): Linear(in_features=128, out_features=1, bias=True)
# )
#
# --- Todos los experimentos de test han finalizado ---

# %% [markdown]
# #### Test con 256 entornos

# %%
import os
df_callbacks = pd.read_csv(path_resultados+"/reward_best_models.csv",index_col='id_run_name')
top5_models = df_callbacks.nlargest(5,columns="reward")

powershell_script_test_3 = os.path.join(cfg_dir, "run_tests_3.ps1")

with open(powershell_script_test_3, "w") as f:
    f.write("$ErrorActionPreference = 'Stop'\n\n")
    
    for run_id, row in top5_models.iterrows():
        # Extraemos el número del id (ej: de 'ppo_random_hover_4' sacamos '4')
        experiment_number = run_id.split('_')[-1]
        
        # Construimos la ruta exacta del checkpoint
        # Nota: Asegúrate de que path_resultados termine en / o usar os.path.join
        checkpoint_path = f"{path_resultados}/best_model_{run_id}_{int(row['num_envs_train'])}.pt"
        f.write(f'Write-Host "Ejecutando Test final para Experimento {experiment_number}..."\n')
        
        # Usamos el experiment_number extraído para la tarea (--task)
        # Se añaden flags típicos de play.py: --num_envs 1 y se quita --headless para ver el visualizador
        f.write(f'& "{isaaclab_bat}" -p "{play_script}" '
                f'--task {id_task}-{experiment_number} '
                f'--num_envs 256 '
                f' --headless '
                f'--checkpoint "{checkpoint_path}"\n\n')
        
print(f"Script de test generado en: {powershell_script_test_3}")
# Out:
# Script de test generado en: C:/Users/Teresa/Documents/GitHub/navsim/isaac_lab/aerotaxi/env_command/env_9/grid_hiperparametros/cfg_files\run_tests_3.ps1

# %%
# Ejecuta el entrenamiento de forma automática
# !powershell -ExecutionPolicy Bypass -File "{powershell_script}"
import subprocess
import sys

# Ruta al script que generaste
powershell_script_path = powershell_script_test_3 

print(f"Iniciando ejecución de: {powershell_script_path}\n")

# Ejecutamos el proceso capturando la salida en tiempo real
process = subprocess.Popen(
    ["powershell.exe", "-ExecutionPolicy", "Bypass", "-File", powershell_script_path],
    stdout=subprocess.PIPE,
    stderr=subprocess.STDOUT, # Redirigimos errores a la salida estándar para verlos
    text=True,
    bufsize=1
)

# Leemos la salida línea a línea conforme se genera
try:
    for line in process.stdout:
        print(line, end="") # Imprime la salida de PowerShell en la celda
        sys.stdout.flush()   # Fuerza a Jupyter a mostrar la línea inmediatamente
except KeyboardInterrupt:
    process.kill()
    print("\nEntrenamiento cancelado por el usuario.")

process.wait()
print("\n--- Todos los experimentos de test han finalizado ---")
# Out:
# Iniciando ejecución de: C:/Users/Teresa/Documents/GitHub/navsim/isaac_lab/aerotaxi/env_command/env_9/grid_hiperparametros/cfg_files\run_tests_3.ps1
#
# Ejecutando Test final para Experimento 11...
# [INFO] Using python from: C:\Users\Teresa\miniconda3\envs\env_isaaclab\python.exe
# [INFO][AppLauncher]: Using device: cuda:0
# [INFO][AppLauncher]: Loading experience file: C:\Users\Teresa\miniconda3\envs\env_isaaclab\Lib\site-packages\isaaclab\apps\isaaclab.python.headless.kit
# Loading user config located at: 'c:/users/teresa/miniconda3/envs/env_isaaclab/lib/site-packages/isaacsim/kit/data/Kit/Isaac-Sim/5.1/user.config.json'
# [Info] [carb] Logging to file: c:/users/teresa/miniconda3/envs/env_isaaclab/lib/site-packages/isaacsim/kit/logs/Kit/Isaac-Sim/5.1/kit_20260205_115402.log
# 2026-02-05T10:54:03Z s] [Warning] [omni.usd_config.extension] Enable omni.materialx.libs extension to use MaterialX
# 2026-02-05T10:54:03Z s] [Warning] [carb] Acquiring non optional plugin interface which is not listed as dependency: [omni::physx::IPhysxBenchmarks v1.0] (plugin: <default plugin>), by client: omni.physics.physx.plugin. Add it to CARB_PLUGIN_IMPL_DEPS() macro of a client.
# 2026-02-05T10:54:03Z s] [Warning] [omni.isaac.dynamic_control] omni.isaac.dynamic_control is deprecated as of Isaac Sim 4.5. No action is needed from end-users.
# 2026-02-05T10:54:05Z [2,384ms] [Warning] [gpu.foundation.plugin] Skipping unsupported non-NVIDIA GPU: AMD Radeon(TM) Graphics
# 2026-02-05T10:54:05Z [2,385ms] [Warning] [gpu.foundation.plugin] Skipping unsupported non-NVIDIA GPU: AMD Radeon(TM) Graphics
#
# |---------------------------------------------------------------------------------------------|
# | Driver Version: 581.29        | Graphics API: D3D12
# |=============================================================================================|
# | GPU | Name                             | Active | LDA | GPU Memory | Vendor-ID | LUID       |
# |     |                                  |        |     |            | Device-ID | UUID       |
# |     |                                  |        |     |            | Bus-ID    |            |
# |---------------------------------------------------------------------------------------------|
# | 0   | NVIDIA GeForce RTX 5080          | Yes: 0 |     | 15889   MB | 10de      | fa570100.. |
# |     |                                  |        |     |            | 2c02      | 0          |
# |     |                                  |        |     |            | 1         |            |
# |---------------------------------------------------------------------------------------------|
# | 1   | AMD Radeon(TM) Graphics          |        |     | 1995    MB | 1002      | d7690100.. |
# |     |                                  |        |     |            | 13c0      | 0          |
# |     |                                  |        |     |            | N/A       |            |
# |=============================================================================================|
# | OS: Windows 11 Pro, Version: 10.0 (24H2), Build: 26100, Kernel: 10.0.26100.7623
# | Processor: AMD Ryzen 9 9950X 16-Core Processor
# | Cores: 16 | Logical Cores: 32
# |---------------------------------------------------------------------------------------------|
# | Total Memory (MB): 128627 | Free Memory: 94040
# | Total Page/Swap (MB): 136819 | Free Page/Swap: 91401
# |---------------------------------------------------------------------------------------------|
# C:\Users\Teresa\Documents\GitHub\navsim\isaac_lab\aerotaxi\env_command\env_9\flight_plan.py:29: UserWarning: Treat the new Tool classes introduced in v1.5 as experimental for now; the API and rcParam may change in future versions.
#   plt.rcParams["toolbar"] = "toolmanager"
# [INFO]: Parsing configuration from: aerotaxi.env_command.env_9.env:UAVEnvCfg
# [INFO]: Parsing configuration from: aerotaxi.env_command.env_9.grid_hiperparametros.cfg_files.ppo_random_command5_11_cfg:Command5PPORunnerCfg
# [INFO] Loading experiment from directory: C:\Users\Teresa\Documents\GitHub\navsim\isaac_lab\aerotaxi\env_command\env_9\logs\rsl_rl\command5
# Setting seed: 42
# [INFO]: Base environment:
# 	Environment device    : cuda:0
# 	Environment seed      : 42
# 	Physics step-size     : 0.005
# 	Rendering step-size   : 0.02
# 	Environment step-size : 0.02
# [INFO]: Time taken for scene creation : 1.113053 seconds
# [INFO]: Scene manager:  <class InteractiveScene>
# 	Number of environments: 256
# 	Environment spacing   : 100.0
# 	Source prim name      : /World/envs/env_0
# 	Global prim paths     : []
# 	Replicate physics     : False
# [INFO]: Starting the simulation. This may take a few seconds. Please wait...
# [INFO]: Time taken for simulation start : 0.381035 seconds
# [INFO] Command Manager:  <CommandManager> contains 1 active terms.
# +--------------------------------------+
# |         Active Command Terms         |
# +-------+-------------+----------------+
# | Index | Name        |      Type      |
# +-------+-------------+----------------+
# |   0   | vel_command | UAVcommandTerm |
# +-------+-------------+----------------+
#
# [INFO] Event Manager:  <EventManager> contains 1 active terms.
# +-----------------------------------+
# | Active Event Terms in Mode: 'reset' |
# +----------+------------------------+
# |  Index   | Name                   |
# +----------+------------------------+
# |    0     | reset_pos              |
# |    1     | randomize_mass         |
# |    2     | randomize_wind         |
# +----------+------------------------+
#
# [INFO] Recorder Manager:  <RecorderManager> contains 0 active terms.
# +---------------------+
# | Active Recorder Terms |
# +-----------+---------+
# |   Index   | Name    |
# +-----------+---------+
# +-----------+---------+
#
# [INFO] Action Manager:  <ActionManager> contains 1 active terms.
# +-----------------------------------+
# |   Active Action Terms (shape: 4)  |
# +--------+-------------+------------+
# | Index  | Name        |  Dimension |
# +--------+-------------+------------+
# |   0    | rotors_vel  |          4 |
# +--------+-------------+------------+
#
# [INFO] Observation Manager: <ObservationManager> contains 1 groups.
# +----------------------------------------------------+
# | Active Observation Terms in Group: 'policy' (shape: (11,)) |
# +---------------+--------------------+---------------+
# |     Index     | Name               |     Shape     |
# +---------------+--------------------+---------------+
# |       0       | pos                |      (3,)     |
# |       1       | lin_vel            |      (3,)     |
# |       2       | ang_vel            |      (3,)     |
# |       3       | roll               |      (1,)     |
# |       4       | pitch              |      (1,)     |
# +---------------+--------------------+---------------+
#
# [INFO] Termination Manager:  <TerminationManager> contains 4 active terms.
# +---------------------------------------+
# |        Active Termination Terms       |
# +-------+--------------------+----------+
# | Index | Name               | Time Out |
# +-------+--------------------+----------+
# |   0   | time_out           |   True   |
# |   1   | below_min_altitude |  False   |
# |   2   | bad_attitude       |  False   |
# |   3   | safety_shutdown    |  False   |
# +-------+--------------------+----------+
#
# [INFO] Reward Manager:  <RewardManager> contains 14 active terms.
# +-----------------------------------------------------+
# |                 Active Reward Terms                 |
# +-------+------------------------------------+--------+
# | Index | Name                               | Weight |
# +-------+------------------------------------+--------+
# |   0   | alive                              |   15.0 |
# |   1   | action_rate                        |   -0.1 |
# |   2   | terminating                        |  -50.0 |
# |   3   | rew_pos_diff                       |   -0.5 |
# |   4   | rew_pos_diff_fine_grained          |   15.0 |
# |   5   | rew_lin_vel_diff                   |   -0.1 |
# |   6   | rew_lin_vel_diff_fine_grained      |    2.0 |
# |   7   | rew_ang_vel_z_diff                 |   -1.0 |
# |   8   | rew_ang_vel_z_diff_fine_grained    |    1.0 |
# |   9   | rew_roll_diff                      |   -0.5 |
# |   10  | rew_roll_diff_fine_grained         |    1.0 |
# |   11  | rew_pitch_diff                     |   -0.5 |
# |   12  | rew_pitch_diff_fine_grained        |    1.0 |
# |   13  | rew_heading_alignment_fine_grained |    5.0 |
# +-------+------------------------------------+--------+
#
# [INFO] Curriculum Manager:  <CurriculumManager> contains 0 active terms.
# +----------------------+
# | Active Curriculum Terms |
# +-----------+----------+
# |   Index   | Name     |
# +-----------+----------+
# +-----------+----------+
#
# [INFO]: Completed setting up the environment...
# 2026-02-05T10:54:08Z [5,536ms] [Warning] [omni.physx.fabric.plugin] FabricManager::initializePointInstancer mismatched prototypes on point instancer: /Visuals/target_commands.
# [INFO]: Loading model checkpoint from: C:\Users\Teresa\Documents\GitHub\navsim\tmp\tmpTeresa\resultados_grid_command_v5\best_model_ppo_random_command5_11_8196.pt
# C:\Users\Teresa\miniconda3\envs\env_isaaclab\Lib\site-packages\rsl_rl\utils\utils.py:244: UserWarning: The observation configuration dictionary 'obs_groups' must contain the 'policy' key. As an observation group with the name 'policy' was found, this is assumed to be the observation set. Consider adding the 'policy' key to the 'obs_groups' dictionary for clarity. This behavior will be removed in a future version.
#   warnings.warn(
# C:\Users\Teresa\miniconda3\envs\env_isaaclab\Lib\site-packages\rsl_rl\utils\utils.py:290: UserWarning: The observation configuration dictionary 'obs_groups' must contain the 'critic' key. As the configuration for 'critic' is missing, the observations from the 'policy' set are used. Consider adding the 'critic' key to the 'obs_groups' dictionary for clarity. This behavior will be removed in a future version.
#   warnings.warn(
# --------------------------------------------------------------------------------
# Resolved observation sets:
# 	 policy :  ['policy']
# 	 critic :  ['policy']
# --------------------------------------------------------------------------------
# Actor MLP: MLP(
#   (0): Linear(in_features=11, out_features=64, bias=True)
#   (1): ELU(alpha=1.0)
#   (2): Linear(in_features=64, out_features=64, bias=True)
#   (3): ELU(alpha=1.0)
#   (4): Linear(in_features=64, out_features=4, bias=True)
# )
# Critic MLP: MLP(
#   (0): Linear(in_features=11, out_features=128, bias=True)
#   (1): ELU(alpha=1.0)
#   (2): Linear(in_features=128, out_features=128, bias=True)
#   (3): ELU(alpha=1.0)
#   (4): Linear(in_features=128, out_features=1, bias=True)
# )
#
# --- Todos los experimentos de test han finalizado ---

# %%
import pandas as pd

df_train = top5_models.copy()
if df_train.index.name == 'id_run_name':
    df_train = df_train.reset_index()

df_train = df_train.rename(columns={
    'reward': 'reward_train',
    'max_reward': 'max_reward_train',
    'std_reward': 'std_train'
})

df_test = df_rewards_play.copy()

df_test = pd.read_csv(path_resultados+'/rewards_play_PPO.csv')
df_test = df_test.rename(columns={
    'reward': 'reward_test',
    'max_reward': 'max_reward_test',
    'std': 'std_test'
})

df_final = pd.merge(
    df_train[['id_run_name', 'num_envs_train', 'reward_train', 'max_reward_train', 'std_train', 'iteration']], 
    df_test[['id_run_name', 'num_envs_test', 'reward_test', 'max_reward_test', 'std_test', 'checkpoint']], 
    on='id_run_name', 
    how='inner'
)

column_order = [
    'id_run_name',
    'num_envs_train',
    'num_envs_test',
    'reward_train', 'reward_test', 
    'max_reward_train', 'max_reward_test', 
    'std_train', 'std_test',
    'iteration'
]
df_final = df_final[column_order]

df_final = df_final.sort_values(by='id_run_name', ascending=False)

# %%
df_rewards_play = df_final.sort_values(by="id_run_name",ascending=False)
df_rewards_play = df_rewards_play.reset_index().drop(columns='index')

df_final = df_rewards_play.copy()

df_final['diff_rw_test_train'] = df_final['reward_test'] - df_final['reward_train']

df_final['diferencia(%)'] = (df_final['diff_rw_test_train'] / df_final['reward_train'].abs()) * 100

df_final['diferencia(%)'] = df_final['diferencia(%)'].apply(lambda x: f"{x:+.2f}%")

df_final
# Out:
#               id_run_name  num_envs_train  num_envs_test  reward_train  \
# 0  ppo_random_command5_11            8196              1    154.030015
# 1  ppo_random_command5_11            8196             64    154.030015
# 2  ppo_random_command5_11            8196             64    154.030015
# 3  ppo_random_command5_11            8196            256    154.030015
#
#    reward_test  max_reward_train  max_reward_test  std_train    std_test  \
# 0   223.073972        616.214417       373.655934  170.69982  150.581962
# 1   112.457990        616.214417       388.230930  170.69982  120.609010
# 2   112.457990        616.214417       388.230930  170.69982  120.609010
# 3   122.212913        616.214417       423.071395  170.69982  113.751531
#
#    iteration  diff_rw_test_train diferencia(%)
# 0       1289           69.043957       +44.83%
# 1       1289          -41.572025       -26.99%
# 2       1289          -41.572025       -26.99%
# 3       1289          -31.817102       -20.66%

# %% [markdown]
# Pruebas con un solo entorno: Vemos cómo se comporta la política para un único agente en una prueba aleatoria.

# %%
df_final[df_final['num_envs_test'] == 1].sort_values(by='reward_test',ascending=False)
# Out:
#               id_run_name  num_envs_train  num_envs_test  reward_train  \
# 0  ppo_random_command5_11            8196              1    154.030015
#
#    reward_test  max_reward_train  max_reward_test  std_train    std_test  \
# 0   223.073972        616.214417       373.655934  170.69982  150.581962
#
#    iteration  diff_rw_test_train diferencia(%)
# 0       1289           69.043957       +44.83%

# %% [markdown]
# ``Interpretación``: Vemos que el modelo 38 se ha estampado en la prueba aleatoria, así que ese modelo no debería usarse para ninguna transferencia real.

# %% [markdown]
# Pruebas con varios entornos: Vemos cómo se comporta la política en múltiples entornos (varias pruebas simuladas en paralelo), teniendo en cuenta cuál es la desviación de cada uno en test, lo que nos permite inferir si la recompensa es estable para todas las pruebas.

# %%
df_final[df_final['num_envs_test'] != 1].sort_values(by='std_test',ascending=True).reset_index().drop(columns="index")
# Out:
#               id_run_name  num_envs_train  num_envs_test  reward_train  \
# 0  ppo_random_command5_11            8196            256    154.030015
# 1  ppo_random_command5_11            8196             64    154.030015
# 2  ppo_random_command5_11            8196             64    154.030015
#
#    reward_test  max_reward_train  max_reward_test  std_train    std_test  \
# 0   122.212913        616.214417       423.071395  170.69982  113.751531
# 1   112.457990        616.214417       388.230930  170.69982  120.609010
# 2   112.457990        616.214417       388.230930  170.69982  120.609010
#
#    iteration  diff_rw_test_train diferencia(%)
# 0       1289          -31.817102       -20.66%
# 1       1289          -41.572025       -26.99%
# 2       1289          -41.572025       -26.99%

# %% [markdown]
# pruebas:

# %% [markdown]
# C:/Users/Teresa/Desktop/RuralData/IsaacLab/IsaacLab/isaaclab.bat -p C:/Users/Teresa/Documents/GitHub/navsim/isaac_lab/rl_v5_1_0/rsl_rl/train.py --task Isaac-Command5-Aerotaxi-RANDOM-11 --num_envs 8196 --headless
