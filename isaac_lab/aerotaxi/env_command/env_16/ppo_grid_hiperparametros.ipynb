# %%
# Parámetros a configurar:
import os
experiment_name = "command12"
task_name = "Command12"
cfg_dir = "C:/Users/Teresa/Documents/GitHub/navsim/isaac_lab/aerotaxi/env_command/env_16/grid_hiperparametros/cfg_files"
path_resultados = "C:/Users/Teresa/Documents/GitHub/navsim/tmp/tmpTeresa/resultados_grid_command_v12"
isaaclab_bat = "C:/Users/Teresa/Desktop/RuralData/IsaacLab/IsaacLab/isaaclab.bat"
train_script = "C:/Users/Teresa/Documents/GitHub/navsim/isaac_lab/rl_v5_1_0/rsl_rl/train.py"
id_task = f"Isaac-{task_name}-Aerotaxi-RANDOM" # luego se le añade el número de task con el guión (Isaac-Command2-Aerotaxi-RANDOM-34)
play_script = "C:/Users/Teresa/Documents/GitHub/navsim/isaac_lab/rl_v5_1_0/rsl_rl/play.py"
num_iter = "1001"
num_steps_per_env = 100
powershell_script = os.path.join(cfg_dir, "run_all.ps1")

# el num_steps_per_env = 100 también está en el env, al final del todo, y deben tener el mismo valor
# Recuerda iniciar en el init todos los experimentos

# %%
import random
import os

# Si los directorios no existen (el último indicado), lo crea
os.makedirs(cfg_dir, exist_ok=True)
os.makedirs(path_resultados, exist_ok=True)
# Opciones de hiperparámetros
param_options = {
    "init_noise_std": [0.0, 0.1, 0.2, 0.5, 0.8, 1.0],
    "actor_hidden_dims": [[64, 64], [128, 128], [256, 256], [128, 64]],
    "critic_hidden_dims": [[64, 64], [128, 128], [256, 256]],
    "activation": ["relu", "tanh", "elu", "gelu"],
    "value_loss_coef": [0.5, 1.0, 2.0],
    "clip_param": [0.1, 0.2, 0.3],
    "entropy_coef": [0.0, 0.001, 0.01, 0.05],
    "num_learning_epochs": [4, 8, 12],
    "num_mini_batches": [2, 4, 8],
    "learning_rate": [5e-05, 1e-4, 3e-4, 1e-3, 3e-3],
    "gamma": [0.95, 0.98, 0.99],
    "lam": [0.90, 0.95, 0.97],
    "max_grad_norm": [0.5, 1.0, 2.0],
    "desired_kl": [0.005, 0.008, 0.01, 0.02],
}

num_trials = 35  # cantidad de configuraciones

cfg_files = []

for i in range(num_trials):
    run_name = f"ppo_random_{experiment_name}_{i+1}"
    sampled = {k: random.choice(v) for k, v in param_options.items()}

    # Convertir listas a string
    actor_dims = sampled["actor_hidden_dims"]
    critic_dims = sampled["critic_hidden_dims"]

    cfg_content = f"""
from isaaclab.utils import configclass
from isaaclab_rl.rsl_rl import RslRlOnPolicyRunnerCfg, RslRlPpoActorCriticCfg, RslRlPpoAlgorithmCfg

@configclass
class {task_name}PPORunnerCfg(RslRlOnPolicyRunnerCfg):
    num_steps_per_env = {num_steps_per_env} 
    max_iterations = {num_iter}
    save_interval = 100
    experiment_name = "{experiment_name}"
    run_name = "{run_name}"
    resume = False
    empirical_normalization = False
    csv_path_metrics = "{path_resultados}"
    callbacks = True
    policy = RslRlPpoActorCriticCfg(
        init_noise_std={sampled['init_noise_std']},
        actor_hidden_dims={actor_dims},
        critic_hidden_dims={critic_dims},
        activation="{sampled['activation']}",
    )
    algorithm = RslRlPpoAlgorithmCfg(
        value_loss_coef={sampled['value_loss_coef']},
        use_clipped_value_loss=True,
        clip_param={sampled['clip_param']},
        entropy_coef={sampled['entropy_coef']},
        num_learning_epochs={sampled['num_learning_epochs']},
        num_mini_batches={sampled['num_mini_batches']},
        learning_rate={sampled['learning_rate']},
        schedule="adaptive",
        gamma={sampled['gamma']},
        lam={sampled['lam']},
        desired_kl={sampled['desired_kl']},
        max_grad_norm={sampled['max_grad_norm']},
    )
"""
    cfg_path = os.path.join(cfg_dir, f"{run_name}_cfg.py")
    with open(cfg_path, "w") as f:
        f.write(cfg_content.strip())
    cfg_files.append((run_name, cfg_path))

# Crear archivo PowerShell para ejecutar todas las configuraciones
powershell_script = os.path.join(cfg_dir, "run_all.ps1")

num_envs =  [64, 128, 512, 1024, 2048, 4096, 8196] #número de entornos para train (paralelizados)

with open(powershell_script, "w") as f:
    f.write("$ErrorActionPreference = 'Stop'\n\n")
    j = 0
    for run_name, cfg_path in cfg_files:
        # Convertir path a módulo Python (reemplazar / y .py)
        num_envs_i = random.choice(num_envs)
        module_path = cfg_path.replace("/", ".").replace("\\", ".").replace(".py", "")
        f.write(f'Write-Host "Ejecutando {run_name}"\n')
        f.write(f'& "{isaaclab_bat}" -p "{train_script}" --task {id_task}-{j+1} --num_envs {num_envs_i} --headless \n\n')
        j += 1
print("Archivos de configuración generados y script PowerShell listo en:", powershell_script)
# Out:
# Archivos de configuración generados y script PowerShell listo en: C:/Users/Teresa/Documents/GitHub/navsim/isaac_lab/aerotaxi/env_command/env_11/grid_hiperparametros/cfg_files\run_all.ps1

# %%
# Ejecuta el entrenamiento de forma automática
# !powershell -ExecutionPolicy Bypass -File "{powershell_script}"
import subprocess
import sys

# Ruta al script que generaste
powershell_script_path = powershell_script 

print(f"Iniciando ejecución de: {powershell_script_path}\n")

# Ejecutamos el proceso capturando la salida en tiempo real
process = subprocess.Popen(
    ["powershell.exe", "-ExecutionPolicy", "Bypass", "-File", powershell_script_path],
    stdout=subprocess.PIPE,
    stderr=subprocess.STDOUT, # Redirigimos errores a la salida estándar para verlos
    text=True,
    bufsize=1
)

# Leemos la salida línea a línea conforme se genera
try:
    for line in process.stdout:
        print(line, end="") # Imprime la salida de PowerShell en la celda
        sys.stdout.flush()   # Fuerza a Jupyter a mostrar la línea inmediatamente
except KeyboardInterrupt:
    process.kill()
    print("\nEntrenamiento cancelado por el usuario.")

process.wait()
print("\n--- Todos los experimentos han finalizado ---")
# Out:
# Iniciando ejecución de: C:/Users/Teresa/Documents/GitHub/navsim/isaac_lab/aerotaxi/env_command/env_15/grid_hiperparametros/cfg_files\run_all.ps1
#
# Ejecutando ppo_random_command11_11
# [INFO] Using python from: C:\Users\Teresa\miniconda3\envs\env_isaaclab\python.exe
# [INFO][AppLauncher]: Using device: cuda:0
# [INFO][AppLauncher]: Loading experience file: C:\Users\Teresa\miniconda3\envs\env_isaaclab\Lib\site-packages\isaaclab\apps\isaaclab.python.headless.kit
# Loading user config located at: 'c:/users/teresa/miniconda3/envs/env_isaaclab/lib/site-packages/isaacsim/kit/data/Kit/Isaac-Sim/5.1/user.config.json'
# [Info] [carb] Logging to file: c:/users/teresa/miniconda3/envs/env_isaaclab/lib/site-packages/isaacsim/kit/logs/Kit/Isaac-Sim/5.1/kit_20260316_121756.log
# 2026-03-16T11:17:56Z s] [Warning] [omni.usd_config.extension] Enable omni.materialx.libs extension to use MaterialX
# 2026-03-16T11:17:57Z s] [Warning] [carb] Acquiring non optional plugin interface which is not listed as dependency: [omni::physx::IPhysxBenchmarks v1.0] (plugin: <default plugin>), by client: omni.physics.physx.plugin. Add it to CARB_PLUGIN_IMPL_DEPS() macro of a client.
# 2026-03-16T11:17:57Z s] [Warning] [omni.isaac.dynamic_control] omni.isaac.dynamic_control is deprecated as of Isaac Sim 4.5. No action is needed from end-users.
# 2026-03-16T11:17:58Z [2,549ms] [Warning] [gpu.foundation.plugin] Skipping unsupported non-NVIDIA GPU: AMD Radeon(TM) Graphics
# 2026-03-16T11:17:58Z [2,549ms] [Warning] [gpu.foundation.plugin] Skipping unsupported non-NVIDIA GPU: AMD Radeon(TM) Graphics
#
# |---------------------------------------------------------------------------------------------|
# | Driver Version: 581.29        | Graphics API: D3D12
# |=============================================================================================|
# | GPU | Name                             | Active | LDA | GPU Memory | Vendor-ID | LUID       |
# |     |                                  |        |     |            | Device-ID | UUID       |
# |     |                                  |        |     |            | Bus-ID    |            |
# |---------------------------------------------------------------------------------------------|
# | 0   | NVIDIA GeForce RTX 5080          | Yes: 0 |     | 15889   MB | 10de      | 08570100.. |
# |     |                                  |        |     |            | 2c02      | 0          |
# |     |                                  |        |     |            | 1         |            |
# |---------------------------------------------------------------------------------------------|
# | 1   | AMD Radeon(TM) Graphics          |        |     | 1995    MB | 1002      | 676a0100.. |
# |     |                                  |        |     |            | 13c0      | 0          |
# |     |                                  |        |     |            | N/A       |            |
# |=============================================================================================|
# | OS: Windows 11 Pro, Version: 10.0 (25H2), Build: 26200, Kernel: 10.0.26100.8036
# | Processor: AMD Ryzen 9 9950X 16-Core Processor
# | Cores: 16 | Logical Cores: 32
# |---------------------------------------------------------------------------------------------|
# | Total Memory (MB): 128627 | Free Memory: 97025
# | Total Page/Swap (MB): 136819 | Free Page/Swap: 96381
# |---------------------------------------------------------------------------------------------|
# C:\Users\Teresa\Documents\GitHub\navsim\isaac_lab\aerotaxi\env_command\env_15\flight_plan.py:29: UserWarning: Treat the new Tool classes introduced in v1.5 as experimental for now; the API and rcParam may change in future versions.
#   plt.rcParams["toolbar"] = "toolmanager"
# [INFO]: Parsing configuration from: aerotaxi.env_command.env_15.env:UAVEnvCfg
# [INFO]: Parsing configuration from: aerotaxi.env_command.env_15.grid_hiperparametros.cfg_files.ppo_random_command11_11_cfg:Command11PPORunnerCfg
# [INFO] Logging experiment in directory: C:\Users\Teresa\Documents\GitHub\navsim\isaac_lab\aerotaxi\env_command\env_15\logs\rsl_rl\command11
# Exact experiment name requested from command line: 2026-03-16_12-18-00
# Setting seed: 42
# [INFO]: Base environment:
# 	Environment device    : cuda:0
# 	Environment seed      : 42
# 	Physics step-size     : 0.005
# 	Rendering step-size   : 0.02
# 	Environment step-size : 0.02
# [INFO]: Time taken for scene creation : 2.835605 seconds
# [INFO]: Scene manager:  <class InteractiveScene>
# 	Number of environments: 4096
# 	Environment spacing   : 200.0
# 	Source prim name      : /World/envs/env_0
# 	Global prim paths     : []
# 	Replicate physics     : False
# [INFO]: Starting the simulation. This may take a few seconds. Please wait...
# [INFO]: Time taken for simulation start : 3.106392 seconds
# [INFO] Command Manager:  <CommandManager> contains 1 active terms.
# +--------------------------------------+
# |         Active Command Terms         |
# +-------+-------------+----------------+
# | Index | Name        |      Type      |
# +-------+-------------+----------------+
# |   0   | vel_command | UAVcommandTerm |
# +-------+-------------+----------------+
#
# [INFO] Event Manager:  <EventManager> contains 1 active terms.
# +-----------------------------------+
# | Active Event Terms in Mode: 'reset' |
# +----------+------------------------+
# |  Index   | Name                   |
# +----------+------------------------+
# |    0     | reset_pos              |
# |    1     | randomize_mass         |
# |    2     | randomize_wind         |
# +----------+------------------------+
#
# [INFO] Recorder Manager:  <RecorderManager> contains 0 active terms.
# +---------------------+
# | Active Recorder Terms |
# +-----------+---------+
# |   Index   | Name    |
# +-----------+---------+
# +-----------+---------+
#
# [INFO] Action Manager:  <ActionManager> contains 1 active terms.
# +-----------------------------------+
# |   Active Action Terms (shape: 4)  |
# +--------+-------------+------------+
# | Index  | Name        |  Dimension |
# +--------+-------------+------------+
# |   0    | rotors_vel  |          4 |
# +--------+-------------+------------+
#
# [INFO] Observation Manager: <ObservationManager> contains 2 groups.
# +---------------------------------------------------------+
# | Active Observation Terms in Group: 'policy' (shape: (16,)) |
# +-----------+---------------------------------+-----------+
# |   Index   | Name                            |   Shape   |
# +-----------+---------------------------------+-----------+
# |     0     | lin_vel                         |    (3,)   |
# |     1     | ang_vel                         |    (3,)   |
# |     2     | projected_gravity               |    (3,)   |
# |     3     | target_vel                      |    (3,)   |
# |     4     | target_future                   |    (3,)   |
# |     5     | yaw_error                       |    (1,)   |
# +-----------+---------------------------------+-----------+
# +---------------------------------------------------------+
# | Active Observation Terms in Group: 'critic' (shape: (16,)) |
# +-----------+---------------------------------+-----------+
# |   Index   | Name                            |   Shape   |
# +-----------+---------------------------------+-----------+
# |     0     | lin_vel                         |    (3,)   |
# |     1     | ang_vel                         |    (3,)   |
# |     2     | projected_gravity               |    (3,)   |
# |     3     | target_vel                      |    (3,)   |
# |     4     | target_future                   |    (3,)   |
# |     5     | yaw_error                       |    (1,)   |
# +-----------+---------------------------------+-----------+
#
# [INFO] Termination Manager:  <TerminationManager> contains 4 active terms.
# +---------------------------------------+
# |        Active Termination Terms       |
# +-------+--------------------+----------+
# | Index | Name               | Time Out |
# +-------+--------------------+----------+
# |   0   | time_out           |   True   |
# |   1   | below_min_altitude |  False   |
# |   2   | bad_attitude       |  False   |
# |   3   | safety_shutdown    |  False   |
# +-------+--------------------+----------+
#
# [INFO] Reward Manager:  <RewardManager> contains 6 active terms.
# +------------------------------------------+
# |           Active Reward Terms            |
# +-------+-------------------------+--------+
# | Index | Name                    | Weight |
# +-------+-------------------------+--------+
# |   0   | rew_attitude_stability2 |    2.0 |
# |   1   | rew_ang_vel_stability4  |    1.0 |
# |   2   | rew_pos2                |    2.0 |
# |   3   | rew_action_rate         |    0.1 |
# |   4   | rew_heading             |    3.0 |
# |   5   | rew_track_vel3          |    8.0 |
# +-------+-------------------------+--------+
#
# [INFO] Curriculum Manager:  <CurriculumManager> contains 0 active terms.
# +----------------------+
# | Active Curriculum Terms |
# +-----------+----------+
# |   Index   | Name     |
# +-----------+----------+
# +-----------+----------+
#
# [INFO]: Completed setting up the environment...
# 2026-03-16T11:18:06Z [10,563ms] [Warning] [omni.physx.fabric.plugin] FabricManager::initializePointInstancer mismatched prototypes on point instancer: /Visuals/target_commands.
# 2026-03-16T11:18:06Z [10,563ms] [Warning] [omni.physx.fabric.plugin] FabricManager::initializePointInstancer mismatched prototypes on point instancer: /Visuals/TargetArrow.
# 2026-03-16T11:18:06Z [10,563ms] [Warning] [omni.physx.fabric.plugin] FabricManager::initializePointInstancer mismatched prototypes on point instancer: /Visuals/DroneArrow.
# C:\Users\Teresa\miniconda3\envs\env_isaaclab\Lib\site-packages\rsl_rl\utils\utils.py:244: UserWarning: The observation configuration dictionary 'obs_groups' must contain the 'policy' key. As an observation group with the name 'policy' was found, this is assumed to be the observation set. Consider adding the 'policy' key to the 'obs_groups' dictionary for clarity. This behavior will be removed in a future version.
#   warnings.warn(
# C:\Users\Teresa\miniconda3\envs\env_isaaclab\Lib\site-packages\rsl_rl\utils\utils.py:282: UserWarning: The observation configuration dictionary 'obs_groups' must contain the 'critic' key. As an observation group with the name 'critic' was found, this is assumed to be the observation set. Consider adding the 'critic' key to the 'obs_groups' dictionary for clarity. This behavior will be removed in a future version.
#   warnings.warn(
# --------------------------------------------------------------------------------
# Resolved observation sets:
# 	 policy :  ['policy']
# 	 critic :  ['critic']
# --------------------------------------------------------------------------------
# Actor MLP: MLP(
#   (0): Linear(in_features=16, out_features=128, bias=True)
#   (1): ELU(alpha=1.0)
#   (2): Linear(in_features=128, out_features=128, bias=True)
#   (3): ELU(alpha=1.0)
#   (4): Linear(in_features=128, out_features=128, bias=True)
#   (5): ELU(alpha=1.0)
#   (6): Linear(in_features=128, out_features=4, bias=True)
# )
# Critic MLP: MLP(
#   (0): Linear(in_features=16, out_features=256, bias=True)
#   (1): ELU(alpha=1.0)
#   (2): Linear(in_features=256, out_features=256, bias=True)
#   (3): ELU(alpha=1.0)
#   (4): Linear(in_features=256, out_features=256, bias=True)
#   (5): ELU(alpha=1.0)
#   (6): Linear(in_features=256, out_features=1, bias=True)
# )
# ################################################################################
#                        Learning iteration 0/1001
#
#                        Computation: 95801 steps/s (collection: 5.170s, learning 0.303s)
#              Mean action noise std: 0.05
#           Mean value_function loss: 2.8873
#                Mean surrogate loss: 0.0252
#                  Mean entropy loss: -6.2789
#                        Mean reward: 7.21
#                Mean episode length: 64.21
# Episode_Reward/rew_attitude_stability2: 0.0441
# Episode_Reward/rew_ang_vel_stability4: 0.0287
#            Episode_Reward/rew_pos2: 0.0508
#     Episode_Reward/rew_action_rate: -0.0000
#         Episode_Reward/rew_heading: 0.0376
#      Episode_Reward/rew_track_vel3: 0.0772
#       Episode_Termination/time_out: 0.0267
# Episode_Termination/below_min_altitude: 0.0024
#   Episode_Termination/bad_attitude: 0.4151
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 524288
#                     Iteration time: 5.47s
#                       Time elapsed: 00:00:05
#                                ETA: 01:31:18
#
# Could not find git repository in C:\Users\Teresa\miniconda3\envs\env_isaaclab\Lib\site-packages\rsl_rl\__init__.py. Skipping.
# Storing git diff for 'navsim' in: C:\Users\Teresa\Documents\GitHub\navsim\isaac_lab\aerotaxi\env_command\env_15\logs\rsl_rl\command11\2026-03-16_12-18-00_ppo_random_command11_11\git\navsim.diff
# ################################################################################
#                        Learning iteration 1/1001
#
#                        Computation: 121561 steps/s (collection: 4.084s, learning 0.229s)
#              Mean action noise std: 0.05
#           Mean value_function loss: 2.1373
#                Mean surrogate loss: 0.0021
#                  Mean entropy loss: -6.2714
#                        Mean reward: 7.44
#                Mean episode length: 61.94
# Episode_Reward/rew_attitude_stability2: 0.0574
# Episode_Reward/rew_ang_vel_stability4: 0.0369
#            Episode_Reward/rew_pos2: 0.0588
#     Episode_Reward/rew_action_rate: -0.0000
#         Episode_Reward/rew_heading: 0.0474
#      Episode_Reward/rew_track_vel3: 0.0993
#       Episode_Termination/time_out: 0.0059
# Episode_Termination/below_min_altitude: 0.0255
#   Episode_Termination/bad_attitude: 0.9486
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 1048576
#                     Iteration time: 4.31s
#                       Time elapsed: 00:00:09
#                                ETA: 01:21:32
#
# ################################################################################
#                        Learning iteration 2/1001
#
#                        Computation: 123873 steps/s (collection: 4.004s, learning 0.229s)
#              Mean action noise std: 0.05
#           Mean value_function loss: 1.8791
#                Mean surrogate loss: 0.0020
#                  Mean entropy loss: -6.2513
#                        Mean reward: 6.27
#                Mean episode length: 57.68
# Episode_Reward/rew_attitude_stability2: 0.0554
# Episode_Reward/rew_ang_vel_stability4: 0.0354
#            Episode_Reward/rew_pos2: 0.0584
#     Episode_Reward/rew_action_rate: -0.0000
#         Episode_Reward/rew_heading: 0.0455
#      Episode_Reward/rew_track_vel3: 0.0951
#       Episode_Termination/time_out: 0.0002
# Episode_Termination/below_min_altitude: 0.0220
#   Episode_Termination/bad_attitude: 0.9775
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 1572864
#                     Iteration time: 4.23s
#                       Time elapsed: 00:00:14
#                                ETA: 01:17:48
#
# ################################################################################
#                        Learning iteration 3/1001
#
#                        Computation: 121971 steps/s (collection: 4.073s, learning 0.225s)
#              Mean action noise std: 0.05
#           Mean value_function loss: 1.6171
#                Mean surrogate loss: 0.0022
#                  Mean entropy loss: -6.2423
#                        Mean reward: 7.56
#                Mean episode length: 58.79
# Episode_Reward/rew_attitude_stability2: 0.0558
# Episode_Reward/rew_ang_vel_stability4: 0.0357
#            Episode_Reward/rew_pos2: 0.0586
#     Episode_Reward/rew_action_rate: -0.0000
#         Episode_Reward/rew_heading: 0.0466
#      Episode_Reward/rew_track_vel3: 0.0965
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 0.0229
#   Episode_Termination/bad_attitude: 0.9771
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 2097152
#                     Iteration time: 4.30s
#                       Time elapsed: 00:00:18
#                                ETA: 01:16:09
#
# ################################################################################
#                        Learning iteration 4/1001
#
#                        Computation: 123334 steps/s (collection: 4.026s, learning 0.225s)
#              Mean action noise std: 0.05
#           Mean value_function loss: 1.4104
#                Mean surrogate loss: 0.0026
#                  Mean entropy loss: -6.2126
#                        Mean reward: 7.46
#                Mean episode length: 59.63
# Episode_Reward/rew_attitude_stability2: 0.0562
# Episode_Reward/rew_ang_vel_stability4: 0.0358
#            Episode_Reward/rew_pos2: 0.0582
#     Episode_Reward/rew_action_rate: -0.0000
#         Episode_Reward/rew_heading: 0.0462
#      Episode_Reward/rew_track_vel3: 0.0943
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 0.0275
#   Episode_Termination/bad_attitude: 0.9725
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 2621440
#                     Iteration time: 4.25s
#                       Time elapsed: 00:00:22
#                                ETA: 01:14:59
#
# ################################################################################
#                        Learning iteration 5/1001
#
#                        Computation: 122900 steps/s (collection: 4.044s, learning 0.222s)
#              Mean action noise std: 0.05
#           Mean value_function loss: 1.2498
#                Mean surrogate loss: 0.0013
#                  Mean entropy loss: -6.1939
#                        Mean reward: 6.39
#                Mean episode length: 58.67
# Episode_Reward/rew_attitude_stability2: 0.0561
# Episode_Reward/rew_ang_vel_stability4: 0.0355
#            Episode_Reward/rew_pos2: 0.0582
#     Episode_Reward/rew_action_rate: -0.0000
#         Episode_Reward/rew_heading: 0.0465
#      Episode_Reward/rew_track_vel3: 0.0948
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 0.0216
#   Episode_Termination/bad_attitude: 0.9784
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 3145728
#                     Iteration time: 4.27s
#                       Time elapsed: 00:00:26
#                                ETA: 01:14:14
#
# ################################################################################
#                        Learning iteration 6/1001
#
#                        Computation: 123508 steps/s (collection: 4.020s, learning 0.225s)
#              Mean action noise std: 0.05
#           Mean value_function loss: 1.1561
#                Mean surrogate loss: 0.0019
#                  Mean entropy loss: -6.1693
#                        Mean reward: 6.51
#                Mean episode length: 63.09
# Episode_Reward/rew_attitude_stability2: 0.0561
# Episode_Reward/rew_ang_vel_stability4: 0.0358
#            Episode_Reward/rew_pos2: 0.0583
#     Episode_Reward/rew_action_rate: -0.0000
#         Episode_Reward/rew_heading: 0.0460
#      Episode_Reward/rew_track_vel3: 0.0954
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 0.0194
#   Episode_Termination/bad_attitude: 0.9806
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 3670016
#                     Iteration time: 4.24s
#                       Time elapsed: 00:00:31
#                                ETA: 01:13:37
#
# ################################################################################
#                        Learning iteration 7/1001
#
#                        Computation: 122915 steps/s (collection: 4.041s, learning 0.224s)
#              Mean action noise std: 0.05
#           Mean value_function loss: 1.0323
#                Mean surrogate loss: 0.0020
#                  Mean entropy loss: -6.1642
#                        Mean reward: 6.69
#                Mean episode length: 59.37
# Episode_Reward/rew_attitude_stability2: 0.0564
# Episode_Reward/rew_ang_vel_stability4: 0.0360
#            Episode_Reward/rew_pos2: 0.0588
#     Episode_Reward/rew_action_rate: -0.0000
#         Episode_Reward/rew_heading: 0.0475
#      Episode_Reward/rew_track_vel3: 0.0976
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 0.0217
#   Episode_Termination/bad_attitude: 0.9783
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 4194304
#                     Iteration time: 4.27s
#                       Time elapsed: 00:00:35
#                                ETA: 01:13:11
#
# ################################################################################
#                        Learning iteration 8/1001
#
#                        Computation: 120347 steps/s (collection: 4.130s, learning 0.226s)
#              Mean action noise std: 0.05
#           Mean value_function loss: 0.9237
#                Mean surrogate loss: 0.0017
#                  Mean entropy loss: -6.1459
#                        Mean reward: 7.74
#                Mean episode length: 61.84
# Episode_Reward/rew_attitude_stability2: 0.0564
# Episode_Reward/rew_ang_vel_stability4: 0.0360
#            Episode_Reward/rew_pos2: 0.0588
#     Episode_Reward/rew_action_rate: -0.0000
#         Episode_Reward/rew_heading: 0.0470
#      Episode_Reward/rew_track_vel3: 0.0979
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 0.0234
#   Episode_Termination/bad_attitude: 0.9766
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 4718592
#                     Iteration time: 4.36s
#                       Time elapsed: 00:00:39
#                                ETA: 01:13:00
#
# ################################################################################
#                        Learning iteration 9/1001
#
#                        Computation: 120692 steps/s (collection: 4.123s, learning 0.221s)
#              Mean action noise std: 0.05
#           Mean value_function loss: 0.8747
#                Mean surrogate loss: 0.0011
#                  Mean entropy loss: -6.1331
#                        Mean reward: 7.49
#                Mean episode length: 62.95
# Episode_Reward/rew_attitude_stability2: 0.0581
# Episode_Reward/rew_ang_vel_stability4: 0.0373
#            Episode_Reward/rew_pos2: 0.0590
#     Episode_Reward/rew_action_rate: -0.0000
#         Episode_Reward/rew_heading: 0.0473
#      Episode_Reward/rew_track_vel3: 0.0980
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 0.0234
#   Episode_Termination/bad_attitude: 0.9766
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 5242880
#                     Iteration time: 4.34s
#                       Time elapsed: 00:00:44
#                                ETA: 01:12:49
#
# ################################################################################
#                        Learning iteration 10/1001
#
#                        Computation: 121913 steps/s (collection: 4.077s, learning 0.223s)
#              Mean action noise std: 0.05
#           Mean value_function loss: 0.7929
#                Mean surrogate loss: 0.0010
#                  Mean entropy loss: -6.1179
#                        Mean reward: 8.09
#                Mean episode length: 66.27
# Episode_Reward/rew_attitude_stability2: 0.0585
# Episode_Reward/rew_ang_vel_stability4: 0.0377
#            Episode_Reward/rew_pos2: 0.0593
#     Episode_Reward/rew_action_rate: -0.0000
#         Episode_Reward/rew_heading: 0.0490
#      Episode_Reward/rew_track_vel3: 0.1012
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 0.0267
#   Episode_Termination/bad_attitude: 0.9733
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 5767168
#                     Iteration time: 4.30s
#                       Time elapsed: 00:00:48
#                                ETA: 01:12:35
#
# ################################################################################
#                        Learning iteration 11/1001
#
#                        Computation: 123843 steps/s (collection: 4.014s, learning 0.220s)
#              Mean action noise std: 0.05
#           Mean value_function loss: 0.7321
#                Mean surrogate loss: 0.0017
#                  Mean entropy loss: -6.1000
#                        Mean reward: 8.15
#                Mean episode length: 68.35
# Episode_Reward/rew_attitude_stability2: 0.0596
# Episode_Reward/rew_ang_vel_stability4: 0.0386
#            Episode_Reward/rew_pos2: 0.0597
#     Episode_Reward/rew_action_rate: -0.0000
#         Episode_Reward/rew_heading: 0.0489
#      Episode_Reward/rew_track_vel3: 0.1004
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 0.0285
#   Episode_Termination/bad_attitude: 0.9715
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 6291456
#                     Iteration time: 4.23s
#                       Time elapsed: 00:00:52
#                                ETA: 01:12:17
#
# ################################################################################
#                        Learning iteration 12/1001
#
#                        Computation: 119753 steps/s (collection: 4.102s, learning 0.276s)
#              Mean action noise std: 0.05
#           Mean value_function loss: 0.6901
#                Mean surrogate loss: 0.0021
#                  Mean entropy loss: -6.0721
#                        Mean reward: 7.67
#                Mean episode length: 61.61
# Episode_Reward/rew_attitude_stability2: 0.0600
# Episode_Reward/rew_ang_vel_stability4: 0.0386
#            Episode_Reward/rew_pos2: 0.0599
#     Episode_Reward/rew_action_rate: -0.0000
#         Episode_Reward/rew_heading: 0.0492
#      Episode_Reward/rew_track_vel3: 0.1026
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 0.0291
#   Episode_Termination/bad_attitude: 0.9709
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 6815744
#                     Iteration time: 4.38s
#                       Time elapsed: 00:00:56
#                                ETA: 01:12:13
#
# ################################################################################
#                        Learning iteration 13/1001
#
#                        Computation: 121616 steps/s (collection: 4.061s, learning 0.250s)
#              Mean action noise std: 0.05
#           Mean value_function loss: 0.6601
#                Mean surrogate loss: 0.0010
#                  Mean entropy loss: -6.0529
#                        Mean reward: 8.33
#                Mean episode length: 61.47
# Episode_Reward/rew_attitude_stability2: 0.0600
# Episode_Reward/rew_ang_vel_stability4: 0.0387
#            Episode_Reward/rew_pos2: 0.0601
#     Episode_Reward/rew_action_rate: -0.0000
#         Episode_Reward/rew_heading: 0.0497
#      Episode_Reward/rew_track_vel3: 0.1058
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 0.0258
#   Episode_Termination/bad_attitude: 0.9742
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 7340032
#                     Iteration time: 4.31s
#                       Time elapsed: 00:01:01
#                                ETA: 01:12:03
#
# ################################################################################
#                        Learning iteration 14/1001
#
#                        Computation: 124181 steps/s (collection: 3.994s, learning 0.228s)
#              Mean action noise std: 0.05
#           Mean value_function loss: 0.5682
#                Mean surrogate loss: 0.0009
#                  Mean entropy loss: -6.0384
#                        Mean reward: 7.08
#                Mean episode length: 65.35
# Episode_Reward/rew_attitude_stability2: 0.0607
# Episode_Reward/rew_ang_vel_stability4: 0.0391
#            Episode_Reward/rew_pos2: 0.0603
#     Episode_Reward/rew_action_rate: -0.0000
#         Episode_Reward/rew_heading: 0.0504
#      Episode_Reward/rew_track_vel3: 0.1033
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 0.0273
#   Episode_Termination/bad_attitude: 0.9727
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 7864320
#                     Iteration time: 4.22s
#                       Time elapsed: 00:01:05
#                                ETA: 01:11:49
#
# ################################################################################
#                        Learning iteration 15/1001
#
#                        Computation: 125145 steps/s (collection: 3.972s, learning 0.218s)
#              Mean action noise std: 0.05
#           Mean value_function loss: 0.5568
#                Mean surrogate loss: 0.0008
#                  Mean entropy loss: -6.0223
#                        Mean reward: 8.42
#                Mean episode length: 72.81
# Episode_Reward/rew_attitude_stability2: 0.0621
# Episode_Reward/rew_ang_vel_stability4: 0.0399
#            Episode_Reward/rew_pos2: 0.0608
#     Episode_Reward/rew_action_rate: -0.0000
#         Episode_Reward/rew_heading: 0.0519
#      Episode_Reward/rew_track_vel3: 0.1070
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 0.0245
#   Episode_Termination/bad_attitude: 0.9755
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 8388608
#                     Iteration time: 4.19s
#                       Time elapsed: 00:01:09
#                                ETA: 01:11:33
#
# ################################################################################
#                        Learning iteration 16/1001
#
#                        Computation: 123917 steps/s (collection: 4.007s, learning 0.224s)
#              Mean action noise std: 0.05
#           Mean value_function loss: 0.4969
#                Mean surrogate loss: 0.0004
#                  Mean entropy loss: -6.0100
#                        Mean reward: 8.73
#                Mean episode length: 73.63
# Episode_Reward/rew_attitude_stability2: 0.0630
# Episode_Reward/rew_ang_vel_stability4: 0.0407
#            Episode_Reward/rew_pos2: 0.0611
#     Episode_Reward/rew_action_rate: -0.0000
#         Episode_Reward/rew_heading: 0.0524
#      Episode_Reward/rew_track_vel3: 0.1081
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 0.0257
#   Episode_Termination/bad_attitude: 0.9743
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 8912896
#                     Iteration time: 4.23s
#                       Time elapsed: 00:01:13
#                                ETA: 01:11:22
#
# ################################################################################
#                        Learning iteration 17/1001
#
#                        Computation: 125308 steps/s (collection: 3.958s, learning 0.226s)
#              Mean action noise std: 0.05
#           Mean value_function loss: 0.4746
#                Mean surrogate loss: 0.0003
#                  Mean entropy loss: -5.9890
#                        Mean reward: 8.72
#                Mean episode length: 72.50
# Episode_Reward/rew_attitude_stability2: 0.0639
# Episode_Reward/rew_ang_vel_stability4: 0.0415
#            Episode_Reward/rew_pos2: 0.0614
#     Episode_Reward/rew_action_rate: -0.0000
#         Episode_Reward/rew_heading: 0.0518
#      Episode_Reward/rew_track_vel3: 0.1088
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 0.0278
#   Episode_Termination/bad_attitude: 0.9722
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 9437184
#                     Iteration time: 4.18s
#                       Time elapsed: 00:01:18
#                                ETA: 01:11:09
#
# ################################################################################
#                        Learning iteration 18/1001
#
#                        Computation: 128704 steps/s (collection: 3.852s, learning 0.222s)
#              Mean action noise std: 0.05
#           Mean value_function loss: 0.4498
#                Mean surrogate loss: 0.0005
#                  Mean entropy loss: -5.9758
#                        Mean reward: 8.21
#                Mean episode length: 67.13
# Episode_Reward/rew_attitude_stability2: 0.0649
# Episode_Reward/rew_ang_vel_stability4: 0.0422
#            Episode_Reward/rew_pos2: 0.0615
#     Episode_Reward/rew_action_rate: -0.0000
#         Episode_Reward/rew_heading: 0.0532
#      Episode_Reward/rew_track_vel3: 0.1096
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 0.0290
#   Episode_Termination/bad_attitude: 0.9710
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 9961472
#                     Iteration time: 4.07s
#                       Time elapsed: 00:01:22
#                                ETA: 01:10:51
#
# ################################################################################
#                        Learning iteration 19/1001
#
#                        Computation: 127969 steps/s (collection: 3.876s, learning 0.221s)
#              Mean action noise std: 0.05
#           Mean value_function loss: 0.4128
#                Mean surrogate loss: -0.0000
#                  Mean entropy loss: -5.9572
#                        Mean reward: 9.17
#                Mean episode length: 68.33
# Episode_Reward/rew_attitude_stability2: 0.0658
# Episode_Reward/rew_ang_vel_stability4: 0.0430
#            Episode_Reward/rew_pos2: 0.0621
#     Episode_Reward/rew_action_rate: -0.0000
#         Episode_Reward/rew_heading: 0.0535
#      Episode_Reward/rew_track_vel3: 0.1122
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 0.0257
#   Episode_Termination/bad_attitude: 0.9743
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 10485760
#                     Iteration time: 4.10s
#                       Time elapsed: 00:01:26
#                                ETA: 01:10:35
#
# ################################################################################
#                        Learning iteration 20/1001
#
#                        Computation: 132080 steps/s (collection: 3.754s, learning 0.216s)
#              Mean action noise std: 0.05
#           Mean value_function loss: 0.4053
#                Mean surrogate loss: -0.0001
#                  Mean entropy loss: -5.9476
#                        Mean reward: 9.34
#                Mean episode length: 75.03
# Episode_Reward/rew_attitude_stability2: 0.0669
# Episode_Reward/rew_ang_vel_stability4: 0.0434
#            Episode_Reward/rew_pos2: 0.0623
#     Episode_Reward/rew_action_rate: -0.0000
#         Episode_Reward/rew_heading: 0.0549
#      Episode_Reward/rew_track_vel3: 0.1136
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 0.0311
#   Episode_Termination/bad_attitude: 0.9689
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 11010048
#                     Iteration time: 3.97s
#                       Time elapsed: 00:01:30
#                                ETA: 01:10:15
#
# ################################################################################
#                        Learning iteration 21/1001
#
#                        Computation: 128346 steps/s (collection: 3.866s, learning 0.219s)
#              Mean action noise std: 0.05
#           Mean value_function loss: 0.3578
#                Mean surrogate loss: -0.0007
#                  Mean entropy loss: -5.9381
#                        Mean reward: 8.09
#                Mean episode length: 70.51
# Episode_Reward/rew_attitude_stability2: 0.0683
# Episode_Reward/rew_ang_vel_stability4: 0.0446
#            Episode_Reward/rew_pos2: 0.0625
#     Episode_Reward/rew_action_rate: -0.0000
#         Episode_Reward/rew_heading: 0.0569
#      Episode_Reward/rew_track_vel3: 0.1145
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 0.0289
#   Episode_Termination/bad_attitude: 0.9711
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 11534336
#                     Iteration time: 4.08s
#                       Time elapsed: 00:01:34
#                                ETA: 01:10:01
#
# ################################################################################
#                        Learning iteration 22/1001
#
#                        Computation: 128929 steps/s (collection: 3.837s, learning 0.230s)
#              Mean action noise std: 0.06
#           Mean value_function loss: 0.3436
#                Mean surrogate loss: -0.0007
#                  Mean entropy loss: -5.9145
#                        Mean reward: 9.20
#                Mean episode length: 80.62
# Episode_Reward/rew_attitude_stability2: 0.0698
# Episode_Reward/rew_ang_vel_stability4: 0.0457
#            Episode_Reward/rew_pos2: 0.0632
#     Episode_Reward/rew_action_rate: -0.0000
#         Episode_Reward/rew_heading: 0.0570
#      Episode_Reward/rew_track_vel3: 0.1172
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 0.0296
#   Episode_Termination/bad_attitude: 0.9704
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 12058624
#                     Iteration time: 4.07s
#                       Time elapsed: 00:01:38
#                                ETA: 01:09:47
#
# ################################################################################
#                        Learning iteration 23/1001
#
#                        Computation: 133314 steps/s (collection: 3.707s, learning 0.226s)
#              Mean action noise std: 0.06
#           Mean value_function loss: 0.3367
#                Mean surrogate loss: -0.0008
#                  Mean entropy loss: -5.8917
#                        Mean reward: 10.00
#                Mean episode length: 80.76
# Episode_Reward/rew_attitude_stability2: 0.0719
# Episode_Reward/rew_ang_vel_stability4: 0.0471
#            Episode_Reward/rew_pos2: 0.0639
#     Episode_Reward/rew_action_rate: -0.0000
#         Episode_Reward/rew_heading: 0.0591
#      Episode_Reward/rew_track_vel3: 0.1205
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 0.0288
#   Episode_Termination/bad_attitude: 0.9712
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 12582912
#                     Iteration time: 3.93s
#                       Time elapsed: 00:01:42
#                                ETA: 01:09:29
#
# ################################################################################
#                        Learning iteration 24/1001
#
#                        Computation: 133579 steps/s (collection: 3.707s, learning 0.218s)
#              Mean action noise std: 0.06
#           Mean value_function loss: 0.3403
#                Mean surrogate loss: -0.0003
#                  Mean entropy loss: -5.8825
#                        Mean reward: 9.39
#                Mean episode length: 78.38
# Episode_Reward/rew_attitude_stability2: 0.0739
# Episode_Reward/rew_ang_vel_stability4: 0.0483
#            Episode_Reward/rew_pos2: 0.0646
#     Episode_Reward/rew_action_rate: -0.0000
#         Episode_Reward/rew_heading: 0.0601
#      Episode_Reward/rew_track_vel3: 0.1284
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 0.0329
#   Episode_Termination/bad_attitude: 0.9671
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 13107200
#                     Iteration time: 3.92s
#                       Time elapsed: 00:01:46
#                                ETA: 01:09:11
#
# ################################################################################
#                        Learning iteration 25/1001
#
#                        Computation: 137357 steps/s (collection: 3.601s, learning 0.216s)
#              Mean action noise std: 0.06
#           Mean value_function loss: 0.3255
#                Mean surrogate loss: -0.0007
#                  Mean entropy loss: -5.8643
#                        Mean reward: 9.72
#                Mean episode length: 80.50
# Episode_Reward/rew_attitude_stability2: 0.0763
# Episode_Reward/rew_ang_vel_stability4: 0.0499
#            Episode_Reward/rew_pos2: 0.0651
#     Episode_Reward/rew_action_rate: -0.0000
#         Episode_Reward/rew_heading: 0.0616
#      Episode_Reward/rew_track_vel3: 0.1296
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 0.0358
#   Episode_Termination/bad_attitude: 0.9642
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 13631488
#                     Iteration time: 3.82s
#                       Time elapsed: 00:01:50
#                                ETA: 01:08:51
#
# ################################################################################
#                        Learning iteration 26/1001
#
#                        Computation: 136074 steps/s (collection: 3.636s, learning 0.217s)
#              Mean action noise std: 0.06
#           Mean value_function loss: 0.3328
#                Mean surrogate loss: -0.0018
#                  Mean entropy loss: -5.8505
#                        Mean reward: 11.10
#                Mean episode length: 83.91
# Episode_Reward/rew_attitude_stability2: 0.0786
# Episode_Reward/rew_ang_vel_stability4: 0.0513
#            Episode_Reward/rew_pos2: 0.0657
#     Episode_Reward/rew_action_rate: -0.0000
#         Episode_Reward/rew_heading: 0.0655
#      Episode_Reward/rew_track_vel3: 0.1343
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 0.0366
#   Episode_Termination/bad_attitude: 0.9634
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 14155776
#                     Iteration time: 3.85s
#                       Time elapsed: 00:01:53
#                                ETA: 01:08:33
#
# ################################################################################
#                        Learning iteration 27/1001
#
#                        Computation: 134883 steps/s (collection: 3.665s, learning 0.222s)
#              Mean action noise std: 0.06
#           Mean value_function loss: 0.3154
#                Mean surrogate loss: -0.0022
#                  Mean entropy loss: -5.8308
#                        Mean reward: 11.52
#                Mean episode length: 86.30
# Episode_Reward/rew_attitude_stability2: 0.0809
# Episode_Reward/rew_ang_vel_stability4: 0.0529
#            Episode_Reward/rew_pos2: 0.0665
#     Episode_Reward/rew_action_rate: -0.0000
#         Episode_Reward/rew_heading: 0.0656
#      Episode_Reward/rew_track_vel3: 0.1405
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 0.0384
#   Episode_Termination/bad_attitude: 0.9616
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 14680064
#                     Iteration time: 3.89s
#                       Time elapsed: 00:01:57
#                                ETA: 01:08:17
#
# ################################################################################
#                        Learning iteration 28/1001
#
#                        Computation: 135328 steps/s (collection: 3.658s, learning 0.217s)
#              Mean action noise std: 0.06
#           Mean value_function loss: 0.3061
#                Mean surrogate loss: -0.0013
#                  Mean entropy loss: -5.8153
#                        Mean reward: 10.54
#                Mean episode length: 85.44
# Episode_Reward/rew_attitude_stability2: 0.0824
# Episode_Reward/rew_ang_vel_stability4: 0.0538
#            Episode_Reward/rew_pos2: 0.0669
#     Episode_Reward/rew_action_rate: -0.0000
#         Episode_Reward/rew_heading: 0.0681
#      Episode_Reward/rew_track_vel3: 0.1431
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 0.0390
#   Episode_Termination/bad_attitude: 0.9610
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 15204352
#                     Iteration time: 3.87s
#                       Time elapsed: 00:02:01
#                                ETA: 01:08:02
#
# ################################################################################
#                        Learning iteration 29/1001
#
#                        Computation: 135841 steps/s (collection: 3.641s, learning 0.219s)
#              Mean action noise std: 0.06
#           Mean value_function loss: 0.3307
#                Mean surrogate loss: -0.0014
#                  Mean entropy loss: -5.8067
#                        Mean reward: 12.21
#                Mean episode length: 96.27
# Episode_Reward/rew_attitude_stability2: 0.0868
# Episode_Reward/rew_ang_vel_stability4: 0.0565
#            Episode_Reward/rew_pos2: 0.0680
#     Episode_Reward/rew_action_rate: -0.0000
#         Episode_Reward/rew_heading: 0.0717
#      Episode_Reward/rew_track_vel3: 0.1536
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 0.0413
#   Episode_Termination/bad_attitude: 0.9587
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 15728640
#                     Iteration time: 3.86s
#                       Time elapsed: 00:02:05
#                                ETA: 01:07:47
#
# ################################################################################
#                        Learning iteration 30/1001
#
#                        Computation: 137575 steps/s (collection: 3.594s, learning 0.217s)
#              Mean action noise std: 0.06
#           Mean value_function loss: 0.3185
#                Mean surrogate loss: -0.0012
#                  Mean entropy loss: -5.7953
#                        Mean reward: 12.15
# ...
# --------------------------------------------------------------------------------
#                    Total timesteps: 517996544
#                     Iteration time: 3.98s
#                       Time elapsed: 01:04:30
#                                ETA: 00:00:54
#
# ################################################################################
#                       Learning iteration 988/1001
#
#                        Computation: 131511 steps/s (collection: 3.769s, learning 0.218s)
#              Mean action noise std: 1.61
#           Mean value_function loss: 0.9050
#                Mean surrogate loss: -0.0004
#                  Mean entropy loss: 7.4190
#                        Mean reward: 339.68
#                Mean episode length: 1234.79
# Episode_Reward/rew_attitude_stability2: 1.8444
# Episode_Reward/rew_ang_vel_stability4: 0.9338
#            Episode_Reward/rew_pos2: 1.1452
#     Episode_Reward/rew_action_rate: -0.0264
#         Episode_Reward/rew_heading: 2.4540
#      Episode_Reward/rew_track_vel3: 7.3317
#       Episode_Termination/time_out: 0.9656
# Episode_Termination/below_min_altitude: 0.0288
#   Episode_Termination/bad_attitude: 0.0056
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 518520832
#                     Iteration time: 3.99s
#                       Time elapsed: 01:04:34
#                                ETA: 00:00:50
#
# ################################################################################
#                       Learning iteration 989/1001
#
#                        Computation: 132675 steps/s (collection: 3.735s, learning 0.217s)
#              Mean action noise std: 1.61
#           Mean value_function loss: 0.9603
#                Mean surrogate loss: -0.0003
#                  Mean entropy loss: 7.4265
#                        Mean reward: 338.18
#                Mean episode length: 1236.16
# Episode_Reward/rew_attitude_stability2: 1.8255
# Episode_Reward/rew_ang_vel_stability4: 0.9279
#            Episode_Reward/rew_pos2: 1.0808
#     Episode_Reward/rew_action_rate: -0.0264
#         Episode_Reward/rew_heading: 2.4414
#      Episode_Reward/rew_track_vel3: 7.2874
#       Episode_Termination/time_out: 0.9667
# Episode_Termination/below_min_altitude: 0.0278
#   Episode_Termination/bad_attitude: 0.0055
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 519045120
#                     Iteration time: 3.95s
#                       Time elapsed: 01:04:38
#                                ETA: 00:00:47
#
# ################################################################################
#                       Learning iteration 990/1001
#
#                        Computation: 133664 steps/s (collection: 3.706s, learning 0.216s)
#              Mean action noise std: 1.62
#           Mean value_function loss: 0.9300
#                Mean surrogate loss: -0.0003
#                  Mean entropy loss: 7.4365
#                        Mean reward: 342.63
#                Mean episode length: 1243.24
# Episode_Reward/rew_attitude_stability2: 1.8393
# Episode_Reward/rew_ang_vel_stability4: 0.9355
#            Episode_Reward/rew_pos2: 1.0857
#     Episode_Reward/rew_action_rate: -0.0268
#         Episode_Reward/rew_heading: 2.4757
#      Episode_Reward/rew_track_vel3: 7.3509
#       Episode_Termination/time_out: 0.9665
# Episode_Termination/below_min_altitude: 0.0281
#   Episode_Termination/bad_attitude: 0.0054
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 519569408
#                     Iteration time: 3.92s
#                       Time elapsed: 01:04:42
#                                ETA: 00:00:43
#
# ################################################################################
#                       Learning iteration 991/1001
#
#                        Computation: 133152 steps/s (collection: 3.721s, learning 0.216s)
#              Mean action noise std: 1.62
#           Mean value_function loss: 0.8804
#                Mean surrogate loss: -0.0004
#                  Mean entropy loss: 7.4464
#                        Mean reward: 338.41
#                Mean episode length: 1238.20
# Episode_Reward/rew_attitude_stability2: 1.8345
# Episode_Reward/rew_ang_vel_stability4: 0.9314
#            Episode_Reward/rew_pos2: 1.1038
#     Episode_Reward/rew_action_rate: -0.0265
#         Episode_Reward/rew_heading: 2.4681
#      Episode_Reward/rew_track_vel3: 7.3096
#       Episode_Termination/time_out: 0.9686
# Episode_Termination/below_min_altitude: 0.0260
#   Episode_Termination/bad_attitude: 0.0054
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 520093696
#                     Iteration time: 3.94s
#                       Time elapsed: 01:04:46
#                                ETA: 00:00:39
#
# ################################################################################
#                       Learning iteration 992/1001
#
#                        Computation: 132680 steps/s (collection: 3.734s, learning 0.217s)
#              Mean action noise std: 1.62
#           Mean value_function loss: 0.9547
#                Mean surrogate loss: -0.0004
#                  Mean entropy loss: 7.4547
#                        Mean reward: 342.08
#                Mean episode length: 1250.00
# Episode_Reward/rew_attitude_stability2: 1.8382
# Episode_Reward/rew_ang_vel_stability4: 0.9341
#            Episode_Reward/rew_pos2: 1.0969
#     Episode_Reward/rew_action_rate: -0.0268
#         Episode_Reward/rew_heading: 2.4504
#      Episode_Reward/rew_track_vel3: 7.3494
#       Episode_Termination/time_out: 0.9692
# Episode_Termination/below_min_altitude: 0.0259
#   Episode_Termination/bad_attitude: 0.0049
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 520617984
#                     Iteration time: 3.95s
#                       Time elapsed: 01:04:50
#                                ETA: 00:00:35
#
# ################################################################################
#                       Learning iteration 993/1001
#
#                        Computation: 132678 steps/s (collection: 3.735s, learning 0.217s)
#              Mean action noise std: 1.63
#           Mean value_function loss: 0.9669
#                Mean surrogate loss: -0.0005
#                  Mean entropy loss: 7.4618
#                        Mean reward: 339.04
#                Mean episode length: 1238.65
# Episode_Reward/rew_attitude_stability2: 1.8335
# Episode_Reward/rew_ang_vel_stability4: 0.9334
#            Episode_Reward/rew_pos2: 1.0927
#     Episode_Reward/rew_action_rate: -0.0269
#         Episode_Reward/rew_heading: 2.4479
#      Episode_Reward/rew_track_vel3: 7.3310
#       Episode_Termination/time_out: 0.9694
# Episode_Termination/below_min_altitude: 0.0258
#   Episode_Termination/bad_attitude: 0.0048
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 521142272
#                     Iteration time: 3.95s
#                       Time elapsed: 01:04:54
#                                ETA: 00:00:31
#
# ################################################################################
#                       Learning iteration 994/1001
#
#                        Computation: 132523 steps/s (collection: 3.740s, learning 0.216s)
#              Mean action noise std: 1.63
#           Mean value_function loss: 0.8883
#                Mean surrogate loss: 0.0000
#                  Mean entropy loss: 7.4675
#                        Mean reward: 338.08
#                Mean episode length: 1226.61
# Episode_Reward/rew_attitude_stability2: 1.8433
# Episode_Reward/rew_ang_vel_stability4: 0.9326
#            Episode_Reward/rew_pos2: 1.1332
#     Episode_Reward/rew_action_rate: -0.0270
#         Episode_Reward/rew_heading: 2.4505
#      Episode_Reward/rew_track_vel3: 7.3361
#       Episode_Termination/time_out: 0.9698
# Episode_Termination/below_min_altitude: 0.0255
#   Episode_Termination/bad_attitude: 0.0047
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 521666560
#                     Iteration time: 3.96s
#                       Time elapsed: 01:04:58
#                                ETA: 00:00:27
#
# ################################################################################
#                       Learning iteration 995/1001
#
#                        Computation: 133340 steps/s (collection: 3.716s, learning 0.216s)
#              Mean action noise std: 1.63
#           Mean value_function loss: 0.9810
#                Mean surrogate loss: -0.0005
#                  Mean entropy loss: 7.4724
#                        Mean reward: 341.68
#                Mean episode length: 1240.04
# Episode_Reward/rew_attitude_stability2: 1.8353
# Episode_Reward/rew_ang_vel_stability4: 0.9325
#            Episode_Reward/rew_pos2: 1.0926
#     Episode_Reward/rew_action_rate: -0.0274
#         Episode_Reward/rew_heading: 2.4482
#      Episode_Reward/rew_track_vel3: 7.3162
#       Episode_Termination/time_out: 0.9684
# Episode_Termination/below_min_altitude: 0.0269
#   Episode_Termination/bad_attitude: 0.0047
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 522190848
#                     Iteration time: 3.93s
#                       Time elapsed: 01:05:02
#                                ETA: 00:00:23
#
# ################################################################################
#                       Learning iteration 996/1001
#
#                        Computation: 132682 steps/s (collection: 3.735s, learning 0.217s)
#              Mean action noise std: 1.63
#           Mean value_function loss: 0.9357
#                Mean surrogate loss: -0.0003
#                  Mean entropy loss: 7.4795
#                        Mean reward: 339.47
#                Mean episode length: 1237.19
# Episode_Reward/rew_attitude_stability2: 1.8316
# Episode_Reward/rew_ang_vel_stability4: 0.9306
#            Episode_Reward/rew_pos2: 1.0987
#     Episode_Reward/rew_action_rate: -0.0273
#         Episode_Reward/rew_heading: 2.4360
#      Episode_Reward/rew_track_vel3: 7.3042
#       Episode_Termination/time_out: 0.9697
# Episode_Termination/below_min_altitude: 0.0257
#   Episode_Termination/bad_attitude: 0.0046
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 522715136
#                     Iteration time: 3.95s
#                       Time elapsed: 01:05:06
#                                ETA: 00:00:19
#
# ################################################################################
#                       Learning iteration 997/1001
#
#                        Computation: 133067 steps/s (collection: 3.717s, learning 0.223s)
#              Mean action noise std: 1.64
#           Mean value_function loss: 1.0474
#                Mean surrogate loss: -0.0006
#                  Mean entropy loss: 7.4869
#                        Mean reward: 344.61
#                Mean episode length: 1246.15
# Episode_Reward/rew_attitude_stability2: 1.8231
# Episode_Reward/rew_ang_vel_stability4: 0.9255
#            Episode_Reward/rew_pos2: 1.1050
#     Episode_Reward/rew_action_rate: -0.0272
#         Episode_Reward/rew_heading: 2.4094
#      Episode_Reward/rew_track_vel3: 7.2624
#       Episode_Termination/time_out: 0.9685
# Episode_Termination/below_min_altitude: 0.0270
#   Episode_Termination/bad_attitude: 0.0045
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 523239424
#                     Iteration time: 3.94s
#                       Time elapsed: 01:05:10
#                                ETA: 00:00:15
#
# ################################################################################
#                       Learning iteration 998/1001
#
#                        Computation: 132443 steps/s (collection: 3.742s, learning 0.217s)
#              Mean action noise std: 1.64
#           Mean value_function loss: 0.9443
#                Mean surrogate loss: -0.0003
#                  Mean entropy loss: 7.4940
#                        Mean reward: 336.56
#                Mean episode length: 1230.08
# Episode_Reward/rew_attitude_stability2: 1.8411
# Episode_Reward/rew_ang_vel_stability4: 0.9335
#            Episode_Reward/rew_pos2: 1.1303
#     Episode_Reward/rew_action_rate: -0.0273
#         Episode_Reward/rew_heading: 2.4408
#      Episode_Reward/rew_track_vel3: 7.3581
#       Episode_Termination/time_out: 0.9680
# Episode_Termination/below_min_altitude: 0.0278
#   Episode_Termination/bad_attitude: 0.0043
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 523763712
#                     Iteration time: 3.96s
#                       Time elapsed: 01:05:14
#                                ETA: 00:00:11
#
# ################################################################################
#                       Learning iteration 999/1001
#
#                        Computation: 132304 steps/s (collection: 3.746s, learning 0.217s)
#              Mean action noise std: 1.64
#           Mean value_function loss: 0.9924
#                Mean surrogate loss: -0.0003
#                  Mean entropy loss: 7.5016
#                        Mean reward: 341.20
#                Mean episode length: 1241.53
# Episode_Reward/rew_attitude_stability2: 1.8363
# Episode_Reward/rew_ang_vel_stability4: 0.9339
#            Episode_Reward/rew_pos2: 1.1020
#     Episode_Reward/rew_action_rate: -0.0277
#         Episode_Reward/rew_heading: 2.4808
#      Episode_Reward/rew_track_vel3: 7.3395
#       Episode_Termination/time_out: 0.9678
# Episode_Termination/below_min_altitude: 0.0288
#   Episode_Termination/bad_attitude: 0.0035
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 524288000
#                     Iteration time: 3.96s
#                       Time elapsed: 01:05:18
#                                ETA: 00:00:07
#
# ################################################################################
#                       Learning iteration 1000/1001
#
#                        Computation: 132867 steps/s (collection: 3.730s, learning 0.216s)
#              Mean action noise std: 1.64
#           Mean value_function loss: 0.9064
#                Mean surrogate loss: -0.0003
#                  Mean entropy loss: 7.5086
#                        Mean reward: 346.17
#                Mean episode length: 1241.98
# Episode_Reward/rew_attitude_stability2: 1.8407
# Episode_Reward/rew_ang_vel_stability4: 0.9339
#            Episode_Reward/rew_pos2: 1.1124
#     Episode_Reward/rew_action_rate: -0.0276
#         Episode_Reward/rew_heading: 2.4926
#      Episode_Reward/rew_track_vel3: 7.3804
#       Episode_Termination/time_out: 0.9684
# Episode_Termination/below_min_altitude: 0.0283
#   Episode_Termination/bad_attitude: 0.0033
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 524812288
#                     Iteration time: 3.95s
#                       Time elapsed: 01:05:22
#                                ETA: 00:00:03
#
#
# --- Todos los experimentos han finalizado ---

# %% [markdown]
# ``Análisis de los datos``

# %%
import csv
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

seed = 42
n=5

df_results_grid_actions = pd.read_csv(path_resultados+"/resultados_grid_PPO.csv")

# %%
def get_group(value):
    if f"_{experiment_name}" in value:
        return task_name

df_results_grid_actions["tarea"] = df_results_grid_actions["id_run_name"].apply(get_group)

# %%
df_copy = df_results_grid_actions.copy()
df_results_grid_actions.sample(n, random_state=seed)
# Out:
#                 id_run_name  iteration      reward  max_reward  std_reward  \
# 5   ppo_random_command11_11        500  343.377062  384.679901   23.872597
# 0   ppo_random_command11_11          0    7.210699   31.774046    5.341968
# 9   ppo_random_command11_11        900  336.125958  382.463043   24.401892
# 10  ppo_random_command11_11       1000  346.165470  386.482513   26.695113
# 2   ppo_random_command11_11        200  116.590707  279.255005   50.570994
#
#     num_envs_train  mean_Episode_Reward/rew_attitude_stability2  \
# 5             4096                                     1.854449
# 0             4096                                     0.044107
# 9             4096                                     1.849036
# 10            4096                                     1.840717
# 2             4096                                     0.773926
#
#     mean_Episode_Reward/rew_ang_vel_stability4  mean_Episode_Reward/rew_pos2  \
# 5                                     0.953060                      1.096505
# 0                                     0.028710                      0.050792
# 9                                     0.937644                      0.912802
# 10                                    0.933910                      1.112417
# 2                                     0.442675                      0.221480
#
#     mean_Episode_Reward/rew_action_rate  mean_Episode_Reward/rew_heading  \
# 5                         -1.637898e-03                         2.581301
# 0                         -8.005556e-07                         0.037599
# 9                         -1.894348e-02                         2.502647
# 10                        -2.764728e-02                         2.492590
# 2                         -2.465242e-05                         0.579574
#
#     mean_Episode_Reward/rew_track_vel3  mean_Episode_Termination/time_out  \
# 5                             7.245661                           0.943876
# 0                             0.077218                           0.026655
# 9                             7.324504                           0.981937
# 10                            7.380430                           0.968416
# 2                             3.070206                           0.030083
#
#     mean_Episode_Termination/below_min_altitude  \
# 5                                      0.056124
# 0                                      0.002415
# 9                                      0.016399
# 10                                     0.028322
# 2                                      0.219662
#
#     mean_Episode_Termination/bad_attitude  \
# 5                                0.000000
# 0                                0.415085
# 9                                0.001663
# 10                               0.003262
# 2                                0.750256
#
#     mean_Episode_Termination/safety_shutdown      tarea
# 5                                        0.0  Command11
# 0                                        0.0  Command11
# 9                                        0.0  Command11
# 10                                       0.0  Command11
# 2                                        0.0  Command11

# %%
df_results_grid_actions.set_index(['tarea','id_run_name'],inplace=True)
top5 = (
    df_results_grid_actions.groupby(level="tarea")
      .apply(lambda g: g.sort_values("reward", ascending=False).head(5))
)

# Eliminar el nivel adicional que introduce groupby+apply
top5.index = top5.index.droplevel(0)

top5
# Out:
#                                    iteration      reward  max_reward  \
# tarea     id_run_name
# Command11 ppo_random_command11_11       1000  346.165470  386.482513
#           ppo_random_command11_11        800  344.530014  378.671631
#           ppo_random_command11_11        500  343.377062  384.679901
#           ppo_random_command11_11        600  337.587253  387.524475
#           ppo_random_command11_11        900  336.125958  382.463043
#
#                                    std_reward  num_envs_train  \
# tarea     id_run_name
# Command11 ppo_random_command11_11   26.695113            4096
#           ppo_random_command11_11   21.126756            4096
#           ppo_random_command11_11   23.872597            4096
#           ppo_random_command11_11   18.912307            4096
#           ppo_random_command11_11   24.401892            4096
#
#                                    mean_Episode_Reward/rew_attitude_stability2  \
# tarea     id_run_name
# Command11 ppo_random_command11_11                                     1.840717
#           ppo_random_command11_11                                     1.866427
#           ppo_random_command11_11                                     1.854449
#           ppo_random_command11_11                                     1.884694
#           ppo_random_command11_11                                     1.849036
#
#                                    mean_Episode_Reward/rew_ang_vel_stability4  \
# tarea     id_run_name
# Command11 ppo_random_command11_11                                    0.933910
#           ppo_random_command11_11                                    0.941058
#           ppo_random_command11_11                                    0.953060
#           ppo_random_command11_11                                    0.953158
#           ppo_random_command11_11                                    0.937644
#
#                                    mean_Episode_Reward/rew_pos2  \
# tarea     id_run_name
# Command11 ppo_random_command11_11                      1.112417
#           ppo_random_command11_11                      0.964188
#           ppo_random_command11_11                      1.096505
#           ppo_random_command11_11                      0.804871
#           ppo_random_command11_11                      0.912802
#
#                                    mean_Episode_Reward/rew_action_rate  \
# tarea     id_run_name
# Command11 ppo_random_command11_11                            -0.027647
#           ppo_random_command11_11                            -0.012586
#           ppo_random_command11_11                            -0.001638
#           ppo_random_command11_11                            -0.004053
#           ppo_random_command11_11                            -0.018943
#
#                                    mean_Episode_Reward/rew_heading  \
# tarea     id_run_name
# Command11 ppo_random_command11_11                         2.492590
#           ppo_random_command11_11                         2.509824
#           ppo_random_command11_11                         2.581301
#           ppo_random_command11_11                         2.548385
#           ppo_random_command11_11                         2.502647
#
#                                    mean_Episode_Reward/rew_track_vel3  \
# tarea     id_run_name
# Command11 ppo_random_command11_11                            7.380430
#           ppo_random_command11_11                            7.362505
#           ppo_random_command11_11                            7.245661
#           ppo_random_command11_11                            7.352054
#           ppo_random_command11_11                            7.324504
#
#                                    mean_Episode_Termination/time_out  \
# tarea     id_run_name
# Command11 ppo_random_command11_11                           0.968416
#           ppo_random_command11_11                           0.984360
#           ppo_random_command11_11                           0.943876
#           ppo_random_command11_11                           0.983829
#           ppo_random_command11_11                           0.981937
#
#                                    mean_Episode_Termination/below_min_altitude  \
# tarea     id_run_name
# Command11 ppo_random_command11_11                                     0.028322
#           ppo_random_command11_11                                     0.014645
#           ppo_random_command11_11                                     0.056124
#           ppo_random_command11_11                                     0.015440
#           ppo_random_command11_11                                     0.016399
#
#                                    mean_Episode_Termination/bad_attitude  \
# tarea     id_run_name
# Command11 ppo_random_command11_11                               0.003262
#           ppo_random_command11_11                               0.000996
#           ppo_random_command11_11                               0.000000
#           ppo_random_command11_11                               0.000731
#           ppo_random_command11_11                               0.001663
#
#                                    mean_Episode_Termination/safety_shutdown
# tarea     id_run_name
# Command11 ppo_random_command11_11                                       0.0
#           ppo_random_command11_11                                       0.0
#           ppo_random_command11_11                                       0.0
#           ppo_random_command11_11                                       0.0
#           ppo_random_command11_11                                       0.0

# %%
mean_rewards = df_results_grid_actions.groupby(["tarea", "id_run_name"])["reward"].mean()

for tarea, subdf in mean_rewards.groupby(level="tarea"):
    plt.figure(figsize=(12,5))
    
    # Convertir a DataFrame y resetear index para graficar
    plot_df = subdf.reset_index()
    plot_df = plot_df.sort_values("reward", ascending=False)
    
    plt.bar(plot_df["id_run_name"], plot_df["reward"])
    plt.title(f"Reward media por modelo - {tarea}")
    plt.xlabel("id_run_name")
    plt.ylabel("Reward media")
    plt.xticks(rotation=90)
    plt.tight_layout()
    plt.show()

# %%
df_callbacks = pd.read_csv(path_resultados+"/reward_best_models.csv",index_col='id_run_name')
top5_models = df_callbacks.nlargest(5,columns="reward")
top5_models
# Out:
#                          iteration      reward  max_reward  std_reward  \
# id_run_name
# ppo_random_command11_11        862  348.842303  383.204346   19.679655
#
#                          num_envs_train  \
# id_run_name
# ppo_random_command11_11            4096
#
#                          mean_Episode_Reward/rew_attitude_stability2  \
# id_run_name
# ppo_random_command11_11                                     1.859552
#
#                          mean_Episode_Reward/rew_ang_vel_stability4  \
# id_run_name
# ppo_random_command11_11                                    0.941792
#
#                          mean_Episode_Reward/rew_pos2  \
# id_run_name
# ppo_random_command11_11                      1.016133
#
#                          mean_Episode_Reward/rew_action_rate  \
# id_run_name
# ppo_random_command11_11                            -0.016763
#
#                          mean_Episode_Reward/rew_heading  \
# id_run_name
# ppo_random_command11_11                         2.502991
#
#                          mean_Episode_Reward/rew_track_vel3  \
# id_run_name
# ppo_random_command11_11                            7.368308
#
#                          mean_Episode_Termination/time_out  \
# id_run_name
# ppo_random_command11_11                            0.98457
#
#                          mean_Episode_Termination/below_min_altitude  \
# id_run_name
# ppo_random_command11_11                                     0.015186
#
#                          mean_Episode_Termination/bad_attitude  \
# id_run_name
# ppo_random_command11_11                               0.000244
#
#                          mean_Episode_Termination/safety_shutdown
# id_run_name
# ppo_random_command11_11                                       0.0

# %% [markdown]
# Graficamos cómo fue el entrenamiento para los 5 mejores modelos según los callbacks:

# %%
import matplotlib.pyplot as plt
import numpy as np

# Aseguramos que `top5_auc` tenga 'tarea' e 'id_run_name' como columnas, no solo en el índice
df_callbacks = pd.read_csv(path_resultados+"/reward_best_models.csv",index_col='id_run_name')
top5_models = df_callbacks.nlargest(5,columns="reward")
top5_reset = top5_models.reset_index()
top5_reset["tarea"] = top5_reset["id_run_name"].apply(get_group)


# Convertir el índice jerárquico en columnas (para acceder a 'tarea' y 'id_run_name')
df_copy_reset = df_copy.reset_index()

# Unimos `top5_auc_reset` con `df_copy_reset` en las columnas comunes: 'tarea' y 'id_run_name'
merged_df = pd.merge(df_copy_reset, top5_reset[['tarea', 'id_run_name']], on=['tarea', 'id_run_name'], how='inner')

# Usamos una lista de colores para asignar un color diferente a cada modelo
colors = plt.cm.viridis(np.linspace(0, 1, len(merged_df['id_run_name'].unique())))

# Ahora, procedemos a graficar
for tarea, task_df in merged_df.groupby('tarea'):
    plt.figure(figsize=(10, 6))
    
    # Iteramos sobre los modelos (id_run_name) para esta tarea
    for i, (run_name, subdf) in enumerate(task_df.groupby('id_run_name')):
        # Graficamos la evolución de la recompensa a lo largo de las iteraciones
        plt.plot(subdf['iteration'], subdf['reward'], label=run_name, color=colors[i])
    
    plt.xlabel('Iteración')
    plt.ylabel('Reward')
    plt.title(f'Evolución de la Recompensa - Tarea: {tarea}')
    plt.legend(title="Modelos", bbox_to_anchor=(1.05, 1), loc='upper left')
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ``Cojo los 5 modelos mejores de todos de los callbacks``

# %%
import os
df_callbacks = pd.read_csv(path_resultados+"/reward_best_models.csv",index_col='id_run_name')
top5_models = df_callbacks.nlargest(5,columns="reward")

powershell_script_test = os.path.join(cfg_dir, "run_tests.ps1")

with open(powershell_script_test, "w") as f:
    f.write("$ErrorActionPreference = 'Stop'\n\n")
    
    for run_id, row in top5_models.iterrows():
        # Extraemos el número del id (ej: de 'ppo_random_hover_4' sacamos '4')
        experiment_number = run_id.split('_')[-1]
        
        # Construimos la ruta exacta del checkpoint
        # Nota: Asegúrate de que path_resultados termine en / o usar os.path.join
        checkpoint_path = f"{path_resultados}/best_model_{run_id}_{int(row['num_envs_train'])}.pt"
        f.write(f'Write-Host "Ejecutando Test final para Experimento {experiment_number}..."\n')
        
        # Usamos el experiment_number extraído para la tarea (--task)
        # Se añaden flags típicos de play.py: --num_envs 1 y se quita --headless para ver el visualizador
        f.write(f'& "{isaaclab_bat}" -p "{play_script}" '
                f'--task {id_task}-{experiment_number} '
                f'--num_envs 1 '
                f' --headless '
                f'--checkpoint "{checkpoint_path}"\n\n')
        
print(f"Script de test generado en: {powershell_script_test}")
# Out:
# Script de test generado en: C:/Users/Teresa/Documents/GitHub/navsim/isaac_lab/aerotaxi/env_command/env_15/grid_hiperparametros/cfg_files\run_tests.ps1

# %% [markdown]
# ### Test con 1 entorno

# %%
# Ejecuta el entrenamiento de forma automática
# !powershell -ExecutionPolicy Bypass -File "{powershell_script}"
import subprocess
import sys

# Ruta al script que generaste
powershell_script_path = powershell_script_test 

print(f"Iniciando ejecución de: {powershell_script_path}\n")

# Ejecutamos el proceso capturando la salida en tiempo real
process = subprocess.Popen(
    ["powershell.exe", "-ExecutionPolicy", "Bypass", "-File", powershell_script_path],
    stdout=subprocess.PIPE,
    stderr=subprocess.STDOUT, # Redirigimos errores a la salida estándar para verlos
    text=True,
    bufsize=1
)

# Leemos la salida línea a línea conforme se genera
try:
    for line in process.stdout:
        print(line, end="") # Imprime la salida de PowerShell en la celda
        sys.stdout.flush()   # Fuerza a Jupyter a mostrar la línea inmediatamente
except KeyboardInterrupt:
    process.kill()
    print("\nEntrenamiento cancelado por el usuario.")

process.wait()
print("\n--- Todos los experimentos de test han finalizado ---")
# Out:
# Iniciando ejecución de: C:/Users/Teresa/Documents/GitHub/navsim/isaac_lab/aerotaxi/env_command/env_15/grid_hiperparametros/cfg_files\run_tests.ps1
#
# Ejecutando Test final para Experimento 11...
# [INFO] Using python from: C:\Users\Teresa\miniconda3\envs\env_isaaclab\python.exe
# [INFO][AppLauncher]: Using device: cuda:0
# [INFO][AppLauncher]: Loading experience file: C:\Users\Teresa\miniconda3\envs\env_isaaclab\Lib\site-packages\isaaclab\apps\isaaclab.python.headless.kit
# Loading user config located at: 'c:/users/teresa/miniconda3/envs/env_isaaclab/lib/site-packages/isaacsim/kit/data/Kit/Isaac-Sim/5.1/user.config.json'
# [Info] [carb] Logging to file: c:/users/teresa/miniconda3/envs/env_isaaclab/lib/site-packages/isaacsim/kit/logs/Kit/Isaac-Sim/5.1/kit_20260316_133017.log
# 2026-03-16T12:30:17Z s] [Warning] [omni.usd_config.extension] Enable omni.materialx.libs extension to use MaterialX
# 2026-03-16T12:30:18Z s] [Warning] [carb] Acquiring non optional plugin interface which is not listed as dependency: [omni::physx::IPhysxBenchmarks v1.0] (plugin: <default plugin>), by client: omni.physics.physx.plugin. Add it to CARB_PLUGIN_IMPL_DEPS() macro of a client.
# 2026-03-16T12:30:18Z s] [Warning] [omni.isaac.dynamic_control] omni.isaac.dynamic_control is deprecated as of Isaac Sim 4.5. No action is needed from end-users.
# 2026-03-16T12:30:20Z [2,475ms] [Warning] [gpu.foundation.plugin] Skipping unsupported non-NVIDIA GPU: AMD Radeon(TM) Graphics
# 2026-03-16T12:30:20Z [2,476ms] [Warning] [gpu.foundation.plugin] Skipping unsupported non-NVIDIA GPU: AMD Radeon(TM) Graphics
#
# |---------------------------------------------------------------------------------------------|
# | Driver Version: 581.29        | Graphics API: D3D12
# |=============================================================================================|
# | GPU | Name                             | Active | LDA | GPU Memory | Vendor-ID | LUID       |
# |     |                                  |        |     |            | Device-ID | UUID       |
# |     |                                  |        |     |            | Bus-ID    |            |
# |---------------------------------------------------------------------------------------------|
# | 0   | NVIDIA GeForce RTX 5080          | Yes: 0 |     | 15889   MB | 10de      | 08570100.. |
# |     |                                  |        |     |            | 2c02      | 0          |
# |     |                                  |        |     |            | 1         |            |
# |---------------------------------------------------------------------------------------------|
# | 1   | AMD Radeon(TM) Graphics          |        |     | 1995    MB | 1002      | 676a0100.. |
# |     |                                  |        |     |            | 13c0      | 0          |
# |     |                                  |        |     |            | N/A       |            |
# |=============================================================================================|
# | OS: Windows 11 Pro, Version: 10.0 (25H2), Build: 26200, Kernel: 10.0.26100.8036
# | Processor: AMD Ryzen 9 9950X 16-Core Processor
# | Cores: 16 | Logical Cores: 32
# |---------------------------------------------------------------------------------------------|
# | Total Memory (MB): 128627 | Free Memory: 97004
# | Total Page/Swap (MB): 136819 | Free Page/Swap: 96392
# |---------------------------------------------------------------------------------------------|
# C:\Users\Teresa\Documents\GitHub\navsim\isaac_lab\aerotaxi\env_command\env_15\flight_plan.py:29: UserWarning: Treat the new Tool classes introduced in v1.5 as experimental for now; the API and rcParam may change in future versions.
#   plt.rcParams["toolbar"] = "toolmanager"
# [INFO]: Parsing configuration from: aerotaxi.env_command.env_15.env:UAVEnvCfg
# [INFO]: Parsing configuration from: aerotaxi.env_command.env_15.grid_hiperparametros.cfg_files.ppo_random_command11_11_cfg:Command11PPORunnerCfg
# [INFO] Loading experiment from directory: C:\Users\Teresa\Documents\GitHub\navsim\isaac_lab\aerotaxi\env_command\env_15\logs\rsl_rl\command11
# Setting seed: 42
# [INFO]: Base environment:
# 	Environment device    : cuda:0
# 	Environment seed      : 42
# 	Physics step-size     : 0.005
# 	Rendering step-size   : 0.02
# 	Environment step-size : 0.02
# [INFO]: Time taken for scene creation : 1.013338 seconds
# [INFO]: Scene manager:  <class InteractiveScene>
# 	Number of environments: 1
# 	Environment spacing   : 200.0
# 	Source prim name      : /World/envs/env_0
# 	Global prim paths     : []
# 	Replicate physics     : False
# [INFO]: Starting the simulation. This may take a few seconds. Please wait...
# [INFO]: Time taken for simulation start : 0.228611 seconds
# [INFO] Command Manager:  <CommandManager> contains 1 active terms.
# +--------------------------------------+
# |         Active Command Terms         |
# +-------+-------------+----------------+
# | Index | Name        |      Type      |
# +-------+-------------+----------------+
# |   0   | vel_command | UAVcommandTerm |
# +-------+-------------+----------------+
#
# [INFO] Event Manager:  <EventManager> contains 1 active terms.
# +-----------------------------------+
# | Active Event Terms in Mode: 'reset' |
# +----------+------------------------+
# |  Index   | Name                   |
# +----------+------------------------+
# |    0     | reset_pos              |
# |    1     | randomize_mass         |
# |    2     | randomize_wind         |
# +----------+------------------------+
#
# [INFO] Recorder Manager:  <RecorderManager> contains 0 active terms.
# +---------------------+
# | Active Recorder Terms |
# +-----------+---------+
# |   Index   | Name    |
# +-----------+---------+
# +-----------+---------+
#
# [INFO] Action Manager:  <ActionManager> contains 1 active terms.
# +-----------------------------------+
# |   Active Action Terms (shape: 4)  |
# +--------+-------------+------------+
# | Index  | Name        |  Dimension |
# +--------+-------------+------------+
# |   0    | rotors_vel  |          4 |
# +--------+-------------+------------+
#
# [INFO] Observation Manager: <ObservationManager> contains 2 groups.
# +---------------------------------------------------------+
# | Active Observation Terms in Group: 'policy' (shape: (16,)) |
# +-----------+---------------------------------+-----------+
# |   Index   | Name                            |   Shape   |
# +-----------+---------------------------------+-----------+
# |     0     | lin_vel                         |    (3,)   |
# |     1     | ang_vel                         |    (3,)   |
# |     2     | projected_gravity               |    (3,)   |
# |     3     | target_vel                      |    (3,)   |
# |     4     | target_future                   |    (3,)   |
# |     5     | yaw_error                       |    (1,)   |
# +-----------+---------------------------------+-----------+
# +---------------------------------------------------------+
# | Active Observation Terms in Group: 'critic' (shape: (16,)) |
# +-----------+---------------------------------+-----------+
# |   Index   | Name                            |   Shape   |
# +-----------+---------------------------------+-----------+
# |     0     | lin_vel                         |    (3,)   |
# |     1     | ang_vel                         |    (3,)   |
# |     2     | projected_gravity               |    (3,)   |
# |     3     | target_vel                      |    (3,)   |
# |     4     | target_future                   |    (3,)   |
# |     5     | yaw_error                       |    (1,)   |
# +-----------+---------------------------------+-----------+
#
# [INFO] Termination Manager:  <TerminationManager> contains 4 active terms.
# +---------------------------------------+
# |        Active Termination Terms       |
# +-------+--------------------+----------+
# | Index | Name               | Time Out |
# +-------+--------------------+----------+
# |   0   | time_out           |   True   |
# |   1   | below_min_altitude |  False   |
# |   2   | bad_attitude       |  False   |
# |   3   | safety_shutdown    |  False   |
# +-------+--------------------+----------+
#
# [INFO] Reward Manager:  <RewardManager> contains 6 active terms.
# +------------------------------------------+
# |           Active Reward Terms            |
# +-------+-------------------------+--------+
# | Index | Name                    | Weight |
# +-------+-------------------------+--------+
# |   0   | rew_attitude_stability2 |    2.0 |
# |   1   | rew_ang_vel_stability4  |    1.0 |
# |   2   | rew_pos2                |    2.0 |
# |   3   | rew_action_rate         |    0.1 |
# |   4   | rew_heading             |    3.0 |
# |   5   | rew_track_vel3          |    8.0 |
# +-------+-------------------------+--------+
#
# [INFO] Curriculum Manager:  <CurriculumManager> contains 0 active terms.
# +----------------------+
# | Active Curriculum Terms |
# +-----------+----------+
# |   Index   | Name     |
# +-----------+----------+
# +-----------+----------+
#
# [INFO]: Completed setting up the environment...
# 2026-03-16T12:30:23Z [5,595ms] [Warning] [omni.physx.fabric.plugin] FabricManager::initializePointInstancer mismatched prototypes on point instancer: /Visuals/target_commands.
# 2026-03-16T12:30:23Z [5,595ms] [Warning] [omni.physx.fabric.plugin] FabricManager::initializePointInstancer mismatched prototypes on point instancer: /Visuals/TargetArrow.
# 2026-03-16T12:30:23Z [5,595ms] [Warning] [omni.physx.fabric.plugin] FabricManager::initializePointInstancer mismatched prototypes on point instancer: /Visuals/DroneArrow.
# [INFO]: Loading model checkpoint from: C:\Users\Teresa\Documents\GitHub\navsim\tmp\tmpTeresa\resultados_grid_command_v11\best_model_ppo_random_command11_11_4096.pt
# C:\Users\Teresa\miniconda3\envs\env_isaaclab\Lib\site-packages\rsl_rl\utils\utils.py:244: UserWarning: The observation configuration dictionary 'obs_groups' must contain the 'policy' key. As an observation group with the name 'policy' was found, this is assumed to be the observation set. Consider adding the 'policy' key to the 'obs_groups' dictionary for clarity. This behavior will be removed in a future version.
#   warnings.warn(
# C:\Users\Teresa\miniconda3\envs\env_isaaclab\Lib\site-packages\rsl_rl\utils\utils.py:282: UserWarning: The observation configuration dictionary 'obs_groups' must contain the 'critic' key. As an observation group with the name 'critic' was found, this is assumed to be the observation set. Consider adding the 'critic' key to the 'obs_groups' dictionary for clarity. This behavior will be removed in a future version.
#   warnings.warn(
# --------------------------------------------------------------------------------
# Resolved observation sets:
# 	 policy :  ['policy']
# 	 critic :  ['critic']
# --------------------------------------------------------------------------------
# Actor MLP: MLP(
#   (0): Linear(in_features=16, out_features=128, bias=True)
#   (1): ELU(alpha=1.0)
#   (2): Linear(in_features=128, out_features=128, bias=True)
#   (3): ELU(alpha=1.0)
#   (4): Linear(in_features=128, out_features=128, bias=True)
#   (5): ELU(alpha=1.0)
#   (6): Linear(in_features=128, out_features=4, bias=True)
# )
# Critic MLP: MLP(
#   (0): Linear(in_features=16, out_features=256, bias=True)
#   (1): ELU(alpha=1.0)
#   (2): Linear(in_features=256, out_features=256, bias=True)
#   (3): ELU(alpha=1.0)
#   (4): Linear(in_features=256, out_features=256, bias=True)
#   (5): ELU(alpha=1.0)
#   (6): Linear(in_features=256, out_features=1, bias=True)
# )
#
# --- Todos los experimentos de test han finalizado ---

# %%
df_callbacks = pd.read_csv(path_resultados+"/reward_best_models.csv",index_col='id_run_name')
top5_models = df_callbacks.nlargest(5,columns="reward")

# %%
df_rewards_play = pd.read_csv(path_resultados+'/rewards_play_PPO.csv')

# %%
df_rewards_play
# Out:
#                id_run_name      reward  max_reward  std  num_envs_test  \
# 0  ppo_random_command11_11  272.287348  272.287348  0.0              1
#
#                                           checkpoint  \
# 0  C:/Users/Teresa/Documents/GitHub/navsim/tmp/tm...
#
#    mean_Episode_Reward/rew_attitude_stability2  \
# 0                                          0.0
#
#    mean_Episode_Reward/rew_ang_vel_stability4  mean_Episode_Reward/rew_pos2  \
# 0                                         0.0                           0.0
#
#    mean_Episode_Reward/rew_action_rate  mean_Episode_Reward/rew_heading  \
# 0                                  0.0                              0.0
#
#    mean_Episode_Reward/rew_track_vel3  mean_Episode_Termination/time_out  \
# 0                                 0.0                                0.0
#
#    mean_Episode_Termination/below_min_altitude  \
# 0                                          0.0
#
#    mean_Episode_Termination/bad_attitude  \
# 0                                    0.0
#
#    mean_Episode_Termination/safety_shutdown
# 0                                       0.0

# %% [markdown]
# ### Test con 64 entornos

# %%
import os
df_callbacks = pd.read_csv(path_resultados+"/reward_best_models.csv",index_col='id_run_name')
top5_models = df_callbacks.nlargest(5,columns="reward")

powershell_script_test_2 = os.path.join(cfg_dir, "run_tests_2.ps1")

with open(powershell_script_test_2, "w") as f:
    f.write("$ErrorActionPreference = 'Stop'\n\n")
    
    for run_id, row in top5_models.iterrows():
        # Extraemos el número del id (ej: de 'ppo_random_hover_4' sacamos '4')
        experiment_number = run_id.split('_')[-1]
        
        # Construimos la ruta exacta del checkpoint
        # Nota: Asegúrate de que path_resultados termine en / o usar os.path.join
        checkpoint_path = f"{path_resultados}/best_model_{run_id}_{int(row['num_envs_train'])}.pt"
        f.write(f'Write-Host "Ejecutando Test final para Experimento {experiment_number}..."\n')
        
        # Usamos el experiment_number extraído para la tarea (--task)
        # Se añaden flags típicos de play.py: --num_envs 1 y se quita --headless para ver el visualizador
        f.write(f'& "{isaaclab_bat}" -p "{play_script}" '
                f'--task {id_task}-{experiment_number} '
                f'--num_envs 64 '
                f' --headless '
                f'--checkpoint "{checkpoint_path}"\n\n')
        
print(f"Script de test generado en: {powershell_script_test_2}")
# Out:
# Script de test generado en: C:/Users/Teresa/Documents/GitHub/navsim/isaac_lab/aerotaxi/env_command/env_15/grid_hiperparametros/cfg_files\run_tests_2.ps1

# %%
# Ejecuta el entrenamiento de forma automática
# !powershell -ExecutionPolicy Bypass -File "{powershell_script}"
import subprocess
import sys

# Ruta al script que generaste
powershell_script_path = powershell_script_test_2 

print(f"Iniciando ejecución de: {powershell_script_path}\n")

# Ejecutamos el proceso capturando la salida en tiempo real
process = subprocess.Popen(
    ["powershell.exe", "-ExecutionPolicy", "Bypass", "-File", powershell_script_path],
    stdout=subprocess.PIPE,
    stderr=subprocess.STDOUT, # Redirigimos errores a la salida estándar para verlos
    text=True,
    bufsize=1
)

# Leemos la salida línea a línea conforme se genera
try:
    for line in process.stdout:
        print(line, end="") # Imprime la salida de PowerShell en la celda
        sys.stdout.flush()   # Fuerza a Jupyter a mostrar la línea inmediatamente
except KeyboardInterrupt:
    process.kill()
    print("\nEntrenamiento cancelado por el usuario.")

process.wait()
print("\n--- Todos los experimentos de test han finalizado ---")
# Out:
# Iniciando ejecución de: C:/Users/Teresa/Documents/GitHub/navsim/isaac_lab/aerotaxi/env_command/env_15/grid_hiperparametros/cfg_files\run_tests_2.ps1
#
# Ejecutando Test final para Experimento 11...
# [INFO] Using python from: C:\Users\Teresa\miniconda3\envs\env_isaaclab\python.exe
# [INFO][AppLauncher]: Using device: cuda:0
# [INFO][AppLauncher]: Loading experience file: C:\Users\Teresa\miniconda3\envs\env_isaaclab\Lib\site-packages\isaaclab\apps\isaaclab.python.headless.kit
# Loading user config located at: 'c:/users/teresa/miniconda3/envs/env_isaaclab/lib/site-packages/isaacsim/kit/data/Kit/Isaac-Sim/5.1/user.config.json'
# [Info] [carb] Logging to file: c:/users/teresa/miniconda3/envs/env_isaaclab/lib/site-packages/isaacsim/kit/logs/Kit/Isaac-Sim/5.1/kit_20260316_133150.log
# 2026-03-16T12:31:51Z s] [Warning] [omni.usd_config.extension] Enable omni.materialx.libs extension to use MaterialX
# 2026-03-16T12:31:51Z s] [Warning] [carb] Acquiring non optional plugin interface which is not listed as dependency: [omni::physx::IPhysxBenchmarks v1.0] (plugin: <default plugin>), by client: omni.physics.physx.plugin. Add it to CARB_PLUGIN_IMPL_DEPS() macro of a client.
# 2026-03-16T12:31:51Z s] [Warning] [omni.isaac.dynamic_control] omni.isaac.dynamic_control is deprecated as of Isaac Sim 4.5. No action is needed from end-users.
# 2026-03-16T12:31:53Z [2,416ms] [Warning] [gpu.foundation.plugin] Skipping unsupported non-NVIDIA GPU: AMD Radeon(TM) Graphics
# 2026-03-16T12:31:53Z [2,416ms] [Warning] [gpu.foundation.plugin] Skipping unsupported non-NVIDIA GPU: AMD Radeon(TM) Graphics
#
# |---------------------------------------------------------------------------------------------|
# | Driver Version: 581.29        | Graphics API: D3D12
# |=============================================================================================|
# | GPU | Name                             | Active | LDA | GPU Memory | Vendor-ID | LUID       |
# |     |                                  |        |     |            | Device-ID | UUID       |
# |     |                                  |        |     |            | Bus-ID    |            |
# |---------------------------------------------------------------------------------------------|
# | 0   | NVIDIA GeForce RTX 5080          | Yes: 0 |     | 15889   MB | 10de      | 08570100.. |
# |     |                                  |        |     |            | 2c02      | 0          |
# |     |                                  |        |     |            | 1         |            |
# |---------------------------------------------------------------------------------------------|
# | 1   | AMD Radeon(TM) Graphics          |        |     | 1995    MB | 1002      | 676a0100.. |
# |     |                                  |        |     |            | 13c0      | 0          |
# |     |                                  |        |     |            | N/A       |            |
# |=============================================================================================|
# | OS: Windows 11 Pro, Version: 10.0 (25H2), Build: 26200, Kernel: 10.0.26100.8036
# | Processor: AMD Ryzen 9 9950X 16-Core Processor
# | Cores: 16 | Logical Cores: 32
# |---------------------------------------------------------------------------------------------|
# | Total Memory (MB): 128627 | Free Memory: 96755
# | Total Page/Swap (MB): 136819 | Free Page/Swap: 96179
# |---------------------------------------------------------------------------------------------|
# C:\Users\Teresa\Documents\GitHub\navsim\isaac_lab\aerotaxi\env_command\env_15\flight_plan.py:29: UserWarning: Treat the new Tool classes introduced in v1.5 as experimental for now; the API and rcParam may change in future versions.
#   plt.rcParams["toolbar"] = "toolmanager"
# [INFO]: Parsing configuration from: aerotaxi.env_command.env_15.env:UAVEnvCfg
# [INFO]: Parsing configuration from: aerotaxi.env_command.env_15.grid_hiperparametros.cfg_files.ppo_random_command11_11_cfg:Command11PPORunnerCfg
# [INFO] Loading experiment from directory: C:\Users\Teresa\Documents\GitHub\navsim\isaac_lab\aerotaxi\env_command\env_15\logs\rsl_rl\command11
# Setting seed: 42
# [INFO]: Base environment:
# 	Environment device    : cuda:0
# 	Environment seed      : 42
# 	Physics step-size     : 0.005
# 	Rendering step-size   : 0.02
# 	Environment step-size : 0.02
# [INFO]: Time taken for scene creation : 0.992144 seconds
# [INFO]: Scene manager:  <class InteractiveScene>
# 	Number of environments: 64
# 	Environment spacing   : 200.0
# 	Source prim name      : /World/envs/env_0
# 	Global prim paths     : []
# 	Replicate physics     : False
# [INFO]: Starting the simulation. This may take a few seconds. Please wait...
# [INFO]: Time taken for simulation start : 0.273134 seconds
# [INFO] Command Manager:  <CommandManager> contains 1 active terms.
# +--------------------------------------+
# |         Active Command Terms         |
# +-------+-------------+----------------+
# | Index | Name        |      Type      |
# +-------+-------------+----------------+
# |   0   | vel_command | UAVcommandTerm |
# +-------+-------------+----------------+
#
# [INFO] Event Manager:  <EventManager> contains 1 active terms.
# +-----------------------------------+
# | Active Event Terms in Mode: 'reset' |
# +----------+------------------------+
# |  Index   | Name                   |
# +----------+------------------------+
# |    0     | reset_pos              |
# |    1     | randomize_mass         |
# |    2     | randomize_wind         |
# +----------+------------------------+
#
# [INFO] Recorder Manager:  <RecorderManager> contains 0 active terms.
# +---------------------+
# | Active Recorder Terms |
# +-----------+---------+
# |   Index   | Name    |
# +-----------+---------+
# +-----------+---------+
#
# [INFO] Action Manager:  <ActionManager> contains 1 active terms.
# +-----------------------------------+
# |   Active Action Terms (shape: 4)  |
# +--------+-------------+------------+
# | Index  | Name        |  Dimension |
# +--------+-------------+------------+
# |   0    | rotors_vel  |          4 |
# +--------+-------------+------------+
#
# [INFO] Observation Manager: <ObservationManager> contains 2 groups.
# +---------------------------------------------------------+
# | Active Observation Terms in Group: 'policy' (shape: (16,)) |
# +-----------+---------------------------------+-----------+
# |   Index   | Name                            |   Shape   |
# +-----------+---------------------------------+-----------+
# |     0     | lin_vel                         |    (3,)   |
# |     1     | ang_vel                         |    (3,)   |
# |     2     | projected_gravity               |    (3,)   |
# |     3     | target_vel                      |    (3,)   |
# |     4     | target_future                   |    (3,)   |
# |     5     | yaw_error                       |    (1,)   |
# +-----------+---------------------------------+-----------+
# +---------------------------------------------------------+
# | Active Observation Terms in Group: 'critic' (shape: (16,)) |
# +-----------+---------------------------------+-----------+
# |   Index   | Name                            |   Shape   |
# +-----------+---------------------------------+-----------+
# |     0     | lin_vel                         |    (3,)   |
# |     1     | ang_vel                         |    (3,)   |
# |     2     | projected_gravity               |    (3,)   |
# |     3     | target_vel                      |    (3,)   |
# |     4     | target_future                   |    (3,)   |
# |     5     | yaw_error                       |    (1,)   |
# +-----------+---------------------------------+-----------+
#
# [INFO] Termination Manager:  <TerminationManager> contains 4 active terms.
# +---------------------------------------+
# |        Active Termination Terms       |
# +-------+--------------------+----------+
# | Index | Name               | Time Out |
# +-------+--------------------+----------+
# |   0   | time_out           |   True   |
# |   1   | below_min_altitude |  False   |
# |   2   | bad_attitude       |  False   |
# |   3   | safety_shutdown    |  False   |
# +-------+--------------------+----------+
#
# [INFO] Reward Manager:  <RewardManager> contains 6 active terms.
# +------------------------------------------+
# |           Active Reward Terms            |
# +-------+-------------------------+--------+
# | Index | Name                    | Weight |
# +-------+-------------------------+--------+
# |   0   | rew_attitude_stability2 |    2.0 |
# |   1   | rew_ang_vel_stability4  |    1.0 |
# |   2   | rew_pos2                |    2.0 |
# |   3   | rew_action_rate         |    0.1 |
# |   4   | rew_heading             |    3.0 |
# |   5   | rew_track_vel3          |    8.0 |
# +-------+-------------------------+--------+
#
# [INFO] Curriculum Manager:  <CurriculumManager> contains 0 active terms.
# +----------------------+
# | Active Curriculum Terms |
# +-----------+----------+
# |   Index   | Name     |
# +-----------+----------+
# +-----------+----------+
#
# [INFO]: Completed setting up the environment...
# 2026-03-16T12:31:56Z [5,637ms] [Warning] [omni.physx.fabric.plugin] FabricManager::initializePointInstancer mismatched prototypes on point instancer: /Visuals/target_commands.
# 2026-03-16T12:31:56Z [5,637ms] [Warning] [omni.physx.fabric.plugin] FabricManager::initializePointInstancer mismatched prototypes on point instancer: /Visuals/TargetArrow.
# 2026-03-16T12:31:56Z [5,637ms] [Warning] [omni.physx.fabric.plugin] FabricManager::initializePointInstancer mismatched prototypes on point instancer: /Visuals/DroneArrow.
# [INFO]: Loading model checkpoint from: C:\Users\Teresa\Documents\GitHub\navsim\tmp\tmpTeresa\resultados_grid_command_v11\best_model_ppo_random_command11_11_4096.pt
# C:\Users\Teresa\miniconda3\envs\env_isaaclab\Lib\site-packages\rsl_rl\utils\utils.py:244: UserWarning: The observation configuration dictionary 'obs_groups' must contain the 'policy' key. As an observation group with the name 'policy' was found, this is assumed to be the observation set. Consider adding the 'policy' key to the 'obs_groups' dictionary for clarity. This behavior will be removed in a future version.
#   warnings.warn(
# C:\Users\Teresa\miniconda3\envs\env_isaaclab\Lib\site-packages\rsl_rl\utils\utils.py:282: UserWarning: The observation configuration dictionary 'obs_groups' must contain the 'critic' key. As an observation group with the name 'critic' was found, this is assumed to be the observation set. Consider adding the 'critic' key to the 'obs_groups' dictionary for clarity. This behavior will be removed in a future version.
#   warnings.warn(
# --------------------------------------------------------------------------------
# Resolved observation sets:
# 	 policy :  ['policy']
# 	 critic :  ['critic']
# --------------------------------------------------------------------------------
# Actor MLP: MLP(
#   (0): Linear(in_features=16, out_features=128, bias=True)
#   (1): ELU(alpha=1.0)
#   (2): Linear(in_features=128, out_features=128, bias=True)
#   (3): ELU(alpha=1.0)
#   (4): Linear(in_features=128, out_features=128, bias=True)
#   (5): ELU(alpha=1.0)
#   (6): Linear(in_features=128, out_features=4, bias=True)
# )
# Critic MLP: MLP(
#   (0): Linear(in_features=16, out_features=256, bias=True)
#   (1): ELU(alpha=1.0)
#   (2): Linear(in_features=256, out_features=256, bias=True)
#   (3): ELU(alpha=1.0)
#   (4): Linear(in_features=256, out_features=256, bias=True)
#   (5): ELU(alpha=1.0)
#   (6): Linear(in_features=256, out_features=1, bias=True)
# )
#
# --- Todos los experimentos de test han finalizado ---

# %% [markdown]
# #### Test con 256 entornos

# %%
import os
df_callbacks = pd.read_csv(path_resultados+"/reward_best_models.csv",index_col='id_run_name')
top5_models = df_callbacks.nlargest(5,columns="reward")

powershell_script_test_3 = os.path.join(cfg_dir, "run_tests_3.ps1")

with open(powershell_script_test_3, "w") as f:
    f.write("$ErrorActionPreference = 'Stop'\n\n")
    
    for run_id, row in top5_models.iterrows():
        # Extraemos el número del id (ej: de 'ppo_random_hover_4' sacamos '4')
        experiment_number = run_id.split('_')[-1]
        
        # Construimos la ruta exacta del checkpoint
        # Nota: Asegúrate de que path_resultados termine en / o usar os.path.join
        checkpoint_path = f"{path_resultados}/best_model_{run_id}_{int(row['num_envs_train'])}.pt"
        f.write(f'Write-Host "Ejecutando Test final para Experimento {experiment_number}..."\n')
        
        # Usamos el experiment_number extraído para la tarea (--task)
        # Se añaden flags típicos de play.py: --num_envs 1 y se quita --headless para ver el visualizador
        f.write(f'& "{isaaclab_bat}" -p "{play_script}" '
                f'--task {id_task}-{experiment_number} '
                f'--num_envs 256 '
                f' --headless '
                f'--checkpoint "{checkpoint_path}"\n\n')
        
print(f"Script de test generado en: {powershell_script_test_3}")
# Out:
# Script de test generado en: C:/Users/Teresa/Documents/GitHub/navsim/isaac_lab/aerotaxi/env_command/env_15/grid_hiperparametros/cfg_files\run_tests_3.ps1

# %%
# Ejecuta el entrenamiento de forma automática
# !powershell -ExecutionPolicy Bypass -File "{powershell_script}"
import subprocess
import sys

# Ruta al script que generaste
powershell_script_path = powershell_script_test_3 

print(f"Iniciando ejecución de: {powershell_script_path}\n")

# Ejecutamos el proceso capturando la salida en tiempo real
process = subprocess.Popen(
    ["powershell.exe", "-ExecutionPolicy", "Bypass", "-File", powershell_script_path],
    stdout=subprocess.PIPE,
    stderr=subprocess.STDOUT, # Redirigimos errores a la salida estándar para verlos
    text=True,
    bufsize=1
)

# Leemos la salida línea a línea conforme se genera
try:
    for line in process.stdout:
        print(line, end="") # Imprime la salida de PowerShell en la celda
        sys.stdout.flush()   # Fuerza a Jupyter a mostrar la línea inmediatamente
except KeyboardInterrupt:
    process.kill()
    print("\nEntrenamiento cancelado por el usuario.")

process.wait()
print("\n--- Todos los experimentos de test han finalizado ---")
# Out:
# Iniciando ejecución de: C:/Users/Teresa/Documents/GitHub/navsim/isaac_lab/aerotaxi/env_command/env_15/grid_hiperparametros/cfg_files\run_tests_3.ps1
#
# Ejecutando Test final para Experimento 11...
# [INFO] Using python from: C:\Users\Teresa\miniconda3\envs\env_isaaclab\python.exe
# [INFO][AppLauncher]: Using device: cuda:0
# [INFO][AppLauncher]: Loading experience file: C:\Users\Teresa\miniconda3\envs\env_isaaclab\Lib\site-packages\isaaclab\apps\isaaclab.python.headless.kit
# Loading user config located at: 'c:/users/teresa/miniconda3/envs/env_isaaclab/lib/site-packages/isaacsim/kit/data/Kit/Isaac-Sim/5.1/user.config.json'
# [Info] [carb] Logging to file: c:/users/teresa/miniconda3/envs/env_isaaclab/lib/site-packages/isaacsim/kit/logs/Kit/Isaac-Sim/5.1/kit_20260316_133232.log
# 2026-03-16T12:32:32Z s] [Warning] [omni.usd_config.extension] Enable omni.materialx.libs extension to use MaterialX
# 2026-03-16T12:32:32Z s] [Warning] [carb] Acquiring non optional plugin interface which is not listed as dependency: [omni::physx::IPhysxBenchmarks v1.0] (plugin: <default plugin>), by client: omni.physics.physx.plugin. Add it to CARB_PLUGIN_IMPL_DEPS() macro of a client.
# 2026-03-16T12:32:32Z s] [Warning] [omni.isaac.dynamic_control] omni.isaac.dynamic_control is deprecated as of Isaac Sim 4.5. No action is needed from end-users.
# 2026-03-16T12:32:34Z [2,380ms] [Warning] [gpu.foundation.plugin] Skipping unsupported non-NVIDIA GPU: AMD Radeon(TM) Graphics
# 2026-03-16T12:32:34Z [2,381ms] [Warning] [gpu.foundation.plugin] Skipping unsupported non-NVIDIA GPU: AMD Radeon(TM) Graphics
#
# |---------------------------------------------------------------------------------------------|
# | Driver Version: 581.29        | Graphics API: D3D12
# |=============================================================================================|
# | GPU | Name                             | Active | LDA | GPU Memory | Vendor-ID | LUID       |
# |     |                                  |        |     |            | Device-ID | UUID       |
# |     |                                  |        |     |            | Bus-ID    |            |
# |---------------------------------------------------------------------------------------------|
# | 0   | NVIDIA GeForce RTX 5080          | Yes: 0 |     | 15889   MB | 10de      | 08570100.. |
# |     |                                  |        |     |            | 2c02      | 0          |
# |     |                                  |        |     |            | 1         |            |
# |---------------------------------------------------------------------------------------------|
# | 1   | AMD Radeon(TM) Graphics          |        |     | 1995    MB | 1002      | 676a0100.. |
# |     |                                  |        |     |            | 13c0      | 0          |
# |     |                                  |        |     |            | N/A       |            |
# |=============================================================================================|
# | OS: Windows 11 Pro, Version: 10.0 (25H2), Build: 26200, Kernel: 10.0.26100.8036
# | Processor: AMD Ryzen 9 9950X 16-Core Processor
# | Cores: 16 | Logical Cores: 32
# |---------------------------------------------------------------------------------------------|
# | Total Memory (MB): 128627 | Free Memory: 96437
# | Total Page/Swap (MB): 136819 | Free Page/Swap: 95878
# |---------------------------------------------------------------------------------------------|
# C:\Users\Teresa\Documents\GitHub\navsim\isaac_lab\aerotaxi\env_command\env_15\flight_plan.py:29: UserWarning: Treat the new Tool classes introduced in v1.5 as experimental for now; the API and rcParam may change in future versions.
#   plt.rcParams["toolbar"] = "toolmanager"
# [INFO]: Parsing configuration from: aerotaxi.env_command.env_15.env:UAVEnvCfg
# [INFO]: Parsing configuration from: aerotaxi.env_command.env_15.grid_hiperparametros.cfg_files.ppo_random_command11_11_cfg:Command11PPORunnerCfg
# [INFO] Loading experiment from directory: C:\Users\Teresa\Documents\GitHub\navsim\isaac_lab\aerotaxi\env_command\env_15\logs\rsl_rl\command11
# Setting seed: 42
# [INFO]: Base environment:
# 	Environment device    : cuda:0
# 	Environment seed      : 42
# 	Physics step-size     : 0.005
# 	Rendering step-size   : 0.02
# 	Environment step-size : 0.02
# [INFO]: Time taken for scene creation : 1.045545 seconds
# [INFO]: Scene manager:  <class InteractiveScene>
# 	Number of environments: 256
# 	Environment spacing   : 200.0
# 	Source prim name      : /World/envs/env_0
# 	Global prim paths     : []
# 	Replicate physics     : False
# [INFO]: Starting the simulation. This may take a few seconds. Please wait...
# [INFO]: Time taken for simulation start : 0.382432 seconds
# [INFO] Command Manager:  <CommandManager> contains 1 active terms.
# +--------------------------------------+
# |         Active Command Terms         |
# +-------+-------------+----------------+
# | Index | Name        |      Type      |
# +-------+-------------+----------------+
# |   0   | vel_command | UAVcommandTerm |
# +-------+-------------+----------------+
#
# [INFO] Event Manager:  <EventManager> contains 1 active terms.
# +-----------------------------------+
# | Active Event Terms in Mode: 'reset' |
# +----------+------------------------+
# |  Index   | Name                   |
# +----------+------------------------+
# |    0     | reset_pos              |
# |    1     | randomize_mass         |
# |    2     | randomize_wind         |
# +----------+------------------------+
#
# [INFO] Recorder Manager:  <RecorderManager> contains 0 active terms.
# +---------------------+
# | Active Recorder Terms |
# +-----------+---------+
# |   Index   | Name    |
# +-----------+---------+
# +-----------+---------+
#
# [INFO] Action Manager:  <ActionManager> contains 1 active terms.
# +-----------------------------------+
# |   Active Action Terms (shape: 4)  |
# +--------+-------------+------------+
# | Index  | Name        |  Dimension |
# +--------+-------------+------------+
# |   0    | rotors_vel  |          4 |
# +--------+-------------+------------+
#
# [INFO] Observation Manager: <ObservationManager> contains 2 groups.
# +---------------------------------------------------------+
# | Active Observation Terms in Group: 'policy' (shape: (16,)) |
# +-----------+---------------------------------+-----------+
# |   Index   | Name                            |   Shape   |
# +-----------+---------------------------------+-----------+
# |     0     | lin_vel                         |    (3,)   |
# |     1     | ang_vel                         |    (3,)   |
# |     2     | projected_gravity               |    (3,)   |
# |     3     | target_vel                      |    (3,)   |
# |     4     | target_future                   |    (3,)   |
# |     5     | yaw_error                       |    (1,)   |
# +-----------+---------------------------------+-----------+
# +---------------------------------------------------------+
# | Active Observation Terms in Group: 'critic' (shape: (16,)) |
# +-----------+---------------------------------+-----------+
# |   Index   | Name                            |   Shape   |
# +-----------+---------------------------------+-----------+
# |     0     | lin_vel                         |    (3,)   |
# |     1     | ang_vel                         |    (3,)   |
# |     2     | projected_gravity               |    (3,)   |
# |     3     | target_vel                      |    (3,)   |
# |     4     | target_future                   |    (3,)   |
# |     5     | yaw_error                       |    (1,)   |
# +-----------+---------------------------------+-----------+
#
# [INFO] Termination Manager:  <TerminationManager> contains 4 active terms.
# +---------------------------------------+
# |        Active Termination Terms       |
# +-------+--------------------+----------+
# | Index | Name               | Time Out |
# +-------+--------------------+----------+
# |   0   | time_out           |   True   |
# |   1   | below_min_altitude |  False   |
# |   2   | bad_attitude       |  False   |
# |   3   | safety_shutdown    |  False   |
# +-------+--------------------+----------+
#
# [INFO] Reward Manager:  <RewardManager> contains 6 active terms.
# +------------------------------------------+
# |           Active Reward Terms            |
# +-------+-------------------------+--------+
# | Index | Name                    | Weight |
# +-------+-------------------------+--------+
# |   0   | rew_attitude_stability2 |    2.0 |
# |   1   | rew_ang_vel_stability4  |    1.0 |
# |   2   | rew_pos2                |    2.0 |
# |   3   | rew_action_rate         |    0.1 |
# |   4   | rew_heading             |    3.0 |
# |   5   | rew_track_vel3          |    8.0 |
# +-------+-------------------------+--------+
#
# [INFO] Curriculum Manager:  <CurriculumManager> contains 0 active terms.
# +----------------------+
# | Active Curriculum Terms |
# +-----------+----------+
# |   Index   | Name     |
# +-----------+----------+
# +-----------+----------+
#
# [INFO]: Completed setting up the environment...
# 2026-03-16T12:32:37Z [5,756ms] [Warning] [omni.physx.fabric.plugin] FabricManager::initializePointInstancer mismatched prototypes on point instancer: /Visuals/target_commands.
# 2026-03-16T12:32:37Z [5,756ms] [Warning] [omni.physx.fabric.plugin] FabricManager::initializePointInstancer mismatched prototypes on point instancer: /Visuals/TargetArrow.
# 2026-03-16T12:32:37Z [5,756ms] [Warning] [omni.physx.fabric.plugin] FabricManager::initializePointInstancer mismatched prototypes on point instancer: /Visuals/DroneArrow.
# [INFO]: Loading model checkpoint from: C:\Users\Teresa\Documents\GitHub\navsim\tmp\tmpTeresa\resultados_grid_command_v11\best_model_ppo_random_command11_11_4096.pt
# C:\Users\Teresa\miniconda3\envs\env_isaaclab\Lib\site-packages\rsl_rl\utils\utils.py:244: UserWarning: The observation configuration dictionary 'obs_groups' must contain the 'policy' key. As an observation group with the name 'policy' was found, this is assumed to be the observation set. Consider adding the 'policy' key to the 'obs_groups' dictionary for clarity. This behavior will be removed in a future version.
#   warnings.warn(
# C:\Users\Teresa\miniconda3\envs\env_isaaclab\Lib\site-packages\rsl_rl\utils\utils.py:282: UserWarning: The observation configuration dictionary 'obs_groups' must contain the 'critic' key. As an observation group with the name 'critic' was found, this is assumed to be the observation set. Consider adding the 'critic' key to the 'obs_groups' dictionary for clarity. This behavior will be removed in a future version.
#   warnings.warn(
# --------------------------------------------------------------------------------
# Resolved observation sets:
# 	 policy :  ['policy']
# 	 critic :  ['critic']
# --------------------------------------------------------------------------------
# Actor MLP: MLP(
#   (0): Linear(in_features=16, out_features=128, bias=True)
#   (1): ELU(alpha=1.0)
#   (2): Linear(in_features=128, out_features=128, bias=True)
#   (3): ELU(alpha=1.0)
#   (4): Linear(in_features=128, out_features=128, bias=True)
#   (5): ELU(alpha=1.0)
#   (6): Linear(in_features=128, out_features=4, bias=True)
# )
# Critic MLP: MLP(
#   (0): Linear(in_features=16, out_features=256, bias=True)
#   (1): ELU(alpha=1.0)
#   (2): Linear(in_features=256, out_features=256, bias=True)
#   (3): ELU(alpha=1.0)
#   (4): Linear(in_features=256, out_features=256, bias=True)
#   (5): ELU(alpha=1.0)
#   (6): Linear(in_features=256, out_features=1, bias=True)
# )
#
# --- Todos los experimentos de test han finalizado ---

# %%
import pandas as pd

df_train = top5_models.copy()
if df_train.index.name == 'id_run_name':
    df_train = df_train.reset_index()

df_train = df_train.rename(columns={
    'reward': 'reward_train',
    'max_reward': 'max_reward_train',
    'std_reward': 'std_train'
})

df_test = df_rewards_play.copy()

df_test = pd.read_csv(path_resultados+'/rewards_play_PPO.csv')
df_test = df_test.rename(columns={
    'reward': 'reward_test',
    'max_reward': 'max_reward_test',
    'std': 'std_test'
})

df_final = pd.merge(
    df_train[['id_run_name', 'num_envs_train', 'reward_train', 'max_reward_train', 'std_train', 'iteration']], 
    df_test[['id_run_name', 'num_envs_test', 'reward_test', 'max_reward_test', 'std_test', 'checkpoint']], 
    on='id_run_name', 
    how='inner'
)

column_order = [
    'id_run_name',
    'num_envs_train',
    'num_envs_test',
    'reward_train', 'reward_test', 
    'max_reward_train', 'max_reward_test', 
    'std_train', 'std_test',
    'iteration'
]
df_final = df_final[column_order]

df_final = df_final.sort_values(by='id_run_name', ascending=False)

# %%
df_rewards_play = df_final.sort_values(by="id_run_name",ascending=False)
df_rewards_play = df_rewards_play.reset_index().drop(columns='index')

df_final = df_rewards_play.copy()

df_final['diff_rw_test_train'] = df_final['reward_test'] - df_final['reward_train']

df_final['diferencia(%)'] = (df_final['diff_rw_test_train'] / df_final['reward_train'].abs()) * 100

df_final['diferencia(%)'] = df_final['diferencia(%)'].apply(lambda x: f"{x:+.2f}%")

df_final
# Out:
#                id_run_name  num_envs_train  num_envs_test  reward_train  \
# 0  ppo_random_command11_11            4096              1    348.842303
# 1  ppo_random_command11_11            4096             64    348.842303
# 2  ppo_random_command11_11            4096            256    348.842303
#
#    reward_test  max_reward_train  max_reward_test  std_train   std_test  \
# 0   272.287348        383.204346       272.287348  19.679655   0.000000
# 1   239.156062        383.204346       293.363596  19.679655  77.266409
# 2   257.452546        383.204346       306.120941  19.679655  50.161326
#
#    iteration  diff_rw_test_train diferencia(%)
# 0        862          -76.554955       -21.95%
# 1        862         -109.686240       -31.44%
# 2        862          -91.389757       -26.20%

# %% [markdown]
# Pruebas con un solo entorno: Vemos cómo se comporta la política para un único agente en una prueba aleatoria.

# %%
df_final[df_final['num_envs_test'] == 1].sort_values(by='reward_test',ascending=False)
# Out:
#                id_run_name  num_envs_train  num_envs_test  reward_train  \
# 0  ppo_random_command11_11            4096              1    348.842303
#
#    reward_test  max_reward_train  max_reward_test  std_train  std_test  \
# 0   272.287348        383.204346       272.287348  19.679655       0.0
#
#    iteration  diff_rw_test_train diferencia(%)
# 0        862          -76.554955       -21.95%

# %% [markdown]
# ``Interpretación``: Vemos que el modelo 38 se ha estampado en la prueba aleatoria, así que ese modelo no debería usarse para ninguna transferencia real.

# %% [markdown]
# Pruebas con varios entornos: Vemos cómo se comporta la política en múltiples entornos (varias pruebas simuladas en paralelo), teniendo en cuenta cuál es la desviación de cada uno en test, lo que nos permite inferir si la recompensa es estable para todas las pruebas.

# %%
df_final[df_final['num_envs_test'] != 1].sort_values(by='std_test',ascending=True).reset_index().drop(columns="index")
# Out:
#                id_run_name  num_envs_train  num_envs_test  reward_train  \
# 0  ppo_random_command11_11            4096            256    348.842303
# 1  ppo_random_command11_11            4096             64    348.842303
#
#    reward_test  max_reward_train  max_reward_test  std_train   std_test  \
# 0   257.452546        383.204346       306.120941  19.679655  50.161326
# 1   239.156062        383.204346       293.363596  19.679655  77.266409
#
#    iteration  diff_rw_test_train diferencia(%)
# 0        862          -91.389757       -26.20%
# 1        862         -109.686240       -31.44%

# %% [markdown]
# pruebas:

# %% [markdown]
# C:/Users/Teresa/Desktop/RuralData/IsaacLab/IsaacLab/isaaclab.bat -p C:/Users/Teresa/Documents/GitHub/navsim/isaac_lab/rl_v5_1_0/rsl_rl/train.py --task Isaac-Command5-Aerotaxi-RANDOM-11 --num_envs 8196 --headless

# %% [markdown]
# C:/Users/Teresa/Desktop/RuralData/IsaacLab/IsaacLab/isaaclab.bat -p C:/Users/Teresa/Documents/GitHub/navsim/isaac_lab/rl_v5_1_0/rsl_rl/play.py --task Isaac-Command11-Aerotaxi-RANDOM-11 --num_envs 256 --checkpoint C:/Users/Teresa/Documents/GitHub/navsim/tmp/tmpTeresa/resultados_grid_command_v11/best_model_ppo_random_command11_11_4096.pt
