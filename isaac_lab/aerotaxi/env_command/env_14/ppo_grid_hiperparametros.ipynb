# %%
# Parámetros a configurar:
import os
experiment_name = "command10"
task_name = "Command10"
cfg_dir = "C:/Users/Teresa/Documents/GitHub/navsim/isaac_lab/aerotaxi/env_command/env_14/grid_hiperparametros/cfg_files"
path_resultados = "C:/Users/Teresa/Documents/GitHub/navsim/tmp/tmpTeresa/resultados_grid_command_v10"
isaaclab_bat = "C:/Users/Teresa/Desktop/RuralData/IsaacLab/IsaacLab/isaaclab.bat"
train_script = "C:/Users/Teresa/Documents/GitHub/navsim/isaac_lab/rl_v5_1_0/rsl_rl/train.py"
id_task = f"Isaac-{task_name}-Aerotaxi-RANDOM" # luego se le añade el número de task con el guión (Isaac-Command2-Aerotaxi-RANDOM-34)
play_script = "C:/Users/Teresa/Documents/GitHub/navsim/isaac_lab/rl_v5_1_0/rsl_rl/play.py"
num_iter = "1001"
num_steps_per_env = 100
powershell_script = os.path.join(cfg_dir, "run_all.ps1")

# el num_steps_per_env = 100 también está en el env, al final del todo, y deben tener el mismo valor
# Recuerda iniciar en el init todos los experimentos

# %%
import random
import os

# Si los directorios no existen (el último indicado), lo crea
os.makedirs(cfg_dir, exist_ok=True)
os.makedirs(path_resultados, exist_ok=True)
# Opciones de hiperparámetros
param_options = {
    "init_noise_std": [0.0, 0.1, 0.2, 0.5, 0.8, 1.0],
    "actor_hidden_dims": [[64, 64], [128, 128], [256, 256], [128, 64]],
    "critic_hidden_dims": [[64, 64], [128, 128], [256, 256]],
    "activation": ["relu", "tanh", "elu", "gelu"],
    "value_loss_coef": [0.5, 1.0, 2.0],
    "clip_param": [0.1, 0.2, 0.3],
    "entropy_coef": [0.0, 0.001, 0.01, 0.05],
    "num_learning_epochs": [4, 8, 12],
    "num_mini_batches": [2, 4, 8],
    "learning_rate": [5e-05, 1e-4, 3e-4, 1e-3, 3e-3],
    "gamma": [0.95, 0.98, 0.99],
    "lam": [0.90, 0.95, 0.97],
    "max_grad_norm": [0.5, 1.0, 2.0],
    "desired_kl": [0.005, 0.008, 0.01, 0.02],
}

num_trials = 35  # cantidad de configuraciones

cfg_files = []

for i in range(num_trials):
    run_name = f"ppo_random_{experiment_name}_{i+1}"
    sampled = {k: random.choice(v) for k, v in param_options.items()}

    # Convertir listas a string
    actor_dims = sampled["actor_hidden_dims"]
    critic_dims = sampled["critic_hidden_dims"]

    cfg_content = f"""
from isaaclab.utils import configclass
from isaaclab_rl.rsl_rl import RslRlOnPolicyRunnerCfg, RslRlPpoActorCriticCfg, RslRlPpoAlgorithmCfg

@configclass
class {task_name}PPORunnerCfg(RslRlOnPolicyRunnerCfg):
    num_steps_per_env = {num_steps_per_env} 
    max_iterations = {num_iter}
    save_interval = 100
    experiment_name = "{experiment_name}"
    run_name = "{run_name}"
    resume = False
    empirical_normalization = False
    csv_path_metrics = "{path_resultados}"
    callbacks = True
    policy = RslRlPpoActorCriticCfg(
        init_noise_std={sampled['init_noise_std']},
        actor_hidden_dims={actor_dims},
        critic_hidden_dims={critic_dims},
        activation="{sampled['activation']}",
    )
    algorithm = RslRlPpoAlgorithmCfg(
        value_loss_coef={sampled['value_loss_coef']},
        use_clipped_value_loss=True,
        clip_param={sampled['clip_param']},
        entropy_coef={sampled['entropy_coef']},
        num_learning_epochs={sampled['num_learning_epochs']},
        num_mini_batches={sampled['num_mini_batches']},
        learning_rate={sampled['learning_rate']},
        schedule="adaptive",
        gamma={sampled['gamma']},
        lam={sampled['lam']},
        desired_kl={sampled['desired_kl']},
        max_grad_norm={sampled['max_grad_norm']},
    )
"""
    cfg_path = os.path.join(cfg_dir, f"{run_name}_cfg.py")
    with open(cfg_path, "w") as f:
        f.write(cfg_content.strip())
    cfg_files.append((run_name, cfg_path))

# Crear archivo PowerShell para ejecutar todas las configuraciones
powershell_script = os.path.join(cfg_dir, "run_all.ps1")

num_envs =  [64, 128, 512, 1024, 2048, 4096, 8196] #número de entornos para train (paralelizados)

with open(powershell_script, "w") as f:
    f.write("$ErrorActionPreference = 'Stop'\n\n")
    j = 0
    for run_name, cfg_path in cfg_files:
        # Convertir path a módulo Python (reemplazar / y .py)
        num_envs_i = random.choice(num_envs)
        module_path = cfg_path.replace("/", ".").replace("\\", ".").replace(".py", "")
        f.write(f'Write-Host "Ejecutando {run_name}"\n')
        f.write(f'& "{isaaclab_bat}" -p "{train_script}" --task {id_task}-{j+1} --num_envs {num_envs_i} --headless \n\n')
        j += 1
print("Archivos de configuración generados y script PowerShell listo en:", powershell_script)
# Out:
# Archivos de configuración generados y script PowerShell listo en: C:/Users/Teresa/Documents/GitHub/navsim/isaac_lab/aerotaxi/env_command/env_11/grid_hiperparametros/cfg_files\run_all.ps1

# %%
# Ejecuta el entrenamiento de forma automática
# !powershell -ExecutionPolicy Bypass -File "{powershell_script}"
import subprocess
import sys

# Ruta al script que generaste
powershell_script_path = powershell_script 

print(f"Iniciando ejecución de: {powershell_script_path}\n")

# Ejecutamos el proceso capturando la salida en tiempo real
process = subprocess.Popen(
    ["powershell.exe", "-ExecutionPolicy", "Bypass", "-File", powershell_script_path],
    stdout=subprocess.PIPE,
    stderr=subprocess.STDOUT, # Redirigimos errores a la salida estándar para verlos
    text=True,
    bufsize=1
)

# Leemos la salida línea a línea conforme se genera
try:
    for line in process.stdout:
        print(line, end="") # Imprime la salida de PowerShell en la celda
        sys.stdout.flush()   # Fuerza a Jupyter a mostrar la línea inmediatamente
except KeyboardInterrupt:
    process.kill()
    print("\nEntrenamiento cancelado por el usuario.")

process.wait()
print("\n--- Todos los experimentos han finalizado ---")
# Out:
# Iniciando ejecución de: C:/Users/Teresa/Documents/GitHub/navsim/isaac_lab/aerotaxi/env_command/env_13/grid_hiperparametros/cfg_files\run_all.ps1
#
# Ejecutando ppo_random_command9_11
# [INFO] Using python from: C:\Users\Teresa\miniconda3\envs\env_isaaclab\python.exe
# [INFO][AppLauncher]: Using device: cuda:0
# [INFO][AppLauncher]: Loading experience file: C:\Users\Teresa\miniconda3\envs\env_isaaclab\Lib\site-packages\isaaclab\apps\isaaclab.python.kit
# Loading user config located at: 'c:/users/teresa/miniconda3/envs/env_isaaclab/lib/site-packages/isaacsim/kit/data/Kit/Isaac-Sim/5.1/user.config.json'
# [Info] [carb] Logging to file: c:/users/teresa/miniconda3/envs/env_isaaclab/lib/site-packages/isaacsim/kit/logs/Kit/Isaac-Sim/5.1/kit_20260304_094918.log
# [0.115s] [ext: omni.kit.async_engine-0.0.3] startup
# [0.222s] [ext: omni.metrics.core-0.0.3] startup
# [0.224s] [ext: omni.client.lib-1.1.0] startup
# [0.238s] [ext: omni.blobkey-1.1.2] startup
# [0.240s] [ext: omni.stats-1.0.1] startup
# [0.243s] [ext: omni.datastore-0.0.0] startup
# [0.245s] [ext: omni.client-1.3.0] startup
# [0.252s] [ext: omni.ujitso.default-1.0.0] startup
# [0.256s] [ext: omni.hsscclient-1.1.2] startup
# [0.265s] [ext: omni.gpu_foundation.shadercache.vulkan-1.0.0] startup
# [0.269s] [ext: omni.assets.plugins-0.0.0] startup
# [0.273s] [ext: omni.gpu_foundation-0.0.0] startup
# [0.300s] [ext: carb.windowing.plugins-1.0.0] startup
# [0.420s] [ext: omni.kit.renderer.init-0.0.0] startup
# [0.422s] [ext: omni.materialx.libs-1.0.7] startup
# [0.438s] [ext: omni.kit.telemetry-0.5.2] startup
# [0.448s] [ext: omni.usd.config-1.0.6] startup
# [0.456s] [ext: omni.gpucompute.plugins-0.0.0] startup
# [0.458s] [ext: omni.usd.libs-1.0.1] startup
# [0.621s] [ext: omni.kit.pipapi-0.0.0] startup
# [0.623s] [ext: omni.mdl-56.0.3] startup
# [0.642s] [ext: omni.iray.libs-0.0.0] startup
# [0.668s] [ext: omni.mdl.neuraylib-0.2.12] startup
# [0.673s] [ext: omni.kit.usd.mdl-1.1.5] startup
# [0.757s] [ext: omni.kit.loop-isaac-1.3.7] startup
# [0.760s] [ext: omni.kit.test-2.0.1] startup
# [0.806s] [ext: omni.appwindow-1.1.10] startup
# [0.829s] [ext: omni.kit.renderer.core-1.1.0] startup
# [0.836s] [ext: omni.kit.renderer.capture-0.0.0] startup
# [0.842s] [ext: omni.kit.renderer.imgui-2.0.5] startup
# [0.860s] [ext: omni.ui-2.27.1] startup
# [0.871s] [ext: omni.kit.mainwindow-1.0.3] startup
# [0.874s] [ext: carb.audio-0.1.0] startup
# [0.876s] [ext: omni.uiaudio-1.0.0] startup
# [0.879s] [ext: omni.kit.uiapp-0.0.0] startup
# [0.879s] [ext: omni.usd.schema.metrics.assembler-107.3.1] startup
# [0.885s] [ext: omni.usd.schema.audio-0.0.0] startup
# [0.897s] [ext: isaacsim.robot.schema-3.6.0] startup
# [0.914s] [ext: omni.usd.schema.anim-0.0.0] startup
# 2026-03-04T08:49:19Z s] [Warning] [gpu.foundation.plugin] Skipping unsupported non-NVIDIA GPU: AMD Radeon(TM) Graphics
# 2026-03-04T08:49:19Z s] [Warning] [gpu.foundation.plugin] Skipping unsupported non-NVIDIA GPU: AMD Radeon(TM) Graphics
# [0.941s] [ext: omni.usd_resolver-1.0.0] startup
# [0.948s] [ext: omni.usd.core-1.5.3] startup
# [0.971s] [ext: omni.usd.schema.omni_sensors-0.0.0] startup
# [0.990s] [ext: omni.usd.schema.physx-107.3.26] startup
# [1.017s] [ext: omni.usd.schema.omniscripting-1.0.0] startup
# [1.026s] [ext: omni.usd.schema.omnigraph-1.0.0] startup
# [1.035s] [ext: omni.usd.schema.semantics-0.0.0] startup
# [1.040s] [ext: omni.usd.schema.geospatial-0.0.0] startup
# [1.045s] [ext: omni.kit.window.popup_dialog-2.0.24] startup
# [1.052s] [ext: omni.activity.core-1.0.3] startup
# [1.055s] [ext: omni.kit.widget.nucleus_connector-2.0.1] startup
# [1.059s] [ext: omni.kit.usd_undo-0.1.8] startup
# [1.060s] [ext: omni.graph.exec-0.9.6] startup
# [1.062s] [ext: omni.kit.actions.core-1.0.0] startup
# [1.069s] [ext: usdrt.scenegraph-7.6.1] startup
# [1.124s] [ext: omni.resourcemonitor-107.0.1] startup
# [1.128s] [ext: omni.kit.exec.core-0.13.4] startup
# [1.133s] [ext: omni.timeline-1.0.14] startup
# [1.137s] [ext: omni.kit.commands-1.4.10] startup
# [1.145s] [ext: omni.kit.audiodeviceenum-1.0.2] startup
# [1.149s] [ext: omni.hydra.usdrt_delegate-7.5.1] startup
#
# |---------------------------------------------------------------------------------------------|
# | Driver Version: 581.29        | Graphics API: Vulkan
# |=============================================================================================|
# | GPU | Name                             | Active | LDA | GPU Memory | Vendor-ID | LUID       |
# |     |                                  |        |     |            | Device-ID | UUID       |
# |     |                                  |        |     |            | Bus-ID    |            |
# |---------------------------------------------------------------------------------------------|
# | 0   | NVIDIA GeForce RTX 5080          | Yes: 0 |     | 15889   MB | 10de      | 295a0100.. |
# |     |                                  |        |     |            | 2c02      | c7fa9756.. |
# |     |                                  |        |     |            | 1         |            |
# |---------------------------------------------------------------------------------------------|
# | 1   | AMD Radeon(TM) Graphics          |        |     | 2048    MB | 1002      | 876d0100.. |
# |     |                                  |        |     |            | 13c0      | 00000000.. |
# |     |                                  |        |     |            | N/A       |            |
# |=============================================================================================|
# | OS: Windows 11 Pro, Version: 10.0 (25H2), Build: 26200, Kernel: 10.0.26100.7824
# | Processor: AMD Ryzen 9 9950X 16-Core Processor
# | Cores: 16 | Logical Cores: 32
# |---------------------------------------------------------------------------------------------|
# | Total Memory (MB): 128627 | Free Memory: 104434
# | Total Page/Swap (MB): 136819 | Free Page/Swap: 107578
# |---------------------------------------------------------------------------------------------|
# [1.160s] [ext: omni.hydra.scene_delegate-0.3.4] startup
# [1.165s] [ext: omni.usd-1.13.10] startup
# [1.202s] [ext: omni.kit.asset_converter-5.0.17] startup
# [1.213s] [ext: omni.usd.schema.omni_lens_distortion-0.0.0] startup
# [1.216s] [ext: omni.usd.schema.render_settings.rtx-0.0.0] startup
# [1.217s] [ext: omni.index.libs-380600.8087.0] startup
# [1.218s] [ext: omni.volume-0.5.2] startup
# [1.227s] [ext: omni.ujitso.client-0.0.0] startup
# [1.229s] [ext: omni.index-1.0.1] startup
# [1.230s] [ext: omni.hydra.rtx.shadercache.vulkan-1.0.0] startup
# [1.232s] [ext: omni.hydra.rtx-1.0.0] startup
# [1.276s] [ext: omni.kit.notification_manager-1.0.10] startup
# [1.279s] [ext: omni.kit.clipboard-1.0.5] startup
# [1.282s] [ext: omni.kit.viewport.legacy_gizmos-1.0.19] startup
# [1.284s] [ext: omni.kit.raycast.query-1.1.0] startup
# [1.288s] [ext: omni.kit.menu.core-1.1.2] startup
# [1.289s] [ext: omni.kit.widget.options_menu-1.1.6] startup
# [1.295s] [ext: omni.kit.helper.file_utils-0.1.9] startup
# [1.297s] [ext: omni.kit.widget.path_field-2.0.11] startup
# [1.299s] [ext: omni.kit.widget.context_menu-1.2.5] startup
# [1.301s] [ext: omni.kit.widget.options_button-1.0.3] startup
# [1.303s] [ext: omni.kit.widget.filebrowser-2.12.3] startup
# [1.311s] [ext: omni.kit.widget.browser_bar-2.0.10] startup
# [1.313s] [ext: omni.kit.usd.layers-2.2.11] startup
# [1.322s] [ext: omni.ui.scene-1.11.5] startup
# [1.328s] [ext: omni.kit.viewport.registry-104.0.6] startup
# [1.329s] [ext: omni.kit.window.filepicker-2.13.4] startup
# [1.347s] [ext: omni.kit.menu.utils-2.0.5] startup
# [1.358s] [ext: omni.kit.context_menu-1.8.6] startup
# [1.362s] [ext: omni.kit.viewport.scene_camera_model-1.0.6] startup
# [1.365s] [ext: omni.kit.hydra_texture-1.4.6] startup
# [1.369s] [ext: omni.kit.window.file_importer-1.1.18] startup
# [1.375s] [ext: omni.kit.widget.searchable_combobox-1.0.6] startup
# [1.377s] [ext: omni.kit.window.drop_support-1.0.5] startup
# [1.378s] [ext: omni.kit.widget.viewport-107.1.3] startup
# [1.385s] [ext: omni.kit.material.library-2.0.7] startup
# [1.393s] [ext: omni.hydra.engine.stats-1.0.3] startup
# [1.395s] [ext: omni.kit.widget.settings-1.2.6] startup
# [1.398s] [ext: omni.kit.viewport.window-107.2.0] startup
# [1.618s] [ext: omni.kit.window.preferences-1.8.0] startup
# [1.631s] [ext: omni.kit.widget.toolbar-2.0.1] startup
# [1.642s] [ext: omni.kit.viewport.utility-1.1.2] startup
# [1.643s] [ext: omni.kit.manipulator.transform-107.0.0] startup
# [1.650s] [ext: omni.kit.manipulator.tool.snap-1.5.13] startup
# [1.657s] [ext: omni.kit.manipulator.selector-1.1.3] startup
# [1.660s] [ext: omni.kit.viewport.manipulator.transform-107.0.4] startup
# [1.663s] [ext: omni.kit.manipulator.viewport-107.0.1] startup
# [1.665s] [ext: omni.kit.primitive.mesh-1.0.17] startup
# [1.671s] [ext: omni.kit.manipulator.prim.core-107.0.8] startup
# [1.681s] [ext: omni.fabric.commands-1.1.6] startup
# [1.687s] [ext: omni.kit.manipulator.prim.usd-107.0.3] startup
# [1.689s] [ext: omni.kit.manipulator.prim.fabric-107.0.4] startup
# [1.691s] [ext: omni.debugdraw-0.1.4] startup
# [1.695s] [ext: omni.kit.property.adapter.core-1.0.2] startup
# [1.699s] [ext: omni.kit.manipulator.prim-107.0.0] startup
# [1.699s] [ext: omni.usdphysics-107.3.26] startup
# [1.702s] [ext: omni.kit.manipulator.selection-106.0.1] startup
# [1.704s] [ext: omni.kit.hotkeys.core-1.3.10] startup
# [1.706s] [ext: omni.kit.property.adapter.usd-1.0.2] startup
# [1.709s] [ext: omni.kit.widget.searchfield-1.1.8] startup
# [1.712s] [ext: omni.kit.widget.filter-1.1.4] startup
# [1.713s] [ext: omni.kit.property.adapter.fabric-1.0.3] startup
# [1.716s] [ext: omni.kit.widget.highlight_label-1.0.3] startup
# [1.717s] [ext: omni.kit.window.file_exporter-1.0.33] startup
# [1.719s] [ext: omni.kit.stage_template.core-1.1.22] startup
# [1.720s] [ext: omni.kit.widget.stage-3.1.4] startup
# [1.743s] [ext: omni.kit.widget.prompt-1.0.7] startup
# [1.745s] [ext: omni.kit.window.property-1.12.1] startup
# [1.751s] [ext: omni.kvdb-107.3.26] startup
# [1.756s] [ext: omni.kit.window.file-2.0.5] startup
# [1.762s] [ext: omni.kit.window.content_browser_registry-0.0.6] startup
# [1.763s] [ext: omni.kit.viewport.menubar.core-107.2.1] startup
# [1.798s] [ext: omni.kit.viewport.actions-107.0.2] startup
# [1.803s] [ext: omni.kit.window.content_browser-3.1.3] startup
# [1.816s] [ext: omni.kit.viewport.menubar.display-107.0.3] startup
# [1.818s] [ext: omni.kit.widget.layers-1.8.6] startup
# [1.838s] [ext: omni.kit.property.usd-4.5.12] startup
# [1.854s] [ext: omni.physx.foundation-107.3.26] startup
# [1.868s] [ext: omni.localcache-107.3.26] startup
# [1.872s] [ext: omni.convexdecomposition-107.3.26] startup
# [1.876s] [ext: omni.usdphysics.ui-107.3.26] startup
# [1.901s] [ext: omni.physx.cooking-107.3.26] startup
# [1.907s] [ext: omni.usd.metrics.assembler-107.3.1] startup
# [1.917s] [ext: omni.physx-107.3.26] startup
# [1.933s] [ext: omni.physics-107.3.26] startup
# [1.939s] [ext: omni.physx.commands-107.3.26] startup
# [1.944s] [ext: omni.physics.stageupdate-107.3.26] startup
# [1.949s] [ext: omni.inspect-1.0.2] startup
# [1.954s] [ext: omni.physx.ui-107.3.26] startup
# [1.992s] [ext: omni.graph.core-2.184.5] startup
# [1.998s] [ext: omni.physics.physx-107.3.26] startup
# 2026-03-04T08:49:20Z [1,927ms] [Warning] [carb] Acquiring non optional plugin interface which is not listed as dependency: [omni::physx::IPhysxBenchmarks v1.0] (plugin: <default plugin>), by client: omni.physics.physx.plugin. Add it to CARB_PLUGIN_IMPL_DEPS() macro of a client.
# [2.000s] [ext: isaacsim.core.deprecation_manager-0.2.7] startup
# [2.002s] [ext: omni.physics.tensors-107.3.26] startup
# [2.009s] [ext: omni.kit.numpy.common-0.1.3] startup
# [2.011s] [ext: isaacsim.core.version-2.0.6] startup
# [2.013s] [ext: omni.warp.core-1.8.2] startup
# [2.141s] [ext: omni.usd.metrics.assembler.physics-107.3.26] startup
# [2.144s] [ext: omni.isaac.dynamic_control-2.0.7] startup
# 2026-03-04T08:49:20Z [2,078ms] [Warning] [omni.isaac.dynamic_control] omni.isaac.dynamic_control is deprecated as of Isaac Sim 4.5. No action is needed from end-users.
# [2.152s] [ext: isaacsim.storage.native-1.5.1] startup
# [2.155s] [ext: isaacsim.core.utils-3.5.1] startup
# [2.158s] [ext: omni.graph.tools-1.79.2] startup
# [2.198s] [ext: omni.graph.action_core-1.1.7] startup
# [2.202s] [ext: omni.graph-1.141.2] startup
# [2.255s] [ext: omni.physx.tensors-107.3.26] startup
# [2.258s] [ext: omni.graph.action_nodes-1.50.4] startup
# [2.263s] [ext: isaacsim.core.simulation_manager-1.4.4] startup
# [2.512s] [ext: omni.kit.usd.collect-2.4.5] startup
# [2.518s] [ext: omni.kit.stage_templates-2.0.0] startup
# [2.522s] [ext: isaacsim.core.prims-0.6.1] startup
# [2.545s] [ext: omni.kit.usdz_export-1.0.9] startup
# [2.550s] [ext: isaacsim.core.api-4.8.0] startup
# [2.571s] [ext: omni.kit.tool.asset_importer-4.3.2] startup
# [2.581s] [ext: omni.graph.action-1.130.0] startup
# [2.582s] [ext: omni.kit.selection-0.1.6] startup
# [2.586s] [ext: omni.ui_query-1.1.8] startup
# [2.588s] [ext: omni.kit.stagerecorder.core-107.0.3] startup
# [2.594s] [ext: omni.kit.widget.text_editor-1.1.1] startup
# [2.598s] [ext: omni.kit.ui_test-1.3.7] startup
# [2.602s] [ext: omni.kit.stagerecorder.ui-107.0.1] startup
# [2.608s] [ext: omni.kit.window.extensions-1.4.27] startup
# [2.619s] [ext: omni.graph.visualization.nodes-2.1.3] startup
# [2.630s] [ext: omni.kit.stagerecorder.bundle-105.0.2] startup
# [2.633s] [ext: isaacsim.gui.components-1.2.1] startup
# [2.642s] [ext: isaacsim.gui.menu-2.4.4] startup
# [2.719s] [ext: isaacsim.app.about-2.0.11] startup
# [2.723s] [ext: isaacsim.asset.importer.mjcf-2.5.13] startup
# [2.734s] [ext: semantics.schema.editor-2.0.2] startup
# 2026-03-04T08:49:20Z [2,668ms] [Warning] [pxr.Semantics] pxr.Semantics is deprecated - please use Semantics instead
# [2.743s] [ext: omni.kit.widget.graph-2.0.0] startup
# [2.754s] [ext: semantics.schema.property-2.0.1] startup
# [2.758s] [ext: omni.kit.graph.delegate.default-1.2.3] startup
# [2.760s] [ext: isaacsim.core.cloner-1.4.10] startup
# [2.764s] [ext: omni.kit.graph.editor.core-1.5.3] startup
# [2.770s] [ext: omni.kit.graph.usd.commands-1.3.1] startup
# [2.772s] [ext: omni.kit.widget.material_preview-1.0.16] startup
# [2.776s] [ext: omni.graph.image.core-0.6.1] startup
# [2.778s] [ext: omni.graph.scriptnode-1.50.0] startup
# [2.780s] [ext: omni.kit.widget.stage_icons-1.0.8] startup
# [2.784s] [ext: omni.kit.window.material_graph-1.9.1] startup
# [2.803s] [ext: omni.graph.image.nodes-1.3.1] startup
# [2.805s] [ext: omni.kit.menu.create-2.0.1] startup
# [2.807s] [ext: omni.kit.window.stage-2.6.1] startup
# [2.813s] [ext: omni.kit.viewport.menubar.settings-107.0.3] startup
# [2.822s] [ext: omni.graph.nodes-1.170.10] startup
# [2.835s] [ext: omni.graph.ui_nodes-1.50.5] startup
# [2.841s] [ext: isaacsim.util.debug_draw-3.1.0] startup
# [2.849s] [ext: omni.syntheticdata-0.6.13] startup
# [2.871s] [ext: omni.kit.scripting-107.3.2] startup
# [2.890s] [ext: omni.videoencoding-0.1.2] startup
# [2.902s] [ext: omni.warp-1.8.2] startup
# [2.913s] [ext: omni.sensors.nv.common-3.0.0] startup
# [2.944s] [ext: isaacsim.sensors.physx-2.3.2] startup
# [2.956s] [ext: isaacsim.replicator.behavior-1.1.16] startup
# [2.962s] [ext: omni.sensors.net-1.0.0] startup
# [2.981s] [ext: omni.replicator.core-1.12.27] startup
# 2026-03-04T08:49:21Z [3,052ms] [Warning] [omni.graph.core.plugin] Found duplicate of category 'Replicator' - was 'Annotators', adding 'Fabric Reader'
# 2026-03-04T08:49:21Z [3,052ms] [Warning] [omni.graph.core.plugin] Category 'Replicator' not accepted on node type 'omni.replicator.core.FabricReader' in extension 'omni.replicator.core'
# 2026-03-04T08:49:21Z [3,053ms] [Warning] [omni.replicator.core.scripts.extension] No material configuration file, adding configuration to material settings directly.
# [3.129s] [ext: omni.sensors.nv.materials-2.0.0] startup
# [3.153s] [ext: isaacsim.simulation_app-2.12.2] startup
# [3.154s] [ext: omni.anim.curve.core-1.3.1] startup
# [3.171s] [ext: omni.kit.manipulator.camera-106.0.4] startup
# [3.179s] [ext: isaacsim.core.nodes-3.4.3] startup
# [3.190s] [ext: omni.sensors.nv.ids-2.0.0] startup
# [3.197s] [ext: omni.sensors.nv.lidar-3.0.0] startup
# [3.214s] [ext: omni.sensors.nv.wpm-3.0.0] startup
# [3.222s] [ext: omni.kit.property.audio-1.0.16] startup
# [3.228s] [ext: omni.kit.property.camera-1.0.10] startup
# [3.232s] [ext: omni.kit.property.light-1.0.12] startup
# [3.246s] [ext: omni.kit.property.geometry-2.0.4] startup
# [3.257s] [ext: omni.sensors.nv.radar-3.0.0] startup
# [3.271s] [ext: isaacsim.gui.property-1.1.3] startup
# [3.282s] [ext: omni.kit.property.render-1.2.1] startup
# [3.287s] [ext: omni.hydra.scene_api-0.1.2] startup
# [3.293s] [ext: isaacsim.test.docstring-1.1.0] startup
# [3.301s] [ext: isaacsim.core.experimental.utils-0.3.0] startup
# [3.306s] [ext: omni.kit.widget.zoombar-1.0.6] startup
# [3.316s] [ext: omni.kit.property.transform-1.5.13] startup
# [3.329s] [ext: omni.kit.property.material-1.11.9] startup
# [3.383s] [ext: isaacsim.core.experimental.prims-0.8.1] startup
# [3.506s] [ext: omni.kit.browser.core-2.3.13] startup
# [3.550s] [ext: omni.kit.property.bundle-1.4.1] startup
# [3.562s] [ext: isaacsim.sensors.rtx-15.8.4] startup
# [3.606s] [ext: omni.kit.viewport.menubar.camera-107.0.6] startup
# [3.671s] [ext: isaacsim.robot.surface_gripper-3.3.1] startup
# [3.710s] [ext: omni.kit.browser.folder.core-1.10.9] startup
# [3.734s] [ext: isaacsim.sensors.physics-0.4.3] startup
# [3.746s] [ext: omni.kit.tool.collect-2.2.18] startup
# [3.754s] [ext: omni.kit.menu.stage-1.2.7] startup
# [3.759s] [ext: isaacsim.robot.manipulators-3.3.6] startup
# [3.766s] [ext: omni.kit.viewport.menubar.lighting-107.3.1] startup
# [3.780s] [ext: omni.kit.viewport.menubar.render-107.0.10] startup
# [3.791s] [ext: isaacsim.robot.policy.examples-4.1.11] startup
# [3.796s] [ext: isaacsim.examples.browser-0.2.1] startup
# [3.808s] [ext: isaacsim.asset.importer.urdf-2.4.30] startup
# [3.838s] [ext: omni.kit.window.console-1.1.4] startup
# [3.853s] [ext: omni.physx.demos-107.3.26] startup
# [3.900s] [ext: omni.kit.property.physx-107.3.26] startup
# [3.922s] [ext: omni.rtx.window.settings-0.6.19] startup
# [3.932s] [ext: omni.ocio-0.1.1] startup
# [3.935s] [ext: omni.replicator.replicator_yaml-2.0.11] startup
# [3.954s] [ext: omni.asset_validator.core-1.1.6] startup
# [4.011s] [ext: omni.physx.vehicle-107.3.26] startup
# [4.034s] [ext: omni.rtx.settings.core-0.6.5] startup
# [4.040s] [ext: omni.kit.window.script_editor-2.0.1] startup
# [4.046s] [ext: isaacsim.robot.wheeled_robots-4.0.24] startup
# [4.061s] [ext: omni.kit.window.toolbar-2.0.0] startup
# [4.066s] [ext: omni.physx.asset_validator-107.3.26] startup
# [4.078s] [ext: omni.physx.camera-107.3.26] startup
# [4.090s] [ext: omni.physx.cct-107.3.26] startup
# [4.105s] [ext: omni.physx.graph-107.3.26] startup
# [4.123s] [ext: omni.physx.supportui-107.3.26] startup
# [4.150s] [ext: omni.physx.telemetry-107.3.26] startup
# [4.154s] [ext: omni.kit.window.status_bar-0.1.9] startup
# [4.159s] [ext: omni.usd.metrics.assembler.ui-107.3.1] startup
# [4.170s] [ext: isaacsim.asset.browser-1.3.23] startup
# [4.375s] [ext: isaacsim.core.throttling-2.2.2] startup
# [4.380s] [ext: omni.kit.ui.actions-1.0.5] startup
# [4.383s] [ext: omni.physx.bundle-107.3.26] startup
# [4.384s] [ext: isaacsim.sensors.camera-1.3.6] startup
# [4.390s] [ext: isaaclab-0.47.2] startup
# [4.564s] [ext: isaaclab_assets-0.2.3] startup
# [4.775s] [ext: isaaclab_tasks-0.11.6] startup
# [5.480s] [ext: omni.kit.menu.common-2.0.1] startup
# [5.482s] [ext: isaaclab_rl-0.4.4] startup
# [5.484s] [ext: isaaclab_mimic-1.0.15] startup
# [5.484s] [ext: isaaclab.python-2.3.0] startup
# [5.487s] Simulation App Starting
# 2026-03-04T08:49:23Z [5,668ms] [Warning] [omni.fabric.plugin] Warning: attribute overrideClipRange not found for bucket id 9
#
# [5.904s] app ready
# [9.593s] Simulation App Startup Complete
# C:\Users\Teresa\Documents\GitHub\navsim\isaac_lab\aerotaxi\env_command\env_13\flight_plan.py:29: UserWarning: Treat the new Tool classes introduced in v1.5 as experimental for now; the API and rcParam may change in future versions.
#   plt.rcParams["toolbar"] = "toolmanager"
# [INFO]: Parsing configuration from: aerotaxi.env_command.env_13.env:UAVEnvCfg
# [INFO]: Parsing configuration from: aerotaxi.env_command.env_13.grid_hiperparametros.cfg_files.ppo_random_command9_11_cfg:Command9PPORunnerCfg
# [INFO] Logging experiment in directory: C:\Users\Teresa\Documents\GitHub\navsim\isaac_lab\aerotaxi\env_command\env_13\logs\rsl_rl\command9
# Exact experiment name requested from command line: 2026-03-04_09-49-28
# Setting seed: 42
# [10.544s] [ext: omni.physx.fabric-107.3.26] startup
# [2026-03-04 09:49:28,795][ogn_registration][INFO] - Looking for Python nodes to register in omni.physx.fabric-107.3.26
# [2026-03-04 09:49:28,796][ogn_registration][INFO] -  -> Registered nodes from module omni.physxfabric at c:\users\teresa\miniconda3\envs\env_isaaclab\lib\site-packages\isaacsim\extscache\omni.physx.fabric-107.3.26+107.3.3.wx64.r.cp311.u353
# [2026-03-04 09:49:28,796][ogn_registration][INFO] - Registering nodes in c:\users\teresa\miniconda3\envs\env_isaaclab\lib\site-packages\isaacsim\extscache\omni.physx.fabric-107.3.26+107.3.3.wx64.r.cp311.u353 imported as omni.physxfabric with AutoNode config {}
# [2026-03-04 09:49:28,796][ogn_registration][INFO] - Registering Python Node Types from omni.physxfabric at c:\users\teresa\miniconda3\envs\env_isaaclab\lib\site-packages\isaacsim\extscache\omni.physx.fabric-107.3.26+107.3.3.wx64.r.cp311.u353 in omni.physx.fabric
# [2026-03-04 09:49:28,796][ogn_registration][INFO] - ========================================================================================================================
# [2026-03-04 09:49:28,797][ogn_registration][INFO] - No dependency on omni.graph, therefore no nodes to register in omni.physx.fabric
# [2026-03-04 09:49:28,797][ogn_registration][INFO] - ...None found, no registration to do
# [2026-03-04 09:49:28,797][ogn_registration][INFO] - ...Skipping: No OmniGraph presence in the module omni.physxfabric - No nodes in this module, do not remember it
# [2026-03-04 09:49:28,797][ogn_registration][INFO] - Destroying registration record for omni.physx.fabric
# [2026-03-04 09:49:28,797][ogn_registration][INFO] - OGN register omni.physx.fabric-107.3.26 took 1329400.000000
# [INFO]: Base environment:
# 	Environment device    : cuda:0
# 	Environment seed      : 42
# 	Physics step-size     : 0.005
# 	Rendering step-size   : 0.02
# 	Environment step-size : 0.02
# [INFO]: Time taken for scene creation : 2.756471 seconds
# [INFO]: Scene manager:  <class InteractiveScene>
# 	Number of environments: 4096
# 	Environment spacing   : 200.0
# 	Source prim name      : /World/envs/env_0
# 	Global prim paths     : []
# 	Replicate physics     : False
# [INFO]: Starting the simulation. This may take a few seconds. Please wait...
# [INFO]: Time taken for simulation start : 30.493509 seconds
# [INFO] Command Manager:  <CommandManager> contains 1 active terms.
# +--------------------------------------+
# |         Active Command Terms         |
# +-------+-------------+----------------+
# | Index | Name        |      Type      |
# +-------+-------------+----------------+
# |   0   | vel_command | UAVcommandTerm |
# +-------+-------------+----------------+
#
# [INFO] Event Manager:  <EventManager> contains 1 active terms.
# +-----------------------------------+
# | Active Event Terms in Mode: 'reset' |
# +----------+------------------------+
# |  Index   | Name                   |
# +----------+------------------------+
# |    0     | reset_pos              |
# |    1     | randomize_mass         |
# |    2     | randomize_wind         |
# +----------+------------------------+
#
# [INFO] Recorder Manager:  <RecorderManager> contains 0 active terms.
# +---------------------+
# | Active Recorder Terms |
# +-----------+---------+
# |   Index   | Name    |
# +-----------+---------+
# +-----------+---------+
#
# [INFO] Action Manager:  <ActionManager> contains 1 active terms.
# +-----------------------------------+
# |   Active Action Terms (shape: 4)  |
# +--------+-------------+------------+
# | Index  | Name        |  Dimension |
# +--------+-------------+------------+
# |   0    | rotors_vel  |          4 |
# +--------+-------------+------------+
#
# [INFO] Observation Manager: <ObservationManager> contains 2 groups.
# +---------------------------------------------------------+
# | Active Observation Terms in Group: 'policy' (shape: (45,)) |
# +-----------+---------------------------------+-----------+
# |   Index   | Name                            |   Shape   |
# +-----------+---------------------------------+-----------+
# |     0     | dist                            |    (9,)   |
# |     1     | lin_vel                         |    (9,)   |
# |     2     | ang_vel                         |    (9,)   |
# |     3     | projected_gravity               |    (9,)   |
# |     4     | target_vel                      |    (9,)   |
# +-----------+---------------------------------+-----------+
# +---------------------------------------------------------+
# | Active Observation Terms in Group: 'critic' (shape: (45,)) |
# +-----------+---------------------------------+-----------+
# |   Index   | Name                            |   Shape   |
# +-----------+---------------------------------+-----------+
# |     0     | dist                            |    (9,)   |
# |     1     | lin_vel                         |    (9,)   |
# |     2     | ang_vel                         |    (9,)   |
# |     3     | projected_gravity               |    (9,)   |
# |     4     | target_vel                      |    (9,)   |
# +-----------+---------------------------------+-----------+
#
# [INFO] Termination Manager:  <TerminationManager> contains 4 active terms.
# +---------------------------------------+
# |        Active Termination Terms       |
# +-------+--------------------+----------+
# | Index | Name               | Time Out |
# +-------+--------------------+----------+
# |   0   | time_out           |   True   |
# |   1   | below_min_altitude |  False   |
# |   2   | bad_attitude       |  False   |
# |   3   | safety_shutdown    |  False   |
# +-------+--------------------+----------+
#
# [INFO] Reward Manager:  <RewardManager> contains 5 active terms.
# +------------------------------------------+
# |           Active Reward Terms            |
# +-------+-------------------------+--------+
# | Index | Name                    | Weight |
# +-------+-------------------------+--------+
# |   0   | rew_attitude_stability2 |    2.0 |
# |   1   | rew_ang_vel_stability4  |    1.0 |
# |   2   | rew_vel2                |    4.0 |
# |   3   | rew_pos2                |   12.0 |
# |   4   | rew_action_rate         |    0.8 |
# +-------+-------------------------+--------+
#
# [INFO] Curriculum Manager:  <CurriculumManager> contains 0 active terms.
# +----------------------+
# | Active Curriculum Terms |
# +-----------+----------+
# |   Index   | Name     |
# +-----------+----------+
# +-----------+----------+
#
# Creating window for environment.
# [INFO]: Completed setting up the environment...
# 2026-03-04T08:50:02Z [44,241ms] [Warning] [omni.physx.fabric.plugin] FabricManager::initializePointInstancer mismatched prototypes on point instancer: /Visuals/target_commands.
# C:\Users\Teresa\miniconda3\envs\env_isaaclab\Lib\site-packages\rsl_rl\utils\utils.py:244: UserWarning: The observation configuration dictionary 'obs_groups' must contain the 'policy' key. As an observation group with the name 'policy' was found, this is assumed to be the observation set. Consider adding the 'policy' key to the 'obs_groups' dictionary for clarity. This behavior will be removed in a future version.
#   warnings.warn(
# C:\Users\Teresa\miniconda3\envs\env_isaaclab\Lib\site-packages\rsl_rl\utils\utils.py:282: UserWarning: The observation configuration dictionary 'obs_groups' must contain the 'critic' key. As an observation group with the name 'critic' was found, this is assumed to be the observation set. Consider adding the 'critic' key to the 'obs_groups' dictionary for clarity. This behavior will be removed in a future version.
#   warnings.warn(
# --------------------------------------------------------------------------------
# Resolved observation sets:
# 	 policy :  ['policy']
# 	 critic :  ['critic']
# --------------------------------------------------------------------------------
# Actor MLP: MLP(
#   (0): Linear(in_features=45, out_features=128, bias=True)
#   (1): ELU(alpha=1.0)
#   (2): Linear(in_features=128, out_features=128, bias=True)
#   (3): ELU(alpha=1.0)
#   (4): Linear(in_features=128, out_features=128, bias=True)
#   (5): ELU(alpha=1.0)
#   (6): Linear(in_features=128, out_features=4, bias=True)
# )
# Critic MLP: MLP(
#   (0): Linear(in_features=45, out_features=256, bias=True)
#   (1): ELU(alpha=1.0)
#   (2): Linear(in_features=256, out_features=256, bias=True)
#   (3): ELU(alpha=1.0)
#   (4): Linear(in_features=256, out_features=256, bias=True)
#   (5): ELU(alpha=1.0)
#   (6): Linear(in_features=256, out_features=1, bias=True)
# )
# 2026-03-04T08:50:10Z [52,523ms] [Warning] [carb] Client gpu.foundation.plugin has acquired [gpu::unstable::IMemoryBudgetManagerFactory v0.1] 100 times. Consider accessing this interface with carb::getCachedInterface() (Performance warning)
# ################################################################################
#                        Learning iteration 0/1001
#
#                        Computation: 51113 steps/s (collection: 9.912s, learning 0.345s)
#              Mean action noise std: 0.05
#           Mean value_function loss: 2.0564
#                Mean surrogate loss: 0.0200
#                  Mean entropy loss: -6.2769
#                        Mean reward: 7.71
#                Mean episode length: 70.48
# Episode_Reward/rew_attitude_stability2: 0.0569
# Episode_Reward/rew_ang_vel_stability4: 0.0297
#            Episode_Reward/rew_vel2: 0.0027
#            Episode_Reward/rew_pos2: 0.1659
#     Episode_Reward/rew_action_rate: -0.0000
#       Episode_Termination/time_out: 0.0243
# Episode_Termination/below_min_altitude: 0.0023
#   Episode_Termination/bad_attitude: 0.4208
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 524288
#                     Iteration time: 10.26s
#                       Time elapsed: 00:00:10
#                                ETA: 02:51:07
#
# Could not find git repository in C:\Users\Teresa\miniconda3\envs\env_isaaclab\Lib\site-packages\rsl_rl\__init__.py. Skipping.
# Storing git diff for 'navsim' in: C:\Users\Teresa\Documents\GitHub\navsim\isaac_lab\aerotaxi\env_command\env_13\logs\rsl_rl\command9\2026-03-04_09-49-28_ppo_random_command9_11\git\navsim.diff
# ################################################################################
#                        Learning iteration 1/1001
#
#                        Computation: 63953 steps/s (collection: 7.917s, learning 0.281s)
#              Mean action noise std: 0.05
#           Mean value_function loss: 1.5420
#                Mean surrogate loss: 0.0014
#                  Mean entropy loss: -6.2608
#                        Mean reward: 7.66
#                Mean episode length: 61.44
# Episode_Reward/rew_attitude_stability2: 0.0732
# Episode_Reward/rew_ang_vel_stability4: 0.0368
#            Episode_Reward/rew_vel2: 0.0034
#            Episode_Reward/rew_pos2: 0.1774
#     Episode_Reward/rew_action_rate: -0.0000
#       Episode_Termination/time_out: 0.0042
# Episode_Termination/below_min_altitude: 0.0212
#   Episode_Termination/bad_attitude: 0.9594
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 1048576
#                     Iteration time: 8.20s
#                       Time elapsed: 00:00:18
#                                ETA: 02:33:47
#
# ################################################################################
#                        Learning iteration 2/1001
#
#                        Computation: 65632 steps/s (collection: 7.731s, learning 0.258s)
#              Mean action noise std: 0.05
#           Mean value_function loss: 1.3301
#                Mean surrogate loss: 0.0009
#                  Mean entropy loss: -6.2305
#                        Mean reward: 7.24
#                Mean episode length: 63.24
# Episode_Reward/rew_attitude_stability2: 0.0725
# Episode_Reward/rew_ang_vel_stability4: 0.0364
#            Episode_Reward/rew_vel2: 0.0035
#            Episode_Reward/rew_pos2: 0.1777
#     Episode_Reward/rew_action_rate: -0.0000
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 0.0183
#   Episode_Termination/bad_attitude: 0.9817
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 1572864
#                     Iteration time: 7.99s
#                       Time elapsed: 00:00:26
#                                ETA: 02:26:45
#
# ################################################################################
#                        Learning iteration 3/1001
#
#                        Computation: 65657 steps/s (collection: 7.760s, learning 0.225s)
#              Mean action noise std: 0.05
#           Mean value_function loss: 1.1562
#                Mean surrogate loss: 0.0010
#                  Mean entropy loss: -6.1945
#                        Mean reward: 7.54
#                Mean episode length: 64.20
# Episode_Reward/rew_attitude_stability2: 0.0728
# Episode_Reward/rew_ang_vel_stability4: 0.0366
#            Episode_Reward/rew_vel2: 0.0033
#            Episode_Reward/rew_pos2: 0.1772
#     Episode_Reward/rew_action_rate: -0.0000
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 0.0194
#   Episode_Termination/bad_attitude: 0.9806
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 2097152
#                     Iteration time: 7.99s
#                       Time elapsed: 00:00:34
#                                ETA: 02:23:09
#
# ################################################################################
#                        Learning iteration 4/1001
#
#                        Computation: 64808 steps/s (collection: 7.795s, learning 0.295s)
#              Mean action noise std: 0.05
#           Mean value_function loss: 1.0242
#                Mean surrogate loss: 0.0009
#                  Mean entropy loss: -6.1631
#                        Mean reward: 7.46
#                Mean episode length: 59.89
# Episode_Reward/rew_attitude_stability2: 0.0730
# Episode_Reward/rew_ang_vel_stability4: 0.0368
#            Episode_Reward/rew_vel2: 0.0035
#            Episode_Reward/rew_pos2: 0.1781
#     Episode_Reward/rew_action_rate: -0.0000
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 0.0160
#   Episode_Termination/bad_attitude: 0.9840
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 2621440
#                     Iteration time: 8.09s
#                       Time elapsed: 00:00:42
#                                ETA: 02:21:18
#
# ################################################################################
#                        Learning iteration 5/1001
#
#                        Computation: 65387 steps/s (collection: 7.739s, learning 0.280s)
#              Mean action noise std: 0.05
#           Mean value_function loss: 0.9490
#                Mean surrogate loss: 0.0009
#                  Mean entropy loss: -6.1418
#                        Mean reward: 7.31
#                Mean episode length: 57.99
# Episode_Reward/rew_attitude_stability2: 0.0725
# Episode_Reward/rew_ang_vel_stability4: 0.0365
#            Episode_Reward/rew_vel2: 0.0033
#            Episode_Reward/rew_pos2: 0.1773
#     Episode_Reward/rew_action_rate: -0.0000
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 0.0163
#   Episode_Termination/bad_attitude: 0.9837
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 3145728
#                     Iteration time: 8.02s
#                       Time elapsed: 00:00:50
#                                ETA: 02:19:49
#
# ################################################################################
#                        Learning iteration 6/1001
#
#                        Computation: 65701 steps/s (collection: 7.756s, learning 0.224s)
#              Mean action noise std: 0.05
#           Mean value_function loss: 0.8202
#                Mean surrogate loss: 0.0010
#                  Mean entropy loss: -6.1106
#                        Mean reward: 8.18
#                Mean episode length: 69.18
# Episode_Reward/rew_attitude_stability2: 0.0740
# Episode_Reward/rew_ang_vel_stability4: 0.0373
#            Episode_Reward/rew_vel2: 0.0036
#            Episode_Reward/rew_pos2: 0.1781
#     Episode_Reward/rew_action_rate: -0.0000
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 0.0153
#   Episode_Termination/bad_attitude: 0.9847
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 3670016
#                     Iteration time: 7.98s
#                       Time elapsed: 00:00:58
#                                ETA: 02:18:37
#
# ################################################################################
#                        Learning iteration 7/1001
#
#                        Computation: 64218 steps/s (collection: 7.897s, learning 0.267s)
#              Mean action noise std: 0.05
#           Mean value_function loss: 0.7234
#                Mean surrogate loss: 0.0007
#                  Mean entropy loss: -6.0897
#                        Mean reward: 7.40
#                Mean episode length: 61.14
# Episode_Reward/rew_attitude_stability2: 0.0732
# Episode_Reward/rew_ang_vel_stability4: 0.0368
#            Episode_Reward/rew_vel2: 0.0036
#            Episode_Reward/rew_pos2: 0.1789
#     Episode_Reward/rew_action_rate: -0.0000
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 0.0186
#   Episode_Termination/bad_attitude: 0.9814
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 4194304
#                     Iteration time: 8.16s
#                       Time elapsed: 00:01:06
#                                ETA: 02:18:05
#
# ################################################################################
#                        Learning iteration 8/1001
#
#                        Computation: 64559 steps/s (collection: 7.827s, learning 0.294s)
#              Mean action noise std: 0.05
#           Mean value_function loss: 0.6395
#                Mean surrogate loss: 0.0011
#                  Mean entropy loss: -6.0695
#                        Mean reward: 7.66
#                Mean episode length: 66.40
# Episode_Reward/rew_attitude_stability2: 0.0747
# Episode_Reward/rew_ang_vel_stability4: 0.0378
#            Episode_Reward/rew_vel2: 0.0036
#            Episode_Reward/rew_pos2: 0.1784
#     Episode_Reward/rew_action_rate: -0.0000
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 0.0201
#   Episode_Termination/bad_attitude: 0.9799
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 4718592
#                     Iteration time: 8.12s
#                       Time elapsed: 00:01:14
#                                ETA: 02:17:33
#
# ################################################################################
#                        Learning iteration 9/1001
#
#                        Computation: 65141 steps/s (collection: 7.806s, learning 0.242s)
#              Mean action noise std: 0.05
#           Mean value_function loss: 0.5293
#                Mean surrogate loss: 0.0004
#                  Mean entropy loss: -6.0459
#                        Mean reward: 7.44
#                Mean episode length: 62.97
# Episode_Reward/rew_attitude_stability2: 0.0749
# Episode_Reward/rew_ang_vel_stability4: 0.0379
#            Episode_Reward/rew_vel2: 0.0036
#            Episode_Reward/rew_pos2: 0.1791
#     Episode_Reward/rew_action_rate: -0.0000
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 0.0168
#   Episode_Termination/bad_attitude: 0.9832
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 5242880
#                     Iteration time: 8.05s
#                       Time elapsed: 00:01:22
#                                ETA: 02:16:58
#
# ################################################################################
#                        Learning iteration 10/1001
#
#                        Computation: 65772 steps/s (collection: 7.729s, learning 0.242s)
#              Mean action noise std: 0.05
#           Mean value_function loss: 0.4307
#                Mean surrogate loss: 0.0003
#                  Mean entropy loss: -6.0249
#                        Mean reward: 7.09
#                Mean episode length: 58.57
# Episode_Reward/rew_attitude_stability2: 0.0762
# Episode_Reward/rew_ang_vel_stability4: 0.0387
#            Episode_Reward/rew_vel2: 0.0036
#            Episode_Reward/rew_pos2: 0.1779
#     Episode_Reward/rew_action_rate: -0.0000
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 0.0208
#   Episode_Termination/bad_attitude: 0.9792
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 5767168
#                     Iteration time: 7.97s
#                       Time elapsed: 00:01:30
#                                ETA: 02:16:22
#
# ################################################################################
#                        Learning iteration 11/1001
#
#                        Computation: 66108 steps/s (collection: 7.670s, learning 0.261s)
#              Mean action noise std: 0.05
#           Mean value_function loss: 0.3683
#                Mean surrogate loss: 0.0004
#                  Mean entropy loss: -6.0149
#                        Mean reward: 7.10
#                Mean episode length: 62.15
# Episode_Reward/rew_attitude_stability2: 0.0763
# Episode_Reward/rew_ang_vel_stability4: 0.0386
#            Episode_Reward/rew_vel2: 0.0036
#            Episode_Reward/rew_pos2: 0.1779
#     Episode_Reward/rew_action_rate: -0.0000
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 0.0205
#   Episode_Termination/bad_attitude: 0.9795
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 6291456
#                     Iteration time: 7.93s
#                       Time elapsed: 00:01:38
#                                ETA: 02:15:47
#
# ################################################################################
#                        Learning iteration 12/1001
#
#                        Computation: 65568 steps/s (collection: 7.751s, learning 0.245s)
#              Mean action noise std: 0.05
#           Mean value_function loss: 0.3004
#                Mean surrogate loss: 0.0002
#                  Mean entropy loss: -5.9964
#                        Mean reward: 7.40
#                Mean episode length: 64.58
# Episode_Reward/rew_attitude_stability2: 0.0771
# Episode_Reward/rew_ang_vel_stability4: 0.0391
#            Episode_Reward/rew_vel2: 0.0037
#            Episode_Reward/rew_pos2: 0.1794
#     Episode_Reward/rew_action_rate: -0.0000
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 0.0174
#   Episode_Termination/bad_attitude: 0.9826
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 6815744
#                     Iteration time: 8.00s
#                       Time elapsed: 00:01:46
#                                ETA: 02:15:21
#
# ################################################################################
#                        Learning iteration 13/1001
#
#                        Computation: 65622 steps/s (collection: 7.766s, learning 0.223s)
#              Mean action noise std: 0.05
#           Mean value_function loss: 0.2439
#                Mean surrogate loss: -0.0005
#                  Mean entropy loss: -5.9722
#                        Mean reward: 7.92
#                Mean episode length: 71.55
# Episode_Reward/rew_attitude_stability2: 0.0788
# Episode_Reward/rew_ang_vel_stability4: 0.0402
#            Episode_Reward/rew_vel2: 0.0037
#            Episode_Reward/rew_pos2: 0.1795
#     Episode_Reward/rew_action_rate: -0.0000
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 0.0201
#   Episode_Termination/bad_attitude: 0.9799
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 7340032
#                     Iteration time: 7.99s
#                       Time elapsed: 00:01:54
#                                ETA: 02:14:57
#
# ################################################################################
#                        Learning iteration 14/1001
#
#                        Computation: 66631 steps/s (collection: 7.572s, learning 0.297s)
#              Mean action noise std: 0.05
#           Mean value_function loss: 0.1892
#                Mean surrogate loss: -0.0004
#                  Mean entropy loss: -5.9512
#                        Mean reward: 7.74
#                Mean episode length: 67.68
# Episode_Reward/rew_attitude_stability2: 0.0791
# Episode_Reward/rew_ang_vel_stability4: 0.0405
#            Episode_Reward/rew_vel2: 0.0038
#            Episode_Reward/rew_pos2: 0.1798
#     Episode_Reward/rew_action_rate: -0.0000
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 0.0211
#   Episode_Termination/bad_attitude: 0.9789
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 7864320
#                     Iteration time: 7.87s
#                       Time elapsed: 00:02:02
#                                ETA: 02:14:27
#
# ################################################################################
#                        Learning iteration 15/1001
#
#                        Computation: 67003 steps/s (collection: 7.582s, learning 0.243s)
#              Mean action noise std: 0.05
#           Mean value_function loss: 0.1594
#                Mean surrogate loss: -0.0011
#                  Mean entropy loss: -5.9349
#                        Mean reward: 7.64
#                Mean episode length: 71.37
# Episode_Reward/rew_attitude_stability2: 0.0800
# Episode_Reward/rew_ang_vel_stability4: 0.0411
#            Episode_Reward/rew_vel2: 0.0038
#            Episode_Reward/rew_pos2: 0.1795
#     Episode_Reward/rew_action_rate: -0.0000
#       Episode_Termination/time_out: 0.0000
# Episode_Termination/below_min_altitude: 0.0233
#   Episode_Termination/bad_attitude: 0.9767
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 8388608
#                     Iteration time: 7.82s
#                       Time elapsed: 00:02:10
#                                ETA: 02:13:57
#
# ################################################################################
#                        Learning iteration 16/1001
#
#                        Computation: 68111 steps/s (collection: 7.395s, learning 0.302s)
#              Mean action noise std: 0.06
#           Mean value_function loss: 0.1325
#                Mean surrogate loss: -0.0008
#                  Mean entropy loss: -5.9105
#                        Mean reward: 7.40
#                Mean episode length: 66.37
# Episode_Reward/rew_attitude_stability2: 0.0822
# ...
#                  Mean entropy loss: 3.3583
#                        Mean reward: 245.00
#                Mean episode length: 1231.62
# Episode_Reward/rew_attitude_stability2: 1.8654
# Episode_Reward/rew_ang_vel_stability4: 0.7820
#            Episode_Reward/rew_vel2: 2.9427
#            Episode_Reward/rew_pos2: 4.3309
#     Episode_Reward/rew_action_rate: -0.0415
#       Episode_Termination/time_out: 0.9507
# Episode_Termination/below_min_altitude: 0.0458
#   Episode_Termination/bad_attitude: 0.0035
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 517996544
#                     Iteration time: 11.32s
#                       Time elapsed: 02:59:33
#                                ETA: 00:02:32
#
# ################################################################################
#                       Learning iteration 988/1001
#
#                        Computation: 46647 steps/s (collection: 10.990s, learning 0.250s)
#              Mean action noise std: 0.69
#           Mean value_function loss: 2.9218
#                Mean surrogate loss: -0.0002
#                  Mean entropy loss: 3.3645
#                        Mean reward: 240.74
#                Mean episode length: 1205.02
# Episode_Reward/rew_attitude_stability2: 1.8555
# Episode_Reward/rew_ang_vel_stability4: 0.7781
#            Episode_Reward/rew_vel2: 2.9168
#            Episode_Reward/rew_pos2: 4.3944
#     Episode_Reward/rew_action_rate: -0.0415
#       Episode_Termination/time_out: 0.9520
# Episode_Termination/below_min_altitude: 0.0445
#   Episode_Termination/bad_attitude: 0.0035
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 518520832
#                     Iteration time: 11.24s
#                       Time elapsed: 02:59:44
#                                ETA: 00:02:21
#
# ################################################################################
#                       Learning iteration 989/1001
#
#                        Computation: 46854 steps/s (collection: 10.955s, learning 0.235s)
#              Mean action noise std: 0.69
#           Mean value_function loss: 2.7980
#                Mean surrogate loss: 0.0001
#                  Mean entropy loss: 3.3765
#                        Mean reward: 231.96
#                Mean episode length: 1236.45
# Episode_Reward/rew_attitude_stability2: 1.8493
# Episode_Reward/rew_ang_vel_stability4: 0.7791
#            Episode_Reward/rew_vel2: 2.8925
#            Episode_Reward/rew_pos2: 4.1649
#     Episode_Reward/rew_action_rate: -0.0414
#       Episode_Termination/time_out: 0.9517
# Episode_Termination/below_min_altitude: 0.0446
#   Episode_Termination/bad_attitude: 0.0037
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 519045120
#                     Iteration time: 11.19s
#                       Time elapsed: 02:59:55
#                                ETA: 00:02:10
#
# ################################################################################
#                       Learning iteration 990/1001
#
#                        Computation: 46437 steps/s (collection: 11.000s, learning 0.290s)
#              Mean action noise std: 0.69
#           Mean value_function loss: 2.9354
#                Mean surrogate loss: 0.0010
#                  Mean entropy loss: 3.3777
#                        Mean reward: 245.59
#                Mean episode length: 1243.51
# Episode_Reward/rew_attitude_stability2: 1.8629
# Episode_Reward/rew_ang_vel_stability4: 0.7837
#            Episode_Reward/rew_vel2: 2.9460
#            Episode_Reward/rew_pos2: 4.3739
#     Episode_Reward/rew_action_rate: -0.0419
#       Episode_Termination/time_out: 0.9522
# Episode_Termination/below_min_altitude: 0.0441
#   Episode_Termination/bad_attitude: 0.0036
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 519569408
#                     Iteration time: 11.29s
#                       Time elapsed: 03:00:06
#                                ETA: 00:01:59
#
# ################################################################################
#                       Learning iteration 991/1001
#
#                        Computation: 46700 steps/s (collection: 10.977s, learning 0.249s)
#              Mean action noise std: 0.69
#           Mean value_function loss: 3.1211
#                Mean surrogate loss: -0.0003
#                  Mean entropy loss: 3.3788
#                        Mean reward: 257.57
#                Mean episode length: 1238.34
# Episode_Reward/rew_attitude_stability2: 1.8469
# Episode_Reward/rew_ang_vel_stability4: 0.7791
#            Episode_Reward/rew_vel2: 2.9111
#            Episode_Reward/rew_pos2: 4.4245
#     Episode_Reward/rew_action_rate: -0.0419
#       Episode_Termination/time_out: 0.9520
# Episode_Termination/below_min_altitude: 0.0443
#   Episode_Termination/bad_attitude: 0.0037
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 520093696
#                     Iteration time: 11.23s
#                       Time elapsed: 03:00:18
#                                ETA: 00:01:49
#
# ################################################################################
#                       Learning iteration 992/1001
#
#                        Computation: 46394 steps/s (collection: 11.000s, learning 0.301s)
#              Mean action noise std: 0.69
#           Mean value_function loss: 2.9324
#                Mean surrogate loss: -0.0002
#                  Mean entropy loss: 3.3824
#                        Mean reward: 252.67
#                Mean episode length: 1238.17
# Episode_Reward/rew_attitude_stability2: 1.8654
# Episode_Reward/rew_ang_vel_stability4: 0.7883
#            Episode_Reward/rew_vel2: 2.9353
#            Episode_Reward/rew_pos2: 4.5188
#     Episode_Reward/rew_action_rate: -0.0423
#       Episode_Termination/time_out: 0.9510
# Episode_Termination/below_min_altitude: 0.0455
#   Episode_Termination/bad_attitude: 0.0035
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 520617984
#                     Iteration time: 11.30s
#                       Time elapsed: 03:00:29
#                                ETA: 00:01:38
#
# ################################################################################
#                       Learning iteration 993/1001
#
#                        Computation: 46653 steps/s (collection: 10.995s, learning 0.243s)
#              Mean action noise std: 0.69
#           Mean value_function loss: 3.2837
#                Mean surrogate loss: -0.0005
#                  Mean entropy loss: 3.3911
#                        Mean reward: 246.78
#                Mean episode length: 1222.95
# Episode_Reward/rew_attitude_stability2: 1.8615
# Episode_Reward/rew_ang_vel_stability4: 0.7785
#            Episode_Reward/rew_vel2: 2.9403
#            Episode_Reward/rew_pos2: 4.4883
#     Episode_Reward/rew_action_rate: -0.0422
#       Episode_Termination/time_out: 0.9530
# Episode_Termination/below_min_altitude: 0.0439
#   Episode_Termination/bad_attitude: 0.0031
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 521142272
#                     Iteration time: 11.24s
#                       Time elapsed: 03:00:40
#                                ETA: 00:01:27
#
# ################################################################################
#                       Learning iteration 994/1001
#
#                        Computation: 46419 steps/s (collection: 10.990s, learning 0.304s)
#              Mean action noise std: 0.69
#           Mean value_function loss: 3.0655
#                Mean surrogate loss: -0.0007
#                  Mean entropy loss: 3.3994
#                        Mean reward: 254.18
#                Mean episode length: 1235.28
# Episode_Reward/rew_attitude_stability2: 1.8701
# Episode_Reward/rew_ang_vel_stability4: 0.7848
#            Episode_Reward/rew_vel2: 2.9492
#            Episode_Reward/rew_pos2: 4.4749
#     Episode_Reward/rew_action_rate: -0.0425
#       Episode_Termination/time_out: 0.9540
# Episode_Termination/below_min_altitude: 0.0431
#   Episode_Termination/bad_attitude: 0.0030
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 521666560
#                     Iteration time: 11.29s
#                       Time elapsed: 03:00:52
#                                ETA: 00:01:16
#
# ################################################################################
#                       Learning iteration 995/1001
#
#                        Computation: 46690 steps/s (collection: 10.972s, learning 0.257s)
#              Mean action noise std: 0.69
#           Mean value_function loss: 3.0400
#                Mean surrogate loss: -0.0004
#                  Mean entropy loss: 3.4023
#                        Mean reward: 252.46
#                Mean episode length: 1231.30
# Episode_Reward/rew_attitude_stability2: 1.8565
# Episode_Reward/rew_ang_vel_stability4: 0.7857
#            Episode_Reward/rew_vel2: 2.9173
#            Episode_Reward/rew_pos2: 4.5388
#     Episode_Reward/rew_action_rate: -0.0425
#       Episode_Termination/time_out: 0.9533
# Episode_Termination/below_min_altitude: 0.0436
#   Episode_Termination/bad_attitude: 0.0031
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 522190848
#                     Iteration time: 11.23s
#                       Time elapsed: 03:01:03
#                                ETA: 00:01:05
#
# ################################################################################
#                       Learning iteration 996/1001
#
#                        Computation: 46886 steps/s (collection: 10.937s, learning 0.245s)
#              Mean action noise std: 0.69
#           Mean value_function loss: 3.0952
#                Mean surrogate loss: -0.0006
#                  Mean entropy loss: 3.4090
#                        Mean reward: 260.30
#                Mean episode length: 1241.73
# Episode_Reward/rew_attitude_stability2: 1.8734
# Episode_Reward/rew_ang_vel_stability4: 0.7924
#            Episode_Reward/rew_vel2: 2.9511
#            Episode_Reward/rew_pos2: 4.5830
#     Episode_Reward/rew_action_rate: -0.0429
#       Episode_Termination/time_out: 0.9531
# Episode_Termination/below_min_altitude: 0.0436
#   Episode_Termination/bad_attitude: 0.0033
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 522715136
#                     Iteration time: 11.18s
#                       Time elapsed: 03:01:14
#                                ETA: 00:00:54
#
# ################################################################################
#                       Learning iteration 997/1001
#
#                        Computation: 46403 steps/s (collection: 10.998s, learning 0.300s)
#              Mean action noise std: 0.69
#           Mean value_function loss: 2.9876
#                Mean surrogate loss: -0.0004
#                  Mean entropy loss: 3.4149
#                        Mean reward: 241.44
#                Mean episode length: 1237.58
# Episode_Reward/rew_attitude_stability2: 1.8546
# Episode_Reward/rew_ang_vel_stability4: 0.7756
#            Episode_Reward/rew_vel2: 2.8666
#            Episode_Reward/rew_pos2: 4.1675
#     Episode_Reward/rew_action_rate: -0.0429
#       Episode_Termination/time_out: 0.9551
# Episode_Termination/below_min_altitude: 0.0420
#   Episode_Termination/bad_attitude: 0.0029
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 523239424
#                     Iteration time: 11.30s
#                       Time elapsed: 03:01:25
#                                ETA: 00:00:43
#
# ################################################################################
#                       Learning iteration 998/1001
#
#                        Computation: 46734 steps/s (collection: 10.957s, learning 0.261s)
#              Mean action noise std: 0.70
#           Mean value_function loss: 3.1546
#                Mean surrogate loss: -0.0004
#                  Mean entropy loss: 3.4235
#                        Mean reward: 244.23
#                Mean episode length: 1236.14
# Episode_Reward/rew_attitude_stability2: 1.8575
# Episode_Reward/rew_ang_vel_stability4: 0.7833
#            Episode_Reward/rew_vel2: 2.9345
#            Episode_Reward/rew_pos2: 4.3711
#     Episode_Reward/rew_action_rate: -0.0429
#       Episode_Termination/time_out: 0.9562
# Episode_Termination/below_min_altitude: 0.0412
#   Episode_Termination/bad_attitude: 0.0026
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 523763712
#                     Iteration time: 11.22s
#                       Time elapsed: 03:01:36
#                                ETA: 00:00:32
#
# ################################################################################
#                       Learning iteration 999/1001
#
#                        Computation: 46388 steps/s (collection: 10.994s, learning 0.308s)
#              Mean action noise std: 0.70
#           Mean value_function loss: 3.2264
#                Mean surrogate loss: -0.0005
#                  Mean entropy loss: 3.4346
#                        Mean reward: 253.09
#                Mean episode length: 1243.01
# Episode_Reward/rew_attitude_stability2: 1.8532
# Episode_Reward/rew_ang_vel_stability4: 0.7782
#            Episode_Reward/rew_vel2: 2.8876
#            Episode_Reward/rew_pos2: 4.3105
#     Episode_Reward/rew_action_rate: -0.0430
#       Episode_Termination/time_out: 0.9573
# Episode_Termination/below_min_altitude: 0.0408
#   Episode_Termination/bad_attitude: 0.0020
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 524288000
#                     Iteration time: 11.30s
#                       Time elapsed: 03:01:48
#                                ETA: 00:00:21
#
# ################################################################################
#                       Learning iteration 1000/1001
#
#                        Computation: 46683 steps/s (collection: 10.971s, learning 0.259s)
#              Mean action noise std: 0.70
#           Mean value_function loss: 3.1158
#                Mean surrogate loss: -0.0005
#                  Mean entropy loss: 3.4393
#                        Mean reward: 238.81
#                Mean episode length: 1230.48
# Episode_Reward/rew_attitude_stability2: 1.8508
# Episode_Reward/rew_ang_vel_stability4: 0.7853
#            Episode_Reward/rew_vel2: 2.8803
#            Episode_Reward/rew_pos2: 4.2262
#     Episode_Reward/rew_action_rate: -0.0430
#       Episode_Termination/time_out: 0.9555
# Episode_Termination/below_min_altitude: 0.0422
#   Episode_Termination/bad_attitude: 0.0023
# Episode_Termination/safety_shutdown: 0.0000
# --------------------------------------------------------------------------------
#                    Total timesteps: 524812288
#                     Iteration time: 11.23s
#                       Time elapsed: 03:01:59
#                                ETA: 00:00:10
#
# [11002.603s] Simulation App Shutting Down
#
# --- Todos los experimentos han finalizado ---

# %% [markdown]
# ``Análisis de los datos``

# %%
import csv
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

seed = 42
n=5

df_results_grid_actions = pd.read_csv(path_resultados+"/resultados_grid_PPO.csv")

# %%
def get_group(value):
    if f"_{experiment_name}" in value:
        return task_name

df_results_grid_actions["tarea"] = df_results_grid_actions["id_run_name"].apply(get_group)

# %%
df_copy = df_results_grid_actions.copy()
df_results_grid_actions.sample(n, random_state=seed)
# Out:
#                id_run_name  iteration      reward  max_reward  std_reward  \
# 5   ppo_random_command9_11        500  214.500141  328.206085   44.437367
# 0   ppo_random_command9_11          0    7.708063   19.757578    2.761157
# 9   ppo_random_command9_11        900  244.107342  405.038574   68.110495
# 10  ppo_random_command9_11       1000  238.813181  383.384216   67.808381
# 2   ppo_random_command9_11        200   82.243783  199.531754   47.128178
#
#     num_envs_train  mean_Episode_Reward/rew_attitude_stability2  \
# 5             4096                                     1.857383
# 0             4096                                     0.056850
# 9             4096                                     1.847473
# 10            4096                                     1.850815
# 2             4096                                     1.160263
#
#     mean_Episode_Reward/rew_ang_vel_stability4  mean_Episode_Reward/rew_vel2  \
# 5                                     0.829990                      2.711785
# 0                                     0.029685                      0.002740
# 9                                     0.769266                      2.818565
# 10                                    0.785324                      2.880291
# 2                                     0.583191                      0.768819
#
#     mean_Episode_Reward/rew_pos2  mean_Episode_Reward/rew_action_rate  \
# 5                       2.842500                            -0.003122
# 0                       0.165859                            -0.000006
# 9                       4.321825                            -0.029492
# 10                      4.226155                            -0.042996
# 2                       0.401976                            -0.000250
#
#     mean_Episode_Termination/time_out  \
# 5                            0.914623
# 0                            0.024328
# 9                            0.940672
# 10                           0.955523
# 2                            0.159092
#
#     mean_Episode_Termination/below_min_altitude  \
# 5                                      0.071945
# 0                                      0.002256
# 9                                      0.056879
# 10                                     0.042208
# 2                                      0.208696
#
#     mean_Episode_Termination/bad_attitude  \
# 5                                0.013432
# 0                                0.420763
# 9                                0.002449
# 10                               0.002270
# 2                                0.632212
#
#     mean_Episode_Termination/safety_shutdown     tarea
# 5                                        0.0  Command9
# 0                                        0.0  Command9
# 9                                        0.0  Command9
# 10                                       0.0  Command9
# 2                                        0.0  Command9

# %%
df_results_grid_actions.set_index(['tarea','id_run_name'],inplace=True)
top5 = (
    df_results_grid_actions.groupby(level="tarea")
      .apply(lambda g: g.sort_values("reward", ascending=False).head(5))
)

# Eliminar el nivel adicional que introduce groupby+apply
top5.index = top5.index.droplevel(0)

top5
# Out:
#                                  iteration      reward  max_reward  \
# tarea    id_run_name
# Command9 ppo_random_command9_11        800  244.396962  406.063293
#          ppo_random_command9_11        900  244.107342  405.038574
#          ppo_random_command9_11        700  238.892825  391.068420
#          ppo_random_command9_11       1000  238.813181  383.384216
#          ppo_random_command9_11        500  214.500141  328.206085
#
#                                  std_reward  num_envs_train  \
# tarea    id_run_name
# Command9 ppo_random_command9_11   72.216836            4096
#          ppo_random_command9_11   68.110495            4096
#          ppo_random_command9_11   69.082464            4096
#          ppo_random_command9_11   67.808381            4096
#          ppo_random_command9_11   44.437367            4096
#
#                                  mean_Episode_Reward/rew_attitude_stability2  \
# tarea    id_run_name
# Command9 ppo_random_command9_11                                     1.848537
#          ppo_random_command9_11                                     1.847473
#          ppo_random_command9_11                                     1.846156
#          ppo_random_command9_11                                     1.850815
#          ppo_random_command9_11                                     1.857383
#
#                                  mean_Episode_Reward/rew_ang_vel_stability4  \
# tarea    id_run_name
# Command9 ppo_random_command9_11                                    0.775194
#          ppo_random_command9_11                                    0.769266
#          ppo_random_command9_11                                    0.778826
#          ppo_random_command9_11                                    0.785324
#          ppo_random_command9_11                                    0.829990
#
#                                  mean_Episode_Reward/rew_vel2  \
# tarea    id_run_name
# Command9 ppo_random_command9_11                      2.835880
#          ppo_random_command9_11                      2.818565
#          ppo_random_command9_11                      2.814582
#          ppo_random_command9_11                      2.880291
#          ppo_random_command9_11                      2.711785
#
#                                  mean_Episode_Reward/rew_pos2  \
# tarea    id_run_name
# Command9 ppo_random_command9_11                      4.222016
#          ppo_random_command9_11                      4.321825
#          ppo_random_command9_11                      3.848910
#          ppo_random_command9_11                      4.226155
#          ppo_random_command9_11                      2.842500
#
#                                  mean_Episode_Reward/rew_action_rate  \
# tarea    id_run_name
# Command9 ppo_random_command9_11                            -0.019827
#          ppo_random_command9_11                            -0.029492
#          ppo_random_command9_11                            -0.011770
#          ppo_random_command9_11                            -0.042996
#          ppo_random_command9_11                            -0.003122
#
#                                  mean_Episode_Termination/time_out  \
# tarea    id_run_name
# Command9 ppo_random_command9_11                           0.942017
#          ppo_random_command9_11                           0.940672
#          ppo_random_command9_11                           0.942364
#          ppo_random_command9_11                           0.955523
#          ppo_random_command9_11                           0.914623
#
#                                  mean_Episode_Termination/below_min_altitude  \
# tarea    id_run_name
# Command9 ppo_random_command9_11                                     0.053905
#          ppo_random_command9_11                                     0.056879
#          ppo_random_command9_11                                     0.053818
#          ppo_random_command9_11                                     0.042208
#          ppo_random_command9_11                                     0.071945
#
#                                  mean_Episode_Termination/bad_attitude  \
# tarea    id_run_name
# Command9 ppo_random_command9_11                               0.004078
#          ppo_random_command9_11                               0.002449
#          ppo_random_command9_11                               0.003819
#          ppo_random_command9_11                               0.002270
#          ppo_random_command9_11                               0.013432
#
#                                  mean_Episode_Termination/safety_shutdown
# tarea    id_run_name
# Command9 ppo_random_command9_11                                       0.0
#          ppo_random_command9_11                                       0.0
#          ppo_random_command9_11                                       0.0
#          ppo_random_command9_11                                       0.0
#          ppo_random_command9_11                                       0.0

# %%
mean_rewards = df_results_grid_actions.groupby(["tarea", "id_run_name"])["reward"].mean()

for tarea, subdf in mean_rewards.groupby(level="tarea"):
    plt.figure(figsize=(12,5))
    
    # Convertir a DataFrame y resetear index para graficar
    plot_df = subdf.reset_index()
    plot_df = plot_df.sort_values("reward", ascending=False)
    
    plt.bar(plot_df["id_run_name"], plot_df["reward"])
    plt.title(f"Reward media por modelo - {tarea}")
    plt.xlabel("id_run_name")
    plt.ylabel("Reward media")
    plt.xticks(rotation=90)
    plt.tight_layout()
    plt.show()

# %%
df_callbacks = pd.read_csv(path_resultados+"/reward_best_models.csv",index_col='id_run_name')
top5_models = df_callbacks.nlargest(5,columns="reward")
top5_models
# Out:
#                         iteration      reward  max_reward  std_reward  \
# id_run_name
# ppo_random_command9_11        917  261.502937  429.041992   69.079971
#
#                         num_envs_train  \
# id_run_name
# ppo_random_command9_11            4096
#
#                         mean_Episode_Reward/rew_attitude_stability2  \
# id_run_name
# ppo_random_command9_11                                     1.848173
#
#                         mean_Episode_Reward/rew_ang_vel_stability4  \
# id_run_name
# ppo_random_command9_11                                    0.775183
#
#                         mean_Episode_Reward/rew_vel2  \
# id_run_name
# ppo_random_command9_11                      2.874317
#
#                         mean_Episode_Reward/rew_pos2  \
# id_run_name
# ppo_random_command9_11                      4.206263
#
#                         mean_Episode_Reward/rew_action_rate  \
# id_run_name
# ppo_random_command9_11                            -0.031396
#
#                         mean_Episode_Termination/time_out  \
# id_run_name
# ppo_random_command9_11                           0.950165
#
#                         mean_Episode_Termination/below_min_altitude  \
# id_run_name
# ppo_random_command9_11                                     0.047409
#
#                         mean_Episode_Termination/bad_attitude  \
# id_run_name
# ppo_random_command9_11                               0.002426
#
#                         mean_Episode_Termination/safety_shutdown
# id_run_name
# ppo_random_command9_11                                       0.0

# %% [markdown]
# Graficamos cómo fue el entrenamiento para los 5 mejores modelos según los callbacks:

# %%
import matplotlib.pyplot as plt
import numpy as np

# Aseguramos que `top5_auc` tenga 'tarea' e 'id_run_name' como columnas, no solo en el índice
df_callbacks = pd.read_csv(path_resultados+"/reward_best_models.csv",index_col='id_run_name')
top5_models = df_callbacks.nlargest(5,columns="reward")
top5_reset = top5_models.reset_index()
top5_reset["tarea"] = top5_reset["id_run_name"].apply(get_group)


# Convertir el índice jerárquico en columnas (para acceder a 'tarea' y 'id_run_name')
df_copy_reset = df_copy.reset_index()

# Unimos `top5_auc_reset` con `df_copy_reset` en las columnas comunes: 'tarea' y 'id_run_name'
merged_df = pd.merge(df_copy_reset, top5_reset[['tarea', 'id_run_name']], on=['tarea', 'id_run_name'], how='inner')

# Usamos una lista de colores para asignar un color diferente a cada modelo
colors = plt.cm.viridis(np.linspace(0, 1, len(merged_df['id_run_name'].unique())))

# Ahora, procedemos a graficar
for tarea, task_df in merged_df.groupby('tarea'):
    plt.figure(figsize=(10, 6))
    
    # Iteramos sobre los modelos (id_run_name) para esta tarea
    for i, (run_name, subdf) in enumerate(task_df.groupby('id_run_name')):
        # Graficamos la evolución de la recompensa a lo largo de las iteraciones
        plt.plot(subdf['iteration'], subdf['reward'], label=run_name, color=colors[i])
    
    plt.xlabel('Iteración')
    plt.ylabel('Reward')
    plt.title(f'Evolución de la Recompensa - Tarea: {tarea}')
    plt.legend(title="Modelos", bbox_to_anchor=(1.05, 1), loc='upper left')
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ``Cojo los 5 modelos mejores de todos de los callbacks``

# %%
import os
df_callbacks = pd.read_csv(path_resultados+"/reward_best_models.csv",index_col='id_run_name')
top5_models = df_callbacks.nlargest(5,columns="reward")

powershell_script_test = os.path.join(cfg_dir, "run_tests.ps1")

with open(powershell_script_test, "w") as f:
    f.write("$ErrorActionPreference = 'Stop'\n\n")
    
    for run_id, row in top5_models.iterrows():
        # Extraemos el número del id (ej: de 'ppo_random_hover_4' sacamos '4')
        experiment_number = run_id.split('_')[-1]
        
        # Construimos la ruta exacta del checkpoint
        # Nota: Asegúrate de que path_resultados termine en / o usar os.path.join
        checkpoint_path = f"{path_resultados}/best_model_{run_id}_{int(row['num_envs_train'])}.pt"
        f.write(f'Write-Host "Ejecutando Test final para Experimento {experiment_number}..."\n')
        
        # Usamos el experiment_number extraído para la tarea (--task)
        # Se añaden flags típicos de play.py: --num_envs 1 y se quita --headless para ver el visualizador
        f.write(f'& "{isaaclab_bat}" -p "{play_script}" '
                f'--task {id_task}-{experiment_number} '
                f'--num_envs 1 '
                f' --headless '
                f'--checkpoint "{checkpoint_path}"\n\n')
        
print(f"Script de test generado en: {powershell_script_test}")
# Out:
# Script de test generado en: C:/Users/Teresa/Documents/GitHub/navsim/isaac_lab/aerotaxi/env_command/env_13/grid_hiperparametros/cfg_files\run_tests.ps1

# %% [markdown]
# ### Test con 1 entorno

# %%
# Ejecuta el entrenamiento de forma automática
# !powershell -ExecutionPolicy Bypass -File "{powershell_script}"
import subprocess
import sys

# Ruta al script que generaste
powershell_script_path = powershell_script_test 

print(f"Iniciando ejecución de: {powershell_script_path}\n")

# Ejecutamos el proceso capturando la salida en tiempo real
process = subprocess.Popen(
    ["powershell.exe", "-ExecutionPolicy", "Bypass", "-File", powershell_script_path],
    stdout=subprocess.PIPE,
    stderr=subprocess.STDOUT, # Redirigimos errores a la salida estándar para verlos
    text=True,
    bufsize=1
)

# Leemos la salida línea a línea conforme se genera
try:
    for line in process.stdout:
        print(line, end="") # Imprime la salida de PowerShell en la celda
        sys.stdout.flush()   # Fuerza a Jupyter a mostrar la línea inmediatamente
except KeyboardInterrupt:
    process.kill()
    print("\nEntrenamiento cancelado por el usuario.")

process.wait()
print("\n--- Todos los experimentos de test han finalizado ---")
# Out:
# Iniciando ejecución de: C:/Users/Teresa/Documents/GitHub/navsim/isaac_lab/aerotaxi/env_command/env_13/grid_hiperparametros/cfg_files\run_tests.ps1
#
# Ejecutando Test final para Experimento 11...
# [INFO] Using python from: C:\Users\Teresa\miniconda3\envs\env_isaaclab\python.exe
# [INFO][AppLauncher]: Using device: cuda:0
# [INFO][AppLauncher]: Loading experience file: C:\Users\Teresa\miniconda3\envs\env_isaaclab\Lib\site-packages\isaaclab\apps\isaaclab.python.headless.kit
# Loading user config located at: 'c:/users/teresa/miniconda3/envs/env_isaaclab/lib/site-packages/isaacsim/kit/data/Kit/Isaac-Sim/5.1/user.config.json'
# [Info] [carb] Logging to file: c:/users/teresa/miniconda3/envs/env_isaaclab/lib/site-packages/isaacsim/kit/logs/Kit/Isaac-Sim/5.1/kit_20260304_132316.log
# 2026-03-04T12:23:17Z s] [Warning] [omni.usd_config.extension] Enable omni.materialx.libs extension to use MaterialX
# 2026-03-04T12:23:17Z s] [Warning] [carb] Acquiring non optional plugin interface which is not listed as dependency: [omni::physx::IPhysxBenchmarks v1.0] (plugin: <default plugin>), by client: omni.physics.physx.plugin. Add it to CARB_PLUGIN_IMPL_DEPS() macro of a client.
# 2026-03-04T12:23:17Z s] [Warning] [omni.isaac.dynamic_control] omni.isaac.dynamic_control is deprecated as of Isaac Sim 4.5. No action is needed from end-users.
# 2026-03-04T12:23:19Z [2,705ms] [Warning] [gpu.foundation.plugin] Skipping unsupported non-NVIDIA GPU: AMD Radeon(TM) Graphics
# 2026-03-04T12:23:19Z [2,706ms] [Warning] [gpu.foundation.plugin] Skipping unsupported non-NVIDIA GPU: AMD Radeon(TM) Graphics
#
# |---------------------------------------------------------------------------------------------|
# | Driver Version: 581.29        | Graphics API: D3D12
# |=============================================================================================|
# | GPU | Name                             | Active | LDA | GPU Memory | Vendor-ID | LUID       |
# |     |                                  |        |     |            | Device-ID | UUID       |
# |     |                                  |        |     |            | Bus-ID    |            |
# |---------------------------------------------------------------------------------------------|
# | 0   | NVIDIA GeForce RTX 5080          | Yes: 0 |     | 15889   MB | 10de      | 295a0100.. |
# |     |                                  |        |     |            | 2c02      | 0          |
# |     |                                  |        |     |            | 1         |            |
# |---------------------------------------------------------------------------------------------|
# | 1   | AMD Radeon(TM) Graphics          |        |     | 1995    MB | 1002      | 876d0100.. |
# |     |                                  |        |     |            | 13c0      | 0          |
# |     |                                  |        |     |            | N/A       |            |
# |=============================================================================================|
# | OS: Windows 11 Pro, Version: 10.0 (25H2), Build: 26200, Kernel: 10.0.26100.7824
# | Processor: AMD Ryzen 9 9950X 16-Core Processor
# | Cores: 16 | Logical Cores: 32
# |---------------------------------------------------------------------------------------------|
# | Total Memory (MB): 128627 | Free Memory: 103289
# | Total Page/Swap (MB): 136819 | Free Page/Swap: 105147
# |---------------------------------------------------------------------------------------------|
# C:\Users\Teresa\Documents\GitHub\navsim\isaac_lab\aerotaxi\env_command\env_13\flight_plan.py:29: UserWarning: Treat the new Tool classes introduced in v1.5 as experimental for now; the API and rcParam may change in future versions.
#   plt.rcParams["toolbar"] = "toolmanager"
# [INFO]: Parsing configuration from: aerotaxi.env_command.env_13.env:UAVEnvCfg
# [INFO]: Parsing configuration from: aerotaxi.env_command.env_13.grid_hiperparametros.cfg_files.ppo_random_command9_11_cfg:Command9PPORunnerCfg
# [INFO] Loading experiment from directory: C:\Users\Teresa\Documents\GitHub\navsim\isaac_lab\aerotaxi\env_command\env_13\logs\rsl_rl\command9
# Setting seed: 42
# [INFO]: Base environment:
# 	Environment device    : cuda:0
# 	Environment seed      : 42
# 	Physics step-size     : 0.005
# 	Rendering step-size   : 0.02
# 	Environment step-size : 0.02
# [INFO]: Time taken for scene creation : 1.009226 seconds
# [INFO]: Scene manager:  <class InteractiveScene>
# 	Number of environments: 1
# 	Environment spacing   : 200.0
# 	Source prim name      : /World/envs/env_0
# 	Global prim paths     : []
# 	Replicate physics     : False
# [INFO]: Starting the simulation. This may take a few seconds. Please wait...
# [INFO]: Time taken for simulation start : 0.281060 seconds
# [INFO] Command Manager:  <CommandManager> contains 1 active terms.
# +--------------------------------------+
# |         Active Command Terms         |
# +-------+-------------+----------------+
# | Index | Name        |      Type      |
# +-------+-------------+----------------+
# |   0   | vel_command | UAVcommandTerm |
# +-------+-------------+----------------+
#
# [INFO] Event Manager:  <EventManager> contains 1 active terms.
# +-----------------------------------+
# | Active Event Terms in Mode: 'reset' |
# +----------+------------------------+
# |  Index   | Name                   |
# +----------+------------------------+
# |    0     | reset_pos              |
# |    1     | randomize_mass         |
# |    2     | randomize_wind         |
# +----------+------------------------+
#
# [INFO] Recorder Manager:  <RecorderManager> contains 0 active terms.
# +---------------------+
# | Active Recorder Terms |
# +-----------+---------+
# |   Index   | Name    |
# +-----------+---------+
# +-----------+---------+
#
# [INFO] Action Manager:  <ActionManager> contains 1 active terms.
# +-----------------------------------+
# |   Active Action Terms (shape: 4)  |
# +--------+-------------+------------+
# | Index  | Name        |  Dimension |
# +--------+-------------+------------+
# |   0    | rotors_vel  |          4 |
# +--------+-------------+------------+
#
# [INFO] Observation Manager: <ObservationManager> contains 2 groups.
# +---------------------------------------------------------+
# | Active Observation Terms in Group: 'policy' (shape: (45,)) |
# +-----------+---------------------------------+-----------+
# |   Index   | Name                            |   Shape   |
# +-----------+---------------------------------+-----------+
# |     0     | dist                            |    (9,)   |
# |     1     | lin_vel                         |    (9,)   |
# |     2     | ang_vel                         |    (9,)   |
# |     3     | projected_gravity               |    (9,)   |
# |     4     | target_vel                      |    (9,)   |
# +-----------+---------------------------------+-----------+
# +---------------------------------------------------------+
# | Active Observation Terms in Group: 'critic' (shape: (45,)) |
# +-----------+---------------------------------+-----------+
# |   Index   | Name                            |   Shape   |
# +-----------+---------------------------------+-----------+
# |     0     | dist                            |    (9,)   |
# |     1     | lin_vel                         |    (9,)   |
# |     2     | ang_vel                         |    (9,)   |
# |     3     | projected_gravity               |    (9,)   |
# |     4     | target_vel                      |    (9,)   |
# +-----------+---------------------------------+-----------+
#
# [INFO] Termination Manager:  <TerminationManager> contains 4 active terms.
# +---------------------------------------+
# |        Active Termination Terms       |
# +-------+--------------------+----------+
# | Index | Name               | Time Out |
# +-------+--------------------+----------+
# |   0   | time_out           |   True   |
# |   1   | below_min_altitude |  False   |
# |   2   | bad_attitude       |  False   |
# |   3   | safety_shutdown    |  False   |
# +-------+--------------------+----------+
#
# [INFO] Reward Manager:  <RewardManager> contains 5 active terms.
# +------------------------------------------+
# |           Active Reward Terms            |
# +-------+-------------------------+--------+
# | Index | Name                    | Weight |
# +-------+-------------------------+--------+
# |   0   | rew_attitude_stability2 |    2.0 |
# |   1   | rew_ang_vel_stability4  |    1.0 |
# |   2   | rew_vel2                |    4.0 |
# |   3   | rew_pos2                |   12.0 |
# |   4   | rew_action_rate         |    0.8 |
# +-------+-------------------------+--------+
#
# [INFO] Curriculum Manager:  <CurriculumManager> contains 0 active terms.
# +----------------------+
# | Active Curriculum Terms |
# +-----------+----------+
# |   Index   | Name     |
# +-----------+----------+
# +-----------+----------+
#
# [INFO]: Completed setting up the environment...
# 2026-03-04T12:23:23Z [6,053ms] [Warning] [omni.physx.fabric.plugin] FabricManager::initializePointInstancer mismatched prototypes on point instancer: /Visuals/target_commands.
# [INFO]: Loading model checkpoint from: C:\Users\Teresa\Documents\GitHub\navsim\tmp\tmpTeresa\resultados_grid_command_v9\best_model_ppo_random_command9_11_4096.pt
# C:\Users\Teresa\miniconda3\envs\env_isaaclab\Lib\site-packages\rsl_rl\utils\utils.py:244: UserWarning: The observation configuration dictionary 'obs_groups' must contain the 'policy' key. As an observation group with the name 'policy' was found, this is assumed to be the observation set. Consider adding the 'policy' key to the 'obs_groups' dictionary for clarity. This behavior will be removed in a future version.
#   warnings.warn(
# C:\Users\Teresa\miniconda3\envs\env_isaaclab\Lib\site-packages\rsl_rl\utils\utils.py:282: UserWarning: The observation configuration dictionary 'obs_groups' must contain the 'critic' key. As an observation group with the name 'critic' was found, this is assumed to be the observation set. Consider adding the 'critic' key to the 'obs_groups' dictionary for clarity. This behavior will be removed in a future version.
#   warnings.warn(
# --------------------------------------------------------------------------------
# Resolved observation sets:
# 	 policy :  ['policy']
# 	 critic :  ['critic']
# --------------------------------------------------------------------------------
# Actor MLP: MLP(
#   (0): Linear(in_features=45, out_features=128, bias=True)
#   (1): ELU(alpha=1.0)
#   (2): Linear(in_features=128, out_features=128, bias=True)
#   (3): ELU(alpha=1.0)
#   (4): Linear(in_features=128, out_features=128, bias=True)
#   (5): ELU(alpha=1.0)
#   (6): Linear(in_features=128, out_features=4, bias=True)
# )
# Critic MLP: MLP(
#   (0): Linear(in_features=45, out_features=256, bias=True)
#   (1): ELU(alpha=1.0)
#   (2): Linear(in_features=256, out_features=256, bias=True)
#   (3): ELU(alpha=1.0)
#   (4): Linear(in_features=256, out_features=256, bias=True)
#   (5): ELU(alpha=1.0)
#   (6): Linear(in_features=256, out_features=1, bias=True)
# )
#
# --- Todos los experimentos de test han finalizado ---

# %%
df_callbacks = pd.read_csv(path_resultados+"/reward_best_models.csv",index_col='id_run_name')
top5_models = df_callbacks.nlargest(5,columns="reward")

# %%
df_rewards_play = pd.read_csv(path_resultados+'/rewards_play_PPO.csv')

# %%
df_rewards_play
# Out:
#               id_run_name    reward  max_reward  std  num_envs_test  \
# 0  ppo_random_command9_11  124.9072    124.9072  0.0              1
#
#                                           checkpoint  \
# 0  C:/Users/Teresa/Documents/GitHub/navsim/tmp/tm...
#
#    mean_Episode_Reward/rew_attitude_stability2  \
# 0                                          0.0
#
#    mean_Episode_Reward/rew_ang_vel_stability4  mean_Episode_Reward/rew_vel2  \
# 0                                         0.0                           0.0
#
#    mean_Episode_Reward/rew_pos2  mean_Episode_Reward/rew_action_rate  \
# 0                           0.0                                  0.0
#
#    mean_Episode_Termination/time_out  \
# 0                                0.0
#
#    mean_Episode_Termination/below_min_altitude  \
# 0                                          0.0
#
#    mean_Episode_Termination/bad_attitude  \
# 0                                    0.0
#
#    mean_Episode_Termination/safety_shutdown
# 0                                       0.0

# %% [markdown]
# ### Test con 64 entornos

# %%
import os
df_callbacks = pd.read_csv(path_resultados+"/reward_best_models.csv",index_col='id_run_name')
top5_models = df_callbacks.nlargest(5,columns="reward")

powershell_script_test_2 = os.path.join(cfg_dir, "run_tests_2.ps1")

with open(powershell_script_test_2, "w") as f:
    f.write("$ErrorActionPreference = 'Stop'\n\n")
    
    for run_id, row in top5_models.iterrows():
        # Extraemos el número del id (ej: de 'ppo_random_hover_4' sacamos '4')
        experiment_number = run_id.split('_')[-1]
        
        # Construimos la ruta exacta del checkpoint
        # Nota: Asegúrate de que path_resultados termine en / o usar os.path.join
        checkpoint_path = f"{path_resultados}/best_model_{run_id}_{int(row['num_envs_train'])}.pt"
        f.write(f'Write-Host "Ejecutando Test final para Experimento {experiment_number}..."\n')
        
        # Usamos el experiment_number extraído para la tarea (--task)
        # Se añaden flags típicos de play.py: --num_envs 1 y se quita --headless para ver el visualizador
        f.write(f'& "{isaaclab_bat}" -p "{play_script}" '
                f'--task {id_task}-{experiment_number} '
                f'--num_envs 64 '
                f' --headless '
                f'--checkpoint "{checkpoint_path}"\n\n')
        
print(f"Script de test generado en: {powershell_script_test_2}")
# Out:
# Script de test generado en: C:/Users/Teresa/Documents/GitHub/navsim/isaac_lab/aerotaxi/env_command/env_13/grid_hiperparametros/cfg_files\run_tests_2.ps1

# %%
# Ejecuta el entrenamiento de forma automática
# !powershell -ExecutionPolicy Bypass -File "{powershell_script}"
import subprocess
import sys

# Ruta al script que generaste
powershell_script_path = powershell_script_test_2 

print(f"Iniciando ejecución de: {powershell_script_path}\n")

# Ejecutamos el proceso capturando la salida en tiempo real
process = subprocess.Popen(
    ["powershell.exe", "-ExecutionPolicy", "Bypass", "-File", powershell_script_path],
    stdout=subprocess.PIPE,
    stderr=subprocess.STDOUT, # Redirigimos errores a la salida estándar para verlos
    text=True,
    bufsize=1
)

# Leemos la salida línea a línea conforme se genera
try:
    for line in process.stdout:
        print(line, end="") # Imprime la salida de PowerShell en la celda
        sys.stdout.flush()   # Fuerza a Jupyter a mostrar la línea inmediatamente
except KeyboardInterrupt:
    process.kill()
    print("\nEntrenamiento cancelado por el usuario.")

process.wait()
print("\n--- Todos los experimentos de test han finalizado ---")
# Out:
# Iniciando ejecución de: C:/Users/Teresa/Documents/GitHub/navsim/isaac_lab/aerotaxi/env_command/env_13/grid_hiperparametros/cfg_files\run_tests_2.ps1
#
# Ejecutando Test final para Experimento 11...
# [INFO] Using python from: C:\Users\Teresa\miniconda3\envs\env_isaaclab\python.exe
# [INFO][AppLauncher]: Using device: cuda:0
# [INFO][AppLauncher]: Loading experience file: C:\Users\Teresa\miniconda3\envs\env_isaaclab\Lib\site-packages\isaaclab\apps\isaaclab.python.headless.kit
# Loading user config located at: 'c:/users/teresa/miniconda3/envs/env_isaaclab/lib/site-packages/isaacsim/kit/data/Kit/Isaac-Sim/5.1/user.config.json'
# [Info] [carb] Logging to file: c:/users/teresa/miniconda3/envs/env_isaaclab/lib/site-packages/isaacsim/kit/logs/Kit/Isaac-Sim/5.1/kit_20260304_132407.log
# 2026-03-04T12:24:07Z s] [Warning] [omni.usd_config.extension] Enable omni.materialx.libs extension to use MaterialX
# 2026-03-04T12:24:08Z s] [Warning] [carb] Acquiring non optional plugin interface which is not listed as dependency: [omni::physx::IPhysxBenchmarks v1.0] (plugin: <default plugin>), by client: omni.physics.physx.plugin. Add it to CARB_PLUGIN_IMPL_DEPS() macro of a client.
# 2026-03-04T12:24:08Z s] [Warning] [omni.isaac.dynamic_control] omni.isaac.dynamic_control is deprecated as of Isaac Sim 4.5. No action is needed from end-users.
# 2026-03-04T12:24:10Z [2,402ms] [Warning] [gpu.foundation.plugin] Skipping unsupported non-NVIDIA GPU: AMD Radeon(TM) Graphics
# 2026-03-04T12:24:10Z [2,403ms] [Warning] [gpu.foundation.plugin] Skipping unsupported non-NVIDIA GPU: AMD Radeon(TM) Graphics
#
# |---------------------------------------------------------------------------------------------|
# | Driver Version: 581.29        | Graphics API: D3D12
# |=============================================================================================|
# | GPU | Name                             | Active | LDA | GPU Memory | Vendor-ID | LUID       |
# |     |                                  |        |     |            | Device-ID | UUID       |
# |     |                                  |        |     |            | Bus-ID    |            |
# |---------------------------------------------------------------------------------------------|
# | 0   | NVIDIA GeForce RTX 5080          | Yes: 0 |     | 15889   MB | 10de      | 295a0100.. |
# |     |                                  |        |     |            | 2c02      | 0          |
# |     |                                  |        |     |            | 1         |            |
# |---------------------------------------------------------------------------------------------|
# | 1   | AMD Radeon(TM) Graphics          |        |     | 1995    MB | 1002      | 876d0100.. |
# |     |                                  |        |     |            | 13c0      | 0          |
# |     |                                  |        |     |            | N/A       |            |
# |=============================================================================================|
# | OS: Windows 11 Pro, Version: 10.0 (25H2), Build: 26200, Kernel: 10.0.26100.7824
# | Processor: AMD Ryzen 9 9950X 16-Core Processor
# | Cores: 16 | Logical Cores: 32
# |---------------------------------------------------------------------------------------------|
# | Total Memory (MB): 128627 | Free Memory: 102685
# | Total Page/Swap (MB): 136819 | Free Page/Swap: 104392
# |---------------------------------------------------------------------------------------------|
# C:\Users\Teresa\Documents\GitHub\navsim\isaac_lab\aerotaxi\env_command\env_13\flight_plan.py:29: UserWarning: Treat the new Tool classes introduced in v1.5 as experimental for now; the API and rcParam may change in future versions.
#   plt.rcParams["toolbar"] = "toolmanager"
# [INFO]: Parsing configuration from: aerotaxi.env_command.env_13.env:UAVEnvCfg
# [INFO]: Parsing configuration from: aerotaxi.env_command.env_13.grid_hiperparametros.cfg_files.ppo_random_command9_11_cfg:Command9PPORunnerCfg
# [INFO] Loading experiment from directory: C:\Users\Teresa\Documents\GitHub\navsim\isaac_lab\aerotaxi\env_command\env_13\logs\rsl_rl\command9
# Setting seed: 42
# [INFO]: Base environment:
# 	Environment device    : cuda:0
# 	Environment seed      : 42
# 	Physics step-size     : 0.005
# 	Rendering step-size   : 0.02
# 	Environment step-size : 0.02
# [INFO]: Time taken for scene creation : 0.987673 seconds
# [INFO]: Scene manager:  <class InteractiveScene>
# 	Number of environments: 64
# 	Environment spacing   : 200.0
# 	Source prim name      : /World/envs/env_0
# 	Global prim paths     : []
# 	Replicate physics     : False
# [INFO]: Starting the simulation. This may take a few seconds. Please wait...
# [INFO]: Time taken for simulation start : 0.274023 seconds
# [INFO] Command Manager:  <CommandManager> contains 1 active terms.
# +--------------------------------------+
# |         Active Command Terms         |
# +-------+-------------+----------------+
# | Index | Name        |      Type      |
# +-------+-------------+----------------+
# |   0   | vel_command | UAVcommandTerm |
# +-------+-------------+----------------+
#
# [INFO] Event Manager:  <EventManager> contains 1 active terms.
# +-----------------------------------+
# | Active Event Terms in Mode: 'reset' |
# +----------+------------------------+
# |  Index   | Name                   |
# +----------+------------------------+
# |    0     | reset_pos              |
# |    1     | randomize_mass         |
# |    2     | randomize_wind         |
# +----------+------------------------+
#
# [INFO] Recorder Manager:  <RecorderManager> contains 0 active terms.
# +---------------------+
# | Active Recorder Terms |
# +-----------+---------+
# |   Index   | Name    |
# +-----------+---------+
# +-----------+---------+
#
# [INFO] Action Manager:  <ActionManager> contains 1 active terms.
# +-----------------------------------+
# |   Active Action Terms (shape: 4)  |
# +--------+-------------+------------+
# | Index  | Name        |  Dimension |
# +--------+-------------+------------+
# |   0    | rotors_vel  |          4 |
# +--------+-------------+------------+
#
# [INFO] Observation Manager: <ObservationManager> contains 2 groups.
# +---------------------------------------------------------+
# | Active Observation Terms in Group: 'policy' (shape: (45,)) |
# +-----------+---------------------------------+-----------+
# |   Index   | Name                            |   Shape   |
# +-----------+---------------------------------+-----------+
# |     0     | dist                            |    (9,)   |
# |     1     | lin_vel                         |    (9,)   |
# |     2     | ang_vel                         |    (9,)   |
# |     3     | projected_gravity               |    (9,)   |
# |     4     | target_vel                      |    (9,)   |
# +-----------+---------------------------------+-----------+
# +---------------------------------------------------------+
# | Active Observation Terms in Group: 'critic' (shape: (45,)) |
# +-----------+---------------------------------+-----------+
# |   Index   | Name                            |   Shape   |
# +-----------+---------------------------------+-----------+
# |     0     | dist                            |    (9,)   |
# |     1     | lin_vel                         |    (9,)   |
# |     2     | ang_vel                         |    (9,)   |
# |     3     | projected_gravity               |    (9,)   |
# |     4     | target_vel                      |    (9,)   |
# +-----------+---------------------------------+-----------+
#
# [INFO] Termination Manager:  <TerminationManager> contains 4 active terms.
# +---------------------------------------+
# |        Active Termination Terms       |
# +-------+--------------------+----------+
# | Index | Name               | Time Out |
# +-------+--------------------+----------+
# |   0   | time_out           |   True   |
# |   1   | below_min_altitude |  False   |
# |   2   | bad_attitude       |  False   |
# |   3   | safety_shutdown    |  False   |
# +-------+--------------------+----------+
#
# [INFO] Reward Manager:  <RewardManager> contains 5 active terms.
# +------------------------------------------+
# |           Active Reward Terms            |
# +-------+-------------------------+--------+
# | Index | Name                    | Weight |
# +-------+-------------------------+--------+
# |   0   | rew_attitude_stability2 |    2.0 |
# |   1   | rew_ang_vel_stability4  |    1.0 |
# |   2   | rew_vel2                |    4.0 |
# |   3   | rew_pos2                |   12.0 |
# |   4   | rew_action_rate         |    0.8 |
# +-------+-------------------------+--------+
#
# [INFO] Curriculum Manager:  <CurriculumManager> contains 0 active terms.
# +----------------------+
# | Active Curriculum Terms |
# +-----------+----------+
# |   Index   | Name     |
# +-----------+----------+
# +-----------+----------+
#
# [INFO]: Completed setting up the environment...
# 2026-03-04T12:24:13Z [5,475ms] [Warning] [omni.physx.fabric.plugin] FabricManager::initializePointInstancer mismatched prototypes on point instancer: /Visuals/target_commands.
# [INFO]: Loading model checkpoint from: C:\Users\Teresa\Documents\GitHub\navsim\tmp\tmpTeresa\resultados_grid_command_v9\best_model_ppo_random_command9_11_4096.pt
# C:\Users\Teresa\miniconda3\envs\env_isaaclab\Lib\site-packages\rsl_rl\utils\utils.py:244: UserWarning: The observation configuration dictionary 'obs_groups' must contain the 'policy' key. As an observation group with the name 'policy' was found, this is assumed to be the observation set. Consider adding the 'policy' key to the 'obs_groups' dictionary for clarity. This behavior will be removed in a future version.
#   warnings.warn(
# C:\Users\Teresa\miniconda3\envs\env_isaaclab\Lib\site-packages\rsl_rl\utils\utils.py:282: UserWarning: The observation configuration dictionary 'obs_groups' must contain the 'critic' key. As an observation group with the name 'critic' was found, this is assumed to be the observation set. Consider adding the 'critic' key to the 'obs_groups' dictionary for clarity. This behavior will be removed in a future version.
#   warnings.warn(
# --------------------------------------------------------------------------------
# Resolved observation sets:
# 	 policy :  ['policy']
# 	 critic :  ['critic']
# --------------------------------------------------------------------------------
# Actor MLP: MLP(
#   (0): Linear(in_features=45, out_features=128, bias=True)
#   (1): ELU(alpha=1.0)
#   (2): Linear(in_features=128, out_features=128, bias=True)
#   (3): ELU(alpha=1.0)
#   (4): Linear(in_features=128, out_features=128, bias=True)
#   (5): ELU(alpha=1.0)
#   (6): Linear(in_features=128, out_features=4, bias=True)
# )
# Critic MLP: MLP(
#   (0): Linear(in_features=45, out_features=256, bias=True)
#   (1): ELU(alpha=1.0)
#   (2): Linear(in_features=256, out_features=256, bias=True)
#   (3): ELU(alpha=1.0)
#   (4): Linear(in_features=256, out_features=256, bias=True)
#   (5): ELU(alpha=1.0)
#   (6): Linear(in_features=256, out_features=1, bias=True)
# )
#
# --- Todos los experimentos de test han finalizado ---

# %% [markdown]
# #### Test con 256 entornos

# %%
import os
df_callbacks = pd.read_csv(path_resultados+"/reward_best_models.csv",index_col='id_run_name')
top5_models = df_callbacks.nlargest(5,columns="reward")

powershell_script_test_3 = os.path.join(cfg_dir, "run_tests_3.ps1")

with open(powershell_script_test_3, "w") as f:
    f.write("$ErrorActionPreference = 'Stop'\n\n")
    
    for run_id, row in top5_models.iterrows():
        # Extraemos el número del id (ej: de 'ppo_random_hover_4' sacamos '4')
        experiment_number = run_id.split('_')[-1]
        
        # Construimos la ruta exacta del checkpoint
        # Nota: Asegúrate de que path_resultados termine en / o usar os.path.join
        checkpoint_path = f"{path_resultados}/best_model_{run_id}_{int(row['num_envs_train'])}.pt"
        f.write(f'Write-Host "Ejecutando Test final para Experimento {experiment_number}..."\n')
        
        # Usamos el experiment_number extraído para la tarea (--task)
        # Se añaden flags típicos de play.py: --num_envs 1 y se quita --headless para ver el visualizador
        f.write(f'& "{isaaclab_bat}" -p "{play_script}" '
                f'--task {id_task}-{experiment_number} '
                f'--num_envs 256 '
                f' --headless '
                f'--checkpoint "{checkpoint_path}"\n\n')
        
print(f"Script de test generado en: {powershell_script_test_3}")
# Out:
# Script de test generado en: C:/Users/Teresa/Documents/GitHub/navsim/isaac_lab/aerotaxi/env_command/env_13/grid_hiperparametros/cfg_files\run_tests_3.ps1

# %%
# Ejecuta el entrenamiento de forma automática
# !powershell -ExecutionPolicy Bypass -File "{powershell_script}"
import subprocess
import sys

# Ruta al script que generaste
powershell_script_path = powershell_script_test_3 

print(f"Iniciando ejecución de: {powershell_script_path}\n")

# Ejecutamos el proceso capturando la salida en tiempo real
process = subprocess.Popen(
    ["powershell.exe", "-ExecutionPolicy", "Bypass", "-File", powershell_script_path],
    stdout=subprocess.PIPE,
    stderr=subprocess.STDOUT, # Redirigimos errores a la salida estándar para verlos
    text=True,
    bufsize=1
)

# Leemos la salida línea a línea conforme se genera
try:
    for line in process.stdout:
        print(line, end="") # Imprime la salida de PowerShell en la celda
        sys.stdout.flush()   # Fuerza a Jupyter a mostrar la línea inmediatamente
except KeyboardInterrupt:
    process.kill()
    print("\nEntrenamiento cancelado por el usuario.")

process.wait()
print("\n--- Todos los experimentos de test han finalizado ---")
# Out:
# Iniciando ejecución de: C:/Users/Teresa/Documents/GitHub/navsim/isaac_lab/aerotaxi/env_command/env_13/grid_hiperparametros/cfg_files\run_tests_3.ps1
#
# Ejecutando Test final para Experimento 11...
# [INFO] Using python from: C:\Users\Teresa\miniconda3\envs\env_isaaclab\python.exe
# [INFO][AppLauncher]: Using device: cuda:0
# [INFO][AppLauncher]: Loading experience file: C:\Users\Teresa\miniconda3\envs\env_isaaclab\Lib\site-packages\isaaclab\apps\isaaclab.python.headless.kit
# Loading user config located at: 'c:/users/teresa/miniconda3/envs/env_isaaclab/lib/site-packages/isaacsim/kit/data/Kit/Isaac-Sim/5.1/user.config.json'
# [Info] [carb] Logging to file: c:/users/teresa/miniconda3/envs/env_isaaclab/lib/site-packages/isaacsim/kit/logs/Kit/Isaac-Sim/5.1/kit_20260304_132443.log
# 2026-03-04T12:24:44Z s] [Warning] [omni.usd_config.extension] Enable omni.materialx.libs extension to use MaterialX
# 2026-03-04T12:24:44Z s] [Warning] [carb] Acquiring non optional plugin interface which is not listed as dependency: [omni::physx::IPhysxBenchmarks v1.0] (plugin: <default plugin>), by client: omni.physics.physx.plugin. Add it to CARB_PLUGIN_IMPL_DEPS() macro of a client.
# 2026-03-04T12:24:44Z s] [Warning] [omni.isaac.dynamic_control] omni.isaac.dynamic_control is deprecated as of Isaac Sim 4.5. No action is needed from end-users.
# 2026-03-04T12:24:46Z [2,403ms] [Warning] [gpu.foundation.plugin] Skipping unsupported non-NVIDIA GPU: AMD Radeon(TM) Graphics
# 2026-03-04T12:24:46Z [2,404ms] [Warning] [gpu.foundation.plugin] Skipping unsupported non-NVIDIA GPU: AMD Radeon(TM) Graphics
#
# |---------------------------------------------------------------------------------------------|
# | Driver Version: 581.29        | Graphics API: D3D12
# |=============================================================================================|
# | GPU | Name                             | Active | LDA | GPU Memory | Vendor-ID | LUID       |
# |     |                                  |        |     |            | Device-ID | UUID       |
# |     |                                  |        |     |            | Bus-ID    |            |
# |---------------------------------------------------------------------------------------------|
# | 0   | NVIDIA GeForce RTX 5080          | Yes: 0 |     | 15889   MB | 10de      | 295a0100.. |
# |     |                                  |        |     |            | 2c02      | 0          |
# |     |                                  |        |     |            | 1         |            |
# |---------------------------------------------------------------------------------------------|
# | 1   | AMD Radeon(TM) Graphics          |        |     | 1995    MB | 1002      | 876d0100.. |
# |     |                                  |        |     |            | 13c0      | 0          |
# |     |                                  |        |     |            | N/A       |            |
# |=============================================================================================|
# | OS: Windows 11 Pro, Version: 10.0 (25H2), Build: 26200, Kernel: 10.0.26100.7824
# | Processor: AMD Ryzen 9 9950X 16-Core Processor
# | Cores: 16 | Logical Cores: 32
# |---------------------------------------------------------------------------------------------|
# | Total Memory (MB): 128627 | Free Memory: 102420
# | Total Page/Swap (MB): 136819 | Free Page/Swap: 104131
# |---------------------------------------------------------------------------------------------|
# C:\Users\Teresa\Documents\GitHub\navsim\isaac_lab\aerotaxi\env_command\env_13\flight_plan.py:29: UserWarning: Treat the new Tool classes introduced in v1.5 as experimental for now; the API and rcParam may change in future versions.
#   plt.rcParams["toolbar"] = "toolmanager"
# [INFO]: Parsing configuration from: aerotaxi.env_command.env_13.env:UAVEnvCfg
# [INFO]: Parsing configuration from: aerotaxi.env_command.env_13.grid_hiperparametros.cfg_files.ppo_random_command9_11_cfg:Command9PPORunnerCfg
# [INFO] Loading experiment from directory: C:\Users\Teresa\Documents\GitHub\navsim\isaac_lab\aerotaxi\env_command\env_13\logs\rsl_rl\command9
# Setting seed: 42
# [INFO]: Base environment:
# 	Environment device    : cuda:0
# 	Environment seed      : 42
# 	Physics step-size     : 0.005
# 	Rendering step-size   : 0.02
# 	Environment step-size : 0.02
# [INFO]: Time taken for scene creation : 1.058795 seconds
# [INFO]: Scene manager:  <class InteractiveScene>
# 	Number of environments: 256
# 	Environment spacing   : 200.0
# 	Source prim name      : /World/envs/env_0
# 	Global prim paths     : []
# 	Replicate physics     : False
# [INFO]: Starting the simulation. This may take a few seconds. Please wait...
# [INFO]: Time taken for simulation start : 0.386310 seconds
# [INFO] Command Manager:  <CommandManager> contains 1 active terms.
# +--------------------------------------+
# |         Active Command Terms         |
# +-------+-------------+----------------+
# | Index | Name        |      Type      |
# +-------+-------------+----------------+
# |   0   | vel_command | UAVcommandTerm |
# +-------+-------------+----------------+
#
# [INFO] Event Manager:  <EventManager> contains 1 active terms.
# +-----------------------------------+
# | Active Event Terms in Mode: 'reset' |
# +----------+------------------------+
# |  Index   | Name                   |
# +----------+------------------------+
# |    0     | reset_pos              |
# |    1     | randomize_mass         |
# |    2     | randomize_wind         |
# +----------+------------------------+
#
# [INFO] Recorder Manager:  <RecorderManager> contains 0 active terms.
# +---------------------+
# | Active Recorder Terms |
# +-----------+---------+
# |   Index   | Name    |
# +-----------+---------+
# +-----------+---------+
#
# [INFO] Action Manager:  <ActionManager> contains 1 active terms.
# +-----------------------------------+
# |   Active Action Terms (shape: 4)  |
# +--------+-------------+------------+
# | Index  | Name        |  Dimension |
# +--------+-------------+------------+
# |   0    | rotors_vel  |          4 |
# +--------+-------------+------------+
#
# [INFO] Observation Manager: <ObservationManager> contains 2 groups.
# +---------------------------------------------------------+
# | Active Observation Terms in Group: 'policy' (shape: (45,)) |
# +-----------+---------------------------------+-----------+
# |   Index   | Name                            |   Shape   |
# +-----------+---------------------------------+-----------+
# |     0     | dist                            |    (9,)   |
# |     1     | lin_vel                         |    (9,)   |
# |     2     | ang_vel                         |    (9,)   |
# |     3     | projected_gravity               |    (9,)   |
# |     4     | target_vel                      |    (9,)   |
# +-----------+---------------------------------+-----------+
# +---------------------------------------------------------+
# | Active Observation Terms in Group: 'critic' (shape: (45,)) |
# +-----------+---------------------------------+-----------+
# |   Index   | Name                            |   Shape   |
# +-----------+---------------------------------+-----------+
# |     0     | dist                            |    (9,)   |
# |     1     | lin_vel                         |    (9,)   |
# |     2     | ang_vel                         |    (9,)   |
# |     3     | projected_gravity               |    (9,)   |
# |     4     | target_vel                      |    (9,)   |
# +-----------+---------------------------------+-----------+
#
# [INFO] Termination Manager:  <TerminationManager> contains 4 active terms.
# +---------------------------------------+
# |        Active Termination Terms       |
# +-------+--------------------+----------+
# | Index | Name               | Time Out |
# +-------+--------------------+----------+
# |   0   | time_out           |   True   |
# |   1   | below_min_altitude |  False   |
# |   2   | bad_attitude       |  False   |
# |   3   | safety_shutdown    |  False   |
# +-------+--------------------+----------+
#
# [INFO] Reward Manager:  <RewardManager> contains 5 active terms.
# +------------------------------------------+
# |           Active Reward Terms            |
# +-------+-------------------------+--------+
# | Index | Name                    | Weight |
# +-------+-------------------------+--------+
# |   0   | rew_attitude_stability2 |    2.0 |
# |   1   | rew_ang_vel_stability4  |    1.0 |
# |   2   | rew_vel2                |    4.0 |
# |   3   | rew_pos2                |   12.0 |
# |   4   | rew_action_rate         |    0.8 |
# +-------+-------------------------+--------+
#
# [INFO] Curriculum Manager:  <CurriculumManager> contains 0 active terms.
# +----------------------+
# | Active Curriculum Terms |
# +-----------+----------+
# |   Index   | Name     |
# +-----------+----------+
# +-----------+----------+
#
# [INFO]: Completed setting up the environment...
# 2026-03-04T12:24:49Z [5,684ms] [Warning] [omni.physx.fabric.plugin] FabricManager::initializePointInstancer mismatched prototypes on point instancer: /Visuals/target_commands.
# [INFO]: Loading model checkpoint from: C:\Users\Teresa\Documents\GitHub\navsim\tmp\tmpTeresa\resultados_grid_command_v9\best_model_ppo_random_command9_11_4096.pt
# C:\Users\Teresa\miniconda3\envs\env_isaaclab\Lib\site-packages\rsl_rl\utils\utils.py:244: UserWarning: The observation configuration dictionary 'obs_groups' must contain the 'policy' key. As an observation group with the name 'policy' was found, this is assumed to be the observation set. Consider adding the 'policy' key to the 'obs_groups' dictionary for clarity. This behavior will be removed in a future version.
#   warnings.warn(
# C:\Users\Teresa\miniconda3\envs\env_isaaclab\Lib\site-packages\rsl_rl\utils\utils.py:282: UserWarning: The observation configuration dictionary 'obs_groups' must contain the 'critic' key. As an observation group with the name 'critic' was found, this is assumed to be the observation set. Consider adding the 'critic' key to the 'obs_groups' dictionary for clarity. This behavior will be removed in a future version.
#   warnings.warn(
# --------------------------------------------------------------------------------
# Resolved observation sets:
# 	 policy :  ['policy']
# 	 critic :  ['critic']
# --------------------------------------------------------------------------------
# Actor MLP: MLP(
#   (0): Linear(in_features=45, out_features=128, bias=True)
#   (1): ELU(alpha=1.0)
#   (2): Linear(in_features=128, out_features=128, bias=True)
#   (3): ELU(alpha=1.0)
#   (4): Linear(in_features=128, out_features=128, bias=True)
#   (5): ELU(alpha=1.0)
#   (6): Linear(in_features=128, out_features=4, bias=True)
# )
# Critic MLP: MLP(
#   (0): Linear(in_features=45, out_features=256, bias=True)
#   (1): ELU(alpha=1.0)
#   (2): Linear(in_features=256, out_features=256, bias=True)
#   (3): ELU(alpha=1.0)
#   (4): Linear(in_features=256, out_features=256, bias=True)
#   (5): ELU(alpha=1.0)
#   (6): Linear(in_features=256, out_features=1, bias=True)
# )
#
# --- Todos los experimentos de test han finalizado ---

# %%
import pandas as pd

df_train = top5_models.copy()
if df_train.index.name == 'id_run_name':
    df_train = df_train.reset_index()

df_train = df_train.rename(columns={
    'reward': 'reward_train',
    'max_reward': 'max_reward_train',
    'std_reward': 'std_train'
})

df_test = df_rewards_play.copy()

df_test = pd.read_csv(path_resultados+'/rewards_play_PPO.csv')
df_test = df_test.rename(columns={
    'reward': 'reward_test',
    'max_reward': 'max_reward_test',
    'std': 'std_test'
})

df_final = pd.merge(
    df_train[['id_run_name', 'num_envs_train', 'reward_train', 'max_reward_train', 'std_train', 'iteration']], 
    df_test[['id_run_name', 'num_envs_test', 'reward_test', 'max_reward_test', 'std_test', 'checkpoint']], 
    on='id_run_name', 
    how='inner'
)

column_order = [
    'id_run_name',
    'num_envs_train',
    'num_envs_test',
    'reward_train', 'reward_test', 
    'max_reward_train', 'max_reward_test', 
    'std_train', 'std_test',
    'iteration'
]
df_final = df_final[column_order]

df_final = df_final.sort_values(by='id_run_name', ascending=False)

# %%
df_rewards_play = df_final.sort_values(by="id_run_name",ascending=False)
df_rewards_play = df_rewards_play.reset_index().drop(columns='index')

df_final = df_rewards_play.copy()

df_final['diff_rw_test_train'] = df_final['reward_test'] - df_final['reward_train']

df_final['diferencia(%)'] = (df_final['diff_rw_test_train'] / df_final['reward_train'].abs()) * 100

df_final['diferencia(%)'] = df_final['diferencia(%)'].apply(lambda x: f"{x:+.2f}%")

df_final
# Out:
#               id_run_name  num_envs_train  num_envs_test  reward_train  \
# 0  ppo_random_command9_11            4096              1    261.502937
# 1  ppo_random_command9_11            4096             64    261.502937
# 2  ppo_random_command9_11            4096            256    261.502937
#
#    reward_test  max_reward_train  max_reward_test  std_train   std_test  \
# 0   124.907200        429.041992       124.907200  69.079971   0.000000
# 1   102.012420        429.041992       269.005353  69.079971  64.305084
# 2   103.153701        429.041992       318.718204  69.079971  67.180449
#
#    iteration  diff_rw_test_train diferencia(%)
# 0        917         -136.595737       -52.23%
# 1        917         -159.490517       -60.99%
# 2        917         -158.349236       -60.55%

# %% [markdown]
# Pruebas con un solo entorno: Vemos cómo se comporta la política para un único agente en una prueba aleatoria.

# %%
df_final[df_final['num_envs_test'] == 1].sort_values(by='reward_test',ascending=False)
# Out:
#               id_run_name  num_envs_train  num_envs_test  reward_train  \
# 0  ppo_random_command9_11            4096              1    261.502937
#
#    reward_test  max_reward_train  max_reward_test  std_train  std_test  \
# 0     124.9072        429.041992         124.9072  69.079971       0.0
#
#    iteration  diff_rw_test_train diferencia(%)
# 0        917         -136.595737       -52.23%

# %% [markdown]
# ``Interpretación``: Vemos que el modelo 38 se ha estampado en la prueba aleatoria, así que ese modelo no debería usarse para ninguna transferencia real.

# %% [markdown]
# Pruebas con varios entornos: Vemos cómo se comporta la política en múltiples entornos (varias pruebas simuladas en paralelo), teniendo en cuenta cuál es la desviación de cada uno en test, lo que nos permite inferir si la recompensa es estable para todas las pruebas.

# %%
df_final[df_final['num_envs_test'] != 1].sort_values(by='std_test',ascending=True).reset_index().drop(columns="index")
# Out:
#               id_run_name  num_envs_train  num_envs_test  reward_train  \
# 0  ppo_random_command9_11            4096             64    261.502937
# 1  ppo_random_command9_11            4096            256    261.502937
#
#    reward_test  max_reward_train  max_reward_test  std_train   std_test  \
# 0   102.012420        429.041992       269.005353  69.079971  64.305084
# 1   103.153701        429.041992       318.718204  69.079971  67.180449
#
#    iteration  diff_rw_test_train diferencia(%)
# 0        917         -159.490517       -60.99%
# 1        917         -158.349236       -60.55%

# %% [markdown]
# pruebas:

# %% [markdown]
# C:/Users/Teresa/Desktop/RuralData/IsaacLab/IsaacLab/isaaclab.bat -p C:/Users/Teresa/Documents/GitHub/navsim/isaac_lab/rl_v5_1_0/rsl_rl/train.py --task Isaac-Command5-Aerotaxi-RANDOM-11 --num_envs 8196 --headless
